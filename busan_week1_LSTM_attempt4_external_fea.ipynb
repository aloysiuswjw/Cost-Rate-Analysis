# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Dropout, LSTM, Dense
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from IPython.core.interactiveshell import InteractiveShell
from sklearn.preprocessing import MinMaxScaler
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline
sns.set()
pd.options.display.max_rows = 100

# %% [markdown]
# <h4>Importing Datasets</h4>

# %%
# Import dataset and clean, ready as a dataframe for creating keys
def createDF(datasets):
    df = pd.read_csv(datasets, converters={'PARTY_ID': str, 'COM_ID': str, 'CNTR_SIZE': str})

    # Formating to type and remove NaN values
    df['POD'] = pd.to_datetime(df['POD'])
    df['ENCODED_TYPE'] = df['ENCODED_TYPE'].fillna(-1).astype(int)
    df = df.dropna(subset=['ENCODED_TYPE'])
    df['RATE'] = df['RATE'].fillna(-1).astype(float)
    df = df.dropna(subset=['RATE'])
    df['ENCODED_TYPE'] = df['ENCODED_TYPE'].astype(int)
    df_clean= df.dropna().reset_index(drop=True)

    # Selecting and rearranging columns
    sel_col = ['CSL_ID', 'CNTR_ID','POD_ID','ETD_POL_D','PARTY_ID',
            'PARTY_NAME','POD','CNTR_SIZE','CNTR_TYPE','RATE']
    df_fc = df_clean[sel_col]

    # Removing years we do not want to process in our models
    df_filtered = df_fc[df_fc['POD'].dt.year != 2002]

    # Sorting the dates
    df_filtered = df_filtered.sort_values(by='POD').reset_index(drop=True)
    
    return df_filtered

# %%
# Create Dataframes for old and new
old_data = '.\Datasets\CR_COST_FC.csv'
df1 = createDF(old_data)
df1.head()

new_data = '.\Datasets\CR_COST_FC_new.csv'
df2 = createDF(new_data)
df2.head()
# Out:
#            CSL_ID           CNTR_ID          POD_ID ETD_POL_D  PARTY_ID  \
# 0  ECS01050600224  CTNR010050700354       ROTTERDAM     NLRTM  01008827
# 1  ECS01050600610  CTNR010050700353      FELIXSTOWE     GBFXT  01002303
# 2  ECS01050600041  CTNR010050700351        AUCKLAND     NZAKL  01005136
# 3  ECS01050600163  CTNR010050700370    PASIR GUDANG     MYPGU  01002767
# 4  ECS01050600456  CTNR010050700450  KARACHI (KICT)     PKKHI  01002783
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0             YANG MING (SINGAPORE) PTE. LTD. 2005-07-15        40    HC NOR
# 1                    GLOBELINK FALLOW LIMITED 2005-07-15        40        GP
# 2  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-15        40    HC NOR
# 3          GLOBELINK CONTAINER LINES (JB) S/B 2005-07-15        40        HC
# 4                GLOBELINK PAKISTAN (PVT) LTD 2005-07-16        40        HC
#
#      RATE
# 0  1620.0
# 1  1800.0
# 2  2170.0
# 3   280.0
# 4  1625.0
#            CSL_ID           CNTR_ID          POD_ID ETD_POL_D  PARTY_ID  \
# 0  ECS01050600224  CTNR010050700354       ROTTERDAM     NLRTM  01008827
# 1  ECS01050600610  CTNR010050700353      FELIXSTOWE     GBFXT  01002303
# 2  ECS01050600041  CTNR010050700351        AUCKLAND     NZAKL  01005136
# 3  ECS01050600163  CTNR010050700370    PASIR GUDANG     MYPGU  01002767
# 4  ECS01050600456  CTNR010050700450  KARACHI (KICT)     PKKHI  01002783
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0             YANG MING (SINGAPORE) PTE. LTD. 2005-07-15        40    HC NOR
# 1                    GLOBELINK FALLOW LIMITED 2005-07-15        40        GP
# 2  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-15        40    HC NOR
# 3          GLOBELINK CONTAINER LINES (JB) S/B 2005-07-15        40        HC
# 4                GLOBELINK PAKISTAN (PVT) LTD 2005-07-16        40        HC
#
#      RATE
# 0  1620.0
# 1  1800.0
# 2  2170.0
# 3   280.0
# 4  1625.0

# %% [markdown]
# <h4>Creating Dictionary Keys</h4>

# %%
def filter_dataframe(df):
    filtered_dataframes = {}

    for (port, size, ctype, party_id), group in df.groupby(['POD_ID', 'CNTR_SIZE', 'CNTR_TYPE', 'PARTY_ID']):
        group = group.reset_index(drop=True).sort_values(by='POD')
        df_id = f"Port_{port}_Size_{size}_Type_{ctype}_PartyID_{party_id}"
        filtered_dataframes[df_id] = group

    return filtered_dataframes

# %%
# Creating keys from data
print("Old Data keys:")
filtered_dataframe1 = filter_dataframe(df1)
df_ids1 = list(filtered_dataframe1.keys())
print(list(df_ids1))
print(len(list(df_ids1)))

print("\nNew Data keys:")
filtered_dataframe2 = filter_dataframe(df2)
df_ids2 = list(filtered_dataframe2.keys())
print(list(df_ids2))
print(len(list(df_ids2)))
# Out:
# Old Data keys:
# ['Port_(CONSTANZA)_Size_40_Type_GP_PartyID_010007816', 'Port_(CONSTANZA)_Size_40_Type_HC_PartyID_010007816', 'Port_AARHUS_Size_20_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100027830', 'Port_AARHUS_Size_20_Type_GP_PartyID_010006666', 'Port_AARHUS_Size_40_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100027830', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100028193', 'Port_AARHUS_Size_40_Type_HC_PartyID_010006666', 'Port_ABIDJAN_Size_20_Type_GP_PartyID_0100027878', 'Port_ABIDJAN_Size_40_Type_HC_PartyID_010021097', 'Port_ADELAIDE_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01005078', 'Port_ADELAIDE_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ALEXANDRIA (EL DEKHELA PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC NOR_PartyID_010004995', 'Port_ALGECIRAS_Size_20_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC NOR_PartyID_01008306', 'Port_ALIAGA_Size_20_Type_GP_PartyID_01008316', 'Port_ALIAGA_Size_40_Type_HC_PartyID_01008316', 'Port_ALIAGA PORT (IZMIR)_Size_40_Type_HC_PartyID_01008316', 'Port_ANTWERP_Size_20_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC NOR_PartyID_01001449', 'Port_AQABA_Size_20_Type_GP_PartyID_010006618', 'Port_AQABA_Size_20_Type_GP_PartyID_010021081', 'Port_AQABA_Size_40_Type_HC_PartyID_010006618', 'Port_AQABA_Size_40_Type_HC_PartyID_010021081', 'Port_ASHDOD_Size_20_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_01008417', 'Port_ASHDOD_Size_40_Type_HC_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_HC_PartyID_01008417', 'Port_AUCKLAND_Size_20_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_20_Type_GP (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC NOR_PartyID_01005136', 'Port_BANGKOK_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_20_Type_GP (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (SOC)_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK (TST)_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK (TST)_Size_40_Type_HC_PartyID_010021593', 'Port_BARCELONA_Size_20_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC NOR_PartyID_01008305', 'Port_BEIRUT_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_HC_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_40_Type_HC_PartyID_0100 ...
# 789
#
# New Data keys:
# ['Port_(CONSTANZA)_Size_40_Type_GP_PartyID_010007816', 'Port_(CONSTANZA)_Size_40_Type_HC_PartyID_010007816', 'Port_AARHUS_Size_20_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100027830', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100028193', 'Port_AARHUS_Size_20_Type_GP_PartyID_010006666', 'Port_AARHUS_Size_40_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100027830', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100028193', 'Port_AARHUS_Size_40_Type_HC_PartyID_010006666', 'Port_ABIDJAN_Size_20_Type_GP_PartyID_0100027878', 'Port_ABIDJAN_Size_40_Type_HC_PartyID_010021097', 'Port_ADELAIDE_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01005078', 'Port_ADELAIDE_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ALEXANDRIA (EL DEKHELA PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC NOR_PartyID_010004995', 'Port_ALGECIRAS_Size_20_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC NOR_PartyID_01008306', 'Port_ALIAGA_Size_20_Type_GP_PartyID_01008316', 'Port_ALIAGA_Size_40_Type_HC_PartyID_01008316', 'Port_ALIAGA PORT (IZMIR)_Size_40_Type_HC_PartyID_01008316', 'Port_ANTWERP_Size_20_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC NOR_PartyID_01001449', 'Port_AQABA_Size_20_Type_GP_PartyID_010006618', 'Port_AQABA_Size_20_Type_GP_PartyID_010021081', 'Port_AQABA_Size_40_Type_HC_PartyID_010006618', 'Port_AQABA_Size_40_Type_HC_PartyID_010021081', 'Port_ASHDOD_Size_20_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_01008417', 'Port_ASHDOD_Size_40_Type_HC_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_HC_PartyID_01008417', 'Port_AUCKLAND_Size_20_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_20_Type_GP (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC NOR_PartyID_01005136', 'Port_BANGKOK_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_20_Type_GP (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (SOC)_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK (TST)_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK (TST)_Size_40_Type_HC_PartyID_010021593', 'Port_BARCELONA_Size_20_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC NOR_PartyID_01008305', 'Port_BEIRUT_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_HC_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_20_Type_GP_PartyID_010003651', ' ...
# 799

# %% [markdown]
# <h4>Getting Top 5 ports keys</h4>

# %%
def getTop5Ports(keybunch):
    keybunch_pouch = []
    
    # Get a dictionary with key and number of rows for each dataframe in filtered_dataframes
    key_row_counts = {key: len(keybunch[key]) for key in keybunch}

    # Sort the key_row_counts dictionary by value (number of rows) in descending order
    sorted_key_row_counts = sorted(key_row_counts.items(), key=lambda item: item[1], reverse=True)

    # Get the top 5 keys with the most rows
    top_5_keys_tuple = sorted_key_row_counts[:5]

    # Create a dictionary with the top 5 keys and their corresponding dataframes (with up to 5 rows per dataframe)
    keybunch_subset = {}

    for key, row_count in top_5_keys_tuple:
        keybunch_subset[key] = keybunch[key][:5]
        print(f"Number of rows in {key}: {row_count}")
        keybunch_pouch.append(key)
    
    # Return array of keys
    return keybunch_pouch

# %%
print('Old Dataset Keybunch:')
old_df = getTop5Ports(filtered_dataframe1)
print('\n')

print('New Dataset Keybunch:')
new_df = getTop5Ports(filtered_dataframe2)
# Out:
# Old Dataset Keybunch:
# Number of rows in Port_BUSAN_Size_40_Type_HC_PartyID_010004286: 1689
# Number of rows in Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136: 1688
# Number of rows in Port_MELBOURNE_Size_40_Type_HC_PartyID_01002778: 1325
# Number of rows in Port_SYDNEY_Size_40_Type_HC_PartyID_01002779: 1300
# Number of rows in Port_DUBAI (JEBEL ALI)_Size_40_Type_HC_PartyID_01002788: 1052
#
#
# New Dataset Keybunch:
# Number of rows in Port_BUSAN_Size_40_Type_HC_PartyID_010004286: 1712
# Number of rows in Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136: 1704
# Number of rows in Port_MELBOURNE_Size_40_Type_HC_PartyID_01002778: 1341
# Number of rows in Port_SYDNEY_Size_40_Type_HC_PartyID_01002779: 1308
# Number of rows in Port_DUBAI (JEBEL ALI)_Size_40_Type_HC_PartyID_01002788: 1070

# %%
# Accessing the highest count in the each keypouch, new and old.
sel_df = filtered_dataframe1[old_df[2]]
sel_df.head(5)
sel_df.tail(5)
sel_df.info()
print("\n")

latest_sel_df = filtered_dataframe2[new_df[2]]
latest_sel_df.head(5)
latest_sel_df.tail(5)
latest_sel_df.info()
# Out:
#             CSL_ID           CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 0   ECS01050600278  CTNR010050700692  MELBOURNE     AUMEL  01002778
# 1   ECS01050600280  CTNR010050701022  MELBOURNE     AUMEL  01002778
# 2  ECS010050700458  CTNR010050800604  MELBOURNE     AUMEL  01002778
# 3  ECS010050700214  CTNR010050800727  MELBOURNE     AUMEL  01002778
# 4  ECS010050900271  CTNR010051000178  MELBOURNE     AUMEL  01002778
#
#                                   PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-07-23        40        HC
# 1  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-07-30        40        HC
# 2  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-08-16        40        HC
# 3  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-08-19        40        HC
# 4  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-10-11        40        HC
#
#      RATE
# 0  1200.0
# 1  1200.0
# 2  1000.0
# 3  1200.0
# 4   900.0
#                CSL_ID       CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 1320  ECS010230100302  010000357415  MELBOURNE     AUMEL  01002778
# 1321  ECS010230100303  010000380481  MELBOURNE     AUMEL  01002778
# 1323  ECS010230100304  010000392586  MELBOURNE     AUMEL  01002778
# 1322  ECS010230100304  010000390964  MELBOURNE     AUMEL  01002778
# 1324  ECS010230100304  010000399293  MELBOURNE     AUMEL  01002778
#
#                                      PARTY_NAME        POD CNTR_SIZE  \
# 1320  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-02-11        40
# 1321  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-02-16        40
# 1323  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-02-24        40
# 1322  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-02-24        40
# 1324  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-02-24        40
#
#      CNTR_TYPE    RATE
# 1320        HC  1200.0
# 1321        HC  1200.0
# 1323        HC  1200.0
# 1322        HC  1200.0
# 1324        HC  1200.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1325 entries, 0 to 1324
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      1325 non-null   object
#  1   CNTR_ID     1325 non-null   object
#  2   POD_ID      1325 non-null   object
#  3   ETD_POL_D   1325 non-null   object
#  4   PARTY_ID    1325 non-null   object
#  5   PARTY_NAME  1325 non-null   object
#  6   POD         1325 non-null   datetime64[ns]
#  7   CNTR_SIZE   1325 non-null   object
#  8   CNTR_TYPE   1325 non-null   object
#  9   RATE        1325 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 113.9+ KB
#             CSL_ID           CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 0   ECS01050600278  CTNR010050700692  MELBOURNE     AUMEL  01002778
# 1   ECS01050600280  CTNR010050701022  MELBOURNE     AUMEL  01002778
# 2  ECS010050700458  CTNR010050800604  MELBOURNE     AUMEL  01002778
# 3  ECS010050700214  CTNR010050800727  MELBOURNE     AUMEL  01002778
# 4  ECS010050900271  CTNR010051000178  MELBOURNE     AUMEL  01002778
#
#                                   PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-07-23        40        HC
# 1  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-07-30        40        HC
# 2  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-08-16        40        HC
# 3  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-08-19        40        HC
# 4  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-10-11        40        HC
#
#      RATE
# 0  1200.0
# 1  1200.0
# 2  1000.0
# 3  1200.0
# 4   900.0
#                CSL_ID       CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 1336  ECS010230300518  010000531211  MELBOURNE     AUMEL  01002778
# 1337  ECS010230300518  010000509487  MELBOURNE     AUMEL  01002778
# 1338  ECS010230400431  010000541165  MELBOURNE     AUMEL  01002778
# 1339  ECS010230400432  010000543217  MELBOURNE     AUMEL  01002778
# 1340  ECS010230400433  010000557443  MELBOURNE     AUMEL  01002778
#
#                                      PARTY_NAME        POD CNTR_SIZE  \
# 1336  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-04-28        40
# 1337  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-04-28        40
# 1338  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-05        40
# 1339  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-11        40
# 1340  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-19        40
#
#      CNTR_TYPE   RATE
# 1336        HC  500.0
# 1337        HC  500.0
# 1338        HC  500.0
# 1339        HC  500.0
# 1340        HC  400.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1341 entries, 0 to 1340
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      1341 non-null   object
#  1   CNTR_ID     1341 non-null   object
#  2   POD_ID      1341 non-null   object
#  3   ETD_POL_D   1341 non-null   object
#  4   PARTY_ID    1341 non-null   object
#  5   PARTY_NAME  1341 non-null   object
#  6   POD         1341 non-null   datetime64[ns]
#  7   CNTR_SIZE   1341 non-null   object
#  8   CNTR_TYPE   1341 non-null   object
#  9   RATE        1341 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 115.2+ KB

# %%
# Select features
sel_feat = ['POD','RATE']
df_minmax = sel_df[sel_feat].copy()  # make a copy to avoid SettingWithCopyWarning

# Min-Max Scaling
scaler = MinMaxScaler()
df_minmax['RATE'] = scaler.fit_transform(df_minmax[['RATE']])

# %%
# Check if the DataFrame has any NaN values
if df_minmax.isna().any().any():
    print("The DataFrame contains NaN values.")
else:
    print("The DataFrame does not contain NaN values.")
# Out:
# The DataFrame does not contain NaN values.

# %% [markdown]
# <h4>Interpolate missing values in between dates</h4>

# %%
# Remove duplicated dates and cost rows
df_minmax = df_minmax.drop_duplicates(subset=['POD', 'RATE']).reset_index(drop=True)

# Create a new dataframe with a date range from min to max date in your dataframe
new_df = pd.DataFrame()
new_df['POD'] = pd.date_range(start=df_minmax['POD'].min(), end=df_minmax['POD'].max())

# Merge the original dataframe with the new one. Missing dates in the original dataframe will be filled with NaN
df_interpolated = pd.merge(new_df, df_minmax, on='POD', how='left')  

# Perform spline interpolation
df_interpolated['RATE'] = df_interpolated['RATE'].interpolate(method='polynomial', order=1)

df_interpolated['RATE'] = df_interpolated['RATE'].round(3)

# Now we need to inverse the scaling
df_interpolated['RATE'] = scaler.inverse_transform(df_interpolated[['RATE']])

df_interpolated.head(5)
df_interpolated.tail(5)
df_interpolated.info()
# Out:
#          POD     RATE
# 0 2005-07-23  1200.47
# 1 2005-07-24  1200.47
# 2 2005-07-25  1200.47
# 3 2005-07-26  1200.47
# 4 2005-07-27  1200.47
#             POD     RATE
# 6441 2023-02-20  1200.47
# 6442 2023-02-21  1200.47
# 6443 2023-02-22  1200.47
# 6444 2023-02-23  1200.47
# 6445 2023-02-24  1200.47
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6446 entries, 0 to 6445
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POD     6446 non-null   datetime64[ns]
#  1   RATE    6446 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 151.1 KB

# %% [markdown]
# <h4>Grouping it to week</h4>

# %%
from scipy import stats

# Create YearMonthWeek directly from the 'POD'
df_interpolated['YearMonthWeek'] = df_interpolated['POD'] - pd.to_timedelta(df_interpolated['POD'].dt.dayofweek, unit='D')

# Create a new dataframe with every week in the range
all_weeks = pd.date_range(start=df_interpolated['POD'].min(), end=df_interpolated['POD'].max(), freq='W')
all_weeks_df = pd.DataFrame(all_weeks, columns=['POD'])

# Create YearMonthWeek in all_weeks_df
all_weeks_df['YearMonthWeek'] = all_weeks_df['POD'] - pd.to_timedelta(all_weeks_df['POD'].dt.dayofweek, unit='D')

# Merge this with your original dataframe
merged_df = pd.merge(all_weeks_df, df_interpolated, on=['YearMonthWeek'], how='left')

# Now you can group by YearMonthWeek and compute your rate
grouped = merged_df.groupby(['YearMonthWeek'])

agg_df = pd.DataFrame(columns=['YearMonthWeek', 'Rate'])

for group_name, group_df in grouped:
    year_month_week = group_name

    # Skip if no data for this week
    if group_df['RATE'].isnull().all():
        continue

    # Calculate sum and skewness of RATE values
    rate_sum = group_df['RATE'].sum()
    rate_skew = group_df['RATE'].skew()

    # Calculate trimmed mean of RATE values
    rate_metric = stats.trim_mean(group_df['RATE'].dropna().values, 0.1) # trimming 10% from each end

    new_row = {
        'YearMonthWeek': year_month_week,
        'Rate': rate_metric
    }

    # Append row to aggregated dataframe
    agg_df = agg_df.append(new_row, ignore_index=True)

agg_df = agg_df.sort_values(by='YearMonthWeek').reset_index(drop=True)
agg_df['Rate'] = agg_df['Rate'].round(2)

agg_df.head(15)
agg_df.tail(15)
agg_df.info()
# Out:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:21: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for group_name, group_df in grouped:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# ...
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
#    YearMonthWeek     Rate
# 0     2005-07-18  1200.47
# 1     2005-07-25  1198.39
# 2     2005-08-01  1141.27
# 3     2005-08-08  1059.22
# 4     2005-08-15  1113.23
# 5     2005-08-22  1166.20
# 6     2005-08-29  1125.69
# 7     2005-09-05  1087.27
# 8     2005-09-12  1046.76
# 9     2005-09-19  1007.30
# 10    2005-09-26   967.83
# 11    2005-10-03   928.36
# 12    2005-10-10   902.40
# 13    2005-10-17   902.40
# 14    2005-10-24   902.40
#     YearMonthWeek     Rate
# 903    2022-11-07  3003.43
# 904    2022-11-14  4445.62
# 905    2022-11-21  3027.32
# 906    2022-11-28  2861.15
# 907    2022-12-05  2571.38
# 908    2022-12-12  2400.02
# 909    2022-12-19  2400.02
# 910    2022-12-26  2308.63
# 911    2023-01-02  2091.56
# 912    2023-01-09  2000.17
# 913    2023-01-16  1842.31
# 914    2023-01-23  1798.69
# 915    2023-01-30  1390.53
# 916    2023-02-06  1200.47
# 917    2023-02-13  1200.47
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   YearMonthWeek  918 non-null    datetime64[ns]
#  1   Rate           918 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 14.5 KB

# %% [markdown]
# <h4>Handle Outliers with external feature</h4>

# %%
# Creating a feature to mark the COVID period
agg_df = agg_df[['YearMonthWeek','Rate']].copy()

# Create a new column indicating whether each month is affected by COVID-19
agg_df['Covid'] = 0
agg_df['YearMonthWeek'] = pd.to_datetime(agg_df['YearMonthWeek'])
agg_df.loc[(agg_df['YearMonthWeek'] >= pd.to_datetime('2020-01')) & 
           (agg_df['YearMonthWeek'] <= pd.to_datetime('2023-01')), 'Covid'] = 1


# Just to preview entries that is marked as covid:
agg_df_covid = agg_df[agg_df['Covid'] == 1]
print("Covid entries preview:")
agg_df_covid.head()
print("\n")

print("Done feature enginering dataframe:")
agg_df.head()
agg_df.tail()
agg_df.info()
# Out:
# Covid entries preview:
#     YearMonthWeek    Rate  Covid
# 755    2020-01-06  502.55      1
# 756    2020-01-13  502.55      1
# 757    2020-01-20  502.55      1
# 758    2020-01-27  502.55      1
# 759    2020-02-03  502.55      1
# Done feature enginering dataframe:
#   YearMonthWeek     Rate  Covid
# 0    2005-07-18  1200.47      0
# 1    2005-07-25  1198.39      0
# 2    2005-08-01  1141.27      0
# 3    2005-08-08  1059.22      0
# 4    2005-08-15  1113.23      0
#     YearMonthWeek     Rate  Covid
# 913    2023-01-16  1842.31      0
# 914    2023-01-23  1798.69      0
# 915    2023-01-30  1390.53      0
# 916    2023-02-06  1200.47      0
# 917    2023-02-13  1200.47      0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   YearMonthWeek  918 non-null    datetime64[ns]
#  1   Rate           918 non-null    float64
#  2   Covid          918 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 21.6 KB

# %% [markdown]
# <h4>Latest datapoints from Latest dataframe for comparing after forecasting (Measure accuracy)</h4>

# %%
max_date_in_old = sel_df['POD'].max()

# Create a new dataframe that only includes rows from the latest dataframe where the date is greater than the maximum date in the old dataframe
new_dates_df = latest_sel_df[latest_sel_df['POD'] > max_date_in_old].reset_index(drop=True)

# Print the new dataframe
new_dates_df.head(3)
new_dates_df.tail(3)
new_dates_df.info()
# Out:
#             CSL_ID       CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 0  ECS010230200328  010000409869  MELBOURNE     AUMEL  01002778
# 1  ECS010230200329  010000419018  MELBOURNE     AUMEL  01002778
# 2  ECS010230200330  010000427048  MELBOURNE     AUMEL  01002778
#
#                                   PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-03-02        40        HC
# 1  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-03-10        40        HC
# 2  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-03-16        40        HC
#
#      RATE
# 0  1000.0
# 1  1000.0
# 2  1000.0
#              CSL_ID       CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 13  ECS010230400431  010000541165  MELBOURNE     AUMEL  01002778
# 14  ECS010230400432  010000543217  MELBOURNE     AUMEL  01002778
# 15  ECS010230400433  010000557443  MELBOURNE     AUMEL  01002778
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 13  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-05        40        HC
# 14  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-11        40        HC
# 15  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-19        40        HC
#
#      RATE
# 13  500.0
# 14  500.0
# 15  400.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      16 non-null     object
#  1   CNTR_ID     16 non-null     object
#  2   POD_ID      16 non-null     object
#  3   ETD_POL_D   16 non-null     object
#  4   PARTY_ID    16 non-null     object
#  5   PARTY_NAME  16 non-null     object
#  6   POD         16 non-null     datetime64[ns]
#  7   CNTR_SIZE   16 non-null     object
#  8   CNTR_TYPE   16 non-null     object
#  9   RATE        16 non-null     float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 1.4+ KB

# %%
plt.figure(figsize=(20, 10))
plt.plot(sel_df['POD'], sel_df['RATE'], color='blue', label="Actual Data")
plt.plot(agg_df['YearMonthWeek'], agg_df['Rate'], color='red', label="Aggregated Data(weeks)")

plt.xlabel('Date(Year Month Week)')
plt.ylabel('Cost Rate(USD)')
plt.title('Port_BUSAN_Size_40_Type_HC_PartyID_010004286')
plt.legend()
plt.show();

# %% [markdown]
# <h4>LSTM Regression<h4>

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# Mean Square Error Function:
def calculate_RMSE(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# Update create_dataset to handle multi-feature dataset
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), :]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)


def create_LSTM_model(trainX, trainY, testX, testY, epochs, lstm_layers):
    model = Sequential()
    
    for i in range(len(lstm_layers)):
        if i == 0:
            # First layer specifies the input_shape and returns sequences
            model.add(LSTM(lstm_layers[i], return_sequences=True, input_shape=(look_back, trainX.shape[2]), 
                           activation='tanh', recurrent_activation='hard_sigmoid', kernel_regularizer=l2(0.01)))
        elif i == len(lstm_layers) - 1:
            # Last layer doesn't return sequences
            model.add(LSTM(lstm_layers[i], activation='tanh', kernel_regularizer=l2(0.01)))
        else:
            # Middle layers return sequences
            model.add(LSTM(lstm_layers[i], return_sequences=True, activation='tanh', 
                           recurrent_activation='hard_sigmoid', kernel_regularizer=l2(0.01)))
        model.add(Dropout(0.2))
        
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=0.0005))
    model.summary()

    # Add early stopping
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)
    
    # Fit the model and store the history
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=128, verbose=2, 
                        validation_data=(testX, testY), callbacks=[es])
    return model, history


def plot_train_val_loss(history):
    plt.figure(figsize=(10,6))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model loss progress during training and validation')
    plt.xlabel('Epoch')
    plt.ylabel('Training and Validation Loss')
    plt.legend()
    plt.show()

# %%
# Normalize dataset for LSTM
from sklearn.preprocessing import MinMaxScaler

# Initialize two separate scalers
scaler_rate = MinMaxScaler(feature_range=(0, 1))
scaler_covid = MinMaxScaler(feature_range=(0, 1))

# Fit and transform 'RATE' and 'during_covid' separately
rate_scaled = scaler_rate.fit_transform(agg_df[['Rate']])
covid_scaled = scaler_covid.fit_transform(agg_df[['Covid']])

# Concatenate the scaled data
dataset = np.concatenate([rate_scaled, covid_scaled], axis=1)

# Split into train and test sets
train_size = int(len(dataset) * 0.7)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# Reshape into X=t and Y=t+1, timestep  look_back
look_back = 5
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# Reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], look_back, trainX.shape[2]))
testX = np.reshape(testX, (testX.shape[0], look_back, testX.shape[2]))

epochs_list = [50, 100, 150]

lstm_layers_list = [
    [64, 64, 32, 32, 16, 16, 8, 8, 4, 4, 2, 2],
    [32, 32, 16, 16, 8, 8, 4, 4, 2, 2],
    [16, 16, 8, 8, 4, 4, 2, 2],
    [8, 8, 4, 4, 2, 2],
    [4, 4, 2, 2],
    [2, 2]
]

rmse_results = {}

for epochs in epochs_list:
    print(f'Training for {epochs} epochs...')
    
    for lstm_layers in lstm_layers_list:
        print(f'Training with LSTM layers: {lstm_layers}')
        model, history = create_LSTM_model(trainX, trainY, testX, testY, epochs, lstm_layers)
        
        # Add the loss for this model to the plot
        plt.plot(history.history['loss'], label=f'Train Loss - {epochs} epochs, layers: {lstm_layers}')
        plt.plot(history.history['val_loss'], label=f'Validation Loss - {epochs} epochs, layers: {lstm_layers}')

        # Evalute LSTM Model
        trainPredict = model.predict(trainX)
        testPredict = model.predict(testX)

        # inverse_transform
        trainPredict = scaler.inverse_transform(trainPredict)
        trainY_orig = scaler.inverse_transform([trainY])
        testPredict = scaler.inverse_transform(testPredict)
        testY_orig = scaler.inverse_transform([testY])

        # Calculate mean squared error
        trainScore = calculate_RMSE(trainY_orig[0], trainPredict[:,0])
        print(f'Train Score: {trainScore:.2f} RMSE for {epochs} epochs')
        testScore = calculate_RMSE(testY_orig[0], testPredict[:,0])
        print(f'Test Score: {testScore:.2f} RMSE for {epochs} epochs')

        rmse_results[f'{epochs} epochs, {lstm_layers} layers'] = {'Train RMSE': trainScore, 'Test RMSE': testScore}

# Configure and show the plot
plt.title('Model loss progress during training and validation')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend()
plt.show();

# Convert the dictionary to a DataFrame for easy display
rmse_df = pd.DataFrame(rmse_results).T
print(rmse_df)
# Out:
# Training for 50 epochs...
# Training with LSTM layers: [64, 64, 32, 32, 16, 16, 8, 8, 4, 4, 2, 2]
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_74 (LSTM)              (None, 5, 64)             17152
#
#  dropout_37 (Dropout)        (None, 5, 64)             0
#
#  lstm_75 (LSTM)              (None, 5, 64)             33024
#
#  dropout_38 (Dropout)        (None, 5, 64)             0
#
#  lstm_76 (LSTM)              (None, 5, 32)             12416
#
#  dropout_39 (Dropout)        (None, 5, 32)             0
#
#  lstm_77 (LSTM)              (None, 5, 32)             8320
#
#  dropout_40 (Dropout)        (None, 5, 32)             0
#
#  lstm_78 (LSTM)              (None, 5, 16)             3136
#
#  dropout_41 (Dropout)        (None, 5, 16)             0
#
#  lstm_79 (LSTM)              (None, 5, 16)             2112
#
#  dropout_42 (Dropout)        (None, 5, 16)             0
#
#  lstm_80 (LSTM)              (None, 5, 8)              800
#
#  dropout_43 (Dropout)        (None, 5, 8)              0
#
#  lstm_81 (LSTM)              (None, 5, 8)              544
#
#  dropout_44 (Dropout)        (None, 5, 8)              0
#
#  lstm_82 (LSTM)              (None, 5, 4)              208
#
#  dropout_45 (Dropout)        (None, 5, 4)              0
#
#  lstm_83 (LSTM)              (None, 5, 4)              144
#
#  dropout_46 (Dropout)        (None, 5, 4)              0
#
#  lstm_84 (LSTM)              (None, 5, 2)              56
#
#  dropout_47 (Dropout)        (None, 5, 2)              0
#
#  lstm_85 (LSTM)              (None, 2)                 40
#
#  dropout_48 (Dropout)        (None, 2)                 0
#
#  dense_17 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 77,955
# Trainable params: 77,955
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 26s - loss: 3.6710 - val_loss: 3.7689 - 26s/epoch - 5s/step
# Epoch 2/50
# 5/5 - 0s - loss: 3.5299 - val_loss: 3.6283 - 256ms/epoch - 51ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 3.3934 - val_loss: 3.4923 - 263ms/epoch - 53ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 3.2615 - val_loss: 3.3612 - 255ms/epoch - 51ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 3.1345 - val_loss: 3.2349 - 246ms/epoch - 49ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 3.0123 - val_loss: 3.1135 - 249ms/epoch - 50ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 2.8948 - val_loss: 2.9968 - 238ms/epoch - 48ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 2.7820 - val_loss: 2.8848 - 234ms/epoch - 47ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 2.6739 - val_loss: 2.7773 - 240ms/epoch - 48ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 2.5700 - val_loss: 2.6743 - 236ms/epoch - 47ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 2.4705 - val_loss: 2.5755 - 246ms/epoch - 49ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 2.3750 - val_loss: 2.4807 - 253ms/epoch - 51ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 2.2834 - val_loss: 2.3900 - 255ms/epoch - 51ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 2.1956 - val_loss: 2.3030 - 255ms/epoch - 51ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 2.1114 - val_loss: 2.2196 - 257ms/epoch - 51ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 2.0306 - val_loss: 2.1397 - 253ms/epoch - 51ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 1.9530 - val_loss: 2.0632 - 250ms/epoch - 50ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 1.8788 - val_loss: 1.9898 - 253ms/epoch - 51ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 1.8075 - val_loss: 1.9195 - 256ms/epoch - 51ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 1.7391 - val_loss: 1.8522 - 257ms/epoch - 51ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 1.6734 - val_loss: 1.7876 - 244ms/epoch - 49ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 1.6105 - val_loss: 1.7257 - 243ms/epoch - 49ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 1.5500 - val_loss: 1.6665 - 254ms/epoch - 51ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 1.4921 - val_loss: 1.6096 - 257ms/epoch - 51ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 1.4365 - val_loss: 1.5550 - 257ms/epoch - 51ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 1.3829 - val_loss: 1.5028 - 270ms/epoch - 54ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 1.3318 - val_loss: 1.4526 - 291ms/epoch - 58ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 1.2825 - val_loss: 1.4044 - 276ms/epoch - 55ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 1.2354 - val_loss: 1.3583 - 253ms/epoch - 51ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 1.1900 - val_loss: 1.3140 - 264ms/epoch - 53ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 1.1465 - val_loss: 1.2715 - 250ms/epoch - 50ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 1.1047 - val_loss: 1.2307 - 246ms/epoch - 49ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 1.0646 - val_loss: 1.1916 - 244ms/epoch - 49ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 1.0261 - val_loss: 1.1541 - 260ms/epoch - 52ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.9892 - val_loss: 1.1181 - 246ms/epoch - 49ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.9537 - val_loss: 1.0835 - 269ms/epoch - 54ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.9197 - val_loss: 1.0502 - 260ms/epoch - 52ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.8870 - val_loss: 1.0183 - 259ms/epoch - 52ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.8556 - val_loss: 0.9877 - 255ms/epoch - 51ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.8254 - val_loss: 0.9582 - 249ms/epoch - 50ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.7965 - val_loss: 0.9299 - 256ms/epoch - 51ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.7686 - val_loss: 0.9028 - 248ms/epoch - 50ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.7420 - val_loss: 0.8767 - 249ms/epoch - 50ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.7164 - val_loss: 0.8516 - 246ms/epoch - 49ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.6917 - val_loss: 0.8276 - 246ms/epoch - 49ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.6681 - val_loss: 0.8045 - 262ms/epoch - 52ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.6453 - val_loss: 0.7823 - 254ms/epoch - 51ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.6235 - val_loss: 0.7609 - 259ms/epoch - 52ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.6025 - val_loss: 0.7404 - 262ms/epoch - 52ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.5823 - val_loss: 0.7206 - 265ms/epoch - 53ms/step
# 20/20 [==============================] - 2s 8ms/step
# 9/9 [==============================] - 0s 6ms/step
# Train Score: 267.43 RMSE for 50 epochs
# Test Score: 2830.75 RMSE for 50 epochs
# Training with LSTM layers: [32, 32, 16, 16, 8, 8, 4, 4, 2, 2]
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_86 (LSTM)              (None, 5, 32)             4480
#
#  dropout_49 (Dropout)        (None, 5, 32)             0
#
#  lstm_87 (LSTM)              (None, 5, 32)             8320
#
#  dropout_50 (Dropout)        (None, 5, 32)             0
#
#  lstm_88 (LSTM)              (None, 5, 16)             3136
#
#  dropout_51 (Dropout)        (None, 5, 16)             0
#
#  lstm_89 (LSTM)              (None, 5, 16)             2112
#
#  dropout_52 (Dropout)        (None, 5, 16)             0
#
#  lstm_90 (LSTM)              (None, 5, 8)              800
#
#  dropout_53 (Dropout)        (None, 5, 8)              0
#
#  lstm_91 (LSTM)              (None, 5, 8)              544
#
#  dropout_54 (Dropout)        (None, 5, 8)              0
#
#  lstm_92 (LSTM)              (None, 5, 4)              208
#
#  dropout_55 (Dropout)        (None, 5, 4)              0
#
#  lstm_93 (LSTM)              (None, 5, 4)              144
#
#  dropout_56 (Dropout)        (None, 5, 4)              0
#
#  lstm_94 (LSTM)              (None, 5, 2)              56
#
#  dropout_57 (Dropout)        (None, 5, 2)              0
#
#  lstm_95 (LSTM)              (None, 2)                 40
#
#  dropout_58 (Dropout)        (None, 2)                 0
#
#  dense_18 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 19,843
# Trainable params: 19,843
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 22s - loss: 1.7691 - val_loss: 1.9222 - 22s/epoch - 4s/step
# Epoch 2/50
# 5/5 - 0s - loss: 1.7187 - val_loss: 1.8704 - 197ms/epoch - 39ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 1.6695 - val_loss: 1.8198 - 200ms/epoch - 40ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 1.6215 - val_loss: 1.7705 - 198ms/epoch - 40ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 1.5749 - val_loss: 1.7225 - 181ms/epoch - 36ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 1.5295 - val_loss: 1.6759 - 174ms/epoch - 35ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 1.4855 - val_loss: 1.6305 - 172ms/epoch - 34ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 1.4426 - val_loss: 1.5866 - 177ms/epoch - 35ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 1.4011 - val_loss: 1.5439 - 182ms/epoch - 36ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 1.3608 - val_loss: 1.5025 - 177ms/epoch - 35ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 1.3218 - val_loss: 1.4624 - 175ms/epoch - 35ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 1.2840 - val_loss: 1.4235 - 206ms/epoch - 41ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 1.2472 - val_loss: 1.3859 - 202ms/epoch - 40ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 1.2116 - val_loss: 1.3495 - 193ms/epoch - 39ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 1.1771 - val_loss: 1.3142 - 202ms/epoch - 40ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 1.1435 - val_loss: 1.2801 - 184ms/epoch - 37ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 1.1111 - val_loss: 1.2471 - 176ms/epoch - 35ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 1.0795 - val_loss: 1.2153 - 177ms/epoch - 35ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 1.0489 - val_loss: 1.1844 - 180ms/epoch - 36ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 1.0192 - val_loss: 1.1545 - 180ms/epoch - 36ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 0.9904 - val_loss: 1.1256 - 183ms/epoch - 37ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 0.9624 - val_loss: 1.0977 - 199ms/epoch - 40ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 0.9352 - val_loss: 1.0706 - 181ms/epoch - 36ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.9088 - val_loss: 1.0444 - 182ms/epoch - 36ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.8832 - val_loss: 1.0190 - 184ms/epoch - 37ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.8583 - val_loss: 0.9944 - 181ms/epoch - 36ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.8342 - val_loss: 0.9706 - 181ms/epoch - 36ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.8107 - val_loss: 0.9475 - 184ms/epoch - 37ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.7879 - val_loss: 0.9251 - 187ms/epoch - 37ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.7658 - val_loss: 0.9033 - 181ms/epoch - 36ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.7443 - val_loss: 0.8822 - 179ms/epoch - 36ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.7235 - val_loss: 0.8616 - 179ms/epoch - 36ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.7032 - val_loss: 0.8417 - 184ms/epoch - 37ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.6835 - val_loss: 0.8224 - 195ms/epoch - 39ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.6644 - val_loss: 0.8036 - 204ms/epoch - 41ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.6459 - val_loss: 0.7853 - 192ms/epoch - 38ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.6279 - val_loss: 0.7676 - 184ms/epoch - 37ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.6104 - val_loss: 0.7504 - 180ms/epoch - 36ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.5934 - val_loss: 0.7337 - 179ms/epoch - 36ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.5768 - val_loss: 0.7175 - 200ms/epoch - 40ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.5608 - val_loss: 0.7018 - 181ms/epoch - 36ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.5453 - val_loss: 0.6865 - 179ms/epoch - 36ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.5301 - val_loss: 0.6716 - 181ms/epoch - 36ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.5155 - val_loss: 0.6572 - 184ms/epoch - 37ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.5012 - val_loss: 0.6432 - 178ms/epoch - 36ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.4874 - val_loss: 0.6296 - 177ms/epoch - 35ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.4739 - val_loss: 0.6164 - 176ms/epoch - 35ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.4609 - val_loss: 0.6035 - 192ms/epoch - 38ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.4482 - val_loss: 0.5911 - 179ms/epoch - 36ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.4358 - val_loss: 0.5789 - 180ms/epoch - 36ms/step
# 20/20 [==============================] - 3s 6ms/step
# 9/9 [==============================] - 0s 5ms/step
# Train Score: 267.64 RMSE for 50 epochs
# Test Score: 2832.70 RMSE for 50 epochs
# Training with LSTM layers: [16, 16, 8, 8, 4, 4, 2, 2]
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_96 (LSTM)              (None, 5, 16)             1216
#
#  dropout_59 (Dropout)        (None, 5, 16)             0
#
#  lstm_97 (LSTM)              (None, 5, 16)             2112
#
#  dropout_60 (Dropout)        (None, 5, 16)             0
#
#  lstm_98 (LSTM)              (None, 5, 8)              800
#
#  dropout_61 (Dropout)        (None, 5, 8)              0
#
#  lstm_99 (LSTM)              (None, 5, 8)              544
#
#  dropout_62 (Dropout)        (None, 5, 8)              0
#
#  lstm_100 (LSTM)             (None, 5, 4)              208
#
#  dropout_63 (Dropout)        (None, 5, 4)              0
#
#  lstm_101 (LSTM)             (None, 5, 4)              144
#
#  dropout_64 (Dropout)        (None, 5, 4)              0
#
#  lstm_102 (LSTM)             (None, 5, 2)              56
#
#  dropout_65 (Dropout)        (None, 5, 2)              0
#
#  lstm_103 (LSTM)             (None, 2)                 40
#
#  dropout_66 (Dropout)        (None, 2)                 0
#
#  dense_19 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 5,123
# Trainable params: 5,123
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 17s - loss: 0.8716 - val_loss: 1.0426 - 17s/epoch - 3s/step
# Epoch 2/50
# 5/5 - 0s - loss: 0.8527 - val_loss: 1.0205 - 143ms/epoch - 29ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 0.8342 - val_loss: 0.9988 - 146ms/epoch - 29ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 0.8162 - val_loss: 0.9777 - 146ms/epoch - 29ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 0.7987 - val_loss: 0.9571 - 137ms/epoch - 27ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 0.7816 - val_loss: 0.9372 - 137ms/epoch - 27ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 0.7649 - val_loss: 0.9179 - 138ms/epoch - 28ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 0.7486 - val_loss: 0.8993 - 138ms/epoch - 28ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 0.7328 - val_loss: 0.8814 - 141ms/epoch - 28ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 0.7173 - val_loss: 0.8642 - 139ms/epoch - 28ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 0.7023 - val_loss: 0.8478 - 143ms/epoch - 29ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 0.6876 - val_loss: 0.8320 - 138ms/epoch - 28ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 0.6733 - val_loss: 0.8169 - 137ms/epoch - 27ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 0.6593 - val_loss: 0.8024 - 138ms/epoch - 28ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 0.6454 - val_loss: 0.7885 - 141ms/epoch - 28ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 0.6319 - val_loss: 0.7750 - 150ms/epoch - 30ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 0.6187 - val_loss: 0.7620 - 145ms/epoch - 29ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 0.6059 - val_loss: 0.7493 - 145ms/epoch - 29ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 0.5933 - val_loss: 0.7368 - 142ms/epoch - 28ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 0.5809 - val_loss: 0.7246 - 139ms/epoch - 28ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 0.5686 - val_loss: 0.7128 - 142ms/epoch - 28ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 0.5569 - val_loss: 0.7011 - 143ms/epoch - 29ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 0.5453 - val_loss: 0.6897 - 149ms/epoch - 30ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.5339 - val_loss: 0.6785 - 142ms/epoch - 28ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.5228 - val_loss: 0.6675 - 139ms/epoch - 28ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.5118 - val_loss: 0.6568 - 168ms/epoch - 34ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.5012 - val_loss: 0.6462 - 142ms/epoch - 28ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.4907 - val_loss: 0.6359 - 141ms/epoch - 28ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.4804 - val_loss: 0.6257 - 143ms/epoch - 29ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.4704 - val_loss: 0.6157 - 143ms/epoch - 29ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.4606 - val_loss: 0.6059 - 144ms/epoch - 29ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.4510 - val_loss: 0.5963 - 143ms/epoch - 29ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.4415 - val_loss: 0.5869 - 144ms/epoch - 29ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.4322 - val_loss: 0.5777 - 145ms/epoch - 29ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.4232 - val_loss: 0.5688 - 144ms/epoch - 29ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.4144 - val_loss: 0.5600 - 146ms/epoch - 29ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.4058 - val_loss: 0.5514 - 143ms/epoch - 29ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.3973 - val_loss: 0.5431 - 145ms/epoch - 29ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.3890 - val_loss: 0.5350 - 142ms/epoch - 28ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.3809 - val_loss: 0.5269 - 141ms/epoch - 28ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.3728 - val_loss: 0.5190 - 139ms/epoch - 28ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.3651 - val_loss: 0.5114 - 141ms/epoch - 28ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.3574 - val_loss: 0.5038 - 147ms/epoch - 29ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.3499 - val_loss: 0.4963 - 143ms/epoch - 29ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.3426 - val_loss: 0.4891 - 144ms/epoch - 29ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.3354 - val_loss: 0.4820 - 159ms/epoch - 32ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.3284 - val_loss: 0.4750 - 144ms/epoch - 29ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.3214 - val_loss: 0.4681 - 146ms/epoch - 29ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.3147 - val_loss: 0.4613 - 146ms/epoch - 29ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.3081 - val_loss: 0.4547 - 144ms/epoch - 29ms/step
# 20/20 [==============================] - 2s 5ms/step
# 9/9 [==============================] - 0s 4ms/step
# Train Score: 267.89 RMSE for 50 epochs
# Test Score: 2834.73 RMSE for 50 epochs
# Training with LSTM layers: [8, 8, 4, 4, 2, 2]
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_104 (LSTM)             (None, 5, 8)              352
#
#  dropout_67 (Dropout)        (None, 5, 8)              0
#
#  lstm_105 (LSTM)             (None, 5, 8)              544
#
#  dropout_68 (Dropout)        (None, 5, 8)              0
#
#  lstm_106 (LSTM)             (None, 5, 4)              208
#
#  dropout_69 (Dropout)        (None, 5, 4)              0
#
#  lstm_107 (LSTM)             (None, 5, 4)              144
#
#  dropout_70 (Dropout)        (None, 5, 4)              0
#
#  lstm_108 (LSTM)             (None, 5, 2)              56
#
#  dropout_71 (Dropout)        (None, 5, 2)              0
#
#  lstm_109 (LSTM)             (None, 2)                 40
#
#  dropout_72 (Dropout)        (None, 2)                 0
#
#  dense_20 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 1,347
# Trainable params: 1,347
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 14s - loss: 0.4336 - val_loss: 0.6127 - 14s/epoch - 3s/step
# Epoch 2/50
# 5/5 - 0s - loss: 0.4263 - val_loss: 0.6027 - 111ms/epoch - 22ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 0.4191 - val_loss: 0.5930 - 108ms/epoch - 22ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 0.4120 - val_loss: 0.5834 - 110ms/epoch - 22ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 0.4052 - val_loss: 0.5741 - 110ms/epoch - 22ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 0.3984 - val_loss: 0.5650 - 109ms/epoch - 22ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 0.3920 - val_loss: 0.5562 - 119ms/epoch - 24ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 0.3855 - val_loss: 0.5476 - 112ms/epoch - 22ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 0.3793 - val_loss: 0.5394 - 106ms/epoch - 21ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 0.3731 - val_loss: 0.5314 - 107ms/epoch - 21ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 0.3673 - val_loss: 0.5237 - 109ms/epoch - 22ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 0.3614 - val_loss: 0.5163 - 111ms/epoch - 22ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 0.3557 - val_loss: 0.5093 - 111ms/epoch - 22ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 0.3501 - val_loss: 0.5025 - 108ms/epoch - 22ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 0.3446 - val_loss: 0.4960 - 109ms/epoch - 22ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 0.3392 - val_loss: 0.4899 - 109ms/epoch - 22ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 0.3339 - val_loss: 0.4840 - 116ms/epoch - 23ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 0.3288 - val_loss: 0.4783 - 122ms/epoch - 24ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 0.3237 - val_loss: 0.4728 - 117ms/epoch - 23ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 0.3186 - val_loss: 0.4676 - 112ms/epoch - 22ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 0.3137 - val_loss: 0.4625 - 112ms/epoch - 22ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 0.3087 - val_loss: 0.4574 - 114ms/epoch - 23ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 0.3039 - val_loss: 0.4525 - 121ms/epoch - 24ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.2992 - val_loss: 0.4478 - 119ms/epoch - 24ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.2945 - val_loss: 0.4430 - 109ms/epoch - 22ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.2899 - val_loss: 0.4385 - 116ms/epoch - 23ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.2854 - val_loss: 0.4339 - 117ms/epoch - 23ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.2811 - val_loss: 0.4295 - 126ms/epoch - 25ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.2765 - val_loss: 0.4251 - 157ms/epoch - 31ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.2723 - val_loss: 0.4207 - 116ms/epoch - 23ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.2681 - val_loss: 0.4165 - 114ms/epoch - 23ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.2638 - val_loss: 0.4123 - 108ms/epoch - 22ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.2597 - val_loss: 0.4082 - 110ms/epoch - 22ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.2557 - val_loss: 0.4043 - 108ms/epoch - 22ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.2517 - val_loss: 0.4003 - 109ms/epoch - 22ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.2478 - val_loss: 0.3963 - 110ms/epoch - 22ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.2439 - val_loss: 0.3924 - 110ms/epoch - 22ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.2400 - val_loss: 0.3885 - 115ms/epoch - 23ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.2363 - val_loss: 0.3847 - 116ms/epoch - 23ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.2325 - val_loss: 0.3811 - 119ms/epoch - 24ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.2290 - val_loss: 0.3775 - 117ms/epoch - 23ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.2253 - val_loss: 0.3739 - 117ms/epoch - 23ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.2217 - val_loss: 0.3703 - 117ms/epoch - 23ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.2184 - val_loss: 0.3669 - 117ms/epoch - 23ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.2149 - val_loss: 0.3634 - 117ms/epoch - 23ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.2115 - val_loss: 0.3601 - 113ms/epoch - 23ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.2082 - val_loss: 0.3568 - 113ms/epoch - 23ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.2049 - val_loss: 0.3536 - 112ms/epoch - 22ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.2017 - val_loss: 0.3503 - 112ms/epoch - 22ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.1985 - val_loss: 0.3471 - 113ms/epoch - 23ms/step
# 20/20 [==============================] - 1s 4ms/step
# 9/9 [==============================] - 0s 3ms/step
# Train Score: 267.74 RMSE for 50 epochs
# Test Score: 2833.85 RMSE for 50 epochs
# Training with LSTM layers: [4, 4, 2, 2]
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_110 (LSTM)             (None, 5, 4)              112
#
#  dropout_73 (Dropout)        (None, 5, 4)              0
#
#  lstm_111 (LSTM)             (None, 5, 4)              144
#
#  dropout_74 (Dropout)        (None, 5, 4)              0
#
#  lstm_112 (LSTM)             (None, 5, 2)              56
#
#  dropout_75 (Dropout)        (None, 5, 2)              0
#
#  lstm_113 (LSTM)             (None, 2)                 40
#
#  dropout_76 (Dropout)        (None, 2)                 0
#
#  dense_21 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 355
# Trainable params: 355
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 8s - loss: 0.1929 - val_loss: 0.3724 - 8s/epoch - 2s/step
# Epoch 2/50
# 5/5 - 0s - loss: 0.1899 - val_loss: 0.3666 - 84ms/epoch - 17ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 0.1869 - val_loss: 0.3610 - 83ms/epoch - 17ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 0.1841 - val_loss: 0.3555 - 83ms/epoch - 17ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 0.1813 - val_loss: 0.3501 - 81ms/epoch - 16ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 0.1787 - val_loss: 0.3449 - 81ms/epoch - 16ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 0.1762 - val_loss: 0.3399 - 82ms/epoch - 16ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 0.1737 - val_loss: 0.3351 - 81ms/epoch - 16ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 0.1713 - val_loss: 0.3306 - 81ms/epoch - 16ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 0.1691 - val_loss: 0.3263 - 82ms/epoch - 16ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 0.1669 - val_loss: 0.3223 - 82ms/epoch - 16ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 0.1649 - val_loss: 0.3187 - 85ms/epoch - 17ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 0.1627 - val_loss: 0.3152 - 83ms/epoch - 17ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 0.1607 - val_loss: 0.3121 - 82ms/epoch - 16ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 0.1588 - val_loss: 0.3092 - 82ms/epoch - 16ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 0.1569 - val_loss: 0.3065 - 105ms/epoch - 21ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 0.1550 - val_loss: 0.3041 - 87ms/epoch - 17ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 0.1531 - val_loss: 0.3018 - 83ms/epoch - 17ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 0.1514 - val_loss: 0.2996 - 84ms/epoch - 17ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 0.1495 - val_loss: 0.2977 - 84ms/epoch - 17ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 0.1476 - val_loss: 0.2959 - 83ms/epoch - 17ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 0.1459 - val_loss: 0.2940 - 86ms/epoch - 17ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 0.1442 - val_loss: 0.2923 - 87ms/epoch - 17ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.1423 - val_loss: 0.2906 - 88ms/epoch - 18ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.1407 - val_loss: 0.2890 - 83ms/epoch - 17ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.1389 - val_loss: 0.2874 - 85ms/epoch - 17ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.1374 - val_loss: 0.2858 - 84ms/epoch - 17ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.1356 - val_loss: 0.2841 - 84ms/epoch - 17ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.1340 - val_loss: 0.2826 - 86ms/epoch - 17ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.1324 - val_loss: 0.2810 - 87ms/epoch - 17ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.1308 - val_loss: 0.2794 - 90ms/epoch - 18ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.1291 - val_loss: 0.2778 - 85ms/epoch - 17ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.1277 - val_loss: 0.2763 - 86ms/epoch - 17ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.1261 - val_loss: 0.2749 - 84ms/epoch - 17ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.1245 - val_loss: 0.2734 - 86ms/epoch - 17ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.1231 - val_loss: 0.2718 - 83ms/epoch - 17ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.1215 - val_loss: 0.2703 - 84ms/epoch - 17ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.1200 - val_loss: 0.2687 - 84ms/epoch - 17ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.1186 - val_loss: 0.2672 - 83ms/epoch - 17ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.1172 - val_loss: 0.2657 - 86ms/epoch - 17ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.1157 - val_loss: 0.2643 - 86ms/epoch - 17ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.1143 - val_loss: 0.2629 - 87ms/epoch - 17ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.1130 - val_loss: 0.2615 - 84ms/epoch - 17ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.1115 - val_loss: 0.2601 - 84ms/epoch - 17ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.1101 - val_loss: 0.2587 - 102ms/epoch - 20ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.1088 - val_loss: 0.2573 - 88ms/epoch - 18ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.1076 - val_loss: 0.2560 - 104ms/epoch - 21ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.1062 - val_loss: 0.2547 - 86ms/epoch - 17ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.1049 - val_loss: 0.2534 - 84ms/epoch - 17ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.1036 - val_loss: 0.2521 - 85ms/epoch - 17ms/step
# 20/20 [==============================] - 1s 3ms/step
# 9/9 [==============================] - 0s 2ms/step
# Train Score: 267.38 RMSE for 50 epochs
# Test Score: 2823.14 RMSE for 50 epochs
# Training with LSTM layers: [2, 2]
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_114 (LSTM)             (None, 5, 2)              40
#
#  dropout_77 (Dropout)        (None, 5, 2)              0
#
#  lstm_115 (LSTM)             (None, 2)                 40
#
#  dropout_78 (Dropout)        (None, 2)                 0
#
#  dense_22 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 83
# Trainable params: 83
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 4s - loss: 0.0825 - val_loss: 0.3264 - 4s/epoch - 847ms/step
# Epoch 2/50
# 5/5 - 0s - loss: 0.0811 - val_loss: 0.3189 - 59ms/epoch - 12ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 0.0800 - val_loss: 0.3118 - 57ms/epoch - 11ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 0.0791 - val_loss: 0.3055 - 58ms/epoch - 12ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 0.0780 - val_loss: 0.3000 - 58ms/epoch - 12ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 0.0773 - val_loss: 0.2956 - 56ms/epoch - 11ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 0.0766 - val_loss: 0.2922 - 56ms/epoch - 11ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 0.0756 - val_loss: 0.2898 - 55ms/epoch - 11ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 0.0750 - val_loss: 0.2880 - 56ms/epoch - 11ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 0.0744 - val_loss: 0.2870 - 71ms/epoch - 14ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 0.0738 - val_loss: 0.2860 - 67ms/epoch - 13ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 0.0730 - val_loss: 0.2850 - 65ms/epoch - 13ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 0.0721 - val_loss: 0.2838 - 60ms/epoch - 12ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 0.0714 - val_loss: 0.2823 - 61ms/epoch - 12ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 0.0707 - val_loss: 0.2805 - 63ms/epoch - 13ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 0.0703 - val_loss: 0.2787 - 59ms/epoch - 12ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 0.0695 - val_loss: 0.2769 - 58ms/epoch - 12ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 0.0689 - val_loss: 0.2751 - 64ms/epoch - 13ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 0.0681 - val_loss: 0.2735 - 84ms/epoch - 17ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 0.0675 - val_loss: 0.2717 - 67ms/epoch - 13ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 0.0668 - val_loss: 0.2699 - 59ms/epoch - 12ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 0.0662 - val_loss: 0.2683 - 58ms/epoch - 12ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 0.0655 - val_loss: 0.2669 - 57ms/epoch - 11ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.0649 - val_loss: 0.2654 - 57ms/epoch - 11ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.0644 - val_loss: 0.2640 - 59ms/epoch - 12ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.0636 - val_loss: 0.2626 - 57ms/epoch - 11ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.0630 - val_loss: 0.2609 - 60ms/epoch - 12ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.0625 - val_loss: 0.2595 - 60ms/epoch - 12ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.0618 - val_loss: 0.2581 - 63ms/epoch - 13ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.0613 - val_loss: 0.2567 - 67ms/epoch - 13ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.0607 - val_loss: 0.2553 - 66ms/epoch - 13ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.0601 - val_loss: 0.2538 - 67ms/epoch - 13ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.0596 - val_loss: 0.2526 - 61ms/epoch - 12ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.0590 - val_loss: 0.2514 - 57ms/epoch - 11ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.0584 - val_loss: 0.2502 - 58ms/epoch - 12ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.0578 - val_loss: 0.2488 - 59ms/epoch - 12ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.0572 - val_loss: 0.2475 - 57ms/epoch - 11ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.0567 - val_loss: 0.2459 - 56ms/epoch - 11ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.0562 - val_loss: 0.2446 - 58ms/epoch - 12ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.0556 - val_loss: 0.2435 - 73ms/epoch - 15ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.0550 - val_loss: 0.2422 - 60ms/epoch - 12ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.0545 - val_loss: 0.2409 - 58ms/epoch - 12ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.0540 - val_loss: 0.2396 - 58ms/epoch - 12ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.0535 - val_loss: 0.2383 - 57ms/epoch - 11ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.0530 - val_loss: 0.2369 - 57ms/epoch - 11ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.0524 - val_loss: 0.2358 - 60ms/epoch - 12ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.0520 - val_loss: 0.2348 - 57ms/epoch - 11ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.0515 - val_loss: 0.2338 - 56ms/epoch - 11ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.0509 - val_loss: 0.2326 - 56ms/epoch - 11ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.0505 - val_loss: 0.2316 - 60ms/epoch - 12ms/step
# 20/20 [==============================] - 1s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# Train Score: 235.77 RMSE for 50 epochs
# Test Score: 3106.17 RMSE for 50 epochs
# Training for 100 epochs...
# Training with LSTM layers: [64, 64, 32, 32, 16, 16, 8, 8, 4, 4, 2, 2]
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_116 (LSTM)             (None, 5, 64)             17152
#
#  dropout_79 (Dropout)        (None, 5, 64)             0
#
#  lstm_117 (LSTM)             (None, 5, 64)             33024
#
#  dropout_80 (Dropout)        (None, 5, 64)             0
#
#  lstm_118 (LSTM)             (None, 5, 32)             12416
#
#  dropout_81 (Dropout)        (None, 5, 32)             0
#
#  lstm_119 (LSTM)             (None, 5, 32)             8320
#
#  dropout_82 (Dropout)        (None, 5, 32)             0
#
#  lstm_120 (LSTM)             (None, 5, 16)             3136
#
#  dropout_83 (Dropout)        (None, 5, 16)             0
#
#  lstm_121 (LSTM)             (None, 5, 16)             2112
#
#  dropout_84 (Dropout)        (None, 5, 16)             0
#
#  lstm_122 (LSTM)             (None, 5, 8)              800
#
#  dropout_85 (Dropout)        (None, 5, 8)              0
#
#  lstm_123 (LSTM)             (None, 5, 8)              544
#
#  dropout_86 (Dropout)        (None, 5, 8)              0
#
#  lstm_124 (LSTM)             (None, 5, 4)              208
#
#  dropout_87 (Dropout)        (None, 5, 4)              0
#
#  lstm_125 (LSTM)             (None, 5, 4)              144
#
#  dropout_88 (Dropout)        (None, 5, 4)              0
#
#  lstm_126 (LSTM)             (None, 5, 2)              56
#
#  dropout_89 (Dropout)        (None, 5, 2)              0
#
#  lstm_127 (LSTM)             (None, 2)                 40
#
#  dropout_90 (Dropout)        (None, 2)                 0
#
#  dense_23 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 77,955
# Trainable params: 77,955
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 5/5 - 25s - loss: 3.6659 - val_loss: 3.7623 - 25s/epoch - 5s/step
# Epoch 2/100
# 5/5 - 0s - loss: 3.5246 - val_loss: 3.6202 - 244ms/epoch - 49ms/step
# Epoch 3/100
# 5/5 - 0s - loss: 3.3878 - val_loss: 3.4828 - 244ms/epoch - 49ms/step
# Epoch 4/100
# 5/5 - 0s - loss: 3.2558 - val_loss: 3.3503 - 243ms/epoch - 49ms/step
# Epoch 5/100
# 5/5 - 0s - loss: 3.1286 - val_loss: 3.2229 - 236ms/epoch - 47ms/step
# Epoch 6/100
# 5/5 - 0s - loss: 3.0065 - val_loss: 3.1006 - 233ms/epoch - 47ms/step
# Epoch 7/100
# 5/5 - 0s - loss: 2.8890 - val_loss: 2.9832 - 235ms/epoch - 47ms/step
# Epoch 8/100
# 5/5 - 0s - loss: 2.7763 - val_loss: 2.8708 - 252ms/epoch - 50ms/step
# Epoch 9/100
# 5/5 - 0s - loss: 2.6684 - val_loss: 2.7631 - 231ms/epoch - 46ms/step
# Epoch 10/100
# 5/5 - 0s - loss: 2.5646 - val_loss: 2.6602 - 232ms/epoch - 46ms/step
# Epoch 11/100
# 5/5 - 0s - loss: 2.4653 - val_loss: 2.5617 - 231ms/epoch - 46ms/step
# Epoch 12/100
# 5/5 - 0s - loss: 2.3701 - val_loss: 2.4676 - 234ms/epoch - 47ms/step
# Epoch 13/100
# 5/5 - 0s - loss: 2.2785 - val_loss: 2.3777 - 230ms/epoch - 46ms/step
# Epoch 14/100
# 5/5 - 0s - loss: 2.1909 - val_loss: 2.2916 - 232ms/epoch - 46ms/step
# Epoch 15/100
# 5/5 - 0s - loss: 2.1069 - val_loss: 2.2093 - 235ms/epoch - 47ms/step
# Epoch 16/100
# 5/5 - 0s - loss: 2.0261 - val_loss: 2.1304 - 235ms/epoch - 47ms/step
# Epoch 17/100
# 5/5 - 0s - loss: 1.9489 - val_loss: 2.0549 - 250ms/epoch - 50ms/step
# Epoch 18/100
# 5/5 - 0s - loss: 1.8745 - val_loss: 1.9825 - 235ms/epoch - 47ms/step
# Epoch 19/100
# 5/5 - 0s - loss: 1.8034 - val_loss: 1.9131 - 231ms/epoch - 46ms/step
# Epoch 20/100
# 5/5 - 0s - loss: 1.7352 - val_loss: 1.8466 - 238ms/epoch - 48ms/step
# Epoch 21/100
# 5/5 - 0s - loss: 1.6696 - val_loss: 1.7827 - 233ms/epoch - 47ms/step
# Epoch 22/100
# 5/5 - 0s - loss: 1.6067 - val_loss: 1.7214 - 234ms/epoch - 47ms/step
# Epoch 23/100
# 5/5 - 0s - loss: 1.5462 - val_loss: 1.6626 - 234ms/epoch - 47ms/step
# Epoch 24/100
# 5/5 - 0s - loss: 1.4885 - val_loss: 1.6062 - 234ms/epoch - 47ms/step
# Epoch 25/100
# 5/5 - 0s - loss: 1.4328 - val_loss: 1.5520 - 237ms/epoch - 47ms/step
# Epoch 26/100
# 5/5 - 0s - loss: 1.3794 - val_loss: 1.4999 - 236ms/epoch - 47ms/step
# Epoch 27/100
# 5/5 - 0s - loss: 1.3284 - val_loss: 1.4498 - 235ms/epoch - 47ms/step
# Epoch 28/100
# 5/5 - 0s - loss: 1.2792 - val_loss: 1.4018 - 233ms/epoch - 47ms/step
# Epoch 29/100
# 5/5 - 0s - loss: 1.2321 - val_loss: 1.3557 - 262ms/epoch - 52ms/step
# Epoch 30/100
# 5/5 - 0s - loss: 1.1868 - val_loss: 1.3115 - 236ms/epoch - 47ms/step
# Epoch 31/100
# 5/5 - 0s - loss: 1.1435 - val_loss: 1.2691 - 235ms/epoch - 47ms/step
# Epoch 32/100
# 5/5 - 0s - loss: 1.1018 - val_loss: 1.2284 - 237ms/epoch - 47ms/step
# Epoch 33/100
# 5/5 - 0s - loss: 1.0618 - val_loss: 1.1894 - 240ms/epoch - 48ms/step
# Epoch 34/100
# 5/5 - 0s - loss: 1.0234 - val_loss: 1.1521 - 235ms/epoch - 47ms/step
# Epoch 35/100
# 5/5 - 0s - loss: 0.9865 - val_loss: 1.1161 - 236ms/epoch - 47ms/step
# Epoch 36/100
# 5/5 - 0s - loss: 0.9512 - val_loss: 1.0816 - 239ms/epoch - 48ms/step
# Epoch 37/100
# 5/5 - 0s - loss: 0.9173 - val_loss: 1.0483 - 236ms/epoch - 47ms/step
# Epoch 38/100
# 5/5 - 0s - loss: 0.8847 - val_loss: 1.0165 - 237ms/epoch - 47ms/step
# Epoch 39/100
# 5/5 - 0s - loss: 0.8533 - val_loss: 0.9859 - 236ms/epoch - 47ms/step
# Epoch 40/100
# 5/5 - 0s - loss: 0.8234 - val_loss: 0.9566 - 233ms/epoch - 47ms/step
# Epoch 41/100
# 5/5 - 0s - loss: 0.7945 - val_loss: 0.9285 - 235ms/epoch - 47ms/step
# Epoch 42/100
# 5/5 - 0s - loss: 0.7668 - val_loss: 0.9014 - 239ms/epoch - 48ms/step
# Epoch 43/100
# 5/5 - 0s - loss: 0.7403 - val_loss: 0.8755 - 236ms/epoch - 47ms/step
# Epoch 44/100
# 5/5 - 0s - loss: 0.7147 - val_loss: 0.8506 - 235ms/epoch - 47ms/step
# Epoch 45/100
# 5/5 - 0s - loss: 0.6901 - val_loss: 0.8267 - 236ms/epoch - 47ms/step
# Epoch 46/100
# 5/5 - 0s - loss: 0.6666 - val_loss: 0.8036 - 239ms/epoch - 48ms/step
# Epoch 47/100
# 5/5 - 0s - loss: 0.6440 - val_loss: 0.7815 - 236ms/epoch - 47ms/step
# Epoch 48/100
# 5/5 - 0s - loss: 0.6222 - val_loss: 0.7602 - 235ms/epoch - 47ms/step
# Epoch 49/100
# 5/5 - 0s - loss: 0.6014 - val_loss: 0.7398 - 235ms/epoch - 47ms/step
# Epoch 50/100
# 5/5 - 0s - loss: 0.5813 - val_loss: 0.7202 - 265ms/epoch - 53ms/step
# Epoch 51/100
# 5/5 - 0s - loss: 0.5620 - val_loss: 0.7014 - 239ms/epoch - 48ms/step
# Epoch 52/100
# ...
# Epoch 142/150
# 5/5 - 0s - loss: 0.0246 - val_loss: 0.1738 - 82ms/epoch - 16ms/step
# Epoch 143/150
# 5/5 - 0s - loss: 0.0242 - val_loss: 0.1735 - 106ms/epoch - 21ms/step
# Epoch 144/150
# 5/5 - 0s - loss: 0.0239 - val_loss: 0.1733 - 90ms/epoch - 18ms/step
# Epoch 145/150
# 5/5 - 0s - loss: 0.0236 - val_loss: 0.1730 - 88ms/epoch - 18ms/step
# Epoch 146/150
# 5/5 - 0s - loss: 0.0233 - val_loss: 0.1727 - 100ms/epoch - 20ms/step
# Epoch 147/150
# 5/5 - 0s - loss: 0.0229 - val_loss: 0.1724 - 94ms/epoch - 19ms/step
# Epoch 148/150
# 5/5 - 0s - loss: 0.0226 - val_loss: 0.1719 - 91ms/epoch - 18ms/step
# Epoch 149/150
# 5/5 - 0s - loss: 0.0223 - val_loss: 0.1714 - 90ms/epoch - 18ms/step
# Epoch 150/150
# 5/5 - 0s - loss: 0.0220 - val_loss: 0.1712 - 89ms/epoch - 18ms/step
# 20/20 [==============================] - 1s 3ms/step
# 9/9 [==============================] - 0s 2ms/step
# Train Score: 266.96 RMSE for 150 epochs
# Test Score: 2822.66 RMSE for 150 epochs
# Training with LSTM layers: [2, 2]
# Model: "sequential_34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_198 (LSTM)             (None, 5, 2)              40
#
#  dropout_161 (Dropout)       (None, 5, 2)              0
#
#  lstm_199 (LSTM)             (None, 2)                 40
#
#  dropout_162 (Dropout)       (None, 2)                 0
#
#  dense_34 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 83
# Trainable params: 83
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 5/5 - 4s - loss: 0.0648 - val_loss: 0.3109 - 4s/epoch - 856ms/step
# Epoch 2/150
# 5/5 - 0s - loss: 0.0633 - val_loss: 0.3040 - 58ms/epoch - 12ms/step
# Epoch 3/150
# 5/5 - 0s - loss: 0.0619 - val_loss: 0.2974 - 57ms/epoch - 11ms/step
# Epoch 4/150
# 5/5 - 0s - loss: 0.0606 - val_loss: 0.2911 - 58ms/epoch - 12ms/step
# Epoch 5/150
# 5/5 - 0s - loss: 0.0593 - val_loss: 0.2852 - 59ms/epoch - 12ms/step
# Epoch 6/150
# 5/5 - 0s - loss: 0.0581 - val_loss: 0.2798 - 69ms/epoch - 14ms/step
# Epoch 7/150
# 5/5 - 0s - loss: 0.0570 - val_loss: 0.2747 - 72ms/epoch - 14ms/step
# Epoch 8/150
# 5/5 - 0s - loss: 0.0561 - val_loss: 0.2700 - 65ms/epoch - 13ms/step
# Epoch 9/150
# 5/5 - 0s - loss: 0.0551 - val_loss: 0.2657 - 60ms/epoch - 12ms/step
# Epoch 10/150
# 5/5 - 0s - loss: 0.0543 - val_loss: 0.2617 - 61ms/epoch - 12ms/step
# Epoch 11/150
# 5/5 - 0s - loss: 0.0535 - val_loss: 0.2580 - 70ms/epoch - 14ms/step
# Epoch 12/150
# 5/5 - 0s - loss: 0.0529 - val_loss: 0.2546 - 64ms/epoch - 13ms/step
# Epoch 13/150
# 5/5 - 0s - loss: 0.0523 - val_loss: 0.2514 - 59ms/epoch - 12ms/step
# Epoch 14/150
# 5/5 - 0s - loss: 0.0515 - val_loss: 0.2485 - 56ms/epoch - 11ms/step
# Epoch 15/150
# 5/5 - 0s - loss: 0.0510 - val_loss: 0.2458 - 58ms/epoch - 12ms/step
# Epoch 16/150
# 5/5 - 0s - loss: 0.0504 - val_loss: 0.2434 - 63ms/epoch - 13ms/step
# Epoch 17/150
# 5/5 - 0s - loss: 0.0498 - val_loss: 0.2410 - 65ms/epoch - 13ms/step
# Epoch 18/150
# 5/5 - 0s - loss: 0.0494 - val_loss: 0.2389 - 69ms/epoch - 14ms/step
# Epoch 19/150
# 5/5 - 0s - loss: 0.0488 - val_loss: 0.2369 - 83ms/epoch - 17ms/step
# Epoch 20/150
# 5/5 - 0s - loss: 0.0483 - val_loss: 0.2350 - 78ms/epoch - 16ms/step
# Epoch 21/150
# 5/5 - 0s - loss: 0.0478 - val_loss: 0.2332 - 80ms/epoch - 16ms/step
# Epoch 22/150
# 5/5 - 0s - loss: 0.0473 - val_loss: 0.2315 - 73ms/epoch - 15ms/step
# Epoch 23/150
# 5/5 - 0s - loss: 0.0468 - val_loss: 0.2299 - 68ms/epoch - 14ms/step
# Epoch 24/150
# 5/5 - 0s - loss: 0.0463 - val_loss: 0.2284 - 72ms/epoch - 14ms/step
# Epoch 25/150
# 5/5 - 0s - loss: 0.0459 - val_loss: 0.2270 - 71ms/epoch - 14ms/step
# Epoch 26/150
# 5/5 - 0s - loss: 0.0454 - val_loss: 0.2256 - 75ms/epoch - 15ms/step
# Epoch 27/150
# 5/5 - 0s - loss: 0.0450 - val_loss: 0.2244 - 71ms/epoch - 14ms/step
# Epoch 28/150
# 5/5 - 0s - loss: 0.0445 - val_loss: 0.2231 - 65ms/epoch - 13ms/step
# Epoch 29/150
# 5/5 - 0s - loss: 0.0440 - val_loss: 0.2220 - 66ms/epoch - 13ms/step
# Epoch 30/150
# 5/5 - 0s - loss: 0.0436 - val_loss: 0.2208 - 65ms/epoch - 13ms/step
# Epoch 31/150
# 5/5 - 0s - loss: 0.0432 - val_loss: 0.2196 - 63ms/epoch - 13ms/step
# Epoch 32/150
# 5/5 - 0s - loss: 0.0428 - val_loss: 0.2185 - 62ms/epoch - 12ms/step
# Epoch 33/150
# 5/5 - 0s - loss: 0.0424 - val_loss: 0.2174 - 63ms/epoch - 13ms/step
# Epoch 34/150
# 5/5 - 0s - loss: 0.0419 - val_loss: 0.2163 - 66ms/epoch - 13ms/step
# Epoch 35/150
# 5/5 - 0s - loss: 0.0414 - val_loss: 0.2152 - 62ms/epoch - 12ms/step
# Epoch 36/150
# 5/5 - 0s - loss: 0.0411 - val_loss: 0.2141 - 66ms/epoch - 13ms/step
# Epoch 37/150
# 5/5 - 0s - loss: 0.0406 - val_loss: 0.2130 - 64ms/epoch - 13ms/step
# Epoch 38/150
# 5/5 - 0s - loss: 0.0402 - val_loss: 0.2120 - 73ms/epoch - 15ms/step
# Epoch 39/150
# 5/5 - 0s - loss: 0.0399 - val_loss: 0.2109 - 62ms/epoch - 12ms/step
# Epoch 40/150
# 5/5 - 0s - loss: 0.0393 - val_loss: 0.2099 - 57ms/epoch - 11ms/step
# Epoch 41/150
# 5/5 - 0s - loss: 0.0390 - val_loss: 0.2090 - 57ms/epoch - 11ms/step
# Epoch 42/150
# 5/5 - 0s - loss: 0.0386 - val_loss: 0.2080 - 59ms/epoch - 12ms/step
# Epoch 43/150
# 5/5 - 0s - loss: 0.0382 - val_loss: 0.2071 - 57ms/epoch - 11ms/step
# Epoch 44/150
# 5/5 - 0s - loss: 0.0378 - val_loss: 0.2063 - 56ms/epoch - 11ms/step
# Epoch 45/150
# 5/5 - 0s - loss: 0.0374 - val_loss: 0.2054 - 57ms/epoch - 11ms/step
# Epoch 46/150
# 5/5 - 0s - loss: 0.0371 - val_loss: 0.2045 - 57ms/epoch - 11ms/step
# Epoch 47/150
# 5/5 - 0s - loss: 0.0367 - val_loss: 0.2037 - 55ms/epoch - 11ms/step
# Epoch 48/150
# 5/5 - 0s - loss: 0.0363 - val_loss: 0.2028 - 55ms/epoch - 11ms/step
# Epoch 49/150
# 5/5 - 0s - loss: 0.0359 - val_loss: 0.2020 - 55ms/epoch - 11ms/step
# Epoch 50/150
# 5/5 - 0s - loss: 0.0356 - val_loss: 0.2012 - 60ms/epoch - 12ms/step
# Epoch 51/150
# 5/5 - 0s - loss: 0.0352 - val_loss: 0.2004 - 61ms/epoch - 12ms/step
# Epoch 52/150
# 5/5 - 0s - loss: 0.0349 - val_loss: 0.1997 - 66ms/epoch - 13ms/step
# Epoch 53/150
# 5/5 - 0s - loss: 0.0345 - val_loss: 0.1990 - 62ms/epoch - 12ms/step
# Epoch 54/150
# 5/5 - 0s - loss: 0.0341 - val_loss: 0.1982 - 63ms/epoch - 13ms/step
# Epoch 55/150
# 5/5 - 0s - loss: 0.0338 - val_loss: 0.1974 - 60ms/epoch - 12ms/step
# Epoch 56/150
# 5/5 - 0s - loss: 0.0335 - val_loss: 0.1967 - 67ms/epoch - 13ms/step
# Epoch 57/150
# 5/5 - 0s - loss: 0.0332 - val_loss: 0.1961 - 59ms/epoch - 12ms/step
# Epoch 58/150
# 5/5 - 0s - loss: 0.0328 - val_loss: 0.1954 - 58ms/epoch - 12ms/step
# Epoch 59/150
# 5/5 - 0s - loss: 0.0325 - val_loss: 0.1947 - 65ms/epoch - 13ms/step
# Epoch 60/150
# 5/5 - 0s - loss: 0.0322 - val_loss: 0.1940 - 58ms/epoch - 12ms/step
# Epoch 61/150
# 5/5 - 0s - loss: 0.0319 - val_loss: 0.1934 - 56ms/epoch - 11ms/step
# Epoch 62/150
# 5/5 - 0s - loss: 0.0316 - val_loss: 0.1927 - 56ms/epoch - 11ms/step
# Epoch 63/150
# 5/5 - 0s - loss: 0.0312 - val_loss: 0.1922 - 55ms/epoch - 11ms/step
# Epoch 64/150
# 5/5 - 0s - loss: 0.0309 - val_loss: 0.1916 - 56ms/epoch - 11ms/step
# Epoch 65/150
# 5/5 - 0s - loss: 0.0305 - val_loss: 0.1909 - 56ms/epoch - 11ms/step
# Epoch 66/150
# 5/5 - 0s - loss: 0.0303 - val_loss: 0.1903 - 58ms/epoch - 12ms/step
# Epoch 67/150
# 5/5 - 0s - loss: 0.0300 - val_loss: 0.1897 - 58ms/epoch - 12ms/step
# Epoch 68/150
# 5/5 - 0s - loss: 0.0296 - val_loss: 0.1891 - 58ms/epoch - 12ms/step
# Epoch 69/150
# 5/5 - 0s - loss: 0.0293 - val_loss: 0.1885 - 62ms/epoch - 12ms/step
# Epoch 70/150
# 5/5 - 0s - loss: 0.0290 - val_loss: 0.1880 - 63ms/epoch - 13ms/step
# Epoch 71/150
# 5/5 - 0s - loss: 0.0287 - val_loss: 0.1875 - 59ms/epoch - 12ms/step
# Epoch 72/150
# 5/5 - 0s - loss: 0.0284 - val_loss: 0.1869 - 60ms/epoch - 12ms/step
# Epoch 73/150
# 5/5 - 0s - loss: 0.0282 - val_loss: 0.1864 - 56ms/epoch - 11ms/step
# Epoch 74/150
# 5/5 - 0s - loss: 0.0279 - val_loss: 0.1859 - 57ms/epoch - 11ms/step
# Epoch 75/150
# 5/5 - 0s - loss: 0.0275 - val_loss: 0.1854 - 56ms/epoch - 11ms/step
# Epoch 76/150
# 5/5 - 0s - loss: 0.0273 - val_loss: 0.1849 - 55ms/epoch - 11ms/step
# Epoch 77/150
# 5/5 - 0s - loss: 0.0270 - val_loss: 0.1844 - 65ms/epoch - 13ms/step
# Epoch 78/150
# 5/5 - 0s - loss: 0.0268 - val_loss: 0.1840 - 63ms/epoch - 13ms/step
# Epoch 79/150
# 5/5 - 0s - loss: 0.0264 - val_loss: 0.1835 - 57ms/epoch - 11ms/step
# Epoch 80/150
# 5/5 - 0s - loss: 0.0262 - val_loss: 0.1830 - 55ms/epoch - 11ms/step
# Epoch 81/150
# 5/5 - 0s - loss: 0.0260 - val_loss: 0.1825 - 57ms/epoch - 11ms/step
# Epoch 82/150
# 5/5 - 0s - loss: 0.0257 - val_loss: 0.1821 - 55ms/epoch - 11ms/step
# Epoch 83/150
# 5/5 - 0s - loss: 0.0254 - val_loss: 0.1816 - 56ms/epoch - 11ms/step
# Epoch 84/150
# 5/5 - 0s - loss: 0.0251 - val_loss: 0.1811 - 56ms/epoch - 11ms/step
# Epoch 85/150
# 5/5 - 0s - loss: 0.0249 - val_loss: 0.1807 - 57ms/epoch - 11ms/step
# Epoch 86/150
# 5/5 - 0s - loss: 0.0247 - val_loss: 0.1802 - 57ms/epoch - 11ms/step
# Epoch 87/150
# 5/5 - 0s - loss: 0.0244 - val_loss: 0.1798 - 57ms/epoch - 11ms/step
# Epoch 88/150
# 5/5 - 0s - loss: 0.0241 - val_loss: 0.1794 - 57ms/epoch - 11ms/step
# Epoch 89/150
# 5/5 - 0s - loss: 0.0239 - val_loss: 0.1791 - 57ms/epoch - 11ms/step
# Epoch 90/150
# 5/5 - 0s - loss: 0.0237 - val_loss: 0.1787 - 56ms/epoch - 11ms/step
# Epoch 91/150
# 5/5 - 0s - loss: 0.0234 - val_loss: 0.1784 - 56ms/epoch - 11ms/step
# Epoch 92/150
# 5/5 - 0s - loss: 0.0232 - val_loss: 0.1780 - 56ms/epoch - 11ms/step
# Epoch 93/150
# 5/5 - 0s - loss: 0.0229 - val_loss: 0.1777 - 56ms/epoch - 11ms/step
# Epoch 94/150
# 5/5 - 0s - loss: 0.0227 - val_loss: 0.1774 - 56ms/epoch - 11ms/step
# Epoch 95/150
# 5/5 - 0s - loss: 0.0225 - val_loss: 0.1770 - 56ms/epoch - 11ms/step
# Epoch 96/150
# 5/5 - 0s - loss: 0.0222 - val_loss: 0.1766 - 58ms/epoch - 12ms/step
# Epoch 97/150
# 5/5 - 0s - loss: 0.0220 - val_loss: 0.1762 - 58ms/epoch - 12ms/step
# Epoch 98/150
# 5/5 - 0s - loss: 0.0218 - val_loss: 0.1759 - 57ms/epoch - 11ms/step
# Epoch 99/150
# 5/5 - 0s - loss: 0.0216 - val_loss: 0.1755 - 57ms/epoch - 11ms/step
# Epoch 100/150
# 5/5 - 0s - loss: 0.0213 - val_loss: 0.1751 - 56ms/epoch - 11ms/step
# Epoch 101/150
# 5/5 - 0s - loss: 0.0211 - val_loss: 0.1748 - 58ms/epoch - 12ms/step
# Epoch 102/150
# 5/5 - 0s - loss: 0.0209 - val_loss: 0.1745 - 61ms/epoch - 12ms/step
# Epoch 103/150
# 5/5 - 0s - loss: 0.0207 - val_loss: 0.1742 - 59ms/epoch - 12ms/step
# Epoch 104/150
# 5/5 - 0s - loss: 0.0205 - val_loss: 0.1739 - 56ms/epoch - 11ms/step
# Epoch 105/150
# 5/5 - 0s - loss: 0.0203 - val_loss: 0.1736 - 56ms/epoch - 11ms/step
# Epoch 106/150
# 5/5 - 0s - loss: 0.0201 - val_loss: 0.1733 - 55ms/epoch - 11ms/step
# Epoch 107/150
# 5/5 - 0s - loss: 0.0198 - val_loss: 0.1730 - 56ms/epoch - 11ms/step
# Epoch 108/150
# 5/5 - 0s - loss: 0.0196 - val_loss: 0.1728 - 54ms/epoch - 11ms/step
# Epoch 109/150
# 5/5 - 0s - loss: 0.0195 - val_loss: 0.1726 - 56ms/epoch - 11ms/step
# Epoch 110/150
# 5/5 - 0s - loss: 0.0192 - val_loss: 0.1723 - 55ms/epoch - 11ms/step
# Epoch 111/150
# 5/5 - 0s - loss: 0.0191 - val_loss: 0.1720 - 55ms/epoch - 11ms/step
# Epoch 112/150
# 5/5 - 0s - loss: 0.0189 - val_loss: 0.1717 - 58ms/epoch - 12ms/step
# Epoch 113/150
# 5/5 - 0s - loss: 0.0186 - val_loss: 0.1714 - 56ms/epoch - 11ms/step
# Epoch 114/150
# 5/5 - 0s - loss: 0.0185 - val_loss: 0.1711 - 56ms/epoch - 11ms/step
# Epoch 115/150
# 5/5 - 0s - loss: 0.0183 - val_loss: 0.1709 - 70ms/epoch - 14ms/step
# Epoch 116/150
# 5/5 - 0s - loss: 0.0181 - val_loss: 0.1706 - 64ms/epoch - 13ms/step
# Epoch 117/150
# 5/5 - 0s - loss: 0.0179 - val_loss: 0.1704 - 56ms/epoch - 11ms/step
# Epoch 118/150
# 5/5 - 0s - loss: 0.0177 - val_loss: 0.1701 - 55ms/epoch - 11ms/step
# Epoch 119/150
# 5/5 - 0s - loss: 0.0175 - val_loss: 0.1699 - 56ms/epoch - 11ms/step
# Epoch 120/150
# 5/5 - 0s - loss: 0.0173 - val_loss: 0.1696 - 57ms/epoch - 11ms/step
# Epoch 121/150
# 5/5 - 0s - loss: 0.0172 - val_loss: 0.1693 - 57ms/epoch - 11ms/step
# Epoch 122/150
# 5/5 - 0s - loss: 0.0170 - val_loss: 0.1690 - 55ms/epoch - 11ms/step
# Epoch 123/150
# 5/5 - 0s - loss: 0.0168 - val_loss: 0.1689 - 56ms/epoch - 11ms/step
# Epoch 124/150
# 5/5 - 0s - loss: 0.0167 - val_loss: 0.1687 - 56ms/epoch - 11ms/step
# Epoch 125/150
# 5/5 - 0s - loss: 0.0165 - val_loss: 0.1685 - 56ms/epoch - 11ms/step
# Epoch 126/150
# 5/5 - 0s - loss: 0.0163 - val_loss: 0.1682 - 67ms/epoch - 13ms/step
# Epoch 127/150
# 5/5 - 0s - loss: 0.0161 - val_loss: 0.1680 - 55ms/epoch - 11ms/step
# Epoch 128/150
# 5/5 - 0s - loss: 0.0160 - val_loss: 0.1677 - 55ms/epoch - 11ms/step
# Epoch 129/150
# 5/5 - 0s - loss: 0.0158 - val_loss: 0.1674 - 55ms/epoch - 11ms/step
# Epoch 130/150
# 5/5 - 0s - loss: 0.0157 - val_loss: 0.1672 - 55ms/epoch - 11ms/step
# Epoch 131/150
# 5/5 - 0s - loss: 0.0155 - val_loss: 0.1671 - 56ms/epoch - 11ms/step
# Epoch 132/150
# 5/5 - 0s - loss: 0.0153 - val_loss: 0.1669 - 59ms/epoch - 12ms/step
# Epoch 133/150
# 5/5 - 0s - loss: 0.0152 - val_loss: 0.1667 - 57ms/epoch - 11ms/step
# Epoch 134/150
# 5/5 - 0s - loss: 0.0150 - val_loss: 0.1665 - 56ms/epoch - 11ms/step
# Epoch 135/150
# 5/5 - 0s - loss: 0.0149 - val_loss: 0.1664 - 57ms/epoch - 11ms/step
# Epoch 136/150
# 5/5 - 0s - loss: 0.0147 - val_loss: 0.1661 - 57ms/epoch - 11ms/step
# Epoch 137/150
# 5/5 - 0s - loss: 0.0146 - val_loss: 0.1660 - 56ms/epoch - 11ms/step
# Epoch 138/150
# 5/5 - 0s - loss: 0.0144 - val_loss: 0.1658 - 57ms/epoch - 11ms/step
# Epoch 139/150
# 5/5 - 0s - loss: 0.0143 - val_loss: 0.1656 - 59ms/epoch - 12ms/step
# Epoch 140/150
# 5/5 - 0s - loss: 0.0141 - val_loss: 0.1655 - 62ms/epoch - 12ms/step
# Epoch 141/150
# 5/5 - 0s - loss: 0.0139 - val_loss: 0.1653 - 61ms/epoch - 12ms/step
# Epoch 142/150
# 5/5 - 0s - loss: 0.0138 - val_loss: 0.1651 - 57ms/epoch - 11ms/step
# Epoch 143/150
# 5/5 - 0s - loss: 0.0137 - val_loss: 0.1648 - 58ms/epoch - 12ms/step
# Epoch 144/150
# 5/5 - 0s - loss: 0.0135 - val_loss: 0.1647 - 57ms/epoch - 11ms/step
# Epoch 145/150
# 5/5 - 0s - loss: 0.0134 - val_loss: 0.1645 - 58ms/epoch - 12ms/step
# Epoch 146/150
# 5/5 - 0s - loss: 0.0133 - val_loss: 0.1643 - 55ms/epoch - 11ms/step
# Epoch 147/150
# 5/5 - 0s - loss: 0.0131 - val_loss: 0.1640 - 55ms/epoch - 11ms/step
# Epoch 148/150
# 5/5 - 0s - loss: 0.0130 - val_loss: 0.1638 - 57ms/epoch - 11ms/step
# Epoch 149/150
# 5/5 - 0s - loss: 0.0128 - val_loss: 0.1636 - 56ms/epoch - 11ms/step
# Epoch 150/150
# 5/5 - 0s - loss: 0.0127 - val_loss: 0.1635 - 63ms/epoch - 13ms/step
# 20/20 [==============================] - 1s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# Train Score: 267.80 RMSE for 150 epochs
# Test Score: 2836.38 RMSE for 150 epochs
# Text(0.5, 1.0, 'Model loss progress during training and validation')
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'Training and Validation Loss')
#                                                     Train RMSE    Test RMSE
# 50 epochs, [64, 64, 32, 32, 16, 16, 8, 8, 4, 4,...  267.430436  2830.753825
# 50 epochs, [32, 32, 16, 16, 8, 8, 4, 4, 2, 2] l...  267.638309  2832.695500
# 50 epochs, [16, 16, 8, 8, 4, 4, 2, 2] layers        267.894465  2834.728725
# 50 epochs, [8, 8, 4, 4, 2, 2] layers                267.740388  2833.846819
# 50 epochs, [4, 4, 2, 2] layers                      267.376773  2823.140519
# 50 epochs, [2, 2] layers                            235.768011  3106.173939
# 100 epochs, [64, 64, 32, 32, 16, 16, 8, 8, 4, 4...  267.106736  2826.589512
# 100 epochs, [32, 32, 16, 16, 8, 8, 4, 4, 2, 2] ...  267.111904  2826.678538
# 100 epochs, [16, 16, 8, 8, 4, 4, 2, 2] layers       267.219434  2828.299761
# 100 epochs, [8, 8, 4, 4, 2, 2] layers               267.076418  2826.036776
# 100 epochs, [4, 4, 2, 2] layers                     267.469815  2831.617686
# 100 epochs, [2, 2] layers                           268.585930  3277.918808
# 150 epochs, [64, 64, 32, 32, 16, 16, 8, 8, 4, 4...  266.950812  2822.411054
# 150 epochs, [32, 32, 16, 16, 8, 8, 4, 4, 2, 2] ...  266.971855  2823.381308
# 150 epochs, [16, 16, 8, 8, 4, 4, 2, 2] layers       266.994922  2824.146279
# 150 epochs, [8, 8, 4, 4, 2, 2] layers               266.962381  2822.999622
# 150 epochs, [4, 4, 2, 2] layers                     266.955400  2822.661831
# 150 epochs, [2, 2] layers                           267.804093  2836.376538

# %% [markdown]
# <h4>Forecast the results</h4>

# %%
# Add check for 'RATE_actual' values to avoid division by zero
def compute_accuracy(row):
    if row['RATE_actual'] == 0:
        return np.nan
    else:
        error = abs(row['RATE_actual'] - row['RATE_forecasted'])
        error_proportion = error / row['RATE_actual']
        return (1 - error_proportion) * 100

def forecast_next_weeks(model, look_back, scaler, last_values, n_weeks):
    forecast = []
    for _ in range(n_weeks):
        last_values_2d = np.array(last_values[-look_back:]).reshape(-1, 1)
        input_values_scaled = scaler.transform(last_values_2d)
        input_values_scaled = input_values_scaled.reshape((1, look_back, 1))
        input_values_scaled = np.repeat(input_values_scaled, 2, axis=-1)
        input_values_scaled[..., 1] = 0

        prediction = model.predict(input_values_scaled)
        prediction = scaler.inverse_transform(prediction)
        forecast.append(prediction[0][0])
        last_values.append(prediction[0][0])

    return forecast

# %%
weeks = 12

# Ensure that 'YearMonthWeek' is a datetime object
agg_df['YearMonthWeek'] = pd.to_datetime(agg_df['YearMonthWeek'])
last_date = agg_df['YearMonthWeek'].iloc[-1]

last_values = list(agg_df['Rate'].values[-look_back:])
forecasted_values = forecast_next_weeks(model, look_back, scaler, last_values, weeks)
forecasted_dates = pd.date_range(start=last_date, periods=weeks+1, freq='W')[1:]

df_forecasted = pd.DataFrame({
    'POD': forecasted_dates,
    'RATE': forecasted_values
})

df_forecasted["RATE"] = df_forecasted["RATE"].round(2)

df_forecasted.head(5)
df_forecasted.tail(5)
df_forecasted.info()
# Out:
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - ETA: 0s
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#          POD        RATE
# 0 2023-02-26  577.669983
# 1 2023-03-05  578.880005
# 2 2023-03-12  580.099976
# 3 2023-03-19  580.940002
# 4 2023-03-26  581.520020
#           POD        RATE
# 7  2023-04-16  581.960022
# 8  2023-04-23  581.960022
# 9  2023-04-30  581.960022
# 10 2023-05-07  581.960022
# 11 2023-05-14  581.960022
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POD     12 non-null     datetime64[ns]
#  1   RATE    12 non-null     float32
# dtypes: datetime64[ns](1), float32(1)
# memory usage: 272.0 bytes

# %% [markdown]
# <h4>Comparing with actual updated against forecasted</h4>

# %%
comparison_df = pd.DataFrame(columns=['WeekStart', 'WeekEnd', 'POD_actual', 'RATE_forecasted', 'RATE_actual'])
df_forecasted['WeekEnd'] = df_forecasted['POD'] + pd.to_timedelta(7, unit='d')  

for _, row in df_forecasted.iterrows():
    mask = (new_dates_df['POD'] >= row['POD']) & (new_dates_df['POD'] < row['WeekEnd'])
    actual_dates_within_week = new_dates_df[mask]

    for _, actual_row in actual_dates_within_week.iterrows():
        comparison_df = comparison_df.append({
            'WeekStart': row['POD'],
            'WeekEnd': row['WeekEnd'],
            'POD_actual': actual_row['POD'],
            'RATE_forecasted': row['RATE'],
            'RATE_actual': actual_row['RATE']
        }, ignore_index=True)

# Remove duplicates
comparison_df = comparison_df.drop_duplicates(subset=['POD_actual', 'RATE_forecasted', 'RATE_actual']).reset_index(drop=True)

# Compute accuracy
comparison_df['accuracy'] = comparison_df.apply(compute_accuracy, axis=1)
comparison_df = comparison_df.dropna(subset=['accuracy'])

total_mean_accuracy = comparison_df['accuracy'].mean()
comparison_df
print(f'The mean accuracy is {total_mean_accuracy:.2f}%\n')
# Out:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_33248\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
#     WeekStart    WeekEnd POD_actual  RATE_forecasted  RATE_actual   accuracy
# 0  2023-02-26 2023-03-05 2023-03-02       577.669983       1000.0  57.766998
# 1  2023-03-05 2023-03-12 2023-03-10       578.880005       1000.0  57.888000
# 2  2023-03-12 2023-03-19 2023-03-16       580.099976       1000.0  58.009998
# 3  2023-03-19 2023-03-26 2023-03-21       580.940002        600.0  96.823334
# 4  2023-03-26 2023-04-02 2023-03-26       581.520020        600.0  96.920003
# 5  2023-03-26 2023-04-02 2023-03-31       581.520020        650.0  89.464618
# 6  2023-04-02 2023-04-09 2023-04-06       581.969971        650.0  89.533842
# 7  2023-04-09 2023-04-16 2023-04-13       581.960022        650.0  89.532311
# 8  2023-04-16 2023-04-23 2023-04-20       581.960022        650.0  89.532311
# 9  2023-04-23 2023-04-30 2023-04-28       581.960022        500.0  83.607996
# 10 2023-04-30 2023-05-07 2023-05-05       581.960022        500.0  83.607996
# 11 2023-05-07 2023-05-14 2023-05-11       581.960022        500.0  83.607996
# 12 2023-05-14 2023-05-21 2023-05-19       581.960022        400.0  54.509995
# The mean accuracy is 79.29%

# %% [markdown]
# <h4>Visualise all, Conclusion</h4>

# %%
plt.figure(figsize=(20, 10))
plt.plot(sel_df['POD'], sel_df['RATE'], color='blue', label="Actual Data")
plt.plot(new_dates_df['POD'], new_dates_df['RATE'], color='blue', label="Actual Data (Updated)")

plt.plot(df_interpolated['POD'], df_interpolated['RATE'], color='green', label="Aggregated Data")
plt.plot(df_forecasted['POD'], df_forecasted['RATE'], color='red', label="Forecasted Data")

plt.xlabel('Date(Year Month)')
plt.ylabel('Cost Rate(USD)')
plt.title('Port_BUSAN_Size_40_Type_HC_PartyID_010004286')
plt.legend()
plt.show();
