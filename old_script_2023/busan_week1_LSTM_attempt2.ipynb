# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Dropout, LSTM, Dense
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from IPython.core.interactiveshell import InteractiveShell
from sklearn.preprocessing import MinMaxScaler
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline
sns.set()
pd.options.display.max_rows = 100

# %% [markdown]
# <h4>Importing Datasets</h4>

# %%
# Import dataset and clean, ready as a dataframe for creating keys
def createDF(datasets):
    df = pd.read_csv(datasets, converters={'PARTY_ID': str, 'COM_ID': str, 'CNTR_SIZE': str})

    # Formating to type and remove NaN values
    df['POD'] = pd.to_datetime(df['POD'])
    df['ENCODED_TYPE'] = df['ENCODED_TYPE'].fillna(-1).astype(int)
    df = df.dropna(subset=['ENCODED_TYPE'])
    df['RATE'] = df['RATE'].fillna(-1).astype(float)
    df = df.dropna(subset=['RATE'])
    df['ENCODED_TYPE'] = df['ENCODED_TYPE'].astype(int)
    df_clean= df.dropna().reset_index(drop=True)

    # Selecting and rearranging columns
    sel_col = ['CSL_ID', 'CNTR_ID','POD_ID','ETD_POL_D','PARTY_ID',
            'PARTY_NAME','POD','CNTR_SIZE','CNTR_TYPE','RATE']
    df_fc = df_clean[sel_col]

    # Removing years we do not want to process in our models
    df_filtered = df_fc[df_fc['POD'].dt.year != 2002]

    # Sorting the dates
    df_filtered = df_filtered.sort_values(by='POD').reset_index(drop=True)
    
    return df_filtered

# %%
# Create Dataframes for old and new
old_data = '.\Datasets\CR_COST_FC.csv'
df1 = createDF(old_data)
df1.head()

new_data = '.\Datasets\CR_COST_FC_new.csv'
df2 = createDF(new_data)
df2.head()
# Out:
#            CSL_ID           CNTR_ID          POD_ID ETD_POL_D  PARTY_ID  \
# 0  ECS01050600224  CTNR010050700354       ROTTERDAM     NLRTM  01008827
# 1  ECS01050600610  CTNR010050700353      FELIXSTOWE     GBFXT  01002303
# 2  ECS01050600041  CTNR010050700351        AUCKLAND     NZAKL  01005136
# 3  ECS01050600163  CTNR010050700370    PASIR GUDANG     MYPGU  01002767
# 4  ECS01050600456  CTNR010050700450  KARACHI (KICT)     PKKHI  01002783
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0             YANG MING (SINGAPORE) PTE. LTD. 2005-07-15        40    HC NOR
# 1                    GLOBELINK FALLOW LIMITED 2005-07-15        40        GP
# 2  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-15        40    HC NOR
# 3          GLOBELINK CONTAINER LINES (JB) S/B 2005-07-15        40        HC
# 4                GLOBELINK PAKISTAN (PVT) LTD 2005-07-16        40        HC
#
#      RATE
# 0  1620.0
# 1  1800.0
# 2  2170.0
# 3   280.0
# 4  1625.0
#            CSL_ID           CNTR_ID          POD_ID ETD_POL_D  PARTY_ID  \
# 0  ECS01050600224  CTNR010050700354       ROTTERDAM     NLRTM  01008827
# 1  ECS01050600610  CTNR010050700353      FELIXSTOWE     GBFXT  01002303
# 2  ECS01050600041  CTNR010050700351        AUCKLAND     NZAKL  01005136
# 3  ECS01050600163  CTNR010050700370    PASIR GUDANG     MYPGU  01002767
# 4  ECS01050600456  CTNR010050700450  KARACHI (KICT)     PKKHI  01002783
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0             YANG MING (SINGAPORE) PTE. LTD. 2005-07-15        40    HC NOR
# 1                    GLOBELINK FALLOW LIMITED 2005-07-15        40        GP
# 2  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-15        40    HC NOR
# 3          GLOBELINK CONTAINER LINES (JB) S/B 2005-07-15        40        HC
# 4                GLOBELINK PAKISTAN (PVT) LTD 2005-07-16        40        HC
#
#      RATE
# 0  1620.0
# 1  1800.0
# 2  2170.0
# 3   280.0
# 4  1625.0

# %% [markdown]
# <h4>Creating Dictionary Keys</h4>

# %%
def filter_dataframe(df):
    filtered_dataframes = {}

    for (port, size, ctype, party_id), group in df.groupby(['POD_ID', 'CNTR_SIZE', 'CNTR_TYPE', 'PARTY_ID']):
        group = group.reset_index(drop=True).sort_values(by='POD')
        df_id = f"Port_{port}_Size_{size}_Type_{ctype}_PartyID_{party_id}"
        filtered_dataframes[df_id] = group

    return filtered_dataframes

# %%
# Creating keys from data
print("Old Data keys:")
filtered_dataframe1 = filter_dataframe(df1)
df_ids1 = list(filtered_dataframe1.keys())
print(list(df_ids1))
print(len(list(df_ids1)))

print("\nNew Data keys:")
filtered_dataframe2 = filter_dataframe(df2)
df_ids2 = list(filtered_dataframe2.keys())
print(list(df_ids2))
print(len(list(df_ids2)))
# Out:
# Old Data keys:
# ['Port_(CONSTANZA)_Size_40_Type_GP_PartyID_010007816', 'Port_(CONSTANZA)_Size_40_Type_HC_PartyID_010007816', 'Port_AARHUS_Size_20_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100027830', 'Port_AARHUS_Size_20_Type_GP_PartyID_010006666', 'Port_AARHUS_Size_40_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100027830', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100028193', 'Port_AARHUS_Size_40_Type_HC_PartyID_010006666', 'Port_ABIDJAN_Size_20_Type_GP_PartyID_0100027878', 'Port_ABIDJAN_Size_40_Type_HC_PartyID_010021097', 'Port_ADELAIDE_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01005078', 'Port_ADELAIDE_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ALEXANDRIA (EL DEKHELA PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC NOR_PartyID_010004995', 'Port_ALGECIRAS_Size_20_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC NOR_PartyID_01008306', 'Port_ALIAGA_Size_20_Type_GP_PartyID_01008316', 'Port_ALIAGA_Size_40_Type_HC_PartyID_01008316', 'Port_ALIAGA PORT (IZMIR)_Size_40_Type_HC_PartyID_01008316', 'Port_ANTWERP_Size_20_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC NOR_PartyID_01001449', 'Port_AQABA_Size_20_Type_GP_PartyID_010006618', 'Port_AQABA_Size_20_Type_GP_PartyID_010021081', 'Port_AQABA_Size_40_Type_HC_PartyID_010006618', 'Port_AQABA_Size_40_Type_HC_PartyID_010021081', 'Port_ASHDOD_Size_20_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_01008417', 'Port_ASHDOD_Size_40_Type_HC_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_HC_PartyID_01008417', 'Port_AUCKLAND_Size_20_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_20_Type_GP (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC NOR_PartyID_01005136', 'Port_BANGKOK_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_20_Type_GP (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (SOC)_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK (TST)_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK (TST)_Size_40_Type_HC_PartyID_010021593', 'Port_BARCELONA_Size_20_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC NOR_PartyID_01008305', 'Port_BEIRUT_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_HC_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_40_Type_HC_PartyID_0100 ...
# 789
#
# New Data keys:
# ['Port_(CONSTANZA)_Size_40_Type_GP_PartyID_010007816', 'Port_(CONSTANZA)_Size_40_Type_HC_PartyID_010007816', 'Port_AARHUS_Size_20_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100027830', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100028193', 'Port_AARHUS_Size_20_Type_GP_PartyID_010006666', 'Port_AARHUS_Size_40_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100027830', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100028193', 'Port_AARHUS_Size_40_Type_HC_PartyID_010006666', 'Port_ABIDJAN_Size_20_Type_GP_PartyID_0100027878', 'Port_ABIDJAN_Size_40_Type_HC_PartyID_010021097', 'Port_ADELAIDE_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01005078', 'Port_ADELAIDE_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ALEXANDRIA (EL DEKHELA PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC NOR_PartyID_010004995', 'Port_ALGECIRAS_Size_20_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC NOR_PartyID_01008306', 'Port_ALIAGA_Size_20_Type_GP_PartyID_01008316', 'Port_ALIAGA_Size_40_Type_HC_PartyID_01008316', 'Port_ALIAGA PORT (IZMIR)_Size_40_Type_HC_PartyID_01008316', 'Port_ANTWERP_Size_20_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC NOR_PartyID_01001449', 'Port_AQABA_Size_20_Type_GP_PartyID_010006618', 'Port_AQABA_Size_20_Type_GP_PartyID_010021081', 'Port_AQABA_Size_40_Type_HC_PartyID_010006618', 'Port_AQABA_Size_40_Type_HC_PartyID_010021081', 'Port_ASHDOD_Size_20_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_01008417', 'Port_ASHDOD_Size_40_Type_HC_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_HC_PartyID_01008417', 'Port_AUCKLAND_Size_20_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_20_Type_GP (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC NOR_PartyID_01005136', 'Port_BANGKOK_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_20_Type_GP (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (SOC)_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK (TST)_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK (TST)_Size_40_Type_HC_PartyID_010021593', 'Port_BARCELONA_Size_20_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC NOR_PartyID_01008305', 'Port_BEIRUT_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_HC_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_20_Type_GP_PartyID_010003651', ' ...
# 799

# %% [markdown]
# <h4>Getting Top 5 ports keys</h4>

# %%
def getTop5Ports(keybunch):
    keybunch_pouch = []
    
    # Get a dictionary with key and number of rows for each dataframe in filtered_dataframes
    key_row_counts = {key: len(keybunch[key]) for key in keybunch}

    # Sort the key_row_counts dictionary by value (number of rows) in descending order
    sorted_key_row_counts = sorted(key_row_counts.items(), key=lambda item: item[1], reverse=True)

    # Get the top 5 keys with the most rows
    top_5_keys_tuple = sorted_key_row_counts[:5]

    # Create a dictionary with the top 5 keys and their corresponding dataframes (with up to 5 rows per dataframe)
    keybunch_subset = {}

    for key, row_count in top_5_keys_tuple:
        keybunch_subset[key] = keybunch[key][:5]
        print(f"Number of rows in {key}: {row_count}")
        keybunch_pouch.append(key)
    
    # Return array of keys
    return keybunch_pouch

# %%
print('Old Dataset Keybunch:')
old_df = getTop5Ports(filtered_dataframe1)
print('\n')

print('New Dataset Keybunch:')
new_df = getTop5Ports(filtered_dataframe2)
# Out:
# Old Dataset Keybunch:
# Number of rows in Port_BUSAN_Size_40_Type_HC_PartyID_010004286: 1689
# Number of rows in Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136: 1688
# Number of rows in Port_MELBOURNE_Size_40_Type_HC_PartyID_01002778: 1325
# Number of rows in Port_SYDNEY_Size_40_Type_HC_PartyID_01002779: 1300
# Number of rows in Port_DUBAI (JEBEL ALI)_Size_40_Type_HC_PartyID_01002788: 1052
#
#
# New Dataset Keybunch:
# Number of rows in Port_BUSAN_Size_40_Type_HC_PartyID_010004286: 1712
# Number of rows in Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136: 1704
# Number of rows in Port_MELBOURNE_Size_40_Type_HC_PartyID_01002778: 1341
# Number of rows in Port_SYDNEY_Size_40_Type_HC_PartyID_01002779: 1308
# Number of rows in Port_DUBAI (JEBEL ALI)_Size_40_Type_HC_PartyID_01002788: 1070

# %%
# Accessing the highest count in the each keypouch, new and old.
sel_df = filtered_dataframe1[old_df[0]]
sel_df.head(5)
sel_df.tail(5)
sel_df.info()
print("\n")

latest_sel_df = filtered_dataframe2[new_df[0]]
latest_sel_df.head(5)
latest_sel_df.tail(5)
latest_sel_df.info()
# Out:
#             CSL_ID           CNTR_ID POD_ID ETD_POL_D   PARTY_ID  \
# 0  ECS010050800407  CTNR010050901151  BUSAN     KRPUS  010004286
# 1  ECS010050800407  CTNR010050901379  BUSAN     KRPUS  010004286
# 2  ECS010050900468  CTNR010051000081  BUSAN     KRPUS  010004286
# 3  ECS010050900468  CTNR010050901461  BUSAN     KRPUS  010004286
# 4  ECS010050900469  CTNR010051000434  BUSAN     KRPUS  010004286
#
#                  PARTY_NAME        POD CNTR_SIZE CNTR_TYPE   RATE
# 0  GLOBELINK KOREA CO., LTD 2005-10-03        40        HC  390.0
# 1  GLOBELINK KOREA CO., LTD 2005-10-03        40        HC  390.0
# 2  GLOBELINK KOREA CO., LTD 2005-10-07        40        HC  390.0
# 3  GLOBELINK KOREA CO., LTD 2005-10-07        40        HC  390.0
# 4  GLOBELINK KOREA CO., LTD 2005-10-14        40        HC  390.0
#                CSL_ID       CNTR_ID POD_ID ETD_POL_D   PARTY_ID  \
# 1684  ECS010230100126  010000391908  BUSAN     KRPUS  010004286
# 1685  ECS010230100126  010000380884  BUSAN     KRPUS  010004286
# 1687  ECS010230100127  010000407833  BUSAN     KRPUS  010004286
# 1686  ECS010230100127  010000390366  BUSAN     KRPUS  010004286
# 1688  ECS010230100127  010000401385  BUSAN     KRPUS  010004286
#
#                     PARTY_NAME        POD CNTR_SIZE CNTR_TYPE   RATE
# 1684  GLOBELINK KOREA CO., LTD 2023-02-22        40        HC  300.0
# 1685  GLOBELINK KOREA CO., LTD 2023-02-22        40        HC  300.0
# 1687  GLOBELINK KOREA CO., LTD 2023-02-28        40        HC  300.0
# 1686  GLOBELINK KOREA CO., LTD 2023-02-28        40        HC  300.0
# 1688  GLOBELINK KOREA CO., LTD 2023-02-28        40        HC  300.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1689 entries, 0 to 1688
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      1689 non-null   object
#  1   CNTR_ID     1689 non-null   object
#  2   POD_ID      1689 non-null   object
#  3   ETD_POL_D   1689 non-null   object
#  4   PARTY_ID    1689 non-null   object
#  5   PARTY_NAME  1689 non-null   object
#  6   POD         1689 non-null   datetime64[ns]
#  7   CNTR_SIZE   1689 non-null   object
#  8   CNTR_TYPE   1689 non-null   object
#  9   RATE        1689 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 145.1+ KB
#             CSL_ID           CNTR_ID POD_ID ETD_POL_D   PARTY_ID  \
# 0  ECS010050800407  CTNR010050901151  BUSAN     KRPUS  010004286
# 1  ECS010050800407  CTNR010050901379  BUSAN     KRPUS  010004286
# 2  ECS010050900468  CTNR010051000081  BUSAN     KRPUS  010004286
# 3  ECS010050900468  CTNR010050901461  BUSAN     KRPUS  010004286
# 4  ECS010050900469  CTNR010051000434  BUSAN     KRPUS  010004286
#
#                  PARTY_NAME        POD CNTR_SIZE CNTR_TYPE   RATE
# 0  GLOBELINK KOREA CO., LTD 2005-10-03        40        HC  390.0
# 1  GLOBELINK KOREA CO., LTD 2005-10-03        40        HC  390.0
# 2  GLOBELINK KOREA CO., LTD 2005-10-07        40        HC  390.0
# 3  GLOBELINK KOREA CO., LTD 2005-10-07        40        HC  390.0
# 4  GLOBELINK KOREA CO., LTD 2005-10-14        40        HC  390.0
#                CSL_ID       CNTR_ID POD_ID ETD_POL_D   PARTY_ID  \
# 1708  ECS010230300113  010000512466  BUSAN     KRPUS  010004286
# 1707  ECS010230300113  010000534846  BUSAN     KRPUS  010004286
# 1709  ECS010230400203  010000544930  BUSAN     KRPUS  010004286
# 1710  ECS010230400183  010000565100  BUSAN     KRPUS  010004286
# 1711  ECS010230400183  010000554335  BUSAN     KRPUS  010004286
#
#                     PARTY_NAME        POD CNTR_SIZE CNTR_TYPE   RATE
# 1708  GLOBELINK KOREA CO., LTD 2023-05-03        40        HC  260.0
# 1707  GLOBELINK KOREA CO., LTD 2023-05-03        40        HC  260.0
# 1709  GLOBELINK KOREA CO., LTD 2023-05-10        40        HC  300.0
# 1710  GLOBELINK KOREA CO., LTD 2023-05-17        40        HC  260.0
# 1711  GLOBELINK KOREA CO., LTD 2023-05-17        40        HC  260.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1712 entries, 0 to 1711
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      1712 non-null   object
#  1   CNTR_ID     1712 non-null   object
#  2   POD_ID      1712 non-null   object
#  3   ETD_POL_D   1712 non-null   object
#  4   PARTY_ID    1712 non-null   object
#  5   PARTY_NAME  1712 non-null   object
#  6   POD         1712 non-null   datetime64[ns]
#  7   CNTR_SIZE   1712 non-null   object
#  8   CNTR_TYPE   1712 non-null   object
#  9   RATE        1712 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 147.1+ KB

# %%
from sklearn.preprocessing import RobustScaler

# Select features
sel_feat = ['POD','RATE']
robust_df = sel_df[sel_feat].copy()  # make a copy to avoid SettingWithCopyWarning

# Robust Scaling
scaler = RobustScaler()
robust_df.loc[:, 'RATE'] = scaler.fit_transform(robust_df[['RATE']])
robust_df.head()
# Out:
#          POD      RATE
# 0 2005-10-03  2.777778
# 1 2005-10-03  2.777778
# 2 2005-10-07  2.777778
# 3 2005-10-07  2.777778
# 4 2005-10-14  2.777778

# %%
# Check if the DataFrame has any NaN values
if robust_df.isna().any().any():
    print("The DataFrame contains NaN values.")
else:
    print("The DataFrame does not contain NaN values.")
# Out:
# The DataFrame does not contain NaN values.

# %% [markdown]
# <h4>Interpolate missing values in between dates</h4>

# %%
# Remove duplicated dates and cost rows
robust_df = robust_df.drop_duplicates(subset=['POD', 'RATE']).reset_index(drop=True)

# Create a new dataframe with a date range from min to max date in your dataframe
new_df = pd.DataFrame()
new_df['POD'] = pd.date_range(start=robust_df['POD'].min(), end=robust_df['POD'].max())

# Merge the original dataframe with the new one. Missing dates in the original dataframe will be filled with NaN
df_interpolated = pd.merge(new_df, robust_df, on='POD', how='left')  

# Perform spline interpolation
df_interpolated['RATE'] = df_interpolated['RATE'].interpolate(method='polynomial', order=1)

df_interpolated['RATE'] = df_interpolated['RATE'].round(3)

# Now we need to inverse the scaling
df_interpolated['RATE'] = scaler.inverse_transform(df_interpolated[['RATE']])

df_interpolated.head(5)
df_interpolated.tail(5)
df_interpolated.info()
# Out:
#          POD    RATE
# 0 2005-10-03  390.02
# 1 2005-10-04  390.02
# 2 2005-10-05  390.02
# 3 2005-10-06  390.02
# 4 2005-10-07  390.02
#             POD    RATE
# 6371 2023-02-24  300.02
# 6372 2023-02-25  300.02
# 6373 2023-02-26  300.02
# 6374 2023-02-27  300.02
# 6375 2023-02-28  300.02
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6376 entries, 0 to 6375
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POD     6376 non-null   datetime64[ns]
#  1   RATE    6376 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 149.4 KB

# %% [markdown]
# <h4>Grouping it to week</h4>

# %%
from scipy import stats

# Create YearMonthWeek directly from the 'POD'
df_interpolated['YearMonthWeek'] = df_interpolated['POD'] - pd.to_timedelta(df_interpolated['POD'].dt.dayofweek, unit='D')

# Create a new dataframe with every week in the range
all_weeks = pd.date_range(start=df_interpolated['POD'].min(), end=df_interpolated['POD'].max(), freq='W')
all_weeks_df = pd.DataFrame(all_weeks, columns=['POD'])

# Create YearMonthWeek in all_weeks_df
all_weeks_df['YearMonthWeek'] = all_weeks_df['POD'] - pd.to_timedelta(all_weeks_df['POD'].dt.dayofweek, unit='D')

# Merge this with your original dataframe
merged_df = pd.merge(all_weeks_df, df_interpolated, on=['YearMonthWeek'], how='left')

# Now you can group by YearMonthWeek and compute your rate
grouped = merged_df.groupby(['YearMonthWeek'])

agg_df = pd.DataFrame(columns=['YearMonthWeek', 'Rate'])

for group_name, group_df in grouped:
    year_month_week = group_name

    # Skip if no data for this week
    if group_df['RATE'].isnull().all():
        continue

    # Calculate sum and skewness of RATE values
    rate_sum = group_df['RATE'].sum()
    rate_skew = group_df['RATE'].skew()

    # Calculate trimmed mean of RATE values
    rate_metric = stats.trim_mean(group_df['RATE'].dropna().values, 0.1) # trimming 10% from each end

    new_row = {
        'YearMonthWeek': year_month_week,
        'Rate': rate_metric
    }

    # Append row to aggregated dataframe
    agg_df = agg_df.append(new_row, ignore_index=True)

agg_df = agg_df.sort_values(by='YearMonthWeek').reset_index(drop=True)
agg_df['Rate'] = agg_df['Rate'].round(2)

agg_df.head(15)
agg_df.tail(15)
agg_df.info()
# Out:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:21: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for group_name, group_df in grouped:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# ...
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
#    YearMonthWeek    Rate
# 0     2005-10-03  390.02
# 1     2005-10-10  390.02
# 2     2005-10-17  390.02
# 3     2005-10-24  390.02
# 4     2005-10-31  390.02
# 5     2005-11-07  390.02
# 6     2005-11-14  390.02
# 7     2005-11-21  390.02
# 8     2005-11-28  390.02
# 9     2005-12-05  390.02
# 10    2005-12-12  390.02
# 11    2005-12-19  390.02
# 12    2005-12-26  390.02
# 13    2006-01-02  390.02
# 14    2006-01-09  390.02
#     YearMonthWeek    Rate
# 893    2022-11-14  149.99
# 894    2022-11-21  158.57
# 895    2022-11-28  191.43
# 896    2022-12-05  184.61
# 897    2022-12-12  211.52
# 898    2022-12-19  161.00
# 899    2022-12-26  159.17
# 900    2023-01-02  269.39
# 901    2023-01-09  300.02
# 902    2023-01-16  295.25
# 903    2023-01-23  233.33
# 904    2023-01-30  204.79
# 905    2023-02-06  245.25
# 906    2023-02-13  214.30
# 907    2023-02-20  292.87
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908 entries, 0 to 907
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   YearMonthWeek  908 non-null    datetime64[ns]
#  1   Rate           908 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 14.3 KB

# %% [markdown]
# <h4>Latest datapoints from Latest dataframe for comparing after forecasting (Measure accuracy)</h4>

# %%
max_date_in_old = sel_df['POD'].max()

# Create a new dataframe that only includes rows from the latest dataframe where the date is greater than the maximum date in the old dataframe
new_dates_df = latest_sel_df[latest_sel_df['POD'] > max_date_in_old].reset_index(drop=True)

# Print the new dataframe
new_dates_df.head(3)
new_dates_df.tail(3)
new_dates_df.info()
# Out:
#             CSL_ID       CNTR_ID POD_ID ETD_POL_D   PARTY_ID  \
# 0  ECS010230200077  010000419950  BUSAN     KRPUS  010004286
# 1  ECS010230200077  010000406570  BUSAN     KRPUS  010004286
# 2  ECS010230200078  010000432251  BUSAN     KRPUS  010004286
#
#                  PARTY_NAME        POD CNTR_SIZE CNTR_TYPE   RATE
# 0  GLOBELINK KOREA CO., LTD 2023-03-08        40        HC  260.0
# 1  GLOBELINK KOREA CO., LTD 2023-03-08        40        HC  260.0
# 2  GLOBELINK KOREA CO., LTD 2023-03-15        40        HC  260.0
#              CSL_ID       CNTR_ID POD_ID ETD_POL_D   PARTY_ID  \
# 20  ECS010230400203  010000544930  BUSAN     KRPUS  010004286
# 21  ECS010230400183  010000565100  BUSAN     KRPUS  010004286
# 22  ECS010230400183  010000554335  BUSAN     KRPUS  010004286
#
#                   PARTY_NAME        POD CNTR_SIZE CNTR_TYPE   RATE
# 20  GLOBELINK KOREA CO., LTD 2023-05-10        40        HC  300.0
# 21  GLOBELINK KOREA CO., LTD 2023-05-17        40        HC  260.0
# 22  GLOBELINK KOREA CO., LTD 2023-05-17        40        HC  260.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      23 non-null     object
#  1   CNTR_ID     23 non-null     object
#  2   POD_ID      23 non-null     object
#  3   ETD_POL_D   23 non-null     object
#  4   PARTY_ID    23 non-null     object
#  5   PARTY_NAME  23 non-null     object
#  6   POD         23 non-null     datetime64[ns]
#  7   CNTR_SIZE   23 non-null     object
#  8   CNTR_TYPE   23 non-null     object
#  9   RATE        23 non-null     float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 1.9+ KB

# %%
plt.figure(figsize=(20, 10))
plt.plot(sel_df['POD'], sel_df['RATE'], color='blue', label="Actual Data")
plt.plot(agg_df['YearMonthWeek'], agg_df['Rate'], color='red', label="Aggregated Data(weeks)")

plt.xlabel('Date(Year Month Week)')
plt.ylabel('Cost Rate(USD)')
plt.title('Port_BUSAN_Size_40_Type_HC_PartyID_010004286')
plt.legend()
plt.show();

# %% [markdown]
# <h4>LSTM Regression<h4>

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# Mean Square Error Function:
def calculate_RMSE(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# Restructure time series data for LSTM model
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

def create_LSTM_model(trainX, trainY, testX, testY, epochs):
    model = Sequential()
    model.add(LSTM(256, return_sequences=True, input_shape=(trainX.shape[1], trainX.shape[2]), 
                   activation='tanh', recurrent_activation='hard_sigmoid', kernel_regularizer=l2(0.01)))
    model.add(Dropout(0.1))  # 30% dropout

    # Add regularization to all LSTM layers
    for size in [256, 128, 128, 64, 64, 32, 32, 16, 16, 8, 8]:
        model.add(LSTM(size, activation='tanh', return_sequences=True, kernel_regularizer=l2(0.01)))
    
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=0.001))
    model.summary()

    # Add early stopping
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
    
    # Fit the model and store the history
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=64, verbose=2, 
                        validation_data=(testX, testY), callbacks=[es])
    return model, history

def plot_train_val_loss(history):
    plt.figure(figsize=(10,6))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model loss progress during training and validation')
    plt.xlabel('Epoch')
    plt.ylabel('Training and Validation Loss')
    plt.legend()
    plt.show()

# %%
# Normalize dataset for LSTM
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(agg_df['Rate'].values.reshape(-1,1))

# Split into train and test sets
train_size = int(len(dataset) * 0.7)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# Reshape into X=t and Y=t+1, timestep  look_back
look_back = 5
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# Reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

epochs_list = [50, 100, 150]

rmse_results = {}

for epochs in epochs_list:
    print(f'Training for {epochs} epochs...')
    model, history = create_LSTM_model(trainX, trainY, testX, testY, epochs)
    
    # Add the loss for this model to the plot
    plt.plot(history.history['loss'], label=f'Train Loss - {epochs} epochs')
    plt.plot(history.history['val_loss'], label=f'Validation Loss - {epochs} epochs')

    # Configure and show the plot
    plt.title('Model loss progress during training and validation')
    plt.xlabel('Epoch')
    plt.ylabel('Training and Validation Loss')
    plt.legend()
    plt.show();

   # Evalute LSTM Model
    trainPredict = model.predict(trainX)
    testPredict = model.predict(testX)

    # Take last predictions from the sequence for each sample
    trainPredict = trainPredict[:, -1, :]
    testPredict = testPredict[:, -1, :]

    # Now you can use inverse_transform
    trainPredict = scaler.inverse_transform(trainPredict)
    trainY_orig = scaler.inverse_transform([trainY])
    testPredict = scaler.inverse_transform(testPredict)
    testY_orig = scaler.inverse_transform([testY])

    # Calculate mean squared error
    trainScore = calculate_RMSE(trainY_orig[0], trainPredict[:,0])
    print(f'Train Score: {trainScore:.2f} RMSE for {epochs} epochs')
    testScore = calculate_RMSE(testY_orig[0], testPredict[:,0])
    print(f'Test Score: {testScore:.2f} RMSE for {epochs} epochs')

    rmse_results[epochs] = {'Train RMSE': trainScore, 'Test RMSE': testScore}

# Convert the dictionary to a DataFrame for easy display
rmse_df = pd.DataFrame(rmse_results).T
print(rmse_df)
# Out:
# Training for 50 epochs...
# Model: "sequential_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_268 (LSTM)             (None, 1, 256)            268288
#
#  dropout_32 (Dropout)        (None, 1, 256)            0
#
#  lstm_269 (LSTM)             (None, 1, 256)            525312
#
#  lstm_270 (LSTM)             (None, 1, 128)            197120
#
#  lstm_271 (LSTM)             (None, 1, 128)            131584
#
#  lstm_272 (LSTM)             (None, 1, 64)             49408
#
#  lstm_273 (LSTM)             (None, 1, 64)             33024
#
#  lstm_274 (LSTM)             (None, 1, 32)             12416
#
#  lstm_275 (LSTM)             (None, 1, 32)             8320
#
#  lstm_276 (LSTM)             (None, 1, 16)             3136
#
#  lstm_277 (LSTM)             (None, 1, 16)             2112
#
#  lstm_278 (LSTM)             (None, 1, 8)              800
#
#  lstm_279 (LSTM)             (None, 1, 8)              544
#
#  dense_32 (Dense)            (None, 1, 1)              9
#
# =================================================================
# Total params: 1,232,073
# Trainable params: 1,232,073
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 10/10 - 24s - loss: 12.9646 - val_loss: 10.8243 - 24s/epoch - 2s/step
# Epoch 2/50
# 10/10 - 0s - loss: 9.3586 - val_loss: 7.7696 - 301ms/epoch - 30ms/step
# Epoch 3/50
# 10/10 - 0s - loss: 6.6949 - val_loss: 5.5615 - 285ms/epoch - 28ms/step
# Epoch 4/50
# 10/10 - 0s - loss: 4.7918 - val_loss: 4.0053 - 289ms/epoch - 29ms/step
# Epoch 5/50
# 10/10 - 0s - loss: 3.4592 - val_loss: 2.9226 - 295ms/epoch - 29ms/step
# Epoch 6/50
# 10/10 - 0s - loss: 2.5338 - val_loss: 2.1706 - 297ms/epoch - 30ms/step
# Epoch 7/50
# 10/10 - 0s - loss: 1.8898 - val_loss: 1.6449 - 289ms/epoch - 29ms/step
# Epoch 8/50
# 10/10 - 0s - loss: 1.4375 - val_loss: 1.2722 - 301ms/epoch - 30ms/step
# Epoch 9/50
# 10/10 - 0s - loss: 1.1146 - val_loss: 1.0033 - 289ms/epoch - 29ms/step
# Epoch 10/50
# 10/10 - 0s - loss: 0.8798 - val_loss: 0.8054 - 293ms/epoch - 29ms/step
# Epoch 11/50
# 10/10 - 0s - loss: 0.7056 - val_loss: 0.6567 - 284ms/epoch - 28ms/step
# Epoch 12/50
# 10/10 - 0s - loss: 0.5736 - val_loss: 0.5429 - 289ms/epoch - 29ms/step
# Epoch 13/50
# 10/10 - 0s - loss: 0.4719 - val_loss: 0.4544 - 288ms/epoch - 29ms/step
# Epoch 14/50
# 10/10 - 0s - loss: 0.3921 - val_loss: 0.3843 - 288ms/epoch - 29ms/step
# Epoch 15/50
# 10/10 - 0s - loss: 0.3287 - val_loss: 0.3282 - 288ms/epoch - 29ms/step
# Epoch 16/50
# 10/10 - 0s - loss: 0.2776 - val_loss: 0.2828 - 304ms/epoch - 30ms/step
# Epoch 17/50
# 10/10 - 0s - loss: 0.2360 - val_loss: 0.2456 - 301ms/epoch - 30ms/step
# Epoch 18/50
# 10/10 - 0s - loss: 0.2019 - val_loss: 0.2149 - 317ms/epoch - 32ms/step
# Epoch 19/50
# 10/10 - 0s - loss: 0.1736 - val_loss: 0.1893 - 321ms/epoch - 32ms/step
# Epoch 20/50
# 10/10 - 0s - loss: 0.1500 - val_loss: 0.1680 - 308ms/epoch - 31ms/step
# Epoch 21/50
# 10/10 - 0s - loss: 0.1302 - val_loss: 0.1501 - 290ms/epoch - 29ms/step
# Epoch 22/50
# 10/10 - 0s - loss: 0.1134 - val_loss: 0.1348 - 304ms/epoch - 30ms/step
# Epoch 23/50
# 10/10 - 0s - loss: 0.0993 - val_loss: 0.1219 - 304ms/epoch - 30ms/step
# Epoch 24/50
# 10/10 - 0s - loss: 0.0872 - val_loss: 0.1109 - 321ms/epoch - 32ms/step
# Epoch 25/50
# 10/10 - 0s - loss: 0.0770 - val_loss: 0.1015 - 309ms/epoch - 31ms/step
# Epoch 26/50
# 10/10 - 0s - loss: 0.0682 - val_loss: 0.0934 - 294ms/epoch - 29ms/step
# Epoch 27/50
# 10/10 - 0s - loss: 0.0606 - val_loss: 0.0864 - 295ms/epoch - 29ms/step
# Epoch 28/50
# 10/10 - 0s - loss: 0.0541 - val_loss: 0.0804 - 291ms/epoch - 29ms/step
# Epoch 29/50
# 10/10 - 0s - loss: 0.0484 - val_loss: 0.0752 - 318ms/epoch - 32ms/step
# Epoch 30/50
# 10/10 - 0s - loss: 0.0436 - val_loss: 0.0707 - 310ms/epoch - 31ms/step
# Epoch 31/50
# 10/10 - 0s - loss: 0.0394 - val_loss: 0.0668 - 302ms/epoch - 30ms/step
# Epoch 32/50
# 10/10 - 0s - loss: 0.0357 - val_loss: 0.0635 - 308ms/epoch - 31ms/step
# Epoch 33/50
# 10/10 - 0s - loss: 0.0325 - val_loss: 0.0605 - 295ms/epoch - 29ms/step
# Epoch 34/50
# 10/10 - 0s - loss: 0.0298 - val_loss: 0.0580 - 289ms/epoch - 29ms/step
# Epoch 35/50
# 10/10 - 0s - loss: 0.0273 - val_loss: 0.0557 - 291ms/epoch - 29ms/step
# Epoch 36/50
# 10/10 - 0s - loss: 0.0252 - val_loss: 0.0538 - 292ms/epoch - 29ms/step
# Epoch 37/50
# 10/10 - 0s - loss: 0.0234 - val_loss: 0.0521 - 290ms/epoch - 29ms/step
# Epoch 38/50
# 10/10 - 0s - loss: 0.0218 - val_loss: 0.0506 - 291ms/epoch - 29ms/step
# Epoch 39/50
# 10/10 - 0s - loss: 0.0204 - val_loss: 0.0493 - 290ms/epoch - 29ms/step
# Epoch 40/50
# 10/10 - 0s - loss: 0.0192 - val_loss: 0.0482 - 300ms/epoch - 30ms/step
# Epoch 41/50
# 10/10 - 0s - loss: 0.0181 - val_loss: 0.0472 - 300ms/epoch - 30ms/step
# Epoch 42/50
# 10/10 - 0s - loss: 0.0172 - val_loss: 0.0464 - 304ms/epoch - 30ms/step
# Epoch 43/50
# 10/10 - 0s - loss: 0.0164 - val_loss: 0.0456 - 293ms/epoch - 29ms/step
# Epoch 44/50
# 10/10 - 0s - loss: 0.0157 - val_loss: 0.0449 - 291ms/epoch - 29ms/step
# Epoch 45/50
# 10/10 - 0s - loss: 0.0151 - val_loss: 0.0444 - 290ms/epoch - 29ms/step
# Epoch 46/50
# 10/10 - 0s - loss: 0.0145 - val_loss: 0.0439 - 288ms/epoch - 29ms/step
# Epoch 47/50
# 10/10 - 0s - loss: 0.0141 - val_loss: 0.0434 - 294ms/epoch - 29ms/step
# Epoch 48/50
# 10/10 - 0s - loss: 0.0137 - val_loss: 0.0431 - 297ms/epoch - 30ms/step
# Epoch 49/50
# 10/10 - 0s - loss: 0.0133 - val_loss: 0.0427 - 299ms/epoch - 30ms/step
# Epoch 50/50
# 10/10 - 0s - loss: 0.0130 - val_loss: 0.0424 - 300ms/epoch - 30ms/step
# Text(0.5, 1.0, 'Model loss progress during training and validation')
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'Training and Validation Loss')
# 20/20 [==============================] - 4s 5ms/step
# 9/9 [==============================] - 0s 5ms/step
# Train Score: 97.20 RMSE for 50 epochs
# Test Score: 187.57 RMSE for 50 epochs
# Training for 100 epochs...
# Model: "sequential_33"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_280 (LSTM)             (None, 1, 256)            268288
#
#  dropout_33 (Dropout)        (None, 1, 256)            0
#
#  lstm_281 (LSTM)             (None, 1, 256)            525312
#
#  lstm_282 (LSTM)             (None, 1, 128)            197120
#
#  lstm_283 (LSTM)             (None, 1, 128)            131584
#
#  lstm_284 (LSTM)             (None, 1, 64)             49408
#
#  lstm_285 (LSTM)             (None, 1, 64)             33024
#
#  lstm_286 (LSTM)             (None, 1, 32)             12416
#
#  lstm_287 (LSTM)             (None, 1, 32)             8320
#
#  lstm_288 (LSTM)             (None, 1, 16)             3136
#
#  lstm_289 (LSTM)             (None, 1, 16)             2112
#
#  lstm_290 (LSTM)             (None, 1, 8)              800
#
#  lstm_291 (LSTM)             (None, 1, 8)              544
#
#  dense_33 (Dense)            (None, 1, 1)              9
#
# =================================================================
# Total params: 1,232,073
# Trainable params: 1,232,073
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 10/10 - 24s - loss: 13.0191 - val_loss: 10.8727 - 24s/epoch - 2s/step
# Epoch 2/100
# 10/10 - 0s - loss: 9.4026 - val_loss: 7.8081 - 293ms/epoch - 29ms/step
# Epoch 3/100
# 10/10 - 0s - loss: 6.7299 - val_loss: 5.5922 - 293ms/epoch - 29ms/step
# Epoch 4/100
# 10/10 - 0s - loss: 4.8197 - val_loss: 4.0296 - 294ms/epoch - 29ms/step
# Epoch 5/100
# 10/10 - 0s - loss: 3.4813 - val_loss: 2.9417 - 306ms/epoch - 31ms/step
# Epoch 6/100
# 10/10 - 0s - loss: 2.5512 - val_loss: 2.1857 - 292ms/epoch - 29ms/step
# Epoch 7/100
# 10/10 - 0s - loss: 1.9037 - val_loss: 1.6568 - 353ms/epoch - 35ms/step
# Epoch 8/100
# 10/10 - 0s - loss: 1.4484 - val_loss: 1.2816 - 286ms/epoch - 29ms/step
# Epoch 9/100
# 10/10 - 0s - loss: 1.1232 - val_loss: 1.0107 - 294ms/epoch - 29ms/step
# Epoch 10/100
# 10/10 - 0s - loss: 0.8867 - val_loss: 0.8112 - 303ms/epoch - 30ms/step
# Epoch 11/100
# 10/10 - 0s - loss: 0.7110 - val_loss: 0.6613 - 289ms/epoch - 29ms/step
# Epoch 12/100
# 10/10 - 0s - loss: 0.5779 - val_loss: 0.5465 - 301ms/epoch - 30ms/step
# Epoch 13/100
# 10/10 - 0s - loss: 0.4752 - val_loss: 0.4571 - 319ms/epoch - 32ms/step
# Epoch 14/100
# 10/10 - 0s - loss: 0.3947 - val_loss: 0.3864 - 300ms/epoch - 30ms/step
# Epoch 15/100
# 10/10 - 0s - loss: 0.3306 - val_loss: 0.3298 - 303ms/epoch - 30ms/step
# Epoch 16/100
# 10/10 - 0s - loss: 0.2790 - val_loss: 0.2838 - 293ms/epoch - 29ms/step
# Epoch 17/100
# 10/10 - 0s - loss: 0.2369 - val_loss: 0.2462 - 315ms/epoch - 31ms/step
# Epoch 18/100
# 10/10 - 0s - loss: 0.2024 - val_loss: 0.2152 - 292ms/epoch - 29ms/step
# Epoch 19/100
# 10/10 - 0s - loss: 0.1738 - val_loss: 0.1894 - 303ms/epoch - 30ms/step
# Epoch 20/100
# 10/10 - 0s - loss: 0.1499 - val_loss: 0.1679 - 290ms/epoch - 29ms/step
# Epoch 21/100
# 10/10 - 0s - loss: 0.1299 - val_loss: 0.1497 - 307ms/epoch - 31ms/step
# Epoch 22/100
# 10/10 - 0s - loss: 0.1130 - val_loss: 0.1344 - 294ms/epoch - 29ms/step
# Epoch 23/100
# 10/10 - 0s - loss: 0.0988 - val_loss: 0.1213 - 290ms/epoch - 29ms/step
# Epoch 24/100
# 10/10 - 0s - loss: 0.0866 - val_loss: 0.1102 - 295ms/epoch - 30ms/step
# Epoch 25/100
# 10/10 - 0s - loss: 0.0763 - val_loss: 0.1007 - 306ms/epoch - 31ms/step
# Epoch 26/100
# 10/10 - 0s - loss: 0.0674 - val_loss: 0.0926 - 302ms/epoch - 30ms/step
# Epoch 27/100
# 10/10 - 0s - loss: 0.0598 - val_loss: 0.0856 - 302ms/epoch - 30ms/step
# Epoch 28/100
# 10/10 - 0s - loss: 0.0532 - val_loss: 0.0796 - 301ms/epoch - 30ms/step
# Epoch 29/100
# 10/10 - 0s - loss: 0.0476 - val_loss: 0.0744 - 292ms/epoch - 29ms/step
# Epoch 30/100
# 10/10 - 0s - loss: 0.0427 - val_loss: 0.0699 - 293ms/epoch - 29ms/step
# Epoch 31/100
# 10/10 - 0s - loss: 0.0385 - val_loss: 0.0660 - 301ms/epoch - 30ms/step
# Epoch 32/100
# 10/10 - 0s - loss: 0.0349 - val_loss: 0.0627 - 299ms/epoch - 30ms/step
# Epoch 33/100
# 10/10 - 0s - loss: 0.0317 - val_loss: 0.0598 - 297ms/epoch - 30ms/step
# Epoch 34/100
# 10/10 - 0s - loss: 0.0290 - val_loss: 0.0572 - 294ms/epoch - 29ms/step
# Epoch 35/100
# 10/10 - 0s - loss: 0.0266 - val_loss: 0.0550 - 296ms/epoch - 30ms/step
# Epoch 36/100
# 10/10 - 0s - loss: 0.0246 - val_loss: 0.0531 - 292ms/epoch - 29ms/step
# Epoch 37/100
# 10/10 - 0s - loss: 0.0228 - val_loss: 0.0515 - 292ms/epoch - 29ms/step
# Epoch 38/100
# 10/10 - 0s - loss: 0.0212 - val_loss: 0.0501 - 297ms/epoch - 30ms/step
# Epoch 39/100
# 10/10 - 0s - loss: 0.0199 - val_loss: 0.0488 - 290ms/epoch - 29ms/step
# Epoch 40/100
# 10/10 - 0s - loss: 0.0187 - val_loss: 0.0477 - 298ms/epoch - 30ms/step
# Epoch 41/100
# 10/10 - 0s - loss: 0.0177 - val_loss: 0.0468 - 294ms/epoch - 29ms/step
# Epoch 42/100
# 10/10 - 0s - loss: 0.0168 - val_loss: 0.0459 - 293ms/epoch - 29ms/step
# Epoch 43/100
# 10/10 - 0s - loss: 0.0160 - val_loss: 0.0452 - 297ms/epoch - 30ms/step
# Epoch 44/100
# 10/10 - 0s - loss: 0.0153 - val_loss: 0.0446 - 294ms/epoch - 29ms/step
# Epoch 45/100
# 10/10 - 0s - loss: 0.0147 - val_loss: 0.0440 - 290ms/epoch - 29ms/step
# Epoch 46/100
# 10/10 - 0s - loss: 0.0142 - val_loss: 0.0436 - 290ms/epoch - 29ms/step
# Epoch 47/100
# 10/10 - 0s - loss: 0.0138 - val_loss: 0.0431 - 292ms/epoch - 29ms/step
# Epoch 48/100
# 10/10 - 0s - loss: 0.0134 - val_loss: 0.0428 - 289ms/epoch - 29ms/step
# Epoch 49/100
# 10/10 - 0s - loss: 0.0130 - val_loss: 0.0425 - 292ms/epoch - 29ms/step
# Epoch 50/100
# 10/10 - 0s - loss: 0.0128 - val_loss: 0.0422 - 288ms/epoch - 29ms/step
# Epoch 51/100
# 10/10 - 0s - loss: 0.0125 - val_loss: 0.0420 - 324ms/epoch - 32ms/step
# Epoch 52/100
# 10/10 - 0s - loss: 0.0123 - val_loss: 0.0418 - 291ms/epoch - 29ms/step
# Epoch 53/100
# 10/10 - 0s - loss: 0.0121 - val_loss: 0.0416 - 293ms/epoch - 29ms/step
# Epoch 54/100
# 10/10 - 0s - loss: 0.0119 - val_loss: 0.0414 - 294ms/epoch - 29ms/step
# Epoch 55/100
# 10/10 - 0s - loss: 0.0118 - val_loss: 0.0413 - 297ms/epoch - 30ms/step
# Epoch 56/100
# 10/10 - 0s - loss: 0.0117 - val_loss: 0.0412 - 291ms/epoch - 29ms/step
# Epoch 57/100
# 10/10 - 0s - loss: 0.0115 - val_loss: 0.0411 - 297ms/epoch - 30ms/step
# Epoch 58/100
# 10/10 - 0s - loss: 0.0114 - val_loss: 0.0410 - 296ms/epoch - 30ms/step
# Epoch 59/100
# 10/10 - 0s - loss: 0.0114 - val_loss: 0.0409 - 293ms/epoch - 29ms/step
# Epoch 60/100
# 10/10 - 0s - loss: 0.0113 - val_loss: 0.0409 - 291ms/epoch - 29ms/step
# Epoch 61/100
# 10/10 - 0s - loss: 0.0112 - val_loss: 0.0408 - 292ms/epoch - 29ms/step
# Epoch 62/100
# 10/10 - 0s - loss: 0.0112 - val_loss: 0.0407 - 295ms/epoch - 30ms/step
# Epoch 63/100
# 10/10 - 0s - loss: 0.0111 - val_loss: 0.0408 - 291ms/epoch - 29ms/step
# Epoch 64/100
# 10/10 - 0s - loss: 0.0111 - val_loss: 0.0407 - 295ms/epoch - 30ms/step
# Epoch 65/100
# 10/10 - 0s - loss: 0.0111 - val_loss: 0.0406 - 297ms/epoch - 30ms/step
# Epoch 66/100
# 10/10 - 0s - loss: 0.0110 - val_loss: 0.0407 - 294ms/epoch - 29ms/step
# Epoch 67/100
# 10/10 - 0s - loss: 0.0110 - val_loss: 0.0406 - 293ms/epoch - 29ms/step
# Epoch 68/100
# 10/10 - 0s - loss: 0.0110 - val_loss: 0.0406 - 310ms/epoch - 31ms/step
# Epoch 69/100
# 10/10 - 0s - loss: 0.0110 - val_loss: 0.0406 - 313ms/epoch - 31ms/step
# Epoch 70/100
# 10/10 - 0s - loss: 0.0110 - val_loss: 0.0405 - 315ms/epoch - 31ms/step
# Epoch 71/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 306ms/epoch - 31ms/step
# Epoch 72/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0406 - 291ms/epoch - 29ms/step
# Epoch 73/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 292ms/epoch - 29ms/step
# Epoch 74/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0406 - 297ms/epoch - 30ms/step
# Epoch 75/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 321ms/epoch - 32ms/step
# Epoch 76/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 295ms/epoch - 30ms/step
# Epoch 77/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 295ms/epoch - 30ms/step
# Epoch 78/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 300ms/epoch - 30ms/step
# Epoch 79/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 297ms/epoch - 30ms/step
# Epoch 80/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 297ms/epoch - 30ms/step
# Epoch 81/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0404 - 306ms/epoch - 31ms/step
# Epoch 82/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 290ms/epoch - 29ms/step
# Epoch 83/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 290ms/epoch - 29ms/step
# Epoch 84/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 306ms/epoch - 31ms/step
# Epoch 85/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 295ms/epoch - 30ms/step
# Epoch 86/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 289ms/epoch - 29ms/step
# Epoch 87/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 325ms/epoch - 32ms/step
# Epoch 88/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 297ms/epoch - 30ms/step
# Epoch 89/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0404 - 292ms/epoch - 29ms/step
# Epoch 90/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0404 - 324ms/epoch - 32ms/step
# Epoch 91/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 313ms/epoch - 31ms/step
# Epoch 92/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 317ms/epoch - 32ms/step
# Epoch 93/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 301ms/epoch - 30ms/step
# Epoch 94/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 318ms/epoch - 32ms/step
# Epoch 95/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 288ms/epoch - 29ms/step
# Epoch 96/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0404 - 302ms/epoch - 30ms/step
# Epoch 97/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 307ms/epoch - 31ms/step
# Epoch 98/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 317ms/epoch - 32ms/step
# Epoch 99/100
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 308ms/epoch - 31ms/step
# Epoch 99: early stopping
# Text(0.5, 1.0, 'Model loss progress during training and validation')
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'Training and Validation Loss')
# 20/20 [==============================] - 4s 5ms/step
# 9/9 [==============================] - 0s 5ms/step
# Train Score: 97.20 RMSE for 100 epochs
# Test Score: 187.61 RMSE for 100 epochs
# Training for 150 epochs...
# Model: "sequential_34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_292 (LSTM)             (None, 1, 256)            268288
#
#  dropout_34 (Dropout)        (None, 1, 256)            0
#
#  lstm_293 (LSTM)             (None, 1, 256)            525312
#
#  lstm_294 (LSTM)             (None, 1, 128)            197120
#
#  lstm_295 (LSTM)             (None, 1, 128)            131584
#
#  lstm_296 (LSTM)             (None, 1, 64)             49408
#
#  lstm_297 (LSTM)             (None, 1, 64)             33024
#
#  lstm_298 (LSTM)             (None, 1, 32)             12416
#
#  lstm_299 (LSTM)             (None, 1, 32)             8320
#
#  lstm_300 (LSTM)             (None, 1, 16)             3136
#
#  lstm_301 (LSTM)             (None, 1, 16)             2112
#
#  lstm_302 (LSTM)             (None, 1, 8)              800
#
#  lstm_303 (LSTM)             (None, 1, 8)              544
#
#  dense_34 (Dense)            (None, 1, 1)              9
#
# =================================================================
# Total params: 1,232,073
# Trainable params: 1,232,073
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 10/10 - 26s - loss: 12.9457 - val_loss: 10.8051 - 26s/epoch - 3s/step
# Epoch 2/150
# 10/10 - 0s - loss: 9.3394 - val_loss: 7.7503 - 300ms/epoch - 30ms/step
# Epoch 3/150
# 10/10 - 0s - loss: 6.6759 - val_loss: 5.5429 - 294ms/epoch - 29ms/step
# Epoch 4/150
# 10/10 - 0s - loss: 4.7738 - val_loss: 3.9879 - 299ms/epoch - 30ms/step
# Epoch 5/150
# 10/10 - 0s - loss: 3.4424 - val_loss: 2.9063 - 312ms/epoch - 31ms/step
# Epoch 6/150
# 10/10 - 0s - loss: 2.5182 - val_loss: 2.1556 - 329ms/epoch - 33ms/step
# Epoch 7/150
# 10/10 - 0s - loss: 1.8755 - val_loss: 1.6311 - 289ms/epoch - 29ms/step
# Epoch 8/150
# 10/10 - 0s - loss: 1.4242 - val_loss: 1.2596 - 288ms/epoch - 29ms/step
# Epoch 9/150
# 10/10 - 0s - loss: 1.1026 - val_loss: 0.9918 - 302ms/epoch - 30ms/step
# Epoch 10/150
# 10/10 - 0s - loss: 0.8688 - val_loss: 0.7950 - 291ms/epoch - 29ms/step
# Epoch 11/150
# 10/10 - 0s - loss: 0.6956 - val_loss: 0.6473 - 293ms/epoch - 29ms/step
# Epoch 12/150
# 10/10 - 0s - loss: 0.5647 - val_loss: 0.5344 - 304ms/epoch - 30ms/step
# Epoch 13/150
# 10/10 - 0s - loss: 0.4638 - val_loss: 0.4466 - 301ms/epoch - 30ms/step
# Epoch 14/150
# 10/10 - 0s - loss: 0.3848 - val_loss: 0.3773 - 316ms/epoch - 32ms/step
# Epoch 15/150
# 10/10 - 0s - loss: 0.3220 - val_loss: 0.3218 - 312ms/epoch - 31ms/step
# Epoch 16/150
# 10/10 - 0s - loss: 0.2715 - val_loss: 0.2770 - 302ms/epoch - 30ms/step
# Epoch 17/150
# 10/10 - 0s - loss: 0.2305 - val_loss: 0.2403 - 301ms/epoch - 30ms/step
# Epoch 18/150
# 10/10 - 0s - loss: 0.1968 - val_loss: 0.2100 - 303ms/epoch - 30ms/step
# Epoch 19/150
# 10/10 - 0s - loss: 0.1689 - val_loss: 0.1849 - 300ms/epoch - 30ms/step
# Epoch 20/150
# 10/10 - 0s - loss: 0.1457 - val_loss: 0.1639 - 309ms/epoch - 31ms/step
# Epoch 21/150
# 10/10 - 0s - loss: 0.1262 - val_loss: 0.1463 - 297ms/epoch - 30ms/step
# Epoch 22/150
# 10/10 - 0s - loss: 0.1098 - val_loss: 0.1314 - 302ms/epoch - 30ms/step
# Epoch 23/150
# 10/10 - 0s - loss: 0.0960 - val_loss: 0.1187 - 284ms/epoch - 28ms/step
# Epoch 24/150
# 10/10 - 0s - loss: 0.0842 - val_loss: 0.1080 - 291ms/epoch - 29ms/step
# Epoch 25/150
# 10/10 - 0s - loss: 0.0742 - val_loss: 0.0988 - 287ms/epoch - 29ms/step
# Epoch 26/150
# 10/10 - 0s - loss: 0.0656 - val_loss: 0.0909 - 290ms/epoch - 29ms/step
# Epoch 27/150
# 10/10 - 0s - loss: 0.0582 - val_loss: 0.0842 - 284ms/epoch - 28ms/step
# Epoch 28/150
# 10/10 - 0s - loss: 0.0519 - val_loss: 0.0784 - 287ms/epoch - 29ms/step
# Epoch 29/150
# 10/10 - 0s - loss: 0.0465 - val_loss: 0.0734 - 304ms/epoch - 30ms/step
# Epoch 30/150
# 10/10 - 0s - loss: 0.0418 - val_loss: 0.0690 - 314ms/epoch - 31ms/step
# Epoch 31/150
# 10/10 - 0s - loss: 0.0377 - val_loss: 0.0653 - 307ms/epoch - 31ms/step
# Epoch 32/150
# 10/10 - 0s - loss: 0.0342 - val_loss: 0.0621 - 301ms/epoch - 30ms/step
# Epoch 33/150
# 10/10 - 0s - loss: 0.0312 - val_loss: 0.0593 - 318ms/epoch - 32ms/step
# Epoch 34/150
# 10/10 - 0s - loss: 0.0285 - val_loss: 0.0568 - 289ms/epoch - 29ms/step
# Epoch 35/150
# 10/10 - 0s - loss: 0.0262 - val_loss: 0.0547 - 301ms/epoch - 30ms/step
# Epoch 36/150
# 10/10 - 0s - loss: 0.0243 - val_loss: 0.0528 - 309ms/epoch - 31ms/step
# Epoch 37/150
# 10/10 - 0s - loss: 0.0225 - val_loss: 0.0513 - 304ms/epoch - 30ms/step
# Epoch 38/150
# 10/10 - 0s - loss: 0.0210 - val_loss: 0.0499 - 285ms/epoch - 29ms/step
# Epoch 39/150
# 10/10 - 0s - loss: 0.0197 - val_loss: 0.0487 - 299ms/epoch - 30ms/step
# Epoch 40/150
# 10/10 - 0s - loss: 0.0186 - val_loss: 0.0476 - 306ms/epoch - 31ms/step
# Epoch 41/150
# 10/10 - 0s - loss: 0.0176 - val_loss: 0.0467 - 290ms/epoch - 29ms/step
# Epoch 42/150
# 10/10 - 0s - loss: 0.0167 - val_loss: 0.0459 - 312ms/epoch - 31ms/step
# Epoch 43/150
# 10/10 - 0s - loss: 0.0159 - val_loss: 0.0452 - 304ms/epoch - 30ms/step
# Epoch 44/150
# 10/10 - 0s - loss: 0.0153 - val_loss: 0.0446 - 285ms/epoch - 29ms/step
# Epoch 45/150
# 10/10 - 0s - loss: 0.0147 - val_loss: 0.0440 - 291ms/epoch - 29ms/step
# Epoch 46/150
# 10/10 - 0s - loss: 0.0142 - val_loss: 0.0435 - 320ms/epoch - 32ms/step
# Epoch 47/150
# 10/10 - 0s - loss: 0.0138 - val_loss: 0.0431 - 315ms/epoch - 31ms/step
# Epoch 48/150
# 10/10 - 0s - loss: 0.0134 - val_loss: 0.0428 - 297ms/epoch - 30ms/step
# Epoch 49/150
# 10/10 - 0s - loss: 0.0131 - val_loss: 0.0425 - 292ms/epoch - 29ms/step
# Epoch 50/150
# 10/10 - 0s - loss: 0.0128 - val_loss: 0.0423 - 297ms/epoch - 30ms/step
# Epoch 51/150
# 10/10 - 0s - loss: 0.0125 - val_loss: 0.0421 - 291ms/epoch - 29ms/step
# Epoch 52/150
# 10/10 - 0s - loss: 0.0123 - val_loss: 0.0418 - 297ms/epoch - 30ms/step
# Epoch 53/150
# 10/10 - 0s - loss: 0.0121 - val_loss: 0.0416 - 284ms/epoch - 28ms/step
# Epoch 54/150
# 10/10 - 0s - loss: 0.0119 - val_loss: 0.0414 - 314ms/epoch - 31ms/step
# Epoch 55/150
# 10/10 - 0s - loss: 0.0118 - val_loss: 0.0413 - 299ms/epoch - 30ms/step
# Epoch 56/150
# 10/10 - 0s - loss: 0.0117 - val_loss: 0.0412 - 286ms/epoch - 29ms/step
# Epoch 57/150
# 10/10 - 0s - loss: 0.0116 - val_loss: 0.0411 - 289ms/epoch - 29ms/step
# Epoch 58/150
# 10/10 - 0s - loss: 0.0115 - val_loss: 0.0410 - 304ms/epoch - 30ms/step
# Epoch 59/150
# 10/10 - 0s - loss: 0.0114 - val_loss: 0.0409 - 327ms/epoch - 33ms/step
# Epoch 60/150
# 10/10 - 0s - loss: 0.0113 - val_loss: 0.0409 - 297ms/epoch - 30ms/step
# Epoch 61/150
# 10/10 - 0s - loss: 0.0113 - val_loss: 0.0408 - 301ms/epoch - 30ms/step
# Epoch 62/150
# 10/10 - 0s - loss: 0.0112 - val_loss: 0.0408 - 301ms/epoch - 30ms/step
# Epoch 63/150
# 10/10 - 0s - loss: 0.0112 - val_loss: 0.0407 - 294ms/epoch - 29ms/step
# Epoch 64/150
# 10/10 - 0s - loss: 0.0111 - val_loss: 0.0407 - 295ms/epoch - 30ms/step
# Epoch 65/150
# 10/10 - 0s - loss: 0.0111 - val_loss: 0.0407 - 296ms/epoch - 30ms/step
# Epoch 66/150
# 10/10 - 0s - loss: 0.0111 - val_loss: 0.0406 - 290ms/epoch - 29ms/step
# Epoch 67/150
# 10/10 - 0s - loss: 0.0110 - val_loss: 0.0407 - 302ms/epoch - 30ms/step
# Epoch 68/150
# 10/10 - 0s - loss: 0.0110 - val_loss: 0.0406 - 285ms/epoch - 28ms/step
# Epoch 69/150
# 10/10 - 0s - loss: 0.0110 - val_loss: 0.0406 - 288ms/epoch - 29ms/step
# Epoch 70/150
# 10/10 - 0s - loss: 0.0110 - val_loss: 0.0406 - 285ms/epoch - 29ms/step
# Epoch 71/150
# 10/10 - 0s - loss: 0.0110 - val_loss: 0.0406 - 289ms/epoch - 29ms/step
# Epoch 72/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 289ms/epoch - 29ms/step
# Epoch 73/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 305ms/epoch - 30ms/step
# Epoch 74/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 337ms/epoch - 34ms/step
# Epoch 75/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 324ms/epoch - 32ms/step
# Epoch 76/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 314ms/epoch - 31ms/step
# Epoch 77/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 306ms/epoch - 31ms/step
# Epoch 78/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 295ms/epoch - 29ms/step
# Epoch 79/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 302ms/epoch - 30ms/step
# Epoch 80/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 296ms/epoch - 30ms/step
# Epoch 81/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0406 - 311ms/epoch - 31ms/step
# Epoch 82/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 289ms/epoch - 29ms/step
# Epoch 83/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 287ms/epoch - 29ms/step
# Epoch 84/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0404 - 291ms/epoch - 29ms/step
# Epoch 85/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 305ms/epoch - 31ms/step
# Epoch 86/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 284ms/epoch - 28ms/step
# Epoch 87/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 284ms/epoch - 28ms/step
# Epoch 88/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 299ms/epoch - 30ms/step
# Epoch 89/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 335ms/epoch - 34ms/step
# Epoch 90/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0404 - 292ms/epoch - 29ms/step
# Epoch 91/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 318ms/epoch - 32ms/step
# Epoch 92/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 300ms/epoch - 30ms/step
# Epoch 93/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0404 - 295ms/epoch - 30ms/step
# Epoch 94/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 295ms/epoch - 29ms/step
# Epoch 95/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 294ms/epoch - 29ms/step
# Epoch 96/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 286ms/epoch - 29ms/step
# Epoch 97/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 283ms/epoch - 28ms/step
# Epoch 98/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 295ms/epoch - 30ms/step
# Epoch 99/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0404 - 292ms/epoch - 29ms/step
# Epoch 100/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 301ms/epoch - 30ms/step
# Epoch 101/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 295ms/epoch - 29ms/step
# Epoch 102/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 286ms/epoch - 29ms/step
# Epoch 103/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 297ms/epoch - 30ms/step
# Epoch 104/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 287ms/epoch - 29ms/step
# Epoch 105/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 288ms/epoch - 29ms/step
# Epoch 106/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 289ms/epoch - 29ms/step
# Epoch 107/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 287ms/epoch - 29ms/step
# Epoch 108/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 289ms/epoch - 29ms/step
# Epoch 109/150
# 10/10 - 0s - loss: 0.0109 - val_loss: 0.0405 - 288ms/epoch - 29ms/step
# Epoch 109: early stopping
# Text(0.5, 1.0, 'Model loss progress during training and validation')
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'Training and Validation Loss')
# 20/20 [==============================] - 4s 5ms/step
# 9/9 [==============================] - 0s 6ms/step
# Train Score: 97.20 RMSE for 150 epochs
# Test Score: 187.62 RMSE for 150 epochs
#      Train RMSE   Test RMSE
# 50    97.203306  187.570033
# 100   97.204188  187.607584
# 150   97.204741  187.619355

# %% [markdown]
# <h4>Forecast the results</h4>

# %%
def forecast_next_weeks(model, look_back, scaler, last_values, n_weeks):
    forecast = []
    input_values = np.array(last_values)
    for _ in range(n_weeks):
        # Scale the input_values to be between 0 and 1
        input_values_scaled = scaler.transform(input_values[-look_back:].reshape(-1, 1))
        
        # Reshape to [samples, time steps, features]
        input_values_scaled = input_values_scaled.reshape((1, 1, look_back))

        # Predict the next value
        prediction = model.predict(input_values_scaled)
        
        # Get last prediction from the sequence
        prediction = prediction[:, -1, :]
        
        # Inverse scale the predicted value
        prediction = scaler.inverse_transform(prediction)
        
        # Append the predicted value to the forecast list
        forecast.append(prediction[0, 0])
        
        # Append the predicted value to the input_values list to be used as input for the next prediction
        input_values = np.append(input_values, prediction)

    return forecast

# %%
# How many weeks you want to forecast
weeks = 12  # approximately equal to 240 days

# Get the last "look_back" values
last_values = list(df_interpolated['RATE'].values[-look_back:])

# Forecast the next weeks
forecasted_values = forecast_next_weeks(model, look_back, scaler, last_values, weeks)

# Get the last date from 'POD'
last_date = df_interpolated['POD'].iloc[-1]

# Create new dates
new_dates = pd.date_range(last_date + pd.DateOffset(weeks=1), periods=weeks, freq='W')

# Create a new DataFrame for the forecasted values
df_forecasted = pd.DataFrame(data={'POD': new_dates, 'RATE': forecasted_values})

# Rounding of the rate nearest 2 decimal point
df_forecasted["RATE"] = df_forecasted["RATE"].round(2)

df_forecasted.head(5)
df_forecasted.tail(5)
df_forecasted.info()
# Out:
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
#          POD        RATE
# 0 2023-03-12  201.600006
# 1 2023-03-19  201.600006
# 2 2023-03-26  201.600006
# 3 2023-04-02  201.600006
# 4 2023-04-09  201.600006
#           POD        RATE
# 7  2023-04-30  201.600006
# 8  2023-05-07  201.600006
# 9  2023-05-14  201.600006
# 10 2023-05-21  201.600006
# 11 2023-05-28  201.600006
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POD     12 non-null     datetime64[ns]
#  1   RATE    12 non-null     float32
# dtypes: datetime64[ns](1), float32(1)
# memory usage: 272.0 bytes

# %% [markdown]
# <h4>Comparing with actual updated against forecasted</h4>

# %%
# Create an empty DataFrame to store comparison data
comparison_df = pd.DataFrame(columns=['WeekStart', 'WeekEnd', 'POD_actual', 'RATE_forecasted', 'RATE_actual', 'error', 'accuracy'])
df_forecasted['WeekEnd'] = df_forecasted['POD'] + pd.to_timedelta(7, unit='d')  

# Loop over df_forecasted
for _, row in df_forecasted.iterrows():
    # Find the actual dates within the week of the forecasted date
    # Add a 'WeekEnd' column to df_forecasted
    mask = (new_dates_df['POD'] >= row['POD']) & (new_dates_df['POD'] < row['WeekEnd'])
    actual_dates_within_week = new_dates_df[mask]

    # Calculate the error and accuracy for each actual date within the week
    for _, actual_row in actual_dates_within_week.iterrows():
        error = abs(actual_row['RATE'] - row['RATE'])
        error_proportion = error / actual_row['RATE']
        accuracy = (1 - error_proportion) * 100

        # Append the data to comparison_df
        comparison_df = comparison_df.append({
            'WeekStart': row['POD'],
            'WeekEnd': row['WeekEnd'],
            'POD_actual': actual_row['POD'],
            'RATE_forecasted': row['RATE'],
            'RATE_actual': actual_row['RATE'],
            'error': error,
            'accuracy': accuracy
        }, ignore_index=True)

# Remove duplicates based on 'POD_actual', 'RATE_forecasted', and 'RATE_actual'
comparison_df = comparison_df.drop_duplicates(subset=['POD_actual', 'RATE_forecasted', 'RATE_actual']).reset_index(drop=True)

# Display the comparison dataframe
comparison_df
comparison_df.info()

total_mean_accuracy = comparison_df['accuracy'].mean()
print(f'The mean accuracy is {total_mean_accuracy:.2f}%')
# Out:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\2601120271.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\2601120271.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\2601120271.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\2601120271.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\2601120271.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\2601120271.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\2601120271.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\2601120271.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\2601120271.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\2601120271.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\2601120271.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\2601120271.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\2601120271.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\2601120271.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\2601120271.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\2601120271.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\2601120271.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\2601120271.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\2601120271.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\2601120271.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_24804\2601120271.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
#     WeekStart    WeekEnd POD_actual  RATE_forecasted  RATE_actual      error  \
# 0  2023-03-12 2023-03-19 2023-03-15       201.600006        260.0  58.399994
# 1  2023-03-19 2023-03-26 2023-03-19       201.600006        300.0  98.399994
# 2  2023-03-26 2023-04-02 2023-03-26       201.600006        260.0  58.399994
# 3  2023-03-26 2023-04-02 2023-04-01       201.600006        260.0  58.399994
# 4  2023-04-02 2023-04-09 2023-04-08       201.600006        260.0  58.399994
# 5  2023-04-09 2023-04-16 2023-04-12       201.600006        300.0  98.399994
# 6  2023-04-09 2023-04-16 2023-04-15       201.600006        260.0  58.399994
# 7  2023-04-16 2023-04-23 2023-04-20       201.600006        260.0  58.399994
# 8  2023-04-23 2023-04-30 2023-04-26       201.600006        300.0  98.399994
# 9  2023-04-30 2023-05-07 2023-05-03       201.600006        260.0  58.399994
# 10 2023-05-07 2023-05-14 2023-05-10       201.600006        300.0  98.399994
# 11 2023-05-14 2023-05-21 2023-05-17       201.600006        260.0  58.399994
#
#      accuracy
# 0   77.538464
# 1   67.200002
# 2   77.538464
# 3   77.538464
# 4   77.538464
# 5   67.200002
# 6   77.538464
# 7   77.538464
# 8   67.200002
# 9   77.538464
# 10  67.200002
# 11  77.538464
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   WeekStart        12 non-null     datetime64[ns]
#  1   WeekEnd          12 non-null     datetime64[ns]
#  2   POD_actual       12 non-null     datetime64[ns]
#  3   RATE_forecasted  12 non-null     float64
#  4   RATE_actual      12 non-null     float64
#  5   error            12 non-null     float64
#  6   accuracy         12 non-null     float64
# dtypes: datetime64[ns](3), float64(4)
# memory usage: 800.0 bytes
# The mean accuracy is 74.09%

# %% [markdown]
# <h4>Visualise all, Conclusion</h4>

# %%
plt.figure(figsize=(20, 10))
plt.plot(sel_df['POD'], sel_df['RATE'], color='blue', label="Actual Data")
plt.plot(new_dates_df['POD'], new_dates_df['RATE'], color='blue', label="Actual Data (Updated)")

plt.plot(df_interpolated['POD'], df_interpolated['RATE'], color='green', label="Aggregated Data")
plt.plot(df_forecasted['POD'], df_forecasted['RATE'], color='red', label="Forecasted Data")

plt.xlabel('Date(Year Month)')
plt.ylabel('Cost Rate(USD)')
plt.title('Port_BUSAN_Size_40_Type_HC_PartyID_010004286')
plt.legend()
plt.show();
