# %% [markdown]
# <h1>BI LSTM remove outlier with zscore</h1>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.losses import MeanSquaredError
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import RobustScaler
from scipy import stats
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from IPython.core.interactiveshell import InteractiveShell

# LSTM
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.layers import Dropout, LSTM, Dense, RepeatVector, TimeDistributed
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Sequential
from keras.callbacks import EarlyStopping
from sklearn.model_selection import ParameterSampler
from scipy.stats import skew


InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline
sns.set()
pd.options.display.max_rows = 100

# %% [markdown]
# <h4>Importing Datasets</h4>

# %%
# Import dataset and clean, ready as a dataframe for creating keys
def createDF(datasets):
    df = pd.read_csv(datasets, converters={'PARTY_ID': str, 'COM_ID': str, 'CNTR_SIZE': str})

    # Formating to type and remove NaN values
    df['POD'] = pd.to_datetime(df['POD'])
    df['ENCODED_TYPE'] = df['ENCODED_TYPE'].fillna(-1).astype(int)
    df = df.dropna(subset=['ENCODED_TYPE'])
    df['RATE'] = df['RATE'].fillna(-1).astype(float)
    df = df.dropna(subset=['RATE'])
    df['ENCODED_TYPE'] = df['ENCODED_TYPE'].astype(int)
    df_clean= df.dropna().reset_index(drop=True)

    # Selecting and rearranging columns
    sel_col = ['CSL_ID', 'CNTR_ID','POD_ID','ETD_POL_D','PARTY_ID',
            'PARTY_NAME','POD','CNTR_SIZE','CNTR_TYPE','RATE']
    df_fc = df_clean[sel_col]

    # Removing years we do not want to process in our models
    df_filtered = df_fc[df_fc['POD'].dt.year != 2002]

    # Sorting the dates
    df_filtered = df_filtered.sort_values(by='POD').reset_index(drop=True)
    
    return df_filtered

# %%
# Create Dataframes for old and new
old_data = '.\Datasets\CR_COST_FC.csv'
df1 = createDF(old_data)
df1.head()

new_data = '.\Datasets\CR_COST_FC_new.csv'
df2 = createDF(new_data)
df2.head()
# Out:
#            CSL_ID           CNTR_ID          POD_ID ETD_POL_D  PARTY_ID  \
# 0  ECS01050600224  CTNR010050700354       ROTTERDAM     NLRTM  01008827
# 1  ECS01050600610  CTNR010050700353      FELIXSTOWE     GBFXT  01002303
# 2  ECS01050600041  CTNR010050700351        AUCKLAND     NZAKL  01005136
# 3  ECS01050600163  CTNR010050700370    PASIR GUDANG     MYPGU  01002767
# 4  ECS01050600456  CTNR010050700450  KARACHI (KICT)     PKKHI  01002783
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0             YANG MING (SINGAPORE) PTE. LTD. 2005-07-15        40    HC NOR
# 1                    GLOBELINK FALLOW LIMITED 2005-07-15        40        GP
# 2  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-15        40    HC NOR
# 3          GLOBELINK CONTAINER LINES (JB) S/B 2005-07-15        40        HC
# 4                GLOBELINK PAKISTAN (PVT) LTD 2005-07-16        40        HC
#
#      RATE
# 0  1620.0
# 1  1800.0
# 2  2170.0
# 3   280.0
# 4  1625.0
#            CSL_ID           CNTR_ID          POD_ID ETD_POL_D  PARTY_ID  \
# 0  ECS01050600224  CTNR010050700354       ROTTERDAM     NLRTM  01008827
# 1  ECS01050600610  CTNR010050700353      FELIXSTOWE     GBFXT  01002303
# 2  ECS01050600041  CTNR010050700351        AUCKLAND     NZAKL  01005136
# 3  ECS01050600163  CTNR010050700370    PASIR GUDANG     MYPGU  01002767
# 4  ECS01050600456  CTNR010050700450  KARACHI (KICT)     PKKHI  01002783
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0             YANG MING (SINGAPORE) PTE. LTD. 2005-07-15        40    HC NOR
# 1                    GLOBELINK FALLOW LIMITED 2005-07-15        40        GP
# 2  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-15        40    HC NOR
# 3          GLOBELINK CONTAINER LINES (JB) S/B 2005-07-15        40        HC
# 4                GLOBELINK PAKISTAN (PVT) LTD 2005-07-16        40        HC
#
#      RATE
# 0  1620.0
# 1  1800.0
# 2  2170.0
# 3   280.0
# 4  1625.0

# %% [markdown]
# <h4>Creating Dictionary Keys</h4>

# %%
def filter_dataframe(df):
    filtered_dataframes = {}

    for (port, size, ctype, party_id), group in df.groupby(['POD_ID', 'CNTR_SIZE', 'CNTR_TYPE', 'PARTY_ID']):
        group = group.reset_index(drop=True).sort_values(by='POD')
        df_id = f"Port_{port}_Size_{size}_Type_{ctype}_PartyID_{party_id}"
        filtered_dataframes[df_id] = group

    return filtered_dataframes

# %%
# Creating keys from data
print("Old Data keys:")
filtered_dataframe1 = filter_dataframe(df1)
df_ids1 = list(filtered_dataframe1.keys())
print(list(df_ids1))
print(len(list(df_ids1)))

print("\nNew Data keys:")
filtered_dataframe2 = filter_dataframe(df2)
df_ids2 = list(filtered_dataframe2.keys())
print(list(df_ids2))
print(len(list(df_ids2)))
# Out:
# Old Data keys:
# ['Port_(CONSTANZA)_Size_40_Type_GP_PartyID_010007816', 'Port_(CONSTANZA)_Size_40_Type_HC_PartyID_010007816', 'Port_AARHUS_Size_20_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100027830', 'Port_AARHUS_Size_20_Type_GP_PartyID_010006666', 'Port_AARHUS_Size_40_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100027830', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100028193', 'Port_AARHUS_Size_40_Type_HC_PartyID_010006666', 'Port_ABIDJAN_Size_20_Type_GP_PartyID_0100027878', 'Port_ABIDJAN_Size_40_Type_HC_PartyID_010021097', 'Port_ADELAIDE_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01005078', 'Port_ADELAIDE_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ALEXANDRIA (EL DEKHELA PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC NOR_PartyID_010004995', 'Port_ALGECIRAS_Size_20_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC NOR_PartyID_01008306', 'Port_ALIAGA_Size_20_Type_GP_PartyID_01008316', 'Port_ALIAGA_Size_40_Type_HC_PartyID_01008316', 'Port_ALIAGA PORT (IZMIR)_Size_40_Type_HC_PartyID_01008316', 'Port_ANTWERP_Size_20_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC NOR_PartyID_01001449', 'Port_AQABA_Size_20_Type_GP_PartyID_010006618', 'Port_AQABA_Size_20_Type_GP_PartyID_010021081', 'Port_AQABA_Size_40_Type_HC_PartyID_010006618', 'Port_AQABA_Size_40_Type_HC_PartyID_010021081', 'Port_ASHDOD_Size_20_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_01008417', 'Port_ASHDOD_Size_40_Type_HC_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_HC_PartyID_01008417', 'Port_AUCKLAND_Size_20_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_20_Type_GP (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC NOR_PartyID_01005136', 'Port_BANGKOK_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_20_Type_GP (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (SOC)_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK (TST)_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK (TST)_Size_40_Type_HC_PartyID_010021593', 'Port_BARCELONA_Size_20_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC NOR_PartyID_01008305', 'Port_BEIRUT_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_HC_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_40_Type_HC_PartyID_0100 ...
# 789
#
# New Data keys:
# ['Port_(CONSTANZA)_Size_40_Type_GP_PartyID_010007816', 'Port_(CONSTANZA)_Size_40_Type_HC_PartyID_010007816', 'Port_AARHUS_Size_20_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100027830', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100028193', 'Port_AARHUS_Size_20_Type_GP_PartyID_010006666', 'Port_AARHUS_Size_40_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100027830', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100028193', 'Port_AARHUS_Size_40_Type_HC_PartyID_010006666', 'Port_ABIDJAN_Size_20_Type_GP_PartyID_0100027878', 'Port_ABIDJAN_Size_40_Type_HC_PartyID_010021097', 'Port_ADELAIDE_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01005078', 'Port_ADELAIDE_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ALEXANDRIA (EL DEKHELA PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC NOR_PartyID_010004995', 'Port_ALGECIRAS_Size_20_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC NOR_PartyID_01008306', 'Port_ALIAGA_Size_20_Type_GP_PartyID_01008316', 'Port_ALIAGA_Size_40_Type_HC_PartyID_01008316', 'Port_ALIAGA PORT (IZMIR)_Size_40_Type_HC_PartyID_01008316', 'Port_ANTWERP_Size_20_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC NOR_PartyID_01001449', 'Port_AQABA_Size_20_Type_GP_PartyID_010006618', 'Port_AQABA_Size_20_Type_GP_PartyID_010021081', 'Port_AQABA_Size_40_Type_HC_PartyID_010006618', 'Port_AQABA_Size_40_Type_HC_PartyID_010021081', 'Port_ASHDOD_Size_20_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_01008417', 'Port_ASHDOD_Size_40_Type_HC_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_HC_PartyID_01008417', 'Port_AUCKLAND_Size_20_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_20_Type_GP (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC NOR_PartyID_01005136', 'Port_BANGKOK_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_20_Type_GP (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (SOC)_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK (TST)_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK (TST)_Size_40_Type_HC_PartyID_010021593', 'Port_BARCELONA_Size_20_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC NOR_PartyID_01008305', 'Port_BEIRUT_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_HC_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_20_Type_GP_PartyID_010003651', ' ...
# 799

# %% [markdown]
# <h4>Getting Top 5 ports keys</h4>

# %%
def getTop5Ports(keybunch):
    keybunch_pouch = []
    
    # Get a dictionary with key and number of rows for each dataframe in filtered_dataframes
    key_row_counts = {key: len(keybunch[key]) for key in keybunch}

    # Sort the key_row_counts dictionary by value (number of rows) in descending order
    sorted_key_row_counts = sorted(key_row_counts.items(), key=lambda item: item[1], reverse=True)

    # Get the top 5 keys with the most rows
    top_5_keys_tuple = sorted_key_row_counts[:5]

    # Create a dictionary with the top 5 keys and their corresponding dataframes (with up to 5 rows per dataframe)
    keybunch_subset = {}

    for key, row_count in top_5_keys_tuple:
        keybunch_subset[key] = keybunch[key][:5]
        print(f"Number of rows in {key}: {row_count}")
        keybunch_pouch.append(key)
    
    # Return array of keys
    return keybunch_pouch

# %%
print('Old Dataset Keybunch:')
old_df = getTop5Ports(filtered_dataframe1)
print('\n')

print('New Dataset Keybunch:')
new_df = getTop5Ports(filtered_dataframe2)
# Out:
# Old Dataset Keybunch:
# Number of rows in Port_BUSAN_Size_40_Type_HC_PartyID_010004286: 1689
# Number of rows in Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136: 1688
# Number of rows in Port_MELBOURNE_Size_40_Type_HC_PartyID_01002778: 1325
# Number of rows in Port_SYDNEY_Size_40_Type_HC_PartyID_01002779: 1300
# Number of rows in Port_DUBAI (JEBEL ALI)_Size_40_Type_HC_PartyID_01002788: 1052
#
#
# New Dataset Keybunch:
# Number of rows in Port_BUSAN_Size_40_Type_HC_PartyID_010004286: 1712
# Number of rows in Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136: 1704
# Number of rows in Port_MELBOURNE_Size_40_Type_HC_PartyID_01002778: 1341
# Number of rows in Port_SYDNEY_Size_40_Type_HC_PartyID_01002779: 1308
# Number of rows in Port_DUBAI (JEBEL ALI)_Size_40_Type_HC_PartyID_01002788: 1070

# %%
# Global selection
sel_country = old_df[2]

# Accessing the highest count in the each keypouch, new and old.
sel_df = filtered_dataframe1[sel_country]
sel_df.head(5)
sel_df.tail(5)
sel_df.info()
print("\n")

latest_sel_df = filtered_dataframe2[sel_country]
latest_sel_df.head(5)
latest_sel_df.tail(5)
latest_sel_df.info()
# Out:
#             CSL_ID           CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 0   ECS01050600278  CTNR010050700692  MELBOURNE     AUMEL  01002778
# 1   ECS01050600280  CTNR010050701022  MELBOURNE     AUMEL  01002778
# 2  ECS010050700458  CTNR010050800604  MELBOURNE     AUMEL  01002778
# 3  ECS010050700214  CTNR010050800727  MELBOURNE     AUMEL  01002778
# 4  ECS010050900271  CTNR010051000178  MELBOURNE     AUMEL  01002778
#
#                                   PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-07-23        40        HC
# 1  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-07-30        40        HC
# 2  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-08-16        40        HC
# 3  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-08-19        40        HC
# 4  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-10-11        40        HC
#
#      RATE
# 0  1200.0
# 1  1200.0
# 2  1000.0
# 3  1200.0
# 4   900.0
#                CSL_ID       CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 1320  ECS010230100302  010000357415  MELBOURNE     AUMEL  01002778
# 1321  ECS010230100303  010000380481  MELBOURNE     AUMEL  01002778
# 1323  ECS010230100304  010000392586  MELBOURNE     AUMEL  01002778
# 1322  ECS010230100304  010000390964  MELBOURNE     AUMEL  01002778
# 1324  ECS010230100304  010000399293  MELBOURNE     AUMEL  01002778
#
#                                      PARTY_NAME        POD CNTR_SIZE  \
# 1320  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-02-11        40
# 1321  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-02-16        40
# 1323  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-02-24        40
# 1322  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-02-24        40
# 1324  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-02-24        40
#
#      CNTR_TYPE    RATE
# 1320        HC  1200.0
# 1321        HC  1200.0
# 1323        HC  1200.0
# 1322        HC  1200.0
# 1324        HC  1200.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1325 entries, 0 to 1324
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      1325 non-null   object
#  1   CNTR_ID     1325 non-null   object
#  2   POD_ID      1325 non-null   object
#  3   ETD_POL_D   1325 non-null   object
#  4   PARTY_ID    1325 non-null   object
#  5   PARTY_NAME  1325 non-null   object
#  6   POD         1325 non-null   datetime64[ns]
#  7   CNTR_SIZE   1325 non-null   object
#  8   CNTR_TYPE   1325 non-null   object
#  9   RATE        1325 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 113.9+ KB
#             CSL_ID           CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 0   ECS01050600278  CTNR010050700692  MELBOURNE     AUMEL  01002778
# 1   ECS01050600280  CTNR010050701022  MELBOURNE     AUMEL  01002778
# 2  ECS010050700458  CTNR010050800604  MELBOURNE     AUMEL  01002778
# 3  ECS010050700214  CTNR010050800727  MELBOURNE     AUMEL  01002778
# 4  ECS010050900271  CTNR010051000178  MELBOURNE     AUMEL  01002778
#
#                                   PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-07-23        40        HC
# 1  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-07-30        40        HC
# 2  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-08-16        40        HC
# 3  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-08-19        40        HC
# 4  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-10-11        40        HC
#
#      RATE
# 0  1200.0
# 1  1200.0
# 2  1000.0
# 3  1200.0
# 4   900.0
#                CSL_ID       CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 1336  ECS010230300518  010000531211  MELBOURNE     AUMEL  01002778
# 1337  ECS010230300518  010000509487  MELBOURNE     AUMEL  01002778
# 1338  ECS010230400431  010000541165  MELBOURNE     AUMEL  01002778
# 1339  ECS010230400432  010000543217  MELBOURNE     AUMEL  01002778
# 1340  ECS010230400433  010000557443  MELBOURNE     AUMEL  01002778
#
#                                      PARTY_NAME        POD CNTR_SIZE  \
# 1336  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-04-28        40
# 1337  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-04-28        40
# 1338  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-05        40
# 1339  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-11        40
# 1340  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-19        40
#
#      CNTR_TYPE   RATE
# 1336        HC  500.0
# 1337        HC  500.0
# 1338        HC  500.0
# 1339        HC  500.0
# 1340        HC  400.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1341 entries, 0 to 1340
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      1341 non-null   object
#  1   CNTR_ID     1341 non-null   object
#  2   POD_ID      1341 non-null   object
#  3   ETD_POL_D   1341 non-null   object
#  4   PARTY_ID    1341 non-null   object
#  5   PARTY_NAME  1341 non-null   object
#  6   POD         1341 non-null   datetime64[ns]
#  7   CNTR_SIZE   1341 non-null   object
#  8   CNTR_TYPE   1341 non-null   object
#  9   RATE        1341 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 115.2+ KB

# %%
# Select features
sel_feat = ['POD','RATE']
sel_feat_df = sel_df[sel_feat].copy()  # make a copy to avoid SettingWithCopyWarning

# %%
plt.figure(figsize=(20, 10))
plt.plot(sel_feat_df['POD'], sel_feat_df['RATE'], color='blue', label="Actual Data")

plt.xlabel('Date(Year Month Week)')
plt.ylabel('Cost Rate(USD)')
plt.title(sel_country)
plt.legend()
plt.show();

# %% [markdown]
# <h4>Remove Outliers</h4>

# %%
# Assuming 'robust_df' is your DataFrame and 'RATE' is the column containing the data
z_scores = stats.zscore(sel_feat_df[['RATE']])
threshold = 3  # Z-score threshold for outlier detection

# Find indices of outliers
outlier_indices = np.where(np.abs(z_scores) > threshold)[0]

# Remove outliers
robust_df = sel_feat_df.drop(sel_feat_df.index[outlier_indices])

# Reset the index
robust_df.reset_index(drop=True, inplace=True)

# Print the modified DataFrame
robust_df.head()
robust_df.info()
# Out:
#          POD    RATE
# 0 2005-07-23  1200.0
# 1 2005-07-30  1200.0
# 2 2005-08-16  1000.0
# 3 2005-08-19  1200.0
# 4 2005-10-11   900.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1275 entries, 0 to 1274
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POD     1275 non-null   datetime64[ns]
#  1   RATE    1275 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 20.0 KB

# %%
plt.figure(figsize=(20, 10))
plt.plot(sel_feat_df['POD'], sel_feat_df['RATE'], color='blue', label="Actual Data")
plt.plot(robust_df['POD'], robust_df['RATE'], color='red', label="Outlier Removed Data")

plt.xlabel('Date(Days)')
plt.ylabel('Cost Rate(USD)')
plt.title(f'Original Dataset plot: {sel_country}')
plt.legend()
plt.show();

# %% [markdown]
# <h4>Interpolate missing values in between dates</h4>

# %%
# Remove duplicated dates and cost rows
robust_df = robust_df.drop_duplicates(subset=['POD', 'RATE']).reset_index(drop=True)

# Create a new dataframe with a date range from min to max date in your dataframe
new_df = pd.DataFrame()
new_df['POD'] = pd.date_range(start=robust_df['POD'].min(), end=robust_df['POD'].max())

# Merge the original dataframe with the new one. Missing dates in the original dataframe will be filled with NaN
df_interpolated = pd.merge(new_df, robust_df, on='POD', how='left')  

# Perform spline interpolation
df_interpolated['RATE'] = df_interpolated['RATE'].interpolate(method='polynomial', order=1)

df_interpolated['RATE'] = df_interpolated['RATE'].round(3)

df_interpolated.head(5)
df_interpolated.tail(5)
df_interpolated.info()
# Out:
#          POD    RATE
# 0 2005-07-23  1200.0
# 1 2005-07-24  1200.0
# 2 2005-07-25  1200.0
# 3 2005-07-26  1200.0
# 4 2005-07-27  1200.0
#             POD    RATE
# 6438 2023-02-20  1200.0
# 6439 2023-02-21  1200.0
# 6440 2023-02-22  1200.0
# 6441 2023-02-23  1200.0
# 6442 2023-02-24  1200.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6443 entries, 0 to 6442
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POD     6443 non-null   datetime64[ns]
#  1   RATE    6443 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 151.0 KB

# %% [markdown]
# <h4>Grouping it to week</h4>

# %%
# Create YearMonthWeek directly from the 'POD'
df_interpolated['YearMonthWeek'] = df_interpolated['POD'] - pd.to_timedelta(df_interpolated['POD'].dt.dayofweek, unit='D')

# Create a new dataframe with every week in the range
all_weeks = pd.date_range(start=df_interpolated['POD'].min(), end=df_interpolated['POD'].max(), freq='W')
all_weeks_df = pd.DataFrame(all_weeks, columns=['POD'])

# Create YearMonthWeek in all_weeks_df
all_weeks_df['YearMonthWeek'] = all_weeks_df['POD'] - pd.to_timedelta(all_weeks_df['POD'].dt.dayofweek, unit='D')

# Merge this with your original dataframe
merged_df = pd.merge(all_weeks_df, df_interpolated, on=['YearMonthWeek'], how='left')

# Now you can group by YearMonthWeek and compute your rate
grouped = merged_df.groupby(['YearMonthWeek'])

agg_df = pd.DataFrame(columns=['YearMonthWeek', 'Rate'])

for group_name, group_df in grouped:
    year_month_week = group_name

    # Skip if no data for this week
    if group_df['RATE'].isnull().all():
        continue

    # Calculate sum and skewness of RATE values
    rate_sum = group_df['RATE'].sum()
    rate_skew = group_df['RATE'].skew()

    # Calculate trimmed mean of RATE values
    rate_metric = stats.trim_mean(group_df['RATE'].dropna().values, 0.1) # trimming 10% from each end

    new_row = {
        'YearMonthWeek': year_month_week,
        'Rate': rate_metric
    }

    # Append row to aggregated dataframe
    agg_df = agg_df.append(new_row, ignore_index=True)

agg_df = agg_df.sort_values(by='YearMonthWeek').reset_index(drop=True)
agg_df['Rate'] = agg_df['Rate'].round(2)

agg_df.head(15)
agg_df.tail(15)
agg_df.info()
# Out:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:19: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for group_name, group_df in grouped:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# ...
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
#    YearMonthWeek     Rate
# 0     2005-07-18  1200.00
# 1     2005-07-25  1198.32
# 2     2005-08-01  1141.18
# 3     2005-08-08  1058.82
# 4     2005-08-15  1113.54
# 5     2005-08-22  1166.04
# 6     2005-08-29  1126.42
# 7     2005-09-05  1086.79
# 8     2005-09-12  1047.17
# 9     2005-09-19  1007.55
# 10    2005-09-26   967.92
# 11    2005-10-03   928.30
# 12    2005-10-10   900.81
# 13    2005-10-17   900.00
# 14    2005-10-24   900.00
#     YearMonthWeek     Rate
# 903    2022-11-07  3000.00
# 904    2022-11-14  3000.00
# 905    2022-11-21  2967.03
# 906    2022-11-28  2861.54
# 907    2022-12-05  2571.43
# 908    2022-12-12  2400.00
# 909    2022-12-19  2400.00
# 910    2022-12-26  2307.69
# 911    2023-01-02  2092.31
# 912    2023-01-09  2000.00
# 913    2023-01-16  1841.88
# 914    2023-01-23  1798.50
# 915    2023-01-30  1390.48
# 916    2023-02-06  1200.00
# 917    2023-02-13  1200.00
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   YearMonthWeek  918 non-null    datetime64[ns]
#  1   Rate           918 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 14.5 KB

# %%
plt.figure(figsize=(20, 10))
plt.plot(sel_df['POD'], sel_df['RATE'], color='blue', label="Actual Data")
plt.plot(agg_df['YearMonthWeek'], agg_df['Rate'], color='red', label="Aggregated Data(weeks)")

plt.xlabel('Date(Year Month Week)')
plt.ylabel('Cost Rate(USD)')
plt.title('Port_BUSAN_Size_40_Type_HC_PartyID_010004286')
plt.legend()
plt.show();

# %% [markdown]
# <h4>Latest datapoints from Latest dataframe for comparing after forecasting (Measure accuracy)</h4>

# %%
max_date_in_old = sel_df['POD'].max()

# Create a new dataframe that only includes rows from the latest dataframe where the date is greater than the maximum date in the old dataframe
new_dates_df = latest_sel_df[latest_sel_df['POD'] > max_date_in_old].reset_index(drop=True)

# Print the new dataframe
new_dates_df.head(3)
new_dates_df.tail(3)
new_dates_df.info()
# Out:
#             CSL_ID       CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 0  ECS010230200328  010000409869  MELBOURNE     AUMEL  01002778
# 1  ECS010230200329  010000419018  MELBOURNE     AUMEL  01002778
# 2  ECS010230200330  010000427048  MELBOURNE     AUMEL  01002778
#
#                                   PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-03-02        40        HC
# 1  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-03-10        40        HC
# 2  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-03-16        40        HC
#
#      RATE
# 0  1000.0
# 1  1000.0
# 2  1000.0
#              CSL_ID       CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 13  ECS010230400431  010000541165  MELBOURNE     AUMEL  01002778
# 14  ECS010230400432  010000543217  MELBOURNE     AUMEL  01002778
# 15  ECS010230400433  010000557443  MELBOURNE     AUMEL  01002778
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 13  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-05        40        HC
# 14  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-11        40        HC
# 15  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-19        40        HC
#
#      RATE
# 13  500.0
# 14  500.0
# 15  400.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      16 non-null     object
#  1   CNTR_ID     16 non-null     object
#  2   POD_ID      16 non-null     object
#  3   ETD_POL_D   16 non-null     object
#  4   PARTY_ID    16 non-null     object
#  5   PARTY_NAME  16 non-null     object
#  6   POD         16 non-null     datetime64[ns]
#  7   CNTR_SIZE   16 non-null     object
#  8   CNTR_TYPE   16 non-null     object
#  9   RATE        16 non-null     float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 1.4+ KB

# %% [markdown]
# <h4>LSTM Regression<h4>

# %%
# Mean Square Error Function:
def calculate_RMSE(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# Update create_dataset to handle multi-feature dataset
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), :]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)


def create_LSTM_model(trainX, trainY, testX, testY, epochs, lstm_layers):
    model = Sequential()
    
    for i in range(len(lstm_layers)):
        if i == 0:
            # First layer specifies the input_shape and returns sequences
            model.add(LSTM(lstm_layers[i], return_sequences=True, input_shape=(look_back, trainX.shape[2]), 
                           activation='tanh', recurrent_activation='hard_sigmoid', kernel_regularizer=l2(0.01)))
        elif i == len(lstm_layers) - 1:
            # Last layer doesn't return sequences
            model.add(LSTM(lstm_layers[i], activation='tanh', kernel_regularizer=l2(0.01)))
        else:
            # Middle layers return sequences
            model.add(LSTM(lstm_layers[i], return_sequences=True, activation='tanh', 
                           recurrent_activation='hard_sigmoid', kernel_regularizer=l2(0.01)))
        model.add(Dropout(0.2))
        
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=0.0005))
    model.summary()

    # Add early stopping
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)
    
    # Fit the model and store the history
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=128, verbose=2, 
                        validation_data=(testX, testY), callbacks=[es])
    return model, history


def plot_train_val_loss(history):
    plt.figure(figsize=(10,6))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model loss progress during training and validation')
    plt.xlabel('Epoch')
    plt.ylabel('Training and Validation Loss')
    plt.legend()
    plt.show()

# %%
# Normalize dataset for LSTM
from sklearn.preprocessing import MinMaxScaler

# Initialize two separate scalers
scaler_rate = MinMaxScaler(feature_range=(0, 1))

# Fit and transform 'RATE' and 'during_covid' separately
rate_scaled = scaler_rate.fit_transform(agg_df[['Rate']])

# Concatenate the scaled data
dataset = np.concatenate([rate_scaled], axis=1)

# Split into train and test sets
train_size = int(len(dataset) * 0.7)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# Reshape into X=t and Y=t+1, timestep  look_back
look_back = 5
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# Reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], look_back, trainX.shape[2]))
testX = np.reshape(testX, (testX.shape[0], look_back, testX.shape[2]))

epochs_list = [50, 100, 150, 300]

lstm_layers_list = [
    [64, 64, 32, 32, 16, 16, 8, 8, 4, 4, 2, 2],
    [32, 32, 16, 16, 8, 8, 4, 4, 2, 2],
    [16, 16, 8, 8, 4, 4, 2, 2],
    [8, 8, 4, 4, 2, 2],
    [4, 4, 2, 2],
    [2, 2]
]

rmse_results = {}

for epochs in epochs_list:
    print(f'Training for {epochs} epochs...')
    
    for lstm_layers in lstm_layers_list:
        print(f'Training with LSTM layers: {lstm_layers}')
        model, history = create_LSTM_model(trainX, trainY, testX, testY, epochs, lstm_layers)
        
        # Add the loss for this model to the plot
        plt.plot(history.history['loss'], label=f'Train Loss - {epochs} epochs, layers: {lstm_layers}')
        plt.plot(history.history['val_loss'], label=f'Validation Loss - {epochs} epochs, layers: {lstm_layers}')

        # Evalute LSTM Model
        trainPredict = model.predict(trainX)
        testPredict = model.predict(testX)

        # inverse_transform
        trainPredict = scaler_rate.inverse_transform(trainPredict)
        trainY_orig = scaler_rate.inverse_transform([trainY])
        testPredict = scaler_rate.inverse_transform(testPredict)
        testY_orig = scaler_rate.inverse_transform([testY])


        # Calculate mean squared error
        trainScore = calculate_RMSE(trainY_orig[0], trainPredict[:,0])
        print(f'Train Score: {trainScore:.2f} RMSE for {epochs} epochs')
        testScore = calculate_RMSE(testY_orig[0], testPredict[:,0])
        print(f'Test Score: {testScore:.2f} RMSE for {epochs} epochs')

        rmse_results[f'{epochs} epochs, {lstm_layers} layers'] = {'Train RMSE': trainScore, 'Test RMSE': testScore}

# Configure and show the plot
plt.title('Model loss progress during training and validation')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend()
plt.show();

# Convert the dictionary to a DataFrame for easy display
rmse_df = pd.DataFrame(rmse_results).T
print(rmse_df)
# Out:
# Training for 50 epochs...
# Training with LSTM layers: [64, 64, 32, 32, 16, 16, 8, 8, 4, 4, 2, 2]
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 5, 64)             16896
#
#  dropout (Dropout)           (None, 5, 64)             0
#
#  lstm_1 (LSTM)               (None, 5, 64)             33024
#
#  dropout_1 (Dropout)         (None, 5, 64)             0
#
#  lstm_2 (LSTM)               (None, 5, 32)             12416
#
#  dropout_2 (Dropout)         (None, 5, 32)             0
#
#  lstm_3 (LSTM)               (None, 5, 32)             8320
#
#  dropout_3 (Dropout)         (None, 5, 32)             0
#
#  lstm_4 (LSTM)               (None, 5, 16)             3136
#
#  dropout_4 (Dropout)         (None, 5, 16)             0
#
#  lstm_5 (LSTM)               (None, 5, 16)             2112
#
#  dropout_5 (Dropout)         (None, 5, 16)             0
#
#  lstm_6 (LSTM)               (None, 5, 8)              800
#
#  dropout_6 (Dropout)         (None, 5, 8)              0
#
#  lstm_7 (LSTM)               (None, 5, 8)              544
#
#  dropout_7 (Dropout)         (None, 5, 8)              0
#
#  lstm_8 (LSTM)               (None, 5, 4)              208
#
#  dropout_8 (Dropout)         (None, 5, 4)              0
#
#  lstm_9 (LSTM)               (None, 5, 4)              144
#
#  dropout_9 (Dropout)         (None, 5, 4)              0
#
#  lstm_10 (LSTM)              (None, 5, 2)              56
#
#  dropout_10 (Dropout)        (None, 5, 2)              0
#
#  lstm_11 (LSTM)              (None, 2)                 40
#
#  dropout_11 (Dropout)        (None, 2)                 0
#
#  dense (Dense)               (None, 1)                 3
#
# =================================================================
# Total params: 77,699
# Trainable params: 77,699
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 25s - loss: 3.6334 - val_loss: 3.7974 - 25s/epoch - 5s/step
# Epoch 2/50
# 5/5 - 0s - loss: 3.4935 - val_loss: 3.6575 - 249ms/epoch - 50ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 3.3582 - val_loss: 3.5222 - 243ms/epoch - 49ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 3.2275 - val_loss: 3.3917 - 262ms/epoch - 52ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 3.1015 - val_loss: 3.2659 - 236ms/epoch - 47ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 2.9804 - val_loss: 3.1449 - 235ms/epoch - 47ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 2.8640 - val_loss: 3.0286 - 234ms/epoch - 47ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 2.7521 - val_loss: 2.9168 - 235ms/epoch - 47ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 2.6447 - val_loss: 2.8095 - 230ms/epoch - 46ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 2.5419 - val_loss: 2.7065 - 231ms/epoch - 46ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 2.4430 - val_loss: 2.6076 - 232ms/epoch - 46ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 2.3483 - val_loss: 2.5128 - 230ms/epoch - 46ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 2.2575 - val_loss: 2.4218 - 231ms/epoch - 46ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 2.1705 - val_loss: 2.3346 - 232ms/epoch - 46ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 2.0871 - val_loss: 2.2509 - 239ms/epoch - 48ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 2.0067 - val_loss: 2.1707 - 234ms/epoch - 47ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 1.9302 - val_loss: 2.0938 - 233ms/epoch - 47ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 1.8565 - val_loss: 2.0201 - 232ms/epoch - 46ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 1.7861 - val_loss: 1.9495 - 232ms/epoch - 46ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 1.7183 - val_loss: 1.8818 - 234ms/epoch - 47ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 1.6532 - val_loss: 1.8169 - 235ms/epoch - 47ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 1.5910 - val_loss: 1.7548 - 234ms/epoch - 47ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 1.5312 - val_loss: 1.6954 - 235ms/epoch - 47ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 1.4739 - val_loss: 1.6385 - 231ms/epoch - 46ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 1.4189 - val_loss: 1.5841 - 232ms/epoch - 46ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 1.3662 - val_loss: 1.5320 - 229ms/epoch - 46ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 1.3152 - val_loss: 1.4820 - 234ms/epoch - 47ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 1.2667 - val_loss: 1.4341 - 232ms/epoch - 46ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 1.2201 - val_loss: 1.3882 - 238ms/epoch - 48ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 1.1753 - val_loss: 1.3443 - 230ms/epoch - 46ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 1.1323 - val_loss: 1.3021 - 230ms/epoch - 46ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 1.0909 - val_loss: 1.2617 - 230ms/epoch - 46ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 1.0515 - val_loss: 1.2228 - 232ms/epoch - 46ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 1.0133 - val_loss: 1.1856 - 232ms/epoch - 46ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.9768 - val_loss: 1.1499 - 231ms/epoch - 46ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.9418 - val_loss: 1.1156 - 230ms/epoch - 46ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.9083 - val_loss: 1.0827 - 231ms/epoch - 46ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.8760 - val_loss: 1.0512 - 235ms/epoch - 47ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.8449 - val_loss: 1.0208 - 229ms/epoch - 46ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.8153 - val_loss: 0.9917 - 231ms/epoch - 46ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.7864 - val_loss: 0.9638 - 236ms/epoch - 47ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.7590 - val_loss: 0.9370 - 236ms/epoch - 47ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.7328 - val_loss: 0.9113 - 232ms/epoch - 46ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.7074 - val_loss: 0.8866 - 231ms/epoch - 46ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.6832 - val_loss: 0.8628 - 240ms/epoch - 48ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.6597 - val_loss: 0.8399 - 234ms/epoch - 47ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.6373 - val_loss: 0.8180 - 264ms/epoch - 53ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.6158 - val_loss: 0.7969 - 231ms/epoch - 46ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.5950 - val_loss: 0.7766 - 230ms/epoch - 46ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.5751 - val_loss: 0.7572 - 233ms/epoch - 47ms/step
# 20/20 [==============================] - 2s 8ms/step
# 9/9 [==============================] - 0s 6ms/step
# Train Score: 246.91 RMSE for 50 epochs
# Test Score: 2118.67 RMSE for 50 epochs
# Training with LSTM layers: [32, 32, 16, 16, 8, 8, 4, 4, 2, 2]
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 5, 32)             4352
#
#  dropout_12 (Dropout)        (None, 5, 32)             0
#
#  lstm_13 (LSTM)              (None, 5, 32)             8320
#
#  dropout_13 (Dropout)        (None, 5, 32)             0
#
#  lstm_14 (LSTM)              (None, 5, 16)             3136
#
#  dropout_14 (Dropout)        (None, 5, 16)             0
#
#  lstm_15 (LSTM)              (None, 5, 16)             2112
#
#  dropout_15 (Dropout)        (None, 5, 16)             0
#
#  lstm_16 (LSTM)              (None, 5, 8)              800
#
#  dropout_16 (Dropout)        (None, 5, 8)              0
#
#  lstm_17 (LSTM)              (None, 5, 8)              544
#
#  dropout_17 (Dropout)        (None, 5, 8)              0
#
#  lstm_18 (LSTM)              (None, 5, 4)              208
#
#  dropout_18 (Dropout)        (None, 5, 4)              0
#
#  lstm_19 (LSTM)              (None, 5, 4)              144
#
#  dropout_19 (Dropout)        (None, 5, 4)              0
#
#  lstm_20 (LSTM)              (None, 5, 2)              56
#
#  dropout_20 (Dropout)        (None, 5, 2)              0
#
#  lstm_21 (LSTM)              (None, 2)                 40
#
#  dropout_21 (Dropout)        (None, 2)                 0
#
#  dense_1 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 19,715
# Trainable params: 19,715
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 21s - loss: 1.8599 - val_loss: 2.0777 - 21s/epoch - 4s/step
# Epoch 2/50
# 5/5 - 0s - loss: 1.8084 - val_loss: 2.0243 - 184ms/epoch - 37ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 1.7580 - val_loss: 1.9720 - 178ms/epoch - 36ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 1.7089 - val_loss: 1.9210 - 179ms/epoch - 36ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 1.6610 - val_loss: 1.8713 - 175ms/epoch - 35ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 1.6145 - val_loss: 1.8228 - 173ms/epoch - 35ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 1.5691 - val_loss: 1.7757 - 173ms/epoch - 35ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 1.5252 - val_loss: 1.7299 - 171ms/epoch - 34ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 1.4824 - val_loss: 1.6854 - 171ms/epoch - 34ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 1.4409 - val_loss: 1.6421 - 174ms/epoch - 35ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 1.4007 - val_loss: 1.6000 - 172ms/epoch - 34ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 1.3616 - val_loss: 1.5592 - 174ms/epoch - 35ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 1.3238 - val_loss: 1.5196 - 174ms/epoch - 35ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 1.2870 - val_loss: 1.4812 - 174ms/epoch - 35ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 1.2513 - val_loss: 1.4440 - 173ms/epoch - 35ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 1.2164 - val_loss: 1.4078 - 173ms/epoch - 35ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 1.1830 - val_loss: 1.3728 - 171ms/epoch - 34ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 1.1503 - val_loss: 1.3389 - 174ms/epoch - 35ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 1.1186 - val_loss: 1.3060 - 173ms/epoch - 35ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 1.0879 - val_loss: 1.2742 - 175ms/epoch - 35ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 1.0580 - val_loss: 1.2434 - 177ms/epoch - 35ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 1.0289 - val_loss: 1.2136 - 176ms/epoch - 35ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 1.0006 - val_loss: 1.1846 - 175ms/epoch - 35ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.9735 - val_loss: 1.1567 - 173ms/epoch - 35ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.9468 - val_loss: 1.1297 - 174ms/epoch - 35ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.9210 - val_loss: 1.1036 - 172ms/epoch - 34ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.8959 - val_loss: 1.0783 - 175ms/epoch - 35ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.8716 - val_loss: 1.0538 - 174ms/epoch - 35ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.8476 - val_loss: 1.0301 - 178ms/epoch - 36ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.8247 - val_loss: 1.0070 - 173ms/epoch - 35ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.8022 - val_loss: 0.9847 - 173ms/epoch - 35ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.7807 - val_loss: 0.9631 - 172ms/epoch - 34ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.7595 - val_loss: 0.9421 - 213ms/epoch - 43ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.7389 - val_loss: 0.9218 - 204ms/epoch - 41ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.7189 - val_loss: 0.9020 - 195ms/epoch - 39ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.6995 - val_loss: 0.8828 - 177ms/epoch - 35ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.6807 - val_loss: 0.8642 - 173ms/epoch - 35ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.6623 - val_loss: 0.8462 - 181ms/epoch - 36ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.6444 - val_loss: 0.8286 - 186ms/epoch - 37ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.6272 - val_loss: 0.8115 - 180ms/epoch - 36ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.6103 - val_loss: 0.7948 - 174ms/epoch - 35ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.5939 - val_loss: 0.7786 - 174ms/epoch - 35ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.5780 - val_loss: 0.7629 - 174ms/epoch - 35ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.5626 - val_loss: 0.7477 - 198ms/epoch - 40ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.5475 - val_loss: 0.7329 - 173ms/epoch - 35ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.5329 - val_loss: 0.7185 - 174ms/epoch - 35ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.5187 - val_loss: 0.7044 - 173ms/epoch - 35ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.5050 - val_loss: 0.6908 - 174ms/epoch - 35ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.4915 - val_loss: 0.6776 - 179ms/epoch - 36ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.4784 - val_loss: 0.6648 - 172ms/epoch - 34ms/step
# 20/20 [==============================] - 2s 6ms/step
# 9/9 [==============================] - 0s 4ms/step
# Train Score: 247.25 RMSE for 50 epochs
# Test Score: 2120.70 RMSE for 50 epochs
# Training with LSTM layers: [16, 16, 8, 8, 4, 4, 2, 2]
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_22 (LSTM)              (None, 5, 16)             1152
#
#  dropout_22 (Dropout)        (None, 5, 16)             0
#
#  lstm_23 (LSTM)              (None, 5, 16)             2112
#
#  dropout_23 (Dropout)        (None, 5, 16)             0
#
#  lstm_24 (LSTM)              (None, 5, 8)              800
#
#  dropout_24 (Dropout)        (None, 5, 8)              0
#
#  lstm_25 (LSTM)              (None, 5, 8)              544
#
#  dropout_25 (Dropout)        (None, 5, 8)              0
#
#  lstm_26 (LSTM)              (None, 5, 4)              208
#
#  dropout_26 (Dropout)        (None, 5, 4)              0
#
#  lstm_27 (LSTM)              (None, 5, 4)              144
#
#  dropout_27 (Dropout)        (None, 5, 4)              0
#
#  lstm_28 (LSTM)              (None, 5, 2)              56
#
#  dropout_28 (Dropout)        (None, 5, 2)              0
#
#  lstm_29 (LSTM)              (None, 2)                 40
#
#  dropout_29 (Dropout)        (None, 2)                 0
#
#  dense_2 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 5,059
# Trainable params: 5,059
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 17s - loss: 0.8235 - val_loss: 1.0624 - 17s/epoch - 3s/step
# Epoch 2/50
# 5/5 - 0s - loss: 0.8058 - val_loss: 1.0429 - 144ms/epoch - 29ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 0.7885 - val_loss: 1.0237 - 143ms/epoch - 29ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 0.7715 - val_loss: 1.0048 - 148ms/epoch - 30ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 0.7548 - val_loss: 0.9862 - 137ms/epoch - 27ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 0.7385 - val_loss: 0.9680 - 137ms/epoch - 27ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 0.7225 - val_loss: 0.9501 - 137ms/epoch - 27ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 0.7068 - val_loss: 0.9325 - 135ms/epoch - 27ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 0.6916 - val_loss: 0.9153 - 136ms/epoch - 27ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 0.6766 - val_loss: 0.8984 - 136ms/epoch - 27ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 0.6621 - val_loss: 0.8818 - 137ms/epoch - 27ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 0.6478 - val_loss: 0.8656 - 138ms/epoch - 28ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 0.6338 - val_loss: 0.8498 - 139ms/epoch - 28ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 0.6202 - val_loss: 0.8343 - 138ms/epoch - 28ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 0.6068 - val_loss: 0.8191 - 139ms/epoch - 28ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 0.5938 - val_loss: 0.8042 - 139ms/epoch - 28ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 0.5812 - val_loss: 0.7897 - 137ms/epoch - 27ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 0.5688 - val_loss: 0.7755 - 137ms/epoch - 27ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 0.5569 - val_loss: 0.7616 - 138ms/epoch - 28ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 0.5450 - val_loss: 0.7481 - 138ms/epoch - 28ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 0.5334 - val_loss: 0.7350 - 138ms/epoch - 28ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 0.5221 - val_loss: 0.7222 - 138ms/epoch - 28ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 0.5111 - val_loss: 0.7097 - 138ms/epoch - 28ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.5004 - val_loss: 0.6976 - 138ms/epoch - 28ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.4899 - val_loss: 0.6859 - 140ms/epoch - 28ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.4796 - val_loss: 0.6745 - 139ms/epoch - 28ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.4696 - val_loss: 0.6634 - 139ms/epoch - 28ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.4599 - val_loss: 0.6527 - 139ms/epoch - 28ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.4502 - val_loss: 0.6423 - 139ms/epoch - 28ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.4409 - val_loss: 0.6323 - 139ms/epoch - 28ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.4319 - val_loss: 0.6226 - 139ms/epoch - 28ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.4227 - val_loss: 0.6132 - 139ms/epoch - 28ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.4140 - val_loss: 0.6040 - 140ms/epoch - 28ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.4053 - val_loss: 0.5951 - 139ms/epoch - 28ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.3969 - val_loss: 0.5866 - 138ms/epoch - 28ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.3887 - val_loss: 0.5782 - 139ms/epoch - 28ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.3808 - val_loss: 0.5700 - 139ms/epoch - 28ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.3728 - val_loss: 0.5621 - 139ms/epoch - 28ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.3650 - val_loss: 0.5544 - 137ms/epoch - 27ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.3574 - val_loss: 0.5468 - 139ms/epoch - 28ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.3501 - val_loss: 0.5394 - 139ms/epoch - 28ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.3428 - val_loss: 0.5321 - 139ms/epoch - 28ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.3358 - val_loss: 0.5250 - 139ms/epoch - 28ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.3289 - val_loss: 0.5182 - 139ms/epoch - 28ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.3221 - val_loss: 0.5115 - 140ms/epoch - 28ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.3155 - val_loss: 0.5050 - 154ms/epoch - 31ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.3087 - val_loss: 0.4985 - 153ms/epoch - 31ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.3024 - val_loss: 0.4922 - 146ms/epoch - 29ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.2961 - val_loss: 0.4860 - 140ms/epoch - 28ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.2901 - val_loss: 0.4800 - 138ms/epoch - 28ms/step
# 20/20 [==============================] - 1s 5ms/step
# 9/9 [==============================] - 0s 4ms/step
# Train Score: 246.85 RMSE for 50 epochs
# Test Score: 2118.25 RMSE for 50 epochs
# Training with LSTM layers: [8, 8, 4, 4, 2, 2]
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_30 (LSTM)              (None, 5, 8)              320
#
#  dropout_30 (Dropout)        (None, 5, 8)              0
#
#  lstm_31 (LSTM)              (None, 5, 8)              544
#
#  dropout_31 (Dropout)        (None, 5, 8)              0
#
#  lstm_32 (LSTM)              (None, 5, 4)              208
#
#  dropout_32 (Dropout)        (None, 5, 4)              0
#
#  lstm_33 (LSTM)              (None, 5, 4)              144
#
#  dropout_33 (Dropout)        (None, 5, 4)              0
#
#  lstm_34 (LSTM)              (None, 5, 2)              56
#
#  dropout_34 (Dropout)        (None, 5, 2)              0
#
#  lstm_35 (LSTM)              (None, 2)                 40
#
#  dropout_35 (Dropout)        (None, 2)                 0
#
#  dense_3 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 1,315
# Trainable params: 1,315
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 13s - loss: 0.4077 - val_loss: 0.6504 - 13s/epoch - 3s/step
# Epoch 2/50
# 5/5 - 0s - loss: 0.4001 - val_loss: 0.6386 - 111ms/epoch - 22ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 0.3927 - val_loss: 0.6270 - 109ms/epoch - 22ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 0.3855 - val_loss: 0.6156 - 112ms/epoch - 22ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 0.3785 - val_loss: 0.6045 - 107ms/epoch - 21ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 0.3718 - val_loss: 0.5936 - 107ms/epoch - 21ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 0.3654 - val_loss: 0.5831 - 106ms/epoch - 21ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 0.3590 - val_loss: 0.5731 - 106ms/epoch - 21ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 0.3529 - val_loss: 0.5634 - 108ms/epoch - 22ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 0.3471 - val_loss: 0.5543 - 108ms/epoch - 22ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 0.3413 - val_loss: 0.5456 - 108ms/epoch - 22ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 0.3358 - val_loss: 0.5373 - 110ms/epoch - 22ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 0.3304 - val_loss: 0.5295 - 112ms/epoch - 22ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 0.3253 - val_loss: 0.5223 - 111ms/epoch - 22ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 0.3202 - val_loss: 0.5156 - 110ms/epoch - 22ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 0.3150 - val_loss: 0.5093 - 112ms/epoch - 22ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 0.3102 - val_loss: 0.5035 - 108ms/epoch - 22ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 0.3055 - val_loss: 0.4981 - 108ms/epoch - 22ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 0.3010 - val_loss: 0.4930 - 109ms/epoch - 22ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 0.2960 - val_loss: 0.4881 - 109ms/epoch - 22ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 0.2916 - val_loss: 0.4834 - 110ms/epoch - 22ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 0.2869 - val_loss: 0.4788 - 108ms/epoch - 22ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 0.2825 - val_loss: 0.4743 - 108ms/epoch - 22ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.2781 - val_loss: 0.4700 - 108ms/epoch - 22ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.2737 - val_loss: 0.4658 - 108ms/epoch - 22ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.2694 - val_loss: 0.4617 - 107ms/epoch - 21ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.2653 - val_loss: 0.4574 - 108ms/epoch - 22ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.2610 - val_loss: 0.4533 - 109ms/epoch - 22ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.2573 - val_loss: 0.4492 - 107ms/epoch - 21ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.2531 - val_loss: 0.4452 - 108ms/epoch - 22ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.2493 - val_loss: 0.4414 - 109ms/epoch - 22ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.2452 - val_loss: 0.4377 - 108ms/epoch - 22ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.2415 - val_loss: 0.4339 - 109ms/epoch - 22ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.2376 - val_loss: 0.4302 - 108ms/epoch - 22ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.2340 - val_loss: 0.4266 - 108ms/epoch - 22ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.2303 - val_loss: 0.4230 - 108ms/epoch - 22ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.2268 - val_loss: 0.4195 - 108ms/epoch - 22ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.2232 - val_loss: 0.4159 - 110ms/epoch - 22ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.2196 - val_loss: 0.4124 - 109ms/epoch - 22ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.2162 - val_loss: 0.4089 - 110ms/epoch - 22ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.2130 - val_loss: 0.4056 - 116ms/epoch - 23ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.2093 - val_loss: 0.4022 - 113ms/epoch - 23ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.2063 - val_loss: 0.3989 - 109ms/epoch - 22ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.2029 - val_loss: 0.3955 - 109ms/epoch - 22ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.1998 - val_loss: 0.3922 - 109ms/epoch - 22ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.1965 - val_loss: 0.3890 - 108ms/epoch - 22ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.1934 - val_loss: 0.3859 - 132ms/epoch - 26ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.1904 - val_loss: 0.3828 - 112ms/epoch - 22ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.1874 - val_loss: 0.3797 - 108ms/epoch - 22ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.1846 - val_loss: 0.3767 - 108ms/epoch - 22ms/step
# 20/20 [==============================] - 1s 4ms/step
# 9/9 [==============================] - 0s 3ms/step
# Train Score: 247.39 RMSE for 50 epochs
# Test Score: 2121.48 RMSE for 50 epochs
# Training with LSTM layers: [4, 4, 2, 2]
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_36 (LSTM)              (None, 5, 4)              96
#
#  dropout_36 (Dropout)        (None, 5, 4)              0
#
#  lstm_37 (LSTM)              (None, 5, 4)              144
#
#  dropout_37 (Dropout)        (None, 5, 4)              0
#
#  lstm_38 (LSTM)              (None, 5, 2)              56
#
#  dropout_38 (Dropout)        (None, 5, 2)              0
#
#  lstm_39 (LSTM)              (None, 2)                 40
#
#  dropout_39 (Dropout)        (None, 2)                 0
#
#  dense_4 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 339
# Trainable params: 339
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 8s - loss: 0.1782 - val_loss: 0.4260 - 8s/epoch - 2s/step
# Epoch 2/50
# 5/5 - 0s - loss: 0.1752 - val_loss: 0.4200 - 83ms/epoch - 17ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 0.1722 - val_loss: 0.4141 - 83ms/epoch - 17ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 0.1693 - val_loss: 0.4083 - 83ms/epoch - 17ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 0.1666 - val_loss: 0.4026 - 80ms/epoch - 16ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 0.1638 - val_loss: 0.3970 - 79ms/epoch - 16ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 0.1611 - val_loss: 0.3916 - 80ms/epoch - 16ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 0.1585 - val_loss: 0.3862 - 80ms/epoch - 16ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 0.1560 - val_loss: 0.3810 - 80ms/epoch - 16ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 0.1536 - val_loss: 0.3759 - 80ms/epoch - 16ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 0.1513 - val_loss: 0.3709 - 82ms/epoch - 16ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 0.1491 - val_loss: 0.3662 - 80ms/epoch - 16ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 0.1469 - val_loss: 0.3616 - 81ms/epoch - 16ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 0.1449 - val_loss: 0.3571 - 92ms/epoch - 18ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 0.1428 - val_loss: 0.3529 - 84ms/epoch - 17ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 0.1409 - val_loss: 0.3488 - 84ms/epoch - 17ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 0.1391 - val_loss: 0.3450 - 82ms/epoch - 16ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 0.1372 - val_loss: 0.3414 - 82ms/epoch - 16ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 0.1353 - val_loss: 0.3380 - 82ms/epoch - 16ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 0.1336 - val_loss: 0.3347 - 82ms/epoch - 16ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 0.1321 - val_loss: 0.3317 - 82ms/epoch - 16ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 0.1304 - val_loss: 0.3289 - 82ms/epoch - 16ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 0.1288 - val_loss: 0.3263 - 81ms/epoch - 16ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.1271 - val_loss: 0.3240 - 81ms/epoch - 16ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.1254 - val_loss: 0.3217 - 82ms/epoch - 16ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.1241 - val_loss: 0.3196 - 82ms/epoch - 16ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.1226 - val_loss: 0.3175 - 81ms/epoch - 16ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.1210 - val_loss: 0.3157 - 81ms/epoch - 16ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.1197 - val_loss: 0.3140 - 81ms/epoch - 16ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.1181 - val_loss: 0.3123 - 80ms/epoch - 16ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.1170 - val_loss: 0.3107 - 80ms/epoch - 16ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.1151 - val_loss: 0.3091 - 80ms/epoch - 16ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.1140 - val_loss: 0.3076 - 82ms/epoch - 16ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.1124 - val_loss: 0.3061 - 82ms/epoch - 16ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.1111 - val_loss: 0.3046 - 83ms/epoch - 17ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.1099 - val_loss: 0.3032 - 82ms/epoch - 16ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.1085 - val_loss: 0.3018 - 82ms/epoch - 16ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.1072 - val_loss: 0.3005 - 83ms/epoch - 17ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.1060 - val_loss: 0.2992 - 82ms/epoch - 16ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.1045 - val_loss: 0.2979 - 83ms/epoch - 17ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.1032 - val_loss: 0.2965 - 83ms/epoch - 17ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.1022 - val_loss: 0.2952 - 83ms/epoch - 17ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.1008 - val_loss: 0.2939 - 84ms/epoch - 17ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.0995 - val_loss: 0.2926 - 88ms/epoch - 18ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.0983 - val_loss: 0.2913 - 85ms/epoch - 17ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.0972 - val_loss: 0.2901 - 83ms/epoch - 17ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.0959 - val_loss: 0.2888 - 103ms/epoch - 21ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.0948 - val_loss: 0.2877 - 88ms/epoch - 18ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.0937 - val_loss: 0.2865 - 84ms/epoch - 17ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.0925 - val_loss: 0.2854 - 84ms/epoch - 17ms/step
# 20/20 [==============================] - 1s 3ms/step
# 9/9 [==============================] - 0s 2ms/step
# Train Score: 246.94 RMSE for 50 epochs
# Test Score: 2119.00 RMSE for 50 epochs
# Training with LSTM layers: [2, 2]
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_40 (LSTM)              (None, 5, 2)              32
#
#  dropout_40 (Dropout)        (None, 5, 2)              0
#
#  lstm_41 (LSTM)              (None, 2)                 40
#
#  dropout_41 (Dropout)        (None, 2)                 0
#
#  dense_5 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 75
# Trainable params: 75
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 4s - loss: 0.0646 - val_loss: 0.3024 - 4s/epoch - 834ms/step
# Epoch 2/50
# 5/5 - 0s - loss: 0.0634 - val_loss: 0.2989 - 57ms/epoch - 11ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 0.0622 - val_loss: 0.2955 - 56ms/epoch - 11ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 0.0610 - val_loss: 0.2920 - 56ms/epoch - 11ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 0.0598 - val_loss: 0.2886 - 56ms/epoch - 11ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 0.0587 - val_loss: 0.2853 - 56ms/epoch - 11ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 0.0576 - val_loss: 0.2820 - 56ms/epoch - 11ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 0.0565 - val_loss: 0.2788 - 56ms/epoch - 11ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 0.0556 - val_loss: 0.2757 - 56ms/epoch - 11ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 0.0546 - val_loss: 0.2727 - 57ms/epoch - 11ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 0.0537 - val_loss: 0.2697 - 55ms/epoch - 11ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 0.0527 - val_loss: 0.2668 - 56ms/epoch - 11ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 0.0518 - val_loss: 0.2640 - 56ms/epoch - 11ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 0.0511 - val_loss: 0.2613 - 57ms/epoch - 11ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 0.0501 - val_loss: 0.2587 - 56ms/epoch - 11ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 0.0495 - val_loss: 0.2562 - 55ms/epoch - 11ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 0.0488 - val_loss: 0.2538 - 56ms/epoch - 11ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 0.0479 - val_loss: 0.2514 - 57ms/epoch - 11ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 0.0474 - val_loss: 0.2492 - 56ms/epoch - 11ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 0.0468 - val_loss: 0.2471 - 55ms/epoch - 11ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 0.0461 - val_loss: 0.2451 - 56ms/epoch - 11ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 0.0455 - val_loss: 0.2433 - 55ms/epoch - 11ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 0.0451 - val_loss: 0.2415 - 56ms/epoch - 11ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.0446 - val_loss: 0.2399 - 56ms/epoch - 11ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.0440 - val_loss: 0.2384 - 57ms/epoch - 11ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.0436 - val_loss: 0.2370 - 56ms/epoch - 11ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.0432 - val_loss: 0.2358 - 55ms/epoch - 11ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.0427 - val_loss: 0.2346 - 56ms/epoch - 11ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.0423 - val_loss: 0.2336 - 56ms/epoch - 11ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.0417 - val_loss: 0.2326 - 71ms/epoch - 14ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.0414 - val_loss: 0.2318 - 56ms/epoch - 11ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.0410 - val_loss: 0.2311 - 56ms/epoch - 11ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.0407 - val_loss: 0.2304 - 55ms/epoch - 11ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.0401 - val_loss: 0.2298 - 55ms/epoch - 11ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.0398 - val_loss: 0.2293 - 56ms/epoch - 11ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.0395 - val_loss: 0.2288 - 55ms/epoch - 11ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.0391 - val_loss: 0.2284 - 57ms/epoch - 11ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.0389 - val_loss: 0.2281 - 55ms/epoch - 11ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.0383 - val_loss: 0.2277 - 54ms/epoch - 11ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.0380 - val_loss: 0.2274 - 56ms/epoch - 11ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.0377 - val_loss: 0.2271 - 55ms/epoch - 11ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.0372 - val_loss: 0.2268 - 57ms/epoch - 11ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.0371 - val_loss: 0.2265 - 55ms/epoch - 11ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.0367 - val_loss: 0.2262 - 56ms/epoch - 11ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.0363 - val_loss: 0.2259 - 55ms/epoch - 11ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.0360 - val_loss: 0.2255 - 56ms/epoch - 11ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.0356 - val_loss: 0.2253 - 56ms/epoch - 11ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.0353 - val_loss: 0.2250 - 75ms/epoch - 15ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.0349 - val_loss: 0.2246 - 60ms/epoch - 12ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.0346 - val_loss: 0.2243 - 57ms/epoch - 11ms/step
# 20/20 [==============================] - 1s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# Train Score: 245.16 RMSE for 50 epochs
# Test Score: 2097.86 RMSE for 50 epochs
# Training for 100 epochs...
# Training with LSTM layers: [64, 64, 32, 32, 16, 16, 8, 8, 4, 4, 2, 2]
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_42 (LSTM)              (None, 5, 64)             16896
#
#  dropout_42 (Dropout)        (None, 5, 64)             0
#
#  lstm_43 (LSTM)              (None, 5, 64)             33024
#
#  dropout_43 (Dropout)        (None, 5, 64)             0
#
#  lstm_44 (LSTM)              (None, 5, 32)             12416
#
#  dropout_44 (Dropout)        (None, 5, 32)             0
#
#  lstm_45 (LSTM)              (None, 5, 32)             8320
#
#  dropout_45 (Dropout)        (None, 5, 32)             0
#
#  lstm_46 (LSTM)              (None, 5, 16)             3136
#
#  dropout_46 (Dropout)        (None, 5, 16)             0
#
#  lstm_47 (LSTM)              (None, 5, 16)             2112
#
#  dropout_47 (Dropout)        (None, 5, 16)             0
#
#  lstm_48 (LSTM)              (None, 5, 8)              800
#
#  dropout_48 (Dropout)        (None, 5, 8)              0
#
#  lstm_49 (LSTM)              (None, 5, 8)              544
#
#  dropout_49 (Dropout)        (None, 5, 8)              0
#
#  lstm_50 (LSTM)              (None, 5, 4)              208
#
#  dropout_50 (Dropout)        (None, 5, 4)              0
#
#  lstm_51 (LSTM)              (None, 5, 4)              144
#
#  dropout_51 (Dropout)        (None, 5, 4)              0
#
#  lstm_52 (LSTM)              (None, 5, 2)              56
#
#  dropout_52 (Dropout)        (None, 5, 2)              0
#
#  lstm_53 (LSTM)              (None, 2)                 40
#
#  dropout_53 (Dropout)        (None, 2)                 0
#
#  dense_6 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 77,699
# Trainable params: 77,699
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 5/5 - 26s - loss: 3.6390 - val_loss: 3.7982 - 26s/epoch - 5s/step
# Epoch 2/100
# 5/5 - 0s - loss: 3.4977 - val_loss: 3.6532 - 239ms/epoch - 48ms/step
# Epoch 3/100
# 5/5 - 0s - loss: 3.3611 - val_loss: 3.5131 - 240ms/epoch - 48ms/step
# Epoch 4/100
# 5/5 - 0s - loss: 3.2294 - val_loss: 3.3780 - 239ms/epoch - 48ms/step
# Epoch 5/100
# 5/5 - 0s - loss: 3.1027 - val_loss: 3.2483 - 232ms/epoch - 46ms/step
# Epoch 6/100
# 5/5 - 0s - loss: 2.9811 - val_loss: 3.1240 - 231ms/epoch - 46ms/step
# Epoch 7/100
# 5/5 - 0s - loss: 2.8645 - val_loss: 3.0050 - 235ms/epoch - 47ms/step
# Epoch 8/100
# 5/5 - 0s - loss: 2.7527 - val_loss: 2.8915 - 232ms/epoch - 46ms/step
# Epoch 9/100
# 5/5 - 0s - loss: 2.6457 - val_loss: 2.7833 - 234ms/epoch - 47ms/step
# Epoch 10/100
# 5/5 - 0s - loss: 2.5429 - val_loss: 2.6804 - 231ms/epoch - 46ms/step
# Epoch 11/100
# 5/5 - 0s - loss: 2.4442 - val_loss: 2.5824 - 232ms/epoch - 46ms/step
# Epoch 12/100
# 5/5 - 0s - loss: 2.3502 - val_loss: 2.4891 - 234ms/epoch - 47ms/step
# Epoch 13/100
# 5/5 - 0s - loss: 2.2594 - val_loss: 2.4005 - 232ms/epoch - 46ms/step
# Epoch 14/100
# 5/5 - 0s - loss: 2.1726 - val_loss: 2.3158 - 229ms/epoch - 46ms/step
# Epoch 15/100
# 5/5 - 0s - loss: 2.0891 - val_loss: 2.2349 - 232ms/epoch - 46ms/step
# Epoch 16/100
# 5/5 - 0s - loss: 2.0091 - val_loss: 2.1574 - 235ms/epoch - 47ms/step
# Epoch 17/100
# 5/5 - 0s - loss: 1.9326 - val_loss: 2.0830 - 234ms/epoch - 47ms/step
# Epoch 18/100
# 5/5 - 0s - loss: 1.8589 - val_loss: 2.0116 - 234ms/epoch - 47ms/step
# Epoch 19/100
# 5/5 - 0s - loss: 1.7883 - val_loss: 1.9429 - 236ms/epoch - 47ms/step
# Epoch 20/100
# 5/5 - 0s - loss: 1.7205 - val_loss: 1.8769 - 258ms/epoch - 52ms/step
# Epoch 21/100
# 5/5 - 0s - loss: 1.6553 - val_loss: 1.8135 - 239ms/epoch - 48ms/step
# Epoch 22/100
# 5/5 - 0s - loss: 1.5932 - val_loss: 1.7528 - 235ms/epoch - 47ms/step
# Epoch 23/100
# 5/5 - 0s - loss: 1.5336 - val_loss: 1.6943 - 236ms/epoch - 47ms/step
# Epoch 24/100
# 5/5 - 0s - loss: 1.4758 - val_loss: 1.6379 - 237ms/epoch - 47ms/step
# Epoch 25/100
# 5/5 - 0s - loss: 1.4210 - val_loss: 1.5839 - 235ms/epoch - 47ms/step
# Epoch 26/100
# 5/5 - 0s - loss: 1.3680 - val_loss: 1.5321 - 237ms/epoch - 47ms/step
# Epoch 27/100
# 5/5 - 0s - loss: 1.3175 - val_loss: 1.4825 - 241ms/epoch - 48ms/step
# Epoch 28/100
# 5/5 - 0s - loss: 1.2685 - val_loss: 1.4350 - 240ms/epoch - 48ms/step
# Epoch 29/100
# 5/5 - 0s - loss: 1.2218 - val_loss: 1.3894 - 270ms/epoch - 54ms/step
# Epoch 30/100
# 5/5 - 0s - loss: 1.1772 - val_loss: 1.3458 - 235ms/epoch - 47ms/step
# Epoch 31/100
# 5/5 - 0s - loss: 1.1339 - val_loss: 1.3038 - 235ms/epoch - 47ms/step
# Epoch 32/100
# 5/5 - 0s - loss: 1.0927 - val_loss: 1.2637 - 234ms/epoch - 47ms/step
# Epoch 33/100
# 5/5 - 0s - loss: 1.0530 - val_loss: 1.2251 - 234ms/epoch - 47ms/step
# Epoch 34/100
# 5/5 - 0s - loss: 1.0147 - val_loss: 1.1878 - 237ms/epoch - 47ms/step
# Epoch 35/100
# 5/5 - 0s - loss: 0.9783 - val_loss: 1.1517 - 235ms/epoch - 47ms/step
# Epoch 36/100
# 5/5 - 0s - loss: 0.9431 - val_loss: 1.1174 - 234ms/epoch - 47ms/step
# Epoch 37/100
# 5/5 - 0s - loss: 0.9096 - val_loss: 1.0843 - 232ms/epoch - 46ms/step
# Epoch 38/100
# 5/5 - 0s - loss: 0.8771 - val_loss: 1.0527 - 237ms/epoch - 47ms/step
# Epoch 39/100
# 5/5 - 0s - loss: 0.8461 - val_loss: 1.0224 - 236ms/epoch - 47ms/step
# Epoch 40/100
# 5/5 - 0s - loss: 0.8164 - val_loss: 0.9935 - 238ms/epoch - 48ms/step
# Epoch 41/100
# 5/5 - 0s - loss: 0.7876 - val_loss: 0.9656 - 236ms/epoch - 47ms/step
# Epoch 42/100
# 5/5 - 0s - loss: 0.7603 - val_loss: 0.9388 - 236ms/epoch - 47ms/step
# Epoch 43/100
# 5/5 - 0s - loss: 0.7338 - val_loss: 0.9131 - 233ms/epoch - 47ms/step
# Epoch 44/100
# 5/5 - 0s - loss: 0.7083 - val_loss: 0.8881 - 234ms/epoch - 47ms/step
# Epoch 45/100
# 5/5 - 0s - loss: 0.6841 - val_loss: 0.8641 - 232ms/epoch - 46ms/step
# Epoch 46/100
# 5/5 - 0s - loss: 0.6606 - val_loss: 0.8411 - 234ms/epoch - 47ms/step
# Epoch 47/100
# 5/5 - 0s - loss: 0.6382 - val_loss: 0.8189 - 237ms/epoch - 47ms/step
# Epoch 48/100
# 5/5 - 0s - loss: 0.6167 - val_loss: 0.7981 - 232ms/epoch - 46ms/step
# Epoch 49/100
# 5/5 - 0s - loss: 0.5957 - val_loss: 0.7778 - 233ms/epoch - 47ms/step
# Epoch 50/100
# 5/5 - 0s - loss: 0.5760 - val_loss: 0.7584 - 235ms/epoch - 47ms/step
# Epoch 51/100
# 5/5 - 0s - loss: 0.5567 - val_loss: 0.7397 - 234ms/epoch - 47ms/step
# Epoch 52/100
# ...
# Epoch 133/300
# 5/5 - 0s - loss: 0.0203 - val_loss: 0.2086 - 60ms/epoch - 12ms/step
# Epoch 134/300
# 5/5 - 0s - loss: 0.0201 - val_loss: 0.2084 - 58ms/epoch - 12ms/step
# Epoch 135/300
# 5/5 - 0s - loss: 0.0200 - val_loss: 0.2083 - 59ms/epoch - 12ms/step
# Epoch 136/300
# 5/5 - 0s - loss: 0.0198 - val_loss: 0.2082 - 60ms/epoch - 12ms/step
# Epoch 137/300
# 5/5 - 0s - loss: 0.0196 - val_loss: 0.2080 - 62ms/epoch - 12ms/step
# Epoch 138/300
# 5/5 - 0s - loss: 0.0194 - val_loss: 0.2079 - 79ms/epoch - 16ms/step
# Epoch 139/300
# 5/5 - 0s - loss: 0.0192 - val_loss: 0.2078 - 83ms/epoch - 17ms/step
# Epoch 140/300
# 5/5 - 0s - loss: 0.0191 - val_loss: 0.2077 - 65ms/epoch - 13ms/step
# Epoch 141/300
# 5/5 - 0s - loss: 0.0189 - val_loss: 0.2077 - 64ms/epoch - 13ms/step
# Epoch 142/300
# 5/5 - 0s - loss: 0.0187 - val_loss: 0.2075 - 62ms/epoch - 12ms/step
# Epoch 143/300
# 5/5 - 0s - loss: 0.0186 - val_loss: 0.2075 - 62ms/epoch - 12ms/step
# Epoch 144/300
# 5/5 - 0s - loss: 0.0184 - val_loss: 0.2074 - 59ms/epoch - 12ms/step
# Epoch 145/300
# 5/5 - 0s - loss: 0.0181 - val_loss: 0.2074 - 59ms/epoch - 12ms/step
# Epoch 146/300
# 5/5 - 0s - loss: 0.0180 - val_loss: 0.2072 - 58ms/epoch - 12ms/step
# Epoch 147/300
# 5/5 - 0s - loss: 0.0178 - val_loss: 0.2070 - 60ms/epoch - 12ms/step
# Epoch 148/300
# 5/5 - 0s - loss: 0.0177 - val_loss: 0.2068 - 60ms/epoch - 12ms/step
# Epoch 149/300
# 5/5 - 0s - loss: 0.0174 - val_loss: 0.2066 - 60ms/epoch - 12ms/step
# Epoch 150/300
# 5/5 - 0s - loss: 0.0173 - val_loss: 0.2064 - 57ms/epoch - 11ms/step
# Epoch 151/300
# 5/5 - 0s - loss: 0.0172 - val_loss: 0.2063 - 56ms/epoch - 11ms/step
# Epoch 152/300
# 5/5 - 0s - loss: 0.0171 - val_loss: 0.2062 - 56ms/epoch - 11ms/step
# Epoch 153/300
# 5/5 - 0s - loss: 0.0169 - val_loss: 0.2060 - 58ms/epoch - 12ms/step
# Epoch 154/300
# 5/5 - 0s - loss: 0.0167 - val_loss: 0.2059 - 56ms/epoch - 11ms/step
# Epoch 155/300
# 5/5 - 0s - loss: 0.0166 - val_loss: 0.2058 - 57ms/epoch - 11ms/step
# Epoch 156/300
# 5/5 - 0s - loss: 0.0164 - val_loss: 0.2058 - 57ms/epoch - 11ms/step
# Epoch 157/300
# 5/5 - 0s - loss: 0.0162 - val_loss: 0.2058 - 59ms/epoch - 12ms/step
# Epoch 158/300
# 5/5 - 0s - loss: 0.0161 - val_loss: 0.2057 - 60ms/epoch - 12ms/step
# Epoch 159/300
# 5/5 - 0s - loss: 0.0159 - val_loss: 0.2056 - 60ms/epoch - 12ms/step
# Epoch 160/300
# 5/5 - 0s - loss: 0.0158 - val_loss: 0.2055 - 60ms/epoch - 12ms/step
# Epoch 161/300
# 5/5 - 0s - loss: 0.0157 - val_loss: 0.2054 - 60ms/epoch - 12ms/step
# Epoch 162/300
# 5/5 - 0s - loss: 0.0155 - val_loss: 0.2052 - 56ms/epoch - 11ms/step
# Epoch 163/300
# 5/5 - 0s - loss: 0.0153 - val_loss: 0.2050 - 56ms/epoch - 11ms/step
# Epoch 164/300
# 5/5 - 0s - loss: 0.0152 - val_loss: 0.2049 - 62ms/epoch - 12ms/step
# Epoch 165/300
# 5/5 - 0s - loss: 0.0151 - val_loss: 0.2048 - 63ms/epoch - 13ms/step
# Epoch 166/300
# 5/5 - 0s - loss: 0.0150 - val_loss: 0.2047 - 56ms/epoch - 11ms/step
# Epoch 167/300
# 5/5 - 0s - loss: 0.0148 - val_loss: 0.2046 - 56ms/epoch - 11ms/step
# Epoch 168/300
# 5/5 - 0s - loss: 0.0147 - val_loss: 0.2046 - 59ms/epoch - 12ms/step
# Epoch 169/300
# 5/5 - 0s - loss: 0.0145 - val_loss: 0.2046 - 60ms/epoch - 12ms/step
# Epoch 170/300
# 5/5 - 0s - loss: 0.0144 - val_loss: 0.2045 - 58ms/epoch - 12ms/step
# Epoch 171/300
# 5/5 - 0s - loss: 0.0142 - val_loss: 0.2044 - 58ms/epoch - 12ms/step
# Epoch 172/300
# 5/5 - 0s - loss: 0.0141 - val_loss: 0.2043 - 57ms/epoch - 11ms/step
# Epoch 173/300
# 5/5 - 0s - loss: 0.0140 - val_loss: 0.2042 - 58ms/epoch - 12ms/step
# Epoch 174/300
# 5/5 - 0s - loss: 0.0139 - val_loss: 0.2041 - 57ms/epoch - 11ms/step
# Epoch 175/300
# 5/5 - 0s - loss: 0.0137 - val_loss: 0.2040 - 57ms/epoch - 11ms/step
# Epoch 176/300
# 5/5 - 0s - loss: 0.0136 - val_loss: 0.2038 - 55ms/epoch - 11ms/step
# Epoch 177/300
# 5/5 - 0s - loss: 0.0135 - val_loss: 0.2037 - 60ms/epoch - 12ms/step
# Epoch 178/300
# 5/5 - 0s - loss: 0.0134 - val_loss: 0.2036 - 55ms/epoch - 11ms/step
# Epoch 179/300
# 5/5 - 0s - loss: 0.0132 - val_loss: 0.2035 - 55ms/epoch - 11ms/step
# Epoch 180/300
# 5/5 - 0s - loss: 0.0131 - val_loss: 0.2035 - 55ms/epoch - 11ms/step
# Epoch 181/300
# 5/5 - 0s - loss: 0.0129 - val_loss: 0.2033 - 56ms/epoch - 11ms/step
# Epoch 182/300
# 5/5 - 0s - loss: 0.0128 - val_loss: 0.2033 - 58ms/epoch - 12ms/step
# Epoch 183/300
# 5/5 - 0s - loss: 0.0127 - val_loss: 0.2031 - 67ms/epoch - 13ms/step
# Epoch 184/300
# 5/5 - 0s - loss: 0.0126 - val_loss: 0.2029 - 78ms/epoch - 16ms/step
# Epoch 185/300
# 5/5 - 0s - loss: 0.0125 - val_loss: 0.2027 - 63ms/epoch - 13ms/step
# Epoch 186/300
# 5/5 - 0s - loss: 0.0124 - val_loss: 0.2026 - 56ms/epoch - 11ms/step
# Epoch 187/300
# 5/5 - 0s - loss: 0.0123 - val_loss: 0.2025 - 87ms/epoch - 17ms/step
# Epoch 188/300
# 5/5 - 0s - loss: 0.0122 - val_loss: 0.2024 - 63ms/epoch - 13ms/step
# Epoch 189/300
# 5/5 - 0s - loss: 0.0120 - val_loss: 0.2023 - 60ms/epoch - 12ms/step
# Epoch 190/300
# 5/5 - 0s - loss: 0.0119 - val_loss: 0.2024 - 59ms/epoch - 12ms/step
# Epoch 191/300
# 5/5 - 0s - loss: 0.0118 - val_loss: 0.2023 - 57ms/epoch - 11ms/step
# Epoch 192/300
# 5/5 - 0s - loss: 0.0117 - val_loss: 0.2023 - 58ms/epoch - 12ms/step
# Epoch 193/300
# 5/5 - 0s - loss: 0.0116 - val_loss: 0.2022 - 63ms/epoch - 13ms/step
# Epoch 194/300
# 5/5 - 0s - loss: 0.0115 - val_loss: 0.2022 - 63ms/epoch - 13ms/step
# Epoch 195/300
# 5/5 - 0s - loss: 0.0114 - val_loss: 0.2021 - 64ms/epoch - 13ms/step
# Epoch 196/300
# 5/5 - 0s - loss: 0.0113 - val_loss: 0.2021 - 64ms/epoch - 13ms/step
# Epoch 197/300
# 5/5 - 0s - loss: 0.0112 - val_loss: 0.2020 - 62ms/epoch - 12ms/step
# Epoch 198/300
# 5/5 - 0s - loss: 0.0111 - val_loss: 0.2020 - 59ms/epoch - 12ms/step
# Epoch 199/300
# 5/5 - 0s - loss: 0.0110 - val_loss: 0.2017 - 60ms/epoch - 12ms/step
# Epoch 200/300
# 5/5 - 0s - loss: 0.0109 - val_loss: 0.2016 - 60ms/epoch - 12ms/step
# Epoch 201/300
# 5/5 - 0s - loss: 0.0108 - val_loss: 0.2014 - 62ms/epoch - 12ms/step
# Epoch 202/300
# 5/5 - 0s - loss: 0.0107 - val_loss: 0.2014 - 59ms/epoch - 12ms/step
# Epoch 203/300
# 5/5 - 0s - loss: 0.0106 - val_loss: 0.2013 - 60ms/epoch - 12ms/step
# Epoch 204/300
# 5/5 - 0s - loss: 0.0105 - val_loss: 0.2012 - 58ms/epoch - 12ms/step
# Epoch 205/300
# 5/5 - 0s - loss: 0.0104 - val_loss: 0.2011 - 61ms/epoch - 12ms/step
# Epoch 206/300
# 5/5 - 0s - loss: 0.0103 - val_loss: 0.2009 - 64ms/epoch - 13ms/step
# Epoch 207/300
# 5/5 - 0s - loss: 0.0102 - val_loss: 0.2009 - 57ms/epoch - 11ms/step
# Epoch 208/300
# 5/5 - 0s - loss: 0.0101 - val_loss: 0.2009 - 56ms/epoch - 11ms/step
# Epoch 209/300
# 5/5 - 0s - loss: 0.0100 - val_loss: 0.2008 - 55ms/epoch - 11ms/step
# Epoch 210/300
# 5/5 - 0s - loss: 0.0099 - val_loss: 0.2008 - 56ms/epoch - 11ms/step
# Epoch 211/300
# 5/5 - 0s - loss: 0.0098 - val_loss: 0.2007 - 56ms/epoch - 11ms/step
# Epoch 212/300
# 5/5 - 0s - loss: 0.0097 - val_loss: 0.2006 - 57ms/epoch - 11ms/step
# Epoch 213/300
# 5/5 - 0s - loss: 0.0097 - val_loss: 0.2005 - 56ms/epoch - 11ms/step
# Epoch 214/300
# 5/5 - 0s - loss: 0.0096 - val_loss: 0.2005 - 56ms/epoch - 11ms/step
# Epoch 215/300
# 5/5 - 0s - loss: 0.0095 - val_loss: 0.2004 - 58ms/epoch - 12ms/step
# Epoch 216/300
# 5/5 - 0s - loss: 0.0094 - val_loss: 0.2003 - 64ms/epoch - 13ms/step
# Epoch 217/300
# 5/5 - 0s - loss: 0.0093 - val_loss: 0.2001 - 64ms/epoch - 13ms/step
# Epoch 218/300
# 5/5 - 0s - loss: 0.0092 - val_loss: 0.2001 - 64ms/epoch - 13ms/step
# Epoch 219/300
# 5/5 - 0s - loss: 0.0092 - val_loss: 0.2000 - 64ms/epoch - 13ms/step
# Epoch 220/300
# 5/5 - 0s - loss: 0.0091 - val_loss: 0.2000 - 71ms/epoch - 14ms/step
# Epoch 221/300
# 5/5 - 0s - loss: 0.0090 - val_loss: 0.1999 - 67ms/epoch - 13ms/step
# Epoch 222/300
# 5/5 - 0s - loss: 0.0089 - val_loss: 0.1999 - 83ms/epoch - 17ms/step
# Epoch 223/300
# 5/5 - 0s - loss: 0.0088 - val_loss: 0.1997 - 78ms/epoch - 16ms/step
# Epoch 224/300
# 5/5 - 0s - loss: 0.0087 - val_loss: 0.1996 - 60ms/epoch - 12ms/step
# Epoch 225/300
# 5/5 - 0s - loss: 0.0087 - val_loss: 0.1996 - 58ms/epoch - 12ms/step
# Epoch 226/300
# 5/5 - 0s - loss: 0.0086 - val_loss: 0.1995 - 61ms/epoch - 12ms/step
# Epoch 227/300
# 5/5 - 0s - loss: 0.0085 - val_loss: 0.1995 - 61ms/epoch - 12ms/step
# Epoch 228/300
# 5/5 - 0s - loss: 0.0084 - val_loss: 0.1994 - 62ms/epoch - 12ms/step
# Epoch 229/300
# 5/5 - 0s - loss: 0.0084 - val_loss: 0.1994 - 72ms/epoch - 14ms/step
# Epoch 230/300
# 5/5 - 0s - loss: 0.0083 - val_loss: 0.1993 - 77ms/epoch - 15ms/step
# Epoch 231/300
# 5/5 - 0s - loss: 0.0082 - val_loss: 0.1993 - 69ms/epoch - 14ms/step
# Epoch 232/300
# 5/5 - 0s - loss: 0.0081 - val_loss: 0.1992 - 90ms/epoch - 18ms/step
# Epoch 233/300
# 5/5 - 0s - loss: 0.0081 - val_loss: 0.1991 - 60ms/epoch - 12ms/step
# Epoch 234/300
# 5/5 - 0s - loss: 0.0080 - val_loss: 0.1991 - 58ms/epoch - 12ms/step
# Epoch 235/300
# 5/5 - 0s - loss: 0.0079 - val_loss: 0.1988 - 56ms/epoch - 11ms/step
# Epoch 236/300
# 5/5 - 0s - loss: 0.0079 - val_loss: 0.1987 - 60ms/epoch - 12ms/step
# Epoch 237/300
# 5/5 - 0s - loss: 0.0078 - val_loss: 0.1987 - 56ms/epoch - 11ms/step
# Epoch 238/300
# 5/5 - 0s - loss: 0.0077 - val_loss: 0.1986 - 58ms/epoch - 12ms/step
# Epoch 239/300
# 5/5 - 0s - loss: 0.0076 - val_loss: 0.1985 - 58ms/epoch - 12ms/step
# Epoch 240/300
# 5/5 - 0s - loss: 0.0076 - val_loss: 0.1984 - 57ms/epoch - 11ms/step
# Epoch 241/300
# 5/5 - 0s - loss: 0.0075 - val_loss: 0.1984 - 57ms/epoch - 11ms/step
# Epoch 242/300
# 5/5 - 0s - loss: 0.0075 - val_loss: 0.1985 - 61ms/epoch - 12ms/step
# Epoch 243/300
# 5/5 - 0s - loss: 0.0074 - val_loss: 0.1983 - 63ms/epoch - 13ms/step
# Epoch 244/300
# 5/5 - 0s - loss: 0.0074 - val_loss: 0.1983 - 65ms/epoch - 13ms/step
# Epoch 245/300
# 5/5 - 0s - loss: 0.0073 - val_loss: 0.1983 - 59ms/epoch - 12ms/step
# Epoch 246/300
# 5/5 - 0s - loss: 0.0072 - val_loss: 0.1982 - 56ms/epoch - 11ms/step
# Epoch 247/300
# 5/5 - 0s - loss: 0.0071 - val_loss: 0.1982 - 57ms/epoch - 11ms/step
# Epoch 248/300
# 5/5 - 0s - loss: 0.0071 - val_loss: 0.1980 - 54ms/epoch - 11ms/step
# Epoch 249/300
# 5/5 - 0s - loss: 0.0070 - val_loss: 0.1980 - 59ms/epoch - 12ms/step
# Epoch 250/300
# 5/5 - 0s - loss: 0.0070 - val_loss: 0.1979 - 57ms/epoch - 11ms/step
# Epoch 251/300
# 5/5 - 0s - loss: 0.0069 - val_loss: 0.1978 - 57ms/epoch - 11ms/step
# Epoch 252/300
# 5/5 - 0s - loss: 0.0069 - val_loss: 0.1977 - 55ms/epoch - 11ms/step
# Epoch 253/300
# 5/5 - 0s - loss: 0.0068 - val_loss: 0.1977 - 59ms/epoch - 12ms/step
# Epoch 254/300
# 5/5 - 0s - loss: 0.0067 - val_loss: 0.1977 - 56ms/epoch - 11ms/step
# Epoch 255/300
# 5/5 - 0s - loss: 0.0067 - val_loss: 0.1977 - 61ms/epoch - 12ms/step
# Epoch 256/300
# 5/5 - 0s - loss: 0.0067 - val_loss: 0.1978 - 80ms/epoch - 16ms/step
# Epoch 257/300
# 5/5 - 0s - loss: 0.0066 - val_loss: 0.1977 - 75ms/epoch - 15ms/step
# Epoch 258/300
# 5/5 - 0s - loss: 0.0066 - val_loss: 0.1978 - 67ms/epoch - 13ms/step
# Epoch 259/300
# 5/5 - 0s - loss: 0.0065 - val_loss: 0.1978 - 60ms/epoch - 12ms/step
# Epoch 260/300
# 5/5 - 0s - loss: 0.0064 - val_loss: 0.1976 - 61ms/epoch - 12ms/step
# Epoch 261/300
# 5/5 - 0s - loss: 0.0064 - val_loss: 0.1976 - 62ms/epoch - 12ms/step
# Epoch 262/300
# 5/5 - 0s - loss: 0.0063 - val_loss: 0.1974 - 63ms/epoch - 13ms/step
# Epoch 263/300
# 5/5 - 0s - loss: 0.0063 - val_loss: 0.1972 - 61ms/epoch - 12ms/step
# Epoch 264/300
# 5/5 - 0s - loss: 0.0063 - val_loss: 0.1973 - 57ms/epoch - 11ms/step
# Epoch 265/300
# 5/5 - 0s - loss: 0.0062 - val_loss: 0.1973 - 74ms/epoch - 15ms/step
# Epoch 266/300
# 5/5 - 0s - loss: 0.0061 - val_loss: 0.1974 - 68ms/epoch - 14ms/step
# Epoch 267/300
# 5/5 - 0s - loss: 0.0061 - val_loss: 0.1973 - 64ms/epoch - 13ms/step
# Epoch 268/300
# 5/5 - 0s - loss: 0.0060 - val_loss: 0.1972 - 58ms/epoch - 12ms/step
# Epoch 269/300
# 5/5 - 0s - loss: 0.0060 - val_loss: 0.1972 - 56ms/epoch - 11ms/step
# Epoch 270/300
# 5/5 - 0s - loss: 0.0060 - val_loss: 0.1971 - 57ms/epoch - 11ms/step
# Epoch 271/300
# 5/5 - 0s - loss: 0.0059 - val_loss: 0.1969 - 60ms/epoch - 12ms/step
# Epoch 272/300
# 5/5 - 0s - loss: 0.0059 - val_loss: 0.1969 - 58ms/epoch - 12ms/step
# Epoch 273/300
# 5/5 - 0s - loss: 0.0058 - val_loss: 0.1968 - 70ms/epoch - 14ms/step
# Epoch 274/300
# 5/5 - 0s - loss: 0.0058 - val_loss: 0.1969 - 57ms/epoch - 11ms/step
# Epoch 275/300
# 5/5 - 0s - loss: 0.0057 - val_loss: 0.1969 - 55ms/epoch - 11ms/step
# Epoch 276/300
# 5/5 - 0s - loss: 0.0057 - val_loss: 0.1969 - 59ms/epoch - 12ms/step
# Epoch 277/300
# 5/5 - 0s - loss: 0.0056 - val_loss: 0.1968 - 60ms/epoch - 12ms/step
# Epoch 278/300
# 5/5 - 0s - loss: 0.0056 - val_loss: 0.1967 - 61ms/epoch - 12ms/step
# Epoch 279/300
# 5/5 - 0s - loss: 0.0055 - val_loss: 0.1966 - 65ms/epoch - 13ms/step
# Epoch 280/300
# 5/5 - 0s - loss: 0.0055 - val_loss: 0.1965 - 57ms/epoch - 11ms/step
# Epoch 281/300
# 5/5 - 0s - loss: 0.0055 - val_loss: 0.1965 - 55ms/epoch - 11ms/step
# Epoch 282/300
# 5/5 - 0s - loss: 0.0054 - val_loss: 0.1965 - 56ms/epoch - 11ms/step
# Epoch 283/300
# 5/5 - 0s - loss: 0.0054 - val_loss: 0.1965 - 57ms/epoch - 11ms/step
# Epoch 284/300
# 5/5 - 0s - loss: 0.0053 - val_loss: 0.1965 - 58ms/epoch - 12ms/step
# Epoch 285/300
# 5/5 - 0s - loss: 0.0053 - val_loss: 0.1965 - 61ms/epoch - 12ms/step
# Epoch 286/300
# 5/5 - 0s - loss: 0.0053 - val_loss: 0.1965 - 61ms/epoch - 12ms/step
# Epoch 287/300
# 5/5 - 0s - loss: 0.0052 - val_loss: 0.1964 - 61ms/epoch - 12ms/step
# Epoch 288/300
# 5/5 - 0s - loss: 0.0052 - val_loss: 0.1964 - 63ms/epoch - 13ms/step
# Epoch 289/300
# 5/5 - 0s - loss: 0.0052 - val_loss: 0.1962 - 59ms/epoch - 12ms/step
# Epoch 290/300
# 5/5 - 0s - loss: 0.0051 - val_loss: 0.1962 - 59ms/epoch - 12ms/step
# Epoch 291/300
# 5/5 - 0s - loss: 0.0051 - val_loss: 0.1962 - 62ms/epoch - 12ms/step
# Epoch 292/300
# 5/5 - 0s - loss: 0.0050 - val_loss: 0.1961 - 61ms/epoch - 12ms/step
# Epoch 293/300
# 5/5 - 0s - loss: 0.0050 - val_loss: 0.1959 - 60ms/epoch - 12ms/step
# Epoch 294/300
# 5/5 - 0s - loss: 0.0050 - val_loss: 0.1959 - 58ms/epoch - 12ms/step
# Epoch 295/300
# 5/5 - 0s - loss: 0.0050 - val_loss: 0.1960 - 58ms/epoch - 12ms/step
# Epoch 296/300
# 5/5 - 0s - loss: 0.0049 - val_loss: 0.1959 - 55ms/epoch - 11ms/step
# Epoch 297/300
# 5/5 - 0s - loss: 0.0049 - val_loss: 0.1959 - 56ms/epoch - 11ms/step
# Epoch 298/300
# 5/5 - 0s - loss: 0.0049 - val_loss: 0.1959 - 57ms/epoch - 11ms/step
# Epoch 299/300
# 5/5 - 0s - loss: 0.0048 - val_loss: 0.1959 - 55ms/epoch - 11ms/step
# Epoch 300/300
# 5/5 - 0s - loss: 0.0048 - val_loss: 0.1961 - 56ms/epoch - 11ms/step
# 20/20 [==============================] - 1s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# Train Score: 245.65 RMSE for 300 epochs
# Test Score: 2104.69 RMSE for 300 epochs
# Text(0.5, 1.0, 'Model loss progress during training and validation')
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'Training and Validation Loss')
#                                                     Train RMSE    Test RMSE
# 50 epochs, [64, 64, 32, 32, 16, 16, 8, 8, 4, 4,...  246.914814  2118.667257
# 50 epochs, [32, 32, 16, 16, 8, 8, 4, 4, 2, 2] l...  247.251691  2120.699864
# 50 epochs, [16, 16, 8, 8, 4, 4, 2, 2] layers        246.850530  2118.251031
# 50 epochs, [8, 8, 4, 4, 2, 2] layers                247.388905  2121.475730
# 50 epochs, [4, 4, 2, 2] layers                      246.937282  2119.000202
# 50 epochs, [2, 2] layers                            245.159845  2097.864434
# 100 epochs, [64, 64, 32, 32, 16, 16, 8, 8, 4, 4...  246.059419  2111.776607
# 100 epochs, [32, 32, 16, 16, 8, 8, 4, 4, 2, 2] ...  246.169557  2112.911337
# 100 epochs, [16, 16, 8, 8, 4, 4, 2, 2] layers       246.112276  2112.336891
# 100 epochs, [8, 8, 4, 4, 2, 2] layers               246.006432  2111.180650
# 100 epochs, [4, 4, 2, 2] layers                     245.849209  2109.212541
# 100 epochs, [2, 2] layers                           248.546611  2136.907053
# 150 epochs, [64, 64, 32, 32, 16, 16, 8, 8, 4, 4...  245.672991  2105.530088
# 150 epochs, [32, 32, 16, 16, 8, 8, 4, 4, 2, 2] ...  245.728420  2106.959871
# 150 epochs, [16, 16, 8, 8, 4, 4, 2, 2] layers       245.767253  2107.745508
# 150 epochs, [8, 8, 4, 4, 2, 2] layers               245.761300  2107.632683
# 150 epochs, [4, 4, 2, 2] layers                     245.803524  2108.388212
# 150 epochs, [2, 2] layers                           242.622526  2057.180325
# 300 epochs, [64, 64, 32, 32, 16, 16, 8, 8, 4, 4...  245.620815  2102.500336
# 300 epochs, [32, 32, 16, 16, 8, 8, 4, 4, 2, 2] ...  245.629842  2103.627765
# 300 epochs, [16, 16, 8, 8, 4, 4, 2, 2] layers       245.629134  2103.574155
# 300 epochs, [8, 8, 4, 4, 2, 2] layers               245.624996  2103.203285
# 300 epochs, [4, 4, 2, 2] layers                     245.622064  2101.681140
# 300 epochs, [2, 2] layers                           245.646839  2104.693470

# %% [markdown]
# <h4>Forecast the results</h4>

# %%
# Add check for 'RATE_actual' values to avoid division by zero
def compute_accuracy(row):
    if row['RATE_actual'] == 0:
        return np.nan
    else:
        error = abs(row['RATE_actual'] - row['RATE_forecasted'])
        error_proportion = error / row['RATE_actual']
        return (1 - error_proportion) * 100

def forecast_next_weeks(model, look_back, scaler, last_values, n_weeks):
    forecast = []
    for _ in range(n_weeks):
        last_values_2d = np.array(last_values[-look_back:]).reshape(-1, 1)
        input_values_scaled = scaler.transform(last_values_2d)
        input_values_scaled = input_values_scaled.reshape((1, look_back, 1))

        prediction = model.predict(input_values_scaled)
        prediction = scaler.inverse_transform(prediction)
        forecast.append(prediction[0][0])
        last_values.append(prediction[0][0])

    return forecast

# %%
weeks = 12

# Ensure that 'YearMonthWeek' is a datetime object
agg_df['YearMonthWeek'] = pd.to_datetime(agg_df['YearMonthWeek'])
last_date = agg_df['YearMonthWeek'].iloc[-1]

last_values = list(agg_df['Rate'].values[-look_back:])
forecasted_values = forecast_next_weeks(model, look_back, scaler_rate, last_values, weeks)
forecasted_dates = pd.date_range(start=last_date, periods=weeks+1, freq='W')[1:]

df_forecasted = pd.DataFrame({
    'POD': forecasted_dates,
    'RATE': forecasted_values
})

df_forecasted["RATE"] = df_forecasted["RATE"].round(2)

df_forecasted.head(5)
df_forecasted.tail(5)
df_forecasted.info()
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - ETA: 0s
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#          POD        RATE
# 0 2023-02-26  726.280029
# 1 2023-03-05  726.270020
# 2 2023-03-12  726.320007
# 3 2023-03-19  726.349976
# 4 2023-03-26  726.390015
#           POD        RATE
# 7  2023-04-16  726.450012
# 8  2023-04-23  726.450012
# 9  2023-04-30  726.450012
# 10 2023-05-07  726.450012
# 11 2023-05-14  726.450012
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POD     12 non-null     datetime64[ns]
#  1   RATE    12 non-null     float32
# dtypes: datetime64[ns](1), float32(1)
# memory usage: 272.0 bytes

# %% [markdown]
# <h4>Comparing with actual updated against forecasted</h4>

# %%
comparison_df = pd.DataFrame(columns=['WeekStart', 'WeekEnd', 'POD_actual', 'RATE_forecasted', 'RATE_actual'])
df_forecasted['WeekEnd'] = df_forecasted['POD'] + pd.to_timedelta(7, unit='d')  

for _, row in df_forecasted.iterrows():
    mask = (new_dates_df['POD'] >= row['POD']) & (new_dates_df['POD'] < row['WeekEnd'])
    actual_dates_within_week = new_dates_df[mask]

    for _, actual_row in actual_dates_within_week.iterrows():
        comparison_df = comparison_df.append({
            'WeekStart': row['POD'],
            'WeekEnd': row['WeekEnd'],
            'POD_actual': actual_row['POD'],
            'RATE_forecasted': row['RATE'],
            'RATE_actual': actual_row['RATE']
        }, ignore_index=True)

# Remove duplicates
comparison_df = comparison_df.drop_duplicates(subset=['POD_actual', 'RATE_forecasted', 'RATE_actual']).reset_index(drop=True)

# Compute accuracy
comparison_df['accuracy'] = comparison_df.apply(compute_accuracy, axis=1)
comparison_df = comparison_df.dropna(subset=['accuracy'])

total_mean_accuracy = comparison_df['accuracy'].mean()
comparison_df
print(f'The mean accuracy is {total_mean_accuracy:.2f}%\n')
# Out:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_42164\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
#     WeekStart    WeekEnd POD_actual  RATE_forecasted  RATE_actual   accuracy
# 0  2023-02-26 2023-03-05 2023-03-02       726.280029       1000.0  72.628003
# 1  2023-03-05 2023-03-12 2023-03-10       726.270020       1000.0  72.627002
# 2  2023-03-12 2023-03-19 2023-03-16       726.320007       1000.0  72.632001
# 3  2023-03-19 2023-03-26 2023-03-21       726.349976        600.0  78.941671
# 4  2023-03-26 2023-04-02 2023-03-26       726.390015        600.0  78.934998
# 5  2023-03-26 2023-04-02 2023-03-31       726.390015        650.0  88.247690
# 6  2023-04-02 2023-04-09 2023-04-06       726.450012        650.0  88.238460
# 7  2023-04-09 2023-04-16 2023-04-13       726.450012        650.0  88.238460
# 8  2023-04-16 2023-04-23 2023-04-20       726.450012        650.0  88.238460
# 9  2023-04-23 2023-04-30 2023-04-28       726.450012        500.0  54.709998
# 10 2023-04-30 2023-05-07 2023-05-05       726.450012        500.0  54.709998
# 11 2023-05-07 2023-05-14 2023-05-11       726.450012        500.0  54.709998
# 12 2023-05-14 2023-05-21 2023-05-19       726.450012        400.0  18.387497
# The mean accuracy is 70.10%

# %% [markdown]
# <h4>Visualise all, Conclusion</h4>

# %%
plt.figure(figsize=(20, 10))
plt.plot(sel_df['POD'], sel_df['RATE'], color='blue', label="Actual Data")
plt.plot(new_dates_df['POD'], new_dates_df['RATE'], color='blue', label="Actual Data (Updated)")

plt.plot(df_interpolated['POD'], df_interpolated['RATE'], color='green', label="Aggregated Data")
plt.plot(df_forecasted['POD'], df_forecasted['RATE'], color='red', label="Forecasted Data")

plt.xlabel('Date(Year Month)')
plt.ylabel('Cost Rate(USD)')
plt.title('Port_BUSAN_Size_40_Type_HC_PartyID_010004286')
plt.legend()
plt.show();
