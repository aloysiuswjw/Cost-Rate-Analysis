# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Dropout, LSTM, Dense, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from IPython.core.interactiveshell import InteractiveShell
from sklearn.preprocessing import MinMaxScaler
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline
sns.set()
pd.options.display.max_rows = 100

# %% [markdown]
# <h4>Importing Datasets</h4>

# %%
# Import dataset and clean, ready as a dataframe for creating keys
def createDF(datasets):
    df = pd.read_csv(datasets, converters={'PARTY_ID': str, 'COM_ID': str, 'CNTR_SIZE': str})

    # Formating to type and remove NaN values
    df['POD'] = pd.to_datetime(df['POD'])
    df['ENCODED_TYPE'] = df['ENCODED_TYPE'].fillna(-1).astype(int)
    df = df.dropna(subset=['ENCODED_TYPE'])
    df['RATE'] = df['RATE'].fillna(-1).astype(float)
    df = df.dropna(subset=['RATE'])
    df['ENCODED_TYPE'] = df['ENCODED_TYPE'].astype(int)
    df_clean= df.dropna().reset_index(drop=True)

    # Selecting and rearranging columns
    sel_col = ['CSL_ID', 'CNTR_ID','POD_ID','ETD_POL_D','PARTY_ID',
            'PARTY_NAME','POD','CNTR_SIZE','CNTR_TYPE','RATE']
    df_fc = df_clean[sel_col]

    # Removing years we do not want to process in our models
    df_filtered = df_fc[df_fc['POD'].dt.year != 2002]

    # Sorting the dates
    df_filtered = df_filtered.sort_values(by='POD').reset_index(drop=True)
    
    return df_filtered

# %%
# Create Dataframes for old and new
old_data = '.\Datasets\CR_COST_FC.csv'
df1 = createDF(old_data)
df1.head()

new_data = '.\Datasets\CR_COST_FC_new.csv'
df2 = createDF(new_data)
df2.head()
# Out:
#            CSL_ID           CNTR_ID          POD_ID ETD_POL_D  PARTY_ID  \
# 0  ECS01050600224  CTNR010050700354       ROTTERDAM     NLRTM  01008827
# 1  ECS01050600610  CTNR010050700353      FELIXSTOWE     GBFXT  01002303
# 2  ECS01050600041  CTNR010050700351        AUCKLAND     NZAKL  01005136
# 3  ECS01050600163  CTNR010050700370    PASIR GUDANG     MYPGU  01002767
# 4  ECS01050600456  CTNR010050700450  KARACHI (KICT)     PKKHI  01002783
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0             YANG MING (SINGAPORE) PTE. LTD. 2005-07-15        40    HC NOR
# 1                    GLOBELINK FALLOW LIMITED 2005-07-15        40        GP
# 2  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-15        40    HC NOR
# 3          GLOBELINK CONTAINER LINES (JB) S/B 2005-07-15        40        HC
# 4                GLOBELINK PAKISTAN (PVT) LTD 2005-07-16        40        HC
#
#      RATE
# 0  1620.0
# 1  1800.0
# 2  2170.0
# 3   280.0
# 4  1625.0
#            CSL_ID           CNTR_ID          POD_ID ETD_POL_D  PARTY_ID  \
# 0  ECS01050600224  CTNR010050700354       ROTTERDAM     NLRTM  01008827
# 1  ECS01050600610  CTNR010050700353      FELIXSTOWE     GBFXT  01002303
# 2  ECS01050600041  CTNR010050700351        AUCKLAND     NZAKL  01005136
# 3  ECS01050600163  CTNR010050700370    PASIR GUDANG     MYPGU  01002767
# 4  ECS01050600456  CTNR010050700450  KARACHI (KICT)     PKKHI  01002783
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0             YANG MING (SINGAPORE) PTE. LTD. 2005-07-15        40    HC NOR
# 1                    GLOBELINK FALLOW LIMITED 2005-07-15        40        GP
# 2  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-15        40    HC NOR
# 3          GLOBELINK CONTAINER LINES (JB) S/B 2005-07-15        40        HC
# 4                GLOBELINK PAKISTAN (PVT) LTD 2005-07-16        40        HC
#
#      RATE
# 0  1620.0
# 1  1800.0
# 2  2170.0
# 3   280.0
# 4  1625.0

# %% [markdown]
# <h4>Creating Dictionary Keys</h4>

# %%
def filter_dataframe(df):
    filtered_dataframes = {}

    for (port, size, ctype, party_id), group in df.groupby(['POD_ID', 'CNTR_SIZE', 'CNTR_TYPE', 'PARTY_ID']):
        group = group.reset_index(drop=True).sort_values(by='POD')
        df_id = f"Port_{port}_Size_{size}_Type_{ctype}_PartyID_{party_id}"
        filtered_dataframes[df_id] = group

    return filtered_dataframes

# %%
# Creating keys from data
print("Old Data keys:")
filtered_dataframe1 = filter_dataframe(df1)
df_ids1 = list(filtered_dataframe1.keys())
print(list(df_ids1))
print(len(list(df_ids1)))

print("\nNew Data keys:")
filtered_dataframe2 = filter_dataframe(df2)
df_ids2 = list(filtered_dataframe2.keys())
print(list(df_ids2))
print(len(list(df_ids2)))
# Out:
# Old Data keys:
# ['Port_(CONSTANZA)_Size_40_Type_GP_PartyID_010007816', 'Port_(CONSTANZA)_Size_40_Type_HC_PartyID_010007816', 'Port_AARHUS_Size_20_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100027830', 'Port_AARHUS_Size_20_Type_GP_PartyID_010006666', 'Port_AARHUS_Size_40_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100027830', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100028193', 'Port_AARHUS_Size_40_Type_HC_PartyID_010006666', 'Port_ABIDJAN_Size_20_Type_GP_PartyID_0100027878', 'Port_ABIDJAN_Size_40_Type_HC_PartyID_010021097', 'Port_ADELAIDE_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01005078', 'Port_ADELAIDE_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ALEXANDRIA (EL DEKHELA PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC NOR_PartyID_010004995', 'Port_ALGECIRAS_Size_20_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC NOR_PartyID_01008306', 'Port_ALIAGA_Size_20_Type_GP_PartyID_01008316', 'Port_ALIAGA_Size_40_Type_HC_PartyID_01008316', 'Port_ALIAGA PORT (IZMIR)_Size_40_Type_HC_PartyID_01008316', 'Port_ANTWERP_Size_20_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC NOR_PartyID_01001449', 'Port_AQABA_Size_20_Type_GP_PartyID_010006618', 'Port_AQABA_Size_20_Type_GP_PartyID_010021081', 'Port_AQABA_Size_40_Type_HC_PartyID_010006618', 'Port_AQABA_Size_40_Type_HC_PartyID_010021081', 'Port_ASHDOD_Size_20_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_01008417', 'Port_ASHDOD_Size_40_Type_HC_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_HC_PartyID_01008417', 'Port_AUCKLAND_Size_20_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_20_Type_GP (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC NOR_PartyID_01005136', 'Port_BANGKOK_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_20_Type_GP (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (SOC)_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK (TST)_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK (TST)_Size_40_Type_HC_PartyID_010021593', 'Port_BARCELONA_Size_20_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC NOR_PartyID_01008305', 'Port_BEIRUT_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_HC_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_40_Type_HC_PartyID_0100 ...
# 789
#
# New Data keys:
# ['Port_(CONSTANZA)_Size_40_Type_GP_PartyID_010007816', 'Port_(CONSTANZA)_Size_40_Type_HC_PartyID_010007816', 'Port_AARHUS_Size_20_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100027830', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100028193', 'Port_AARHUS_Size_20_Type_GP_PartyID_010006666', 'Port_AARHUS_Size_40_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100027830', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100028193', 'Port_AARHUS_Size_40_Type_HC_PartyID_010006666', 'Port_ABIDJAN_Size_20_Type_GP_PartyID_0100027878', 'Port_ABIDJAN_Size_40_Type_HC_PartyID_010021097', 'Port_ADELAIDE_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01005078', 'Port_ADELAIDE_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ALEXANDRIA (EL DEKHELA PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC NOR_PartyID_010004995', 'Port_ALGECIRAS_Size_20_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC NOR_PartyID_01008306', 'Port_ALIAGA_Size_20_Type_GP_PartyID_01008316', 'Port_ALIAGA_Size_40_Type_HC_PartyID_01008316', 'Port_ALIAGA PORT (IZMIR)_Size_40_Type_HC_PartyID_01008316', 'Port_ANTWERP_Size_20_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC NOR_PartyID_01001449', 'Port_AQABA_Size_20_Type_GP_PartyID_010006618', 'Port_AQABA_Size_20_Type_GP_PartyID_010021081', 'Port_AQABA_Size_40_Type_HC_PartyID_010006618', 'Port_AQABA_Size_40_Type_HC_PartyID_010021081', 'Port_ASHDOD_Size_20_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_01008417', 'Port_ASHDOD_Size_40_Type_HC_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_HC_PartyID_01008417', 'Port_AUCKLAND_Size_20_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_20_Type_GP (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC NOR_PartyID_01005136', 'Port_BANGKOK_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_20_Type_GP (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (SOC)_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK (TST)_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK (TST)_Size_40_Type_HC_PartyID_010021593', 'Port_BARCELONA_Size_20_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC NOR_PartyID_01008305', 'Port_BEIRUT_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_HC_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_20_Type_GP_PartyID_010003651', ' ...
# 799

# %% [markdown]
# <h4>Getting Top 5 ports keys</h4>

# %%
def getTop5Ports(keybunch):
    keybunch_pouch = []
    
    # Get a dictionary with key and number of rows for each dataframe in filtered_dataframes
    key_row_counts = {key: len(keybunch[key]) for key in keybunch}

    # Sort the key_row_counts dictionary by value (number of rows) in descending order
    sorted_key_row_counts = sorted(key_row_counts.items(), key=lambda item: item[1], reverse=True)

    # Get the top 5 keys with the most rows
    top_5_keys_tuple = sorted_key_row_counts[:5]

    # Create a dictionary with the top 5 keys and their corresponding dataframes (with up to 5 rows per dataframe)
    keybunch_subset = {}

    for key, row_count in top_5_keys_tuple:
        keybunch_subset[key] = keybunch[key][:5]
        print(f"Number of rows in {key}: {row_count}")
        keybunch_pouch.append(key)
    
    # Return array of keys
    return keybunch_pouch

# %%
print('Old Dataset Keybunch:')
old_df = getTop5Ports(filtered_dataframe1)
print('\n')

print('New Dataset Keybunch:')
new_df = getTop5Ports(filtered_dataframe2)
# Out:
# Old Dataset Keybunch:
# Number of rows in Port_BUSAN_Size_40_Type_HC_PartyID_010004286: 1689
# Number of rows in Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136: 1688
# Number of rows in Port_MELBOURNE_Size_40_Type_HC_PartyID_01002778: 1325
# Number of rows in Port_SYDNEY_Size_40_Type_HC_PartyID_01002779: 1300
# Number of rows in Port_DUBAI (JEBEL ALI)_Size_40_Type_HC_PartyID_01002788: 1052
#
#
# New Dataset Keybunch:
# Number of rows in Port_BUSAN_Size_40_Type_HC_PartyID_010004286: 1712
# Number of rows in Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136: 1704
# Number of rows in Port_MELBOURNE_Size_40_Type_HC_PartyID_01002778: 1341
# Number of rows in Port_SYDNEY_Size_40_Type_HC_PartyID_01002779: 1308
# Number of rows in Port_DUBAI (JEBEL ALI)_Size_40_Type_HC_PartyID_01002788: 1070

# %%
# Accessing the highest count in the each keypouch, new and old.
sel_df = filtered_dataframe1[old_df[2]]
sel_df.head(5)
sel_df.tail(5)
sel_df.info()
print("\n")

latest_sel_df = filtered_dataframe2[new_df[2]]
latest_sel_df.head(5)
latest_sel_df.tail(5)
latest_sel_df.info()
# Out:
#             CSL_ID           CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 0   ECS01050600278  CTNR010050700692  MELBOURNE     AUMEL  01002778
# 1   ECS01050600280  CTNR010050701022  MELBOURNE     AUMEL  01002778
# 2  ECS010050700458  CTNR010050800604  MELBOURNE     AUMEL  01002778
# 3  ECS010050700214  CTNR010050800727  MELBOURNE     AUMEL  01002778
# 4  ECS010050900271  CTNR010051000178  MELBOURNE     AUMEL  01002778
#
#                                   PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-07-23        40        HC
# 1  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-07-30        40        HC
# 2  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-08-16        40        HC
# 3  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-08-19        40        HC
# 4  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-10-11        40        HC
#
#      RATE
# 0  1200.0
# 1  1200.0
# 2  1000.0
# 3  1200.0
# 4   900.0
#                CSL_ID       CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 1320  ECS010230100302  010000357415  MELBOURNE     AUMEL  01002778
# 1321  ECS010230100303  010000380481  MELBOURNE     AUMEL  01002778
# 1323  ECS010230100304  010000392586  MELBOURNE     AUMEL  01002778
# 1322  ECS010230100304  010000390964  MELBOURNE     AUMEL  01002778
# 1324  ECS010230100304  010000399293  MELBOURNE     AUMEL  01002778
#
#                                      PARTY_NAME        POD CNTR_SIZE  \
# 1320  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-02-11        40
# 1321  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-02-16        40
# 1323  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-02-24        40
# 1322  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-02-24        40
# 1324  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-02-24        40
#
#      CNTR_TYPE    RATE
# 1320        HC  1200.0
# 1321        HC  1200.0
# 1323        HC  1200.0
# 1322        HC  1200.0
# 1324        HC  1200.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1325 entries, 0 to 1324
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      1325 non-null   object
#  1   CNTR_ID     1325 non-null   object
#  2   POD_ID      1325 non-null   object
#  3   ETD_POL_D   1325 non-null   object
#  4   PARTY_ID    1325 non-null   object
#  5   PARTY_NAME  1325 non-null   object
#  6   POD         1325 non-null   datetime64[ns]
#  7   CNTR_SIZE   1325 non-null   object
#  8   CNTR_TYPE   1325 non-null   object
#  9   RATE        1325 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 113.9+ KB
#             CSL_ID           CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 0   ECS01050600278  CTNR010050700692  MELBOURNE     AUMEL  01002778
# 1   ECS01050600280  CTNR010050701022  MELBOURNE     AUMEL  01002778
# 2  ECS010050700458  CTNR010050800604  MELBOURNE     AUMEL  01002778
# 3  ECS010050700214  CTNR010050800727  MELBOURNE     AUMEL  01002778
# 4  ECS010050900271  CTNR010051000178  MELBOURNE     AUMEL  01002778
#
#                                   PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-07-23        40        HC
# 1  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-07-30        40        HC
# 2  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-08-16        40        HC
# 3  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-08-19        40        HC
# 4  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-10-11        40        HC
#
#      RATE
# 0  1200.0
# 1  1200.0
# 2  1000.0
# 3  1200.0
# 4   900.0
#                CSL_ID       CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 1336  ECS010230300518  010000531211  MELBOURNE     AUMEL  01002778
# 1337  ECS010230300518  010000509487  MELBOURNE     AUMEL  01002778
# 1338  ECS010230400431  010000541165  MELBOURNE     AUMEL  01002778
# 1339  ECS010230400432  010000543217  MELBOURNE     AUMEL  01002778
# 1340  ECS010230400433  010000557443  MELBOURNE     AUMEL  01002778
#
#                                      PARTY_NAME        POD CNTR_SIZE  \
# 1336  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-04-28        40
# 1337  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-04-28        40
# 1338  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-05        40
# 1339  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-11        40
# 1340  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-19        40
#
#      CNTR_TYPE   RATE
# 1336        HC  500.0
# 1337        HC  500.0
# 1338        HC  500.0
# 1339        HC  500.0
# 1340        HC  400.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1341 entries, 0 to 1340
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      1341 non-null   object
#  1   CNTR_ID     1341 non-null   object
#  2   POD_ID      1341 non-null   object
#  3   ETD_POL_D   1341 non-null   object
#  4   PARTY_ID    1341 non-null   object
#  5   PARTY_NAME  1341 non-null   object
#  6   POD         1341 non-null   datetime64[ns]
#  7   CNTR_SIZE   1341 non-null   object
#  8   CNTR_TYPE   1341 non-null   object
#  9   RATE        1341 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 115.2+ KB

# %%
# Select features
sel_feat = ['POD','RATE']
df_minmax = sel_df[sel_feat].copy()  # make a copy to avoid SettingWithCopyWarning

# Min-Max Scaling
scaler = MinMaxScaler()
df_minmax['RATE'] = scaler.fit_transform(df_minmax[['RATE']])

# %%
# Check if the DataFrame has any NaN values
if df_minmax.isna().any().any():
    print("The DataFrame contains NaN values.")
else:
    print("The DataFrame does not contain NaN values.")
# Out:
# The DataFrame does not contain NaN values.

# %% [markdown]
# <h4>Interpolate missing values in between dates</h4>

# %%
# Remove duplicated dates and cost rows
df_minmax = df_minmax.drop_duplicates(subset=['POD', 'RATE']).reset_index(drop=True)

# Create a new dataframe with a date range from min to max date in your dataframe
new_df = pd.DataFrame()
new_df['POD'] = pd.date_range(start=df_minmax['POD'].min(), end=df_minmax['POD'].max())

# Merge the original dataframe with the new one. Missing dates in the original dataframe will be filled with NaN
df_interpolated = pd.merge(new_df, df_minmax, on='POD', how='left')  

# Perform spline interpolation
df_interpolated['RATE'] = df_interpolated['RATE'].interpolate(method='polynomial', order=1)

df_interpolated['RATE'] = df_interpolated['RATE'].round(3)

# Now we need to inverse the scaling
df_interpolated['RATE'] = scaler.inverse_transform(df_interpolated[['RATE']])

df_interpolated.head(5)
df_interpolated.tail(5)
df_interpolated.info()
# Out:
#          POD     RATE
# 0 2005-07-23  1200.47
# 1 2005-07-24  1200.47
# 2 2005-07-25  1200.47
# 3 2005-07-26  1200.47
# 4 2005-07-27  1200.47
#             POD     RATE
# 6441 2023-02-20  1200.47
# 6442 2023-02-21  1200.47
# 6443 2023-02-22  1200.47
# 6444 2023-02-23  1200.47
# 6445 2023-02-24  1200.47
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6446 entries, 0 to 6445
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POD     6446 non-null   datetime64[ns]
#  1   RATE    6446 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 151.1 KB

# %% [markdown]
# <h4>Grouping it to week</h4>

# %%
from scipy import stats

# Create YearMonthWeek directly from the 'POD'
df_interpolated['YearMonthWeek'] = df_interpolated['POD'] - pd.to_timedelta(df_interpolated['POD'].dt.dayofweek, unit='D')

# Create a new dataframe with every week in the range
all_weeks = pd.date_range(start=df_interpolated['POD'].min(), end=df_interpolated['POD'].max(), freq='W')
all_weeks_df = pd.DataFrame(all_weeks, columns=['POD'])

# Create YearMonthWeek in all_weeks_df
all_weeks_df['YearMonthWeek'] = all_weeks_df['POD'] - pd.to_timedelta(all_weeks_df['POD'].dt.dayofweek, unit='D')

# Merge this with your original dataframe
merged_df = pd.merge(all_weeks_df, df_interpolated, on=['YearMonthWeek'], how='left')

# Now you can group by YearMonthWeek and compute your rate
grouped = merged_df.groupby(['YearMonthWeek'])

agg_df = pd.DataFrame(columns=['YearMonthWeek', 'Rate'])

for group_name, group_df in grouped:
    year_month_week = group_name

    # Skip if no data for this week
    if group_df['RATE'].isnull().all():
        continue

    # Calculate sum and skewness of RATE values
    rate_sum = group_df['RATE'].sum()
    rate_skew = group_df['RATE'].skew()

    # Calculate trimmed mean of RATE values
    rate_metric = stats.trim_mean(group_df['RATE'].dropna().values, 0.1) # trimming 10% from each end

    new_row = {
        'YearMonthWeek': year_month_week,
        'Rate': rate_metric
    }

    # Append row to aggregated dataframe
    agg_df = agg_df.append(new_row, ignore_index=True)

agg_df = agg_df.sort_values(by='YearMonthWeek').reset_index(drop=True)
agg_df['Rate'] = agg_df['Rate'].round(2)

agg_df.head(15)
agg_df.tail(15)
agg_df.info()
# Out:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:21: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for group_name, group_df in grouped:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# ...
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
#    YearMonthWeek     Rate
# 0     2005-07-18  1200.47
# 1     2005-07-25  1198.39
# 2     2005-08-01  1141.27
# 3     2005-08-08  1059.22
# 4     2005-08-15  1113.23
# 5     2005-08-22  1166.20
# 6     2005-08-29  1125.69
# 7     2005-09-05  1087.27
# 8     2005-09-12  1046.76
# 9     2005-09-19  1007.30
# 10    2005-09-26   967.83
# 11    2005-10-03   928.36
# 12    2005-10-10   902.40
# 13    2005-10-17   902.40
# 14    2005-10-24   902.40
#     YearMonthWeek     Rate
# 903    2022-11-07  3003.43
# 904    2022-11-14  4445.62
# 905    2022-11-21  3027.32
# 906    2022-11-28  2861.15
# 907    2022-12-05  2571.38
# 908    2022-12-12  2400.02
# 909    2022-12-19  2400.02
# 910    2022-12-26  2308.63
# 911    2023-01-02  2091.56
# 912    2023-01-09  2000.17
# 913    2023-01-16  1842.31
# 914    2023-01-23  1798.69
# 915    2023-01-30  1390.53
# 916    2023-02-06  1200.47
# 917    2023-02-13  1200.47
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   YearMonthWeek  918 non-null    datetime64[ns]
#  1   Rate           918 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 14.5 KB

# %% [markdown]
# <h4>Handle Outliers with external feature</h4>

# %%
# Creating a feature to mark the COVID period
agg_df = agg_df[['YearMonthWeek','Rate']].copy()

# Create a new column indicating whether each month is affected by COVID-19
agg_df['Covid'] = 0
agg_df['YearMonthWeek'] = pd.to_datetime(agg_df['YearMonthWeek'])
agg_df.loc[(agg_df['YearMonthWeek'] >= pd.to_datetime('2020-01')) & 
           (agg_df['YearMonthWeek'] <= pd.to_datetime('2023-01')), 'Covid'] = 1


# Just to preview entries that is marked as covid:
agg_df_covid = agg_df[agg_df['Covid'] == 1]
print("Covid entries preview:")
agg_df_covid.head()
print("\n")

print("Done feature enginering dataframe:")
agg_df.head()
agg_df.tail()
agg_df.info()
# Out:
# Covid entries preview:
#     YearMonthWeek    Rate  Covid
# 755    2020-01-06  502.55      1
# 756    2020-01-13  502.55      1
# 757    2020-01-20  502.55      1
# 758    2020-01-27  502.55      1
# 759    2020-02-03  502.55      1
# Done feature enginering dataframe:
#   YearMonthWeek     Rate  Covid
# 0    2005-07-18  1200.47      0
# 1    2005-07-25  1198.39      0
# 2    2005-08-01  1141.27      0
# 3    2005-08-08  1059.22      0
# 4    2005-08-15  1113.23      0
#     YearMonthWeek     Rate  Covid
# 913    2023-01-16  1842.31      0
# 914    2023-01-23  1798.69      0
# 915    2023-01-30  1390.53      0
# 916    2023-02-06  1200.47      0
# 917    2023-02-13  1200.47      0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   YearMonthWeek  918 non-null    datetime64[ns]
#  1   Rate           918 non-null    float64
#  2   Covid          918 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 21.6 KB

# %% [markdown]
# <h4>Latest datapoints from Latest dataframe for comparing after forecasting (Measure accuracy)</h4>

# %%
max_date_in_old = sel_df['POD'].max()

# Create a new dataframe that only includes rows from the latest dataframe where the date is greater than the maximum date in the old dataframe
new_dates_df = latest_sel_df[latest_sel_df['POD'] > max_date_in_old].reset_index(drop=True)

# Print the new dataframe
new_dates_df.head(3)
new_dates_df.tail(3)
new_dates_df.info()
# Out:
#             CSL_ID       CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 0  ECS010230200328  010000409869  MELBOURNE     AUMEL  01002778
# 1  ECS010230200329  010000419018  MELBOURNE     AUMEL  01002778
# 2  ECS010230200330  010000427048  MELBOURNE     AUMEL  01002778
#
#                                   PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-03-02        40        HC
# 1  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-03-10        40        HC
# 2  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-03-16        40        HC
#
#      RATE
# 0  1000.0
# 1  1000.0
# 2  1000.0
#              CSL_ID       CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 13  ECS010230400431  010000541165  MELBOURNE     AUMEL  01002778
# 14  ECS010230400432  010000543217  MELBOURNE     AUMEL  01002778
# 15  ECS010230400433  010000557443  MELBOURNE     AUMEL  01002778
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 13  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-05        40        HC
# 14  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-11        40        HC
# 15  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-19        40        HC
#
#      RATE
# 13  500.0
# 14  500.0
# 15  400.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      16 non-null     object
#  1   CNTR_ID     16 non-null     object
#  2   POD_ID      16 non-null     object
#  3   ETD_POL_D   16 non-null     object
#  4   PARTY_ID    16 non-null     object
#  5   PARTY_NAME  16 non-null     object
#  6   POD         16 non-null     datetime64[ns]
#  7   CNTR_SIZE   16 non-null     object
#  8   CNTR_TYPE   16 non-null     object
#  9   RATE        16 non-null     float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 1.4+ KB

# %%
plt.figure(figsize=(20, 10))
plt.plot(sel_df['POD'], sel_df['RATE'], color='blue', label="Actual Data")
plt.plot(agg_df['YearMonthWeek'], agg_df['Rate'], color='red', label="Aggregated Data(weeks)")

plt.xlabel('Date(Year Month Week)')
plt.ylabel('Cost Rate(USD)')
plt.title('Port_BUSAN_Size_40_Type_HC_PartyID_010004286')
plt.legend()
plt.show();

# %% [markdown]
# <h4>LSTM Regression<h4>

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# Mean Square Error Function:
def calculate_RMSE(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# Update create_dataset to handle multi-feature dataset
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), :]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)


def create_LSTM_model(trainX, trainY, testX, testY, epochs, lstm_layers):
    model = Sequential()

    # input layer
    model.add(Bidirectional(LSTM(lstm_layers[0], return_sequences=True), 
                            input_shape=(trainX.shape[1], trainX.shape[2])))
    model.add(Dropout(0.2))

    # hidden layers
    for i in range(1, len(lstm_layers)):
        model.add(Bidirectional(LSTM(lstm_layers[i], return_sequences=(i!=(len(lstm_layers)-1))))) 
        
    # output layer
    model.add(Dense(1))

    model.compile(loss='mean_squared_error', optimizer='adam')
    
    history = model.fit(trainX, trainY, epochs=epochs, validation_data=(testX, testY), 
                        callbacks=[EarlyStopping(monitor='val_loss', patience=10)], 
                        verbose=2, shuffle=False)

    return model, history


def plot_train_val_loss(history):
    plt.figure(figsize=(10,6))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model loss progress during training and validation')
    plt.xlabel('Epoch')
    plt.ylabel('Training and Validation Loss')
    plt.legend()
    plt.show()

# %%
# Normalize dataset for LSTM
from sklearn.preprocessing import MinMaxScaler

# Initialize two separate scalers
scaler_rate = MinMaxScaler(feature_range=(0, 1))
scaler_covid = MinMaxScaler(feature_range=(0, 1))

# Fit and transform 'RATE' and 'during_covid' separately
rate_scaled = scaler_rate.fit_transform(agg_df[['Rate']])
covid_scaled = scaler_covid.fit_transform(agg_df[['Covid']])

# Concatenate the scaled data
dataset = np.concatenate([rate_scaled, covid_scaled], axis=1)

# Split into train and test sets
train_size = int(len(dataset) * 0.7)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# Reshape into X=t and Y=t+1, timestep  look_back
look_back = 5
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# Reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], look_back, trainX.shape[2]))
testX = np.reshape(testX, (testX.shape[0], look_back, testX.shape[2]))

epochs_list = [50, 100, 150]

lstm_layers_list = [
    [64, 64, 32, 32, 16, 16, 8, 8, 4, 4, 2, 2],
    [32, 32, 16, 16, 8, 8, 4, 4, 2, 2],
    [16, 16, 8, 8, 4, 4, 2, 2],
    [8, 8, 4, 4, 2, 2],
    [4, 4, 2, 2],
    [2, 2]
]

rmse_results = {}

for epochs in epochs_list:
    print(f'Training for {epochs} epochs...')
    
    for lstm_layers in lstm_layers_list:
        print(f'Training with LSTM layers: {lstm_layers}')
        model, history = create_LSTM_model(trainX, trainY, testX, testY, epochs, lstm_layers)
        
        # Add the loss for this model to the plot
        plt.plot(history.history['loss'], label=f'Train Loss - {epochs} epochs, layers: {lstm_layers}')
        plt.plot(history.history['val_loss'], label=f'Validation Loss - {epochs} epochs, layers: {lstm_layers}')

        # Evalute LSTM Model
        trainPredict = model.predict(trainX)
        testPredict = model.predict(testX)

        # inverse_transform
        trainPredict = scaler.inverse_transform(trainPredict)
        trainY_orig = scaler.inverse_transform([trainY])
        testPredict = scaler.inverse_transform(testPredict)
        testY_orig = scaler.inverse_transform([testY])

        # Calculate mean squared error
        trainScore = calculate_RMSE(trainY_orig[0], trainPredict[:,0])
        print(f'Train Score: {trainScore:.2f} RMSE for {epochs} epochs')
        testScore = calculate_RMSE(testY_orig[0], testPredict[:,0])
        print(f'Test Score: {testScore:.2f} RMSE for {epochs} epochs')

        rmse_results[f'{epochs} epochs, {lstm_layers} layers'] = {'Train RMSE': trainScore, 'Test RMSE': testScore}

# Configure and show the plot
plt.title('Model loss progress during training and validation')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend()
plt.show();

# Convert the dictionary to a DataFrame for easy display
rmse_df = pd.DataFrame(rmse_results).T
print(rmse_df)
# Out:
# Training for 50 epochs...
# Training with LSTM layers: [64, 64, 32, 32, 16, 16, 8, 8, 4, 4, 2, 2]
# Epoch 1/50
# 20/20 - 45s - loss: 0.0040 - val_loss: 0.1488 - 45s/epoch - 2s/step
# Epoch 2/50
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1488 - 705ms/epoch - 35ms/step
# Epoch 3/50
# 20/20 - 1s - loss: 0.0014 - val_loss: 0.1518 - 713ms/epoch - 36ms/step
# Epoch 4/50
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1501 - 703ms/epoch - 35ms/step
# Epoch 5/50
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1505 - 684ms/epoch - 34ms/step
# Epoch 6/50
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1505 - 683ms/epoch - 34ms/step
# Epoch 7/50
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1505 - 678ms/epoch - 34ms/step
# Epoch 8/50
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1505 - 678ms/epoch - 34ms/step
# Epoch 9/50
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1505 - 705ms/epoch - 35ms/step
# Epoch 10/50
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1505 - 724ms/epoch - 36ms/step
# Epoch 11/50
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1504 - 706ms/epoch - 35ms/step
# 20/20 [==============================] - 8s 9ms/step
# 9/9 [==============================] - 0s 8ms/step
# Train Score: 266.90 RMSE for 50 epochs
# Test Score: 2819.86 RMSE for 50 epochs
# Training with LSTM layers: [32, 32, 16, 16, 8, 8, 4, 4, 2, 2]
# Epoch 1/50
# 20/20 - 37s - loss: 0.0037 - val_loss: 0.1426 - 37s/epoch - 2s/step
# Epoch 2/50
# 20/20 - 1s - loss: 0.0013 - val_loss: 0.1515 - 605ms/epoch - 30ms/step
# Epoch 3/50
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1503 - 586ms/epoch - 29ms/step
# Epoch 4/50
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1498 - 703ms/epoch - 35ms/step
# Epoch 5/50
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1501 - 703ms/epoch - 35ms/step
# Epoch 6/50
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1498 - 635ms/epoch - 32ms/step
# Epoch 7/50
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1496 - 660ms/epoch - 33ms/step
# Epoch 8/50
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1494 - 622ms/epoch - 31ms/step
# Epoch 9/50
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1489 - 695ms/epoch - 35ms/step
# Epoch 10/50
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1481 - 707ms/epoch - 35ms/step
# Epoch 11/50
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1465 - 641ms/epoch - 32ms/step
# 20/20 [==============================] - 7s 8ms/step
# 9/9 [==============================] - 0s 7ms/step
# Train Score: 263.87 RMSE for 50 epochs
# Test Score: 2782.60 RMSE for 50 epochs
# Training with LSTM layers: [16, 16, 8, 8, 4, 4, 2, 2]
# Epoch 1/50
# 20/20 - 31s - loss: 0.0038 - val_loss: 0.1427 - 31s/epoch - 2s/step
# Epoch 2/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1482 - 450ms/epoch - 22ms/step
# Epoch 3/50
# 20/20 - 0s - loss: 0.0015 - val_loss: 0.1486 - 431ms/epoch - 22ms/step
# Epoch 4/50
# 20/20 - 0s - loss: 0.0015 - val_loss: 0.1466 - 432ms/epoch - 22ms/step
# Epoch 5/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1460 - 424ms/epoch - 21ms/step
# Epoch 6/50
# 20/20 - 0s - loss: 0.0015 - val_loss: 0.1439 - 436ms/epoch - 22ms/step
# Epoch 7/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1408 - 431ms/epoch - 22ms/step
# Epoch 8/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1352 - 423ms/epoch - 21ms/step
# Epoch 9/50
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1253 - 421ms/epoch - 21ms/step
# Epoch 10/50
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.1090 - 422ms/epoch - 21ms/step
# Epoch 11/50
# 20/20 - 0s - loss: 7.4873e-04 - val_loss: 0.0991 - 419ms/epoch - 21ms/step
# Epoch 12/50
# 20/20 - 0s - loss: 6.8613e-04 - val_loss: 0.1116 - 419ms/epoch - 21ms/step
# Epoch 13/50
# 20/20 - 0s - loss: 7.2685e-04 - val_loss: 0.1121 - 421ms/epoch - 21ms/step
# Epoch 14/50
# 20/20 - 0s - loss: 6.9909e-04 - val_loss: 0.1110 - 422ms/epoch - 21ms/step
# Epoch 15/50
# 20/20 - 0s - loss: 6.5920e-04 - val_loss: 0.1134 - 420ms/epoch - 21ms/step
# Epoch 16/50
# 20/20 - 0s - loss: 6.4592e-04 - val_loss: 0.1139 - 430ms/epoch - 22ms/step
# Epoch 17/50
# 20/20 - 0s - loss: 6.4039e-04 - val_loss: 0.1148 - 422ms/epoch - 21ms/step
# Epoch 18/50
# 20/20 - 0s - loss: 6.2879e-04 - val_loss: 0.1156 - 448ms/epoch - 22ms/step
# Epoch 19/50
# 20/20 - 0s - loss: 6.1373e-04 - val_loss: 0.1159 - 447ms/epoch - 22ms/step
# Epoch 20/50
# 20/20 - 0s - loss: 6.1609e-04 - val_loss: 0.1167 - 477ms/epoch - 24ms/step
# Epoch 21/50
# 20/20 - 0s - loss: 6.0751e-04 - val_loss: 0.1173 - 470ms/epoch - 24ms/step
# 20/20 [==============================] - 5s 5ms/step
# 9/9 [==============================] - 0s 5ms/step
# Train Score: 177.80 RMSE for 50 epochs
# Test Score: 2489.71 RMSE for 50 epochs
# Training with LSTM layers: [8, 8, 4, 4, 2, 2]
# Epoch 1/50
# 20/20 - 24s - loss: 0.0049 - val_loss: 0.1648 - 24s/epoch - 1s/step
# Epoch 2/50
# 20/20 - 0s - loss: 0.0020 - val_loss: 0.1449 - 358ms/epoch - 18ms/step
# Epoch 3/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1452 - 345ms/epoch - 17ms/step
# Epoch 4/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1467 - 335ms/epoch - 17ms/step
# Epoch 5/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1455 - 344ms/epoch - 17ms/step
# Epoch 6/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1446 - 370ms/epoch - 19ms/step
# Epoch 7/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1439 - 335ms/epoch - 17ms/step
# Epoch 8/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1430 - 329ms/epoch - 16ms/step
# Epoch 9/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1418 - 325ms/epoch - 16ms/step
# Epoch 10/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1405 - 331ms/epoch - 17ms/step
# Epoch 11/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1389 - 342ms/epoch - 17ms/step
# Epoch 12/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1370 - 326ms/epoch - 16ms/step
# Epoch 13/50
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1345 - 322ms/epoch - 16ms/step
# Epoch 14/50
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1316 - 365ms/epoch - 18ms/step
# Epoch 15/50
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1280 - 322ms/epoch - 16ms/step
# Epoch 16/50
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.1239 - 324ms/epoch - 16ms/step
# Epoch 17/50
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.1193 - 326ms/epoch - 16ms/step
# Epoch 18/50
# 20/20 - 0s - loss: 9.9603e-04 - val_loss: 0.1144 - 321ms/epoch - 16ms/step
# Epoch 19/50
# 20/20 - 0s - loss: 8.0611e-04 - val_loss: 0.1095 - 320ms/epoch - 16ms/step
# Epoch 20/50
# 20/20 - 0s - loss: 6.9603e-04 - val_loss: 0.1072 - 327ms/epoch - 16ms/step
# Epoch 21/50
# 20/20 - 0s - loss: 6.6181e-04 - val_loss: 0.1092 - 321ms/epoch - 16ms/step
# Epoch 22/50
# 20/20 - 0s - loss: 6.5900e-04 - val_loss: 0.1113 - 325ms/epoch - 16ms/step
# Epoch 23/50
# 20/20 - 0s - loss: 6.5625e-04 - val_loss: 0.1125 - 324ms/epoch - 16ms/step
# Epoch 24/50
# 20/20 - 0s - loss: 6.5825e-04 - val_loss: 0.1136 - 324ms/epoch - 16ms/step
# Epoch 25/50
# 20/20 - 0s - loss: 6.5652e-04 - val_loss: 0.1141 - 323ms/epoch - 16ms/step
# Epoch 26/50
# 20/20 - 0s - loss: 6.1334e-04 - val_loss: 0.1139 - 324ms/epoch - 16ms/step
# Epoch 27/50
# 20/20 - 0s - loss: 6.0516e-04 - val_loss: 0.1143 - 321ms/epoch - 16ms/step
# Epoch 28/50
# 20/20 - 0s - loss: 6.1980e-04 - val_loss: 0.1150 - 327ms/epoch - 16ms/step
# Epoch 29/50
# 20/20 - 0s - loss: 6.0464e-04 - val_loss: 0.1155 - 328ms/epoch - 16ms/step
# Epoch 30/50
# 20/20 - 0s - loss: 5.9632e-04 - val_loss: 0.1156 - 322ms/epoch - 16ms/step
# 20/20 [==============================] - 4s 4ms/step
# 9/9 [==============================] - 0s 4ms/step
# Train Score: 173.90 RMSE for 50 epochs
# Test Score: 2472.29 RMSE for 50 epochs
# Training with LSTM layers: [4, 4, 2, 2]
# Epoch 1/50
# 20/20 - 16s - loss: 0.0048 - val_loss: 0.1642 - 16s/epoch - 816ms/step
# Epoch 2/50
# 20/20 - 0s - loss: 0.0018 - val_loss: 0.1504 - 263ms/epoch - 13ms/step
# Epoch 3/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1521 - 258ms/epoch - 13ms/step
# Epoch 4/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1531 - 246ms/epoch - 12ms/step
# Epoch 5/50
# 20/20 - 0s - loss: 0.0015 - val_loss: 0.1523 - 232ms/epoch - 12ms/step
# Epoch 6/50
# 20/20 - 0s - loss: 0.0015 - val_loss: 0.1520 - 231ms/epoch - 12ms/step
# Epoch 7/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1518 - 233ms/epoch - 12ms/step
# Epoch 8/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1516 - 231ms/epoch - 12ms/step
# Epoch 9/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1513 - 231ms/epoch - 12ms/step
# Epoch 10/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1510 - 232ms/epoch - 12ms/step
# Epoch 11/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1507 - 231ms/epoch - 12ms/step
# Epoch 12/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1503 - 234ms/epoch - 12ms/step
# Epoch 13/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1497 - 231ms/epoch - 12ms/step
# Epoch 14/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1490 - 229ms/epoch - 11ms/step
# Epoch 15/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1479 - 229ms/epoch - 11ms/step
# Epoch 16/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1464 - 229ms/epoch - 11ms/step
# Epoch 17/50
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1444 - 228ms/epoch - 11ms/step
# Epoch 18/50
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1416 - 231ms/epoch - 12ms/step
# Epoch 19/50
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1377 - 229ms/epoch - 11ms/step
# Epoch 20/50
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.1326 - 231ms/epoch - 12ms/step
# Epoch 21/50
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.1263 - 229ms/epoch - 11ms/step
# Epoch 22/50
# 20/20 - 0s - loss: 9.4500e-04 - val_loss: 0.1190 - 231ms/epoch - 12ms/step
# Epoch 23/50
# 20/20 - 0s - loss: 7.9772e-04 - val_loss: 0.1121 - 244ms/epoch - 12ms/step
# Epoch 24/50
# 20/20 - 0s - loss: 6.9662e-04 - val_loss: 0.1068 - 240ms/epoch - 12ms/step
# Epoch 25/50
# 20/20 - 0s - loss: 6.7762e-04 - val_loss: 0.1046 - 230ms/epoch - 11ms/step
# Epoch 26/50
# 20/20 - 0s - loss: 6.6956e-04 - val_loss: 0.1034 - 233ms/epoch - 12ms/step
# Epoch 27/50
# 20/20 - 0s - loss: 6.7683e-04 - val_loss: 0.1018 - 227ms/epoch - 11ms/step
# Epoch 28/50
# 20/20 - 0s - loss: 6.5624e-04 - val_loss: 0.0994 - 230ms/epoch - 11ms/step
# Epoch 29/50
# 20/20 - 0s - loss: 6.6041e-04 - val_loss: 0.0984 - 229ms/epoch - 11ms/step
# Epoch 30/50
# 20/20 - 0s - loss: 6.4881e-04 - val_loss: 0.0974 - 230ms/epoch - 11ms/step
# Epoch 31/50
# 20/20 - 0s - loss: 6.4884e-04 - val_loss: 0.0963 - 228ms/epoch - 11ms/step
# Epoch 32/50
# 20/20 - 0s - loss: 6.2904e-04 - val_loss: 0.0946 - 257ms/epoch - 13ms/step
# Epoch 33/50
# 20/20 - 0s - loss: 6.2429e-04 - val_loss: 0.0941 - 229ms/epoch - 11ms/step
# Epoch 34/50
# 20/20 - 0s - loss: 6.0685e-04 - val_loss: 0.0932 - 239ms/epoch - 12ms/step
# Epoch 35/50
# 20/20 - 0s - loss: 6.0779e-04 - val_loss: 0.0924 - 229ms/epoch - 11ms/step
# Epoch 36/50
# 20/20 - 0s - loss: 6.1437e-04 - val_loss: 0.0920 - 234ms/epoch - 12ms/step
# Epoch 37/50
# 20/20 - 0s - loss: 6.2461e-04 - val_loss: 0.0926 - 230ms/epoch - 12ms/step
# Epoch 38/50
# 20/20 - 0s - loss: 6.1009e-04 - val_loss: 0.0922 - 230ms/epoch - 12ms/step
# Epoch 39/50
# 20/20 - 0s - loss: 6.0048e-04 - val_loss: 0.0919 - 229ms/epoch - 11ms/step
# Epoch 40/50
# 20/20 - 0s - loss: 5.6583e-04 - val_loss: 0.0913 - 229ms/epoch - 11ms/step
# Epoch 41/50
# 20/20 - 0s - loss: 5.9628e-04 - val_loss: 0.0919 - 234ms/epoch - 12ms/step
# Epoch 42/50
# 20/20 - 0s - loss: 6.0249e-04 - val_loss: 0.0927 - 228ms/epoch - 11ms/step
# Epoch 43/50
# 20/20 - 0s - loss: 6.0777e-04 - val_loss: 0.0929 - 229ms/epoch - 11ms/step
# Epoch 44/50
# 20/20 - 0s - loss: 5.8203e-04 - val_loss: 0.0928 - 230ms/epoch - 12ms/step
# Epoch 45/50
# 20/20 - 0s - loss: 5.8016e-04 - val_loss: 0.0923 - 248ms/epoch - 12ms/step
# Epoch 46/50
# 20/20 - 0s - loss: 5.9712e-04 - val_loss: 0.0930 - 230ms/epoch - 12ms/step
# Epoch 47/50
# 20/20 - 0s - loss: 5.9038e-04 - val_loss: 0.0941 - 230ms/epoch - 11ms/step
# Epoch 48/50
# 20/20 - 0s - loss: 5.8738e-04 - val_loss: 0.0945 - 231ms/epoch - 12ms/step
# Epoch 49/50
# 20/20 - 0s - loss: 5.8624e-04 - val_loss: 0.0944 - 228ms/epoch - 11ms/step
# Epoch 50/50
# 20/20 - 0s - loss: 5.6939e-04 - val_loss: 0.0944 - 235ms/epoch - 12ms/step
# 20/20 [==============================] - 3s 3ms/step
# 9/9 [==============================] - 0s 3ms/step
# Train Score: 170.67 RMSE for 50 epochs
# Test Score: 2233.98 RMSE for 50 epochs
# Training with LSTM layers: [2, 2]
# Epoch 1/50
# 20/20 - 8s - loss: 0.0038 - val_loss: 0.1660 - 8s/epoch - 376ms/step
# Epoch 2/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1577 - 148ms/epoch - 7ms/step
# Epoch 3/50
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.1586 - 145ms/epoch - 7ms/step
# Epoch 4/50
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.1539 - 143ms/epoch - 7ms/step
# Epoch 5/50
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.1507 - 142ms/epoch - 7ms/step
# Epoch 6/50
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.1469 - 148ms/epoch - 7ms/step
# Epoch 7/50
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.1439 - 141ms/epoch - 7ms/step
# Epoch 8/50
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.1405 - 142ms/epoch - 7ms/step
# Epoch 9/50
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.1369 - 141ms/epoch - 7ms/step
# Epoch 10/50
# 20/20 - 0s - loss: 0.0010 - val_loss: 0.1340 - 152ms/epoch - 8ms/step
# Epoch 11/50
# 20/20 - 0s - loss: 0.0010 - val_loss: 0.1306 - 154ms/epoch - 8ms/step
# Epoch 12/50
# 20/20 - 0s - loss: 9.6771e-04 - val_loss: 0.1277 - 175ms/epoch - 9ms/step
# Epoch 13/50
# 20/20 - 0s - loss: 9.4742e-04 - val_loss: 0.1245 - 157ms/epoch - 8ms/step
# Epoch 14/50
# 20/20 - 0s - loss: 9.2495e-04 - val_loss: 0.1210 - 143ms/epoch - 7ms/step
# Epoch 15/50
# 20/20 - 0s - loss: 9.2759e-04 - val_loss: 0.1183 - 140ms/epoch - 7ms/step
# Epoch 16/50
# 20/20 - 0s - loss: 9.2548e-04 - val_loss: 0.1154 - 139ms/epoch - 7ms/step
# Epoch 17/50
# 20/20 - 0s - loss: 8.3857e-04 - val_loss: 0.1131 - 140ms/epoch - 7ms/step
# Epoch 18/50
# 20/20 - 0s - loss: 8.6784e-04 - val_loss: 0.1103 - 139ms/epoch - 7ms/step
# Epoch 19/50
# 20/20 - 0s - loss: 8.0799e-04 - val_loss: 0.1080 - 140ms/epoch - 7ms/step
# Epoch 20/50
# 20/20 - 0s - loss: 7.8802e-04 - val_loss: 0.1055 - 138ms/epoch - 7ms/step
# Epoch 21/50
# 20/20 - 0s - loss: 8.1491e-04 - val_loss: 0.1034 - 138ms/epoch - 7ms/step
# Epoch 22/50
# 20/20 - 0s - loss: 7.8611e-04 - val_loss: 0.1009 - 166ms/epoch - 8ms/step
# Epoch 23/50
# 20/20 - 0s - loss: 7.6247e-04 - val_loss: 0.0997 - 139ms/epoch - 7ms/step
# Epoch 24/50
# 20/20 - 0s - loss: 8.0293e-04 - val_loss: 0.0985 - 142ms/epoch - 7ms/step
# Epoch 25/50
# 20/20 - 0s - loss: 7.6041e-04 - val_loss: 0.0978 - 138ms/epoch - 7ms/step
# Epoch 26/50
# 20/20 - 0s - loss: 7.6899e-04 - val_loss: 0.0962 - 141ms/epoch - 7ms/step
# Epoch 27/50
# 20/20 - 0s - loss: 7.2447e-04 - val_loss: 0.0950 - 140ms/epoch - 7ms/step
# Epoch 28/50
# 20/20 - 0s - loss: 6.7200e-04 - val_loss: 0.0939 - 139ms/epoch - 7ms/step
# Epoch 29/50
# 20/20 - 0s - loss: 7.2007e-04 - val_loss: 0.0930 - 137ms/epoch - 7ms/step
# Epoch 30/50
# 20/20 - 0s - loss: 6.9333e-04 - val_loss: 0.0925 - 138ms/epoch - 7ms/step
# Epoch 31/50
# 20/20 - 0s - loss: 7.2646e-04 - val_loss: 0.0926 - 141ms/epoch - 7ms/step
# Epoch 32/50
# 20/20 - 0s - loss: 6.9871e-04 - val_loss: 0.0916 - 142ms/epoch - 7ms/step
# Epoch 33/50
# 20/20 - 0s - loss: 7.0123e-04 - val_loss: 0.0919 - 140ms/epoch - 7ms/step
# Epoch 34/50
# 20/20 - 0s - loss: 6.9717e-04 - val_loss: 0.0920 - 139ms/epoch - 7ms/step
# Epoch 35/50
# 20/20 - 0s - loss: 6.7755e-04 - val_loss: 0.0917 - 140ms/epoch - 7ms/step
# Epoch 36/50
# 20/20 - 0s - loss: 6.7173e-04 - val_loss: 0.0921 - 138ms/epoch - 7ms/step
# Epoch 37/50
# 20/20 - 0s - loss: 6.6834e-04 - val_loss: 0.0919 - 138ms/epoch - 7ms/step
# Epoch 38/50
# 20/20 - 0s - loss: 6.6997e-04 - val_loss: 0.0922 - 138ms/epoch - 7ms/step
# Epoch 39/50
# 20/20 - 0s - loss: 6.9401e-04 - val_loss: 0.0924 - 140ms/epoch - 7ms/step
# Epoch 40/50
# 20/20 - 0s - loss: 6.7029e-04 - val_loss: 0.0918 - 140ms/epoch - 7ms/step
# Epoch 41/50
# 20/20 - 0s - loss: 6.8148e-04 - val_loss: 0.0925 - 140ms/epoch - 7ms/step
# Epoch 42/50
# 20/20 - 0s - loss: 6.8360e-04 - val_loss: 0.0928 - 139ms/epoch - 7ms/step
# 20/20 [==============================] - 1s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# Train Score: 181.30 RMSE for 50 epochs
# Test Score: 2214.74 RMSE for 50 epochs
# Training for 100 epochs...
# Training with LSTM layers: [64, 64, 32, 32, 16, 16, 8, 8, 4, 4, 2, 2]
# Epoch 1/100
# 20/20 - 44s - loss: 0.0039 - val_loss: 0.1477 - 44s/epoch - 2s/step
# Epoch 2/100
# 20/20 - 1s - loss: 0.0014 - val_loss: 0.1492 - 694ms/epoch - 35ms/step
# Epoch 3/100
# 20/20 - 1s - loss: 0.0014 - val_loss: 0.1516 - 713ms/epoch - 36ms/step
# Epoch 4/100
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1501 - 699ms/epoch - 35ms/step
# Epoch 5/100
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1505 - 696ms/epoch - 35ms/step
# Epoch 6/100
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1505 - 697ms/epoch - 35ms/step
# Epoch 7/100
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1504 - 687ms/epoch - 34ms/step
# Epoch 8/100
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1504 - 684ms/epoch - 34ms/step
# Epoch 9/100
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1504 - 684ms/epoch - 34ms/step
# Epoch 10/100
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1504 - 718ms/epoch - 36ms/step
# Epoch 11/100
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1504 - 685ms/epoch - 34ms/step
# 20/20 [==============================] - 8s 9ms/step
# 9/9 [==============================] - 0s 9ms/step
# Train Score: 266.89 RMSE for 100 epochs
# Test Score: 2819.39 RMSE for 100 epochs
# Training with LSTM layers: [32, 32, 16, 16, 8, 8, 4, 4, 2, 2]
# Epoch 1/100
# 20/20 - 37s - loss: 0.0038 - val_loss: 0.1436 - 37s/epoch - 2s/step
# Epoch 2/100
# 20/20 - 1s - loss: 0.0014 - val_loss: 0.1506 - 548ms/epoch - 27ms/step
# Epoch 3/100
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1507 - 536ms/epoch - 27ms/step
# Epoch 4/100
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1497 - 536ms/epoch - 27ms/step
# Epoch 5/100
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1501 - 535ms/epoch - 27ms/step
# Epoch 6/100
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1499 - 524ms/epoch - 26ms/step
# Epoch 7/100
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1498 - 526ms/epoch - 26ms/step
# Epoch 8/100
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1496 - 535ms/epoch - 27ms/step
# Epoch 9/100
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1494 - 523ms/epoch - 26ms/step
# Epoch 10/100
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1490 - 525ms/epoch - 26ms/step
# Epoch 11/100
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1483 - 522ms/epoch - 26ms/step
# 20/20 [==============================] - 6s 7ms/step
# 9/9 [==============================] - 0s 6ms/step
# Train Score: 265.32 RMSE for 100 epochs
# Test Score: 2799.90 RMSE for 100 epochs
# Training with LSTM layers: [16, 16, 8, 8, 4, 4, 2, 2]
# Epoch 1/100
# 20/20 - 30s - loss: 0.0038 - val_loss: 0.1447 - 30s/epoch - 2s/step
# Epoch 2/100
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1499 - 456ms/epoch - 23ms/step
# Epoch 3/100
# 20/20 - 0s - loss: 0.0015 - val_loss: 0.1505 - 429ms/epoch - 21ms/step
# Epoch 4/100
# 20/20 - 0s - loss: 0.0015 - val_loss: 0.1490 - 423ms/epoch - 21ms/step
# Epoch 5/100
# 20/20 - 0s - loss: 0.0015 - val_loss: 0.1490 - 418ms/epoch - 21ms/step
# Epoch 6/100
# 20/20 - 0s - loss: 0.0015 - val_loss: 0.1480 - 419ms/epoch - 21ms/step
# Epoch 7/100
# 20/20 - 0s - loss: 0.0015 - val_loss: 0.1468 - 410ms/epoch - 21ms/step
# Epoch 8/100
# 20/20 - 0s - loss: 0.0015 - val_loss: 0.1443 - 420ms/epoch - 21ms/step
# Epoch 9/100
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1395 - 436ms/epoch - 22ms/step
# Epoch 10/100
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1307 - 415ms/epoch - 21ms/step
# Epoch 11/100
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.1176 - 413ms/epoch - 21ms/step
# Epoch 12/100
# 20/20 - 0s - loss: 7.9215e-04 - val_loss: 0.1136 - 412ms/epoch - 21ms/step
# Epoch 13/100
# 20/20 - 0s - loss: 7.4825e-04 - val_loss: 0.1212 - 410ms/epoch - 21ms/step
# Epoch 14/100
# 20/20 - 0s - loss: 8.0156e-04 - val_loss: 0.1205 - 412ms/epoch - 21ms/step
# Epoch 15/100
# 20/20 - 0s - loss: 7.3812e-04 - val_loss: 0.1191 - 412ms/epoch - 21ms/step
# Epoch 16/100
# 20/20 - 0s - loss: 6.7968e-04 - val_loss: 0.1207 - 410ms/epoch - 20ms/step
# Epoch 17/100
# 20/20 - 0s - loss: 6.6976e-04 - val_loss: 0.1215 - 411ms/epoch - 21ms/step
# Epoch 18/100
# 20/20 - 0s - loss: 6.6885e-04 - val_loss: 0.1220 - 411ms/epoch - 21ms/step
# Epoch 19/100
# 20/20 - 0s - loss: 6.5889e-04 - val_loss: 0.1218 - 413ms/epoch - 21ms/step
# Epoch 20/100
# 20/20 - 0s - loss: 6.4445e-04 - val_loss: 0.1217 - 411ms/epoch - 21ms/step
# Epoch 21/100
# 20/20 - 0s - loss: 6.3185e-04 - val_loss: 0.1216 - 411ms/epoch - 21ms/step
# Epoch 22/100
# 20/20 - 0s - loss: 6.2643e-04 - val_loss: 0.1219 - 431ms/epoch - 22ms/step
# 20/20 [==============================] - 5s 5ms/step
# 9/9 [==============================] - 0s 5ms/step
# Train Score: 179.24 RMSE for 100 epochs
# Test Score: 2537.76 RMSE for 100 epochs
# Training with LSTM layers: [8, 8, 4, 4, 2, 2]
# Epoch 1/100
# 20/20 - 23s - loss: 0.0038 - val_loss: 0.1443 - 23s/epoch - 1s/step
# Epoch 2/100
# 20/20 - 0s - loss: 0.0015 - val_loss: 0.1434 - 328ms/epoch - 16ms/step
# Epoch 3/100
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1465 - 325ms/epoch - 16ms/step
# Epoch 4/100
# 20/20 - 0s - loss: 0.0015 - val_loss: 0.1437 - 320ms/epoch - 16ms/step
# Epoch 5/100
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1428 - 320ms/epoch - 16ms/step
# Epoch 6/100
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1411 - 321ms/epoch - 16ms/step
# Epoch 7/100
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1387 - 320ms/epoch - 16ms/step
# Epoch 8/100
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1355 - 319ms/epoch - 16ms/step
# Epoch 9/100
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1308 - 319ms/epoch - 16ms/step
# Epoch 10/100
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1245 - 318ms/epoch - 16ms/step
# Epoch 11/100
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1159 - 319ms/epoch - 16ms/step
# Epoch 12/100
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.1054 - 323ms/epoch - 16ms/step
# Epoch 13/100
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.0945 - 322ms/epoch - 16ms/step
# Epoch 14/100
# 20/20 - 0s - loss: 8.4947e-04 - val_loss: 0.0861 - 316ms/epoch - 16ms/step
# Epoch 15/100
# 20/20 - 0s - loss: 6.8819e-04 - val_loss: 0.0829 - 318ms/epoch - 16ms/step
# Epoch 16/100
# 20/20 - 0s - loss: 6.5792e-04 - val_loss: 0.0854 - 320ms/epoch - 16ms/step
# Epoch 17/100
# 20/20 - 0s - loss: 6.5143e-04 - val_loss: 0.0879 - 321ms/epoch - 16ms/step
# Epoch 18/100
# 20/20 - 0s - loss: 6.7010e-04 - val_loss: 0.0890 - 317ms/epoch - 16ms/step
# Epoch 19/100
# 20/20 - 0s - loss: 6.6898e-04 - val_loss: 0.0891 - 319ms/epoch - 16ms/step
# Epoch 20/100
# 20/20 - 0s - loss: 6.4195e-04 - val_loss: 0.0898 - 319ms/epoch - 16ms/step
# Epoch 21/100
# 20/20 - 0s - loss: 6.2780e-04 - val_loss: 0.0906 - 321ms/epoch - 16ms/step
# Epoch 22/100
# 20/20 - 0s - loss: 6.1753e-04 - val_loss: 0.0914 - 318ms/epoch - 16ms/step
# Epoch 23/100
# 20/20 - 0s - loss: 6.3111e-04 - val_loss: 0.0925 - 318ms/epoch - 16ms/step
# Epoch 24/100
# 20/20 - 0s - loss: 6.2466e-04 - val_loss: 0.0933 - 320ms/epoch - 16ms/step
# Epoch 25/100
# 20/20 - 0s - loss: 6.3816e-04 - val_loss: 0.0947 - 314ms/epoch - 16ms/step
# 20/20 [==============================] - 4s 4ms/step
# 9/9 [==============================] - 0s 4ms/step
# Train Score: 178.45 RMSE for 100 epochs
# Test Score: 2237.04 RMSE for 100 epochs
# Training with LSTM layers: [4, 4, 2, 2]
# Epoch 1/100
# 20/20 - 16s - loss: 0.0037 - val_loss: 0.1401 - 16s/epoch - 820ms/step
# Epoch 2/100
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1367 - 239ms/epoch - 12ms/step
# Epoch 3/100
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1383 - 261ms/epoch - 13ms/step
# Epoch 4/100
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1333 - 233ms/epoch - 12ms/step
# Epoch 5/100
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1301 - 234ms/epoch - 12ms/step
# Epoch 6/100
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1257 - 233ms/epoch - 12ms/step
# Epoch 7/100
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1203 - 232ms/epoch - 12ms/step
# Epoch 8/100
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.1136 - 232ms/epoch - 12ms/step
# Epoch 9/100
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.1053 - 231ms/epoch - 12ms/step
# Epoch 10/100
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.0958 - 230ms/epoch - 12ms/step
# Epoch 11/100
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.0843 - 231ms/epoch - 12ms/step
# Epoch 12/100
# 20/20 - 0s - loss: 0.0010 - val_loss: 0.0709 - 230ms/epoch - 12ms/step
# Epoch 13/100
# 20/20 - 0s - loss: 9.6591e-04 - val_loss: 0.0571 - 229ms/epoch - 11ms/step
# Epoch 14/100
# 20/20 - 0s - loss: 8.8240e-04 - val_loss: 0.0455 - 229ms/epoch - 11ms/step
# Epoch 15/100
# 20/20 - 0s - loss: 7.9981e-04 - val_loss: 0.0353 - 235ms/epoch - 12ms/step
# Epoch 16/100
# 20/20 - 0s - loss: 7.4286e-04 - val_loss: 0.0289 - 231ms/epoch - 12ms/step
# Epoch 17/100
# 20/20 - 0s - loss: 7.1063e-04 - val_loss: 0.0274 - 230ms/epoch - 11ms/step
# Epoch 18/100
# 20/20 - 0s - loss: 7.2475e-04 - val_loss: 0.0281 - 231ms/epoch - 12ms/step
# Epoch 19/100
# 20/20 - 0s - loss: 7.0699e-04 - val_loss: 0.0289 - 230ms/epoch - 11ms/step
# Epoch 20/100
# 20/20 - 0s - loss: 7.0954e-04 - val_loss: 0.0290 - 236ms/epoch - 12ms/step
# Epoch 21/100
# 20/20 - 0s - loss: 7.2917e-04 - val_loss: 0.0290 - 234ms/epoch - 12ms/step
# Epoch 22/100
# 20/20 - 0s - loss: 6.8263e-04 - val_loss: 0.0293 - 229ms/epoch - 11ms/step
# Epoch 23/100
# 20/20 - 0s - loss: 6.6893e-04 - val_loss: 0.0300 - 229ms/epoch - 11ms/step
# Epoch 24/100
# 20/20 - 0s - loss: 6.6750e-04 - val_loss: 0.0306 - 234ms/epoch - 12ms/step
# Epoch 25/100
# 20/20 - 0s - loss: 6.7391e-04 - val_loss: 0.0320 - 233ms/epoch - 12ms/step
# Epoch 26/100
# 20/20 - 0s - loss: 6.6698e-04 - val_loss: 0.0333 - 231ms/epoch - 12ms/step
# Epoch 27/100
# 20/20 - 0s - loss: 6.9310e-04 - val_loss: 0.0341 - 237ms/epoch - 12ms/step
# 20/20 [==============================] - 3s 3ms/step
# 9/9 [==============================] - 0s 3ms/step
# Train Score: 182.18 RMSE for 100 epochs
# Test Score: 1342.52 RMSE for 100 epochs
# Training with LSTM layers: [2, 2]
# Epoch 1/100
# 20/20 - 9s - loss: 0.0075 - val_loss: 0.2785 - 9s/epoch - 444ms/step
# Epoch 2/100
# 20/20 - 0s - loss: 0.0028 - val_loss: 0.2537 - 145ms/epoch - 7ms/step
# Epoch 3/100
# 20/20 - 0s - loss: 0.0018 - val_loss: 0.2445 - 141ms/epoch - 7ms/step
# Epoch 4/100
# 20/20 - 0s - loss: 0.0017 - val_loss: 0.2414 - 151ms/epoch - 8ms/step
# Epoch 5/100
# 20/20 - 0s - loss: 0.0016 - val_loss: 0.2383 - 142ms/epoch - 7ms/step
# Epoch 6/100
# 20/20 - 0s - loss: 0.0016 - val_loss: 0.2345 - 140ms/epoch - 7ms/step
# Epoch 7/100
# 20/20 - 0s - loss: 0.0016 - val_loss: 0.2305 - 142ms/epoch - 7ms/step
# Epoch 8/100
# 20/20 - 0s - loss: 0.0016 - val_loss: 0.2265 - 142ms/epoch - 7ms/step
# Epoch 9/100
# 20/20 - 0s - loss: 0.0015 - val_loss: 0.2226 - 143ms/epoch - 7ms/step
# Epoch 10/100
# 20/20 - 0s - loss: 0.0015 - val_loss: 0.2187 - 141ms/epoch - 7ms/step
# Epoch 11/100
# 20/20 - 0s - loss: 0.0015 - val_loss: 0.2147 - 141ms/epoch - 7ms/step
# Epoch 12/100
# 20/20 - 0s - loss: 0.0015 - val_loss: 0.2109 - 140ms/epoch - 7ms/step
# Epoch 13/100
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.2069 - 140ms/epoch - 7ms/step
# Epoch 14/100
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.2031 - 139ms/epoch - 7ms/step
# Epoch 15/100
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1992 - 138ms/epoch - 7ms/step
# Epoch 16/100
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1954 - 141ms/epoch - 7ms/step
# Epoch 17/100
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1914 - 140ms/epoch - 7ms/step
# Epoch 18/100
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1873 - 141ms/epoch - 7ms/step
# Epoch 19/100
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1831 - 140ms/epoch - 7ms/step
# Epoch 20/100
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1791 - 140ms/epoch - 7ms/step
# Epoch 21/100
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.1748 - 140ms/epoch - 7ms/step
# Epoch 22/100
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.1702 - 140ms/epoch - 7ms/step
# Epoch 23/100
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.1657 - 139ms/epoch - 7ms/step
# Epoch 24/100
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.1609 - 140ms/epoch - 7ms/step
# Epoch 25/100
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.1562 - 140ms/epoch - 7ms/step
# Epoch 26/100
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.1516 - 145ms/epoch - 7ms/step
# Epoch 27/100
# 20/20 - 0s - loss: 0.0010 - val_loss: 0.1466 - 142ms/epoch - 7ms/step
# Epoch 28/100
# 20/20 - 0s - loss: 0.0010 - val_loss: 0.1411 - 138ms/epoch - 7ms/step
# Epoch 29/100
# 20/20 - 0s - loss: 9.9603e-04 - val_loss: 0.1360 - 138ms/epoch - 7ms/step
# Epoch 30/100
# 20/20 - 0s - loss: 9.4408e-04 - val_loss: 0.1302 - 138ms/epoch - 7ms/step
# Epoch 31/100
# 20/20 - 0s - loss: 8.9927e-04 - val_loss: 0.1245 - 138ms/epoch - 7ms/step
# Epoch 32/100
# 20/20 - 0s - loss: 8.8788e-04 - val_loss: 0.1187 - 139ms/epoch - 7ms/step
# Epoch 33/100
# 20/20 - 0s - loss: 8.5007e-04 - val_loss: 0.1134 - 140ms/epoch - 7ms/step
# Epoch 34/100
# 20/20 - 0s - loss: 8.2280e-04 - val_loss: 0.1078 - 138ms/epoch - 7ms/step
# Epoch 35/100
# 20/20 - 0s - loss: 7.7849e-04 - val_loss: 0.1022 - 140ms/epoch - 7ms/step
# Epoch 36/100
# 20/20 - 0s - loss: 7.5235e-04 - val_loss: 0.0964 - 139ms/epoch - 7ms/step
# Epoch 37/100
# 20/20 - 0s - loss: 7.6448e-04 - val_loss: 0.0919 - 139ms/epoch - 7ms/step
# Epoch 38/100
# 20/20 - 0s - loss: 7.0326e-04 - val_loss: 0.0858 - 146ms/epoch - 7ms/step
# Epoch 39/100
# 20/20 - 0s - loss: 6.9969e-04 - val_loss: 0.0825 - 155ms/epoch - 8ms/step
# Epoch 40/100
# 20/20 - 0s - loss: 7.0112e-04 - val_loss: 0.0777 - 139ms/epoch - 7ms/step
# Epoch 41/100
# 20/20 - 0s - loss: 6.8461e-04 - val_loss: 0.0746 - 140ms/epoch - 7ms/step
# Epoch 42/100
# 20/20 - 0s - loss: 6.2744e-04 - val_loss: 0.0715 - 140ms/epoch - 7ms/step
# Epoch 43/100
# 20/20 - 0s - loss: 6.4727e-04 - val_loss: 0.0685 - 139ms/epoch - 7ms/step
# Epoch 44/100
# 20/20 - 0s - loss: 6.3811e-04 - val_loss: 0.0671 - 139ms/epoch - 7ms/step
# Epoch 45/100
# 20/20 - 0s - loss: 6.6485e-04 - val_loss: 0.0655 - 140ms/epoch - 7ms/step
# Epoch 46/100
# 20/20 - 0s - loss: 6.1781e-04 - val_loss: 0.0643 - 148ms/epoch - 7ms/step
# Epoch 47/100
# 20/20 - 0s - loss: 5.9357e-04 - val_loss: 0.0638 - 140ms/epoch - 7ms/step
# Epoch 48/100
# 20/20 - 0s - loss: 6.5226e-04 - val_loss: 0.0627 - 140ms/epoch - 7ms/step
# Epoch 49/100
# 20/20 - 0s - loss: 6.2228e-04 - val_loss: 0.0622 - 140ms/epoch - 7ms/step
# Epoch 50/100
# 20/20 - 0s - loss: 6.2782e-04 - val_loss: 0.0617 - 140ms/epoch - 7ms/step
# Epoch 51/100
# 20/20 - 0s - loss: 6.1972e-04 - val_loss: 0.0608 - 139ms/epoch - 7ms/step
# Epoch 52/100
# 20/20 - 0s - loss: 6.1698e-04 - val_loss: 0.0602 - 139ms/epoch - 7ms/step
# Epoch 53/100
# 20/20 - 0s - loss: 6.2319e-04 - val_loss: 0.0603 - 140ms/epoch - 7ms/step
# Epoch 54/100
# 20/20 - 0s - loss: 5.8458e-04 - val_loss: 0.0603 - 140ms/epoch - 7ms/step
# Epoch 55/100
# 20/20 - 0s - loss: 5.8720e-04 - val_loss: 0.0602 - 141ms/epoch - 7ms/step
# Epoch 56/100
# 20/20 - 0s - loss: 5.8583e-04 - val_loss: 0.0602 - 139ms/epoch - 7ms/step
# Epoch 57/100
# 20/20 - 0s - loss: 5.8928e-04 - val_loss: 0.0605 - 140ms/epoch - 7ms/step
# Epoch 58/100
# 20/20 - 0s - loss: 6.0037e-04 - val_loss: 0.0606 - 139ms/epoch - 7ms/step
# Epoch 59/100
# 20/20 - 0s - loss: 6.1760e-04 - val_loss: 0.0604 - 140ms/epoch - 7ms/step
# Epoch 60/100
# 20/20 - 0s - loss: 5.8180e-04 - val_loss: 0.0613 - 141ms/epoch - 7ms/step
# Epoch 61/100
# 20/20 - 0s - loss: 6.1099e-04 - val_loss: 0.0611 - 139ms/epoch - 7ms/step
# Epoch 62/100
# 20/20 - 0s - loss: 6.1254e-04 - val_loss: 0.0611 - 143ms/epoch - 7ms/step
# Epoch 63/100
# 20/20 - 0s - loss: 5.6883e-04 - val_loss: 0.0607 - 140ms/epoch - 7ms/step
# Epoch 64/100
# 20/20 - 0s - loss: 6.1826e-04 - val_loss: 0.0611 - 141ms/epoch - 7ms/step
# Epoch 65/100
# 20/20 - 0s - loss: 5.9417e-04 - val_loss: 0.0609 - 141ms/epoch - 7ms/step
# 20/20 [==============================] - 1s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# Train Score: 171.68 RMSE for 100 epochs
# Test Score: 1794.06 RMSE for 100 epochs
# Training for 150 epochs...
# Training with LSTM layers: [64, 64, 32, 32, 16, 16, 8, 8, 4, 4, 2, 2]
# Epoch 1/150
# 20/20 - 46s - loss: 0.0037 - val_loss: 0.1418 - 46s/epoch - 2s/step
# Epoch 2/150
# 20/20 - 1s - loss: 0.0013 - val_loss: 0.1534 - 735ms/epoch - 37ms/step
# Epoch 3/150
# 20/20 - 1s - loss: 0.0016 - val_loss: 0.1496 - 737ms/epoch - 37ms/step
# Epoch 4/150
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1506 - 718ms/epoch - 36ms/step
# Epoch 5/150
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1504 - 719ms/epoch - 36ms/step
# Epoch 6/150
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1504 - 691ms/epoch - 35ms/step
# Epoch 7/150
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1504 - 691ms/epoch - 35ms/step
# Epoch 8/150
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1504 - 690ms/epoch - 34ms/step
# Epoch 9/150
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1504 - 693ms/epoch - 35ms/step
# Epoch 10/150
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1504 - 698ms/epoch - 35ms/step
# Epoch 11/150
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1504 - 692ms/epoch - 35ms/step
# 20/20 [==============================] - 8s 9ms/step
# 9/9 [==============================] - 0s 9ms/step
# Train Score: 266.94 RMSE for 150 epochs
# Test Score: 2819.25 RMSE for 150 epochs
# Training with LSTM layers: [32, 32, 16, 16, 8, 8, 4, 4, 2, 2]
# Epoch 1/150
# 20/20 - 37s - loss: 0.0036 - val_loss: 0.1415 - 37s/epoch - 2s/step
# Epoch 2/150
# 20/20 - 1s - loss: 0.0014 - val_loss: 0.1524 - 559ms/epoch - 28ms/step
# Epoch 3/150
# 20/20 - 1s - loss: 0.0016 - val_loss: 0.1479 - 554ms/epoch - 28ms/step
# Epoch 4/150
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1492 - 563ms/epoch - 28ms/step
# Epoch 5/150
# 20/20 - 1s - loss: 0.0016 - val_loss: 0.1482 - 541ms/epoch - 27ms/step
# Epoch 6/150
# 20/20 - 1s - loss: 0.0016 - val_loss: 0.1477 - 551ms/epoch - 28ms/step
# Epoch 7/150
# 20/20 - 1s - loss: 0.0016 - val_loss: 0.1466 - 538ms/epoch - 27ms/step
# Epoch 8/150
# 20/20 - 1s - loss: 0.0016 - val_loss: 0.1447 - 531ms/epoch - 27ms/step
# Epoch 9/150
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1411 - 532ms/epoch - 27ms/step
# Epoch 10/150
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.1339 - 532ms/epoch - 27ms/step
# Epoch 11/150
# 20/20 - 1s - loss: 0.0013 - val_loss: 0.1228 - 532ms/epoch - 27ms/step
# Epoch 12/150
# 20/20 - 1s - loss: 0.0010 - val_loss: 0.1254 - 533ms/epoch - 27ms/step
# Epoch 13/150
# 20/20 - 1s - loss: 0.0011 - val_loss: 0.1216 - 531ms/epoch - 27ms/step
# Epoch 14/150
# 20/20 - 1s - loss: 8.4500e-04 - val_loss: 0.1236 - 537ms/epoch - 27ms/step
# Epoch 15/150
# 20/20 - 1s - loss: 7.5905e-04 - val_loss: 0.1226 - 556ms/epoch - 28ms/step
# Epoch 16/150
# 20/20 - 1s - loss: 7.0448e-04 - val_loss: 0.1247 - 542ms/epoch - 27ms/step
# Epoch 17/150
# 20/20 - 1s - loss: 7.0122e-04 - val_loss: 0.1242 - 543ms/epoch - 27ms/step
# Epoch 18/150
# 20/20 - 1s - loss: 6.9150e-04 - val_loss: 0.1249 - 568ms/epoch - 28ms/step
# Epoch 19/150
# 20/20 - 1s - loss: 6.8175e-04 - val_loss: 0.1238 - 573ms/epoch - 29ms/step
# Epoch 20/150
# 20/20 - 1s - loss: 6.6360e-04 - val_loss: 0.1242 - 568ms/epoch - 28ms/step
# Epoch 21/150
# 20/20 - 1s - loss: 6.5571e-04 - val_loss: 0.1237 - 578ms/epoch - 29ms/step
# Epoch 22/150
# 20/20 - 1s - loss: 6.4791e-04 - val_loss: 0.1241 - 585ms/epoch - 29ms/step
# Epoch 23/150
# 20/20 - 1s - loss: 6.5166e-04 - val_loss: 0.1236 - 616ms/epoch - 31ms/step
# 20/20 [==============================] - 7s 7ms/step
# 9/9 [==============================] - 0s 7ms/step
# Train Score: 181.17 RMSE for 150 epochs
# Test Score: 2556.19 RMSE for 150 epochs
# Training with LSTM layers: [16, 16, 8, 8, 4, 4, 2, 2]
# Epoch 1/150
# 20/20 - 29s - loss: 0.0037 - val_loss: 0.1413 - 29s/epoch - 1s/step
# Epoch 2/150
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1512 - 461ms/epoch - 23ms/step
# Epoch 3/150
# 20/20 - 0s - loss: 0.0016 - val_loss: 0.1491 - 430ms/epoch - 22ms/step
# Epoch 4/150
# 20/20 - 0s - loss: 0.0015 - val_loss: 0.1485 - 433ms/epoch - 22ms/step
# Epoch 5/150
# 20/20 - 0s - loss: 0.0015 - val_loss: 0.1481 - 434ms/epoch - 22ms/step
# Epoch 6/150
# 20/20 - 0s - loss: 0.0015 - val_loss: 0.1469 - 447ms/epoch - 22ms/step
# Epoch 7/150
# 20/20 - 0s - loss: 0.0015 - val_loss: 0.1452 - 439ms/epoch - 22ms/step
# Epoch 8/150
# 20/20 - 0s - loss: 0.0015 - val_loss: 0.1419 - 423ms/epoch - 21ms/step
# Epoch 9/150
# 20/20 - 0s - loss: 0.0015 - val_loss: 0.1356 - 422ms/epoch - 21ms/step
# Epoch 10/150
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1236 - 416ms/epoch - 21ms/step
# Epoch 11/150
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.1066 - 435ms/epoch - 22ms/step
# Epoch 12/150
# 20/20 - 0s - loss: 8.3461e-04 - val_loss: 0.1038 - 425ms/epoch - 21ms/step
# Epoch 13/150
# 20/20 - 0s - loss: 7.6890e-04 - val_loss: 0.1114 - 419ms/epoch - 21ms/step
# Epoch 14/150
# 20/20 - 0s - loss: 8.1070e-04 - val_loss: 0.1108 - 422ms/epoch - 21ms/step
# Epoch 15/150
# 20/20 - 0s - loss: 7.5166e-04 - val_loss: 0.1101 - 416ms/epoch - 21ms/step
# Epoch 16/150
# 20/20 - 0s - loss: 6.9515e-04 - val_loss: 0.1119 - 423ms/epoch - 21ms/step
# Epoch 17/150
# 20/20 - 0s - loss: 6.7408e-04 - val_loss: 0.1128 - 417ms/epoch - 21ms/step
# Epoch 18/150
# 20/20 - 0s - loss: 6.6532e-04 - val_loss: 0.1134 - 417ms/epoch - 21ms/step
# Epoch 19/150
# 20/20 - 0s - loss: 6.6006e-04 - val_loss: 0.1141 - 412ms/epoch - 21ms/step
# Epoch 20/150
# 20/20 - 0s - loss: 6.5312e-04 - val_loss: 0.1144 - 417ms/epoch - 21ms/step
# Epoch 21/150
# 20/20 - 0s - loss: 6.3338e-04 - val_loss: 0.1140 - 420ms/epoch - 21ms/step
# Epoch 22/150
# 20/20 - 0s - loss: 6.2380e-04 - val_loss: 0.1142 - 465ms/epoch - 23ms/step
# 20/20 [==============================] - 7s 6ms/step
# 9/9 [==============================] - 0s 6ms/step
# Train Score: 179.70 RMSE for 150 epochs
# Test Score: 2457.29 RMSE for 150 epochs
# Training with LSTM layers: [8, 8, 4, 4, 2, 2]
# Epoch 1/150
# 20/20 - 24s - loss: 0.0039 - val_loss: 0.1433 - 24s/epoch - 1s/step
# Epoch 2/150
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1420 - 385ms/epoch - 19ms/step
# Epoch 3/150
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1450 - 393ms/epoch - 20ms/step
# Epoch 4/150
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1417 - 393ms/epoch - 20ms/step
# Epoch 5/150
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1406 - 393ms/epoch - 20ms/step
# Epoch 6/150
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1381 - 370ms/epoch - 18ms/step
# Epoch 7/150
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1350 - 348ms/epoch - 17ms/step
# Epoch 8/150
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1306 - 342ms/epoch - 17ms/step
# Epoch 9/150
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1247 - 343ms/epoch - 17ms/step
# Epoch 10/150
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.1164 - 343ms/epoch - 17ms/step
# Epoch 11/150
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.1057 - 332ms/epoch - 17ms/step
# Epoch 12/150
# 20/20 - 0s - loss: 9.1826e-04 - val_loss: 0.0938 - 324ms/epoch - 16ms/step
# Epoch 13/150
# 20/20 - 0s - loss: 7.5182e-04 - val_loss: 0.0850 - 333ms/epoch - 17ms/step
# Epoch 14/150
# 20/20 - 0s - loss: 7.0075e-04 - val_loss: 0.0843 - 324ms/epoch - 16ms/step
# Epoch 15/150
# 20/20 - 0s - loss: 6.8066e-04 - val_loss: 0.0883 - 329ms/epoch - 16ms/step
# Epoch 16/150
# 20/20 - 0s - loss: 6.7590e-04 - val_loss: 0.0916 - 327ms/epoch - 16ms/step
# Epoch 17/150
# 20/20 - 0s - loss: 6.9209e-04 - val_loss: 0.0937 - 332ms/epoch - 17ms/step
# Epoch 18/150
# 20/20 - 0s - loss: 6.8046e-04 - val_loss: 0.0946 - 325ms/epoch - 16ms/step
# Epoch 19/150
# 20/20 - 0s - loss: 6.6378e-04 - val_loss: 0.0953 - 326ms/epoch - 16ms/step
# Epoch 20/150
# 20/20 - 0s - loss: 6.6607e-04 - val_loss: 0.0966 - 324ms/epoch - 16ms/step
# Epoch 21/150
# 20/20 - 0s - loss: 6.4678e-04 - val_loss: 0.0981 - 324ms/epoch - 16ms/step
# Epoch 22/150
# 20/20 - 0s - loss: 6.5687e-04 - val_loss: 0.0995 - 336ms/epoch - 17ms/step
# Epoch 23/150
# 20/20 - 0s - loss: 6.4312e-04 - val_loss: 0.1004 - 321ms/epoch - 16ms/step
# Epoch 24/150
# 20/20 - 0s - loss: 6.4521e-04 - val_loss: 0.1018 - 334ms/epoch - 17ms/step
# 20/20 [==============================] - 4s 4ms/step
# 9/9 [==============================] - 0s 4ms/step
# Train Score: 180.90 RMSE for 150 epochs
# Test Score: 2319.84 RMSE for 150 epochs
# Training with LSTM layers: [4, 4, 2, 2]
# Epoch 1/150
# 20/20 - 16s - loss: 0.0052 - val_loss: 0.1663 - 16s/epoch - 819ms/step
# Epoch 2/150
# 20/20 - 0s - loss: 0.0022 - val_loss: 0.1462 - 252ms/epoch - 13ms/step
# Epoch 3/150
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.1400 - 255ms/epoch - 13ms/step
# Epoch 4/150
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1408 - 249ms/epoch - 12ms/step
# Epoch 5/150
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1397 - 268ms/epoch - 13ms/step
# Epoch 6/150
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1376 - 249ms/epoch - 12ms/step
# Epoch 7/150
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1356 - 241ms/epoch - 12ms/step
# Epoch 8/150
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1336 - 259ms/epoch - 13ms/step
# Epoch 9/150
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1313 - 245ms/epoch - 12ms/step
# Epoch 10/150
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1284 - 234ms/epoch - 12ms/step
# Epoch 11/150
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1253 - 239ms/epoch - 12ms/step
# Epoch 12/150
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.1218 - 251ms/epoch - 13ms/step
# Epoch 13/150
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.1172 - 248ms/epoch - 12ms/step
# Epoch 14/150
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.1121 - 242ms/epoch - 12ms/step
# Epoch 15/150
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.1059 - 244ms/epoch - 12ms/step
# Epoch 16/150
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.0985 - 268ms/epoch - 13ms/step
# Epoch 17/150
# 20/20 - 0s - loss: 0.0010 - val_loss: 0.0896 - 249ms/epoch - 12ms/step
# Epoch 18/150
# 20/20 - 0s - loss: 9.3616e-04 - val_loss: 0.0798 - 248ms/epoch - 12ms/step
# Epoch 19/150
# 20/20 - 0s - loss: 8.4506e-04 - val_loss: 0.0695 - 243ms/epoch - 12ms/step
# Epoch 20/150
# 20/20 - 0s - loss: 7.3003e-04 - val_loss: 0.0612 - 246ms/epoch - 12ms/step
# Epoch 21/150
# 20/20 - 0s - loss: 7.1115e-04 - val_loss: 0.0576 - 246ms/epoch - 12ms/step
# Epoch 22/150
# 20/20 - 0s - loss: 6.9974e-04 - val_loss: 0.0577 - 246ms/epoch - 12ms/step
# Epoch 23/150
# 20/20 - 0s - loss: 6.2018e-04 - val_loss: 0.0583 - 244ms/epoch - 12ms/step
# Epoch 24/150
# 20/20 - 0s - loss: 6.6682e-04 - val_loss: 0.0593 - 246ms/epoch - 12ms/step
# Epoch 25/150
# 20/20 - 0s - loss: 6.6708e-04 - val_loss: 0.0605 - 242ms/epoch - 12ms/step
# Epoch 26/150
# 20/20 - 0s - loss: 6.8443e-04 - val_loss: 0.0612 - 263ms/epoch - 13ms/step
# Epoch 27/150
# 20/20 - 0s - loss: 6.2744e-04 - val_loss: 0.0611 - 263ms/epoch - 13ms/step
# Epoch 28/150
# 20/20 - 0s - loss: 6.3812e-04 - val_loss: 0.0615 - 257ms/epoch - 13ms/step
# Epoch 29/150
# 20/20 - 0s - loss: 6.1152e-04 - val_loss: 0.0622 - 254ms/epoch - 13ms/step
# Epoch 30/150
# 20/20 - 0s - loss: 6.4268e-04 - val_loss: 0.0634 - 233ms/epoch - 12ms/step
# Epoch 31/150
# 20/20 - 0s - loss: 6.0904e-04 - val_loss: 0.0636 - 237ms/epoch - 12ms/step
# 20/20 [==============================] - 3s 3ms/step
# 9/9 [==============================] - 0s 3ms/step
# Train Score: 175.37 RMSE for 150 epochs
# Test Score: 1834.09 RMSE for 150 epochs
# Training with LSTM layers: [2, 2]
# Epoch 1/150
# 20/20 - 8s - loss: 0.0039 - val_loss: 0.1138 - 8s/epoch - 407ms/step
# Epoch 2/150
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.0965 - 152ms/epoch - 8ms/step
# Epoch 3/150
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.0948 - 152ms/epoch - 8ms/step
# Epoch 4/150
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.0895 - 149ms/epoch - 7ms/step
# Epoch 5/150
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.0829 - 147ms/epoch - 7ms/step
# Epoch 6/150
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.0766 - 146ms/epoch - 7ms/step
# Epoch 7/150
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.0711 - 141ms/epoch - 7ms/step
# Epoch 8/150
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.0658 - 140ms/epoch - 7ms/step
# Epoch 9/150
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.0607 - 140ms/epoch - 7ms/step
# Epoch 10/150
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.0559 - 141ms/epoch - 7ms/step
# Epoch 11/150
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.0514 - 139ms/epoch - 7ms/step
# Epoch 12/150
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.0473 - 150ms/epoch - 8ms/step
# Epoch 13/150
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.0436 - 173ms/epoch - 9ms/step
# Epoch 14/150
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.0400 - 154ms/epoch - 8ms/step
# Epoch 15/150
# 20/20 - 0s - loss: 0.0010 - val_loss: 0.0370 - 156ms/epoch - 8ms/step
# Epoch 16/150
# 20/20 - 0s - loss: 0.0010 - val_loss: 0.0344 - 155ms/epoch - 8ms/step
# Epoch 17/150
# 20/20 - 0s - loss: 0.0010 - val_loss: 0.0321 - 144ms/epoch - 7ms/step
# Epoch 18/150
# 20/20 - 0s - loss: 0.0010 - val_loss: 0.0305 - 143ms/epoch - 7ms/step
# Epoch 19/150
# 20/20 - 0s - loss: 9.9499e-04 - val_loss: 0.0293 - 146ms/epoch - 7ms/step
# Epoch 20/150
# 20/20 - 0s - loss: 9.3232e-04 - val_loss: 0.0285 - 178ms/epoch - 9ms/step
# Epoch 21/150
# 20/20 - 0s - loss: 9.4345e-04 - val_loss: 0.0281 - 167ms/epoch - 8ms/step
# Epoch 22/150
# 20/20 - 0s - loss: 9.0770e-04 - val_loss: 0.0282 - 160ms/epoch - 8ms/step
# Epoch 23/150
# 20/20 - 0s - loss: 8.6818e-04 - val_loss: 0.0287 - 152ms/epoch - 8ms/step
# Epoch 24/150
# 20/20 - 0s - loss: 8.6435e-04 - val_loss: 0.0296 - 145ms/epoch - 7ms/step
# Epoch 25/150
# 20/20 - 0s - loss: 8.9354e-04 - val_loss: 0.0308 - 146ms/epoch - 7ms/step
# Epoch 26/150
# 20/20 - 0s - loss: 8.4474e-04 - val_loss: 0.0325 - 144ms/epoch - 7ms/step
# Epoch 27/150
# 20/20 - 0s - loss: 8.4240e-04 - val_loss: 0.0345 - 139ms/epoch - 7ms/step
# Epoch 28/150
# 20/20 - 0s - loss: 7.9088e-04 - val_loss: 0.0364 - 140ms/epoch - 7ms/step
# Epoch 29/150
# 20/20 - 0s - loss: 8.1660e-04 - val_loss: 0.0385 - 147ms/epoch - 7ms/step
# Epoch 30/150
# 20/20 - 0s - loss: 7.6543e-04 - val_loss: 0.0409 - 144ms/epoch - 7ms/step
# Epoch 31/150
# 20/20 - 0s - loss: 7.8906e-04 - val_loss: 0.0438 - 151ms/epoch - 8ms/step
# 20/20 [==============================] - 1s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# Train Score: 189.81 RMSE for 150 epochs
# Test Score: 1521.41 RMSE for 150 epochs
# Text(0.5, 1.0, 'Model loss progress during training and validation')
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'Training and Validation Loss')
#                                                     Train RMSE    Test RMSE
# 50 epochs, [64, 64, 32, 32, 16, 16, 8, 8, 4, 4,...  266.903720  2819.858453
# 50 epochs, [32, 32, 16, 16, 8, 8, 4, 4, 2, 2] l...  263.872652  2782.604394
# 50 epochs, [16, 16, 8, 8, 4, 4, 2, 2] layers        177.797560  2489.713819
# 50 epochs, [8, 8, 4, 4, 2, 2] layers                173.904710  2472.294853
# 50 epochs, [4, 4, 2, 2] layers                      170.666472  2233.980617
# 50 epochs, [2, 2] layers                            181.300240  2214.741775
# 100 epochs, [64, 64, 32, 32, 16, 16, 8, 8, 4, 4...  266.891964  2819.385938
# 100 epochs, [32, 32, 16, 16, 8, 8, 4, 4, 2, 2] ...  265.324215  2799.902965
# 100 epochs, [16, 16, 8, 8, 4, 4, 2, 2] layers       179.240423  2537.760912
# 100 epochs, [8, 8, 4, 4, 2, 2] layers               178.449878  2237.042679
# 100 epochs, [4, 4, 2, 2] layers                     182.180165  1342.523051
# 100 epochs, [2, 2] layers                           171.678088  1794.061244
# 150 epochs, [64, 64, 32, 32, 16, 16, 8, 8, 4, 4...  266.935392  2819.246694
# 150 epochs, [32, 32, 16, 16, 8, 8, 4, 4, 2, 2] ...  181.166676  2556.185791
# 150 epochs, [16, 16, 8, 8, 4, 4, 2, 2] layers       179.699007  2457.286849
# 150 epochs, [8, 8, 4, 4, 2, 2] layers               180.895744  2319.844842
# 150 epochs, [4, 4, 2, 2] layers                     175.372104  1834.094537
# 150 epochs, [2, 2] layers                           189.814972  1521.409931

# %% [markdown]
# <h4>Forecast the results</h4>

# %%
# Add check for 'RATE_actual' values to avoid division by zero
def compute_accuracy(row):
    if row['RATE_actual'] == 0:
        return np.nan
    else:
        error = abs(row['RATE_actual'] - row['RATE_forecasted'])
        error_proportion = error / row['RATE_actual']
        return (1 - error_proportion) * 100

def forecast_next_weeks(model, look_back, scaler, last_values, n_weeks):
    forecast = []
    for _ in range(n_weeks):
        last_values_2d = np.array(last_values[-look_back:]).reshape(-1, 1)
        input_values_scaled = scaler.transform(last_values_2d)
        input_values_scaled = input_values_scaled.reshape((1, look_back, 1))
        input_values_scaled = np.repeat(input_values_scaled, 2, axis=-1)
        input_values_scaled[..., 1] = 0

        prediction = model.predict(input_values_scaled)
        prediction = scaler.inverse_transform(prediction)
        forecast.append(prediction[0][0])
        last_values.append(prediction[0][0])

    return forecast

# %%
weeks = 12

# Ensure that 'YearMonthWeek' is a datetime object
agg_df['YearMonthWeek'] = pd.to_datetime(agg_df['YearMonthWeek'])
last_date = agg_df['YearMonthWeek'].iloc[-1]

last_values = list(agg_df['Rate'].values[-look_back:])
forecasted_values = forecast_next_weeks(model, look_back, scaler, last_values, weeks)
forecasted_dates = pd.date_range(start=last_date, periods=weeks+1, freq='W')[1:]

df_forecasted = pd.DataFrame({
    'POD': forecasted_dates,
    'RATE': forecasted_values
})

df_forecasted["RATE"] = df_forecasted["RATE"].round(2)

df_forecasted.head(5)
df_forecasted.tail(5)
df_forecasted.info()
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#          POD         RATE
# 0 2023-02-26  1164.670044
# 1 2023-03-05  1067.479980
# 2 2023-03-12   976.359985
# 3 2023-03-19   923.330017
# 4 2023-03-26   883.719971
#           POD        RATE
# 7  2023-04-16  767.369995
# 8  2023-04-23  741.119995
# 9  2023-04-30  718.270020
# 10 2023-05-07  697.989990
# 11 2023-05-14  680.719971
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POD     12 non-null     datetime64[ns]
#  1   RATE    12 non-null     float32
# dtypes: datetime64[ns](1), float32(1)
# memory usage: 272.0 bytes

# %% [markdown]
# <h4>Comparing with actual updated against forecasted</h4>

# %%
comparison_df = pd.DataFrame(columns=['WeekStart', 'WeekEnd', 'POD_actual', 'RATE_forecasted', 'RATE_actual'])
df_forecasted['WeekEnd'] = df_forecasted['POD'] + pd.to_timedelta(7, unit='d')  

for _, row in df_forecasted.iterrows():
    mask = (new_dates_df['POD'] >= row['POD']) & (new_dates_df['POD'] < row['WeekEnd'])
    actual_dates_within_week = new_dates_df[mask]

    for _, actual_row in actual_dates_within_week.iterrows():
        comparison_df = comparison_df.append({
            'WeekStart': row['POD'],
            'WeekEnd': row['WeekEnd'],
            'POD_actual': actual_row['POD'],
            'RATE_forecasted': row['RATE'],
            'RATE_actual': actual_row['RATE']
        }, ignore_index=True)

# Remove duplicates
comparison_df = comparison_df.drop_duplicates(subset=['POD_actual', 'RATE_forecasted', 'RATE_actual']).reset_index(drop=True)

# Compute accuracy
comparison_df['accuracy'] = comparison_df.apply(compute_accuracy, axis=1)
comparison_df = comparison_df.dropna(subset=['accuracy'])

total_mean_accuracy = comparison_df['accuracy'].mean()
comparison_df
print(f'The mean accuracy is {total_mean_accuracy:.2f}%\n')
# Out:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29232\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
#     WeekStart    WeekEnd POD_actual  RATE_forecasted  RATE_actual   accuracy
# 0  2023-02-26 2023-03-05 2023-03-02      1164.670044       1000.0  83.532996
# 1  2023-03-05 2023-03-12 2023-03-10      1067.479980       1000.0  93.252002
# 2  2023-03-12 2023-03-19 2023-03-16       976.359985       1000.0  97.635999
# 3  2023-03-19 2023-03-26 2023-03-21       923.330017        600.0  46.111664
# 4  2023-03-26 2023-04-02 2023-03-26       883.719971        600.0  52.713338
# 5  2023-03-26 2023-04-02 2023-03-31       883.719971        650.0  64.043081
# 6  2023-04-02 2023-04-09 2023-04-06       841.030029        650.0  70.610765
# 7  2023-04-09 2023-04-16 2023-04-13       800.330017        650.0  76.872305
# 8  2023-04-16 2023-04-23 2023-04-20       767.369995        650.0  81.943078
# 9  2023-04-23 2023-04-30 2023-04-28       741.119995        500.0  51.776001
# 10 2023-04-30 2023-05-07 2023-05-05       718.270020        500.0  56.345996
# 11 2023-05-07 2023-05-14 2023-05-11       697.989990        500.0  60.402002
# 12 2023-05-14 2023-05-21 2023-05-19       680.719971        400.0  29.820007
# The mean accuracy is 66.54%

# %% [markdown]
# <h4>Visualise all, Conclusion</h4>

# %%
plt.figure(figsize=(20, 10))
plt.plot(sel_df['POD'], sel_df['RATE'], color='blue', label="Actual Data")
plt.plot(new_dates_df['POD'], new_dates_df['RATE'], color='blue', label="Actual Data (Updated)")

plt.plot(df_interpolated['POD'], df_interpolated['RATE'], color='green', label="Aggregated Data")
plt.plot(df_forecasted['POD'], df_forecasted['RATE'], color='red', label="Forecasted Data")

plt.xlabel('Date(Year Month)')
plt.ylabel('Cost Rate(USD)')
plt.title('Port_BUSAN_Size_40_Type_HC_PartyID_010004286')
plt.legend()
plt.show();
