# %% [markdown]
# <h4>Split Train and Test on the same Dataset.</h4>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Dropout, LSTM, Dense
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from IPython.core.interactiveshell import InteractiveShell
from sklearn.preprocessing import MinMaxScaler
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline
sns.set()
pd.options.display.max_rows = 100

# %% [markdown]
# <h4>Importing Datasets</h4>

# %%
# Import dataset and clean, ready as a dataframe for creating keys
def createDF(datasets):
    df = pd.read_csv(datasets, converters={'PARTY_ID': str, 'COM_ID': str, 'CNTR_SIZE': str})

    # Formating to type and remove NaN values
    df['POD'] = pd.to_datetime(df['POD'])
    df['ENCODED_TYPE'] = df['ENCODED_TYPE'].fillna(-1).astype(int)
    df = df.dropna(subset=['ENCODED_TYPE'])
    df['RATE'] = df['RATE'].fillna(-1).astype(float)
    df = df.dropna(subset=['RATE'])
    df['ENCODED_TYPE'] = df['ENCODED_TYPE'].astype(int)
    df_clean= df.dropna().reset_index(drop=True)

    # Selecting and rearranging columns
    sel_col = ['CSL_ID', 'CNTR_ID','POD_ID','ETD_POL_D','PARTY_ID',
            'PARTY_NAME','POD','CNTR_SIZE','CNTR_TYPE','RATE']
    df_fc = df_clean[sel_col]

    # Removing years we do not want to process in our models
    df_filtered = df_fc[df_fc['POD'].dt.year != 2002]

    # Sorting the dates
    df_filtered = df_filtered.sort_values(by='POD').reset_index(drop=True)
    
    return df_filtered

# %%
# Create Dataframes for old and new
data = '.\Datasets\CR_COST_FC_new.csv'
df1 = createDF(data)
df1.head()
# Out:
#            CSL_ID           CNTR_ID          POD_ID ETD_POL_D  PARTY_ID  \
# 0  ECS01050600224  CTNR010050700354       ROTTERDAM     NLRTM  01008827
# 1  ECS01050600610  CTNR010050700353      FELIXSTOWE     GBFXT  01002303
# 2  ECS01050600041  CTNR010050700351        AUCKLAND     NZAKL  01005136
# 3  ECS01050600163  CTNR010050700370    PASIR GUDANG     MYPGU  01002767
# 4  ECS01050600456  CTNR010050700450  KARACHI (KICT)     PKKHI  01002783
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0             YANG MING (SINGAPORE) PTE. LTD. 2005-07-15        40    HC NOR
# 1                    GLOBELINK FALLOW LIMITED 2005-07-15        40        GP
# 2  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-15        40    HC NOR
# 3          GLOBELINK CONTAINER LINES (JB) S/B 2005-07-15        40        HC
# 4                GLOBELINK PAKISTAN (PVT) LTD 2005-07-16        40        HC
#
#      RATE
# 0  1620.0
# 1  1800.0
# 2  2170.0
# 3   280.0
# 4  1625.0

# %% [markdown]
# <h4>Creating Dictionary Keys</h4>

# %%
def filter_dataframe(df):
    filtered_dataframes = {}

    for (port, size, ctype, party_id), group in df.groupby(['POD_ID', 'CNTR_SIZE', 'CNTR_TYPE', 'PARTY_ID']):
        group = group.reset_index(drop=True).sort_values(by='POD')
        df_id = f"Port_{port}_Size_{size}_Type_{ctype}_PartyID_{party_id}"
        filtered_dataframes[df_id] = group

    return filtered_dataframes

# %%
# Creating keys from data
print("Data keys:")
filtered_dataframe1 = filter_dataframe(df1)
df_ids1 = list(filtered_dataframe1.keys())
print(list(df_ids1))
print(len(list(df_ids1)))
# Out:
# Data keys:
# ['Port_(CONSTANZA)_Size_40_Type_GP_PartyID_010007816', 'Port_(CONSTANZA)_Size_40_Type_HC_PartyID_010007816', 'Port_AARHUS_Size_20_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100027830', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100028193', 'Port_AARHUS_Size_20_Type_GP_PartyID_010006666', 'Port_AARHUS_Size_40_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100027830', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100028193', 'Port_AARHUS_Size_40_Type_HC_PartyID_010006666', 'Port_ABIDJAN_Size_20_Type_GP_PartyID_0100027878', 'Port_ABIDJAN_Size_40_Type_HC_PartyID_010021097', 'Port_ADELAIDE_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01005078', 'Port_ADELAIDE_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ALEXANDRIA (EL DEKHELA PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC NOR_PartyID_010004995', 'Port_ALGECIRAS_Size_20_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC NOR_PartyID_01008306', 'Port_ALIAGA_Size_20_Type_GP_PartyID_01008316', 'Port_ALIAGA_Size_40_Type_HC_PartyID_01008316', 'Port_ALIAGA PORT (IZMIR)_Size_40_Type_HC_PartyID_01008316', 'Port_ANTWERP_Size_20_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC NOR_PartyID_01001449', 'Port_AQABA_Size_20_Type_GP_PartyID_010006618', 'Port_AQABA_Size_20_Type_GP_PartyID_010021081', 'Port_AQABA_Size_40_Type_HC_PartyID_010006618', 'Port_AQABA_Size_40_Type_HC_PartyID_010021081', 'Port_ASHDOD_Size_20_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_01008417', 'Port_ASHDOD_Size_40_Type_HC_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_HC_PartyID_01008417', 'Port_AUCKLAND_Size_20_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_20_Type_GP (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC NOR_PartyID_01005136', 'Port_BANGKOK_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_20_Type_GP (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (SOC)_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK (TST)_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK (TST)_Size_40_Type_HC_PartyID_010021593', 'Port_BARCELONA_Size_20_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC NOR_PartyID_01008305', 'Port_BEIRUT_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_HC_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_20_Type_GP_PartyID_010003651', ' ...
# 799

# %% [markdown]
# <h4>Getting Top 5 ports keys</h4>

# %%
def getTop5Ports(keybunch):
    keybunch_pouch = []
    
    # Get a dictionary with key and number of rows for each dataframe in filtered_dataframes
    key_row_counts = {key: len(keybunch[key]) for key in keybunch}

    # Sort the key_row_counts dictionary by value (number of rows) in descending order
    sorted_key_row_counts = sorted(key_row_counts.items(), key=lambda item: item[1], reverse=True)

    # Get the top 5 keys with the most rows
    top_5_keys_tuple = sorted_key_row_counts[:5]

    # Create a dictionary with the top 5 keys and their corresponding dataframes (with up to 5 rows per dataframe)
    keybunch_subset = {}

    for key, row_count in top_5_keys_tuple:
        keybunch_subset[key] = keybunch[key][:5]
        print(f"Number of rows in {key}: {row_count}")
        keybunch_pouch.append(key)
    
    # Return array of keys
    return keybunch_pouch

# %%
print('Dataset Keybunch:')
key_df = getTop5Ports(filtered_dataframe1)
print('\n')
# Out:
# Dataset Keybunch:
# Number of rows in Port_BUSAN_Size_40_Type_HC_PartyID_010004286: 1712
# Number of rows in Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136: 1704
# Number of rows in Port_MELBOURNE_Size_40_Type_HC_PartyID_01002778: 1341
# Number of rows in Port_SYDNEY_Size_40_Type_HC_PartyID_01002779: 1308
# Number of rows in Port_DUBAI (JEBEL ALI)_Size_40_Type_HC_PartyID_01002788: 1070

# %%
# Accessing the highest count in the each keypouch, new and old.
sel_df = filtered_dataframe1[key_df[1]]
sel_df.head(5)
sel_df.tail(5)
sel_df.info()
print("\n")
# Out:
#             CSL_ID           CNTR_ID    POD_ID ETD_POL_D  PARTY_ID  \
# 0   ECS01050600140  CTNR010050700496  AUCKLAND     NZAKL  01005136
# 1   ECS01050600140  CTNR010050700495  AUCKLAND     NZAKL  01005136
# 2  ECS010050700037  CTNR010050700657  AUCKLAND     NZAKL  01005136
# 3   ECS01050600141  CTNR010050700808  AUCKLAND     NZAKL  01005136
# 4   ECS01050600042  CTNR010050700971  AUCKLAND     NZAKL  01005136
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-19        40        HC
# 1  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-19        40        HC
# 2  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-21        40        HC
# 3  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-26        40        HC
# 4  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-29        40        HC
#
#      RATE
# 0  2200.0
# 1  2200.0
# 2  2300.0
# 3  2200.0
# 4  2600.0
#                CSL_ID       CNTR_ID    POD_ID ETD_POL_D  PARTY_ID  \
# 1699  ECS010230200029  010000495920  AUCKLAND     NZAKL  01005136
# 1700  ECS010230400101  010000535699  AUCKLAND     NZAKL  01005136
# 1701  ECS010230300066  010000515298  AUCKLAND     NZAKL  01005136
# 1702  ECS010230300067  010000550266  AUCKLAND     NZAKL  01005136
# 1703  ECS010230300067  010000535541  AUCKLAND     NZAKL  01005136
#
#                                       PARTY_NAME        POD CNTR_SIZE  \
# 1699  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2023-04-23        40
# 1700  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2023-05-02        40
# 1701  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2023-05-02        40
# 1702  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2023-05-08        40
# 1703  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2023-05-08        40
#
#      CNTR_TYPE   RATE
# 1699        HC  664.0
# 1700        HC  350.0
# 1701        HC  264.0
# 1702        HC  264.0
# 1703        HC  264.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1704 entries, 0 to 1703
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      1704 non-null   object
#  1   CNTR_ID     1704 non-null   object
#  2   POD_ID      1704 non-null   object
#  3   ETD_POL_D   1704 non-null   object
#  4   PARTY_ID    1704 non-null   object
#  5   PARTY_NAME  1704 non-null   object
#  6   POD         1704 non-null   datetime64[ns]
#  7   CNTR_SIZE   1704 non-null   object
#  8   CNTR_TYPE   1704 non-null   object
#  9   RATE        1704 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 146.4+ KB

# %%
from sklearn.preprocessing import RobustScaler

# Select features
sel_feat = ['POD','RATE']
robust_df = sel_df[sel_feat].copy()  # make a copy to avoid SettingWithCopyWarning

# Robust Scaling
scaler = RobustScaler()
robust_df.loc[:, 'RATE'] = scaler.fit_transform(robust_df[['RATE']])
robust_df.head()
# Out:
#          POD      RATE
# 0 2005-07-19  1.255814
# 1 2005-07-19  1.255814
# 2 2005-07-21  1.372093
# 3 2005-07-26  1.255814
# 4 2005-07-29  1.720930

# %%
# Check if the DataFrame has any NaN values
if robust_df.isna().any().any():
    print("The DataFrame contains NaN values.")
else:
    print("The DataFrame does not contain NaN values.")
# Out:
# The DataFrame does not contain NaN values.

# %% [markdown]
# <h4>Interpolate missing values in between dates</h4>

# %%
# Remove duplicated dates and cost rows
robust_df = robust_df.drop_duplicates(subset=['POD', 'RATE']).reset_index(drop=True)

# Create a new dataframe with a date range from min to max date in your dataframe
new_df = pd.DataFrame()
new_df['POD'] = pd.date_range(start=robust_df['POD'].min(), end=robust_df['POD'].max())

# Merge the original dataframe with the new one. Missing dates in the original dataframe will be filled with NaN
df_interpolated = pd.merge(new_df, robust_df, on='POD', how='left')  

# Perform spline interpolation
df_interpolated['RATE'] = df_interpolated['RATE'].interpolate(method='polynomial', order=1)

df_interpolated['RATE'] = df_interpolated['RATE'].round(3)

# Now we need to inverse the scaling
df_interpolated['RATE'] = scaler.inverse_transform(df_interpolated[['RATE']])

df_interpolated.head(5)
df_interpolated.tail(5)
df_interpolated.info()
# Out:
#          POD     RATE
# 0 2005-07-19  2200.16
# 1 2005-07-20  2250.04
# 2 2005-07-21  2299.92
# 3 2005-07-22  2280.14
# 4 2005-07-23  2260.36
#             POD   RATE
# 6524 2023-05-04  264.3
# 6525 2023-05-05  264.3
# 6526 2023-05-06  264.3
# 6527 2023-05-07  264.3
# 6528 2023-05-08  264.3
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6529 entries, 0 to 6528
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POD     6529 non-null   datetime64[ns]
#  1   RATE    6529 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 153.0 KB

# %% [markdown]
# <h4>Grouping it to week</h4>

# %%
from scipy import stats

# Create YearMonthWeek directly from the 'POD'
df_interpolated['YearMonthWeek'] = df_interpolated['POD'] - pd.to_timedelta(df_interpolated['POD'].dt.dayofweek, unit='D')

# Create a new dataframe with every week in the range
all_weeks = pd.date_range(start=df_interpolated['POD'].min(), end=df_interpolated['POD'].max(), freq='W')
all_weeks_df = pd.DataFrame(all_weeks, columns=['POD'])

# Create YearMonthWeek in all_weeks_df
all_weeks_df['YearMonthWeek'] = all_weeks_df['POD'] - pd.to_timedelta(all_weeks_df['POD'].dt.dayofweek, unit='D')

# Merge this with your original dataframe
merged_df = pd.merge(all_weeks_df, df_interpolated, on=['YearMonthWeek'], how='left')

# Now you can group by YearMonthWeek and compute your rate
grouped = merged_df.groupby(['YearMonthWeek'])

agg_df = pd.DataFrame(columns=['YearMonthWeek', 'Rate'])

for group_name, group_df in grouped:
    year_month_week = group_name

    # Skip if no data for this week
    if group_df['RATE'].isnull().all():
        continue

    # Calculate sum and skewness of RATE values
    rate_sum = group_df['RATE'].sum()
    rate_skew = group_df['RATE'].skew()

    # Calculate trimmed mean of RATE values
    rate_metric = stats.trim_mean(group_df['RATE'].dropna().values, 0.1) # trimming 10% from each end

    new_row = {
        'YearMonthWeek': year_month_week,
        'Rate': rate_metric
    }

    # Append row to aggregated dataframe
    agg_df = agg_df.append(new_row, ignore_index=True)

agg_df = agg_df.sort_values(by='YearMonthWeek').reset_index(drop=True)
agg_df['Rate'] = agg_df['Rate'].round(2)

agg_df.head(15)
agg_df.tail(15)
agg_df.info()
# Out:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:21: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for group_name, group_df in grouped:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# ...
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21308\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
#    YearMonthWeek     Rate
# 0     2005-07-18  2255.06
# 1     2005-07-25  2388.62
# 2     2005-08-01  2261.47
# 3     2005-08-08  2202.99
# 4     2005-08-15  2253.60
# 5     2005-08-22  2252.25
# 6     2005-08-29  2252.37
# 7     2005-09-05  2220.43
# 8     2005-09-12  2200.16
# 9     2005-09-19  2200.16
# 10    2005-09-26  2200.16
# 11    2005-10-03  2200.16
# 12    2005-10-10  2200.16
# 13    2005-10-17  2200.16
# 14    2005-10-24  2200.16
#     YearMonthWeek     Rate
# 914    2023-01-23  3350.84
# 915    2023-01-30  1604.18
# 916    2023-02-06  1500.12
# 917    2023-02-13  1500.12
# 918    2023-02-20  1449.63
# 919    2023-02-27  1288.31
# 920    2023-03-06  1121.35
# 921    2023-03-13  1182.04
# 922    2023-03-20  1759.23
# 923    2023-03-27  1245.56
# 924    2023-04-03   662.36
# 925    2023-04-10   629.19
# 926    2023-04-17   664.20
# 927    2023-04-24   524.39
# 928    2023-05-01   290.10
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 929 entries, 0 to 928
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   YearMonthWeek  929 non-null    datetime64[ns]
#  1   Rate           929 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 14.6 KB

# %%
plt.figure(figsize=(20, 10))
plt.plot(sel_df['POD'], sel_df['RATE'], color='blue', label="Actual Data")
plt.plot(agg_df['YearMonthWeek'], agg_df['Rate'], color='red', label="Aggregated Data(weeks)")

plt.xlabel('Date(Year Month Week)')
plt.ylabel('Cost Rate(USD)')
plt.title('Port_BUSAN_Size_40_Type_HC_PartyID_010004286')
plt.legend()
plt.show();

# %% [markdown]
# <h4>LSTM Regression<h4>

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# Mean Square Error Function:
def calculate_RMSE(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# Restructure time series data for LSTM model
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

def create_LSTM_model(trainX, trainY, testX, testY, epochs):
    model = Sequential()
    model.add(LSTM(256, return_sequences=True, input_shape=(trainX.shape[1], trainX.shape[2]), 
                   activation='tanh', recurrent_activation='hard_sigmoid', kernel_regularizer=l2(0.01)))
    model.add(Dropout(0.1))  # 30% dropout

    # Add regularization to all LSTM layers
    for size in [256, 128, 128, 64, 64, 32, 32, 16, 16, 8, 8]:
        model.add(LSTM(size, activation='tanh', return_sequences=True, kernel_regularizer=l2(0.01)))
    
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=0.001))
    model.summary()

    # Add early stopping
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
    
    # Fit the model and store the history
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=64, verbose=2, 
                        validation_data=(testX, testY), callbacks=[es])
    return model, history

def plot_train_val_loss(history):
    plt.figure(figsize=(10,6))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model loss progress during training and validation')
    plt.xlabel('Epoch')
    plt.ylabel('Training and Validation Loss')
    plt.legend()
    plt.show()

# %%
# Normalize dataset for LSTM
from sklearn.preprocessing import MinMaxScaler

agg_df = pd.DataFrame({'YearMonthWeek': range(100), 'Rate': np.random.rand(100) * 100})

# Normalize dataset for LSTM
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(agg_df['Rate'].values.reshape(-1,1))

# Split into train and test sets
train_size = int(len(dataset) * 0.7)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# Reshape into X=t and Y=t+1, timestep  look_back
look_back = 5
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# Reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

epochs_list = [50, 100, 150]

rmse_results = {}

for epochs in epochs_list:
    print(f'Training for {epochs} epochs...')
    model, history = create_LSTM_model(trainX, trainY, trainX, trainY, epochs)  # Use train data for forecasting
    
    # Add the loss for this model to the plot
    plt.plot(history.history['loss'], label=f'Train Loss - {epochs} epochs')
    plt.plot(history.history['val_loss'], label=f'Validation Loss - {epochs} epochs')

    # Configure and show the plot
    plt.title('Model loss progress during training and validation')
    plt.xlabel('Epoch')
    plt.ylabel('Training and Validation Loss')
    plt.legend()
    plt.show()

    # Evaluate LSTM Model on train data
    trainPredict = model.predict(trainX)

    # Take last predictions from the sequence for each sample
    trainPredict = trainPredict[:, -1, :]

    # Now you can use inverse_transform
    trainPredict = scaler.inverse_transform(trainPredict)
    trainY_orig = scaler.inverse_transform([trainY])

    # Calculate mean squared error
    trainScore = calculate_RMSE(trainY_orig[0], trainPredict[:,0])
    print(f'Train Score: {trainScore:.2f} RMSE for {epochs} epochs')

    rmse_results[epochs] = {'Train RMSE': trainScore}

# Convert the dictionary to a DataFrame for easy display
rmse_df = pd.DataFrame(rmse_results).T
print(rmse_df)
# Out:
# Training for 50 epochs...
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_36 (LSTM)              (None, 1, 256)            268288
#
#  dropout_3 (Dropout)         (None, 1, 256)            0
#
#  lstm_37 (LSTM)              (None, 1, 256)            525312
#
#  lstm_38 (LSTM)              (None, 1, 128)            197120
#
#  lstm_39 (LSTM)              (None, 1, 128)            131584
#
#  lstm_40 (LSTM)              (None, 1, 64)             49408
#
#  lstm_41 (LSTM)              (None, 1, 64)             33024
#
#  lstm_42 (LSTM)              (None, 1, 32)             12416
#
#  lstm_43 (LSTM)              (None, 1, 32)             8320
#
#  lstm_44 (LSTM)              (None, 1, 16)             3136
#
#  lstm_45 (LSTM)              (None, 1, 16)             2112
#
#  lstm_46 (LSTM)              (None, 1, 8)              800
#
#  lstm_47 (LSTM)              (None, 1, 8)              544
#
#  dense_3 (Dense)             (None, 1, 1)              9
#
# =================================================================
# Total params: 1,232,073
# Trainable params: 1,232,073
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1/1 - 20s - loss: 15.1209 - val_loss: 14.6669 - 20s/epoch - 20s/step
# Epoch 2/50
# 1/1 - 0s - loss: 14.6669 - val_loss: 14.2231 - 54ms/epoch - 54ms/step
# Epoch 3/50
# 1/1 - 0s - loss: 14.2231 - val_loss: 13.7899 - 52ms/epoch - 52ms/step
# Epoch 4/50
# 1/1 - 0s - loss: 13.7899 - val_loss: 13.3672 - 54ms/epoch - 54ms/step
# Epoch 5/50
# 1/1 - 0s - loss: 13.3672 - val_loss: 12.9552 - 51ms/epoch - 51ms/step
# Epoch 6/50
# 1/1 - 0s - loss: 12.9552 - val_loss: 12.5538 - 52ms/epoch - 52ms/step
# Epoch 7/50
# 1/1 - 0s - loss: 12.5538 - val_loss: 12.1630 - 53ms/epoch - 53ms/step
# Epoch 8/50
# 1/1 - 0s - loss: 12.1630 - val_loss: 11.7827 - 54ms/epoch - 54ms/step
# Epoch 9/50
# 1/1 - 0s - loss: 11.7827 - val_loss: 11.4127 - 54ms/epoch - 54ms/step
# Epoch 10/50
# 1/1 - 0s - loss: 11.4127 - val_loss: 11.0531 - 54ms/epoch - 54ms/step
# Epoch 11/50
# 1/1 - 0s - loss: 11.0531 - val_loss: 10.7037 - 70ms/epoch - 70ms/step
# Epoch 12/50
# 1/1 - 0s - loss: 10.7037 - val_loss: 10.3643 - 62ms/epoch - 62ms/step
# Epoch 13/50
# 1/1 - 0s - loss: 10.3643 - val_loss: 10.0348 - 53ms/epoch - 53ms/step
# Epoch 14/50
# 1/1 - 0s - loss: 10.0348 - val_loss: 9.7151 - 53ms/epoch - 53ms/step
# Epoch 15/50
# 1/1 - 0s - loss: 9.7151 - val_loss: 9.4050 - 56ms/epoch - 56ms/step
# Epoch 16/50
# 1/1 - 0s - loss: 9.4050 - val_loss: 9.1043 - 52ms/epoch - 52ms/step
# Epoch 17/50
# 1/1 - 0s - loss: 9.1043 - val_loss: 8.8128 - 52ms/epoch - 52ms/step
# Epoch 18/50
# 1/1 - 0s - loss: 8.8128 - val_loss: 8.5304 - 53ms/epoch - 53ms/step
# Epoch 19/50
# 1/1 - 0s - loss: 8.5304 - val_loss: 8.2569 - 52ms/epoch - 52ms/step
# Epoch 20/50
# 1/1 - 0s - loss: 8.2569 - val_loss: 7.9921 - 53ms/epoch - 53ms/step
# Epoch 21/50
# 1/1 - 0s - loss: 7.9921 - val_loss: 7.7357 - 55ms/epoch - 55ms/step
# Epoch 22/50
# 1/1 - 0s - loss: 7.7357 - val_loss: 7.4876 - 51ms/epoch - 51ms/step
# Epoch 23/50
# 1/1 - 0s - loss: 7.4876 - val_loss: 7.2477 - 52ms/epoch - 52ms/step
# Epoch 24/50
# 1/1 - 0s - loss: 7.2477 - val_loss: 7.0156 - 54ms/epoch - 54ms/step
# Epoch 25/50
# 1/1 - 0s - loss: 7.0156 - val_loss: 6.7912 - 52ms/epoch - 52ms/step
# Epoch 26/50
# 1/1 - 0s - loss: 6.7912 - val_loss: 6.5743 - 52ms/epoch - 52ms/step
# Epoch 27/50
# 1/1 - 0s - loss: 6.5743 - val_loss: 6.3646 - 54ms/epoch - 54ms/step
# Epoch 28/50
# 1/1 - 0s - loss: 6.3646 - val_loss: 6.1621 - 51ms/epoch - 51ms/step
# Epoch 29/50
# 1/1 - 0s - loss: 6.1621 - val_loss: 5.9664 - 52ms/epoch - 52ms/step
# Epoch 30/50
# 1/1 - 0s - loss: 5.9664 - val_loss: 5.7774 - 55ms/epoch - 55ms/step
# Epoch 31/50
# 1/1 - 0s - loss: 5.7774 - val_loss: 5.5949 - 51ms/epoch - 51ms/step
# Epoch 32/50
# 1/1 - 0s - loss: 5.5949 - val_loss: 5.4187 - 53ms/epoch - 53ms/step
# Epoch 33/50
# 1/1 - 0s - loss: 5.4187 - val_loss: 5.2486 - 55ms/epoch - 55ms/step
# Epoch 34/50
# 1/1 - 0s - loss: 5.2486 - val_loss: 5.0845 - 54ms/epoch - 54ms/step
# Epoch 35/50
# 1/1 - 0s - loss: 5.0845 - val_loss: 4.9260 - 57ms/epoch - 57ms/step
# Epoch 36/50
# 1/1 - 0s - loss: 4.9260 - val_loss: 4.7731 - 55ms/epoch - 55ms/step
# Epoch 37/50
# 1/1 - 0s - loss: 4.7731 - val_loss: 4.6256 - 52ms/epoch - 52ms/step
# Epoch 38/50
# 1/1 - 0s - loss: 4.6256 - val_loss: 4.4832 - 54ms/epoch - 54ms/step
# Epoch 39/50
# 1/1 - 0s - loss: 4.4832 - val_loss: 4.3459 - 53ms/epoch - 53ms/step
# Epoch 40/50
# 1/1 - 0s - loss: 4.3459 - val_loss: 4.2134 - 53ms/epoch - 53ms/step
# Epoch 41/50
# 1/1 - 0s - loss: 4.2134 - val_loss: 4.0857 - 52ms/epoch - 52ms/step
# Epoch 42/50
# 1/1 - 0s - loss: 4.0857 - val_loss: 3.9624 - 53ms/epoch - 53ms/step
# Epoch 43/50
# 1/1 - 0s - loss: 3.9624 - val_loss: 3.8435 - 53ms/epoch - 53ms/step
# Epoch 44/50
# 1/1 - 0s - loss: 3.8435 - val_loss: 3.7289 - 53ms/epoch - 53ms/step
# Epoch 45/50
# 1/1 - 0s - loss: 3.7289 - val_loss: 3.6183 - 55ms/epoch - 55ms/step
# Epoch 46/50
# 1/1 - 0s - loss: 3.6183 - val_loss: 3.5116 - 52ms/epoch - 52ms/step
# Epoch 47/50
# 1/1 - 0s - loss: 3.5116 - val_loss: 3.4087 - 52ms/epoch - 52ms/step
# Epoch 48/50
# 1/1 - 0s - loss: 3.4087 - val_loss: 3.3095 - 51ms/epoch - 51ms/step
# Epoch 49/50
# 1/1 - 0s - loss: 3.3095 - val_loss: 3.2137 - 87ms/epoch - 87ms/step
# Epoch 50/50
# 1/1 - 0s - loss: 3.2137 - val_loss: 3.1214 - 63ms/epoch - 63ms/step
# Text(0.5, 1.0, 'Model loss progress during training and validation')
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'Training and Validation Loss')
# 2/2 [==============================] - 4s 6ms/step
# Train Score: 51.76 RMSE for 50 epochs
# Training for 100 epochs...
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_48 (LSTM)              (None, 1, 256)            268288
#
#  dropout_4 (Dropout)         (None, 1, 256)            0
#
#  lstm_49 (LSTM)              (None, 1, 256)            525312
#
#  lstm_50 (LSTM)              (None, 1, 128)            197120
#
#  lstm_51 (LSTM)              (None, 1, 128)            131584
#
#  lstm_52 (LSTM)              (None, 1, 64)             49408
#
#  lstm_53 (LSTM)              (None, 1, 64)             33024
#
#  lstm_54 (LSTM)              (None, 1, 32)             12416
#
#  lstm_55 (LSTM)              (None, 1, 32)             8320
#
#  lstm_56 (LSTM)              (None, 1, 16)             3136
#
#  lstm_57 (LSTM)              (None, 1, 16)             2112
#
#  lstm_58 (LSTM)              (None, 1, 8)              800
#
#  lstm_59 (LSTM)              (None, 1, 8)              544
#
#  dense_4 (Dense)             (None, 1, 1)              9
#
# =================================================================
# Total params: 1,232,073
# Trainable params: 1,232,073
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 1/1 - 20s - loss: 15.1120 - val_loss: 14.6578 - 20s/epoch - 20s/step
# Epoch 2/100
# 1/1 - 0s - loss: 14.6578 - val_loss: 14.2138 - 65ms/epoch - 65ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 14.2138 - val_loss: 13.7803 - 51ms/epoch - 51ms/step
# Epoch 4/100
# 1/1 - 0s - loss: 13.7803 - val_loss: 13.3573 - 54ms/epoch - 54ms/step
# Epoch 5/100
# 1/1 - 0s - loss: 13.3573 - val_loss: 12.9450 - 54ms/epoch - 54ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 12.9450 - val_loss: 12.5434 - 54ms/epoch - 54ms/step
# Epoch 7/100
# 1/1 - 0s - loss: 12.5434 - val_loss: 12.1523 - 52ms/epoch - 52ms/step
# Epoch 8/100
# 1/1 - 0s - loss: 12.1523 - val_loss: 11.7716 - 56ms/epoch - 56ms/step
# Epoch 9/100
# 1/1 - 0s - loss: 11.7716 - val_loss: 11.4014 - 52ms/epoch - 52ms/step
# Epoch 10/100
# 1/1 - 0s - loss: 11.4014 - val_loss: 11.0415 - 52ms/epoch - 52ms/step
# Epoch 11/100
# 1/1 - 0s - loss: 11.0415 - val_loss: 10.6917 - 52ms/epoch - 52ms/step
# Epoch 12/100
# 1/1 - 0s - loss: 10.6917 - val_loss: 10.3520 - 51ms/epoch - 51ms/step
# Epoch 13/100
# 1/1 - 0s - loss: 10.3520 - val_loss: 10.0222 - 53ms/epoch - 53ms/step
# Epoch 14/100
# 1/1 - 0s - loss: 10.0222 - val_loss: 9.7021 - 51ms/epoch - 51ms/step
# Epoch 15/100
# 1/1 - 0s - loss: 9.7021 - val_loss: 9.3916 - 52ms/epoch - 52ms/step
# Epoch 16/100
# 1/1 - 0s - loss: 9.3916 - val_loss: 9.0906 - 52ms/epoch - 52ms/step
# Epoch 17/100
# 1/1 - 0s - loss: 9.0906 - val_loss: 8.7988 - 52ms/epoch - 52ms/step
# Epoch 18/100
# 1/1 - 0s - loss: 8.7988 - val_loss: 8.5160 - 51ms/epoch - 51ms/step
# Epoch 19/100
# 1/1 - 0s - loss: 8.5160 - val_loss: 8.2421 - 52ms/epoch - 52ms/step
# Epoch 20/100
# 1/1 - 0s - loss: 8.2421 - val_loss: 7.9770 - 67ms/epoch - 67ms/step
# Epoch 21/100
# 1/1 - 0s - loss: 7.9770 - val_loss: 7.7203 - 60ms/epoch - 60ms/step
# Epoch 22/100
# 1/1 - 0s - loss: 7.7203 - val_loss: 7.4719 - 58ms/epoch - 58ms/step
# Epoch 23/100
# 1/1 - 0s - loss: 7.4719 - val_loss: 7.2316 - 53ms/epoch - 53ms/step
# Epoch 24/100
# 1/1 - 0s - loss: 7.2316 - val_loss: 6.9992 - 56ms/epoch - 56ms/step
# Epoch 25/100
# 1/1 - 0s - loss: 6.9992 - val_loss: 6.7744 - 52ms/epoch - 52ms/step
# Epoch 26/100
# 1/1 - 0s - loss: 6.7744 - val_loss: 6.5572 - 53ms/epoch - 53ms/step
# Epoch 27/100
# 1/1 - 0s - loss: 6.5572 - val_loss: 6.3473 - 53ms/epoch - 53ms/step
# Epoch 28/100
# 1/1 - 0s - loss: 6.3473 - val_loss: 6.1445 - 51ms/epoch - 51ms/step
# Epoch 29/100
# 1/1 - 0s - loss: 6.1445 - val_loss: 5.9486 - 52ms/epoch - 52ms/step
# Epoch 30/100
# 1/1 - 0s - loss: 5.9486 - val_loss: 5.7593 - 55ms/epoch - 55ms/step
# Epoch 31/100
# 1/1 - 0s - loss: 5.7593 - val_loss: 5.5766 - 52ms/epoch - 52ms/step
# Epoch 32/100
# 1/1 - 0s - loss: 5.5766 - val_loss: 5.4002 - 52ms/epoch - 52ms/step
# Epoch 33/100
# 1/1 - 0s - loss: 5.4002 - val_loss: 5.2299 - 53ms/epoch - 53ms/step
# Epoch 34/100
# 1/1 - 0s - loss: 5.2299 - val_loss: 5.0655 - 52ms/epoch - 52ms/step
# Epoch 35/100
# 1/1 - 0s - loss: 5.0655 - val_loss: 4.9069 - 53ms/epoch - 53ms/step
# Epoch 36/100
# 1/1 - 0s - loss: 4.9069 - val_loss: 4.7538 - 54ms/epoch - 54ms/step
# Epoch 37/100
# 1/1 - 0s - loss: 4.7538 - val_loss: 4.6061 - 53ms/epoch - 53ms/step
# Epoch 38/100
# 1/1 - 0s - loss: 4.6061 - val_loss: 4.4636 - 53ms/epoch - 53ms/step
# Epoch 39/100
# 1/1 - 0s - loss: 4.4636 - val_loss: 4.3262 - 66ms/epoch - 66ms/step
# Epoch 40/100
# 1/1 - 0s - loss: 4.3262 - val_loss: 4.1936 - 76ms/epoch - 76ms/step
# Epoch 41/100
# 1/1 - 0s - loss: 4.1936 - val_loss: 4.0657 - 66ms/epoch - 66ms/step
# Epoch 42/100
# 1/1 - 0s - loss: 4.0657 - val_loss: 3.9423 - 55ms/epoch - 55ms/step
# Epoch 43/100
# 1/1 - 0s - loss: 3.9423 - val_loss: 3.8234 - 51ms/epoch - 51ms/step
# Epoch 44/100
# 1/1 - 0s - loss: 3.8234 - val_loss: 3.7086 - 53ms/epoch - 53ms/step
# Epoch 45/100
# 1/1 - 0s - loss: 3.7086 - val_loss: 3.5979 - 51ms/epoch - 51ms/step
# Epoch 46/100
# 1/1 - 0s - loss: 3.5979 - val_loss: 3.4912 - 52ms/epoch - 52ms/step
# Epoch 47/100
# 1/1 - 0s - loss: 3.4912 - val_loss: 3.3883 - 52ms/epoch - 52ms/step
# Epoch 48/100
# 1/1 - 0s - loss: 3.3883 - val_loss: 3.2890 - 51ms/epoch - 51ms/step
# Epoch 49/100
# 1/1 - 0s - loss: 3.2890 - val_loss: 3.1933 - 56ms/epoch - 56ms/step
# Epoch 50/100
# 1/1 - 0s - loss: 3.1933 - val_loss: 3.1009 - 53ms/epoch - 53ms/step
# Epoch 51/100
# 1/1 - 0s - loss: 3.1009 - val_loss: 3.0118 - 51ms/epoch - 51ms/step
# Epoch 52/100
# 1/1 - 0s - loss: 3.0118 - val_loss: 2.9259 - 54ms/epoch - 54ms/step
# Epoch 53/100
# 1/1 - 0s - loss: 2.9259 - val_loss: 2.8430 - 52ms/epoch - 52ms/step
# Epoch 54/100
# 1/1 - 0s - loss: 2.8430 - val_loss: 2.7630 - 51ms/epoch - 51ms/step
# Epoch 55/100
# 1/1 - 0s - loss: 2.7630 - val_loss: 2.6858 - 52ms/epoch - 52ms/step
# Epoch 56/100
# 1/1 - 0s - loss: 2.6858 - val_loss: 2.6114 - 51ms/epoch - 51ms/step
# Epoch 57/100
# 1/1 - 0s - loss: 2.6114 - val_loss: 2.5395 - 51ms/epoch - 51ms/step
# Epoch 58/100
# 1/1 - 0s - loss: 2.5395 - val_loss: 2.4702 - 57ms/epoch - 57ms/step
# Epoch 59/100
# 1/1 - 0s - loss: 2.4702 - val_loss: 2.4032 - 59ms/epoch - 59ms/step
# Epoch 60/100
# 1/1 - 0s - loss: 2.4032 - val_loss: 2.3386 - 52ms/epoch - 52ms/step
# Epoch 61/100
# 1/1 - 0s - loss: 2.3386 - val_loss: 2.2762 - 53ms/epoch - 53ms/step
# Epoch 62/100
# 1/1 - 0s - loss: 2.2762 - val_loss: 2.2160 - 52ms/epoch - 52ms/step
# Epoch 63/100
# 1/1 - 0s - loss: 2.2160 - val_loss: 2.1578 - 52ms/epoch - 52ms/step
# Epoch 64/100
# 1/1 - 0s - loss: 2.1578 - val_loss: 2.1016 - 53ms/epoch - 53ms/step
# Epoch 65/100
# 1/1 - 0s - loss: 2.1016 - val_loss: 2.0473 - 51ms/epoch - 51ms/step
# Epoch 66/100
# 1/1 - 0s - loss: 2.0473 - val_loss: 1.9948 - 53ms/epoch - 53ms/step
# Epoch 67/100
# 1/1 - 0s - loss: 1.9948 - val_loss: 1.9441 - 52ms/epoch - 52ms/step
# Epoch 68/100
# 1/1 - 0s - loss: 1.9441 - val_loss: 1.8951 - 51ms/epoch - 51ms/step
# Epoch 69/100
# 1/1 - 0s - loss: 1.8951 - val_loss: 1.8477 - 53ms/epoch - 53ms/step
# Epoch 70/100
# 1/1 - 0s - loss: 1.8477 - val_loss: 1.8019 - 52ms/epoch - 52ms/step
# Epoch 71/100
# 1/1 - 0s - loss: 1.8019 - val_loss: 1.7576 - 51ms/epoch - 51ms/step
# Epoch 72/100
# 1/1 - 0s - loss: 1.7576 - val_loss: 1.7147 - 54ms/epoch - 54ms/step
# Epoch 73/100
# 1/1 - 0s - loss: 1.7147 - val_loss: 1.6733 - 52ms/epoch - 52ms/step
# Epoch 74/100
# 1/1 - 0s - loss: 1.6733 - val_loss: 1.6332 - 54ms/epoch - 54ms/step
# Epoch 75/100
# 1/1 - 0s - loss: 1.6332 - val_loss: 1.5943 - 53ms/epoch - 53ms/step
# Epoch 76/100
# 1/1 - 0s - loss: 1.5943 - val_loss: 1.5567 - 52ms/epoch - 52ms/step
# Epoch 77/100
# 1/1 - 0s - loss: 1.5567 - val_loss: 1.5203 - 53ms/epoch - 53ms/step
# Epoch 78/100
# 1/1 - 0s - loss: 1.5203 - val_loss: 1.4851 - 53ms/epoch - 53ms/step
# Epoch 79/100
# 1/1 - 0s - loss: 1.4851 - val_loss: 1.4509 - 50ms/epoch - 50ms/step
# Epoch 80/100
# 1/1 - 0s - loss: 1.4509 - val_loss: 1.4178 - 52ms/epoch - 52ms/step
# Epoch 81/100
# 1/1 - 0s - loss: 1.4178 - val_loss: 1.3858 - 58ms/epoch - 58ms/step
# Epoch 82/100
# 1/1 - 0s - loss: 1.3858 - val_loss: 1.3547 - 52ms/epoch - 52ms/step
# Epoch 83/100
# 1/1 - 0s - loss: 1.3547 - val_loss: 1.3245 - 52ms/epoch - 52ms/step
# Epoch 84/100
# 1/1 - 0s - loss: 1.3245 - val_loss: 1.2953 - 54ms/epoch - 54ms/step
# Epoch 85/100
# 1/1 - 0s - loss: 1.2953 - val_loss: 1.2670 - 52ms/epoch - 52ms/step
# Epoch 86/100
# 1/1 - 0s - loss: 1.2670 - val_loss: 1.2395 - 53ms/epoch - 53ms/step
# Epoch 87/100
# 1/1 - 0s - loss: 1.2395 - val_loss: 1.2128 - 53ms/epoch - 53ms/step
# Epoch 88/100
# 1/1 - 0s - loss: 1.2128 - val_loss: 1.1868 - 52ms/epoch - 52ms/step
# Epoch 89/100
# 1/1 - 0s - loss: 1.1868 - val_loss: 1.1617 - 54ms/epoch - 54ms/step
# Epoch 90/100
# 1/1 - 0s - loss: 1.1617 - val_loss: 1.1373 - 83ms/epoch - 83ms/step
# Epoch 91/100
# 1/1 - 0s - loss: 1.1373 - val_loss: 1.1135 - 61ms/epoch - 61ms/step
# Epoch 92/100
# 1/1 - 0s - loss: 1.1135 - val_loss: 1.0905 - 54ms/epoch - 54ms/step
# Epoch 93/100
# 1/1 - 0s - loss: 1.0905 - val_loss: 1.0681 - 53ms/epoch - 53ms/step
# Epoch 94/100
# 1/1 - 0s - loss: 1.0681 - val_loss: 1.0463 - 56ms/epoch - 56ms/step
# Epoch 95/100
# 1/1 - 0s - loss: 1.0463 - val_loss: 1.0252 - 54ms/epoch - 54ms/step
# Epoch 96/100
# 1/1 - 0s - loss: 1.0252 - val_loss: 1.0046 - 67ms/epoch - 67ms/step
# Epoch 97/100
# 1/1 - 0s - loss: 1.0046 - val_loss: 0.9846 - 66ms/epoch - 66ms/step
# Epoch 98/100
# 1/1 - 0s - loss: 0.9846 - val_loss: 0.9651 - 52ms/epoch - 52ms/step
# Epoch 99/100
# 1/1 - 0s - loss: 0.9651 - val_loss: 0.9462 - 53ms/epoch - 53ms/step
# Epoch 100/100
# 1/1 - 0s - loss: 0.9462 - val_loss: 0.9277 - 53ms/epoch - 53ms/step
# Text(0.5, 1.0, 'Model loss progress during training and validation')
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'Training and Validation Loss')
# 2/2 [==============================] - 4s 6ms/step
# Train Score: 42.47 RMSE for 100 epochs
# Training for 150 epochs...
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_60 (LSTM)              (None, 1, 256)            268288
#
#  dropout_5 (Dropout)         (None, 1, 256)            0
#
#  lstm_61 (LSTM)              (None, 1, 256)            525312
#
#  lstm_62 (LSTM)              (None, 1, 128)            197120
#
#  lstm_63 (LSTM)              (None, 1, 128)            131584
#
#  lstm_64 (LSTM)              (None, 1, 64)             49408
#
#  lstm_65 (LSTM)              (None, 1, 64)             33024
#
#  lstm_66 (LSTM)              (None, 1, 32)             12416
#
#  lstm_67 (LSTM)              (None, 1, 32)             8320
#
#  lstm_68 (LSTM)              (None, 1, 16)             3136
#
#  lstm_69 (LSTM)              (None, 1, 16)             2112
#
#  lstm_70 (LSTM)              (None, 1, 8)              800
#
#  lstm_71 (LSTM)              (None, 1, 8)              544
#
#  dense_5 (Dense)             (None, 1, 1)              9
#
# =================================================================
# Total params: 1,232,073
# Trainable params: 1,232,073
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 1/1 - 20s - loss: 15.1181 - val_loss: 14.6633 - 20s/epoch - 20s/step
# Epoch 2/150
# 1/1 - 0s - loss: 14.6633 - val_loss: 14.2187 - 52ms/epoch - 52ms/step
# Epoch 3/150
# 1/1 - 0s - loss: 14.2187 - val_loss: 13.7847 - 53ms/epoch - 53ms/step
# Epoch 4/150
# 1/1 - 0s - loss: 13.7847 - val_loss: 13.3613 - 53ms/epoch - 53ms/step
# Epoch 5/150
# 1/1 - 0s - loss: 13.3613 - val_loss: 12.9485 - 51ms/epoch - 51ms/step
# Epoch 6/150
# 1/1 - 0s - loss: 12.9485 - val_loss: 12.5463 - 54ms/epoch - 54ms/step
# Epoch 7/150
# 1/1 - 0s - loss: 12.5463 - val_loss: 12.1547 - 51ms/epoch - 51ms/step
# Epoch 8/150
# 1/1 - 0s - loss: 12.1547 - val_loss: 11.7736 - 53ms/epoch - 53ms/step
# Epoch 9/150
# 1/1 - 0s - loss: 11.7736 - val_loss: 11.4029 - 52ms/epoch - 52ms/step
# Epoch 10/150
# 1/1 - 0s - loss: 11.4029 - val_loss: 11.0426 - 52ms/epoch - 52ms/step
# Epoch 11/150
# 1/1 - 0s - loss: 11.0426 - val_loss: 10.6924 - 52ms/epoch - 52ms/step
# Epoch 12/150
# 1/1 - 0s - loss: 10.6924 - val_loss: 10.3523 - 53ms/epoch - 53ms/step
# Epoch 13/150
# 1/1 - 0s - loss: 10.3523 - val_loss: 10.0221 - 53ms/epoch - 53ms/step
# Epoch 14/150
# 1/1 - 0s - loss: 10.0221 - val_loss: 9.7016 - 52ms/epoch - 52ms/step
# Epoch 15/150
# 1/1 - 0s - loss: 9.7016 - val_loss: 9.3907 - 60ms/epoch - 60ms/step
# Epoch 16/150
# 1/1 - 0s - loss: 9.3907 - val_loss: 9.0893 - 53ms/epoch - 53ms/step
# Epoch 17/150
# 1/1 - 0s - loss: 9.0893 - val_loss: 8.7971 - 53ms/epoch - 53ms/step
# Epoch 18/150
# 1/1 - 0s - loss: 8.7971 - val_loss: 8.5140 - 52ms/epoch - 52ms/step
# Epoch 19/150
# 1/1 - 0s - loss: 8.5140 - val_loss: 8.2398 - 52ms/epoch - 52ms/step
# Epoch 20/150
# 1/1 - 0s - loss: 8.2398 - val_loss: 7.9743 - 53ms/epoch - 53ms/step
# Epoch 21/150
# 1/1 - 0s - loss: 7.9743 - val_loss: 7.7173 - 54ms/epoch - 54ms/step
# Epoch 22/150
# 1/1 - 0s - loss: 7.7173 - val_loss: 7.4686 - 52ms/epoch - 52ms/step
# Epoch 23/150
# 1/1 - 0s - loss: 7.4686 - val_loss: 7.2279 - 54ms/epoch - 54ms/step
# Epoch 24/150
# 1/1 - 0s - loss: 7.2279 - val_loss: 6.9952 - 51ms/epoch - 51ms/step
# Epoch 25/150
# 1/1 - 0s - loss: 6.9952 - val_loss: 6.7702 - 52ms/epoch - 52ms/step
# Epoch 26/150
# 1/1 - 0s - loss: 6.7702 - val_loss: 6.5527 - 53ms/epoch - 53ms/step
# Epoch 27/150
# 1/1 - 0s - loss: 6.5527 - val_loss: 6.3425 - 50ms/epoch - 50ms/step
# Epoch 28/150
# 1/1 - 0s - loss: 6.3425 - val_loss: 6.1394 - 51ms/epoch - 51ms/step
# Epoch 29/150
# 1/1 - 0s - loss: 6.1394 - val_loss: 5.9431 - 52ms/epoch - 52ms/step
# Epoch 30/150
# 1/1 - 0s - loss: 5.9431 - val_loss: 5.7536 - 51ms/epoch - 51ms/step
# Epoch 31/150
# 1/1 - 0s - loss: 5.7536 - val_loss: 5.5706 - 52ms/epoch - 52ms/step
# Epoch 32/150
# 1/1 - 0s - loss: 5.5706 - val_loss: 5.3939 - 52ms/epoch - 52ms/step
# Epoch 33/150
# 1/1 - 0s - loss: 5.3939 - val_loss: 5.2233 - 52ms/epoch - 52ms/step
# Epoch 34/150
# 1/1 - 0s - loss: 5.2233 - val_loss: 5.0586 - 53ms/epoch - 53ms/step
# Epoch 35/150
# 1/1 - 0s - loss: 5.0586 - val_loss: 4.8997 - 53ms/epoch - 53ms/step
# Epoch 36/150
# 1/1 - 0s - loss: 4.8997 - val_loss: 4.7464 - 51ms/epoch - 51ms/step
# Epoch 37/150
# 1/1 - 0s - loss: 4.7464 - val_loss: 4.5984 - 53ms/epoch - 53ms/step
# Epoch 38/150
# 1/1 - 0s - loss: 4.5984 - val_loss: 4.4556 - 53ms/epoch - 53ms/step
# Epoch 39/150
# 1/1 - 0s - loss: 4.4556 - val_loss: 4.3179 - 65ms/epoch - 65ms/step
# Epoch 40/150
# 1/1 - 0s - loss: 4.3179 - val_loss: 4.1850 - 77ms/epoch - 77ms/step
# Epoch 41/150
# 1/1 - 0s - loss: 4.1850 - val_loss: 4.0569 - 58ms/epoch - 58ms/step
# Epoch 42/150
# 1/1 - 0s - loss: 4.0569 - val_loss: 3.9333 - 52ms/epoch - 52ms/step
# Epoch 43/150
# 1/1 - 0s - loss: 3.9333 - val_loss: 3.8140 - 52ms/epoch - 52ms/step
# Epoch 44/150
# 1/1 - 0s - loss: 3.8140 - val_loss: 3.6990 - 53ms/epoch - 53ms/step
# Epoch 45/150
# 1/1 - 0s - loss: 3.6990 - val_loss: 3.5881 - 52ms/epoch - 52ms/step
# Epoch 46/150
# 1/1 - 0s - loss: 3.5881 - val_loss: 3.4812 - 52ms/epoch - 52ms/step
# Epoch 47/150
# 1/1 - 0s - loss: 3.4812 - val_loss: 3.3780 - 51ms/epoch - 51ms/step
# Epoch 48/150
# 1/1 - 0s - loss: 3.3780 - val_loss: 3.2785 - 52ms/epoch - 52ms/step
# Epoch 49/150
# 1/1 - 0s - loss: 3.2785 - val_loss: 3.1825 - 54ms/epoch - 54ms/step
# Epoch 50/150
# 1/1 - 0s - loss: 3.1825 - val_loss: 3.0899 - 50ms/epoch - 50ms/step
# Epoch 51/150
# 1/1 - 0s - loss: 3.0899 - val_loss: 3.0006 - 54ms/epoch - 54ms/step
# Epoch 52/150
# 1/1 - 0s - loss: 3.0006 - val_loss: 2.9144 - 54ms/epoch - 54ms/step
# Epoch 53/150
# 1/1 - 0s - loss: 2.9144 - val_loss: 2.8313 - 52ms/epoch - 52ms/step
# Epoch 54/150
# 1/1 - 0s - loss: 2.8313 - val_loss: 2.7512 - 54ms/epoch - 54ms/step
# Epoch 55/150
# 1/1 - 0s - loss: 2.7512 - val_loss: 2.6738 - 58ms/epoch - 58ms/step
# Epoch 56/150
# 1/1 - 0s - loss: 2.6738 - val_loss: 2.5991 - 51ms/epoch - 51ms/step
# Epoch 57/150
# 1/1 - 0s - loss: 2.5991 - val_loss: 2.5271 - 53ms/epoch - 53ms/step
# Epoch 58/150
# 1/1 - 0s - loss: 2.5271 - val_loss: 2.4575 - 52ms/epoch - 52ms/step
# Epoch 59/150
# 1/1 - 0s - loss: 2.4575 - val_loss: 2.3904 - 54ms/epoch - 54ms/step
# Epoch 60/150
# 1/1 - 0s - loss: 2.3904 - val_loss: 2.3256 - 54ms/epoch - 54ms/step
# Epoch 61/150
# 1/1 - 0s - loss: 2.3256 - val_loss: 2.2630 - 51ms/epoch - 51ms/step
# Epoch 62/150
# 1/1 - 0s - loss: 2.2630 - val_loss: 2.2026 - 51ms/epoch - 51ms/step
# Epoch 63/150
# 1/1 - 0s - loss: 2.2026 - val_loss: 2.1443 - 52ms/epoch - 52ms/step
# Epoch 64/150
# 1/1 - 0s - loss: 2.1443 - val_loss: 2.0879 - 51ms/epoch - 51ms/step
# Epoch 65/150
# 1/1 - 0s - loss: 2.0879 - val_loss: 2.0335 - 52ms/epoch - 52ms/step
# Epoch 66/150
# 1/1 - 0s - loss: 2.0335 - val_loss: 1.9809 - 53ms/epoch - 53ms/step
# Epoch 67/150
# 1/1 - 0s - loss: 1.9809 - val_loss: 1.9300 - 54ms/epoch - 54ms/step
# Epoch 68/150
# 1/1 - 0s - loss: 1.9300 - val_loss: 1.8809 - 52ms/epoch - 52ms/step
# Epoch 69/150
# 1/1 - 0s - loss: 1.8809 - val_loss: 1.8334 - 55ms/epoch - 55ms/step
# Epoch 70/150
# 1/1 - 0s - loss: 1.8334 - val_loss: 1.7875 - 54ms/epoch - 54ms/step
# Epoch 71/150
# 1/1 - 0s - loss: 1.7875 - val_loss: 1.7430 - 58ms/epoch - 58ms/step
# Epoch 72/150
# 1/1 - 0s - loss: 1.7430 - val_loss: 1.7001 - 52ms/epoch - 52ms/step
# Epoch 73/150
# 1/1 - 0s - loss: 1.7001 - val_loss: 1.6585 - 54ms/epoch - 54ms/step
# Epoch 74/150
# 1/1 - 0s - loss: 1.6585 - val_loss: 1.6183 - 56ms/epoch - 56ms/step
# Epoch 75/150
# 1/1 - 0s - loss: 1.6183 - val_loss: 1.5794 - 67ms/epoch - 67ms/step
# Epoch 76/150
# 1/1 - 0s - loss: 1.5794 - val_loss: 1.5417 - 60ms/epoch - 60ms/step
# Epoch 77/150
# 1/1 - 0s - loss: 1.5417 - val_loss: 1.5052 - 56ms/epoch - 56ms/step
# Epoch 78/150
# 1/1 - 0s - loss: 1.5052 - val_loss: 1.4699 - 53ms/epoch - 53ms/step
# Epoch 79/150
# 1/1 - 0s - loss: 1.4699 - val_loss: 1.4357 - 54ms/epoch - 54ms/step
# Epoch 80/150
# 1/1 - 0s - loss: 1.4357 - val_loss: 1.4025 - 54ms/epoch - 54ms/step
# Epoch 81/150
# 1/1 - 0s - loss: 1.4025 - val_loss: 1.3704 - 52ms/epoch - 52ms/step
# Epoch 82/150
# 1/1 - 0s - loss: 1.3704 - val_loss: 1.3393 - 59ms/epoch - 59ms/step
# Epoch 83/150
# 1/1 - 0s - loss: 1.3393 - val_loss: 1.3091 - 56ms/epoch - 56ms/step
# Epoch 84/150
# 1/1 - 0s - loss: 1.3091 - val_loss: 1.2798 - 55ms/epoch - 55ms/step
# Epoch 85/150
# 1/1 - 0s - loss: 1.2798 - val_loss: 1.2514 - 55ms/epoch - 55ms/step
# Epoch 86/150
# 1/1 - 0s - loss: 1.2514 - val_loss: 1.2239 - 55ms/epoch - 55ms/step
# Epoch 87/150
# 1/1 - 0s - loss: 1.2239 - val_loss: 1.1972 - 57ms/epoch - 57ms/step
# Epoch 88/150
# 1/1 - 0s - loss: 1.1972 - val_loss: 1.1713 - 56ms/epoch - 56ms/step
# Epoch 89/150
# 1/1 - 0s - loss: 1.1713 - val_loss: 1.1461 - 54ms/epoch - 54ms/step
# Epoch 90/150
# 1/1 - 0s - loss: 1.1461 - val_loss: 1.1217 - 92ms/epoch - 92ms/step
# Epoch 91/150
# 1/1 - 0s - loss: 1.1217 - val_loss: 1.0980 - 61ms/epoch - 61ms/step
# Epoch 92/150
# 1/1 - 0s - loss: 1.0980 - val_loss: 1.0750 - 53ms/epoch - 53ms/step
# Epoch 93/150
# 1/1 - 0s - loss: 1.0750 - val_loss: 1.0526 - 57ms/epoch - 57ms/step
# Epoch 94/150
# 1/1 - 0s - loss: 1.0526 - val_loss: 1.0309 - 55ms/epoch - 55ms/step
# Epoch 95/150
# 1/1 - 0s - loss: 1.0309 - val_loss: 1.0098 - 52ms/epoch - 52ms/step
# Epoch 96/150
# 1/1 - 0s - loss: 1.0098 - val_loss: 0.9892 - 55ms/epoch - 55ms/step
# Epoch 97/150
# 1/1 - 0s - loss: 0.9892 - val_loss: 0.9693 - 52ms/epoch - 52ms/step
# Epoch 98/150
# 1/1 - 0s - loss: 0.9693 - val_loss: 0.9499 - 53ms/epoch - 53ms/step
# Epoch 99/150
# 1/1 - 0s - loss: 0.9499 - val_loss: 0.9310 - 53ms/epoch - 53ms/step
# Epoch 100/150
# 1/1 - 0s - loss: 0.9310 - val_loss: 0.9127 - 52ms/epoch - 52ms/step
# Epoch 101/150
# 1/1 - 0s - loss: 0.9127 - val_loss: 0.8948 - 53ms/epoch - 53ms/step
# Epoch 102/150
# 1/1 - 0s - loss: 0.8948 - val_loss: 0.8775 - 51ms/epoch - 51ms/step
# Epoch 103/150
# 1/1 - 0s - loss: 0.8775 - val_loss: 0.8606 - 54ms/epoch - 54ms/step
# Epoch 104/150
# 1/1 - 0s - loss: 0.8606 - val_loss: 0.8441 - 60ms/epoch - 60ms/step
# Epoch 105/150
# 1/1 - 0s - loss: 0.8441 - val_loss: 0.8281 - 55ms/epoch - 55ms/step
# Epoch 106/150
# 1/1 - 0s - loss: 0.8281 - val_loss: 0.8125 - 58ms/epoch - 58ms/step
# Epoch 107/150
# 1/1 - 0s - loss: 0.8125 - val_loss: 0.7973 - 57ms/epoch - 57ms/step
# Epoch 108/150
# 1/1 - 0s - loss: 0.7973 - val_loss: 0.7825 - 57ms/epoch - 57ms/step
# Epoch 109/150
# 1/1 - 0s - loss: 0.7825 - val_loss: 0.7681 - 60ms/epoch - 60ms/step
# Epoch 110/150
# 1/1 - 0s - loss: 0.7681 - val_loss: 0.7541 - 60ms/epoch - 60ms/step
# Epoch 111/150
# 1/1 - 0s - loss: 0.7541 - val_loss: 0.7404 - 55ms/epoch - 55ms/step
# Epoch 112/150
# 1/1 - 0s - loss: 0.7404 - val_loss: 0.7271 - 55ms/epoch - 55ms/step
# Epoch 113/150
# 1/1 - 0s - loss: 0.7271 - val_loss: 0.7141 - 54ms/epoch - 54ms/step
# Epoch 114/150
# 1/1 - 0s - loss: 0.7141 - val_loss: 0.7015 - 52ms/epoch - 52ms/step
# Epoch 115/150
# 1/1 - 0s - loss: 0.7015 - val_loss: 0.6891 - 51ms/epoch - 51ms/step
# Epoch 116/150
# 1/1 - 0s - loss: 0.6891 - val_loss: 0.6771 - 52ms/epoch - 52ms/step
# Epoch 117/150
# 1/1 - 0s - loss: 0.6771 - val_loss: 0.6654 - 51ms/epoch - 51ms/step
# Epoch 118/150
# 1/1 - 0s - loss: 0.6654 - val_loss: 0.6540 - 53ms/epoch - 53ms/step
# Epoch 119/150
# 1/1 - 0s - loss: 0.6540 - val_loss: 0.6428 - 52ms/epoch - 52ms/step
# Epoch 120/150
# 1/1 - 0s - loss: 0.6428 - val_loss: 0.6319 - 51ms/epoch - 51ms/step
# Epoch 121/150
# 1/1 - 0s - loss: 0.6319 - val_loss: 0.6213 - 55ms/epoch - 55ms/step
# Epoch 122/150
# 1/1 - 0s - loss: 0.6213 - val_loss: 0.6110 - 53ms/epoch - 53ms/step
# Epoch 123/150
# 1/1 - 0s - loss: 0.6110 - val_loss: 0.6009 - 57ms/epoch - 57ms/step
# Epoch 124/150
# 1/1 - 0s - loss: 0.6009 - val_loss: 0.5911 - 54ms/epoch - 54ms/step
# Epoch 125/150
# 1/1 - 0s - loss: 0.5911 - val_loss: 0.5814 - 52ms/epoch - 52ms/step
# Epoch 126/150
# 1/1 - 0s - loss: 0.5814 - val_loss: 0.5721 - 52ms/epoch - 52ms/step
# Epoch 127/150
# 1/1 - 0s - loss: 0.5721 - val_loss: 0.5629 - 53ms/epoch - 53ms/step
# Epoch 128/150
# 1/1 - 0s - loss: 0.5629 - val_loss: 0.5540 - 52ms/epoch - 52ms/step
# Epoch 129/150
# 1/1 - 0s - loss: 0.5540 - val_loss: 0.5453 - 53ms/epoch - 53ms/step
# Epoch 130/150
# 1/1 - 0s - loss: 0.5453 - val_loss: 0.5367 - 54ms/epoch - 54ms/step
# Epoch 131/150
# 1/1 - 0s - loss: 0.5367 - val_loss: 0.5284 - 50ms/epoch - 50ms/step
# Epoch 132/150
# 1/1 - 0s - loss: 0.5284 - val_loss: 0.5203 - 52ms/epoch - 52ms/step
# Epoch 133/150
# 1/1 - 0s - loss: 0.5203 - val_loss: 0.5124 - 63ms/epoch - 63ms/step
# Epoch 134/150
# 1/1 - 0s - loss: 0.5124 - val_loss: 0.5047 - 70ms/epoch - 70ms/step
# Epoch 135/150
# 1/1 - 0s - loss: 0.5047 - val_loss: 0.4971 - 60ms/epoch - 60ms/step
# Epoch 136/150
# 1/1 - 0s - loss: 0.4971 - val_loss: 0.4897 - 52ms/epoch - 52ms/step
# Epoch 137/150
# 1/1 - 0s - loss: 0.4897 - val_loss: 0.4825 - 54ms/epoch - 54ms/step
# Epoch 138/150
# 1/1 - 0s - loss: 0.4825 - val_loss: 0.4755 - 74ms/epoch - 74ms/step
# Epoch 139/150
# 1/1 - 0s - loss: 0.4755 - val_loss: 0.4686 - 61ms/epoch - 61ms/step
# Epoch 140/150
# 1/1 - 0s - loss: 0.4686 - val_loss: 0.4618 - 58ms/epoch - 58ms/step
# Epoch 141/150
# 1/1 - 0s - loss: 0.4618 - val_loss: 0.4553 - 53ms/epoch - 53ms/step
# Epoch 142/150
# 1/1 - 0s - loss: 0.4553 - val_loss: 0.4489 - 53ms/epoch - 53ms/step
# Epoch 143/150
# 1/1 - 0s - loss: 0.4489 - val_loss: 0.4426 - 53ms/epoch - 53ms/step
# Epoch 144/150
# 1/1 - 0s - loss: 0.4426 - val_loss: 0.4364 - 52ms/epoch - 52ms/step
# Epoch 145/150
# 1/1 - 0s - loss: 0.4364 - val_loss: 0.4305 - 54ms/epoch - 54ms/step
# Epoch 146/150
# 1/1 - 0s - loss: 0.4305 - val_loss: 0.4246 - 55ms/epoch - 55ms/step
# Epoch 147/150
# 1/1 - 0s - loss: 0.4246 - val_loss: 0.4189 - 54ms/epoch - 54ms/step
# Epoch 148/150
# 1/1 - 0s - loss: 0.4189 - val_loss: 0.4133 - 59ms/epoch - 59ms/step
# Epoch 149/150
# 1/1 - 0s - loss: 0.4133 - val_loss: 0.4078 - 54ms/epoch - 54ms/step
# Epoch 150/150
# 1/1 - 0s - loss: 0.4078 - val_loss: 0.4024 - 52ms/epoch - 52ms/step
# Text(0.5, 1.0, 'Model loss progress during training and validation')
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'Training and Validation Loss')
# 2/2 [==============================] - 4s 6ms/step
# Train Score: 33.95 RMSE for 150 epochs
#      Train RMSE
# 50    51.758199
# 100   42.465942
# 150   33.950200

# %% [markdown]
# <h4>Forecast the results</h4>

# %%
def forecast_next_weeks(model, look_back, scaler, last_values, n_weeks):
    forecast = []
    input_values = np.array(last_values)
    for _ in range(n_weeks):
        # Scale the input_values to be between 0 and 1
        input_values_scaled = scaler.transform(input_values[-look_back:].reshape(-1, 1))
        
        # Reshape to [samples, time steps, features]
        input_values_scaled = input_values_scaled.reshape((1, 1, look_back))

        # Predict the next value
        prediction = model.predict(input_values_scaled)
        
        # Get last prediction from the sequence
        prediction = prediction[:, -1, :]
        
        # Inverse scale the predicted value
        prediction = scaler.inverse_transform(prediction)
        
        # Append the predicted value to the forecast list
        forecast.append(prediction[0, 0])
        
        # Append the predicted value to the input_values list to be used as input for the next prediction
        input_values = np.append(input_values, prediction)

    return forecast

# %%
# How many weeks you want to forecast
weeks = 20  # approximately equal to 5 months

# Get the last "look_back" values
last_values = list(df_interpolated['RATE'].values[-look_back:])

# Forecast the next weeks
forecasted_values = forecast_next_weeks(model, look_back, scaler, last_values, weeks)

# Get the last date from 'POD'
last_date = df_interpolated['POD'].iloc[-1]

# Create new dates
new_dates = pd.date_range(last_date + pd.DateOffset(weeks=1), periods=weeks, freq='W')

# Create a new DataFrame for the forecasted values
df_forecasted = pd.DataFrame(data={'POD': new_dates, 'RATE': forecasted_values})

# Rounding of the rate nearest 2 decimal point
df_forecasted["RATE"] = df_forecasted["RATE"].round(2)

df_forecasted.head(5)
df_forecasted.tail(5)
df_forecasted.info()
# Out:
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
#          POD       RATE
# 0 2023-05-21  41.450001
# 1 2023-05-28  41.450001
# 2 2023-06-04  41.450001
# 3 2023-06-11  41.450001
# 4 2023-06-18  41.450001
#           POD       RATE
# 15 2023-09-03  41.450001
# 16 2023-09-10  41.450001
# 17 2023-09-17  41.450001
# 18 2023-09-24  41.450001
# 19 2023-10-01  41.450001
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POD     20 non-null     datetime64[ns]
#  1   RATE    20 non-null     float32
# dtypes: datetime64[ns](1), float32(1)
# memory usage: 368.0 bytes

# %% [markdown]
# <h4>Comparing with actual updated against forecasted</h4>

# %%
# # Create an empty DataFrame to store comparison data
# comparison_df = pd.DataFrame(columns=['WeekStart', 'WeekEnd', 'POD_actual', 'RATE_forecasted', 'RATE_actual', 'error', 'accuracy'])
# df_forecasted['WeekEnd'] = df_forecasted['POD'] + pd.to_timedelta(7, unit='d')  

# # Loop over df_forecasted
# for _, row in df_forecasted.iterrows():
#     # Find the actual dates within the week of the forecasted date
#     # Add a 'WeekEnd' column to df_forecasted
#     mask = (new_dates_df['POD'] >= row['POD']) & (new_dates_df['POD'] < row['WeekEnd'])
#     actual_dates_within_week = new_dates_df[mask]

#     # Calculate the error and accuracy for each actual date within the week
#     for _, actual_row in actual_dates_within_week.iterrows():
#         error = abs(actual_row['RATE'] - row['RATE'])
#         error_proportion = error / actual_row['RATE']
#         accuracy = (1 - error_proportion) * 100

#         # Append the data to comparison_df
#         comparison_df = comparison_df.append({
#             'WeekStart': row['POD'],
#             'WeekEnd': row['WeekEnd'],
#             'POD_actual': actual_row['POD'],
#             'RATE_forecasted': row['RATE'],
#             'RATE_actual': actual_row['RATE'],
#             'error': error,
#             'accuracy': accuracy
#         }, ignore_index=True)

# # Remove duplicates based on 'POD_actual', 'RATE_forecasted', and 'RATE_actual'
# comparison_df = comparison_df.drop_duplicates(subset=['POD_actual', 'RATE_forecasted', 'RATE_actual']).reset_index(drop=True)

# # Display the comparison dataframe
# comparison_df
# comparison_df.info()

# total_mean_accuracy = comparison_df['accuracy'].mean()
# print(f'The mean accuracy is {total_mean_accuracy:.2f}%')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Create an empty DataFrame to store comparison data
# ----> 2 comparison_df = pd.DataFrame(columns=['WeekStart', 'WeekEnd', 'POD_actual', 'RATE_forecasted', 'RATE_actual', 'error', 'accuracy'])
#       3 df_forecasted['WeekEnd'] = df_forecasted['POD'] + pd.to_timedelta(7, unit='d')
#       5 # Loop over df_forecasted
#
# NameError: name 'pd' is not defined

# %% [markdown]
# <h4>Visualise all, Conclusion</h4>

# %%
plt.figure(figsize=(20, 10))
plt.plot(sel_df['POD'], sel_df['RATE'], color='blue', label="Actual Data")

plt.plot(df_interpolated['POD'], df_interpolated['RATE'], color='green', label="Aggregated Data")
plt.plot(df_forecasted['POD'], df_forecasted['RATE'], color='red', label="Forecasted Data")

plt.xlabel('Date(Year Month)')
plt.ylabel('Cost Rate(USD)')
plt.title('Port_BUSAN_Size_40_Type_HC_PartyID_010004286')
plt.legend()
plt.show();
