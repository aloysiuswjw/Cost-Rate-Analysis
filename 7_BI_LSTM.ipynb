# %% [markdown]
# <h1>BI-LSTM</h1>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from IPython.core.interactiveshell import InteractiveShell

# LSTM
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.svm import OneClassSVM
from tensorflow.keras.layers import Dropout, LSTM, Dense, RepeatVector, TimeDistributed, Bidirectional
from tensorflow.keras.models import Sequential
from keras.callbacks import EarlyStopping
from sklearn.model_selection import ParameterSampler
from scipy.stats import skew


InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline
sns.set()
pd.options.display.max_rows = 100

# %% [markdown]
# <h4>Importing Datasets</h4>

# %%
# Import dataset and clean, ready as a dataframe for creating keys
def createDF(datasets):
    df = pd.read_csv(datasets, converters={
                     'PARTY_ID': str, 'COM_ID': str, 'CNTR_SIZE': str})

    # Formating to type and remove NaN values
    df['POD'] = pd.to_datetime(df['POD'])
    df['ENCODED_TYPE'] = df['ENCODED_TYPE'].fillna(-1).astype(int)
    df = df.dropna(subset=['ENCODED_TYPE'])
    df['RATE'] = df['RATE'].fillna(-1).astype(float)
    df = df.dropna(subset=['RATE'])
    df['ENCODED_TYPE'] = df['ENCODED_TYPE'].astype(int)
    df_clean = df.dropna().reset_index(drop=True)

    # Selecting and rearranging columns
    sel_col = ['CSL_ID', 'CNTR_ID', 'POD_ID', 'ETD_POL_D', 'PARTY_ID',
               'PARTY_NAME', 'POD', 'CNTR_SIZE', 'CNTR_TYPE', 'RATE']
    df_fc = df_clean[sel_col]

    # Removing years we do not want to process in our models
    df_filtered = df_fc[df_fc['POD'].dt.year != 2002]

    # Sorting the dates
    df_filtered = df_filtered.sort_values(by='POD').reset_index(drop=True)

    return df_filtered

# %%
# Create Dataframes for old and new
old_data = '.\Datasets\CR_COST_FC.csv'
df1 = createDF(old_data)
df1.head()

new_data = '.\Datasets\CR_COST_FC_new.csv'
df2 = createDF(new_data)
df2.head()
# Out:
#            CSL_ID           CNTR_ID          POD_ID ETD_POL_D  PARTY_ID  \
# 0  ECS01050600224  CTNR010050700354       ROTTERDAM     NLRTM  01008827
# 1  ECS01050600610  CTNR010050700353      FELIXSTOWE     GBFXT  01002303
# 2  ECS01050600041  CTNR010050700351        AUCKLAND     NZAKL  01005136
# 3  ECS01050600163  CTNR010050700370    PASIR GUDANG     MYPGU  01002767
# 4  ECS01050600456  CTNR010050700450  KARACHI (KICT)     PKKHI  01002783
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0             YANG MING (SINGAPORE) PTE. LTD. 2005-07-15        40    HC NOR
# 1                    GLOBELINK FALLOW LIMITED 2005-07-15        40        GP
# 2  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-15        40    HC NOR
# 3          GLOBELINK CONTAINER LINES (JB) S/B 2005-07-15        40        HC
# 4                GLOBELINK PAKISTAN (PVT) LTD 2005-07-16        40        HC
#
#      RATE
# 0  1620.0
# 1  1800.0
# 2  2170.0
# 3   280.0
# 4  1625.0
#            CSL_ID           CNTR_ID          POD_ID ETD_POL_D  PARTY_ID  \
# 0  ECS01050600224  CTNR010050700354       ROTTERDAM     NLRTM  01008827
# 1  ECS01050600610  CTNR010050700353      FELIXSTOWE     GBFXT  01002303
# 2  ECS01050600041  CTNR010050700351        AUCKLAND     NZAKL  01005136
# 3  ECS01050600163  CTNR010050700370    PASIR GUDANG     MYPGU  01002767
# 4  ECS01050600456  CTNR010050700450  KARACHI (KICT)     PKKHI  01002783
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0             YANG MING (SINGAPORE) PTE. LTD. 2005-07-15        40    HC NOR
# 1                    GLOBELINK FALLOW LIMITED 2005-07-15        40        GP
# 2  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-15        40    HC NOR
# 3          GLOBELINK CONTAINER LINES (JB) S/B 2005-07-15        40        HC
# 4                GLOBELINK PAKISTAN (PVT) LTD 2005-07-16        40        HC
#
#      RATE
# 0  1620.0
# 1  1800.0
# 2  2170.0
# 3   280.0
# 4  1625.0

# %% [markdown]
# <h4>Creating Dictionary Keys</h4>

# %%
def filter_dataframe(df):
    filtered_dataframes = {}

    for (port, size, ctype, party_id), group in df.groupby(['POD_ID', 'CNTR_SIZE', 'CNTR_TYPE', 'PARTY_ID']):
        group = group.reset_index(drop=True).sort_values(by='POD')
        df_id = f"Port_{port}_Size_{size}_Type_{ctype}_PartyID_{party_id}"
        filtered_dataframes[df_id] = group

    return filtered_dataframes

# %%
# Creating keys from data
print("Old Data keys:")
filtered_dataframe1 = filter_dataframe(df1)
df_ids1 = list(filtered_dataframe1.keys())
print(list(df_ids1))
print(len(list(df_ids1)))

print("\nNew Data keys:")
filtered_dataframe2 = filter_dataframe(df2)
df_ids2 = list(filtered_dataframe2.keys())
print(list(df_ids2))
print(len(list(df_ids2)))
# Out:
# Old Data keys:
# ['Port_(CONSTANZA)_Size_40_Type_GP_PartyID_010007816', 'Port_(CONSTANZA)_Size_40_Type_HC_PartyID_010007816', 'Port_AARHUS_Size_20_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100027830', 'Port_AARHUS_Size_20_Type_GP_PartyID_010006666', 'Port_AARHUS_Size_40_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100027830', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100028193', 'Port_AARHUS_Size_40_Type_HC_PartyID_010006666', 'Port_ABIDJAN_Size_20_Type_GP_PartyID_0100027878', 'Port_ABIDJAN_Size_40_Type_HC_PartyID_010021097', 'Port_ADELAIDE_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01005078', 'Port_ADELAIDE_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ALEXANDRIA (EL DEKHELA PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC NOR_PartyID_010004995', 'Port_ALGECIRAS_Size_20_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC NOR_PartyID_01008306', 'Port_ALIAGA_Size_20_Type_GP_PartyID_01008316', 'Port_ALIAGA_Size_40_Type_HC_PartyID_01008316', 'Port_ALIAGA PORT (IZMIR)_Size_40_Type_HC_PartyID_01008316', 'Port_ANTWERP_Size_20_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC NOR_PartyID_01001449', 'Port_AQABA_Size_20_Type_GP_PartyID_010006618', 'Port_AQABA_Size_20_Type_GP_PartyID_010021081', 'Port_AQABA_Size_40_Type_HC_PartyID_010006618', 'Port_AQABA_Size_40_Type_HC_PartyID_010021081', 'Port_ASHDOD_Size_20_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_01008417', 'Port_ASHDOD_Size_40_Type_HC_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_HC_PartyID_01008417', 'Port_AUCKLAND_Size_20_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_20_Type_GP (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC NOR_PartyID_01005136', 'Port_BANGKOK_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_20_Type_GP (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (SOC)_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK (TST)_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK (TST)_Size_40_Type_HC_PartyID_010021593', 'Port_BARCELONA_Size_20_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC NOR_PartyID_01008305', 'Port_BEIRUT_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_HC_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_40_Type_HC_PartyID_0100 ...
# 789
#
# New Data keys:
# ['Port_(CONSTANZA)_Size_40_Type_GP_PartyID_010007816', 'Port_(CONSTANZA)_Size_40_Type_HC_PartyID_010007816', 'Port_AARHUS_Size_20_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100027830', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100028193', 'Port_AARHUS_Size_20_Type_GP_PartyID_010006666', 'Port_AARHUS_Size_40_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100027830', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100028193', 'Port_AARHUS_Size_40_Type_HC_PartyID_010006666', 'Port_ABIDJAN_Size_20_Type_GP_PartyID_0100027878', 'Port_ABIDJAN_Size_40_Type_HC_PartyID_010021097', 'Port_ADELAIDE_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01005078', 'Port_ADELAIDE_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ALEXANDRIA (EL DEKHELA PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC NOR_PartyID_010004995', 'Port_ALGECIRAS_Size_20_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC NOR_PartyID_01008306', 'Port_ALIAGA_Size_20_Type_GP_PartyID_01008316', 'Port_ALIAGA_Size_40_Type_HC_PartyID_01008316', 'Port_ALIAGA PORT (IZMIR)_Size_40_Type_HC_PartyID_01008316', 'Port_ANTWERP_Size_20_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC NOR_PartyID_01001449', 'Port_AQABA_Size_20_Type_GP_PartyID_010006618', 'Port_AQABA_Size_20_Type_GP_PartyID_010021081', 'Port_AQABA_Size_40_Type_HC_PartyID_010006618', 'Port_AQABA_Size_40_Type_HC_PartyID_010021081', 'Port_ASHDOD_Size_20_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_01008417', 'Port_ASHDOD_Size_40_Type_HC_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_HC_PartyID_01008417', 'Port_AUCKLAND_Size_20_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_20_Type_GP (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC NOR_PartyID_01005136', 'Port_BANGKOK_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_20_Type_GP (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (SOC)_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK (TST)_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK (TST)_Size_40_Type_HC_PartyID_010021593', 'Port_BARCELONA_Size_20_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC NOR_PartyID_01008305', 'Port_BEIRUT_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_HC_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_20_Type_GP_PartyID_010003651', ' ...
# 799

# %% [markdown]
# <h4>Getting ports keys</h4>

# %%
def getKeyPorts(keybunch):
    keybunch_pouch = []

    # Get a dictionary with key and number of rows for each dataframe in keybunch,
    # but only if the number of rows is greater than 1000
    key_row_counts = {key: len(keybunch[key])
                      for key in keybunch if len(keybunch[key]) > 1000}

    # Sort the keys in descending order of the number of rows
    sorted_keys = sorted(key_row_counts, key=key_row_counts.get, reverse=True)

    for key in sorted_keys:
        row_count = key_row_counts[key]
        print(f"Number of rows in {key}: {row_count}")
        keybunch_pouch.append(key)

    # Return array of keys
    return keybunch_pouch


print('Old Dataset Keybunch:')
old_df = getKeyPorts(filtered_dataframe1)
print('\n')

print('New Dataset Keybunch:')
new_df = getKeyPorts(filtered_dataframe2)
# Out:
# Old Dataset Keybunch:
# Number of rows in Port_BUSAN_Size_40_Type_HC_PartyID_010004286: 1689
# Number of rows in Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136: 1688
# Number of rows in Port_MELBOURNE_Size_40_Type_HC_PartyID_01002778: 1325
# Number of rows in Port_SYDNEY_Size_40_Type_HC_PartyID_01002779: 1300
# Number of rows in Port_DUBAI (JEBEL ALI)_Size_40_Type_HC_PartyID_01002788: 1052
#
#
# New Dataset Keybunch:
# Number of rows in Port_BUSAN_Size_40_Type_HC_PartyID_010004286: 1712
# Number of rows in Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136: 1704
# Number of rows in Port_MELBOURNE_Size_40_Type_HC_PartyID_01002778: 1341
# Number of rows in Port_SYDNEY_Size_40_Type_HC_PartyID_01002779: 1308
# Number of rows in Port_DUBAI (JEBEL ALI)_Size_40_Type_HC_PartyID_01002788: 1070

# %% [markdown]
# <h2>Selection of Key</h2>

# %%
# Global selection
sel_country = old_df[0]

# Accessing the highest count in the each keypouch, new and old.
sel_df = filtered_dataframe1[sel_country]
sel_df.head(5)
sel_df.tail(5)
sel_df.info()
print("\n")

latest_sel_df = filtered_dataframe2[sel_country]
latest_sel_df.head(5)
latest_sel_df.tail(5)
latest_sel_df.info()
# Out:
#             CSL_ID           CNTR_ID POD_ID ETD_POL_D   PARTY_ID  \
# 0  ECS010050800407  CTNR010050901151  BUSAN     KRPUS  010004286
# 1  ECS010050800407  CTNR010050901379  BUSAN     KRPUS  010004286
# 2  ECS010050900468  CTNR010051000081  BUSAN     KRPUS  010004286
# 3  ECS010050900468  CTNR010050901461  BUSAN     KRPUS  010004286
# 4  ECS010050900469  CTNR010051000434  BUSAN     KRPUS  010004286
#
#                  PARTY_NAME        POD CNTR_SIZE CNTR_TYPE   RATE
# 0  GLOBELINK KOREA CO., LTD 2005-10-03        40        HC  390.0
# 1  GLOBELINK KOREA CO., LTD 2005-10-03        40        HC  390.0
# 2  GLOBELINK KOREA CO., LTD 2005-10-07        40        HC  390.0
# 3  GLOBELINK KOREA CO., LTD 2005-10-07        40        HC  390.0
# 4  GLOBELINK KOREA CO., LTD 2005-10-14        40        HC  390.0
#                CSL_ID       CNTR_ID POD_ID ETD_POL_D   PARTY_ID  \
# 1684  ECS010230100126  010000391908  BUSAN     KRPUS  010004286
# 1685  ECS010230100126  010000380884  BUSAN     KRPUS  010004286
# 1687  ECS010230100127  010000407833  BUSAN     KRPUS  010004286
# 1686  ECS010230100127  010000390366  BUSAN     KRPUS  010004286
# 1688  ECS010230100127  010000401385  BUSAN     KRPUS  010004286
#
#                     PARTY_NAME        POD CNTR_SIZE CNTR_TYPE   RATE
# 1684  GLOBELINK KOREA CO., LTD 2023-02-22        40        HC  300.0
# 1685  GLOBELINK KOREA CO., LTD 2023-02-22        40        HC  300.0
# 1687  GLOBELINK KOREA CO., LTD 2023-02-28        40        HC  300.0
# 1686  GLOBELINK KOREA CO., LTD 2023-02-28        40        HC  300.0
# 1688  GLOBELINK KOREA CO., LTD 2023-02-28        40        HC  300.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1689 entries, 0 to 1688
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      1689 non-null   object
#  1   CNTR_ID     1689 non-null   object
#  2   POD_ID      1689 non-null   object
#  3   ETD_POL_D   1689 non-null   object
#  4   PARTY_ID    1689 non-null   object
#  5   PARTY_NAME  1689 non-null   object
#  6   POD         1689 non-null   datetime64[ns]
#  7   CNTR_SIZE   1689 non-null   object
#  8   CNTR_TYPE   1689 non-null   object
#  9   RATE        1689 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 145.1+ KB
#             CSL_ID           CNTR_ID POD_ID ETD_POL_D   PARTY_ID  \
# 0  ECS010050800407  CTNR010050901151  BUSAN     KRPUS  010004286
# 1  ECS010050800407  CTNR010050901379  BUSAN     KRPUS  010004286
# 2  ECS010050900468  CTNR010051000081  BUSAN     KRPUS  010004286
# 3  ECS010050900468  CTNR010050901461  BUSAN     KRPUS  010004286
# 4  ECS010050900469  CTNR010051000434  BUSAN     KRPUS  010004286
#
#                  PARTY_NAME        POD CNTR_SIZE CNTR_TYPE   RATE
# 0  GLOBELINK KOREA CO., LTD 2005-10-03        40        HC  390.0
# 1  GLOBELINK KOREA CO., LTD 2005-10-03        40        HC  390.0
# 2  GLOBELINK KOREA CO., LTD 2005-10-07        40        HC  390.0
# 3  GLOBELINK KOREA CO., LTD 2005-10-07        40        HC  390.0
# 4  GLOBELINK KOREA CO., LTD 2005-10-14        40        HC  390.0
#                CSL_ID       CNTR_ID POD_ID ETD_POL_D   PARTY_ID  \
# 1708  ECS010230300113  010000512466  BUSAN     KRPUS  010004286
# 1707  ECS010230300113  010000534846  BUSAN     KRPUS  010004286
# 1709  ECS010230400203  010000544930  BUSAN     KRPUS  010004286
# 1710  ECS010230400183  010000565100  BUSAN     KRPUS  010004286
# 1711  ECS010230400183  010000554335  BUSAN     KRPUS  010004286
#
#                     PARTY_NAME        POD CNTR_SIZE CNTR_TYPE   RATE
# 1708  GLOBELINK KOREA CO., LTD 2023-05-03        40        HC  260.0
# 1707  GLOBELINK KOREA CO., LTD 2023-05-03        40        HC  260.0
# 1709  GLOBELINK KOREA CO., LTD 2023-05-10        40        HC  300.0
# 1710  GLOBELINK KOREA CO., LTD 2023-05-17        40        HC  260.0
# 1711  GLOBELINK KOREA CO., LTD 2023-05-17        40        HC  260.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1712 entries, 0 to 1711
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      1712 non-null   object
#  1   CNTR_ID     1712 non-null   object
#  2   POD_ID      1712 non-null   object
#  3   ETD_POL_D   1712 non-null   object
#  4   PARTY_ID    1712 non-null   object
#  5   PARTY_NAME  1712 non-null   object
#  6   POD         1712 non-null   datetime64[ns]
#  7   CNTR_SIZE   1712 non-null   object
#  8   CNTR_TYPE   1712 non-null   object
#  9   RATE        1712 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 147.1+ KB

# %%
# Select features
sel_feat = ['POD', 'RATE']
# make a copy to avoid SettingWithCopyWarning
sel_feat_df = sel_df[sel_feat].copy()

# %%
plt.figure(figsize=(20, 10))
plt.plot(sel_feat_df['POD'], sel_feat_df['RATE'],
         color='blue', label="Actual Data")
plt.plot(latest_sel_df['POD'], latest_sel_df['RATE'],
         color='red', label="New Actual Data")

plt.xlabel('Date(Year Month Week)')
plt.ylabel('Cost Rate(USD)')
plt.title(sel_country)
plt.legend()
plt.show()
# Out:
# Text(0.5, 0, 'Date(Year Month Week)')
# Text(0, 0.5, 'Cost Rate(USD)')
# Text(0.5, 1.0, 'Port_BUSAN_Size_40_Type_HC_PartyID_010004286')

# %% [markdown]
# <h4>Remove Outliers</h4>

# %%
# Histogram
plt.hist(sel_feat_df['RATE'], bins=30, edgecolor='black')
plt.title("Histogram of RATE")
plt.xlabel("RATE")
plt.ylabel("Frequency")
plt.show()

# Q-Q plot
stats.probplot(sel_feat_df['RATE'], plot=plt)
plt.title("Q-Q plot of RATE")
plt.show()

# Shapiro-Wilk test
print("Shapiro-Wilk test:")
W, p = stats.shapiro(sel_feat_df['RATE'])
print(f"W: {W}, p-value: {p}")

# Anderson-Darling test
print("Anderson-Darling test:")
result = stats.anderson(sel_feat_df['RATE'])
print(f"Statistic: {result.statistic}")
# using a 5% significance level
if result.statistic < result.critical_values[2]:
    print("\n======================================")
    print("\nData looks normal (fail to reject H0)")
    print("Performing Interquartile Range (IQR) to remove outliers...")
    print("======================================\n")

    # IQR
    Q1 = sel_feat_df['RATE'].quantile(0.25)
    Q3 = sel_feat_df['RATE'].quantile(0.75)
    IQR = Q3 - Q1

    # Define bounds for outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Remove outliers
    sel_feat_df = sel_feat_df[(sel_feat_df['RATE'] >= lower_bound) & (
        sel_feat_df['RATE'] <= upper_bound)]

else:
    print("\n======================================")
    print("\nData does not look normal (reject H0)")
    print("Performing z-score of 3 to remove outliers... \n")
    print("======================================\n")

    # z-score
    z_scores = stats.zscore(sel_feat_df['RATE'])
    threshold = 3  # Z-score threshold for outlier detection

    # Remove outliers
    robust_df = sel_feat_df[(np.abs(z_scores) < threshold)]

# Reset the index
robust_df.reset_index(drop=True, inplace=True)

# Print the modified DataFrame
robust_df.head()
robust_df.info()
# Out:
# (array([ 79.,  79., 257., 476., 246., 147.,  10., 120.,  90.,  10.,  21.,
#          60.,   9.,   0.,   2.,   2.,   0.,  15.,   0.,   0.,  12.,   0.,
#          46.,   0.,   0.,   0.,   7.,   0.,   0.,   1.]),
#  array([  10.,   43.,   76.,  109.,  142.,  175.,  208.,  241.,  274.,
#          307.,  340.,  373.,  406.,  439.,  472.,  505.,  538.,  571.,
#          604.,  637.,  670.,  703.,  736.,  769.,  802.,  835.,  868.,
#          901.,  934.,  967., 1000.]),
#  <BarContainer object of 30 artists>)
# Text(0.5, 1.0, 'Histogram of RATE')
# Text(0.5, 0, 'RATE')
# Text(0, 0.5, 'Frequency')
# ((array([-3.34574786, -3.09144144, -2.95019352, ...,  2.95019352,
#           3.09144144,  3.34574786]),
#   array([  10.,   10.,   10., ...,  900.,  900., 1000.])),
#  (128.44807803687263, 185.65719360568386, 0.8514817671330853))
# Text(0.5, 1.0, 'Q-Q plot of RATE')
# Shapiro-Wilk test:
# W: 0.7252808809280396, p-value: 0.0
# Anderson-Darling test:
# Statistic: 139.16692731944386
#
# ======================================
#
# Data does not look normal (reject H0)
# Performing z-score of 3 to remove outliers...
#
# ======================================
#          POD   RATE
# 0 2005-10-03  390.0
# 1 2005-10-03  390.0
# 2 2005-10-07  390.0
# 3 2005-10-07  390.0
# 4 2005-10-14  390.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1623 entries, 0 to 1622
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POD     1623 non-null   datetime64[ns]
#  1   RATE    1623 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 25.5 KB

# %% [markdown]
# <h4>Interpolate missing values in between dates</h4>

# %%
# Interpolate missing values

# Remove duplicated dates and cost rows
robust_df = robust_df.drop_duplicates(
    subset=['POD', 'RATE']).reset_index(drop=True)

# Create a new dataframe with
# a date range from min to max date dataframe
new_df = pd.DataFrame()
new_df['POD'] = pd.date_range(
    start=robust_df['POD'].min(), end=robust_df['POD'].max())

# Merge the original dataframe with the new one.
# Missing dates in the original dataframe will be filled with NaN
df_interpolated = pd.merge(new_df, robust_df, on='POD', how='left')

# Perform interpolation polynomial
df_interpolated['RATE'] = df_interpolated['RATE'].interpolate(
    method='polynomial', order=1)

df_interpolated['RATE'] = df_interpolated['RATE'].round(3)

df_interpolated.head(5)
df_interpolated.tail(5)
df_interpolated.info()
# Out:
#          POD   RATE
# 0 2005-10-03  390.0
# 1 2005-10-04  390.0
# 2 2005-10-05  390.0
# 3 2005-10-06  390.0
# 4 2005-10-07  390.0
#             POD   RATE
# 6366 2023-02-24  300.0
# 6367 2023-02-25  300.0
# 6368 2023-02-26  300.0
# 6369 2023-02-27  300.0
# 6370 2023-02-28  300.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6371 entries, 0 to 6370
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POD     6371 non-null   datetime64[ns]
#  1   RATE    6371 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 149.3 KB

# %% [markdown]
# <h4>Grouping it to week</h4>

# %%
# Group Weekly

# Create YearMonthWeek directly from the 'POD'
df_interpolated['YearMonthWeek'] = df_interpolated['POD'] - \
    pd.to_timedelta(df_interpolated['POD'].dt.dayofweek, unit='D')

# Create a new dataframe with every week in the range
all_weeks = pd.date_range(start=df_interpolated['POD'].min(
), end=df_interpolated['POD'].max(), freq='W')
all_weeks_df = pd.DataFrame(all_weeks, columns=['POD'])

# Create YearMonthWeek in all_weeks_df
all_weeks_df['YearMonthWeek'] = all_weeks_df['POD'] - \
    pd.to_timedelta(all_weeks_df['POD'].dt.dayofweek, unit='D')

# Merge this with the dataframe
merged_df = pd.merge(all_weeks_df, df_interpolated,
                     on=['YearMonthWeek'], how='left')

# group by YearMonthWeek and compute rate
grouped = merged_df.groupby(['YearMonthWeek'])

agg_df = pd.DataFrame(columns=['YearMonthWeek', 'Rate'])

for group_name, group_df in grouped:
    year_month_week = group_name

    # Skip if no data for this week
    if group_df['RATE'].isnull().all():
        continue

    # Calculate sum and skewness of RATE values
    rate_sum = group_df['RATE'].sum()
    rate_skew = group_df['RATE'].skew()

    # Handle summed values with skewness
    if abs(rate_skew) > 0.5:
        rate_metric = group_df['RATE'].median()
    else:
        rate_metric = group_df['RATE'].mean()

    new_row = {
        'YearMonthWeek': year_month_week,
        'Rate': rate_metric
    }

    # Append row to aggregated dataframe
    agg_df = agg_df.append(new_row, ignore_index=True)

agg_df = agg_df.sort_values(by='YearMonthWeek').reset_index(drop=True)
agg_df['Rate'] = agg_df['Rate'].round(2)

agg_df.head(15)
agg_df.tail(15)
agg_df.info()
# Out:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:25: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for group_name, group_df in grouped:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2057257721.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
#    YearMonthWeek   Rate
# 0     2005-10-03  390.0
# 1     2005-10-10  390.0
# 2     2005-10-17  390.0
# 3     2005-10-24  390.0
# 4     2005-10-31  390.0
# 5     2005-11-07  390.0
# 6     2005-11-14  390.0
# 7     2005-11-21  390.0
# 8     2005-11-28  390.0
# 9     2005-12-05  390.0
# 10    2005-12-12  390.0
# 11    2005-12-19  390.0
# 12    2005-12-26  390.0
# 13    2006-01-02  390.0
# 14    2006-01-09  390.0
#     YearMonthWeek    Rate
# 893    2022-11-14  150.00
# 894    2022-11-21  150.00
# 895    2022-11-28  191.43
# 896    2022-12-05  150.00
# 897    2022-12-12  211.54
# 898    2022-12-19  157.69
# 899    2022-12-26  150.00
# 900    2023-01-02  278.57
# 901    2023-01-09  300.00
# 902    2023-01-16  300.00
# 903    2023-01-23  233.33
# 904    2023-01-30  200.00
# 905    2023-02-06  245.24
# 906    2023-02-13  200.00
# 907    2023-02-20  300.00
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908 entries, 0 to 907
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   YearMonthWeek  908 non-null    datetime64[ns]
#  1   Rate           908 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 14.3 KB

# %%
plt.figure(figsize=(20, 10))
plt.plot(sel_df['POD'], sel_df['RATE'], color='blue', label="Actual Data")
plt.plot(agg_df['YearMonthWeek'], agg_df['Rate'],
         color='red', label="Aggregated Data(weeks)")

plt.xlabel('Date(Year Month Week)')
plt.ylabel('Cost Rate(USD)')
plt.title(sel_country)
plt.legend()
plt.show()
# Out:
# Text(0.5, 0, 'Date(Year Month Week)')
# Text(0, 0.5, 'Cost Rate(USD)')
# Text(0.5, 1.0, 'Port_BUSAN_Size_40_Type_HC_PartyID_010004286')

# %% [markdown]
# <h4>Latest datapoints from Latest dataframe for comparing after forecasting (Measure accuracy)</h4>

# %%
max_date_in_old = sel_df['POD'].max()

# Create a new dataframe that only includes rows from the latest
# dataframe where the date is greater than the maximum date in the old dataframe
new_dates_df = latest_sel_df[latest_sel_df['POD']
                             > max_date_in_old].reset_index(drop=True)

# Print the new dataframe
new_dates_df.head(3)
new_dates_df.tail(3)
new_dates_df.info()
# Out:
#             CSL_ID       CNTR_ID POD_ID ETD_POL_D   PARTY_ID  \
# 0  ECS010230200077  010000419950  BUSAN     KRPUS  010004286
# 1  ECS010230200077  010000406570  BUSAN     KRPUS  010004286
# 2  ECS010230200078  010000432251  BUSAN     KRPUS  010004286
#
#                  PARTY_NAME        POD CNTR_SIZE CNTR_TYPE   RATE
# 0  GLOBELINK KOREA CO., LTD 2023-03-08        40        HC  260.0
# 1  GLOBELINK KOREA CO., LTD 2023-03-08        40        HC  260.0
# 2  GLOBELINK KOREA CO., LTD 2023-03-15        40        HC  260.0
#              CSL_ID       CNTR_ID POD_ID ETD_POL_D   PARTY_ID  \
# 20  ECS010230400203  010000544930  BUSAN     KRPUS  010004286
# 21  ECS010230400183  010000565100  BUSAN     KRPUS  010004286
# 22  ECS010230400183  010000554335  BUSAN     KRPUS  010004286
#
#                   PARTY_NAME        POD CNTR_SIZE CNTR_TYPE   RATE
# 20  GLOBELINK KOREA CO., LTD 2023-05-10        40        HC  300.0
# 21  GLOBELINK KOREA CO., LTD 2023-05-17        40        HC  260.0
# 22  GLOBELINK KOREA CO., LTD 2023-05-17        40        HC  260.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      23 non-null     object
#  1   CNTR_ID     23 non-null     object
#  2   POD_ID      23 non-null     object
#  3   ETD_POL_D   23 non-null     object
#  4   PARTY_ID    23 non-null     object
#  5   PARTY_NAME  23 non-null     object
#  6   POD         23 non-null     datetime64[ns]
#  7   CNTR_SIZE   23 non-null     object
#  8   CNTR_TYPE   23 non-null     object
#  9   RATE        23 non-null     float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 1.9+ KB

# %% [markdown]
# <h4>LSTM Regression<h4>

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# Mean Square Error Function:
def calculate_RMSE(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# Update create_dataset to handle multi-feature dataset
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), :]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)


def create_BiLSTM_model(trainX, trainY, testX, testY, epochs, lstm_layers):
    model = Sequential()

    for i in range(len(lstm_layers)):
        if i == 0:
            # First layer specifies the input_shape and returns sequences
            model.add(Bidirectional(LSTM(units=lstm_layers[0], return_sequences=True, input_shape=(
                trainX.shape[1], trainX.shape[2]))))
            model.add(Dropout(0.2))

        elif i == len(lstm_layers) - 1:
            # Last layer doesn't return sequences
            model.add(Bidirectional(LSTM(lstm_layers[i], activation='tanh', kernel_regularizer=l2(
                0.01), return_sequences=False)))

        else:
            # Middle layers return sequences
            model.add(Bidirectional(LSTM(lstm_layers[i], return_sequences=True, activation='tanh',
                                        recurrent_activation='hard_sigmoid', kernel_regularizer=l2(0.01))))
            model.add(Dropout(0.2))

    model.add(Dense(1))
    model.compile(loss='mean_squared_error',
                  optimizer=Adam(learning_rate=0.0005))
    
    # Add early stopping
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)

    # Fit the model and store the history
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=128, verbose=2,
                        validation_data=(testX, testY), callbacks=[es])
    return model, history


def plot_train_val_loss(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model loss progress during training and validation')
    plt.xlabel('Epoch')
    plt.ylabel('Training and Validation Loss')
    plt.legend()
    plt.show()

# %%
# Initialize two separate scalers for normalization
scaler_rate = MinMaxScaler(feature_range=(0, 1))

# Fit and transform 'RATE' and 'during_covid' separately
rate_scaled = scaler_rate.fit_transform(agg_df[['Rate']])

# Concatenate the scaled data
dataset = np.concatenate([rate_scaled], axis=1)

# Split into train and test sets
train_size = int(len(dataset) * 0.7)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size, :], dataset[train_size:len(dataset), :]

# Reshape into X=t and Y=t+1, timestep  look_back
look_back = 5
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# Reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], look_back, trainX.shape[2]))
testX = np.reshape(testX, (testX.shape[0], look_back, testX.shape[2]))

epochs_list = [50, 100, 150, 300]

lstm_layers_list = [
    [64, 64, 32, 32, 16, 16, 8, 8, 4, 4, 2, 2],
    [32, 32, 16, 16, 8, 8, 4, 4, 2, 2],
    [16, 16, 8, 8, 4, 4, 2, 2],
    [8, 8, 4, 4, 2, 2],
    [4, 4, 2, 2],
    [2, 2]
]

rmse_results = {}  # store all rmse results
history_results = {}  # store history for all models

for epochs in epochs_list:
    print(f'Training for {epochs} epochs...')

    for lstm_layers in lstm_layers_list:
        print(f'Training with LSTM layers: {lstm_layers}')
        model, history = create_BiLSTM_model(
            trainX, trainY, testX, testY, epochs, lstm_layers)

        # Add the history to history_results
        history_results[f'{epochs} epochs, {lstm_layers} layers'] = {
            'loss': history.history['loss'],
            'val_loss': history.history['val_loss']
        }

        # Add the loss for this model to the plot
        plt.plot(
            history.history['loss'], label=f'Train Loss - {epochs} epochs, layers: {lstm_layers}')
        plt.plot(
            history.history['val_loss'], label=f'Validation Loss - {epochs} epochs, layers: {lstm_layers}')

        # Evalute LSTM Model
        trainPredict = model.predict(trainX)
        testPredict = model.predict(testX)

        # inverse_transform
        trainPredict = scaler_rate.inverse_transform(trainPredict)
        trainY_orig = scaler_rate.inverse_transform([trainY])
        testPredict = scaler_rate.inverse_transform(testPredict)
        testY_orig = scaler_rate.inverse_transform([testY])

        # Calculate mean squared error
        trainScore = calculate_RMSE(trainY_orig[0], trainPredict[:, 0])
        print(f'Train Score: {trainScore:.2f} RMSE for {epochs} epochs')
        testScore = calculate_RMSE(testY_orig[0], testPredict[:, 0])
        print(f'Test Score: {testScore:.2f} RMSE for {epochs} epochs')

        rmse_results[f'{epochs} epochs, {lstm_layers} layers'] = {
            'Train RMSE': trainScore, 'Test RMSE': testScore}

# Plotting
for key, val in history_results.items():
    plt.plot(val['loss'], label=f'{key} - Train Loss')
    plt.plot(val['val_loss'], label=f'{key} - Validation Loss')

# Configure and show the plot
plt.figure(figsize=(20, 10))
plt.title('Model loss progress during training and validation')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend()
plt.show()

# Convert the dictionary to a DataFrame for easy display
rmse_df = pd.DataFrame(rmse_results).T
print(rmse_df)
# Out:
# Training for 50 epochs...
# Training with LSTM layers: [64, 64, 32, 32, 16, 16, 8, 8, 4, 4, 2, 2]
# Epoch 1/50
# 5/5 - 54s - loss: 11.6368 - val_loss: 11.3110 - 54s/epoch - 11s/step
# Epoch 2/50
# 5/5 - 0s - loss: 11.1348 - val_loss: 10.8206 - 356ms/epoch - 71ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 10.6506 - val_loss: 10.3486 - 354ms/epoch - 71ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 10.1848 - val_loss: 9.8952 - 369ms/epoch - 74ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 9.7376 - val_loss: 9.4606 - 373ms/epoch - 75ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 9.3093 - val_loss: 9.0446 - 353ms/epoch - 71ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 8.8992 - val_loss: 8.6468 - 351ms/epoch - 70ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 8.5072 - val_loss: 8.2668 - 357ms/epoch - 71ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 8.1334 - val_loss: 7.9040 - 362ms/epoch - 72ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 7.7756 - val_loss: 7.5577 - 352ms/epoch - 70ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 7.4344 - val_loss: 7.2274 - 349ms/epoch - 70ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 7.1093 - val_loss: 6.9124 - 377ms/epoch - 75ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 6.7985 - val_loss: 6.6120 - 347ms/epoch - 69ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 6.5025 - val_loss: 6.3255 - 362ms/epoch - 72ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 6.2202 - val_loss: 6.0525 - 353ms/epoch - 71ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 5.9511 - val_loss: 5.7922 - 345ms/epoch - 69ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 5.6954 - val_loss: 5.5442 - 349ms/epoch - 70ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 5.4503 - val_loss: 5.3077 - 346ms/epoch - 69ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 5.2167 - val_loss: 5.0823 - 351ms/epoch - 70ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 4.9956 - val_loss: 4.8674 - 368ms/epoch - 74ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 4.7839 - val_loss: 4.6624 - 348ms/epoch - 70ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 4.5814 - val_loss: 4.4668 - 386ms/epoch - 77ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 4.3886 - val_loss: 4.2801 - 342ms/epoch - 68ms/step
# Epoch 24/50
# 5/5 - 0s - loss:
ms/step
# 20/20 [==============================] - 1s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# Train Score: 85.13 RMSE for 50 epochs
# Test Score: 98.23 RMSE for 50 epochs
# Training for 100 epochs...
# Training with LSTM layers: [64, 64, 32, 32, 16, 16, 8, 8, 4, 4, 2, 2]
# Epoch 1/100
# 5/5 - 55s - loss: 11.6256 - val_loss: 11.3013 - 55s/epoch - 11s/step
# Epoch 2/100
# 5/5 - 0s - loss: 11.1266 - val_loss: 10.8137 - 346ms/epoch - 69ms/step
# Epoch 3/100
# 5/5 - 0s - loss: 10.6453 - val_loss: 10.3442 - 346ms/epoch - 69ms/step
# Epoch 4/100
# 5/5 - 0s - loss: 10.1823 - val_loss: 9.8933 - 338ms/epoch - 68ms/step
# Epoch 5/100
# 5/5 - 0s - loss: 9.7379 - val_loss: 9.4610 - 344ms/epoch - 69ms/step
# Epoch 6/100
# 5/5 - 0s - loss: 9.3121 - val_loss: 9.0470 - 339ms/epoch - 68ms/step
# Epoch 7/100
# 5/5 - 0s - loss: 8.9046 - val_loss: 8.6512 - 343ms/epoch - 69ms/step
# Epoch 8/100
# 5/5 - 0s - loss: 8.5149 - val_loss: 8.2729 - 345ms/epoch - 69ms/step
# Epoch 9/100
# 5/5 - 0s - loss: 8.1425 - val_loss: 7.9116 - 365ms/epoch - 73ms/step
# Epoch 10/100
# 5/5 - 0s - loss: 7.7865 - val_loss: 7.5665 - 381ms/epoch - 76ms/step
# Epoch 11/100
# 5/5 - 0s - loss: 7.4468 - val_loss: 7.2372 - 379ms/epoch - 76ms/step
# Epoch 12/100
# 5/5 - 0s - loss: 7.1228 - val_loss: 6.9228 - 375ms/epoch - 75ms/step
# Epoch 13/100
# 5/5 - 0s - loss: 6.8129 - val_loss: 6.6228 - 382ms/epoch - 76ms/step
# Epoch 14/100
# 5/5 - 0s - loss: 6.5173 - val_loss: 6.3364 - 373ms/epoch - 75ms/step
# Epoch 15/100
# 5/5 - 0s - loss: 6.2353 - val_loss: 6.0633 - 351ms/epoch - 70ms/step
# Epoch 16/100
# 5/5 - 0s - loss: 5.9662 - val_loss: 5.8026 - 342ms/epoch - 68ms/step
# Epoch 17/100
# 5/5 - 0s - loss: 5.7089 - val_loss: 5.5540 - 340ms/epoch - 68ms/step
# Epoch 18/100
# 5/5 - 0s - loss: 5.4642 - val_loss: 5.3168 - 340ms/epoch - 68ms/step
# Epoch 19/100
# 5/5 - 0s - loss: 5.2301 - val_loss: 5.0905 - 346ms/epoch - 69ms/step
# Epoch 20/100
# 5/5 - 0s - loss: 5.0074 - val_loss: 4.8748 - 336ms/epoch - 67ms/step
# Epoch 21/100
# 5/5 - 0s - loss: 4.7944 - val_loss: 4.6692 - 344ms/epoch - 69ms/step
# Epoch 22/100
# 5/5 - 0s - loss: 4.5921 - val_loss: 4.4730 - 334ms/epoch - 67ms/step
# Epoch 23/100
# 5/5 - 0s - loss: 4.3988 - val_loss: 4.2860 - 333ms/epoch - 67ms/step
# Epoch 24/100
# 5/5 - 0s - loss: 4.2142 - val_loss: 4.1077 - 340ms/epoch - 68ms/step
# Epoch 25/100
# 5/5 - 0s - loss: 4.0384 - val_loss: 3.9375 - 364ms/epoch - 73ms/step
# Epoch 26/100
# 5/5 - 0s - loss: 3.8704 - val_loss: 3.7752 - 353ms/epoch - 71ms/step
# Epoch 27/100
# 5/5 - 0s - loss: 3.7100 - val_loss: 3.6203 - 349ms/epoch - 70ms/step
# Epoch 28/100
# 5/5 - 0s - loss: 3.5577 - val_loss: 3.4723 - 337ms/epoch - 67ms/step
# Epoch 29/100
# 5/5 - 0s - loss: 3.4123 - val_loss: 3.3311 - 333ms/epoch - 67ms/step
# Epoch 30/100
# 5/5 - 0s - loss: 3.2731 - val_loss: 3.1962 - 360ms/epoch - 72ms/step
# Epoch 31/100
# 5/5 - 0s - loss: 3.1400 - val_loss: 3.0673 - 334ms/epoch - 67ms/step
# Epoch 32/100
# 5/5 - 0s - loss: 3.0132 - val_loss: 2.9442 - 340ms/epoch - 68ms/step
# Epoch 33/100
# 5/5 - 0s - loss: 2.8925 - val_loss: 2.8266 - 338ms/epoch - 68ms/step
# Epoch 34/100
# 5/5 - 0s - loss: 2.7766 - val_loss: 2.7142 - 335ms/epoch - 67ms/step
# Epoch 35/100
# 5/5 - 0s - loss: 2.6660 - val_loss: 2.6069 - 340ms/epoch - 68ms/step
# Epoch 36/100
# 5/5 - 0s - loss: 2.5607 - val_loss: 2.5044 - 406ms/epoch - 81ms/step
# Epoch 37/100
# 5/5 - 0s - loss: 2.4594 - val_loss: 2.4064 - 368ms/epoch - 74ms/step
# Epoch 38/100
# 5/5 - 0s - loss: 2.3635 - val_loss: 2.3128 - 358ms/epoch - 72ms/step
# Epoch 39/100
# 5/5 - 0s - loss: 2.2715 - val_loss: 2.2234 - 344ms/epoch - 69ms/step
# Epoch 40/100
# 5/5 - 0s - loss: 2.1837 - val_loss: 2.1379 - 346ms/epoch - 69ms/step
# Epoch 41/100
# 5/5 - 0s - loss: 2.0998 - val_loss: 2.0563 - 365ms/epoch - 73ms/step
# Epoch 42/100
# 5/5 - 0s - loss: 2.0193 - val_loss: 1.9782 - 346ms/epoch - 69ms/step
# Epoch 43/100
# 5/5 - 0s - loss: 1.9429 - val_loss: 1.9036 - 361ms/epoch - 72ms/step
# Epoch 44/100
# 5/5 - 0s - loss: 1.8690 - val_loss: 1.8324 - 363ms/epoch - 73ms/step
# Epoch 45/100
# 5/5 - 0s - loss: 1.7992 - val_loss: 1.7642 - 370ms/epoch - 74ms/step
# Epoch 46/100
# 5/5 - 0s - loss: 1.7320 - val_loss: 1.6991 - 344ms/epoch - 69ms/step
# Epoch 47/100
# 5/5 - 0s - loss: 1.6681 - val_loss: 1.6367 - 343ms/epoch - 69ms/step
# Epoch 48/100
# 5/5 - 0s - loss: 1.6065 - val_loss: 1.5771 - 341ms/epoch - 68ms/step
# Epoch 49/100
# 5/5 - 0s - loss: 1.5478 - val_loss: 1.5202 - 352ms/epoch - 70ms/step
# Epoch 50/100
# 5/5 - 0s - loss: 1.4925 - val_loss: 1.4657 - 340ms/epoch - 68ms/step
# Epoch 51/100
# 5/5 - 0s - loss: 1.4387 - val_loss: 1.4135 - 344ms/epoch - 69ms/step
# Epoch 52/100
# 5/5 - 0s - loss: 1.3871 - val_loss: 1.3635 - 342ms/epoch - 68ms/step
# Epoch 53/100
# 5/5 - 0s - loss: 1.3381 - val_loss: 1.3158 - 346ms/epoch - 69ms/step
# Epoch 54/100
# 5/5 - 0s - loss: 1.2912 - val_loss: 1.2700 - 347ms/epoch - 69ms/step
# Epoch 55/100
# 5/5 - 0s - loss: 1.2460 - val_loss: 1.2262 - 331ms/epoch - 66ms/step
# Epoch 56/100
# 5/5 - 0s - loss: 1.2035 - val_loss: 1.1842 - 351ms/epoch - 70ms/step
# Epoch 57/100
# 5/5 - 0s - loss: 1.1616 - val_loss: 1.1441 - 334ms/epoch - 67ms/step
# Epoch 58/100
# 5/5 - 0s - loss: 1.1218 - val_loss: 1.1055 - 334ms/epoch - 67ms/step
# Epoch 59/100
# 5/5 - 0s - loss: 1.0840 - val_loss: 1.0686 - 343ms/epoch - 69ms/step
# Epoch 60/100
# 5/5 - 0s - loss: 1.0478 - val_loss: 1.0333 - 350ms/epoch - 70ms/step
# Epoch 61/100
# 5/5 - 0s - loss: 1.0134 - val_loss: 0.9994 - 356ms/epoch - 71ms/step
# Epoch 62/100
# 5/5 - 0s - loss: 0.9802 - val_loss: 0.9669 - 354ms/epoch - 71ms/step
# Epoch 63/100
# 5/5 - 0s - loss: 0.9484 - val_loss: 0.9356 - 354ms/epoch - 71ms/step
# Epoch 64/100
# 5/5 - 0s - loss: 0.9168 - val_loss: 0.9057 - 346ms/epoch - 69ms/step
# Epoch 65/100
# 5/5 - 0s - loss: 0.8872 - val_loss: 0.8770 - 380ms/epoch - 76ms/step
# Epoch 66/100
# 5/5 - 0s - loss: 0.8596 - val_loss: 0.8494 - 372ms/epoch - 74ms/step
# Epoch 67/100
# 5/5 - 0s - loss: 0.8324 - val_loss: 0.8229 - 338ms/epoch - 68ms/step
# Epoch 68/100
# 5/5 - 0s - loss: 0.8060 - val_loss: 0.7975 - 357ms/epoch - 71ms/step
# Epoch 69/100
# 5/5 - 0s - loss: 0.7807 - val_loss: 0.7731 - 334ms/epoch - 67ms/step
# Epoch 70/100
# 5/5 - 0s - loss: 0.7568 - val_loss: 0.7496 - 338ms/epoch - 68ms/step
# Epoch 71/100
# 5/5 - 0s - loss: 0.7340 - val_loss: 0.7271 - 333ms/epoch - 67ms/step
# Epoch 72/100
# 5/5 - 0s - loss: 0.7116 - val_loss: 0.7054 - 334ms/epoch - 67ms/step
# Epoch 73/100
# 5/5 - 0s - loss: 0.6907 - val_loss: 0.6846 - 333ms/epoch - 67ms/step
# Epoch 74/100
# 5/5 - 0s - loss: 0.6696 - val_loss: 0.6645 - 337ms/epoch - 67ms/step
# Epoch 75/100
# 5/5 - 0s - loss: 0.6500 - val_loss: 0.6452 - 337ms/epoch - 67ms/step
# Epoch 76/100
# 5/5 - 0s - loss: 0.6305 - val_loss: 0.6267 - 331ms/epoch - 66ms/step
# Epoch 77/100
# 5/5 - 0s - loss: 0.6128 - val_loss: 0.6087 - 334ms/epoch - 67ms/step
# Epoch 78/100
# 5/5 - 0s - loss: 0.5949 - val_loss: 0.5915 - 331ms/epoch - 66ms/step
# Epoch 79/100
# 5/5 - 0s - loss: 0.5782 - val_loss: 0.5749 - 335ms/epoch - 67ms/step
# Epoch 80/100
# 5/5 - 0s - loss: 0.5615 - val_loss: 0.5589 - 353ms/epoch - 71ms/step
# Epoch 81/100
# 5/5 - 0s - loss: 0.5461 - val_loss: 0.5435 - 345ms/epoch - 69ms/step
# Epoch 82/100
# 5/5 - 0s - loss: 0.5305 - val_loss: 0.5287 - 351ms/epoch - 70ms/step
# Epoch 83/100
# 5/5 - 0s - loss: 0.5159 - val_loss: 0.5144 - 345ms/epoch - 69ms/step
# Epoch 84/100
# 5/5 - 0s - loss: 0.5020 - val_loss: 0.5006 - 336ms/epoch - 67ms/step
# Epoch 85/100
# 5/5 - 0s - loss: 0.4884 - val_loss: 0.4873 - 336ms/epoch - 67ms/step
# Epoch 86/100
# 5/5 - 0s - loss: 0.4752 - val_loss: 0.4744 - 336ms/epoch - 67ms/step
# Epoch 87/100
# 5/5 - 0s - loss: 0.4625 - val_loss: 0.4620 - 336ms/epoch - 67ms/step
# Epoch 88/100
# 5/5 - 0s - loss: 0.4499 - val_loss: 0.4500 - 330ms/epoch - 66ms/step
# Epoch 89/100
# 5/5 - 0s - loss: 0.4383 - val_loss: 0.4384 - 337ms/epoch - 67ms/step
# Epoch 90/100
# 5/5 - 0s - loss: 0.4271 - val_loss: 0.4272 - 332ms/epoch - 66ms/step
# Epoch 91/100
# 5/5 - 0s - loss: 0.4158 - val_loss: 0.4164 - 334ms/epoch - 67ms/step
# Epoch 92/100
# 5/5 - 0s - loss: 0.4051 - val_loss: 0.4059 - 340ms/epoch - 68ms/step
# Epoch 93/100
# 5/5 - 0s - loss: 0.3949 - val_loss: 0.3958 - 332ms/epoch - 66ms/step
# Epoch 94/100
# 5/5 - 0s - loss: 0.3846 - val_loss: 0.3860 - 333ms/epoch - 67ms/step
# Epoch 95/100
# 5/5 - 0s - loss: 0.3752 - val_loss: 0.3766 - 338ms/epoch - 68ms/step
# Epoch 96/100
# 5/5 - 0s - loss: 0.3659 - val_loss: 0.3675 - 349ms/epoch - 70ms/step
# Epoch 97/100
# 5/5 - 0s - loss: 0.3571 - val_loss: 0.3586 - 341ms/epoch - 68ms/step
# Epoch 98/100
# 5/5 - 0s - loss: 0.3480 - val_loss: 0.3500 - 335ms/epoch - 67ms/step
# Epoch 99/100
# 5/5 - 0s - loss: 0.3397 - val_loss: 0.3418 - 335ms/epoch - 67ms/step
# Epoch 100/100
# 5/5 - 0s - loss: 0.3312 - val_loss: 0.3337 - 336ms/epoch - 67ms/step
# 20/20 [==============================] - 5s 9ms/step
# 9/9 [==============================] - 0s 8ms/step
# Train Score: 97.27 RMSE for 100 epochs
# Test Score: 109.62 RMSE for 100 epochs
# Training with LSTM layers: [32, 32, 16, 16, 8, 8, 4, 4, 2, 2]
# Epoch 1/100
# 5/5 - 46s - loss: 5.8044 - val_loss: 5.6737 - 46s/epoch - 9s/step
# Epoch 2/100
# 5/5 - 0s - loss: 5.6205 - val_loss: 5.4937 - 232ms/epoch - 46ms/step
# Epoch 3/100
# 5/5 - 0s - loss: 5.4415 - val_loss: 5.3186 - 231ms/epoch - 46ms/step
# Epoch 4/100
# 5/5 - 0s - loss: 5.2673 - val_loss: 5.1487 - 232ms/epoch - 46ms/step
# Epoch 5/100
# 5/5 - 0s - loss: 5.0983 - val_loss: 4.9838 - 233ms/epoch - 47ms/step
# Epoch 6/100
# 5/5 - 0s - loss: 4.9344 - val_loss: 4.8242 - 233ms/epoch - 47ms/step
# Epoch 7/100
# 5/5 - 0s - loss: 4.7752 - val_loss: 4.6696 - 225ms/epoch - 45ms/step
# Epoch 8/100
# 5/5 - 0s - loss: 4.6218 - val_loss: 4.5201 - 231ms/epoch - 46ms/step
# Epoch 9/100
# 5/5 - 0s - loss: 4.4732 - val_loss: 4.3755 - 231ms/epoch - 46ms/step
# Epoch 10/100
# 5/5 - 0s - loss: 4.3295 - val_loss: 4.2358 - 226ms/epoch - 45ms/step
# Epoch 11/100
# 5/5 - 0s - loss: 4.1905 - val_loss: 4.1009 - 229ms/epoch - 46ms/step
# Epoch 12/100
# 5/5 - 0s - loss: 4.0562 - val_loss: 3.9706 - 225ms/epoch - 45ms/step
# Epoch 13/100
# 5/5 - 0s - loss: 3.9268 - val_loss: 3.8448 - 233ms/epoch - 47ms/step
# Epoch 14/100
# 5/5 - 0s - loss: 3.8015 - val_loss: 3.7234 - 263ms/epoch - 53ms/step
# Epoch 15/100
# 5/5 - 0s - loss: 3.6810 - val_loss: 3.6063 - 248ms/epoch - 50ms/step
# Epoch 16/100
# 5/5 - 0s - loss: 3.5644 - val_loss: 3.4932 - 239ms/epoch - 48ms/step
# Epoch 17/100
# 5/5 - 0s - loss: 3.4513 - val_loss: 3.3842 - 234ms/epoch - 47ms/step
# Epoch 18/100
# 5/5 - 0s - loss: 3.3433 - val_loss: 3.2789 - 242ms/epoch - 48ms/step
# Epoch 19/100
# 5/5 - 0s - loss: 3.2381 - val_loss: 3.1773 - 236ms/epoch - 47ms/step
# Epoch 20/100
# 5/5 - 0s - loss: 3.1373 - val_loss: 3.0791 - 255ms/epoch - 51ms/step
# Epoch 21/100
# 5/5 - 0s - loss: 3.0397 - val_loss: 2.9843 - 233ms/epoch - 47ms/step
# Epoch 22/100
# 5/5 - 0s - loss: 2.9451 - val_loss: 2.8926 - 230ms/epoch - 46ms/step
# Epoch 23/100
# 5/5 - 0s - loss: 2.8545 - val_loss: 2.8039 - 234ms/epoch - 47ms/step
# Epoch 24/100
# 5/5 - 0s - loss: 2.7660 - val_loss: 2.7181 - 228ms/epoch - 46ms/step
# Epoch 25/100
# 5/5 - 0s - loss: 2.6812 - val_loss: 2.6350 - 224ms/epoch - 45ms/step
# Epoch 26/100
# 5/5 - 0s - loss: 2.5990 - val_loss: 2.5546 - 229ms/epoch - 46ms/step
# Epoch 27/100
# 5/5 - 0s - loss: 2.5192 - val_loss: 2.4767 - 228ms/epoch - 46ms/step
# Epoch 28/100
# 5/5 - 0s - loss: 2.4426 - val_loss: 2.4013 - 228ms/epoch - 46ms/step
# Epoch 29/100
# 5/5 - 0s - loss: 2.3675 - val_loss: 2.3282 - 230ms/epoch - 46ms/step
# Epoch 30/100
# 5/5 - 0s - loss: 2.2949 - val_loss: 2.2575 - 223ms/epoch - 45ms/step
# Epoch 31/100
# 5/5 - 0s - loss: 2.2258 - val_loss: 2.1891 - 226ms/epoch - 45ms/step
# Epoch 32/100
# 5/5 - 0s - loss: 2.1575 - val_loss: 2.1228 - 225ms/epoch - 45ms/step
# Epoch 33/100
# 5/5 - 0s - loss: 2.0927 - val_loss: 2.0586 - 228ms/epoch - 46ms/step
# Epoch 34/100
# 5/5 - 0s - loss: 2.0285 - val_loss: 1.9964 - 231ms/epoch - 46ms/step
# Epoch 35/100
# 5/5 - 0s - loss: 1.9674 - val_loss: 1.9363 - 256ms/epoch - 51ms/step
# Epoch 36/100
# 5/5 - 0s - loss: 1.9078 - val_loss: 1.8781 - 234ms/epoch - 47ms/step
# Epoch 37/100
# 5/5 - 0s - loss: 1.8502 - val_loss: 1.8218 - 240ms/epoch - 48ms/step
# Epoch 38/100
# 5/5 - 0s - loss: 1.7944 - val_loss: 1.7672 - 226ms/epoch - 45ms/step
# Epoch 39/100
# 5/5 - 0s - loss: 1.7409 - val_loss: 1.7144 - 228ms/epoch - 46ms/step
# Epoch 40/100
# 5/5 - 0s - loss: 1.6883 - val_loss: 1.6633 - 232ms/epoch - 46ms/step
# Epoch 41/100
# 5/5 - 0s - loss: 1.6383 - val_loss: 1.6139 - 227ms/epoch - 45ms/step
# Epoch 42/100
# 5/5 - 0s - loss: 1.5890 - val_loss: 1.5661 - 229ms/epoch - 46ms/step
# Epoch 43/100
# 5/5 - 0s - loss: 1.5423 - val_loss: 1.5197 - 225ms/epoch - 45ms/step
# Epoch 44/100
# 5/5 - 0s - loss: 1.4967 - val_loss: 1.4749 - 227ms/epoch - 45ms/step
# Epoch 45/100
# 5/5 - 0s - loss: 1.4521 - val_loss: 1.4315 - 225ms/epoch - 45ms/step
# Epoch 46/100
# 5/5 - 0s - loss: 1.4086 - val_loss: 1.3894 - 227ms/epoch - 45ms/step
# Epoch 47/100
# 5/5 - 0s - loss: 1.3681 - val_loss: 1.3487 - 229ms/epoch - 46ms/step
# Epoch 48/100
# 5/5 - 0s - loss: 1.3267 - val_loss: 1.3093 - 231ms/epoch - 46ms/step
# Epoch 49/100
# 5/5 - 0s - loss: 1.2880 - val_loss: 1.2712 - 231ms/epoch - 46ms/step
# Epoch 50/100
# 5/5 - 0s - loss: 1.2516 - val_loss: 1.2344 - 233ms/epoch - 47ms/step
# Epoch 51/100
# 5/5 - 0s - loss: 1.2146 - val_loss: 1.1987 - 230ms/epoch - 46ms/step
# Epoch 52/100
# 5/5 - 0s - loss: 1.1784 - val_loss: 1.1641 - 240ms/epoch - 48ms/step
# Epoch 53/100
# 5/5 - 0s - loss: 1.1447 - val_loss: 1.1306 - 235ms/epoch - 47ms/step
# Epoch 54/100
# 5/5 - 0s - loss: 1.1115 - val_loss: 1.0982 - 227ms/epoch - 45ms/step
# Epoch 55/100
# 5/5 - 0s - loss: 1.0797 - val_loss: 1.0669 - 236ms/epoch - 47ms/step
# Epoch 56/100
# 5/5 - 0s - loss: 1.0490 - val_loss: 1.0365 - 230ms/epoch - 46ms/step
# Epoch 57/100
# 5/5 - 0s - loss: 1.0181 - val_loss: 1.0071 - 248ms/epoch - 50ms/step
# Epoch 58/100
# 5/5 - 0s - loss: 0.9897 - val_loss: 0.9787 - 242ms/epoch - 48ms/step
# Epoch 59/100
# 5/5 - 0s - loss: 0.9617 - val_loss: 0.9512 - 248ms/epoch - 50ms/step
# Epoch 60/100
# 5/5 - 0s - loss: 0.9343 - val_loss: 0.9245 - 233ms/epoch - 47ms/step
# Epoch 61/100
# 5/5 - 0s - loss: 0.9079 - val_loss: 0.8987 - 244ms/epoch - 49ms/step
# Epoch 62/100
# 5/5 - 0s - loss: 0.8825 - val_loss: 0.8737 - 241ms/epoch - 48ms/step
# Epoch 63/100
# 5/5 - 0s - loss: 0.8581 - val_loss: 0.8495 - 232ms/epoch - 46ms/step
# Epoch 64/100
# 5/5 - 0s - loss: 0.8340 - val_loss: 0.8260 - 242ms/epoch - 48ms/step
# Epoch 65/100
# 5/5 - 0s - loss: 0.8106 - val_loss: 0.8033 - 242ms/epoch - 48ms/step
# Epoch 66/100
# 5/5 - 0s - loss: 0.7884 - val_loss: 0.7813 - 231ms/epoch - 46ms/step
# Epoch 67/100
# 5/5 - 0s - loss: 0.7662 - val_loss: 0.7601 - 255ms/epoch - 51ms/step
# Epoch 68/100
# 5/5 - 0s - loss: 0.7460 - val_loss: 0.7395 - 242ms/epoch - 48ms/step
# Epoch 69/100
# 5/5 - 0s - loss: 0.7247 - val_loss: 0.7195 - 237ms/epoch - 47ms/step
# Epoch 70/100
# 5/5 - 0s - loss: 0.7051 - val_loss: 0.7002 - 240ms/epoch - 48ms/step
# Epoch 71/100
# 5/5 - 0s - loss: 0.6863 - val_loss: 0.6815 - 232ms/epoch - 46ms/step
# Epoch 72/100
# 5/5 - 0s - loss: 0.6677 - val_loss: 0.6634 - 238ms/epoch - 48ms/step
# Epoch 73/100
# 5/5 - 0s - loss: 0.6499 - val_loss: 0.6458 - 256ms/epoch - 51ms/step
# Epoch 74/100
# 5/5 - 0s - loss: 0.6327 - val_loss: 0.6288 - 246ms/epoch - 49ms/step
# Epoch 75/100
# 5/5 - 0s - loss: 0.6158 - val_loss: 0.6123 - 239ms/epoch - 48ms/step
# Epoch 76/100
# 5/5 - 0s - loss: 0.5993 - val_loss: 0.5963 - 243ms/epoch - 49ms/step
# Epoch 77/100
# 5/5 - 0s - loss: 0.5832 - val_loss: 0.5809 - 248ms/epoch - 50ms/step
# Epoch 78/100
# 5/5 - 0s - loss: 0.5682 - val_loss: 0.5659 - 243ms/epoch - 49ms/step
# Epoch 79/100
# 5/5 - 0s - loss: 0.5536 - val_loss: 0.5514 - 245ms/epoch - 49ms/step
# Epoch 80/100
# 5/5 - 0s - loss: 0.5388 - val_loss: 0.5373 - 239ms/epoch - 48ms/step
# Epoch 81/100
# 5/5 - 0s - loss: 0.5250 - val_loss: 0.5237 - 243ms/epoch - 49ms/step
# Epoch 82/100
# 5/5 - 0s - loss: 0.5113 - val_loss: 0.5104 - 231ms/epoch - 46ms/step
# Epoch 83/100
# 5/5 - 0s - loss: 0.4987 - val_loss: 0.4976 - 234ms/epoch - 47ms/step
# Epoch 84/100
# 5/5 - 0s - loss: 0.4859 - val_loss: 0.4852 - 242ms/epoch - 48ms/step
# Epoch 85/100
# 5/5 - 0s - loss: 0.4736 - val_loss: 0.4731 - 241ms/epoch - 48ms/step
# Epoch 86/100
# 5/5 - 0s - loss: 0.4617 - val_loss: 0.4615 - 238ms/epoch - 48ms/step
# Epoch 87/100
# 5/5 - 0s - loss: 0.4501 - val_loss: 0.4501 - 247ms/epoch - 49ms/step
# Epoch 88/100
# 5/5 - 0s - loss: 0.4389 - val_loss: 0.4391 - 236ms/epoch - 47ms/step
# Epoch 89/100
# 5/5 - 0s - loss: 0.4276 - val_loss: 0.4285 - 224ms/epoch - 45ms/step
# Epoch 90/100
# 5/5 - 0s - loss: 0.4175 - val_loss: 0.4181 - 228ms/epoch - 46ms/step
# Epoch 91/100
# 5/5 - 0s - loss: 0.4070 - val_loss: 0.4081 - 228ms/epoch - 46ms/step
# Epoch 92/100
# 5/5 - 0s - loss: 0.3972 - val_loss: 0.3984 - 224ms/epoch - 45ms/step
# Epoch 93/100
# 5/5 - 0s - loss: 0.3880 - val_loss: 0.3890 - 230ms/epoch - 46ms/step
# Epoch 94/100
# 5/5 - 0s - loss: 0.3782 - val_loss: 0.3798 - 232ms/epoch - 46ms/step
# Epoch 95/100
# 5/5 - 0s - loss: 0.3695 - val_loss: 0.3709 - 227ms/epoch - 45ms/step
# Epoch 96/100
# 5/5 - 0s - loss: 0.3608 - val_loss: 0.3623 - 230ms/epoch - 46ms/step
# Epoch 97/100
# 5/5 - 0s - loss: 0.3521 - val_loss: 0.3540 - 226ms/epoch - 45ms/step
# Epoch 98/100
# 5/5 - 0s - loss: 0.3439 - val_loss: 0.3458 - 228ms/epoch - 46ms/step
# Epoch 99/100
# 5/5 - 0s - loss: 0.3356 - val_loss: 0.3379 - 229ms/epoch - 46ms/step
# Epoch 100/100
# 5/5 - 0s - loss: 0.3285 - val_loss: 0.3303 - 227ms/epoch - 45ms/step
# 20/20 [==============================] - 4s 7ms/step
# 9/9 [==============================] - 0s 6ms/step
# Train Score: 97.28 RMSE for 100 epochs
# Test Score: 109.52 RMSE for 100 epochs
# Training with LSTM layers: [16, 16, 8, 8, 4, 4, 2, 2]
# Epoch 1/100
# 5/5 - 37s - loss: 2.8199 - val_loss: 2.7606 - 37s/epoch - 7s/step
# Epoch 2/100
# 5/5 - 0s - loss: 2.7533 - val_loss: 2.6955 - 177ms/epoch - 35ms/step
# Epoch 3/100
# 5/5 - 0s - loss: 2.6879 - val_loss: 2.6315 - 179ms/epoch - 36ms/step
# Epoch 4/100
# 5/5 - 0s - loss: 2.6237 - val_loss: 2.5689 - 176ms/epoch - 35ms/step
# Epoch 5/100
# 5/5 - 0s - loss: 2.5608 - val_loss: 2.5076 - 176ms/epoch - 35ms/step
# Epoch 6/100
# 5/5 - 0s - loss: 2.4991 - val_loss: 2.4476 - 178ms/epoch - 36ms/step
# Epoch 7/100
# 5/5 - 0s - loss: 2.4388 - val_loss: 2.3889 - 177ms/epoch - 35ms/step
# Epoch 8/100
# 5/5 - 0s - loss: 2.3801 - val_loss: 2.3316 - 174ms/epoch - 35ms/step
# Epoch 9/100
# 5/5 - 0s - loss: 2.3221 - val_loss: 2.2756 - 171ms/epoch - 34ms/step
# Epoch 10/100
# 5/5 - 0s - loss: 2.2659 - val_loss: 2.2209 - 174ms/epoch - 35ms/step
# Epoch 11/100
# 5/5 - 0s - loss: 2.2112 - val_loss: 2.1675 - 173ms/epoch - 35ms/step
# Epoch 12/100
# 5/5 - 0s - loss: 2.1568 - val_loss: 2.1154 - 174ms/epoch - 35ms/step
# Epoch 13/100
# 5/5 - 0s - loss: 2.1047 - val_loss: 2.0646 - 173ms/epoch - 35ms/step
# Epoch 14/100
# 5/5 - 0s - loss: 2.0531 - val_loss: 2.0152 - 172ms/epoch - 34ms/step
# Epoch 15/100
# 5/5 - 0s - loss: 2.0033 - val_loss: 1.9670 - 172ms/epoch - 34ms/step
# Epoch 16/100
# 5/5 - 0s - loss: 1.9545 - val_loss: 1.9202 - 176ms/epoch - 35ms/step
# Epoch 17/100
# 5/5 - 0s - loss: 1.9074 - val_loss: 1.8747 - 175ms/epoch - 35ms/step
# Epoch 18/100
# 5/5 - 0s - loss: 1.8614 - val_loss: 1.8305 - 176ms/epoch - 35ms/step
# Epoch 19/100
# 5/5 - 0s - loss: 1.8165 - val_loss: 1.7877 - 172ms/epoch - 34ms/step
# Epoch 20/100
# 5/5 - 0s - loss: 1.7731 - val_loss: 1.7462 - 173ms/epoch - 35ms/step
# Epoch 21/100
# 5/5 - 0s - loss: 1.7309 - val_loss: 1.7060 - 172ms/epoch - 34ms/step
# Epoch 22/100
# 5/5 - 0s - loss: 1.6910 - val_loss: 1.6670 - 172ms/epoch - 34ms/step
# Epoch 23/100
# 5/5 - 0s - loss: 1.6513 - val_loss: 1.6292 - 170ms/epoch - 34ms/step
# Epoch 24/100
# 5/5 - 0s - loss: 1.6128 - val_loss: 1.5924 - 169ms/epoch - 34ms/step
# Epoch 25/100
# 5/5 - 0s - loss: 1.5763 - val_loss: 1.5567 - 201ms/epoch - 40ms/step
# Epoch 26/100
# 5/5 - 0s - loss: 1.5402 - val_loss: 1.5218 - 180ms/epoch - 36ms/step
# Epoch 27/100
# 5/5 - 0s - loss: 1.5048 - val_loss: 1.4878 - 185ms/epoch - 37ms/step
# Epoch 28/100
# 5/5 - 0s - loss: 1.4701 - val_loss: 1.4545 - 173ms/epoch - 35ms/step
# Epoch 29/100
# 5/5 - 0s - loss: 1.4368 - val_loss: 1.4219 - 178ms/epoch - 36ms/step
# Epoch 30/100
# 5/5 - 0s - loss: 1.4054 - val_loss: 1.3901 - 172ms/epoch - 34ms/step
# Epoch 31/100
# 5/5 - 0s - loss: 1.3728 - val_loss: 1.3590 - 170ms/epoch - 34ms/step
# Epoch 32/100
# 5/5 - 0s - loss: 1.3424 - val_loss: 1.3285 - 170ms/epoch - 34ms/step
# Epoch 33/100
# 5/5 - 0s - loss: 1.3116 - val_loss: 1.2987 - 171ms/epoch - 34ms/step
# Epoch 34/100
# 5/5 - 0s - loss: 1.2821 - val_loss: 1.2696 - 170ms/epoch - 34ms/step
# Epoch 35/100
# 5/5 - 0s - loss: 1.2529 - val_loss: 1.2411 - 172ms/epoch - 34ms/step
# Epoch 36/100
# 5/5 - 0s - loss: 1.2239 - val_loss: 1.2133 - 171ms/epoch - 34ms/step
# Epoch 37/100
# 5/5 - 0s - loss: 1.1969 - val_loss: 1.1862 - 171ms/epoch - 34ms/step
# Epoch 38/100
# 5/5 - 0s - loss: 1.1705 - val_loss: 1.1596 - 172ms/epoch - 34ms/step
# Epoch 39/100
# 5/5 - 0s - loss: 1.1436 - val_loss: 1.1337 - 175ms/epoch - 35ms/step
# Epoch 40/100
# 5/5 - 0s - loss: 1.1177 - val_loss: 1.1084 - 175ms/epoch - 35ms/step
# Epoch 41/100
# 5/5 - 0s - loss: 1.0933 - val_loss: 1.0837 - 172ms/epoch - 34ms/step
# Epoch 42/100
# 5/5 - 0s - loss: 1.0682 - val_loss: 1.0594 - 172ms/epoch - 34ms/step
# Epoch 43/100
# 5/5 - 0s - loss: 1.0447 - val_loss: 1.0358 - 170ms/epoch - 34ms/step
# Epoch 44/100
# 5/5 - 0s - loss: 1.0207 - val_loss: 1.0127 - 172ms/epoch - 34ms/step
# Epoch 45/100
# 5/5 - 0s - loss: 0.9981 - val_loss: 0.9902 - 173ms/epoch - 35ms/step
# Epoch 46/100
# 5/5 - 0s - loss: 0.9760 - val_loss: 0.9681 - 175ms/epoch - 35ms/step
# Epoch 47/100
# 5/5 - 0s - loss: 0.9539 - val_loss: 0.9466 - 173ms/epoch - 35ms/step
# Epoch 48/100
# 5/5 - 0s - loss: 0.9330 - val_loss: 0.9255 - 170ms/epoch - 34ms/step
# Epoch 49/100
# 5/5 - 0s - loss: 0.9119 - val_loss: 0.9049 - 173ms/epoch - 35ms/step
# Epoch 50/100
# 5/5 - 0s - loss: 0.8910 - val_loss: 0.8848 - 170ms/epoch - 34ms/step
# Epoch 51/100
# 5/5 - 0s - loss: 0.8711 - val_loss: 0.8652 - 171ms/epoch - 34ms/step
# Epoch 52/100
# 5/5 - 0s - loss: 0.8519 - val_loss: 0.8460 - 171ms/epoch - 34ms/step
# Epoch 53/100
# 5/5 - 0s - loss: 0.8326 - val_loss: 0.8273 - 172ms/epoch - 34ms/step
# Epoch 54/100
# 5/5 - 0s - loss: 0.8139 - val_loss: 0.8091 - 172ms/epoch - 34ms/step
# Epoch 55/100
# 5/5 - 0s - loss: 0.7961 - val_loss: 0.7912 - 171ms/epoch - 34ms/step
# Epoch 56/100
# 5/5 - 0s - loss: 0.7781 - val_loss: 0.7738 - 175ms/epoch - 35ms/step
# Epoch 57/100
# 5/5 - 0s - loss: 0.7614 - val_loss: 0.7567 - 177ms/epoch - 35ms/step
# Epoch 58/100
# 5/5 - 0s - loss: 0.7447 - val_loss: 0.7401 - 172ms/epoch - 34ms/step
# Epoch 59/100
# 5/5 - 0s - loss: 0.7275 - val_loss: 0.7238 - 170ms/epoch - 34ms/step
# Epoch 60/100
# 5/5 - 0s - loss: 0.7110 - val_loss: 0.7079 - 182ms/epoch - 36ms/step
# Epoch 61/100
# 5/5 - 0s - loss: 0.6952 - val_loss: 0.6924 - 181ms/epoch - 36ms/step
# Epoch 62/100
# 5/5 - 0s - loss: 0.6805 - val_loss: 0.6773 - 178ms/epoch - 36ms/step
# Epoch 63/100
# 5/5 - 0s - loss: 0.6651 - val_loss: 0.6625 - 189ms/epoch - 38ms/step
# Epoch 64/100
# 5/5 - 0s - loss: 0.6502 - val_loss: 0.6480 - 175ms/epoch - 35ms/step
# Epoch 65/100
# 5/5 - 0s - loss: 0.6361 - val_loss: 0.6339 - 173ms/epoch - 35ms/step
# Epoch 66/100
# 5/5 - 0s - loss: 0.6221 - val_loss: 0.6200 - 195ms/epoch - 39ms/step
# Epoch 67/100
# ...
# Epoch 135/300
# 5/5 - 0s - loss: 0.0401 - val_loss: 0.0451 - 58ms/epoch - 12ms/step
# Epoch 136/300
# 5/5 - 0s - loss: 0.0400 - val_loss: 0.0446 - 58ms/epoch - 12ms/step
# Epoch 137/300
# 5/5 - 0s - loss: 0.0393 - val_loss: 0.0440 - 60ms/epoch - 12ms/step
# Epoch 138/300
# 5/5 - 0s - loss: 0.0394 - val_loss: 0.0435 - 61ms/epoch - 12ms/step
# Epoch 139/300
# 5/5 - 0s - loss: 0.0378 - val_loss: 0.0430 - 57ms/epoch - 11ms/step
# Epoch 140/300
# 5/5 - 0s - loss: 0.0376 - val_loss: 0.0425 - 59ms/epoch - 12ms/step
# Epoch 141/300
# 5/5 - 0s - loss: 0.0376 - val_loss: 0.0420 - 58ms/epoch - 12ms/step
# Epoch 142/300
# 5/5 - 0s - loss: 0.0368 - val_loss: 0.0415 - 59ms/epoch - 12ms/step
# Epoch 143/300
# 5/5 - 0s - loss: 0.0367 - val_loss: 0.0410 - 59ms/epoch - 12ms/step
# Epoch 144/300
# 5/5 - 0s - loss: 0.0361 - val_loss: 0.0406 - 58ms/epoch - 12ms/step
# Epoch 145/300
# 5/5 - 0s - loss: 0.0355 - val_loss: 0.0401 - 57ms/epoch - 11ms/step
# Epoch 146/300
# 5/5 - 0s - loss: 0.0346 - val_loss: 0.0396 - 58ms/epoch - 12ms/step
# Epoch 147/300
# 5/5 - 0s - loss: 0.0348 - val_loss: 0.0391 - 56ms/epoch - 11ms/step
# Epoch 148/300
# 5/5 - 0s - loss: 0.0341 - val_loss: 0.0386 - 58ms/epoch - 12ms/step
# Epoch 149/300
# 5/5 - 0s - loss: 0.0335 - val_loss: 0.0382 - 56ms/epoch - 11ms/step
# Epoch 150/300
# 5/5 - 0s - loss: 0.0329 - val_loss: 0.0377 - 59ms/epoch - 12ms/step
# Epoch 151/300
# 5/5 - 0s - loss: 0.0322 - val_loss: 0.0372 - 58ms/epoch - 12ms/step
# Epoch 178/300
# 5/5 - 0s - loss: 0.0223 - val_loss: 0.0274 - 58ms/epoch - 12ms/step
# Epoch 179/300
# 5/5 - 0s - loss: 0.0220 - val_loss: 0.0271 - 57ms/epoch - 11ms/step
# Epoch 180/300
# 5/5 - 0s - loss: 0.0218 - val_loss: 0.0269 - 58ms/epoch - 12ms/step
# Epoch 181/300
# 5/5 - 0s - loss: 0.0220 - val_loss: 0.0266 - 58ms/epoch - 12ms/step
# Epoch 182/300
# 5/5 - 0s - loss: 0.0215 - val_loss: 0.0264 - 59ms/epoch - 12ms/step
# Epoch 183/300
# 5/5 - 0s - loss: 0.0210 - val_loss: 0.0261 - 56ms/epoch - 11ms/step
# Epoch 184/300
# 5/5 - 0s - loss: 0.0208 - val_loss: 0.0259 - 58ms/epoch - 12ms/step
# Epoch 185/300
# 5/5 - 0s - loss: 0.0207 - val_loss: 0.0256 - 56ms/epoch - 11ms/step
# Epoch 186/300
# 5/5 - 0s - loss: 0.0203 - val_loss: 0.0254 - 58ms/epoch - 12ms/step
# Epoch 187/300
# 5/5 - 0s - loss: 0.0201 - val_loss: 0.0252 - 56ms/epoch - 11ms/step
# Epoch 188/300
# 5/5 - 0s - loss: 0.0201 - val_loss: 0.0249 - 58ms/epoch - 12ms/step
# Epoch 189/300
# 5/5 - 0s - loss: 0.0196 - val_loss: 0.0247 - 57ms/epoch - 11ms/step
# Epoch 190/300
# 5/5 - 0s - loss: 0.0195 - val_loss: 0.0245 - 57ms/epoch - 11ms/step
# Epoch 191/300
# 5/5 - 0s - loss: 0.0193 - val_loss: 0.0243 - 56ms/epoch - 11ms/step
# Epoch 192/300
# 5/5 - 0s - loss: 0.0190 - val_loss: 0.0241 - 58ms/epoch - 12ms/step
# Epoch 193/300
# 5/5 - 0s - loss: 0.0189 - val_loss: 0.0239 - 56ms/epoch - 11ms/step
# Epoch 194/300
# 5/5 - 0s - loss: 0.0186 - val_loss: 0.0237 - 57ms/epoch - 11ms/step
# Epoch 195/300
# 5/5 - 0s - loss: 0.0185 - val_loss: 0.0234 - 57ms/epoch - 11ms/step
# Epoch 196/300
# 5/5 - 0s - loss: 0.0180 - val_loss: 0.0232 - 57ms/epoch - 11ms/step
# Epoch 197/300
# 5/5 - 0s - loss: 0.0179 - val_loss: 0.0231 - 57ms/epoch - 11ms/step
# Epoch 198/300
# 5/5 - 0s - loss: 0.0173 - val_loss: 0.0229 - 58ms/epoch - 12ms/step
# Epoch 199/300
# 5/5 - 0s - loss: 0.0172 - val_loss: 0.0227 - 57ms/epoch - 11ms/step
# Epoch 200/300
# 5/5 - 0s - loss: 0.0169 - val_loss: 0.0225 - 58ms/epoch - 12ms/step
# Epoch 201/300
# 5/5 - 0s - loss: 0.0172 - val_loss: 0.0223 - 56ms/epoch - 11ms/step
# Epoch 202/300
# 5/5 - 0s - loss: 0.0169 - val_loss: 0.0221 - 58ms/epoch - 12ms/step
# Epoch 203/300
# 5/5 - 0s - loss: 0.0167 - val_loss: 0.0219 - 57ms/epoch - 11ms/step
# Epoch 204/300
# 5/5 - 0s - loss: 0.0166 - val_loss: 0.0217 - 57ms/epoch - 11ms/step
# Epoch 205/300
# 5/5 - 0s - loss: 0.0165 - val_loss: 0.0216 - 57ms/epoch - 11ms/step
# Epoch 206/300
# 5/5 - 0s - loss: 0.0162 - val_loss: 0.0214 - 56ms/epoch - 11ms/step
# Epoch 207/300
# 5/5 - 0s - loss: 0.0158 - val_loss: 0.0212 - 57ms/epoch - 11ms/step
# Epoch 208/300
# 5/5 - 0s - loss: 0.0158 - val_loss: 0.0211 - 57ms/epoch - 11ms/step
# Epoch 209/300
# 5/5 - 0s - loss: 0.0159 - val_loss: 0.0209 - 57ms/epoch - 11ms/step
# Epoch 210/300
# 5/5 - 0s - loss: 0.0156 - val_loss: 0.0207 - 56ms/epoch - 11ms/step
# Epoch 211/300
# 5/5 - 0s - loss: 0.0152 - val_loss: 0.0206 - 57ms/epoch - 11ms/step
# Epoch 212/300
# 5/5 - 0s - loss: 0.0151 - val_loss: 0.0204 - 57ms/epoch - 11ms/step
# Epoch 213/300
# 5/5 - 0s - loss: 0.0148 - val_loss: 0.0202 - 58ms/epoch - 12ms/step
# Epoch 214/300
# 5/5 - 0s - loss: 0.0151 - val_loss: 0.0201 - 72ms/epoch - 14ms/step
# Epoch 215/300
# 5/5 - 0s - loss: 0.0147 - val_loss: 0.0199 - 62ms/epoch - 12ms/step
# Epoch 216/300
# 5/5 - 0s - loss: 0.0144 - val_loss: 0.0198 - 57ms/epoch - 11ms/step
# Epoch 217/300
# 5/5 - 0s - loss: 0.0143 - val_loss: 0.0196 - 57ms/epoch - 11ms/step
# Epoch 218/300
# 5/5 - 0s - loss: 0.0143 - val_loss: 0.0195 - 58ms/epoch - 12ms/step
# Epoch 219/300
# 5/5 - 0s - loss: 0.0139 - val_loss: 0.0193 - 56ms/epoch - 11ms/step
# Epoch 220/300
# 5/5 - 0s - loss: 0.0137 - val_loss: 0.0192 - 57ms/epoch - 11ms/step
# Epoch 221/300
# 5/5 - 0s - loss: 0.0136 - val_loss: 0.0190 - 57ms/epoch - 11ms/step
# Epoch 222/300
# 5/5 - 0s - loss: 0.0139 - val_loss: 0.0189 - 59ms/epoch - 12ms/step
# Epoch 223/300
# 5/5 - 0s - loss: 0.0135 - val_loss: 0.0188 - 58ms/epoch - 12ms/step
# Epoch 224/300
# 5/5 - 0s - loss: 0.0132 - val_loss: 0.0186 - 61ms/epoch - 12ms/step
# Epoch 225/300
# 5/5 - 0s - loss: 0.0132 - val_loss: 0.0185 - 58ms/epoch - 12ms/step
# Epoch 226/300
# 5/5 - 0s - loss: 0.0130 - val_loss: 0.0184 - 57ms/epoch - 11ms/step
# Epoch 227/300
# 5/5 - 0s - loss: 0.0130 - val_loss: 0.0182 - 57ms/epoch - 11ms/step
# Epoch 228/300
# 5/5 - 0s - loss: 0.0130 - val_loss: 0.0181 - 56ms/epoch - 11ms/step
# Epoch 229/300
# 5/5 - 0s - loss: 0.0129 - val_loss: 0.0180 - 57ms/epoch - 11ms/step
# Epoch 230/300
# 5/5 - 0s - loss: 0.0124 - val_loss: 0.0179 - 55ms/epoch - 11ms/step
# Epoch 231/300
# 5/5 - 0s - loss: 0.0124 - val_loss: 0.0177 - 57ms/epoch - 11ms/step
# Epoch 232/300
# 5/5 - 0s - loss: 0.0121 - val_loss: 0.0176 - 56ms/epoch - 11ms/step
# Epoch 233/300
# 5/5 - 0s - loss: 0.0119 - val_loss: 0.0175 - 57ms/epoch - 11ms/step
# Epoch 234/300
# 5/5 - 0s - loss: 0.0118 - val_loss: 0.0174 - 57ms/epoch - 11ms/step
# Epoch 235/300
# 5/5 - 0s - loss: 0.0116 - val_loss: 0.0172 - 57ms/epoch - 11ms/step
# Epoch 236/300
# 5/5 - 0s - loss: 0.0118 - val_loss: 0.0171 - 57ms/epoch - 11ms/step
# Epoch 237/300
# 5/5 - 0s - loss: 0.0117 - val_loss: 0.0170 - 58ms/epoch - 12ms/step
# Epoch 238/300
# 5/5 - 0s - loss: 0.0116 - val_loss: 0.0169 - 59ms/epoch - 12ms/step
# Epoch 239/300
# 5/5 - 0s - loss: 0.0113 - val_loss: 0.0168 - 60ms/epoch - 12ms/step
# Epoch 240/300
# 5/5 - 0s - loss: 0.0110 - val_loss: 0.0167 - 58ms/epoch - 12ms/step
# Epoch 241/300
# 5/5 - 0s - loss: 0.0110 - val_loss: 0.0166 - 57ms/epoch - 11ms/step
# Epoch 242/300
# 5/5 - 0s - loss: 0.0111 - val_loss: 0.0164 - 57ms/epoch - 11ms/step
# Epoch 243/300
# 5/5 - 0s - loss: 0.0105 - val_loss: 0.0163 - 57ms/epoch - 11ms/step
# Epoch 244/300
# 5/5 - 0s - loss: 0.0106 - val_loss: 0.0162 - 58ms/epoch - 12ms/step
# Epoch 245/300
# 5/5 - 0s - loss: 0.0107 - val_loss: 0.0161 - 56ms/epoch - 11ms/step
# Epoch 246/300
# 5/5 - 0s - loss: 0.0106 - val_loss: 0.0160 - 57ms/epoch - 11ms/step
# Epoch 247/300
# 5/5 - 0s - loss: 0.0103 - val_loss: 0.0159 - 57ms/epoch - 11ms/step
# Epoch 248/300
# 5/5 - 0s - loss: 0.0106 - val_loss: 0.0158 - 58ms/epoch - 12ms/step
# Epoch 249/300
# 5/5 - 0s - loss: 0.0098 - val_loss: 0.0157 - 56ms/epoch - 11ms/step
# Epoch 250/300
# 5/5 - 0s - loss: 0.0103 - val_loss: 0.0156 - 57ms/epoch - 11ms/step
# Epoch 251/300
# 5/5 - 0s - loss: 0.0101 - val_loss: 0.0156 - 56ms/epoch - 11ms/step
# Epoch 252/300
# 5/5 - 0s - loss: 0.0099 - val_loss: 0.0155 - 57ms/epoch - 11ms/step
# Epoch 253/300
# 5/5 - 0s - loss: 0.0097 - val_loss: 0.0154 - 56ms/epoch - 11ms/step
# Epoch 254/300
# 5/5 - 0s - loss: 0.0096 - val_loss: 0.0153 - 57ms/epoch - 11ms/step
# Epoch 255/300
# 5/5 - 0s - loss: 0.0096 - val_loss: 0.0152 - 57ms/epoch - 11ms/step
# Epoch 256/300
# 5/5 - 0s - loss: 0.0095 - val_loss: 0.0151 - 58ms/epoch - 12ms/step
# Epoch 257/300
# 5/5 - 0s - loss: 0.0096 - val_loss: 0.0150 - 59ms/epoch - 12ms/step
# Epoch 258/300
# 5/5 - 0s - loss: 0.0094 - val_loss: 0.0149 - 58ms/epoch - 12ms/step
# Epoch 259/300
# 5/5 - 0s - loss: 0.0092 - val_loss: 0.0148 - 81ms/epoch - 16ms/step
# Epoch 260/300
# 5/5 - 0s - loss: 0.0092 - val_loss: 0.0147 - 59ms/epoch - 12ms/step
# Epoch 261/300
# 5/5 - 0s - loss: 0.0088 - val_loss: 0.0146 - 56ms/epoch - 11ms/step
# Epoch 262/300
# 5/5 - 0s - loss: 0.0088 - val_loss: 0.0146 - 59ms/epoch - 12ms/step
# Epoch 263/300
# 5/5 - 0s - loss: 0.0089 - val_loss: 0.0145 - 57ms/epoch - 11ms/step
# Epoch 264/300
# 5/5 - 0s - loss: 0.0087 - val_loss: 0.0144 - 59ms/epoch - 12ms/step
# Epoch 265/300
# 5/5 - 0s - loss: 0.0086 - val_loss: 0.0143 - 58ms/epoch - 12ms/step
# Epoch 266/300
# 5/5 - 0s - loss: 0.0086 - val_loss: 0.0142 - 57ms/epoch - 11ms/step
# Epoch 267/300
# 5/5 - 0s - loss: 0.0084 - val_loss: 0.0142 - 58ms/epoch - 12ms/step
# Epoch 268/300
# 5/5 - 0s - loss: 0.0082 - val_loss: 0.0141 - 56ms/epoch - 11ms/step
# Epoch 269/300
# 5/5 - 0s - loss: 0.0081 - val_loss: 0.0140 - 58ms/epoch - 12ms/step
# Epoch 270/300
# 5/5 - 0s - loss: 0.0080 - val_loss: 0.0139 - 57ms/epoch - 11ms/step
# Epoch 271/300
# 5/5 - 0s - loss: 0.0083 - val_loss: 0.0139 - 58ms/epoch - 12ms/step
# Epoch 272/300
# 5/5 - 0s - loss: 0.0080 - val_loss: 0.0138 - 57ms/epoch - 11ms/step
# Epoch 273/300
# 5/5 - 0s - loss: 0.0080 - val_loss: 0.0137 - 57ms/epoch - 11ms/step
# Epoch 274/300
# 5/5 - 0s - loss: 0.0078 - val_loss: 0.0136 - 58ms/epoch - 12ms/step
# Epoch 275/300
# 5/5 - 0s - loss: 0.0078 - val_loss: 0.0136 - 57ms/epoch - 11ms/step
# Epoch 276/300
# 5/5 - 0s - loss: 0.0077 - val_loss: 0.0135 - 57ms/epoch - 11ms/step
# Epoch 277/300
# 5/5 - 0s - loss: 0.0077 - val_loss: 0.0134 - 58ms/epoch - 12ms/step
# Epoch 278/300
# 5/5 - 0s - loss: 0.0074 - val_loss: 0.0134 - 57ms/epoch - 11ms/step
# Epoch 279/300
# 5/5 - 0s - loss: 0.0076 - val_loss: 0.0133 - 59ms/epoch - 12ms/step
# Epoch 280/300
# 5/5 - 0s - loss: 0.0072 - val_loss: 0.0132 - 58ms/epoch - 12ms/step
# Epoch 281/300
# 5/5 - 0s - loss: 0.0073 - val_loss: 0.0132 - 57ms/epoch - 11ms/step
# Epoch 282/300
# 5/5 - 0s - loss: 0.0073 - val_loss: 0.0131 - 57ms/epoch - 11ms/step
# Epoch 283/300
# 5/5 - 0s - loss: 0.0070 - val_loss: 0.0130 - 56ms/epoch - 11ms/step
# Epoch 284/300
# 5/5 - 0s - loss: 0.0070 - val_loss: 0.0130 - 58ms/epoch - 12ms/step
# Epoch 285/300
# 5/5 - 0s - loss: 0.0071 - val_loss: 0.0129 - 59ms/epoch - 12ms/step
# Epoch 286/300
# 5/5 - 0s - loss: 0.0069 - val_loss: 0.0129 - 57ms/epoch - 11ms/step
# Epoch 287/300
# 5/5 - 0s - loss: 0.0069 - val_loss: 0.0128 - 57ms/epoch - 11ms/step
# Epoch 288/300
# 5/5 - 0s - loss: 0.0070 - val_loss: 0.0127 - 57ms/epoch - 11ms/step
# Epoch 289/300
# 5/5 - 0s - loss: 0.0069 - val_loss: 0.0127 - 56ms/epoch - 11ms/step
# Epoch 290/300
# 5/5 - 0s - loss: 0.0068 - val_loss: 0.0126 - 57ms/epoch - 11ms/step
# Epoch 291/300
# 5/5 - 0s - loss: 0.0066 - val_loss: 0.0126 - 57ms/epoch - 11ms/step
# Epoch 292/300
# 5/5 - 0s - loss: 0.0065 - val_loss: 0.0125 - 58ms/epoch - 12ms/step
# Epoch 293/300
# 5/5 - 0s - loss: 0.0066 - val_loss: 0.0125 - 57ms/epoch - 11ms/step
# Epoch 294/300
# 5/5 - 0s - loss: 0.0063 - val_loss: 0.0124 - 58ms/epoch - 12ms/step
# Epoch 295/300
# 5/5 - 0s - loss: 0.0062 - val_loss: 0.0123 - 56ms/epoch - 11ms/step
# Epoch 296/300
# 5/5 - 0s - loss: 0.0066 - val_loss: 0.0123 - 58ms/epoch - 12ms/step
# Epoch 297/300
# 5/5 - 0s - loss: 0.0062 - val_loss: 0.0123 - 58ms/epoch - 12ms/step
# Epoch 298/300
# 5/5 - 0s - loss: 0.0062 - val_loss: 0.0122 - 56ms/epoch - 11ms/step
# Epoch 299/300
# 5/5 - 0s - loss: 0.0063 - val_loss: 0.0122 - 72ms/epoch - 14ms/step
# Epoch 300/300
# 5/5 - 0s - loss: 0.0062 - val_loss: 0.0121 - 68ms/epoch - 14ms/step
# 20/20 [==============================] - 1s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# Train Score: 19.10 RMSE for 300 epochs
# Test Score: 52.16 RMSE for 300 epochs
# Text(0.5, 1.0, 'Model loss progress during training and validation')
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'Training and Validation Loss')
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#                                                     Train RMSE   Test RMSE
# 50 epochs, [64, 64, 32, 32, 16, 16, 8, 8, 4, 4,...   97.355484  109.137056
# 50 epochs, [32, 32, 16, 16, 8, 8, 4, 4, 2, 2] l...   97.400701  108.939634
# 50 epochs, [16, 16, 8, 8, 4, 4, 2, 2] layers         97.442685  108.151558
# 50 epochs, [8, 8, 4, 4, 2, 2] layers                 96.301228  107.560991
# 50 epochs, [4, 4, 2, 2] layers                       93.375415  105.488767
# 50 epochs, [2, 2] layers                             85.134788   98.233081
# 100 epochs, [64, 64, 32, 32, 16, 16, 8, 8, 4, 4...   97.270189  109.616134
# 100 epochs, [32, 32, 16, 16, 8, 8, 4, 4, 2, 2] ...   97.281361  109.522277
# 100 epochs, [16, 16, 8, 8, 4, 4, 2, 2] layers        97.284173  109.312453
# 100 epochs, [8, 8, 4, 4, 2, 2] layers                97.176736  109.548562
# 100 epochs, [4, 4, 2, 2] layers                      93.855455  106.751768
# 100 epochs, [2, 2] layers                            60.349757   73.952269
# 150 epochs, [64, 64, 32, 32, 16, 16, 8, 8, 4, 4...   97.252350  109.849197
# 150 epochs, [32, 32, 16, 16, 8, 8, 4, 4, 2, 2] ...   97.289132  109.467080
# 150 epochs, [16, 16, 8, 8, 4, 4, 2, 2] layers        97.255158  109.797322
# 150 epochs, [8, 8, 4, 4, 2, 2] layers                97.223502  109.764723
# 150 epochs, [4, 4, 2, 2] layers                      26.081559   56.283237
# 150 epochs, [2, 2] layers                            24.033954   53.232120
# 300 epochs, [64, 64, 32, 32, 16, 16, 8, 8, 4, 4...   97.247256  110.086347
# 300 epochs, [32, 32, 16, 16, 8, 8, 4, 4, 2, 2] ...   97.247818  110.143796
# 300 epochs, [16, 16, 8, 8, 4, 4, 2, 2] layers        97.247219  110.069888
# 300 epochs, [8, 8, 4, 4, 2, 2] layers                97.248677  109.949930
# 300 epochs, [4, 4, 2, 2] layers                      28.198667   61.523027
# 300 epochs, [2, 2] layers                            19.104357   52.160688

# %% [markdown]
# <h4>Forecast the results</h4>

# %%
# Add check for 'RATE_actual' values to avoid division by zero
def compute_accuracy(row):
    if row['RATE_actual'] == 0:
        return np.nan
    else:
        error = abs(row['RATE_actual'] - row['RATE_forecasted'])
        error_proportion = error / row['RATE_actual']
        return (1 - error_proportion) * 100


def forecast_next_weeks(model, look_back, scaler, last_values, n_weeks):
    forecast = []
    for _ in range(n_weeks):
        last_values_2d = np.array(last_values[-look_back:]).reshape(-1, 1)
        input_values_scaled = scaler.transform(last_values_2d)
        input_values_scaled = input_values_scaled.reshape((1, look_back, 1))

        prediction = model.predict(input_values_scaled)
        prediction = scaler.inverse_transform(prediction)
        forecast.append(prediction[0][0])
        last_values.append(prediction[0][0])

    return forecast

# %%
weeks = 12

# Ensure that 'YearMonthWeek' is a datetime object
agg_df['YearMonthWeek'] = pd.to_datetime(agg_df['YearMonthWeek'])
last_date = agg_df['YearMonthWeek'].iloc[-1]

last_values = list(agg_df['Rate'].values[-look_back:])
forecasted_values = forecast_next_weeks(
    model, look_back, scaler_rate, last_values, weeks)
forecasted_dates = pd.date_range(
    start=last_date, periods=weeks+1, freq='W')[1:]

df_forecasted = pd.DataFrame({
    'POD': forecasted_dates,
    'RATE': forecasted_values
})

df_forecasted["RATE"] = df_forecasted["RATE"].round(2)

df_forecasted.head(5)
df_forecasted.tail(5)
df_forecasted.info()
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 [==============================] - 0s 22ms/step
#          POD        RATE
# 0 2023-03-05  242.839996
# 1 2023-03-12  244.210007
# 2 2023-03-19  246.369995
# 3 2023-03-26  245.929993
# 4 2023-04-02  246.839996
#           POD        RATE
# 7  2023-04-23  241.289993
# 8  2023-04-30  240.039993
# 9  2023-05-07  238.720001
# 10 2023-05-14  237.289993
# 11 2023-05-21  235.949997
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POD     12 non-null     datetime64[ns]
#  1   RATE    12 non-null     float32
# dtypes: datetime64[ns](1), float32(1)
# memory usage: 272.0 bytes

# %% [markdown]
# <h4>Comparing with actual updated against forecasted</h4>

# %%
comparison_df = pd.DataFrame(
    columns=['WeekStart', 'WeekEnd', 'POD_actual', 'RATE_forecasted', 'RATE_actual'])
df_forecasted['WeekEnd'] = df_forecasted['POD'] + pd.to_timedelta(7, unit='d')

for _, row in df_forecasted.iterrows():
    mask = (new_dates_df['POD'] >= row['POD']) & (
        new_dates_df['POD'] < row['WeekEnd'])
    actual_dates_within_week = new_dates_df[mask]

    for _, actual_row in actual_dates_within_week.iterrows():
        comparison_df = comparison_df.append({
            'WeekStart': row['POD'],
            'WeekEnd': row['WeekEnd'],
            'POD_actual': actual_row['POD'],
            'RATE_forecasted': row['RATE'],
            'RATE_actual': actual_row['RATE']
        }, ignore_index=True)

# Remove duplicates
comparison_df = comparison_df.drop_duplicates(
    subset=['POD_actual', 'RATE_forecasted', 'RATE_actual']).reset_index(drop=True)

# Compute accuracy
comparison_df['accuracy'] = comparison_df.apply(compute_accuracy, axis=1)
comparison_df = comparison_df.dropna(subset=['accuracy'])

total_mean_accuracy = comparison_df['accuracy'].mean()
comparison_df
print(f'The mean accuracy is {total_mean_accuracy:.2f}%\n')
# Out:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2511611426.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2511611426.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2511611426.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2511611426.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2511611426.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2511611426.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2511611426.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2511611426.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2511611426.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2511611426.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2511611426.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2511611426.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2511611426.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2511611426.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2511611426.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2511611426.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2511611426.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2511611426.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2511611426.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2511611426.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2511611426.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2511611426.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_29064\2511611426.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
#     WeekStart    WeekEnd POD_actual  RATE_forecasted  RATE_actual   accuracy
# 0  2023-03-05 2023-03-12 2023-03-08       242.839996        260.0  93.399999
# 1  2023-03-12 2023-03-19 2023-03-15       244.210007        260.0  93.926926
# 2  2023-03-19 2023-03-26 2023-03-19       246.369995        300.0  82.123332
# 3  2023-03-26 2023-04-02 2023-03-26       245.929993        260.0  94.588459
# 4  2023-03-26 2023-04-02 2023-04-01       245.929993        260.0  94.588459
# 5  2023-04-02 2023-04-09 2023-04-08       246.839996        260.0  94.938460
# 6  2023-04-09 2023-04-16 2023-04-12       243.089996        300.0  81.029999
# 7  2023-04-09 2023-04-16 2023-04-15       243.089996        260.0  93.496152
# 8  2023-04-16 2023-04-23 2023-04-20       242.309998        260.0  93.196153
# 9  2023-04-23 2023-04-30 2023-04-26       241.289993        300.0  80.429998
# 10 2023-04-30 2023-05-07 2023-05-03       240.039993        260.0  92.323074
# 11 2023-05-07 2023-05-14 2023-05-10       238.720001        300.0  79.573334
# 12 2023-05-14 2023-05-21 2023-05-17       237.289993        260.0  91.265382
# The mean accuracy is 89.61%

# %%
model.summary()
# Out:
# Model: "sequential_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_262 (Bidirect  (None, 5, 4)             64
#  ional)
#
#  dropout_235 (Dropout)       (None, 5, 4)              0
#
#  bidirectional_263 (Bidirect  (None, 4)                112
#  ional)
#
#  dense_31 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 181
# Trainable params: 181
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <h4>Visualise all, Conclusion</h4>

# %%
plt.figure(figsize=(20, 10))
plt.plot(sel_df['POD'], sel_df['RATE'], color='blue', label="Actual Data")
plt.plot(new_dates_df['POD'], new_dates_df['RATE'],
         color='blue', label="Actual Data (Updated)")

plt.plot(df_interpolated['POD'], df_interpolated['RATE'],
         color='green', label="Aggregated Data")
plt.plot(df_forecasted['POD'], df_forecasted['RATE'],
         color='red', label="Forecasted Data")

plt.xlabel('Date(Year Month)')
plt.ylabel('Cost Rate(USD)')
plt.title('Port_BUSAN_Size_40_Type_HC_PartyID_010004286')
plt.legend()
plt.show()
# Out:
# Text(0.5, 0, 'Date(Year Month)')
# Text(0, 0.5, 'Cost Rate(USD)')
# Text(0.5, 1.0, 'Port_BUSAN_Size_40_Type_HC_PartyID_010004286')
