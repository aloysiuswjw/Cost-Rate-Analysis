# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.losses import MeanSquaredError
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from IPython.core.interactiveshell import InteractiveShell

# BayesianOptimization
from sklearn.model_selection import cross_val_score
from bayes_opt import BayesianOptimization # for OCSVM param
from kerastuner.tuners import BayesianOptimization # for LSTM param

# Anomaly detector
import itertools
from sklearn.svm import OneClassSVM

# LSTM
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.layers import Dropout, LSTM, Dense, RepeatVector, TimeDistributed
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from keras.callbacks import EarlyStopping
from sklearn.model_selection import ParameterSampler
from scipy.stats import skew


InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline
sns.set()
pd.options.display.max_rows = 100

# %% [markdown]
# <h4>Importing Datasets</h4>

# %%
# Import dataset and clean, ready as a dataframe for creating keys
def createDF(datasets):
    df = pd.read_csv(datasets, converters={'PARTY_ID': str, 'COM_ID': str, 'CNTR_SIZE': str})

    # Formating to type and remove NaN values
    df['POD'] = pd.to_datetime(df['POD'])
    df['ENCODED_TYPE'] = df['ENCODED_TYPE'].fillna(-1).astype(int)
    df = df.dropna(subset=['ENCODED_TYPE'])
    df['RATE'] = df['RATE'].fillna(-1).astype(float)
    df = df.dropna(subset=['RATE'])
    df['ENCODED_TYPE'] = df['ENCODED_TYPE'].astype(int)
    df_clean= df.dropna().reset_index(drop=True)

    # Selecting and rearranging columns
    sel_col = ['CSL_ID', 'CNTR_ID','POD_ID','ETD_POL_D','PARTY_ID',
            'PARTY_NAME','POD','CNTR_SIZE','CNTR_TYPE','RATE']
    df_fc = df_clean[sel_col]

    # Removing years we do not want to process in our models
    df_filtered = df_fc[df_fc['POD'].dt.year != 2002]

    # Sorting the dates
    df_filtered = df_filtered.sort_values(by='POD').reset_index(drop=True)
    
    return df_filtered

# %%
# Create Dataframes for old and new
old_data = '.\Datasets\CR_COST_FC.csv'
df1 = createDF(old_data)
df1.head()

new_data = '.\Datasets\CR_COST_FC_new.csv'
df2 = createDF(new_data)
df2.head()
# Out:
#            CSL_ID           CNTR_ID          POD_ID ETD_POL_D  PARTY_ID  \
# 0  ECS01050600224  CTNR010050700354       ROTTERDAM     NLRTM  01008827
# 1  ECS01050600610  CTNR010050700353      FELIXSTOWE     GBFXT  01002303
# 2  ECS01050600041  CTNR010050700351        AUCKLAND     NZAKL  01005136
# 3  ECS01050600163  CTNR010050700370    PASIR GUDANG     MYPGU  01002767
# 4  ECS01050600456  CTNR010050700450  KARACHI (KICT)     PKKHI  01002783
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0             YANG MING (SINGAPORE) PTE. LTD. 2005-07-15        40    HC NOR
# 1                    GLOBELINK FALLOW LIMITED 2005-07-15        40        GP
# 2  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-15        40    HC NOR
# 3          GLOBELINK CONTAINER LINES (JB) S/B 2005-07-15        40        HC
# 4                GLOBELINK PAKISTAN (PVT) LTD 2005-07-16        40        HC
#
#      RATE
# 0  1620.0
# 1  1800.0
# 2  2170.0
# 3   280.0
# 4  1625.0
#            CSL_ID           CNTR_ID          POD_ID ETD_POL_D  PARTY_ID  \
# 0  ECS01050600224  CTNR010050700354       ROTTERDAM     NLRTM  01008827
# 1  ECS01050600610  CTNR010050700353      FELIXSTOWE     GBFXT  01002303
# 2  ECS01050600041  CTNR010050700351        AUCKLAND     NZAKL  01005136
# 3  ECS01050600163  CTNR010050700370    PASIR GUDANG     MYPGU  01002767
# 4  ECS01050600456  CTNR010050700450  KARACHI (KICT)     PKKHI  01002783
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0             YANG MING (SINGAPORE) PTE. LTD. 2005-07-15        40    HC NOR
# 1                    GLOBELINK FALLOW LIMITED 2005-07-15        40        GP
# 2  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-15        40    HC NOR
# 3          GLOBELINK CONTAINER LINES (JB) S/B 2005-07-15        40        HC
# 4                GLOBELINK PAKISTAN (PVT) LTD 2005-07-16        40        HC
#
#      RATE
# 0  1620.0
# 1  1800.0
# 2  2170.0
# 3   280.0
# 4  1625.0

# %% [markdown]
# <h4>Creating Dictionary Keys</h4>

# %%
def filter_dataframe(df):
    filtered_dataframes = {}

    for (port, size, ctype, party_id), group in df.groupby(['POD_ID', 'CNTR_SIZE', 'CNTR_TYPE', 'PARTY_ID']):
        group = group.reset_index(drop=True).sort_values(by='POD')
        df_id = f"Port_{port}_Size_{size}_Type_{ctype}_PartyID_{party_id}"
        filtered_dataframes[df_id] = group

    return filtered_dataframes

# %%
# Creating keys from data
print("Old Data keys:")
filtered_dataframe1 = filter_dataframe(df1)
df_ids1 = list(filtered_dataframe1.keys())
print(list(df_ids1))
print(len(list(df_ids1)))

print("\nNew Data keys:")
filtered_dataframe2 = filter_dataframe(df2)
df_ids2 = list(filtered_dataframe2.keys())
print(list(df_ids2))
print(len(list(df_ids2)))
# Out:
# Old Data keys:
# ['Port_(CONSTANZA)_Size_40_Type_GP_PartyID_010007816', 'Port_(CONSTANZA)_Size_40_Type_HC_PartyID_010007816', 'Port_AARHUS_Size_20_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100027830', 'Port_AARHUS_Size_20_Type_GP_PartyID_010006666', 'Port_AARHUS_Size_40_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100027830', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100028193', 'Port_AARHUS_Size_40_Type_HC_PartyID_010006666', 'Port_ABIDJAN_Size_20_Type_GP_PartyID_0100027878', 'Port_ABIDJAN_Size_40_Type_HC_PartyID_010021097', 'Port_ADELAIDE_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01005078', 'Port_ADELAIDE_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ALEXANDRIA (EL DEKHELA PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC NOR_PartyID_010004995', 'Port_ALGECIRAS_Size_20_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC NOR_PartyID_01008306', 'Port_ALIAGA_Size_20_Type_GP_PartyID_01008316', 'Port_ALIAGA_Size_40_Type_HC_PartyID_01008316', 'Port_ALIAGA PORT (IZMIR)_Size_40_Type_HC_PartyID_01008316', 'Port_ANTWERP_Size_20_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC NOR_PartyID_01001449', 'Port_AQABA_Size_20_Type_GP_PartyID_010006618', 'Port_AQABA_Size_20_Type_GP_PartyID_010021081', 'Port_AQABA_Size_40_Type_HC_PartyID_010006618', 'Port_AQABA_Size_40_Type_HC_PartyID_010021081', 'Port_ASHDOD_Size_20_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_01008417', 'Port_ASHDOD_Size_40_Type_HC_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_HC_PartyID_01008417', 'Port_AUCKLAND_Size_20_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_20_Type_GP (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC NOR_PartyID_01005136', 'Port_BANGKOK_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_20_Type_GP (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (SOC)_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK (TST)_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK (TST)_Size_40_Type_HC_PartyID_010021593', 'Port_BARCELONA_Size_20_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC NOR_PartyID_01008305', 'Port_BEIRUT_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_HC_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_40_Type_HC_PartyID_0100 ...
# 789
#
# New Data keys:
# ['Port_(CONSTANZA)_Size_40_Type_GP_PartyID_010007816', 'Port_(CONSTANZA)_Size_40_Type_HC_PartyID_010007816', 'Port_AARHUS_Size_20_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100027830', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100028193', 'Port_AARHUS_Size_20_Type_GP_PartyID_010006666', 'Port_AARHUS_Size_40_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100027830', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100028193', 'Port_AARHUS_Size_40_Type_HC_PartyID_010006666', 'Port_ABIDJAN_Size_20_Type_GP_PartyID_0100027878', 'Port_ABIDJAN_Size_40_Type_HC_PartyID_010021097', 'Port_ADELAIDE_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01005078', 'Port_ADELAIDE_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ALEXANDRIA (EL DEKHELA PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC NOR_PartyID_010004995', 'Port_ALGECIRAS_Size_20_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC NOR_PartyID_01008306', 'Port_ALIAGA_Size_20_Type_GP_PartyID_01008316', 'Port_ALIAGA_Size_40_Type_HC_PartyID_01008316', 'Port_ALIAGA PORT (IZMIR)_Size_40_Type_HC_PartyID_01008316', 'Port_ANTWERP_Size_20_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC NOR_PartyID_01001449', 'Port_AQABA_Size_20_Type_GP_PartyID_010006618', 'Port_AQABA_Size_20_Type_GP_PartyID_010021081', 'Port_AQABA_Size_40_Type_HC_PartyID_010006618', 'Port_AQABA_Size_40_Type_HC_PartyID_010021081', 'Port_ASHDOD_Size_20_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_01008417', 'Port_ASHDOD_Size_40_Type_HC_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_HC_PartyID_01008417', 'Port_AUCKLAND_Size_20_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_20_Type_GP (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC NOR_PartyID_01005136', 'Port_BANGKOK_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_20_Type_GP (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (SOC)_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK (TST)_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK (TST)_Size_40_Type_HC_PartyID_010021593', 'Port_BARCELONA_Size_20_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC NOR_PartyID_01008305', 'Port_BEIRUT_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_HC_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_20_Type_GP_PartyID_010003651', ' ...
# 799

# %% [markdown]
# <h4>Getting Top 5 ports keys</h4>

# %%
def getTop5Ports(keybunch):
    keybunch_pouch = []
    
    # Get a dictionary with key and number of rows for each dataframe in filtered_dataframes
    key_row_counts = {key: len(keybunch[key]) for key in keybunch}

    # Sort the key_row_counts dictionary by value (number of rows) in descending order
    sorted_key_row_counts = sorted(key_row_counts.items(), key=lambda item: item[1], reverse=True)

    # Get the top 5 keys with the most rows
    top_5_keys_tuple = sorted_key_row_counts[:5]

    # Create a dictionary with the top 5 keys and their corresponding dataframes (with up to 5 rows per dataframe)
    keybunch_subset = {}

    for key, row_count in top_5_keys_tuple:
        keybunch_subset[key] = keybunch[key][:5]
        print(f"Number of rows in {key}: {row_count}")
        keybunch_pouch.append(key)
    
    # Return array of keys
    return keybunch_pouch

# %%
print('Old Dataset Keybunch:')
old_df = getTop5Ports(filtered_dataframe1)
print('\n')

print('New Dataset Keybunch:')
new_df = getTop5Ports(filtered_dataframe2)
# Out:
# Old Dataset Keybunch:
# Number of rows in Port_BUSAN_Size_40_Type_HC_PartyID_010004286: 1689
# Number of rows in Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136: 1688
# Number of rows in Port_MELBOURNE_Size_40_Type_HC_PartyID_01002778: 1325
# Number of rows in Port_SYDNEY_Size_40_Type_HC_PartyID_01002779: 1300
# Number of rows in Port_DUBAI (JEBEL ALI)_Size_40_Type_HC_PartyID_01002788: 1052
#
#
# New Dataset Keybunch:
# Number of rows in Port_BUSAN_Size_40_Type_HC_PartyID_010004286: 1712
# Number of rows in Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136: 1704
# Number of rows in Port_MELBOURNE_Size_40_Type_HC_PartyID_01002778: 1341
# Number of rows in Port_SYDNEY_Size_40_Type_HC_PartyID_01002779: 1308
# Number of rows in Port_DUBAI (JEBEL ALI)_Size_40_Type_HC_PartyID_01002788: 1070

# %%
# Global selection
sel_country = old_df[2]

# Accessing the highest count in the each keypouch, new and old.
sel_df = filtered_dataframe1[sel_country]
sel_df.head(5)
sel_df.tail(5)
sel_df.info()
print("\n")

latest_sel_df = filtered_dataframe2[sel_country]
latest_sel_df.head(5)
latest_sel_df.tail(5)
latest_sel_df.info()
# Out:
#             CSL_ID           CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 0   ECS01050600278  CTNR010050700692  MELBOURNE     AUMEL  01002778
# 1   ECS01050600280  CTNR010050701022  MELBOURNE     AUMEL  01002778
# 2  ECS010050700458  CTNR010050800604  MELBOURNE     AUMEL  01002778
# 3  ECS010050700214  CTNR010050800727  MELBOURNE     AUMEL  01002778
# 4  ECS010050900271  CTNR010051000178  MELBOURNE     AUMEL  01002778
#
#                                   PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-07-23        40        HC
# 1  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-07-30        40        HC
# 2  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-08-16        40        HC
# 3  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-08-19        40        HC
# 4  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-10-11        40        HC
#
#      RATE
# 0  1200.0
# 1  1200.0
# 2  1000.0
# 3  1200.0
# 4   900.0
#                CSL_ID       CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 1320  ECS010230100302  010000357415  MELBOURNE     AUMEL  01002778
# 1321  ECS010230100303  010000380481  MELBOURNE     AUMEL  01002778
# 1323  ECS010230100304  010000392586  MELBOURNE     AUMEL  01002778
# 1322  ECS010230100304  010000390964  MELBOURNE     AUMEL  01002778
# 1324  ECS010230100304  010000399293  MELBOURNE     AUMEL  01002778
#
#                                      PARTY_NAME        POD CNTR_SIZE  \
# 1320  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-02-11        40
# 1321  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-02-16        40
# 1323  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-02-24        40
# 1322  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-02-24        40
# 1324  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-02-24        40
#
#      CNTR_TYPE    RATE
# 1320        HC  1200.0
# 1321        HC  1200.0
# 1323        HC  1200.0
# 1322        HC  1200.0
# 1324        HC  1200.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1325 entries, 0 to 1324
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      1325 non-null   object
#  1   CNTR_ID     1325 non-null   object
#  2   POD_ID      1325 non-null   object
#  3   ETD_POL_D   1325 non-null   object
#  4   PARTY_ID    1325 non-null   object
#  5   PARTY_NAME  1325 non-null   object
#  6   POD         1325 non-null   datetime64[ns]
#  7   CNTR_SIZE   1325 non-null   object
#  8   CNTR_TYPE   1325 non-null   object
#  9   RATE        1325 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 113.9+ KB
#             CSL_ID           CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 0   ECS01050600278  CTNR010050700692  MELBOURNE     AUMEL  01002778
# 1   ECS01050600280  CTNR010050701022  MELBOURNE     AUMEL  01002778
# 2  ECS010050700458  CTNR010050800604  MELBOURNE     AUMEL  01002778
# 3  ECS010050700214  CTNR010050800727  MELBOURNE     AUMEL  01002778
# 4  ECS010050900271  CTNR010051000178  MELBOURNE     AUMEL  01002778
#
#                                   PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-07-23        40        HC
# 1  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-07-30        40        HC
# 2  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-08-16        40        HC
# 3  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-08-19        40        HC
# 4  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-10-11        40        HC
#
#      RATE
# 0  1200.0
# 1  1200.0
# 2  1000.0
# 3  1200.0
# 4   900.0
#                CSL_ID       CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 1336  ECS010230300518  010000531211  MELBOURNE     AUMEL  01002778
# 1337  ECS010230300518  010000509487  MELBOURNE     AUMEL  01002778
# 1338  ECS010230400431  010000541165  MELBOURNE     AUMEL  01002778
# 1339  ECS010230400432  010000543217  MELBOURNE     AUMEL  01002778
# 1340  ECS010230400433  010000557443  MELBOURNE     AUMEL  01002778
#
#                                      PARTY_NAME        POD CNTR_SIZE  \
# 1336  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-04-28        40
# 1337  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-04-28        40
# 1338  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-05        40
# 1339  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-11        40
# 1340  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-19        40
#
#      CNTR_TYPE   RATE
# 1336        HC  500.0
# 1337        HC  500.0
# 1338        HC  500.0
# 1339        HC  500.0
# 1340        HC  400.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1341 entries, 0 to 1340
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      1341 non-null   object
#  1   CNTR_ID     1341 non-null   object
#  2   POD_ID      1341 non-null   object
#  3   ETD_POL_D   1341 non-null   object
#  4   PARTY_ID    1341 non-null   object
#  5   PARTY_NAME  1341 non-null   object
#  6   POD         1341 non-null   datetime64[ns]
#  7   CNTR_SIZE   1341 non-null   object
#  8   CNTR_TYPE   1341 non-null   object
#  9   RATE        1341 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 115.2+ KB

# %%
# Select features
sel_feat = ['POD','RATE']
robust_df = sel_df[sel_feat].copy()  # make a copy to avoid SettingWithCopyWarning
robust_df.head()
robust_df.info()
# Out:
#          POD    RATE
# 0 2005-07-23  1200.0
# 1 2005-07-30  1200.0
# 2 2005-08-16  1000.0
# 3 2005-08-19  1200.0
# 4 2005-10-11   900.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1325 entries, 0 to 1324
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POD     1325 non-null   datetime64[ns]
#  1   RATE    1325 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 31.1 KB
# <module 'matplotlib.pyplot' from 'c:\\Users\\Aloysius Wong\\Documents\\GitHub\\Cost-Rate-Analysis\\env\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
plt.figure(figsize=(20, 10))
plt.plot(robust_df['POD'], robust_df['RATE'], color='blue', label="Data")

plt.xlabel('Date(Days)')
plt.ylabel('Cost Rate(USD)')
plt.title(f'Original Dataset plot: {sel_country}')
plt.legend()
plt.show();

# %% [markdown]
# <h2>Annomaly Detection using LSTM Autoencoder with OCSVM</h2>

# %% [markdown]
# <h4>Finding best params for LSTM auto-encoder and nu for one class svm</h4>

# %%
# Preprocessing: scaling data to [-1, 1] range

# Instantiate the scaler
scaler = MinMaxScaler(feature_range=(-1, 1))
data_scaled = scaler.fit_transform(robust_df['RATE'].values.reshape(-1, 1))

# %%
# # Define model builder function
# def build_model(hp):
#     model = Sequential([
#         LSTM(hp.Int('input_units', min_value=32, max_value=256, step=32), 
#              activation='relu', 
#              input_shape=(time_steps, 1), 
#              return_sequences=False),
#         RepeatVector(time_steps),
#         LSTM(hp.Int('output_units', min_value=32, max_value=256, step=32), 
#              activation='relu', 
#              return_sequences=True),
#         TimeDistributed(Dense(1))
#     ])
#     model.compile(optimizer=Adam(hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])), loss=MeanSquaredError())
#     return model

# # Preprocessing: scaling data to [0, 1] range
# scaler = MinMaxScaler()
# data_scaled = scaler.fit_transform(robust_df['RATE'].values.reshape(-1, 1))

# # Define your time_steps
# time_steps = 20

# # Creating a series generator for the LSTM autoencoder
# series_gen = TimeseriesGenerator(data_scaled, data_scaled, length=time_steps, batch_size=32)

# # Instantiate tuner
# tuner = BayesianOptimization(
#     build_model,
#     objective='loss',
#     max_trials=10,
#     executions_per_trial=2,
#     directory='my_dir',
#     project_name='lstm_autoencoder')

# # Perform hyperparameter search
# tuner.search(series_gen, epochs=50)

# # Get the best hyperparameters for LSTM
# best_lstm_params = tuner.get_best_hyperparameters()[0].values

# %%
# def ocsvm_cv(nu, data, targets):
#     estimator = OneClassSVM(nu=nu)
#     cval = cross_val_score(estimator, data, targets, scoring='roc_auc', cv=5)
#     return cval.mean()

# def optimize_ocsvm(data, targets):
#     def ocsvm_crossval(nu):
#         return ocsvm_cv(nu = nu, data=data, targets=targets)
    
#     optimizer = BayesianOptimization(
#         f=ocsvm_crossval,
#         pbounds={"nu": (0.01, 0.5)},
#         random_state=1234,
#         verbose=2
#     )
#     optimizer.maximize(n_iter=15)
    
#     print("Final result:", optimizer.max)
#     return optimizer.max['params']['nu']

# %%
# # Get the best hyperparameters for LSTM
# best_lstm_params = tuner.get_best_hyperparameters()[0].values
# print(f'Best LSTM Autoencoder param: {best_lstm_params}')

# # Get the best nu for One-Class SVM
# best_svm_nu = best_nu
# print(f'Best svm param: {best_svm_nu}')

# %%
# Define a result list
results = []

# Define the hyperparameters grid
param_grid = {
    'lstm_units': [64, 128],
    'time_steps': [10, 20],
    'batch_size': [16, 32],
    'epochs': [30, 50]
}

# Define early stopping
early_stopping = EarlyStopping(monitor='loss', patience=5)

# Create a random hyperparameters sampler
param_list = list(ParameterSampler(param_grid, n_iter=10, random_state=42))

# Start the manual random search
for params in param_list:
    # Extract parameters from current combination
    lstm_units, time_steps, batch_size, epochs = params['lstm_units'], params['time_steps'], params['batch_size'], params['epochs']
    
    # Create generator with current time_steps
    series_gen = TimeseriesGenerator(data_scaled, data_scaled, length=time_steps, batch_size=batch_size)
    
    # Create and train model with current hyperparameters
    model = Sequential([
        LSTM(lstm_units, activation='relu', input_shape=(time_steps, 1), return_sequences=False),
        RepeatVector(time_steps),
        LSTM(lstm_units, activation='relu', return_sequences=True),
        TimeDistributed(Dense(1))
    ])
    model.compile(optimizer='adam', loss='mse')
    history = model.fit(series_gen, epochs=epochs, verbose=0, callbacks=[early_stopping])
    
    # Calculate final loss
    final_loss = history.history['loss'][-1]
    
    # Append current hyperparameters and result to results list
    results.append((params, final_loss))

# Print results
for params, final_loss in results:
    print(f'Parameters: {params}, loss={final_loss}')
    

# Find best parameters
best_params, best_loss = min(results, key=lambda x: x[1])
# Out:
# Parameters: {'time_steps': 10, 'lstm_units': 64, 'epochs': 30, 'batch_size': 16}, loss=0.011554491706192493
# Parameters: {'time_steps': 20, 'lstm_units': 64, 'epochs': 30, 'batch_size': 16}, loss=0.008961677551269531
# Parameters: {'time_steps': 20, 'lstm_units': 64, 'epochs': 50, 'batch_size': 16}, loss=0.007455660030245781
# Parameters: {'time_steps': 10, 'lstm_units': 128, 'epochs': 50, 'batch_size': 32}, loss=0.008059121668338776
# Parameters: {'time_steps': 20, 'lstm_units': 64, 'epochs': 50, 'batch_size': 32}, loss=0.008904489688575268
# Parameters: {'time_steps': 20, 'lstm_units': 128, 'epochs': 30, 'batch_size': 32}, loss=0.008336562663316727
# Parameters: {'time_steps': 10, 'lstm_units': 64, 'epochs': 30, 'batch_size': 32}, loss=0.010636713355779648
# Parameters: {'time_steps': 20, 'lstm_units': 64, 'epochs': 30, 'batch_size': 32}, loss=0.008510679937899113
# Parameters: {'time_steps': 10, 'lstm_units': 128, 'epochs': 30, 'batch_size': 16}, loss=0.01243484579026699
# Parameters: {'time_steps': 20, 'lstm_units': 128, 'epochs': 50, 'batch_size': 32}, loss=0.007421215996146202

# %%
# Extracting parameters from best_params
time_steps = best_params['time_steps']
batch_size = best_params['batch_size']
lstm_units = best_params['lstm_units']
epochs = best_params['epochs']

# Creating a series generator for the LSTM autoencoder
series_gen = TimeseriesGenerator(data_scaled, data_scaled,
                                 length=time_steps, batch_size=batch_size)

# LSTM autoencoder
model = Sequential([
    LSTM(lstm_units, activation='relu', input_shape=(time_steps, 1), return_sequences=False),
    RepeatVector(time_steps),
    LSTM(lstm_units, activation='relu', return_sequences=True),
    TimeDistributed(Dense(1))
])
model.compile(optimizer='adam', loss='mse')
model.fit(series_gen, epochs=epochs)

# Calculating reconstruction error
preds = model.predict(series_gen)

# Reshape data_scaled to match preds' shape
data_scaled_reshaped = np.array([data_scaled[i-time_steps:i] for i in range(time_steps, len(data_scaled))])

# Calculate mean square error
errors = np.mean(np.square(preds - data_scaled_reshaped), axis=(1, 2))
# Out:
# Epoch 1/50
# 41/41 [==============================] - 4s 34ms/step - loss: 0.1698
# Epoch 2/50
# 41/41 [==============================] - 1s 35ms/step - loss: 0.0305
# Epoch 3/50
# 41/41 [==============================] - 1s 35ms/step - loss: 0.0582
# Epoch 4/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0288
# Epoch 5/50
# 41/41 [==============================] - 1s 36ms/step - loss: 0.0180
# Epoch 6/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0176
# Epoch 7/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0161
# Epoch 8/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0120
# Epoch 9/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0109
# Epoch 10/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0106
# Epoch 11/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0110
# Epoch 12/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0103
# Epoch 13/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0110
# Epoch 14/50
# 41/41 [==============================] - 1s 35ms/step - loss: 0.0106
# Epoch 15/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0092
# Epoch 16/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0085
# Epoch 17/50
# 41/41 [==============================] - 1s 35ms/step - loss: 0.0087
# Epoch 18/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0090
# Epoch 19/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0092
# Epoch 20/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0094
# Epoch 21/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0084
# Epoch 22/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0092
# Epoch 23/50
# 41/41 [==============================] - 1s 35ms/step - loss: 0.0087
# Epoch 24/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0082
# Epoch 25/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0076
# Epoch 26/50
# 41/41 [==============================] - 1s 35ms/step - loss: 0.0078
# Epoch 27/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0077
# Epoch 28/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0075
# Epoch 29/50
# 41/41 [==============================] - 1s 35ms/step - loss: 0.0080
# Epoch 30/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0083
# Epoch 31/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0090
# Epoch 32/50
# 41/41 [==============================] - 1s 35ms/step - loss: 0.0078
# Epoch 33/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0076
# Epoch 34/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0077
# Epoch 35/50
# 41/41 [==============================] - 1s 35ms/step - loss: 0.0073
# Epoch 36/50
# 41/41 [==============================] - 1s 35ms/step - loss: 0.0093
# Epoch 37/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0080
# Epoch 38/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0082
# Epoch 39/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0075
# Epoch 40/50
# 41/41 [==============================] - 1s 35ms/step - loss: 0.0071
# Epoch 41/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0079
# Epoch 42/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0072
# Epoch 43/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0075
# Epoch 44/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0086
# Epoch 45/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0075
# Epoch 46/50
# 41/41 [==============================] - 1s 35ms/step - loss: 0.0071
# Epoch 47/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0072
# Epoch 48/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0078
# Epoch 49/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0078
# Epoch 50/50
# 41/41 [==============================] - 1s 34ms/step - loss: 0.0080
# 41/41 [==============================] - 1s 10ms/step

# %%
# Define a list of possible nu values
nu_values = [0.01, 0.02, 0.05, 0.1, 0.2, 0.5]

best_nu = 0
best_score = float('inf')

# Loop over the nu_values
for nu in nu_values:
    # Using One-Class SVM for anomaly detection
    ocsvm = OneClassSVM(nu=nu)
    ocsvm.fit(errors.reshape(-1, 1))
    anomaly_flags = ocsvm.predict(errors.reshape(-1, 1))

    # Count the number of anomalies detected
    num_anomalies = sum(anomaly_flags == -1)

    # Calculate the mean square error of anomalies
    mse_anomalies = np.mean(errors[anomaly_flags == -1])

    # Combine num_anomalies and mse_anomalies into a score
    # This is just one example of how to score. You should adjust this to fit your needs.
    score = num_anomalies * mse_anomalies

    # If the score for this nu value is better than our current best, update best_nu and best_score
    if score < best_score:
        best_nu = nu
        best_score = score

    print(f"nu: {nu}, score: {score}")

print(f"Best nu: {best_nu}, best score: {best_score}")
# Out:
# OneClassSVM(nu=0.01)
# nu: 0.01, score: 3.1761036857996308
# OneClassSVM(nu=0.02)
# nu: 0.02, score: 3.6140775883030902
# OneClassSVM(nu=0.05)
# nu: 0.05, score: 6.1620683073125555
# OneClassSVM(nu=0.1)
# nu: 0.1, score: 9.720992701949847
# OneClassSVM(nu=0.2)
# nu: 0.2, score: 12.655579703117745
# OneClassSVM()
# nu: 0.5, score: 15.847038657971538
# Best nu: 0.01, best score: 3.1761036857996308

# %%
# Using One-Class SVM for anomaly detection
ocsvm = OneClassSVM(nu=0.5)
ocsvm.fit(errors.reshape(-1, 1))
anomaly_flags = ocsvm.predict(errors.reshape(-1, 1))

# Marking anomalies in the data
robust_df['Anomaly'] = 0
robust_df.iloc[time_steps:len(preds) + time_steps, robust_df.columns.get_loc('Anomaly')] = anomaly_flags

# If you want to exclude anomalies from the data:
df_no_anomalies = robust_df[robust_df['Anomaly'] != -1]
# Out:
# OneClassSVM()

# %%
plt.figure(figsize=(20, 10))
plt.plot(robust_df['POD'], robust_df['RATE'], color='blue', label="Data")
plt.scatter(df_no_anomalies['POD'], df_no_anomalies['RATE'], color='red', label="Anomalies")
plt.legend()
plt.show()

# %% [markdown]
# <h4>Handling Anomaly</h4>

# %%
# calculate skewness
skewness = skew(robust_df['RATE'])

# if skewness is high, fill anomalies with median, else fill with mean
if abs(skewness) > 0.5:
    robust_df.loc[robust_df['Anomaly'] == -1, 'RATE'] = robust_df['RATE'].median()
else:
    robust_df.loc[robust_df['Anomaly'] == -1, 'RATE'] = robust_df['RATE'].mean()
  
# Plot to visualise
plt.figure(figsize=(20, 10))
plt.plot(sel_df['POD'], sel_df['RATE'], color='blue', label="Actual Data")
plt.plot(robust_df['POD'], robust_df['RATE'], color='Red', label="Data after handling anomaly")
plt.title(sel_country)
plt.legend()
plt.show();

# %%
# Remove Anomaly column
without_ann = ['POD','RATE']
robust_df = robust_df[without_ann]

# %% [markdown]
# <h4>Interpolate missing values in between dates</h4>

# %%
# Remove duplicated dates and cost rows
robust_df = robust_df.drop_duplicates(subset=['POD', 'RATE']).reset_index(drop=True)

# Create a new dataframe with a date range from min to max date in your dataframe
new_df = pd.DataFrame()
new_df['POD'] = pd.date_range(start=robust_df['POD'].min(), end=robust_df['POD'].max())

# Merge the original dataframe with the new one. Missing dates in the original dataframe will be filled with NaN
df_interpolated = pd.merge(new_df, robust_df, on='POD', how='left')  

# Perform spline interpolation
df_interpolated['RATE'] = df_interpolated['RATE'].interpolate(method='polynomial', order=1)

df_interpolated['RATE'] = df_interpolated['RATE'].round(3)

df_interpolated.head(5)
df_interpolated.tail(5)
df_interpolated.info()
# Out:
#          POD    RATE
# 0 2005-07-23  1200.0
# 1 2005-07-24  1200.0
# 2 2005-07-25  1200.0
# 3 2005-07-26  1200.0
# 4 2005-07-27  1200.0
#             POD   RATE
# 6447 2023-02-20  800.0
# 6448 2023-02-21  800.0
# 6449 2023-02-22  800.0
# 6450 2023-02-23  800.0
# 6451 2023-02-24  800.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6452 entries, 0 to 6451
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POD     6452 non-null   datetime64[ns]
#  1   RATE    6452 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 151.2 KB

# %% [markdown]
# <h4>Grouping it to week</h4>

# %%
from scipy import stats

# Create YearMonthWeek directly from the 'POD'
df_interpolated['YearMonthWeek'] = df_interpolated['POD'] - pd.to_timedelta(df_interpolated['POD'].dt.dayofweek, unit='D')

# Create a new dataframe with every week in the range
all_weeks = pd.date_range(start=df_interpolated['POD'].min(), end=df_interpolated['POD'].max(), freq='W')
all_weeks_df = pd.DataFrame(all_weeks, columns=['POD'])

# Create YearMonthWeek in all_weeks_df
all_weeks_df['YearMonthWeek'] = all_weeks_df['POD'] - pd.to_timedelta(all_weeks_df['POD'].dt.dayofweek, unit='D')

# Merge this with your original dataframe
merged_df = pd.merge(all_weeks_df, df_interpolated, on=['YearMonthWeek'], how='left')

# Now you can group by YearMonthWeek and compute your rate
grouped = merged_df.groupby(['YearMonthWeek'])

agg_df = pd.DataFrame(columns=['YearMonthWeek', 'Rate'])

for group_name, group_df in grouped:
    year_month_week = group_name

    # Skip if no data for this week
    if group_df['RATE'].isnull().all():
        continue

    # Calculate sum and skewness of RATE values
    rate_sum = group_df['RATE'].sum()
    rate_skew = group_df['RATE'].skew()

    # Calculate trimmed mean of RATE values
    rate_metric = stats.trim_mean(group_df['RATE'].dropna().values, 0.1) # trimming 10% from each end

    new_row = {
        'YearMonthWeek': year_month_week,
        'Rate': rate_metric
    }

    # Append row to aggregated dataframe
    agg_df = agg_df.append(new_row, ignore_index=True)

agg_df = agg_df.sort_values(by='YearMonthWeek').reset_index(drop=True)
agg_df['Rate'] = agg_df['Rate'].round(2)

agg_df.head(15)
agg_df.tail(15)
agg_df.info()
# Out:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:21: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for group_name, group_df in grouped:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# ...
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
#    YearMonthWeek     Rate
# 0     2005-07-18  1200.00
# 1     2005-07-25  1198.32
# 2     2005-08-01  1141.18
# 3     2005-08-08  1058.82
# 4     2005-08-15  1113.54
# 5     2005-08-22  1166.04
# 6     2005-08-29  1126.42
# 7     2005-09-05  1086.79
# 8     2005-09-12  1047.17
# 9     2005-09-19  1007.55
# 10    2005-09-26   967.92
# 11    2005-10-03   928.30
# 12    2005-10-10   900.81
# 13    2005-10-17   900.00
# 14    2005-10-24   900.00
#     YearMonthWeek   Rate
# 903    2022-11-07  800.0
# 904    2022-11-14  800.0
# 905    2022-11-21  800.0
# 906    2022-11-28  800.0
# 907    2022-12-05  800.0
# 908    2022-12-12  800.0
# 909    2022-12-19  800.0
# 910    2022-12-26  800.0
# 911    2023-01-02  800.0
# 912    2023-01-09  800.0
# 913    2023-01-16  800.0
# 914    2023-01-23  800.0
# 915    2023-01-30  800.0
# 916    2023-02-06  800.0
# 917    2023-02-13  800.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   YearMonthWeek  918 non-null    datetime64[ns]
#  1   Rate           918 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 14.5 KB

# %% [markdown]
# <h4>Latest datapoints from Latest dataframe for comparing after forecasting (Measure accuracy)</h4>

# %%
max_date_in_old = sel_df['POD'].max()

# Create a new dataframe that only includes rows from the latest dataframe where the date is greater than the maximum date in the old dataframe
new_dates_df = latest_sel_df[latest_sel_df['POD'] > max_date_in_old].reset_index(drop=True)

# Print the new dataframe
new_dates_df.head(3)
new_dates_df.tail(3)
new_dates_df.info()
# Out:
#             CSL_ID       CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 0  ECS010230200328  010000409869  MELBOURNE     AUMEL  01002778
# 1  ECS010230200329  010000419018  MELBOURNE     AUMEL  01002778
# 2  ECS010230200330  010000427048  MELBOURNE     AUMEL  01002778
#
#                                   PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-03-02        40        HC
# 1  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-03-10        40        HC
# 2  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-03-16        40        HC
#
#      RATE
# 0  1000.0
# 1  1000.0
# 2  1000.0
#              CSL_ID       CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 13  ECS010230400431  010000541165  MELBOURNE     AUMEL  01002778
# 14  ECS010230400432  010000543217  MELBOURNE     AUMEL  01002778
# 15  ECS010230400433  010000557443  MELBOURNE     AUMEL  01002778
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 13  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-05        40        HC
# 14  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-11        40        HC
# 15  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-19        40        HC
#
#      RATE
# 13  500.0
# 14  500.0
# 15  400.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      16 non-null     object
#  1   CNTR_ID     16 non-null     object
#  2   POD_ID      16 non-null     object
#  3   ETD_POL_D   16 non-null     object
#  4   PARTY_ID    16 non-null     object
#  5   PARTY_NAME  16 non-null     object
#  6   POD         16 non-null     datetime64[ns]
#  7   CNTR_SIZE   16 non-null     object
#  8   CNTR_TYPE   16 non-null     object
#  9   RATE        16 non-null     float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 1.4+ KB

# %%
plt.figure(figsize=(20, 10))
plt.plot(sel_df['POD'], sel_df['RATE'], color='blue', label="Actual Data")
plt.plot(agg_df['YearMonthWeek'], agg_df['Rate'], color='red', label="Aggregated Data(weeks)")

plt.xlabel('Date(Year Month Week)')
plt.ylabel('Cost Rate(USD)')
plt.title(sel_country)
plt.legend()
plt.show();

# %% [markdown]
# <h4>LSTM Regression<h4>

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# Mean Square Error Function:
def calculate_RMSE(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# Update create_dataset to handle multi-feature dataset
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), :]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)


def create_LSTM_model(trainX, trainY, testX, testY, epochs, lstm_layers):
    model = Sequential()
    
    for i in range(len(lstm_layers)):
        if i == 0:
            # First layer specifies the input_shape and returns sequences
            model.add(LSTM(lstm_layers[i], return_sequences=True, input_shape=(look_back, trainX.shape[2]), 
                           activation='tanh', recurrent_activation='hard_sigmoid', kernel_regularizer=l2(0.01)))
        elif i == len(lstm_layers) - 1:
            # Last layer doesn't return sequences
            model.add(LSTM(lstm_layers[i], activation='tanh', kernel_regularizer=l2(0.01)))
        else:
            # Middle layers return sequences
            model.add(LSTM(lstm_layers[i], return_sequences=True, activation='tanh', 
                           recurrent_activation='hard_sigmoid', kernel_regularizer=l2(0.01)))
        model.add(Dropout(0.2))
        
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=0.0005))
    model.summary()

    # Add early stopping
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)
    
    # Fit the model and store the history
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=128, verbose=2, 
                        validation_data=(testX, testY), callbacks=[es])
    return model, history


def plot_train_val_loss(history):
    plt.figure(figsize=(10,6))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model loss progress during training and validation')
    plt.xlabel('Epoch')
    plt.ylabel('Training and Validation Loss')
    plt.legend()
    plt.show()

# %%
# Normalize dataset for LSTM
from sklearn.preprocessing import MinMaxScaler

# Initialize two separate scalers
scaler_rate = MinMaxScaler(feature_range=(0, 1))

# Fit and transform 'RATE' and 'during_covid' separately
rate_scaled = scaler_rate.fit_transform(agg_df[['Rate']])

# Concatenate the scaled data
dataset = np.concatenate([rate_scaled], axis=1)

# Split into train and test sets
train_size = int(len(dataset) * 0.7)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# Reshape into X=t and Y=t+1, timestep  look_back
look_back = 5
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# Reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], look_back, trainX.shape[2]))
testX = np.reshape(testX, (testX.shape[0], look_back, testX.shape[2]))

epochs_list = [50, 100, 150]

lstm_layers_list = [
    [64, 64, 32, 32, 16, 16, 8, 8, 4, 4, 2, 2],
    [32, 32, 16, 16, 8, 8, 4, 4, 2, 2],
    [16, 16, 8, 8, 4, 4, 2, 2],
    [8, 8, 4, 4, 2, 2],
    [4, 4, 2, 2],
    [2, 2]
]

rmse_results = {}

for epochs in epochs_list:
    print(f'Training for {epochs} epochs...')
    
    for lstm_layers in lstm_layers_list:
        print(f'Training with LSTM layers: {lstm_layers}')
        model, history = create_LSTM_model(trainX, trainY, testX, testY, epochs, lstm_layers)
        
        # Add the loss for this model to the plot
        plt.plot(history.history['loss'], label=f'Train Loss - {epochs} epochs, layers: {lstm_layers}')
        plt.plot(history.history['val_loss'], label=f'Validation Loss - {epochs} epochs, layers: {lstm_layers}')

        # Evalute LSTM Model
        trainPredict = model.predict(trainX)
        testPredict = model.predict(testX)

        # inverse_transform
        trainPredict = scaler.inverse_transform(trainPredict)
        trainY_orig = scaler.inverse_transform([trainY])
        testPredict = scaler.inverse_transform(testPredict)
        testY_orig = scaler.inverse_transform([testY])

        # Calculate mean squared error
        trainScore = calculate_RMSE(trainY_orig[0], trainPredict[:,0])
        print(f'Train Score: {trainScore:.2f} RMSE for {epochs} epochs')
        testScore = calculate_RMSE(testY_orig[0], testPredict[:,0])
        print(f'Test Score: {testScore:.2f} RMSE for {epochs} epochs')

        rmse_results[f'{epochs} epochs, {lstm_layers} layers'] = {'Train RMSE': trainScore, 'Test RMSE': testScore}

# Configure and show the plot
plt.title('Model loss progress during training and validation')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend()
plt.show();

# Convert the dictionary to a DataFrame for easy display
rmse_df = pd.DataFrame(rmse_results).T
print(rmse_df)
# Out:
# Training for 50 epochs...
# Training with LSTM layers: [64, 64, 32, 32, 16, 16, 8, 8, 4, 4, 2, 2]
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_46 (LSTM)              (None, 5, 64)             16896
#
#  dropout (Dropout)           (None, 5, 64)             0
#
#  lstm_47 (LSTM)              (None, 5, 64)             33024
#
#  dropout_1 (Dropout)         (None, 5, 64)             0
#
#  lstm_48 (LSTM)              (None, 5, 32)             12416
#
#  dropout_2 (Dropout)         (None, 5, 32)             0
#
#  lstm_49 (LSTM)              (None, 5, 32)             8320
#
#  dropout_3 (Dropout)         (None, 5, 32)             0
#
#  lstm_50 (LSTM)              (None, 5, 16)             3136
#
#  dropout_4 (Dropout)         (None, 5, 16)             0
#
#  lstm_51 (LSTM)              (None, 5, 16)             2112
#
#  dropout_5 (Dropout)         (None, 5, 16)             0
#
#  lstm_52 (LSTM)              (None, 5, 8)              800
#
#  dropout_6 (Dropout)         (None, 5, 8)              0
#
#  lstm_53 (LSTM)              (None, 5, 8)              544
#
#  dropout_7 (Dropout)         (None, 5, 8)              0
#
#  lstm_54 (LSTM)              (None, 5, 4)              208
#
#  dropout_8 (Dropout)         (None, 5, 4)              0
#
#  lstm_55 (LSTM)              (None, 5, 4)              144
#
#  dropout_9 (Dropout)         (None, 5, 4)              0
#
#  lstm_56 (LSTM)              (None, 5, 2)              56
#
#  dropout_10 (Dropout)        (None, 5, 2)              0
#
#  lstm_57 (LSTM)              (None, 2)                 40
#
#  dropout_11 (Dropout)        (None, 2)                 0
#
#  dense_23 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 77,699
# Trainable params: 77,699
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 26s - loss: 3.6556 - val_loss: 3.6038 - 26s/epoch - 5s/step
# Epoch 2/50
# 5/5 - 0s - loss: 3.5153 - val_loss: 3.4657 - 247ms/epoch - 49ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 3.3795 - val_loss: 3.3323 - 251ms/epoch - 50ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 3.2484 - val_loss: 3.2035 - 246ms/epoch - 49ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 3.1220 - val_loss: 3.0795 - 262ms/epoch - 52ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 3.0003 - val_loss: 2.9602 - 239ms/epoch - 48ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 2.8833 - val_loss: 2.8456 - 240ms/epoch - 48ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 2.7709 - val_loss: 2.7355 - 238ms/epoch - 48ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 2.6631 - val_loss: 2.6298 - 236ms/epoch - 47ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 2.5597 - val_loss: 2.5284 - 235ms/epoch - 47ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 2.4603 - val_loss: 2.4311 - 237ms/epoch - 47ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 2.3649 - val_loss: 2.3378 - 235ms/epoch - 47ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 2.2737 - val_loss: 2.2482 - 236ms/epoch - 47ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 2.1860 - val_loss: 2.1623 - 236ms/epoch - 47ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 2.1019 - val_loss: 2.0798 - 235ms/epoch - 47ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 2.0212 - val_loss: 2.0007 - 242ms/epoch - 48ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 1.9439 - val_loss: 1.9248 - 239ms/epoch - 48ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 1.8698 - val_loss: 1.8520 - 239ms/epoch - 48ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 1.7984 - val_loss: 1.7821 - 240ms/epoch - 48ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 1.7301 - val_loss: 1.7151 - 241ms/epoch - 48ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 1.6647 - val_loss: 1.6508 - 238ms/epoch - 48ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 1.6019 - val_loss: 1.5890 - 236ms/epoch - 47ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 1.5419 - val_loss: 1.5298 - 235ms/epoch - 47ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 1.4837 - val_loss: 1.4730 - 240ms/epoch - 48ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 1.4285 - val_loss: 1.4186 - 239ms/epoch - 48ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 1.3751 - val_loss: 1.3663 - 237ms/epoch - 47ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 1.3241 - val_loss: 1.3161 - 254ms/epoch - 51ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 1.2752 - val_loss: 1.2680 - 240ms/epoch - 48ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 1.2280 - val_loss: 1.2219 - 245ms/epoch - 49ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 1.1834 - val_loss: 1.1776 - 239ms/epoch - 48ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 1.1399 - val_loss: 1.1351 - 240ms/epoch - 48ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 1.0982 - val_loss: 1.0944 - 239ms/epoch - 48ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 1.0584 - val_loss: 1.0553 - 245ms/epoch - 49ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 1.0201 - val_loss: 1.0178 - 238ms/epoch - 48ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.9835 - val_loss: 0.9818 - 239ms/epoch - 48ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.9483 - val_loss: 0.9473 - 240ms/epoch - 48ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.9145 - val_loss: 0.9142 - 244ms/epoch - 49ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.8819 - val_loss: 0.8823 - 238ms/epoch - 48ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.8506 - val_loss: 0.8518 - 238ms/epoch - 48ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.8209 - val_loss: 0.8225 - 239ms/epoch - 48ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.7921 - val_loss: 0.7944 - 244ms/epoch - 49ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.7645 - val_loss: 0.7674 - 240ms/epoch - 48ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.7380 - val_loss: 0.7415 - 262ms/epoch - 52ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.7123 - val_loss: 0.7166 - 238ms/epoch - 48ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.6882 - val_loss: 0.6927 - 241ms/epoch - 48ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.6643 - val_loss: 0.6697 - 243ms/epoch - 49ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.6418 - val_loss: 0.6476 - 237ms/epoch - 47ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.6205 - val_loss: 0.6264 - 237ms/epoch - 47ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.5994 - val_loss: 0.6060 - 236ms/epoch - 47ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.5793 - val_loss: 0.5865 - 238ms/epoch - 48ms/step
# 20/20 [==============================] - 2s 7ms/step
# 9/9 [==============================] - 0s 6ms/step
# Train Score: 226.52 RMSE for 50 epochs
# Test Score: 555.33 RMSE for 50 epochs
# Training with LSTM layers: [32, 32, 16, 16, 8, 8, 4, 4, 2, 2]
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_58 (LSTM)              (None, 5, 32)             4352
#
#  dropout_12 (Dropout)        (None, 5, 32)             0
#
#  lstm_59 (LSTM)              (None, 5, 32)             8320
#
#  dropout_13 (Dropout)        (None, 5, 32)             0
#
#  lstm_60 (LSTM)              (None, 5, 16)             3136
#
#  dropout_14 (Dropout)        (None, 5, 16)             0
#
#  lstm_61 (LSTM)              (None, 5, 16)             2112
#
#  dropout_15 (Dropout)        (None, 5, 16)             0
#
#  lstm_62 (LSTM)              (None, 5, 8)              800
#
#  dropout_16 (Dropout)        (None, 5, 8)              0
#
#  lstm_63 (LSTM)              (None, 5, 8)              544
#
#  dropout_17 (Dropout)        (None, 5, 8)              0
#
#  lstm_64 (LSTM)              (None, 5, 4)              208
#
#  dropout_18 (Dropout)        (None, 5, 4)              0
#
#  lstm_65 (LSTM)              (None, 5, 4)              144
#
#  dropout_19 (Dropout)        (None, 5, 4)              0
#
#  lstm_66 (LSTM)              (None, 5, 2)              56
#
#  dropout_20 (Dropout)        (None, 5, 2)              0
#
#  lstm_67 (LSTM)              (None, 2)                 40
#
#  dropout_21 (Dropout)        (None, 2)                 0
#
#  dense_24 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 19,715
# Trainable params: 19,715
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 21s - loss: 1.7983 - val_loss: 1.8011 - 21s/epoch - 4s/step
# Epoch 2/50
# 5/5 - 0s - loss: 1.7479 - val_loss: 1.7509 - 188ms/epoch - 38ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 1.6985 - val_loss: 1.7019 - 182ms/epoch - 36ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 1.6504 - val_loss: 1.6541 - 180ms/epoch - 36ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 1.6035 - val_loss: 1.6075 - 175ms/epoch - 35ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 1.5579 - val_loss: 1.5622 - 191ms/epoch - 38ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 1.5135 - val_loss: 1.5181 - 176ms/epoch - 35ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 1.4704 - val_loss: 1.4753 - 179ms/epoch - 36ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 1.4285 - val_loss: 1.4337 - 175ms/epoch - 35ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 1.3878 - val_loss: 1.3932 - 175ms/epoch - 35ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 1.3484 - val_loss: 1.3540 - 176ms/epoch - 35ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 1.3099 - val_loss: 1.3159 - 175ms/epoch - 35ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 1.2727 - val_loss: 1.2788 - 176ms/epoch - 35ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 1.2366 - val_loss: 1.2429 - 176ms/epoch - 35ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 1.2017 - val_loss: 1.2080 - 176ms/epoch - 35ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 1.1676 - val_loss: 1.1741 - 179ms/epoch - 36ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 1.1344 - val_loss: 1.1412 - 175ms/epoch - 35ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 1.1025 - val_loss: 1.1093 - 175ms/epoch - 35ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 1.0712 - val_loss: 1.0783 - 175ms/epoch - 35ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 1.0410 - val_loss: 1.0482 - 175ms/epoch - 35ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 1.0118 - val_loss: 1.0189 - 176ms/epoch - 35ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 0.9835 - val_loss: 0.9906 - 175ms/epoch - 35ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 0.9559 - val_loss: 0.9631 - 178ms/epoch - 36ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.9291 - val_loss: 0.9364 - 175ms/epoch - 35ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.9032 - val_loss: 0.9105 - 175ms/epoch - 35ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.8780 - val_loss: 0.8854 - 181ms/epoch - 36ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.8536 - val_loss: 0.8610 - 174ms/epoch - 35ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.8300 - val_loss: 0.8374 - 179ms/epoch - 36ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.8072 - val_loss: 0.8145 - 181ms/epoch - 36ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.7845 - val_loss: 0.7923 - 179ms/epoch - 36ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.7628 - val_loss: 0.7708 - 176ms/epoch - 35ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.7423 - val_loss: 0.7499 - 174ms/epoch - 35ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.7215 - val_loss: 0.7296 - 177ms/epoch - 35ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.7017 - val_loss: 0.7099 - 177ms/epoch - 35ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.6826 - val_loss: 0.6909 - 178ms/epoch - 36ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.6639 - val_loss: 0.6724 - 177ms/epoch - 35ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.6458 - val_loss: 0.6544 - 175ms/epoch - 35ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.6281 - val_loss: 0.6370 - 177ms/epoch - 35ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.6110 - val_loss: 0.6201 - 202ms/epoch - 40ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.5945 - val_loss: 0.6037 - 178ms/epoch - 36ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.5783 - val_loss: 0.5878 - 177ms/epoch - 35ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.5625 - val_loss: 0.5724 - 176ms/epoch - 35ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.5474 - val_loss: 0.5574 - 178ms/epoch - 36ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.5325 - val_loss: 0.5428 - 176ms/epoch - 35ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.5181 - val_loss: 0.5287 - 175ms/epoch - 35ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.5043 - val_loss: 0.5149 - 177ms/epoch - 35ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.4906 - val_loss: 0.5016 - 177ms/epoch - 35ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.4778 - val_loss: 0.4887 - 177ms/epoch - 35ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.4646 - val_loss: 0.4761 - 177ms/epoch - 35ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.4524 - val_loss: 0.4639 - 176ms/epoch - 35ms/step
# 20/20 [==============================] - 2s 6ms/step
# 9/9 [==============================] - 0s 5ms/step
# Train Score: 226.57 RMSE for 50 epochs
# Test Score: 555.48 RMSE for 50 epochs
# Training with LSTM layers: [16, 16, 8, 8, 4, 4, 2, 2]
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_68 (LSTM)              (None, 5, 16)             1152
#
#  dropout_22 (Dropout)        (None, 5, 16)             0
#
#  lstm_69 (LSTM)              (None, 5, 16)             2112
#
#  dropout_23 (Dropout)        (None, 5, 16)             0
#
#  lstm_70 (LSTM)              (None, 5, 8)              800
#
#  dropout_24 (Dropout)        (None, 5, 8)              0
#
#  lstm_71 (LSTM)              (None, 5, 8)              544
#
#  dropout_25 (Dropout)        (None, 5, 8)              0
#
#  lstm_72 (LSTM)              (None, 5, 4)              208
#
#  dropout_26 (Dropout)        (None, 5, 4)              0
#
#  lstm_73 (LSTM)              (None, 5, 4)              144
#
#  dropout_27 (Dropout)        (None, 5, 4)              0
#
#  lstm_74 (LSTM)              (None, 5, 2)              56
#
#  dropout_28 (Dropout)        (None, 5, 2)              0
#
#  lstm_75 (LSTM)              (None, 2)                 40
#
#  dropout_29 (Dropout)        (None, 2)                 0
#
#  dense_25 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 5,059
# Trainable params: 5,059
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 17s - loss: 0.8812 - val_loss: 0.9025 - 17s/epoch - 3s/step
# Epoch 2/50
# 5/5 - 0s - loss: 0.8618 - val_loss: 0.8826 - 145ms/epoch - 29ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 0.8428 - val_loss: 0.8631 - 142ms/epoch - 28ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 0.8241 - val_loss: 0.8440 - 144ms/epoch - 29ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 0.8060 - val_loss: 0.8253 - 139ms/epoch - 28ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 0.7883 - val_loss: 0.8071 - 139ms/epoch - 28ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 0.7709 - val_loss: 0.7893 - 140ms/epoch - 28ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 0.7540 - val_loss: 0.7720 - 139ms/epoch - 28ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 0.7375 - val_loss: 0.7551 - 137ms/epoch - 27ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 0.7215 - val_loss: 0.7386 - 139ms/epoch - 28ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 0.7058 - val_loss: 0.7225 - 139ms/epoch - 28ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 0.6909 - val_loss: 0.7069 - 139ms/epoch - 28ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 0.6761 - val_loss: 0.6917 - 140ms/epoch - 28ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 0.6619 - val_loss: 0.6770 - 142ms/epoch - 28ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 0.6477 - val_loss: 0.6626 - 139ms/epoch - 28ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 0.6341 - val_loss: 0.6486 - 140ms/epoch - 28ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 0.6208 - val_loss: 0.6350 - 138ms/epoch - 28ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 0.6079 - val_loss: 0.6217 - 142ms/epoch - 28ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 0.5947 - val_loss: 0.6088 - 143ms/epoch - 29ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 0.5826 - val_loss: 0.5962 - 141ms/epoch - 28ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 0.5703 - val_loss: 0.5839 - 140ms/epoch - 28ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 0.5587 - val_loss: 0.5720 - 140ms/epoch - 28ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 0.5474 - val_loss: 0.5604 - 140ms/epoch - 28ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.5359 - val_loss: 0.5490 - 140ms/epoch - 28ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.5246 - val_loss: 0.5379 - 141ms/epoch - 28ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.5136 - val_loss: 0.5271 - 142ms/epoch - 28ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.5034 - val_loss: 0.5166 - 140ms/epoch - 28ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.4929 - val_loss: 0.5062 - 141ms/epoch - 28ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.4831 - val_loss: 0.4961 - 160ms/epoch - 32ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.4727 - val_loss: 0.4863 - 159ms/epoch - 32ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.4632 - val_loss: 0.4766 - 140ms/epoch - 28ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.4538 - val_loss: 0.4671 - 141ms/epoch - 28ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.4444 - val_loss: 0.4579 - 140ms/epoch - 28ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.4353 - val_loss: 0.4488 - 140ms/epoch - 28ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.4262 - val_loss: 0.4400 - 141ms/epoch - 28ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.4172 - val_loss: 0.4313 - 140ms/epoch - 28ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.4089 - val_loss: 0.4228 - 140ms/epoch - 28ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.4004 - val_loss: 0.4145 - 140ms/epoch - 28ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.3922 - val_loss: 0.4063 - 141ms/epoch - 28ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.3842 - val_loss: 0.3983 - 141ms/epoch - 28ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.3760 - val_loss: 0.3905 - 140ms/epoch - 28ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.3687 - val_loss: 0.3828 - 140ms/epoch - 28ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.3610 - val_loss: 0.3753 - 140ms/epoch - 28ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.3535 - val_loss: 0.3679 - 143ms/epoch - 29ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.3462 - val_loss: 0.3608 - 142ms/epoch - 28ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.3392 - val_loss: 0.3537 - 139ms/epoch - 28ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.3322 - val_loss: 0.3468 - 141ms/epoch - 28ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.3253 - val_loss: 0.3400 - 139ms/epoch - 28ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.3183 - val_loss: 0.3334 - 141ms/epoch - 28ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.3117 - val_loss: 0.3269 - 143ms/epoch - 29ms/step
# 20/20 [==============================] - 1s 5ms/step
# 9/9 [==============================] - 0s 4ms/step
# Train Score: 227.41 RMSE for 50 epochs
# Test Score: 557.83 RMSE for 50 epochs
# Training with LSTM layers: [8, 8, 4, 4, 2, 2]
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_76 (LSTM)              (None, 5, 8)              320
#
#  dropout_30 (Dropout)        (None, 5, 8)              0
#
#  lstm_77 (LSTM)              (None, 5, 8)              544
#
#  dropout_31 (Dropout)        (None, 5, 8)              0
#
#  lstm_78 (LSTM)              (None, 5, 4)              208
#
#  dropout_32 (Dropout)        (None, 5, 4)              0
#
#  lstm_79 (LSTM)              (None, 5, 4)              144
#
#  dropout_33 (Dropout)        (None, 5, 4)              0
#
#  lstm_80 (LSTM)              (None, 5, 2)              56
#
#  dropout_34 (Dropout)        (None, 5, 2)              0
#
#  lstm_81 (LSTM)              (None, 2)                 40
#
#  dropout_35 (Dropout)        (None, 2)                 0
#
#  dense_26 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 1,315
# Trainable params: 1,315
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 12s - loss: 0.3922 - val_loss: 0.4211 - 12s/epoch - 2s/step
# Epoch 2/50
# 5/5 - 0s - loss: 0.3850 - val_loss: 0.4135 - 112ms/epoch - 22ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 0.3780 - val_loss: 0.4060 - 110ms/epoch - 22ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 0.3711 - val_loss: 0.3986 - 111ms/epoch - 22ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 0.3643 - val_loss: 0.3914 - 107ms/epoch - 21ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 0.3576 - val_loss: 0.3843 - 108ms/epoch - 22ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 0.3511 - val_loss: 0.3773 - 107ms/epoch - 21ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 0.3446 - val_loss: 0.3704 - 107ms/epoch - 21ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 0.3384 - val_loss: 0.3637 - 109ms/epoch - 22ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 0.3325 - val_loss: 0.3571 - 109ms/epoch - 22ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 0.3266 - val_loss: 0.3507 - 109ms/epoch - 22ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 0.3205 - val_loss: 0.3444 - 109ms/epoch - 22ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 0.3147 - val_loss: 0.3383 - 109ms/epoch - 22ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 0.3093 - val_loss: 0.3323 - 108ms/epoch - 22ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 0.3041 - val_loss: 0.3264 - 110ms/epoch - 22ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 0.2988 - val_loss: 0.3207 - 109ms/epoch - 22ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 0.2937 - val_loss: 0.3151 - 111ms/epoch - 22ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 0.2885 - val_loss: 0.3096 - 111ms/epoch - 22ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 0.2836 - val_loss: 0.3043 - 110ms/epoch - 22ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 0.2790 - val_loss: 0.2992 - 111ms/epoch - 22ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 0.2742 - val_loss: 0.2942 - 109ms/epoch - 22ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 0.2697 - val_loss: 0.2893 - 108ms/epoch - 22ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 0.2653 - val_loss: 0.2845 - 109ms/epoch - 22ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.2612 - val_loss: 0.2799 - 109ms/epoch - 22ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.2566 - val_loss: 0.2754 - 108ms/epoch - 22ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.2527 - val_loss: 0.2710 - 109ms/epoch - 22ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.2488 - val_loss: 0.2668 - 109ms/epoch - 22ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.2449 - val_loss: 0.2626 - 108ms/epoch - 22ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.2412 - val_loss: 0.2586 - 108ms/epoch - 22ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.2372 - val_loss: 0.2546 - 107ms/epoch - 21ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.2331 - val_loss: 0.2508 - 109ms/epoch - 22ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.2298 - val_loss: 0.2470 - 110ms/epoch - 22ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.2266 - val_loss: 0.2433 - 110ms/epoch - 22ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.2226 - val_loss: 0.2398 - 110ms/epoch - 22ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.2192 - val_loss: 0.2363 - 111ms/epoch - 22ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.2159 - val_loss: 0.2328 - 109ms/epoch - 22ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.2124 - val_loss: 0.2294 - 109ms/epoch - 22ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.2089 - val_loss: 0.2261 - 109ms/epoch - 22ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.2058 - val_loss: 0.2228 - 108ms/epoch - 22ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.2024 - val_loss: 0.2196 - 132ms/epoch - 26ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.1993 - val_loss: 0.2164 - 111ms/epoch - 22ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.1963 - val_loss: 0.2133 - 109ms/epoch - 22ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.1930 - val_loss: 0.2103 - 110ms/epoch - 22ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.1902 - val_loss: 0.2073 - 110ms/epoch - 22ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.1870 - val_loss: 0.2043 - 112ms/epoch - 22ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.1844 - val_loss: 0.2014 - 108ms/epoch - 22ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.1812 - val_loss: 0.1985 - 109ms/epoch - 22ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.1785 - val_loss: 0.1957 - 111ms/epoch - 22ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.1756 - val_loss: 0.1930 - 110ms/epoch - 22ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.1731 - val_loss: 0.1902 - 109ms/epoch - 22ms/step
# 20/20 [==============================] - 1s 4ms/step
# 9/9 [==============================] - 0s 3ms/step
# Train Score: 226.97 RMSE for 50 epochs
# Test Score: 556.64 RMSE for 50 epochs
# Training with LSTM layers: [4, 4, 2, 2]
# Model: "sequential_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_82 (LSTM)              (None, 5, 4)              96
#
#  dropout_36 (Dropout)        (None, 5, 4)              0
#
#  lstm_83 (LSTM)              (None, 5, 4)              144
#
#  dropout_37 (Dropout)        (None, 5, 4)              0
#
#  lstm_84 (LSTM)              (None, 5, 2)              56
#
#  dropout_38 (Dropout)        (None, 5, 2)              0
#
#  lstm_85 (LSTM)              (None, 2)                 40
#
#  dropout_39 (Dropout)        (None, 2)                 0
#
#  dense_27 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 339
# Trainable params: 339
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 9s - loss: 0.1893 - val_loss: 0.2205 - 9s/epoch - 2s/step
# Epoch 2/50
# 5/5 - 0s - loss: 0.1861 - val_loss: 0.2168 - 84ms/epoch - 17ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 0.1829 - val_loss: 0.2132 - 83ms/epoch - 17ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 0.1799 - val_loss: 0.2097 - 85ms/epoch - 17ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 0.1768 - val_loss: 0.2062 - 81ms/epoch - 16ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 0.1737 - val_loss: 0.2027 - 80ms/epoch - 16ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 0.1709 - val_loss: 0.1994 - 81ms/epoch - 16ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 0.1681 - val_loss: 0.1960 - 81ms/epoch - 16ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 0.1653 - val_loss: 0.1928 - 81ms/epoch - 16ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 0.1624 - val_loss: 0.1896 - 81ms/epoch - 16ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 0.1599 - val_loss: 0.1865 - 80ms/epoch - 16ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 0.1573 - val_loss: 0.1834 - 82ms/epoch - 16ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 0.1549 - val_loss: 0.1804 - 80ms/epoch - 16ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 0.1525 - val_loss: 0.1775 - 81ms/epoch - 16ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 0.1501 - val_loss: 0.1746 - 80ms/epoch - 16ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 0.1477 - val_loss: 0.1719 - 80ms/epoch - 16ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 0.1455 - val_loss: 0.1692 - 81ms/epoch - 16ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 0.1433 - val_loss: 0.1666 - 81ms/epoch - 16ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 0.1414 - val_loss: 0.1640 - 81ms/epoch - 16ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 0.1395 - val_loss: 0.1616 - 81ms/epoch - 16ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 0.1372 - val_loss: 0.1592 - 82ms/epoch - 16ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 0.1355 - val_loss: 0.1570 - 81ms/epoch - 16ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 0.1339 - val_loss: 0.1548 - 83ms/epoch - 17ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.1323 - val_loss: 0.1527 - 82ms/epoch - 16ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.1302 - val_loss: 0.1506 - 83ms/epoch - 17ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.1286 - val_loss: 0.1487 - 83ms/epoch - 17ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.1272 - val_loss: 0.1468 - 82ms/epoch - 16ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.1256 - val_loss: 0.1450 - 81ms/epoch - 16ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.1240 - val_loss: 0.1433 - 82ms/epoch - 16ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.1225 - val_loss: 0.1417 - 83ms/epoch - 17ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.1213 - val_loss: 0.1401 - 82ms/epoch - 16ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.1199 - val_loss: 0.1385 - 83ms/epoch - 17ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.1185 - val_loss: 0.1370 - 82ms/epoch - 16ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.1173 - val_loss: 0.1356 - 82ms/epoch - 16ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.1157 - val_loss: 0.1342 - 82ms/epoch - 16ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.1139 - val_loss: 0.1328 - 82ms/epoch - 16ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.1129 - val_loss: 0.1314 - 83ms/epoch - 17ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.1118 - val_loss: 0.1300 - 83ms/epoch - 17ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.1105 - val_loss: 0.1287 - 84ms/epoch - 17ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.1091 - val_loss: 0.1274 - 83ms/epoch - 17ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.1081 - val_loss: 0.1262 - 104ms/epoch - 21ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.1066 - val_loss: 0.1249 - 85ms/epoch - 17ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.1051 - val_loss: 0.1236 - 82ms/epoch - 16ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.1040 - val_loss: 0.1224 - 84ms/epoch - 17ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.1030 - val_loss: 0.1212 - 83ms/epoch - 17ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.1018 - val_loss: 0.1200 - 85ms/epoch - 17ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.1007 - val_loss: 0.1188 - 82ms/epoch - 16ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.0994 - val_loss: 0.1177 - 82ms/epoch - 16ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.0982 - val_loss: 0.1165 - 84ms/epoch - 17ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.0972 - val_loss: 0.1154 - 83ms/epoch - 17ms/step
# 20/20 [==============================] - 1s 3ms/step
# 9/9 [==============================] - 0s 2ms/step
# Train Score: 227.62 RMSE for 50 epochs
# Test Score: 558.58 RMSE for 50 epochs
# Training with LSTM layers: [2, 2]
# Model: "sequential_28"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_86 (LSTM)              (None, 5, 2)              32
#
#  dropout_40 (Dropout)        (None, 5, 2)              0
#
#  lstm_87 (LSTM)              (None, 2)                 40
#
#  dropout_41 (Dropout)        (None, 2)                 0
#
#  dense_28 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 75
# Trainable params: 75
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 4s - loss: 0.0774 - val_loss: 0.1143 - 4s/epoch - 836ms/step
# Epoch 2/50
# 5/5 - 0s - loss: 0.0752 - val_loss: 0.1116 - 59ms/epoch - 12ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 0.0730 - val_loss: 0.1091 - 57ms/epoch - 11ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 0.0714 - val_loss: 0.1066 - 59ms/epoch - 12ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 0.0694 - val_loss: 0.1042 - 56ms/epoch - 11ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 0.0677 - val_loss: 0.1019 - 57ms/epoch - 11ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 0.0660 - val_loss: 0.0997 - 57ms/epoch - 11ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 0.0646 - val_loss: 0.0976 - 58ms/epoch - 12ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 0.0630 - val_loss: 0.0956 - 58ms/epoch - 12ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 0.0614 - val_loss: 0.0936 - 58ms/epoch - 12ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 0.0602 - val_loss: 0.0918 - 57ms/epoch - 11ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 0.0587 - val_loss: 0.0899 - 56ms/epoch - 11ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 0.0575 - val_loss: 0.0882 - 70ms/epoch - 14ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 0.0562 - val_loss: 0.0865 - 59ms/epoch - 12ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 0.0551 - val_loss: 0.0849 - 57ms/epoch - 11ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 0.0540 - val_loss: 0.0833 - 58ms/epoch - 12ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 0.0529 - val_loss: 0.0818 - 57ms/epoch - 11ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 0.0520 - val_loss: 0.0803 - 58ms/epoch - 12ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 0.0509 - val_loss: 0.0789 - 57ms/epoch - 11ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 0.0498 - val_loss: 0.0776 - 57ms/epoch - 11ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 0.0491 - val_loss: 0.0763 - 57ms/epoch - 11ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 0.0483 - val_loss: 0.0750 - 57ms/epoch - 11ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 0.0473 - val_loss: 0.0738 - 58ms/epoch - 12ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.0465 - val_loss: 0.0726 - 59ms/epoch - 12ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.0459 - val_loss: 0.0715 - 58ms/epoch - 12ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.0453 - val_loss: 0.0705 - 57ms/epoch - 11ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.0444 - val_loss: 0.0694 - 58ms/epoch - 12ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.0438 - val_loss: 0.0685 - 56ms/epoch - 11ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.0432 - val_loss: 0.0675 - 57ms/epoch - 11ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.0427 - val_loss: 0.0666 - 57ms/epoch - 11ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.0423 - val_loss: 0.0657 - 57ms/epoch - 11ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.0416 - val_loss: 0.0649 - 56ms/epoch - 11ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.0411 - val_loss: 0.0641 - 56ms/epoch - 11ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.0408 - val_loss: 0.0634 - 55ms/epoch - 11ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.0401 - val_loss: 0.0627 - 56ms/epoch - 11ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.0399 - val_loss: 0.0620 - 57ms/epoch - 11ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.0392 - val_loss: 0.0614 - 56ms/epoch - 11ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.0389 - val_loss: 0.0608 - 57ms/epoch - 11ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.0386 - val_loss: 0.0602 - 57ms/epoch - 11ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.0381 - val_loss: 0.0596 - 57ms/epoch - 11ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.0375 - val_loss: 0.0591 - 57ms/epoch - 11ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.0376 - val_loss: 0.0586 - 66ms/epoch - 13ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.0370 - val_loss: 0.0581 - 70ms/epoch - 14ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.0366 - val_loss: 0.0576 - 59ms/epoch - 12ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.0364 - val_loss: 0.0571 - 56ms/epoch - 11ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.0361 - val_loss: 0.0567 - 55ms/epoch - 11ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.0357 - val_loss: 0.0563 - 58ms/epoch - 12ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.0354 - val_loss: 0.0558 - 56ms/epoch - 11ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.0350 - val_loss: 0.0554 - 56ms/epoch - 11ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.0349 - val_loss: 0.0551 - 56ms/epoch - 11ms/step
# 20/20 [==============================] - 1s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# Train Score: 236.45 RMSE for 50 epochs
# Test Score: 576.68 RMSE for 50 epochs
# Training for 100 epochs...
# Training with LSTM layers: [64, 64, 32, 32, 16, 16, 8, 8, 4, 4, 2, 2]
# Model: "sequential_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_88 (LSTM)              (None, 5, 64)             16896
#
#  dropout_42 (Dropout)        (None, 5, 64)             0
#
#  lstm_89 (LSTM)              (None, 5, 64)             33024
#
#  dropout_43 (Dropout)        (None, 5, 64)             0
#
#  lstm_90 (LSTM)              (None, 5, 32)             12416
#
#  dropout_44 (Dropout)        (None, 5, 32)             0
#
#  lstm_91 (LSTM)              (None, 5, 32)             8320
#
#  dropout_45 (Dropout)        (None, 5, 32)             0
#
#  lstm_92 (LSTM)              (None, 5, 16)             3136
#
#  dropout_46 (Dropout)        (None, 5, 16)             0
#
#  lstm_93 (LSTM)              (None, 5, 16)             2112
#
#  dropout_47 (Dropout)        (None, 5, 16)             0
#
#  lstm_94 (LSTM)              (None, 5, 8)              800
#
#  dropout_48 (Dropout)        (None, 5, 8)              0
#
#  lstm_95 (LSTM)              (None, 5, 8)              544
#
#  dropout_49 (Dropout)        (None, 5, 8)              0
#
#  lstm_96 (LSTM)              (None, 5, 4)              208
#
#  dropout_50 (Dropout)        (None, 5, 4)              0
#
#  lstm_97 (LSTM)              (None, 5, 4)              144
#
#  dropout_51 (Dropout)        (None, 5, 4)              0
#
#  lstm_98 (LSTM)              (None, 5, 2)              56
#
#  dropout_52 (Dropout)        (None, 5, 2)              0
#
#  lstm_99 (LSTM)              (None, 2)                 40
#
#  dropout_53 (Dropout)        (None, 2)                 0
#
#  dense_29 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 77,699
# Trainable params: 77,699
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 5/5 - 26s - loss: 3.6394 - val_loss: 3.5870 - 26s/epoch - 5s/step
# Epoch 2/100
# 5/5 - 0s - loss: 3.4987 - val_loss: 3.4483 - 242ms/epoch - 48ms/step
# Epoch 3/100
# 5/5 - 0s - loss: 3.3625 - val_loss: 3.3142 - 250ms/epoch - 50ms/step
# Epoch 4/100
# 5/5 - 0s - loss: 3.2312 - val_loss: 3.1850 - 242ms/epoch - 48ms/step
# Epoch 5/100
# 5/5 - 0s - loss: 3.1049 - val_loss: 3.0606 - 236ms/epoch - 47ms/step
# Epoch 6/100
# 5/5 - 0s - loss: 2.9827 - val_loss: 2.9410 - 231ms/epoch - 46ms/step
# Epoch 7/100
# 5/5 - 0s - loss: 2.8658 - val_loss: 2.8261 - 234ms/epoch - 47ms/step
# Epoch 8/100
# 5/5 - 0s - loss: 2.7536 - val_loss: 2.7158 - 235ms/epoch - 47ms/step
# Epoch 9/100
# 5/5 - 0s - loss: 2.6463 - val_loss: 2.6101 - 233ms/epoch - 47ms/step
# Epoch 10/100
# 5/5 - 0s - loss: 2.5426 - val_loss: 2.5087 - 234ms/epoch - 47ms/step
# Epoch 11/100
# 5/5 - 0s - loss: 2.4437 - val_loss: 2.4115 - 235ms/epoch - 47ms/step
# Epoch 12/100
# 5/5 - 0s - loss: 2.3485 - val_loss: 2.3184 - 239ms/epoch - 48ms/step
# Epoch 13/100
# 5/5 - 0s - loss: 2.2576 - val_loss: 2.2291 - 234ms/epoch - 47ms/step
# Epoch 14/100
# 5/5 - 0s - loss: 2.1706 - val_loss: 2.1435 - 236ms/epoch - 47ms/step
# Epoch 15/100
# 5/5 - 0s - loss: 2.0872 - val_loss: 2.0614 - 239ms/epoch - 48ms/step
# Epoch 16/100
# 5/5 - 0s - loss: 2.0070 - val_loss: 1.9828 - 236ms/epoch - 47ms/step
# Epoch 17/100
# 5/5 - 0s - loss: 1.9302 - val_loss: 1.9075 - 233ms/epoch - 47ms/step
# Epoch 18/100
# 5/5 - 0s - loss: 1.8567 - val_loss: 1.8352 - 236ms/epoch - 47ms/step
# Epoch 19/100
# 5/5 - 0s - loss: 1.7862 - val_loss: 1.7660 - 234ms/epoch - 47ms/step
# Epoch 20/100
# 5/5 - 0s - loss: 1.7183 - val_loss: 1.6996 - 234ms/epoch - 47ms/step
# Epoch 21/100
# 5/5 - 0s - loss: 1.6534 - val_loss: 1.6360 - 235ms/epoch - 47ms/step
# Epoch 22/100
# 5/5 - 0s - loss: 1.5915 - val_loss: 1.5750 - 235ms/epoch - 47ms/step
# Epoch 23/100
# 5/5 - 0s - loss: 1.5316 - val_loss: 1.5165 - 235ms/epoch - 47ms/step
# Epoch 24/100
# 5/5 - 0s - loss: 1.4746 - val_loss: 1.4604 - 235ms/epoch - 47ms/step
# Epoch 25/100
# 5/5 - 0s - loss: 1.4193 - val_loss: 1.4067 - 235ms/epoch - 47ms/step
# Epoch 26/100
# 5/5 - 0s - loss: 1.3670 - val_loss: 1.3551 - 234ms/epoch - 47ms/step
# Epoch 27/100
# 5/5 - 0s - loss: 1.3163 - val_loss: 1.3056 - 233ms/epoch - 47ms/step
# Epoch 28/100
# 5/5 - 0s - loss: 1.2675 - val_loss: 1.2582 - 233ms/epoch - 47ms/step
# Epoch 29/100
# 5/5 - 0s - loss: 1.2209 - val_loss: 1.2127 - 234ms/epoch - 47ms/step
# Epoch 30/100
# 5/5 - 0s - loss: 1.1765 - val_loss: 1.1690 - 233ms/epoch - 47ms/step
# Epoch 31/100
# 5/5 - 0s - loss: 1.1333 - val_loss: 1.1271 - 235ms/epoch - 47ms/step
# Epoch 32/100
# 5/5 - 0s - loss: 1.0921 - val_loss: 1.0869 - 229ms/epoch - 46ms/step
# Epoch 33/100
# 5/5 - 0s - loss: 1.0526 - val_loss: 1.0483 - 233ms/epoch - 47ms/step
# Epoch 34/100
# 5/5 - 0s - loss: 1.0146 - val_loss: 1.0112 - 237ms/epoch - 47ms/step
# Epoch 35/100
# 5/5 - 0s - loss: 0.9782 - val_loss: 0.9757 - 233ms/epoch - 47ms/step
# Epoch 36/100
# 5/5 - 0s - loss: 0.9431 - val_loss: 0.9415 - 252ms/epoch - 50ms/step
# Epoch 37/100
# 5/5 - 0s - loss: 0.9095 - val_loss: 0.9087 - 241ms/epoch - 48ms/step
# Epoch 38/100
# 5/5 - 0s - loss: 0.8776 - val_loss: 0.8772 - 268ms/epoch - 54ms/step
# Epoch 39/100
# 5/5 - 0s - loss: 0.8464 - val_loss: 0.8470 - 241ms/epoch - 48ms/step
# Epoch 40/100
# 5/5 - 0s - loss: 0.8165 - val_loss: 0.8180 - 243ms/epoch - 49ms/step
# Epoch 41/100
# 5/5 - 0s - loss: 0.7880 - val_loss: 0.7902 - 234ms/epoch - 47ms/step
# Epoch 42/100
# 5/5 - 0s - loss: 0.7607 - val_loss: 0.7634 - 242ms/epoch - 48ms/step
# Epoch 43/100
# 5/5 - 0s - loss: 0.7344 - val_loss: 0.7377 - 234ms/epoch - 47ms/step
# Epoch 44/100
# 5/5 - 0s - loss: 0.7088 - val_loss: 0.7130 - 239ms/epoch - 48ms/step
# Epoch 45/100
# 5/5 - 0s - loss: 0.6849 - val_loss: 0.6893 - 239ms/epoch - 48ms/step
# Epoch 46/100
# 5/5 - 0s - loss: 0.6617 - val_loss: 0.6666 - 241ms/epoch - 48ms/step
# Epoch 47/100
# 5/5 - 0s - loss: 0.6389 - val_loss: 0.6447 - 244ms/epoch - 49ms/step
# Epoch 48/100
# 5/5 - 0s - loss: 0.6174 - val_loss: 0.6237 - 236ms/epoch - 47ms/step
# Epoch 49/100
# 5/5 - 0s - loss: 0.5968 - val_loss: 0.6034 - 235ms/epoch - 47ms/step
# Epoch 50/100
# 5/5 - 0s - loss: 0.5768 - val_loss: 0.5840 - 238ms/epoch - 48ms/step
# Epoch 51/100
# 5/5 - 0s - loss: 0.5578 - val_loss: 0.5654 - 240ms/epoch - 48ms/step
# Epoch 52/100
# ...
# Epoch 142/150
# 5/5 - 0s - loss: 0.0233 - val_loss: 0.0421 - 83ms/epoch - 17ms/step
# Epoch 143/150
# 5/5 - 0s - loss: 0.0231 - val_loss: 0.0417 - 82ms/epoch - 16ms/step
# Epoch 144/150
# 5/5 - 0s - loss: 0.0228 - val_loss: 0.0414 - 82ms/epoch - 16ms/step
# Epoch 145/150
# 5/5 - 0s - loss: 0.0224 - val_loss: 0.0411 - 84ms/epoch - 17ms/step
# Epoch 146/150
# 5/5 - 0s - loss: 0.0221 - val_loss: 0.0408 - 83ms/epoch - 17ms/step
# Epoch 147/150
# 5/5 - 0s - loss: 0.0220 - val_loss: 0.0405 - 82ms/epoch - 16ms/step
# Epoch 148/150
# 5/5 - 0s - loss: 0.0217 - val_loss: 0.0402 - 83ms/epoch - 17ms/step
# Epoch 149/150
# 5/5 - 0s - loss: 0.0213 - val_loss: 0.0399 - 83ms/epoch - 17ms/step
# Epoch 150/150
# 5/5 - 0s - loss: 0.0211 - val_loss: 0.0397 - 84ms/epoch - 17ms/step
# 20/20 [==============================] - 1s 3ms/step
# 9/9 [==============================] - 0s 2ms/step
# Train Score: 225.03 RMSE for 150 epochs
# Test Score: 549.24 RMSE for 150 epochs
# Training with LSTM layers: [2, 2]
# Model: "sequential_40"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_170 (LSTM)             (None, 5, 2)              32
#
#  dropout_124 (Dropout)       (None, 5, 2)              0
#
#  lstm_171 (LSTM)             (None, 2)                 40
#
#  dropout_125 (Dropout)       (None, 2)                 0
#
#  dense_40 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 75
# Trainable params: 75
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 5/5 - 4s - loss: 0.0673 - val_loss: 0.1028 - 4s/epoch - 840ms/step
# Epoch 2/150
# 5/5 - 0s - loss: 0.0655 - val_loss: 0.1008 - 58ms/epoch - 12ms/step
# Epoch 3/150
# 5/5 - 0s - loss: 0.0640 - val_loss: 0.0988 - 58ms/epoch - 12ms/step
# Epoch 4/150
# 5/5 - 0s - loss: 0.0625 - val_loss: 0.0969 - 57ms/epoch - 11ms/step
# Epoch 5/150
# 5/5 - 0s - loss: 0.0611 - val_loss: 0.0950 - 58ms/epoch - 12ms/step
# Epoch 6/150
# 5/5 - 0s - loss: 0.0597 - val_loss: 0.0932 - 56ms/epoch - 11ms/step
# Epoch 7/150
# 5/5 - 0s - loss: 0.0584 - val_loss: 0.0915 - 56ms/epoch - 11ms/step
# Epoch 8/150
# 5/5 - 0s - loss: 0.0571 - val_loss: 0.0898 - 56ms/epoch - 11ms/step
# Epoch 9/150
# 5/5 - 0s - loss: 0.0559 - val_loss: 0.0882 - 55ms/epoch - 11ms/step
# Epoch 10/150
# 5/5 - 0s - loss: 0.0547 - val_loss: 0.0866 - 57ms/epoch - 11ms/step
# Epoch 11/150
# 5/5 - 0s - loss: 0.0536 - val_loss: 0.0851 - 56ms/epoch - 11ms/step
# Epoch 12/150
# 5/5 - 0s - loss: 0.0524 - val_loss: 0.0836 - 57ms/epoch - 11ms/step
# Epoch 13/150
# 5/5 - 0s - loss: 0.0513 - val_loss: 0.0821 - 57ms/epoch - 11ms/step
# Epoch 14/150
# 5/5 - 0s - loss: 0.0503 - val_loss: 0.0807 - 70ms/epoch - 14ms/step
# Epoch 15/150
# 5/5 - 0s - loss: 0.0492 - val_loss: 0.0793 - 61ms/epoch - 12ms/step
# Epoch 16/150
# 5/5 - 0s - loss: 0.0483 - val_loss: 0.0780 - 56ms/epoch - 11ms/step
# Epoch 17/150
# 5/5 - 0s - loss: 0.0473 - val_loss: 0.0767 - 58ms/epoch - 12ms/step
# Epoch 18/150
# 5/5 - 0s - loss: 0.0463 - val_loss: 0.0754 - 57ms/epoch - 11ms/step
# Epoch 19/150
# 5/5 - 0s - loss: 0.0456 - val_loss: 0.0742 - 59ms/epoch - 12ms/step
# Epoch 20/150
# 5/5 - 0s - loss: 0.0446 - val_loss: 0.0730 - 57ms/epoch - 11ms/step
# Epoch 21/150
# 5/5 - 0s - loss: 0.0438 - val_loss: 0.0718 - 57ms/epoch - 11ms/step
# Epoch 22/150
# 5/5 - 0s - loss: 0.0431 - val_loss: 0.0707 - 55ms/epoch - 11ms/step
# Epoch 23/150
# 5/5 - 0s - loss: 0.0422 - val_loss: 0.0696 - 57ms/epoch - 11ms/step
# Epoch 24/150
# 5/5 - 0s - loss: 0.0414 - val_loss: 0.0685 - 56ms/epoch - 11ms/step
# Epoch 25/150
# 5/5 - 0s - loss: 0.0407 - val_loss: 0.0674 - 57ms/epoch - 11ms/step
# Epoch 26/150
# 5/5 - 0s - loss: 0.0401 - val_loss: 0.0664 - 57ms/epoch - 11ms/step
# Epoch 27/150
# 5/5 - 0s - loss: 0.0393 - val_loss: 0.0654 - 57ms/epoch - 11ms/step
# Epoch 28/150
# 5/5 - 0s - loss: 0.0388 - val_loss: 0.0645 - 56ms/epoch - 11ms/step
# Epoch 29/150
# 5/5 - 0s - loss: 0.0381 - val_loss: 0.0635 - 55ms/epoch - 11ms/step
# Epoch 30/150
# 5/5 - 0s - loss: 0.0375 - val_loss: 0.0626 - 57ms/epoch - 11ms/step
# Epoch 31/150
# 5/5 - 0s - loss: 0.0369 - val_loss: 0.0618 - 54ms/epoch - 11ms/step
# Epoch 32/150
# 5/5 - 0s - loss: 0.0365 - val_loss: 0.0609 - 56ms/epoch - 11ms/step
# Epoch 33/150
# 5/5 - 0s - loss: 0.0359 - val_loss: 0.0601 - 56ms/epoch - 11ms/step
# Epoch 34/150
# 5/5 - 0s - loss: 0.0354 - val_loss: 0.0593 - 57ms/epoch - 11ms/step
# Epoch 35/150
# 5/5 - 0s - loss: 0.0348 - val_loss: 0.0586 - 56ms/epoch - 11ms/step
# Epoch 36/150
# 5/5 - 0s - loss: 0.0345 - val_loss: 0.0578 - 56ms/epoch - 11ms/step
# Epoch 37/150
# 5/5 - 0s - loss: 0.0340 - val_loss: 0.0571 - 55ms/epoch - 11ms/step
# Epoch 38/150
# 5/5 - 0s - loss: 0.0334 - val_loss: 0.0565 - 56ms/epoch - 11ms/step
# Epoch 39/150
# 5/5 - 0s - loss: 0.0332 - val_loss: 0.0558 - 56ms/epoch - 11ms/step
# Epoch 40/150
# 5/5 - 0s - loss: 0.0328 - val_loss: 0.0552 - 55ms/epoch - 11ms/step
# Epoch 41/150
# 5/5 - 0s - loss: 0.0324 - val_loss: 0.0546 - 58ms/epoch - 12ms/step
# Epoch 42/150
# 5/5 - 0s - loss: 0.0319 - val_loss: 0.0541 - 56ms/epoch - 11ms/step
# Epoch 43/150
# 5/5 - 0s - loss: 0.0317 - val_loss: 0.0535 - 57ms/epoch - 11ms/step
# Epoch 44/150
# 5/5 - 0s - loss: 0.0314 - val_loss: 0.0530 - 55ms/epoch - 11ms/step
# Epoch 45/150
# 5/5 - 0s - loss: 0.0311 - val_loss: 0.0525 - 76ms/epoch - 15ms/step
# Epoch 46/150
# 5/5 - 0s - loss: 0.0308 - val_loss: 0.0521 - 66ms/epoch - 13ms/step
# Epoch 47/150
# 5/5 - 0s - loss: 0.0304 - val_loss: 0.0516 - 57ms/epoch - 11ms/step
# Epoch 48/150
# 5/5 - 0s - loss: 0.0301 - val_loss: 0.0512 - 56ms/epoch - 11ms/step
# Epoch 49/150
# 5/5 - 0s - loss: 0.0300 - val_loss: 0.0508 - 56ms/epoch - 11ms/step
# Epoch 50/150
# 5/5 - 0s - loss: 0.0297 - val_loss: 0.0504 - 59ms/epoch - 12ms/step
# Epoch 51/150
# 5/5 - 0s - loss: 0.0294 - val_loss: 0.0501 - 56ms/epoch - 11ms/step
# Epoch 52/150
# 5/5 - 0s - loss: 0.0293 - val_loss: 0.0497 - 58ms/epoch - 12ms/step
# Epoch 53/150
# 5/5 - 0s - loss: 0.0292 - val_loss: 0.0494 - 56ms/epoch - 11ms/step
# Epoch 54/150
# 5/5 - 0s - loss: 0.0286 - val_loss: 0.0490 - 56ms/epoch - 11ms/step
# Epoch 55/150
# 5/5 - 0s - loss: 0.0283 - val_loss: 0.0487 - 57ms/epoch - 11ms/step
# Epoch 56/150
# 5/5 - 0s - loss: 0.0283 - val_loss: 0.0484 - 58ms/epoch - 12ms/step
# Epoch 57/150
# 5/5 - 0s - loss: 0.0280 - val_loss: 0.0481 - 62ms/epoch - 12ms/step
# Epoch 58/150
# 5/5 - 0s - loss: 0.0280 - val_loss: 0.0479 - 58ms/epoch - 12ms/step
# Epoch 59/150
# 5/5 - 0s - loss: 0.0276 - val_loss: 0.0476 - 58ms/epoch - 12ms/step
# Epoch 60/150
# 5/5 - 0s - loss: 0.0274 - val_loss: 0.0473 - 56ms/epoch - 11ms/step
# Epoch 61/150
# 5/5 - 0s - loss: 0.0271 - val_loss: 0.0471 - 58ms/epoch - 12ms/step
# Epoch 62/150
# 5/5 - 0s - loss: 0.0271 - val_loss: 0.0468 - 56ms/epoch - 11ms/step
# Epoch 63/150
# 5/5 - 0s - loss: 0.0268 - val_loss: 0.0466 - 57ms/epoch - 11ms/step
# Epoch 64/150
# 5/5 - 0s - loss: 0.0267 - val_loss: 0.0463 - 55ms/epoch - 11ms/step
# Epoch 65/150
# 5/5 - 0s - loss: 0.0262 - val_loss: 0.0461 - 59ms/epoch - 12ms/step
# Epoch 66/150
# 5/5 - 0s - loss: 0.0259 - val_loss: 0.0459 - 56ms/epoch - 11ms/step
# Epoch 67/150
# 5/5 - 0s - loss: 0.0259 - val_loss: 0.0457 - 58ms/epoch - 12ms/step
# Epoch 68/150
# 5/5 - 0s - loss: 0.0257 - val_loss: 0.0454 - 56ms/epoch - 11ms/step
# Epoch 69/150
# 5/5 - 0s - loss: 0.0255 - val_loss: 0.0452 - 57ms/epoch - 11ms/step
# Epoch 70/150
# 5/5 - 0s - loss: 0.0254 - val_loss: 0.0450 - 55ms/epoch - 11ms/step
# Epoch 71/150
# 5/5 - 0s - loss: 0.0251 - val_loss: 0.0448 - 57ms/epoch - 11ms/step
# Epoch 72/150
# 5/5 - 0s - loss: 0.0249 - val_loss: 0.0445 - 58ms/epoch - 12ms/step
# Epoch 73/150
# 5/5 - 0s - loss: 0.0246 - val_loss: 0.0443 - 59ms/epoch - 12ms/step
# Epoch 74/150
# 5/5 - 0s - loss: 0.0244 - val_loss: 0.0441 - 58ms/epoch - 12ms/step
# Epoch 75/150
# 5/5 - 0s - loss: 0.0245 - val_loss: 0.0439 - 57ms/epoch - 11ms/step
# Epoch 76/150
# 5/5 - 0s - loss: 0.0241 - val_loss: 0.0437 - 57ms/epoch - 11ms/step
# Epoch 77/150
# 5/5 - 0s - loss: 0.0239 - val_loss: 0.0435 - 71ms/epoch - 14ms/step
# Epoch 78/150
# 5/5 - 0s - loss: 0.0238 - val_loss: 0.0433 - 56ms/epoch - 11ms/step
# Epoch 79/150
# 5/5 - 0s - loss: 0.0236 - val_loss: 0.0431 - 56ms/epoch - 11ms/step
# Epoch 80/150
# 5/5 - 0s - loss: 0.0233 - val_loss: 0.0429 - 57ms/epoch - 11ms/step
# Epoch 81/150
# 5/5 - 0s - loss: 0.0233 - val_loss: 0.0427 - 55ms/epoch - 11ms/step
# Epoch 82/150
# 5/5 - 0s - loss: 0.0229 - val_loss: 0.0425 - 57ms/epoch - 11ms/step
# Epoch 83/150
# 5/5 - 0s - loss: 0.0229 - val_loss: 0.0423 - 65ms/epoch - 13ms/step
# Epoch 84/150
# 5/5 - 0s - loss: 0.0227 - val_loss: 0.0421 - 74ms/epoch - 15ms/step
# Epoch 85/150
# 5/5 - 0s - loss: 0.0225 - val_loss: 0.0420 - 58ms/epoch - 12ms/step
# Epoch 86/150
# 5/5 - 0s - loss: 0.0223 - val_loss: 0.0418 - 56ms/epoch - 11ms/step
# Epoch 87/150
# 5/5 - 0s - loss: 0.0221 - val_loss: 0.0416 - 57ms/epoch - 11ms/step
# Epoch 88/150
# 5/5 - 0s - loss: 0.0220 - val_loss: 0.0414 - 56ms/epoch - 11ms/step
# Epoch 89/150
# 5/5 - 0s - loss: 0.0217 - val_loss: 0.0412 - 55ms/epoch - 11ms/step
# Epoch 90/150
# 5/5 - 0s - loss: 0.0217 - val_loss: 0.0411 - 56ms/epoch - 11ms/step
# Epoch 91/150
# 5/5 - 0s - loss: 0.0215 - val_loss: 0.0409 - 56ms/epoch - 11ms/step
# Epoch 92/150
# 5/5 - 0s - loss: 0.0213 - val_loss: 0.0407 - 58ms/epoch - 12ms/step
# Epoch 93/150
# 5/5 - 0s - loss: 0.0211 - val_loss: 0.0406 - 56ms/epoch - 11ms/step
# Epoch 94/150
# 5/5 - 0s - loss: 0.0210 - val_loss: 0.0404 - 56ms/epoch - 11ms/step
# Epoch 95/150
# 5/5 - 0s - loss: 0.0208 - val_loss: 0.0402 - 57ms/epoch - 11ms/step
# Epoch 96/150
# 5/5 - 0s - loss: 0.0205 - val_loss: 0.0400 - 57ms/epoch - 11ms/step
# Epoch 97/150
# 5/5 - 0s - loss: 0.0204 - val_loss: 0.0399 - 56ms/epoch - 11ms/step
# Epoch 98/150
# 5/5 - 0s - loss: 0.0205 - val_loss: 0.0397 - 57ms/epoch - 11ms/step
# Epoch 99/150
# 5/5 - 0s - loss: 0.0202 - val_loss: 0.0395 - 56ms/epoch - 11ms/step
# Epoch 100/150
# 5/5 - 0s - loss: 0.0201 - val_loss: 0.0394 - 56ms/epoch - 11ms/step
# Epoch 101/150
# 5/5 - 0s - loss: 0.0199 - val_loss: 0.0392 - 56ms/epoch - 11ms/step
# Epoch 102/150
# 5/5 - 0s - loss: 0.0196 - val_loss: 0.0390 - 57ms/epoch - 11ms/step
# Epoch 103/150
# 5/5 - 0s - loss: 0.0197 - val_loss: 0.0389 - 58ms/epoch - 12ms/step
# Epoch 104/150
# 5/5 - 0s - loss: 0.0194 - val_loss: 0.0387 - 57ms/epoch - 11ms/step
# Epoch 105/150
# 5/5 - 0s - loss: 0.0193 - val_loss: 0.0386 - 56ms/epoch - 11ms/step
# Epoch 106/150
# 5/5 - 0s - loss: 0.0192 - val_loss: 0.0384 - 57ms/epoch - 11ms/step
# Epoch 107/150
# 5/5 - 0s - loss: 0.0192 - val_loss: 0.0383 - 55ms/epoch - 11ms/step
# Epoch 108/150
# 5/5 - 0s - loss: 0.0188 - val_loss: 0.0381 - 58ms/epoch - 12ms/step
# Epoch 109/150
# 5/5 - 0s - loss: 0.0186 - val_loss: 0.0380 - 56ms/epoch - 11ms/step
# Epoch 110/150
# 5/5 - 0s - loss: 0.0184 - val_loss: 0.0378 - 57ms/epoch - 11ms/step
# Epoch 111/150
# 5/5 - 0s - loss: 0.0187 - val_loss: 0.0377 - 57ms/epoch - 11ms/step
# Epoch 112/150
# 5/5 - 0s - loss: 0.0182 - val_loss: 0.0375 - 56ms/epoch - 11ms/step
# Epoch 113/150
# 5/5 - 0s - loss: 0.0181 - val_loss: 0.0374 - 56ms/epoch - 11ms/step
# Epoch 114/150
# 5/5 - 0s - loss: 0.0180 - val_loss: 0.0372 - 57ms/epoch - 11ms/step
# Epoch 115/150
# 5/5 - 0s - loss: 0.0180 - val_loss: 0.0371 - 56ms/epoch - 11ms/step
# Epoch 116/150
# 5/5 - 0s - loss: 0.0178 - val_loss: 0.0369 - 57ms/epoch - 11ms/step
# Epoch 117/150
# 5/5 - 0s - loss: 0.0177 - val_loss: 0.0368 - 57ms/epoch - 11ms/step
# Epoch 118/150
# 5/5 - 0s - loss: 0.0173 - val_loss: 0.0367 - 57ms/epoch - 11ms/step
# Epoch 119/150
# 5/5 - 0s - loss: 0.0174 - val_loss: 0.0365 - 56ms/epoch - 11ms/step
# Epoch 120/150
# 5/5 - 0s - loss: 0.0173 - val_loss: 0.0364 - 56ms/epoch - 11ms/step
# Epoch 121/150
# 5/5 - 0s - loss: 0.0171 - val_loss: 0.0362 - 57ms/epoch - 11ms/step
# Epoch 122/150
# 5/5 - 0s - loss: 0.0170 - val_loss: 0.0361 - 56ms/epoch - 11ms/step
# Epoch 123/150
# 5/5 - 0s - loss: 0.0170 - val_loss: 0.0360 - 56ms/epoch - 11ms/step
# Epoch 124/150
# 5/5 - 0s - loss: 0.0168 - val_loss: 0.0358 - 75ms/epoch - 15ms/step
# Epoch 125/150
# 5/5 - 0s - loss: 0.0166 - val_loss: 0.0357 - 62ms/epoch - 12ms/step
# Epoch 126/150
# 5/5 - 0s - loss: 0.0164 - val_loss: 0.0356 - 58ms/epoch - 12ms/step
# Epoch 127/150
# 5/5 - 0s - loss: 0.0163 - val_loss: 0.0355 - 56ms/epoch - 11ms/step
# Epoch 128/150
# 5/5 - 0s - loss: 0.0162 - val_loss: 0.0353 - 57ms/epoch - 11ms/step
# Epoch 129/150
# 5/5 - 0s - loss: 0.0161 - val_loss: 0.0352 - 57ms/epoch - 11ms/step
# Epoch 130/150
# 5/5 - 0s - loss: 0.0161 - val_loss: 0.0351 - 58ms/epoch - 12ms/step
# Epoch 131/150
# 5/5 - 0s - loss: 0.0158 - val_loss: 0.0349 - 56ms/epoch - 11ms/step
# Epoch 132/150
# 5/5 - 0s - loss: 0.0159 - val_loss: 0.0348 - 57ms/epoch - 11ms/step
# Epoch 133/150
# 5/5 - 0s - loss: 0.0156 - val_loss: 0.0347 - 54ms/epoch - 11ms/step
# Epoch 134/150
# 5/5 - 0s - loss: 0.0155 - val_loss: 0.0346 - 56ms/epoch - 11ms/step
# Epoch 135/150
# 5/5 - 0s - loss: 0.0153 - val_loss: 0.0345 - 56ms/epoch - 11ms/step
# Epoch 136/150
# 5/5 - 0s - loss: 0.0154 - val_loss: 0.0344 - 57ms/epoch - 11ms/step
# Epoch 137/150
# 5/5 - 0s - loss: 0.0153 - val_loss: 0.0342 - 58ms/epoch - 12ms/step
# Epoch 138/150
# 5/5 - 0s - loss: 0.0150 - val_loss: 0.0341 - 56ms/epoch - 11ms/step
# Epoch 139/150
# 5/5 - 0s - loss: 0.0149 - val_loss: 0.0340 - 56ms/epoch - 11ms/step
# Epoch 140/150
# 5/5 - 0s - loss: 0.0148 - val_loss: 0.0339 - 57ms/epoch - 11ms/step
# Epoch 141/150
# 5/5 - 0s - loss: 0.0146 - val_loss: 0.0338 - 57ms/epoch - 11ms/step
# Epoch 142/150
# 5/5 - 0s - loss: 0.0146 - val_loss: 0.0337 - 55ms/epoch - 11ms/step
# Epoch 143/150
# 5/5 - 0s - loss: 0.0145 - val_loss: 0.0335 - 57ms/epoch - 11ms/step
# Epoch 144/150
# 5/5 - 0s - loss: 0.0145 - val_loss: 0.0334 - 57ms/epoch - 11ms/step
# Epoch 145/150
# 5/5 - 0s - loss: 0.0143 - val_loss: 0.0333 - 56ms/epoch - 11ms/step
# Epoch 146/150
# 5/5 - 0s - loss: 0.0142 - val_loss: 0.0332 - 58ms/epoch - 12ms/step
# Epoch 147/150
# 5/5 - 0s - loss: 0.0140 - val_loss: 0.0331 - 56ms/epoch - 11ms/step
# Epoch 148/150
# 5/5 - 0s - loss: 0.0142 - val_loss: 0.0330 - 56ms/epoch - 11ms/step
# Epoch 149/150
# 5/5 - 0s - loss: 0.0140 - val_loss: 0.0329 - 57ms/epoch - 11ms/step
# Epoch 150/150
# 5/5 - 0s - loss: 0.0138 - val_loss: 0.0328 - 55ms/epoch - 11ms/step
# 20/20 [==============================] - 1s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# Train Score: 227.05 RMSE for 150 epochs
# Test Score: 552.64 RMSE for 150 epochs
# Text(0.5, 1.0, 'Model loss progress during training and validation')
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'Training and Validation Loss')
#                                                     Train RMSE   Test RMSE
# 50 epochs, [64, 64, 32, 32, 16, 16, 8, 8, 4, 4,...  226.520651  555.329932
# 50 epochs, [32, 32, 16, 16, 8, 8, 4, 4, 2, 2] l...  226.568692  555.476945
# 50 epochs, [16, 16, 8, 8, 4, 4, 2, 2] layers        227.405863  557.827403
# 50 epochs, [8, 8, 4, 4, 2, 2] layers                226.968346  556.644443
# 50 epochs, [4, 4, 2, 2] layers                      227.621751  558.579544
# 50 epochs, [2, 2] layers                            236.453603  576.684264
# 100 epochs, [64, 64, 32, 32, 16, 16, 8, 8, 4, 4...  225.623467  552.188366
# 100 epochs, [32, 32, 16, 16, 8, 8, 4, 4, 2, 2] ...  225.674552  552.394737
# 100 epochs, [16, 16, 8, 8, 4, 4, 2, 2] layers       225.687173  552.445027
# 100 epochs, [8, 8, 4, 4, 2, 2] layers               225.859652  553.109070
# 100 epochs, [4, 4, 2, 2] layers                     225.443345  551.401059
# 100 epochs, [2, 2] layers                           224.939714  550.135318
# 150 epochs, [64, 64, 32, 32, 16, 16, 8, 8, 4, 4...  224.914554  548.520197
# 150 epochs, [32, 32, 16, 16, 8, 8, 4, 4, 2, 2] ...  224.980263  548.969212
# 150 epochs, [16, 16, 8, 8, 4, 4, 2, 2] layers       225.061435  549.474357
# 150 epochs, [8, 8, 4, 4, 2, 2] layers               225.106411  549.735721
# 150 epochs, [4, 4, 2, 2] layers                     225.033320  549.241534
# 150 epochs, [2, 2] layers                           227.052579  552.640643

# %% [markdown]
# <h4>Forecast the results</h4>

# %%
# Add check for 'RATE_actual' values to avoid division by zero
def compute_accuracy(row):
    if row['RATE_actual'] == 0:
        return np.nan
    else:
        error = abs(row['RATE_actual'] - row['RATE_forecasted'])
        error_proportion = error / row['RATE_actual']
        return (1 - error_proportion) * 100

def forecast_next_weeks(model, look_back, scaler, last_values, n_weeks):
    forecast = []
    for _ in range(n_weeks):
        last_values_2d = np.array(last_values[-look_back:]).reshape(-1, 1)
        input_values_scaled = scaler.transform(last_values_2d)
        input_values_scaled = input_values_scaled.reshape((1, look_back, 1))

        prediction = model.predict(input_values_scaled)
        prediction = scaler.inverse_transform(prediction)
        forecast.append(prediction[0][0])
        last_values.append(prediction[0][0])

    return forecast

# %%
weeks = 12

# Ensure that 'YearMonthWeek' is a datetime object
agg_df['YearMonthWeek'] = pd.to_datetime(agg_df['YearMonthWeek'])
last_date = agg_df['YearMonthWeek'].iloc[-1]

last_values = list(agg_df['Rate'].values[-look_back:])
forecasted_values = forecast_next_weeks(model, look_back, scaler, last_values, weeks)
forecasted_dates = pd.date_range(start=last_date, periods=weeks+1, freq='W')[1:]

df_forecasted = pd.DataFrame({
    'POD': forecasted_dates,
    'RATE': forecasted_values
})

df_forecasted["RATE"] = df_forecasted["RATE"].round(2)

df_forecasted.head(5)
df_forecasted.tail(5)
df_forecasted.info()
# Out:
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 20ms/step
#          POD         RATE
# 0 2023-02-26  4214.410156
# 1 2023-03-05  4210.220215
# 2 2023-03-12  4202.250000
# 3 2023-03-19  4193.270020
# 4 2023-03-26  4184.669922
#           POD         RATE
# 7  2023-04-16  4177.359863
# 8  2023-04-23  4177.430176
# 9  2023-04-30  4177.470215
# 10 2023-05-07  4177.479980
# 11 2023-05-14  4177.479980
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POD     12 non-null     datetime64[ns]
#  1   RATE    12 non-null     float32
# dtypes: datetime64[ns](1), float32(1)
# memory usage: 272.0 bytes

# %% [markdown]
# <h4>Comparing with actual updated against forecasted</h4>

# %%
comparison_df = pd.DataFrame(columns=['WeekStart', 'WeekEnd', 'POD_actual', 'RATE_forecasted', 'RATE_actual'])
df_forecasted['WeekEnd'] = df_forecasted['POD'] + pd.to_timedelta(7, unit='d')  

for _, row in df_forecasted.iterrows():
    mask = (new_dates_df['POD'] >= row['POD']) & (new_dates_df['POD'] < row['WeekEnd'])
    actual_dates_within_week = new_dates_df[mask]

    for _, actual_row in actual_dates_within_week.iterrows():
        comparison_df = comparison_df.append({
            'WeekStart': row['POD'],
            'WeekEnd': row['WeekEnd'],
            'POD_actual': actual_row['POD'],
            'RATE_forecasted': row['RATE'],
            'RATE_actual': actual_row['RATE']
        }, ignore_index=True)

# Remove duplicates
comparison_df = comparison_df.drop_duplicates(subset=['POD_actual', 'RATE_forecasted', 'RATE_actual']).reset_index(drop=True)

# Compute accuracy
comparison_df['accuracy'] = comparison_df.apply(compute_accuracy, axis=1)
comparison_df = comparison_df.dropna(subset=['accuracy'])

total_mean_accuracy = comparison_df['accuracy'].mean()
comparison_df
print(f'The mean accuracy is {total_mean_accuracy:.2f}%\n')
# Out:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_2584\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
#     WeekStart    WeekEnd POD_actual  RATE_forecasted  RATE_actual    accuracy
# 0  2023-02-26 2023-03-05 2023-03-02      4214.410156       1000.0 -221.441016
# 1  2023-03-05 2023-03-12 2023-03-10      4210.220215       1000.0 -221.022021
# 2  2023-03-12 2023-03-19 2023-03-16      4202.250000       1000.0 -220.225000
# 3  2023-03-19 2023-03-26 2023-03-21      4193.270020        600.0 -498.878337
# 4  2023-03-26 2023-04-02 2023-03-26      4184.669922        600.0 -497.444987
# 5  2023-03-26 2023-04-02 2023-03-31      4184.669922        650.0 -443.795373
# 6  2023-04-02 2023-04-09 2023-04-06      4177.160156        650.0 -442.640024
# 7  2023-04-09 2023-04-16 2023-04-13      4177.270020        650.0 -442.656926
# 8  2023-04-16 2023-04-23 2023-04-20      4177.359863        650.0 -442.670748
# 9  2023-04-23 2023-04-30 2023-04-28      4177.430176        500.0 -635.486035
# 10 2023-04-30 2023-05-07 2023-05-05      4177.470215        500.0 -635.494043
# 11 2023-05-07 2023-05-14 2023-05-11      4177.479980        500.0 -635.495996
# 12 2023-05-14 2023-05-21 2023-05-19      4177.479980        400.0 -844.369995
# The mean accuracy is -475.51%

# %% [markdown]
# <h4>Visualise all, Conclusion</h4>

# %%
plt.figure(figsize=(20, 10))
plt.plot(sel_df['POD'], sel_df['RATE'], color='blue', label="Actual Data")
plt.plot(new_dates_df['POD'], new_dates_df['RATE'], color='blue', label="Actual Data (Updated)")

plt.plot(df_interpolated['POD'], df_interpolated['RATE'], color='green', label="Aggregated Data")
plt.plot(df_forecasted['POD'], df_forecasted['RATE'], color='red', label="Forecasted Data")

plt.xlabel('Date(Year Month)')
plt.ylabel('Cost Rate(USD)')
plt.title('Port_BUSAN_Size_40_Type_HC_PartyID_010004286')
plt.legend()
plt.show();
