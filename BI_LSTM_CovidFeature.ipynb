# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.losses import MeanSquaredError
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import RobustScaler
from scipy import stats
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from IPython.core.interactiveshell import InteractiveShell

# LSTM
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.layers import Dropout, LSTM, Dense, RepeatVector, TimeDistributed
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Sequential
from keras.callbacks import EarlyStopping
from sklearn.model_selection import ParameterSampler
from scipy.stats import skew


InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline
sns.set()
pd.options.display.max_rows = 100

# %% [markdown]
# <h4>Importing Datasets</h4>

# %%
# Import dataset and clean, ready as a dataframe for creating keys
def createDF(datasets):
    df = pd.read_csv(datasets, converters={'PARTY_ID': str, 'COM_ID': str, 'CNTR_SIZE': str})

    # Formating to type and remove NaN values
    df['POD'] = pd.to_datetime(df['POD'])
    df['ENCODED_TYPE'] = df['ENCODED_TYPE'].fillna(-1).astype(int)
    df = df.dropna(subset=['ENCODED_TYPE'])
    df['RATE'] = df['RATE'].fillna(-1).astype(float)
    df = df.dropna(subset=['RATE'])
    df['ENCODED_TYPE'] = df['ENCODED_TYPE'].astype(int)
    df_clean= df.dropna().reset_index(drop=True)

    # Selecting and rearranging columns
    sel_col = ['CSL_ID', 'CNTR_ID','POD_ID','ETD_POL_D','PARTY_ID',
            'PARTY_NAME','POD','CNTR_SIZE','CNTR_TYPE','RATE']
    df_fc = df_clean[sel_col]

    # Removing years we do not want to process in our models
    df_filtered = df_fc[df_fc['POD'].dt.year != 2002]

    # Sorting the dates
    df_filtered = df_filtered.sort_values(by='POD').reset_index(drop=True)
    
    return df_filtered

# %%
# Create Dataframes for old and new
old_data = '.\Datasets\CR_COST_FC.csv'
df1 = createDF(old_data)
df1.head()

new_data = '.\Datasets\CR_COST_FC_new.csv'
df2 = createDF(new_data)
df2.head()
# Out:
#            CSL_ID           CNTR_ID          POD_ID ETD_POL_D  PARTY_ID  \
# 0  ECS01050600224  CTNR010050700354       ROTTERDAM     NLRTM  01008827
# 1  ECS01050600610  CTNR010050700353      FELIXSTOWE     GBFXT  01002303
# 2  ECS01050600041  CTNR010050700351        AUCKLAND     NZAKL  01005136
# 3  ECS01050600163  CTNR010050700370    PASIR GUDANG     MYPGU  01002767
# 4  ECS01050600456  CTNR010050700450  KARACHI (KICT)     PKKHI  01002783
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0             YANG MING (SINGAPORE) PTE. LTD. 2005-07-15        40    HC NOR
# 1                    GLOBELINK FALLOW LIMITED 2005-07-15        40        GP
# 2  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-15        40    HC NOR
# 3          GLOBELINK CONTAINER LINES (JB) S/B 2005-07-15        40        HC
# 4                GLOBELINK PAKISTAN (PVT) LTD 2005-07-16        40        HC
#
#      RATE
# 0  1620.0
# 1  1800.0
# 2  2170.0
# 3   280.0
# 4  1625.0
#            CSL_ID           CNTR_ID          POD_ID ETD_POL_D  PARTY_ID  \
# 0  ECS01050600224  CTNR010050700354       ROTTERDAM     NLRTM  01008827
# 1  ECS01050600610  CTNR010050700353      FELIXSTOWE     GBFXT  01002303
# 2  ECS01050600041  CTNR010050700351        AUCKLAND     NZAKL  01005136
# 3  ECS01050600163  CTNR010050700370    PASIR GUDANG     MYPGU  01002767
# 4  ECS01050600456  CTNR010050700450  KARACHI (KICT)     PKKHI  01002783
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0             YANG MING (SINGAPORE) PTE. LTD. 2005-07-15        40    HC NOR
# 1                    GLOBELINK FALLOW LIMITED 2005-07-15        40        GP
# 2  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-15        40    HC NOR
# 3          GLOBELINK CONTAINER LINES (JB) S/B 2005-07-15        40        HC
# 4                GLOBELINK PAKISTAN (PVT) LTD 2005-07-16        40        HC
#
#      RATE
# 0  1620.0
# 1  1800.0
# 2  2170.0
# 3   280.0
# 4  1625.0

# %% [markdown]
# <h4>Creating Dictionary Keys</h4>

# %%
def filter_dataframe(df):
    filtered_dataframes = {}

    for (port, size, ctype, party_id), group in df.groupby(['POD_ID', 'CNTR_SIZE', 'CNTR_TYPE', 'PARTY_ID']):
        group = group.reset_index(drop=True).sort_values(by='POD')
        df_id = f"Port_{port}_Size_{size}_Type_{ctype}_PartyID_{party_id}"
        filtered_dataframes[df_id] = group

    return filtered_dataframes

# %%
# Creating keys from data
print("Old Data keys:")
filtered_dataframe1 = filter_dataframe(df1)
df_ids1 = list(filtered_dataframe1.keys())
print(list(df_ids1))
print(len(list(df_ids1)))

print("\nNew Data keys:")
filtered_dataframe2 = filter_dataframe(df2)
df_ids2 = list(filtered_dataframe2.keys())
print(list(df_ids2))
print(len(list(df_ids2)))
# Out:
# Old Data keys:
# ['Port_(CONSTANZA)_Size_40_Type_GP_PartyID_010007816', 'Port_(CONSTANZA)_Size_40_Type_HC_PartyID_010007816', 'Port_AARHUS_Size_20_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100027830', 'Port_AARHUS_Size_20_Type_GP_PartyID_010006666', 'Port_AARHUS_Size_40_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100027830', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100028193', 'Port_AARHUS_Size_40_Type_HC_PartyID_010006666', 'Port_ABIDJAN_Size_20_Type_GP_PartyID_0100027878', 'Port_ABIDJAN_Size_40_Type_HC_PartyID_010021097', 'Port_ADELAIDE_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01005078', 'Port_ADELAIDE_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ALEXANDRIA (EL DEKHELA PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC NOR_PartyID_010004995', 'Port_ALGECIRAS_Size_20_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC NOR_PartyID_01008306', 'Port_ALIAGA_Size_20_Type_GP_PartyID_01008316', 'Port_ALIAGA_Size_40_Type_HC_PartyID_01008316', 'Port_ALIAGA PORT (IZMIR)_Size_40_Type_HC_PartyID_01008316', 'Port_ANTWERP_Size_20_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC NOR_PartyID_01001449', 'Port_AQABA_Size_20_Type_GP_PartyID_010006618', 'Port_AQABA_Size_20_Type_GP_PartyID_010021081', 'Port_AQABA_Size_40_Type_HC_PartyID_010006618', 'Port_AQABA_Size_40_Type_HC_PartyID_010021081', 'Port_ASHDOD_Size_20_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_01008417', 'Port_ASHDOD_Size_40_Type_HC_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_HC_PartyID_01008417', 'Port_AUCKLAND_Size_20_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_20_Type_GP (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC NOR_PartyID_01005136', 'Port_BANGKOK_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_20_Type_GP (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (SOC)_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK (TST)_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK (TST)_Size_40_Type_HC_PartyID_010021593', 'Port_BARCELONA_Size_20_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC NOR_PartyID_01008305', 'Port_BEIRUT_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_HC_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_40_Type_HC_PartyID_0100 ...
# 789
#
# New Data keys:
# ['Port_(CONSTANZA)_Size_40_Type_GP_PartyID_010007816', 'Port_(CONSTANZA)_Size_40_Type_HC_PartyID_010007816', 'Port_AARHUS_Size_20_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100027830', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100028193', 'Port_AARHUS_Size_20_Type_GP_PartyID_010006666', 'Port_AARHUS_Size_40_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100027830', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100028193', 'Port_AARHUS_Size_40_Type_HC_PartyID_010006666', 'Port_ABIDJAN_Size_20_Type_GP_PartyID_0100027878', 'Port_ABIDJAN_Size_40_Type_HC_PartyID_010021097', 'Port_ADELAIDE_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01005078', 'Port_ADELAIDE_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ALEXANDRIA (EL DEKHELA PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC NOR_PartyID_010004995', 'Port_ALGECIRAS_Size_20_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC NOR_PartyID_01008306', 'Port_ALIAGA_Size_20_Type_GP_PartyID_01008316', 'Port_ALIAGA_Size_40_Type_HC_PartyID_01008316', 'Port_ALIAGA PORT (IZMIR)_Size_40_Type_HC_PartyID_01008316', 'Port_ANTWERP_Size_20_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC NOR_PartyID_01001449', 'Port_AQABA_Size_20_Type_GP_PartyID_010006618', 'Port_AQABA_Size_20_Type_GP_PartyID_010021081', 'Port_AQABA_Size_40_Type_HC_PartyID_010006618', 'Port_AQABA_Size_40_Type_HC_PartyID_010021081', 'Port_ASHDOD_Size_20_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_01008417', 'Port_ASHDOD_Size_40_Type_HC_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_HC_PartyID_01008417', 'Port_AUCKLAND_Size_20_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_20_Type_GP (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC NOR_PartyID_01005136', 'Port_BANGKOK_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_20_Type_GP (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (SOC)_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK (TST)_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK (TST)_Size_40_Type_HC_PartyID_010021593', 'Port_BARCELONA_Size_20_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC NOR_PartyID_01008305', 'Port_BEIRUT_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_HC_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_20_Type_GP_PartyID_010003651', ' ...
# 799

# %% [markdown]
# <h4>Getting Top 5 ports keys</h4>

# %%
def getTop5Ports(keybunch):
    keybunch_pouch = []
    
    # Get a dictionary with key and number of rows for each dataframe in filtered_dataframes
    key_row_counts = {key: len(keybunch[key]) for key in keybunch}

    # Sort the key_row_counts dictionary by value (number of rows) in descending order
    sorted_key_row_counts = sorted(key_row_counts.items(), key=lambda item: item[1], reverse=True)

    # Get the top 5 keys with the most rows
    top_5_keys_tuple = sorted_key_row_counts[:5]

    # Create a dictionary with the top 5 keys and their corresponding dataframes (with up to 5 rows per dataframe)
    keybunch_subset = {}

    for key, row_count in top_5_keys_tuple:
        keybunch_subset[key] = keybunch[key][:5]
        print(f"Number of rows in {key}: {row_count}")
        keybunch_pouch.append(key)
    
    # Return array of keys
    return keybunch_pouch

# %%
print('Old Dataset Keybunch:')
old_df = getTop5Ports(filtered_dataframe1)
print('\n')

print('New Dataset Keybunch:')
new_df = getTop5Ports(filtered_dataframe2)
# Out:
# Old Dataset Keybunch:
# Number of rows in Port_BUSAN_Size_40_Type_HC_PartyID_010004286: 1689
# Number of rows in Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136: 1688
# Number of rows in Port_MELBOURNE_Size_40_Type_HC_PartyID_01002778: 1325
# Number of rows in Port_SYDNEY_Size_40_Type_HC_PartyID_01002779: 1300
# Number of rows in Port_DUBAI (JEBEL ALI)_Size_40_Type_HC_PartyID_01002788: 1052
#
#
# New Dataset Keybunch:
# Number of rows in Port_BUSAN_Size_40_Type_HC_PartyID_010004286: 1712
# Number of rows in Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136: 1704
# Number of rows in Port_MELBOURNE_Size_40_Type_HC_PartyID_01002778: 1341
# Number of rows in Port_SYDNEY_Size_40_Type_HC_PartyID_01002779: 1308
# Number of rows in Port_DUBAI (JEBEL ALI)_Size_40_Type_HC_PartyID_01002788: 1070

# %%
# Global selection
sel_country = old_df[2]

# Accessing the highest count in the each keypouch, new and old.
sel_df = filtered_dataframe1[sel_country]
sel_df.head(5)
sel_df.tail(5)
sel_df.info()
print("\n")

latest_sel_df = filtered_dataframe2[sel_country]
latest_sel_df.head(5)
latest_sel_df.tail(5)
latest_sel_df.info()
# Out:
#             CSL_ID           CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 0   ECS01050600278  CTNR010050700692  MELBOURNE     AUMEL  01002778
# 1   ECS01050600280  CTNR010050701022  MELBOURNE     AUMEL  01002778
# 2  ECS010050700458  CTNR010050800604  MELBOURNE     AUMEL  01002778
# 3  ECS010050700214  CTNR010050800727  MELBOURNE     AUMEL  01002778
# 4  ECS010050900271  CTNR010051000178  MELBOURNE     AUMEL  01002778
#
#                                   PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-07-23        40        HC
# 1  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-07-30        40        HC
# 2  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-08-16        40        HC
# 3  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-08-19        40        HC
# 4  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-10-11        40        HC
#
#      RATE
# 0  1200.0
# 1  1200.0
# 2  1000.0
# 3  1200.0
# 4   900.0
#                CSL_ID       CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 1320  ECS010230100302  010000357415  MELBOURNE     AUMEL  01002778
# 1321  ECS010230100303  010000380481  MELBOURNE     AUMEL  01002778
# 1323  ECS010230100304  010000392586  MELBOURNE     AUMEL  01002778
# 1322  ECS010230100304  010000390964  MELBOURNE     AUMEL  01002778
# 1324  ECS010230100304  010000399293  MELBOURNE     AUMEL  01002778
#
#                                      PARTY_NAME        POD CNTR_SIZE  \
# 1320  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-02-11        40
# 1321  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-02-16        40
# 1323  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-02-24        40
# 1322  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-02-24        40
# 1324  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-02-24        40
#
#      CNTR_TYPE    RATE
# 1320        HC  1200.0
# 1321        HC  1200.0
# 1323        HC  1200.0
# 1322        HC  1200.0
# 1324        HC  1200.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1325 entries, 0 to 1324
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      1325 non-null   object
#  1   CNTR_ID     1325 non-null   object
#  2   POD_ID      1325 non-null   object
#  3   ETD_POL_D   1325 non-null   object
#  4   PARTY_ID    1325 non-null   object
#  5   PARTY_NAME  1325 non-null   object
#  6   POD         1325 non-null   datetime64[ns]
#  7   CNTR_SIZE   1325 non-null   object
#  8   CNTR_TYPE   1325 non-null   object
#  9   RATE        1325 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 113.9+ KB
#             CSL_ID           CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 0   ECS01050600278  CTNR010050700692  MELBOURNE     AUMEL  01002778
# 1   ECS01050600280  CTNR010050701022  MELBOURNE     AUMEL  01002778
# 2  ECS010050700458  CTNR010050800604  MELBOURNE     AUMEL  01002778
# 3  ECS010050700214  CTNR010050800727  MELBOURNE     AUMEL  01002778
# 4  ECS010050900271  CTNR010051000178  MELBOURNE     AUMEL  01002778
#
#                                   PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-07-23        40        HC
# 1  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-07-30        40        HC
# 2  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-08-16        40        HC
# 3  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-08-19        40        HC
# 4  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2005-10-11        40        HC
#
#      RATE
# 0  1200.0
# 1  1200.0
# 2  1000.0
# 3  1200.0
# 4   900.0
#                CSL_ID       CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 1336  ECS010230300518  010000531211  MELBOURNE     AUMEL  01002778
# 1337  ECS010230300518  010000509487  MELBOURNE     AUMEL  01002778
# 1338  ECS010230400431  010000541165  MELBOURNE     AUMEL  01002778
# 1339  ECS010230400432  010000543217  MELBOURNE     AUMEL  01002778
# 1340  ECS010230400433  010000557443  MELBOURNE     AUMEL  01002778
#
#                                      PARTY_NAME        POD CNTR_SIZE  \
# 1336  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-04-28        40
# 1337  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-04-28        40
# 1338  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-05        40
# 1339  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-11        40
# 1340  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-19        40
#
#      CNTR_TYPE   RATE
# 1336        HC  500.0
# 1337        HC  500.0
# 1338        HC  500.0
# 1339        HC  500.0
# 1340        HC  400.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1341 entries, 0 to 1340
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      1341 non-null   object
#  1   CNTR_ID     1341 non-null   object
#  2   POD_ID      1341 non-null   object
#  3   ETD_POL_D   1341 non-null   object
#  4   PARTY_ID    1341 non-null   object
#  5   PARTY_NAME  1341 non-null   object
#  6   POD         1341 non-null   datetime64[ns]
#  7   CNTR_SIZE   1341 non-null   object
#  8   CNTR_TYPE   1341 non-null   object
#  9   RATE        1341 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 115.2+ KB

# %%
# Select features
sel_feat = ['POD','RATE']
robust_df = sel_df[sel_feat].copy()  # make a copy to avoid SettingWithCopyWarning
robust_df.head()
robust_df.info()
# Out:
#          POD    RATE
# 0 2005-07-23  1200.0
# 1 2005-07-30  1200.0
# 2 2005-08-16  1000.0
# 3 2005-08-19  1200.0
# 4 2005-10-11   900.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1325 entries, 0 to 1324
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POD     1325 non-null   datetime64[ns]
#  1   RATE    1325 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 31.1 KB

# %%
plt.figure(figsize=(20, 10))
plt.plot(robust_df['POD'], robust_df['RATE'], color='blue', label="Data")

plt.xlabel('Date(Days)')
plt.ylabel('Cost Rate(USD)')
plt.title(f'Original Dataset plot: {sel_country}')
plt.legend()
plt.show();

# %% [markdown]
# <h4>Handling covid period</h4>

# %%
# Dataframe for LSTM2
robust_df = robust_df[['POD','RATE']].copy()

# Create a new column indicating whether each month is affected by COVID-19
robust_df['Covid'] = 0
robust_df.loc[(robust_df['POD'] >= '2020-01') & (robust_df['POD'] <= '2023-01'), 'Covid'] = 1

# Just to preview entries that is marked as covid:
robust_df_covid = robust_df[robust_df['Covid'] == 1]
print("Covid entries preview:")
robust_df_covid.head()
print("\n")

print("Done feature enginering dataframe:")
robust_df.head()
robust_df.tail()
robust_df.info()
# Out:
# Covid entries preview:
#             POD   RATE  Covid
# 1107 2020-01-01  500.0      1
# 1108 2020-01-01  500.0      1
# 1109 2020-01-11  500.0      1
# 1110 2020-01-11  500.0      1
# 1111 2020-01-18  500.0      1
# Done feature enginering dataframe:
#          POD    RATE  Covid
# 0 2005-07-23  1200.0      0
# 1 2005-07-30  1200.0      0
# 2 2005-08-16  1000.0      0
# 3 2005-08-19  1200.0      0
# 4 2005-10-11   900.0      0
#             POD    RATE  Covid
# 1320 2023-02-11  1200.0      0
# 1321 2023-02-16  1200.0      0
# 1323 2023-02-24  1200.0      0
# 1322 2023-02-24  1200.0      0
# 1324 2023-02-24  1200.0      0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1325 entries, 0 to 1324
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POD     1325 non-null   datetime64[ns]
#  1   RATE    1325 non-null   float64
#  2   Covid   1325 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 41.4 KB

# %%
# Create a mask where 'Covid' is not equal to 1
mask = robust_df['Covid'] != 1

# Apply the mask to the DataFrame to keep only the rows where 'Covid' is not equal to 1
robust_df = robust_df[mask]

# Plot to visualise
plt.figure(figsize=(20, 10))
plt.plot(sel_df['POD'], sel_df['RATE'], color='blue', label="Actual Data")
plt.plot(robust_df['POD'], robust_df['RATE'], color='Red', label="Data after handling anomaly")
plt.title(sel_country)
plt.legend()
plt.show();

# %%
# Remove Anomaly column
without_ann = ['POD','RATE']
robust_df = robust_df[without_ann]

# %% [markdown]
# <h4>Interpolate missing values in between dates</h4>

# %%
# Remove duplicated dates and cost rows
robust_df = robust_df.drop_duplicates(subset=['POD', 'RATE']).reset_index(drop=True)

# Create a new dataframe with a date range from min to max date in your dataframe
new_df = pd.DataFrame()
new_df['POD'] = pd.date_range(start=robust_df['POD'].min(), end=robust_df['POD'].max())

# Merge the original dataframe with the new one. Missing dates in the original dataframe will be filled with NaN
df_interpolated = pd.merge(new_df, robust_df, on='POD', how='left')  

# Perform spline interpolation
df_interpolated['RATE'] = df_interpolated['RATE'].interpolate(method='polynomial', order=1)

df_interpolated['RATE'] = df_interpolated['RATE'].round(3)

df_interpolated.head(5)
df_interpolated.tail(5)
df_interpolated.info()
# Out:
#          POD    RATE
# 0 2005-07-23  1200.0
# 1 2005-07-24  1200.0
# 2 2005-07-25  1200.0
# 3 2005-07-26  1200.0
# 4 2005-07-27  1200.0
#             POD    RATE
# 6433 2023-02-20  1200.0
# 6434 2023-02-21  1200.0
# 6435 2023-02-22  1200.0
# 6436 2023-02-23  1200.0
# 6437 2023-02-24  1200.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6438 entries, 0 to 6437
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POD     6438 non-null   datetime64[ns]
#  1   RATE    6438 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 150.9 KB

# %% [markdown]
# <h4>Grouping it to week</h4>

# %%
# Create YearMonthWeek directly from the 'POD'
df_interpolated['YearMonthWeek'] = df_interpolated['POD'] - pd.to_timedelta(df_interpolated['POD'].dt.dayofweek, unit='D')

# Create a new dataframe with every week in the range
all_weeks = pd.date_range(start=df_interpolated['POD'].min(), end=df_interpolated['POD'].max(), freq='W')
all_weeks_df = pd.DataFrame(all_weeks, columns=['POD'])

# Create YearMonthWeek in all_weeks_df
all_weeks_df['YearMonthWeek'] = all_weeks_df['POD'] - pd.to_timedelta(all_weeks_df['POD'].dt.dayofweek, unit='D')

# Merge this with your original dataframe
merged_df = pd.merge(all_weeks_df, df_interpolated, on=['YearMonthWeek'], how='left')

# Now you can group by YearMonthWeek and compute your rate
grouped = merged_df.groupby(['YearMonthWeek'])

agg_df = pd.DataFrame(columns=['YearMonthWeek', 'Rate'])

for group_name, group_df in grouped:
    year_month_week = group_name

    # Skip if no data for this week
    if group_df['RATE'].isnull().all():
        continue

    # Calculate sum and skewness of RATE values
    rate_sum = group_df['RATE'].sum()
    rate_skew = group_df['RATE'].skew()

    # Calculate trimmed mean of RATE values
    rate_metric = stats.trim_mean(group_df['RATE'].dropna().values, 0.1) # trimming 10% from each end

    new_row = {
        'YearMonthWeek': year_month_week,
        'Rate': rate_metric
    }

    # Append row to aggregated dataframe
    agg_df = agg_df.append(new_row, ignore_index=True)

agg_df = agg_df.sort_values(by='YearMonthWeek').reset_index(drop=True)
agg_df['Rate'] = agg_df['Rate'].round(2)

agg_df.head(15)
agg_df.tail(15)
agg_df.info()
# Out:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:19: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for group_name, group_df in grouped:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# ...
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\545048384.py:39: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
#    YearMonthWeek     Rate
# 0     2005-07-18  1200.00
# 1     2005-07-25  1198.32
# 2     2005-08-01  1141.18
# 3     2005-08-08  1058.82
# 4     2005-08-15  1113.54
# 5     2005-08-22  1166.04
# 6     2005-08-29  1126.42
# 7     2005-09-05  1086.79
# 8     2005-09-12  1047.17
# 9     2005-09-19  1007.55
# 10    2005-09-26   967.92
# 11    2005-10-03   928.30
# 12    2005-10-10   900.81
# 13    2005-10-17   900.00
# 14    2005-10-24   900.00
#     YearMonthWeek     Rate
# 903    2022-11-07  1920.63
# 904    2022-11-14  1930.04
# 905    2022-11-21  1939.46
# 906    2022-11-28  1948.88
# 907    2022-12-05  1958.30
# 908    2022-12-12  1967.71
# 909    2022-12-19  1977.13
# 910    2022-12-26  1986.55
# 911    2023-01-02  1995.96
# 912    2023-01-09  2000.00
# 913    2023-01-16  1841.88
# 914    2023-01-23  1798.50
# 915    2023-01-30  1390.48
# 916    2023-02-06  1200.00
# 917    2023-02-13  1200.00
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   YearMonthWeek  918 non-null    datetime64[ns]
#  1   Rate           918 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 14.5 KB

# %%
plt.figure(figsize=(20, 10))
plt.plot(sel_df['POD'], sel_df['RATE'], color='blue', label="Actual Data")
plt.plot(agg_df['YearMonthWeek'], agg_df['Rate'], color='red', label="Aggregated Data(weeks)")

plt.xlabel('Date(Year Month Week)')
plt.ylabel('Cost Rate(USD)')
plt.title('Port_BUSAN_Size_40_Type_HC_PartyID_010004286')
plt.legend()
plt.show();

# %% [markdown]
# <h4>Latest datapoints from Latest dataframe for comparing after forecasting (Measure accuracy)</h4>

# %%
max_date_in_old = sel_df['POD'].max()

# Create a new dataframe that only includes rows from the latest dataframe where the date is greater than the maximum date in the old dataframe
new_dates_df = latest_sel_df[latest_sel_df['POD'] > max_date_in_old].reset_index(drop=True)

# Print the new dataframe
new_dates_df.head(3)
new_dates_df.tail(3)
new_dates_df.info()
# Out:
#             CSL_ID       CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 0  ECS010230200328  010000409869  MELBOURNE     AUMEL  01002778
# 1  ECS010230200329  010000419018  MELBOURNE     AUMEL  01002778
# 2  ECS010230200330  010000427048  MELBOURNE     AUMEL  01002778
#
#                                   PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-03-02        40        HC
# 1  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-03-10        40        HC
# 2  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-03-16        40        HC
#
#      RATE
# 0  1000.0
# 1  1000.0
# 2  1000.0
#              CSL_ID       CNTR_ID     POD_ID ETD_POL_D  PARTY_ID  \
# 13  ECS010230400431  010000541165  MELBOURNE     AUMEL  01002778
# 14  ECS010230400432  010000543217  MELBOURNE     AUMEL  01002778
# 15  ECS010230400433  010000557443  MELBOURNE     AUMEL  01002778
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 13  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-05        40        HC
# 14  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-11        40        HC
# 15  GLOBELINK INTERNATIONAL PTY LTD-MELBOURNE 2023-05-19        40        HC
#
#      RATE
# 13  500.0
# 14  500.0
# 15  400.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      16 non-null     object
#  1   CNTR_ID     16 non-null     object
#  2   POD_ID      16 non-null     object
#  3   ETD_POL_D   16 non-null     object
#  4   PARTY_ID    16 non-null     object
#  5   PARTY_NAME  16 non-null     object
#  6   POD         16 non-null     datetime64[ns]
#  7   CNTR_SIZE   16 non-null     object
#  8   CNTR_TYPE   16 non-null     object
#  9   RATE        16 non-null     float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 1.4+ KB

# %% [markdown]
# <h4>LSTM Regression<h4>

# %%
# Mean Square Error Function:
def calculate_RMSE(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# Update create_dataset to handle multi-feature dataset
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), :]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)


def create_LSTM_model(trainX, trainY, testX, testY, epochs, lstm_layers):
    model = Sequential()
    
    for i in range(len(lstm_layers)):
        if i == 0:
            # First layer specifies the input_shape and returns sequences
            model.add(LSTM(lstm_layers[i], return_sequences=True, input_shape=(look_back, trainX.shape[2]), 
                           activation='tanh', recurrent_activation='hard_sigmoid', kernel_regularizer=l2(0.01)))
        elif i == len(lstm_layers) - 1:
            # Last layer doesn't return sequences
            model.add(LSTM(lstm_layers[i], activation='tanh', kernel_regularizer=l2(0.01)))
        else:
            # Middle layers return sequences
            model.add(LSTM(lstm_layers[i], return_sequences=True, activation='tanh', 
                           recurrent_activation='hard_sigmoid', kernel_regularizer=l2(0.01)))
        model.add(Dropout(0.2))
        
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=0.0005))
    model.summary()

    # Add early stopping
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)
    
    # Fit the model and store the history
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=128, verbose=2, 
                        validation_data=(testX, testY), callbacks=[es])
    return model, history


def plot_train_val_loss(history):
    plt.figure(figsize=(10,6))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model loss progress during training and validation')
    plt.xlabel('Epoch')
    plt.ylabel('Training and Validation Loss')
    plt.legend()
    plt.show()

# %%
# Normalize dataset for LSTM
from sklearn.preprocessing import MinMaxScaler

# Initialize two separate scalers
scaler_rate = MinMaxScaler(feature_range=(0, 1))

# Fit and transform 'RATE' and 'during_covid' separately
rate_scaled = scaler_rate.fit_transform(agg_df[['Rate']])

# Concatenate the scaled data
dataset = np.concatenate([rate_scaled], axis=1)

# Split into train and test sets
train_size = int(len(dataset) * 0.7)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# Reshape into X=t and Y=t+1, timestep  look_back
look_back = 5
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# Reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], look_back, trainX.shape[2]))
testX = np.reshape(testX, (testX.shape[0], look_back, testX.shape[2]))

epochs_list = [50, 100, 150]

lstm_layers_list = [
    [64, 64, 32, 32, 16, 16, 8, 8, 4, 4, 2, 2],
    [32, 32, 16, 16, 8, 8, 4, 4, 2, 2],
    [16, 16, 8, 8, 4, 4, 2, 2],
    [8, 8, 4, 4, 2, 2],
    [4, 4, 2, 2],
    [2, 2]
]

rmse_results = {}

for epochs in epochs_list:
    print(f'Training for {epochs} epochs...')
    
    for lstm_layers in lstm_layers_list:
        print(f'Training with LSTM layers: {lstm_layers}')
        model, history = create_LSTM_model(trainX, trainY, testX, testY, epochs, lstm_layers)
        
        # Add the loss for this model to the plot
        plt.plot(history.history['loss'], label=f'Train Loss - {epochs} epochs, layers: {lstm_layers}')
        plt.plot(history.history['val_loss'], label=f'Validation Loss - {epochs} epochs, layers: {lstm_layers}')

        # Evalute LSTM Model
        trainPredict = model.predict(trainX)
        testPredict = model.predict(testX)

        # inverse_transform
        trainPredict = scaler_rate.inverse_transform(trainPredict)
        trainY_orig = scaler_rate.inverse_transform([trainY])
        testPredict = scaler_rate.inverse_transform(testPredict)
        testY_orig = scaler_rate.inverse_transform([testY])


        # Calculate mean squared error
        trainScore = calculate_RMSE(trainY_orig[0], trainPredict[:,0])
        print(f'Train Score: {trainScore:.2f} RMSE for {epochs} epochs')
        testScore = calculate_RMSE(testY_orig[0], testPredict[:,0])
        print(f'Test Score: {testScore:.2f} RMSE for {epochs} epochs')

        rmse_results[f'{epochs} epochs, {lstm_layers} layers'] = {'Train RMSE': trainScore, 'Test RMSE': testScore}

# Configure and show the plot
plt.title('Model loss progress during training and validation')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend()
plt.show();

# Convert the dictionary to a DataFrame for easy display
rmse_df = pd.DataFrame(rmse_results).T
print(rmse_df)
# Out:
# Training for 50 epochs...
# Training with LSTM layers: [64, 64, 32, 32, 16, 16, 8, 8, 4, 4, 2, 2]
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_48 (LSTM)              (None, 5, 64)             16896
#
#  dropout_48 (Dropout)        (None, 5, 64)             0
#
#  lstm_49 (LSTM)              (None, 5, 64)             33024
#
#  dropout_49 (Dropout)        (None, 5, 64)             0
#
#  lstm_50 (LSTM)              (None, 5, 32)             12416
#
#  dropout_50 (Dropout)        (None, 5, 32)             0
#
#  lstm_51 (LSTM)              (None, 5, 32)             8320
#
#  dropout_51 (Dropout)        (None, 5, 32)             0
#
#  lstm_52 (LSTM)              (None, 5, 16)             3136
#
#  dropout_52 (Dropout)        (None, 5, 16)             0
#
#  lstm_53 (LSTM)              (None, 5, 16)             2112
#
#  dropout_53 (Dropout)        (None, 5, 16)             0
#
#  lstm_54 (LSTM)              (None, 5, 8)              800
#
#  dropout_54 (Dropout)        (None, 5, 8)              0
#
#  lstm_55 (LSTM)              (None, 5, 8)              544
#
#  dropout_55 (Dropout)        (None, 5, 8)              0
#
#  lstm_56 (LSTM)              (None, 5, 4)              208
#
#  dropout_56 (Dropout)        (None, 5, 4)              0
#
#  lstm_57 (LSTM)              (None, 5, 4)              144
#
#  dropout_57 (Dropout)        (None, 5, 4)              0
#
#  lstm_58 (LSTM)              (None, 5, 2)              56
#
#  dropout_58 (Dropout)        (None, 5, 2)              0
#
#  lstm_59 (LSTM)              (None, 2)                 40
#
#  dropout_59 (Dropout)        (None, 2)                 0
#
#  dense_4 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 77,699
# Trainable params: 77,699
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 27s - loss: 3.7163 - val_loss: 3.8295 - 27s/epoch - 5s/step
# Epoch 2/50
# 5/5 - 0s - loss: 3.5750 - val_loss: 3.6893 - 265ms/epoch - 53ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 3.4382 - val_loss: 3.5536 - 269ms/epoch - 54ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 3.3061 - val_loss: 3.4227 - 257ms/epoch - 51ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 3.1786 - val_loss: 3.2964 - 279ms/epoch - 56ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 3.0559 - val_loss: 3.1748 - 266ms/epoch - 53ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 2.9377 - val_loss: 3.0578 - 238ms/epoch - 48ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 2.8244 - val_loss: 2.9453 - 236ms/epoch - 47ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 2.7152 - val_loss: 2.8372 - 240ms/epoch - 48ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 2.6107 - val_loss: 2.7332 - 244ms/epoch - 49ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 2.5103 - val_loss: 2.6333 - 243ms/epoch - 49ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 2.4138 - val_loss: 2.5373 - 237ms/epoch - 47ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 2.3209 - val_loss: 2.4450 - 235ms/epoch - 47ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 2.2320 - val_loss: 2.3562 - 236ms/epoch - 47ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 2.1470 - val_loss: 2.2709 - 234ms/epoch - 47ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 2.0645 - val_loss: 2.1888 - 236ms/epoch - 47ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 1.9852 - val_loss: 2.1099 - 237ms/epoch - 47ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 1.9097 - val_loss: 2.0339 - 232ms/epoch - 46ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 1.8371 - val_loss: 1.9609 - 234ms/epoch - 47ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 1.7679 - val_loss: 1.8906 - 236ms/epoch - 47ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 1.7009 - val_loss: 1.8230 - 236ms/epoch - 47ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 1.6357 - val_loss: 1.7579 - 233ms/epoch - 47ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 1.5742 - val_loss: 1.6953 - 235ms/epoch - 47ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 1.5160 - val_loss: 1.6350 - 236ms/epoch - 47ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 1.4578 - val_loss: 1.5771 - 242ms/epoch - 48ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 1.4035 - val_loss: 1.5213 - 235ms/epoch - 47ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 1.3512 - val_loss: 1.4676 - 238ms/epoch - 48ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 1.3007 - val_loss: 1.4160 - 238ms/epoch - 48ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 1.2518 - val_loss: 1.3662 - 237ms/epoch - 47ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 1.2060 - val_loss: 1.3184 - 237ms/epoch - 47ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 1.1617 - val_loss: 1.2724 - 239ms/epoch - 48ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 1.1182 - val_loss: 1.2282 - 242ms/epoch - 48ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 1.0777 - val_loss: 1.1857 - 236ms/epoch - 47ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 1.0382 - val_loss: 1.1448 - 240ms/epoch - 48ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.9990 - val_loss: 1.1056 - 237ms/epoch - 47ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.9644 - val_loss: 1.0678 - 237ms/epoch - 47ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.9287 - val_loss: 1.0315 - 238ms/epoch - 48ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.8955 - val_loss: 0.9967 - 236ms/epoch - 47ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.8644 - val_loss: 0.9632 - 237ms/epoch - 47ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.8331 - val_loss: 0.9312 - 262ms/epoch - 52ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.8043 - val_loss: 0.9003 - 237ms/epoch - 47ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.7757 - val_loss: 0.8708 - 237ms/epoch - 47ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.7497 - val_loss: 0.8425 - 239ms/epoch - 48ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.7220 - val_loss: 0.8154 - 241ms/epoch - 48ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.6986 - val_loss: 0.7894 - 239ms/epoch - 48ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.6748 - val_loss: 0.7645 - 236ms/epoch - 47ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.6527 - val_loss: 0.7407 - 256ms/epoch - 51ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.6296 - val_loss: 0.7179 - 239ms/epoch - 48ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.6079 - val_loss: 0.6961 - 244ms/epoch - 49ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.5875 - val_loss: 0.6752 - 237ms/epoch - 47ms/step
# 20/20 [==============================] - 2s 7ms/step
# 9/9 [==============================] - 0s 7ms/step
# Train Score: 259.68 RMSE for 50 epochs
# Test Score: 623.16 RMSE for 50 epochs
# Training with LSTM layers: [32, 32, 16, 16, 8, 8, 4, 4, 2, 2]
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_60 (LSTM)              (None, 5, 32)             4352
#
#  dropout_60 (Dropout)        (None, 5, 32)             0
#
#  lstm_61 (LSTM)              (None, 5, 32)             8320
#
#  dropout_61 (Dropout)        (None, 5, 32)             0
#
#  lstm_62 (LSTM)              (None, 5, 16)             3136
#
#  dropout_62 (Dropout)        (None, 5, 16)             0
#
#  lstm_63 (LSTM)              (None, 5, 16)             2112
#
#  dropout_63 (Dropout)        (None, 5, 16)             0
#
#  lstm_64 (LSTM)              (None, 5, 8)              800
#
#  dropout_64 (Dropout)        (None, 5, 8)              0
#
#  lstm_65 (LSTM)              (None, 5, 8)              544
#
#  dropout_65 (Dropout)        (None, 5, 8)              0
#
#  lstm_66 (LSTM)              (None, 5, 4)              208
#
#  dropout_66 (Dropout)        (None, 5, 4)              0
#
#  lstm_67 (LSTM)              (None, 5, 4)              144
#
#  dropout_67 (Dropout)        (None, 5, 4)              0
#
#  lstm_68 (LSTM)              (None, 5, 2)              56
#
#  dropout_68 (Dropout)        (None, 5, 2)              0
#
#  lstm_69 (LSTM)              (None, 2)                 40
#
#  dropout_69 (Dropout)        (None, 2)                 0
#
#  dense_5 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 19,715
# Trainable params: 19,715
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 21s - loss: 1.8711 - val_loss: 2.0352 - 21s/epoch - 4s/step
# Epoch 2/50
# 5/5 - 0s - loss: 1.8170 - val_loss: 1.9781 - 182ms/epoch - 36ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 1.7641 - val_loss: 1.9222 - 182ms/epoch - 36ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 1.7123 - val_loss: 1.8675 - 182ms/epoch - 36ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 1.6621 - val_loss: 1.8141 - 181ms/epoch - 36ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 1.6129 - val_loss: 1.7619 - 175ms/epoch - 35ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 1.5653 - val_loss: 1.7110 - 175ms/epoch - 35ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 1.5186 - val_loss: 1.6614 - 175ms/epoch - 35ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 1.4736 - val_loss: 1.6130 - 175ms/epoch - 35ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 1.4306 - val_loss: 1.5659 - 173ms/epoch - 35ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 1.3879 - val_loss: 1.5201 - 177ms/epoch - 35ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 1.3476 - val_loss: 1.4755 - 178ms/epoch - 36ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 1.3086 - val_loss: 1.4323 - 176ms/epoch - 35ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 1.2684 - val_loss: 1.3903 - 177ms/epoch - 35ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 1.2332 - val_loss: 1.3496 - 181ms/epoch - 36ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 1.1973 - val_loss: 1.3101 - 179ms/epoch - 36ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 1.1624 - val_loss: 1.2720 - 178ms/epoch - 36ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 1.1290 - val_loss: 1.2351 - 185ms/epoch - 37ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 1.0974 - val_loss: 1.1995 - 201ms/epoch - 40ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 1.0664 - val_loss: 1.1652 - 181ms/epoch - 36ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 1.0381 - val_loss: 1.1322 - 179ms/epoch - 36ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 1.0056 - val_loss: 1.1005 - 178ms/epoch - 36ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 0.9776 - val_loss: 1.0699 - 177ms/epoch - 35ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.9511 - val_loss: 1.0405 - 176ms/epoch - 35ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.9246 - val_loss: 1.0123 - 177ms/epoch - 35ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.9013 - val_loss: 0.9854 - 176ms/epoch - 35ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.8770 - val_loss: 0.9596 - 179ms/epoch - 36ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.8497 - val_loss: 0.9348 - 188ms/epoch - 38ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.8276 - val_loss: 0.9108 - 175ms/epoch - 35ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.8072 - val_loss: 0.8877 - 178ms/epoch - 36ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.7827 - val_loss: 0.8655 - 177ms/epoch - 35ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.7636 - val_loss: 0.8440 - 181ms/epoch - 36ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.7417 - val_loss: 0.8232 - 180ms/epoch - 36ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.7216 - val_loss: 0.8031 - 180ms/epoch - 36ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.7058 - val_loss: 0.7839 - 179ms/epoch - 36ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.6859 - val_loss: 0.7653 - 181ms/epoch - 36ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.6673 - val_loss: 0.7473 - 180ms/epoch - 36ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.6486 - val_loss: 0.7298 - 181ms/epoch - 36ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.6347 - val_loss: 0.7128 - 184ms/epoch - 37ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.6136 - val_loss: 0.6964 - 178ms/epoch - 36ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.5997 - val_loss: 0.6802 - 182ms/epoch - 36ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.5829 - val_loss: 0.6644 - 176ms/epoch - 35ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.5677 - val_loss: 0.6490 - 179ms/epoch - 36ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.5536 - val_loss: 0.6340 - 177ms/epoch - 35ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.5395 - val_loss: 0.6195 - 206ms/epoch - 41ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.5280 - val_loss: 0.6056 - 178ms/epoch - 36ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.5103 - val_loss: 0.5921 - 181ms/epoch - 36ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.4981 - val_loss: 0.5789 - 178ms/epoch - 36ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.4867 - val_loss: 0.5661 - 180ms/epoch - 36ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.4744 - val_loss: 0.5539 - 180ms/epoch - 36ms/step
# 20/20 [==============================] - 2s 6ms/step
# 9/9 [==============================] - 0s 5ms/step
# Train Score: 250.61 RMSE for 50 epochs
# Test Score: 598.48 RMSE for 50 epochs
# Training with LSTM layers: [16, 16, 8, 8, 4, 4, 2, 2]
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_70 (LSTM)              (None, 5, 16)             1152
#
#  dropout_70 (Dropout)        (None, 5, 16)             0
#
#  lstm_71 (LSTM)              (None, 5, 16)             2112
#
#  dropout_71 (Dropout)        (None, 5, 16)             0
#
#  lstm_72 (LSTM)              (None, 5, 8)              800
#
#  dropout_72 (Dropout)        (None, 5, 8)              0
#
#  lstm_73 (LSTM)              (None, 5, 8)              544
#
#  dropout_73 (Dropout)        (None, 5, 8)              0
#
#  lstm_74 (LSTM)              (None, 5, 4)              208
#
#  dropout_74 (Dropout)        (None, 5, 4)              0
#
#  lstm_75 (LSTM)              (None, 5, 4)              144
#
#  dropout_75 (Dropout)        (None, 5, 4)              0
#
#  lstm_76 (LSTM)              (None, 5, 2)              56
#
#  dropout_76 (Dropout)        (None, 5, 2)              0
#
#  lstm_77 (LSTM)              (None, 2)                 40
#
#  dropout_77 (Dropout)        (None, 2)                 0
#
#  dense_6 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 5,059
# Trainable params: 5,059
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 17s - loss: 0.9631 - val_loss: 1.1474 - 17s/epoch - 3s/step
# Epoch 2/50
# 5/5 - 0s - loss: 0.9412 - val_loss: 1.1227 - 161ms/epoch - 32ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 0.9199 - val_loss: 1.0984 - 153ms/epoch - 31ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 0.8991 - val_loss: 1.0745 - 146ms/epoch - 29ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 0.8782 - val_loss: 1.0509 - 143ms/epoch - 29ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 0.8578 - val_loss: 1.0276 - 137ms/epoch - 27ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 0.8389 - val_loss: 1.0048 - 146ms/epoch - 29ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 0.8193 - val_loss: 0.9824 - 153ms/epoch - 31ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 0.8005 - val_loss: 0.9604 - 148ms/epoch - 30ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 0.7820 - val_loss: 0.9388 - 143ms/epoch - 29ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 0.7642 - val_loss: 0.9175 - 149ms/epoch - 30ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 0.7450 - val_loss: 0.8966 - 147ms/epoch - 29ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 0.7304 - val_loss: 0.8761 - 139ms/epoch - 28ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 0.7128 - val_loss: 0.8561 - 136ms/epoch - 27ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 0.6957 - val_loss: 0.8364 - 147ms/epoch - 29ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 0.6806 - val_loss: 0.8172 - 141ms/epoch - 28ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 0.6644 - val_loss: 0.7983 - 148ms/epoch - 30ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 0.6515 - val_loss: 0.7799 - 150ms/epoch - 30ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 0.6364 - val_loss: 0.7621 - 154ms/epoch - 31ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 0.6217 - val_loss: 0.7448 - 152ms/epoch - 30ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 0.6077 - val_loss: 0.7278 - 145ms/epoch - 29ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 0.5946 - val_loss: 0.7114 - 143ms/epoch - 29ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 0.5830 - val_loss: 0.6955 - 149ms/epoch - 30ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.5712 - val_loss: 0.6802 - 151ms/epoch - 30ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.5585 - val_loss: 0.6655 - 142ms/epoch - 28ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.5458 - val_loss: 0.6513 - 154ms/epoch - 31ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.5352 - val_loss: 0.6375 - 157ms/epoch - 31ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.5253 - val_loss: 0.6243 - 149ms/epoch - 30ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.5133 - val_loss: 0.6115 - 152ms/epoch - 30ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.5019 - val_loss: 0.5993 - 154ms/epoch - 31ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.4940 - val_loss: 0.5876 - 144ms/epoch - 29ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.4837 - val_loss: 0.5764 - 150ms/epoch - 30ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.4735 - val_loss: 0.5656 - 146ms/epoch - 29ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.4628 - val_loss: 0.5551 - 152ms/epoch - 30ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.4554 - val_loss: 0.5451 - 156ms/epoch - 31ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.4447 - val_loss: 0.5355 - 152ms/epoch - 30ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.4375 - val_loss: 0.5261 - 151ms/epoch - 30ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.4277 - val_loss: 0.5169 - 176ms/epoch - 35ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.4193 - val_loss: 0.5081 - 150ms/epoch - 30ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.4126 - val_loss: 0.4995 - 161ms/epoch - 32ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.4034 - val_loss: 0.4911 - 153ms/epoch - 31ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.3978 - val_loss: 0.4830 - 164ms/epoch - 33ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.3889 - val_loss: 0.4752 - 162ms/epoch - 32ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.3819 - val_loss: 0.4676 - 153ms/epoch - 31ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.3738 - val_loss: 0.4601 - 138ms/epoch - 28ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.3660 - val_loss: 0.4527 - 143ms/epoch - 29ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.3577 - val_loss: 0.4455 - 146ms/epoch - 29ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.3519 - val_loss: 0.4383 - 141ms/epoch - 28ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.3448 - val_loss: 0.4314 - 137ms/epoch - 27ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.3392 - val_loss: 0.4247 - 155ms/epoch - 31ms/step
# 20/20 [==============================] - 2s 5ms/step
# 9/9 [==============================] - 0s 4ms/step
# Train Score: 252.35 RMSE for 50 epochs
# Test Score: 604.23 RMSE for 50 epochs
# Training with LSTM layers: [8, 8, 4, 4, 2, 2]
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_78 (LSTM)              (None, 5, 8)              320
#
#  dropout_78 (Dropout)        (None, 5, 8)              0
#
#  lstm_79 (LSTM)              (None, 5, 8)              544
#
#  dropout_79 (Dropout)        (None, 5, 8)              0
#
#  lstm_80 (LSTM)              (None, 5, 4)              208
#
#  dropout_80 (Dropout)        (None, 5, 4)              0
#
#  lstm_81 (LSTM)              (None, 5, 4)              144
#
#  dropout_81 (Dropout)        (None, 5, 4)              0
#
#  lstm_82 (LSTM)              (None, 5, 2)              56
#
#  dropout_82 (Dropout)        (None, 5, 2)              0
#
#  lstm_83 (LSTM)              (None, 2)                 40
#
#  dropout_83 (Dropout)        (None, 2)                 0
#
#  dense_7 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 1,315
# Trainable params: 1,315
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 15s - loss: 0.4898 - val_loss: 0.6815 - 15s/epoch - 3s/step
# Epoch 2/50
# 5/5 - 0s - loss: 0.4797 - val_loss: 0.6687 - 111ms/epoch - 22ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 0.4700 - val_loss: 0.6560 - 108ms/epoch - 22ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 0.4601 - val_loss: 0.6435 - 108ms/epoch - 22ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 0.4506 - val_loss: 0.6312 - 104ms/epoch - 21ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 0.4417 - val_loss: 0.6189 - 102ms/epoch - 20ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 0.4324 - val_loss: 0.6069 - 104ms/epoch - 21ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 0.4238 - val_loss: 0.5950 - 107ms/epoch - 21ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 0.4144 - val_loss: 0.5832 - 106ms/epoch - 21ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 0.4057 - val_loss: 0.5716 - 106ms/epoch - 21ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 0.3977 - val_loss: 0.5601 - 106ms/epoch - 21ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 0.3888 - val_loss: 0.5487 - 106ms/epoch - 21ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 0.3809 - val_loss: 0.5375 - 106ms/epoch - 21ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 0.3728 - val_loss: 0.5264 - 107ms/epoch - 21ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 0.3652 - val_loss: 0.5155 - 105ms/epoch - 21ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 0.3580 - val_loss: 0.5048 - 106ms/epoch - 21ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 0.3512 - val_loss: 0.4943 - 107ms/epoch - 21ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 0.3427 - val_loss: 0.4839 - 107ms/epoch - 21ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 0.3352 - val_loss: 0.4738 - 106ms/epoch - 21ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 0.3300 - val_loss: 0.4638 - 113ms/epoch - 23ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 0.3221 - val_loss: 0.4541 - 113ms/epoch - 23ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 0.3166 - val_loss: 0.4446 - 110ms/epoch - 22ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 0.3107 - val_loss: 0.4354 - 107ms/epoch - 21ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.3056 - val_loss: 0.4264 - 106ms/epoch - 21ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.2998 - val_loss: 0.4178 - 107ms/epoch - 21ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.2935 - val_loss: 0.4094 - 107ms/epoch - 21ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.2886 - val_loss: 0.4013 - 111ms/epoch - 22ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.2825 - val_loss: 0.3935 - 110ms/epoch - 22ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.2795 - val_loss: 0.3860 - 111ms/epoch - 22ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.2726 - val_loss: 0.3788 - 109ms/epoch - 22ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.2699 - val_loss: 0.3720 - 109ms/epoch - 22ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.2630 - val_loss: 0.3654 - 113ms/epoch - 23ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.2601 - val_loss: 0.3590 - 109ms/epoch - 22ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.2567 - val_loss: 0.3530 - 125ms/epoch - 25ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.2522 - val_loss: 0.3473 - 110ms/epoch - 22ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.2494 - val_loss: 0.3421 - 108ms/epoch - 22ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.2438 - val_loss: 0.3370 - 121ms/epoch - 24ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.2405 - val_loss: 0.3321 - 117ms/epoch - 23ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.2361 - val_loss: 0.3274 - 116ms/epoch - 23ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.2344 - val_loss: 0.3230 - 112ms/epoch - 22ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.2320 - val_loss: 0.3188 - 109ms/epoch - 22ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.2274 - val_loss: 0.3149 - 116ms/epoch - 23ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.2239 - val_loss: 0.3112 - 122ms/epoch - 24ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.2210 - val_loss: 0.3076 - 114ms/epoch - 23ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.2166 - val_loss: 0.3041 - 123ms/epoch - 25ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.2127 - val_loss: 0.3007 - 118ms/epoch - 24ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.2100 - val_loss: 0.2974 - 120ms/epoch - 24ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.2082 - val_loss: 0.2941 - 111ms/epoch - 22ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.2036 - val_loss: 0.2908 - 107ms/epoch - 21ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.2001 - val_loss: 0.2876 - 111ms/epoch - 22ms/step
# 20/20 [==============================] - 1s 4ms/step
# 9/9 [==============================] - 0s 3ms/step
# Train Score: 249.93 RMSE for 50 epochs
# Test Score: 596.01 RMSE for 50 epochs
# Training with LSTM layers: [4, 4, 2, 2]
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_84 (LSTM)              (None, 5, 4)              96
#
#  dropout_84 (Dropout)        (None, 5, 4)              0
#
#  lstm_85 (LSTM)              (None, 5, 4)              144
#
#  dropout_85 (Dropout)        (None, 5, 4)              0
#
#  lstm_86 (LSTM)              (None, 5, 2)              56
#
#  dropout_86 (Dropout)        (None, 5, 2)              0
#
#  lstm_87 (LSTM)              (None, 2)                 40
#
#  dropout_87 (Dropout)        (None, 2)                 0
#
#  dense_8 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 339
# Trainable params: 339
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 9s - loss: 0.2584 - val_loss: 0.4545 - 9s/epoch - 2s/step
# Epoch 2/50
# 5/5 - 0s - loss: 0.2535 - val_loss: 0.4474 - 88ms/epoch - 18ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 0.2486 - val_loss: 0.4403 - 86ms/epoch - 17ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 0.2436 - val_loss: 0.4332 - 82ms/epoch - 16ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 0.2393 - val_loss: 0.4262 - 80ms/epoch - 16ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 0.2345 - val_loss: 0.4192 - 85ms/epoch - 17ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 0.2301 - val_loss: 0.4123 - 84ms/epoch - 17ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 0.2251 - val_loss: 0.4053 - 95ms/epoch - 19ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 0.2208 - val_loss: 0.3984 - 96ms/epoch - 19ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 0.2168 - val_loss: 0.3915 - 82ms/epoch - 16ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 0.2120 - val_loss: 0.3846 - 82ms/epoch - 16ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 0.2082 - val_loss: 0.3778 - 82ms/epoch - 16ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 0.2036 - val_loss: 0.3710 - 82ms/epoch - 16ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 0.1998 - val_loss: 0.3641 - 87ms/epoch - 17ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 0.1951 - val_loss: 0.3573 - 91ms/epoch - 18ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 0.1906 - val_loss: 0.3505 - 93ms/epoch - 19ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 0.1870 - val_loss: 0.3437 - 90ms/epoch - 18ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 0.1836 - val_loss: 0.3370 - 90ms/epoch - 18ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 0.1803 - val_loss: 0.3303 - 86ms/epoch - 17ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 0.1766 - val_loss: 0.3237 - 85ms/epoch - 17ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 0.1735 - val_loss: 0.3173 - 94ms/epoch - 19ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 0.1682 - val_loss: 0.3108 - 83ms/epoch - 17ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 0.1662 - val_loss: 0.3045 - 83ms/epoch - 17ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.1624 - val_loss: 0.2984 - 83ms/epoch - 17ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.1580 - val_loss: 0.2922 - 90ms/epoch - 18ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.1574 - val_loss: 0.2863 - 88ms/epoch - 18ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.1534 - val_loss: 0.2806 - 89ms/epoch - 18ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.1504 - val_loss: 0.2750 - 87ms/epoch - 17ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.1476 - val_loss: 0.2696 - 84ms/epoch - 17ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.1466 - val_loss: 0.2644 - 83ms/epoch - 17ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.1444 - val_loss: 0.2595 - 82ms/epoch - 16ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.1407 - val_loss: 0.2548 - 82ms/epoch - 16ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.1376 - val_loss: 0.2503 - 101ms/epoch - 20ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.1360 - val_loss: 0.2460 - 88ms/epoch - 18ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.1351 - val_loss: 0.2420 - 84ms/epoch - 17ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.1329 - val_loss: 0.2382 - 83ms/epoch - 17ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.1313 - val_loss: 0.2347 - 92ms/epoch - 18ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.1296 - val_loss: 0.2313 - 91ms/epoch - 18ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.1274 - val_loss: 0.2282 - 97ms/epoch - 19ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.1286 - val_loss: 0.2253 - 92ms/epoch - 18ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.1253 - val_loss: 0.2226 - 93ms/epoch - 19ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.1245 - val_loss: 0.2200 - 87ms/epoch - 17ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.1219 - val_loss: 0.2177 - 87ms/epoch - 17ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.1225 - val_loss: 0.2154 - 86ms/epoch - 17ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.1195 - val_loss: 0.2132 - 84ms/epoch - 17ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.1194 - val_loss: 0.2112 - 83ms/epoch - 17ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.1171 - val_loss: 0.2094 - 83ms/epoch - 17ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.1162 - val_loss: 0.2076 - 84ms/epoch - 17ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.1171 - val_loss: 0.2059 - 82ms/epoch - 16ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.1143 - val_loss: 0.2043 - 84ms/epoch - 17ms/step
# 20/20 [==============================] - 1s 3ms/step
# 9/9 [==============================] - 0s 2ms/step
# Train Score: 253.61 RMSE for 50 epochs
# Test Score: 607.75 RMSE for 50 epochs
# Training with LSTM layers: [2, 2]
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_88 (LSTM)              (None, 5, 2)              32
#
#  dropout_88 (Dropout)        (None, 5, 2)              0
#
#  lstm_89 (LSTM)              (None, 2)                 40
#
#  dropout_89 (Dropout)        (None, 2)                 0
#
#  dense_9 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 75
# Trainable params: 75
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 - 6s - loss: 0.1376 - val_loss: 0.3154 - 6s/epoch - 1s/step
# Epoch 2/50
# 5/5 - 0s - loss: 0.1335 - val_loss: 0.3069 - 61ms/epoch - 12ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 0.1292 - val_loss: 0.2986 - 61ms/epoch - 12ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 0.1235 - val_loss: 0.2903 - 60ms/epoch - 12ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 0.1198 - val_loss: 0.2822 - 59ms/epoch - 12ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 0.1164 - val_loss: 0.2743 - 59ms/epoch - 12ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 0.1107 - val_loss: 0.2666 - 57ms/epoch - 11ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 0.1093 - val_loss: 0.2591 - 59ms/epoch - 12ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 0.1046 - val_loss: 0.2518 - 83ms/epoch - 17ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 0.1001 - val_loss: 0.2447 - 65ms/epoch - 13ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 0.0985 - val_loss: 0.2378 - 62ms/epoch - 12ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 0.0959 - val_loss: 0.2311 - 60ms/epoch - 12ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 0.0911 - val_loss: 0.2246 - 61ms/epoch - 12ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 0.0904 - val_loss: 0.2182 - 60ms/epoch - 12ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 0.0869 - val_loss: 0.2122 - 62ms/epoch - 12ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 0.0833 - val_loss: 0.2063 - 65ms/epoch - 13ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 0.0825 - val_loss: 0.2006 - 64ms/epoch - 13ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 0.0786 - val_loss: 0.1951 - 63ms/epoch - 13ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 0.0765 - val_loss: 0.1897 - 60ms/epoch - 12ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 0.0751 - val_loss: 0.1846 - 58ms/epoch - 12ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 0.0727 - val_loss: 0.1796 - 59ms/epoch - 12ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 0.0734 - val_loss: 0.1749 - 57ms/epoch - 11ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 0.0716 - val_loss: 0.1705 - 57ms/epoch - 11ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 0.0687 - val_loss: 0.1663 - 59ms/epoch - 12ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 0.0688 - val_loss: 0.1623 - 60ms/epoch - 12ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 0.0676 - val_loss: 0.1585 - 59ms/epoch - 12ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 0.0638 - val_loss: 0.1549 - 65ms/epoch - 13ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 0.0651 - val_loss: 0.1516 - 63ms/epoch - 13ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 0.0610 - val_loss: 0.1484 - 61ms/epoch - 12ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 0.0626 - val_loss: 0.1455 - 56ms/epoch - 11ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 0.0608 - val_loss: 0.1427 - 59ms/epoch - 12ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.0620 - val_loss: 0.1401 - 59ms/epoch - 12ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.0586 - val_loss: 0.1378 - 65ms/epoch - 13ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.0599 - val_loss: 0.1356 - 63ms/epoch - 13ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.0600 - val_loss: 0.1337 - 66ms/epoch - 13ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.0573 - val_loss: 0.1319 - 61ms/epoch - 12ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.0589 - val_loss: 0.1303 - 60ms/epoch - 12ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.0578 - val_loss: 0.1288 - 58ms/epoch - 12ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.0583 - val_loss: 0.1276 - 60ms/epoch - 12ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.0579 - val_loss: 0.1263 - 59ms/epoch - 12ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.0568 - val_loss: 0.1252 - 57ms/epoch - 11ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.0577 - val_loss: 0.1243 - 56ms/epoch - 11ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.0559 - val_loss: 0.1234 - 56ms/epoch - 11ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.0560 - val_loss: 0.1226 - 56ms/epoch - 11ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.0564 - val_loss: 0.1220 - 59ms/epoch - 12ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.0556 - val_loss: 0.1214 - 59ms/epoch - 12ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.0530 - val_loss: 0.1207 - 59ms/epoch - 12ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.0540 - val_loss: 0.1201 - 57ms/epoch - 11ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.0526 - val_loss: 0.1196 - 57ms/epoch - 11ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.0548 - val_loss: 0.1191 - 58ms/epoch - 12ms/step
# 20/20 [==============================] - 1s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# Train Score: 232.15 RMSE for 50 epochs
# Test Score: 531.77 RMSE for 50 epochs
# Training for 100 epochs...
# Training with LSTM layers: [64, 64, 32, 32, 16, 16, 8, 8, 4, 4, 2, 2]
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_90 (LSTM)              (None, 5, 64)             16896
#
#  dropout_90 (Dropout)        (None, 5, 64)             0
#
#  lstm_91 (LSTM)              (None, 5, 64)             33024
#
#  dropout_91 (Dropout)        (None, 5, 64)             0
#
#  lstm_92 (LSTM)              (None, 5, 32)             12416
#
#  dropout_92 (Dropout)        (None, 5, 32)             0
#
#  lstm_93 (LSTM)              (None, 5, 32)             8320
#
#  dropout_93 (Dropout)        (None, 5, 32)             0
#
#  lstm_94 (LSTM)              (None, 5, 16)             3136
#
#  dropout_94 (Dropout)        (None, 5, 16)             0
#
#  lstm_95 (LSTM)              (None, 5, 16)             2112
#
#  dropout_95 (Dropout)        (None, 5, 16)             0
#
#  lstm_96 (LSTM)              (None, 5, 8)              800
#
#  dropout_96 (Dropout)        (None, 5, 8)              0
#
#  lstm_97 (LSTM)              (None, 5, 8)              544
#
#  dropout_97 (Dropout)        (None, 5, 8)              0
#
#  lstm_98 (LSTM)              (None, 5, 4)              208
#
#  dropout_98 (Dropout)        (None, 5, 4)              0
#
#  lstm_99 (LSTM)              (None, 5, 4)              144
#
#  dropout_99 (Dropout)        (None, 5, 4)              0
#
#  lstm_100 (LSTM)             (None, 5, 2)              56
#
#  dropout_100 (Dropout)       (None, 5, 2)              0
#
#  lstm_101 (LSTM)             (None, 2)                 40
#
#  dropout_101 (Dropout)       (None, 2)                 0
#
#  dense_10 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 77,699
# Trainable params: 77,699
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 5/5 - 26s - loss: 3.7556 - val_loss: 3.8674 - 26s/epoch - 5s/step
# Epoch 2/100
# 5/5 - 0s - loss: 3.6131 - val_loss: 3.7254 - 247ms/epoch - 49ms/step
# Epoch 3/100
# 5/5 - 0s - loss: 3.4751 - val_loss: 3.5880 - 243ms/epoch - 49ms/step
# Epoch 4/100
# 5/5 - 0s - loss: 3.3418 - val_loss: 3.4553 - 242ms/epoch - 48ms/step
# Epoch 5/100
# 5/5 - 0s - loss: 3.2130 - val_loss: 3.3274 - 253ms/epoch - 51ms/step
# Epoch 6/100
# 5/5 - 0s - loss: 3.0895 - val_loss: 3.2041 - 244ms/epoch - 49ms/step
# Epoch 7/100
# 5/5 - 0s - loss: 2.9703 - val_loss: 3.0855 - 238ms/epoch - 48ms/step
# Epoch 8/100
# 5/5 - 0s - loss: 2.8558 - val_loss: 2.9714 - 237ms/epoch - 47ms/step
# Epoch 9/100
# 5/5 - 0s - loss: 2.7458 - val_loss: 2.8617 - 239ms/epoch - 48ms/step
# Epoch 10/100
# 5/5 - 0s - loss: 2.6401 - val_loss: 2.7562 - 242ms/epoch - 48ms/step
# Epoch 11/100
# 5/5 - 0s - loss: 2.5392 - val_loss: 2.6548 - 243ms/epoch - 49ms/step
# Epoch 12/100
# 5/5 - 0s - loss: 2.4407 - val_loss: 2.5573 - 243ms/epoch - 49ms/step
# Epoch 13/100
# 5/5 - 0s - loss: 2.3480 - val_loss: 2.4636 - 234ms/epoch - 47ms/step
# Epoch 14/100
# 5/5 - 0s - loss: 2.2579 - val_loss: 2.3734 - 240ms/epoch - 48ms/step
# Epoch 15/100
# 5/5 - 0s - loss: 2.1722 - val_loss: 2.2868 - 249ms/epoch - 50ms/step
# Epoch 16/100
# 5/5 - 0s - loss: 2.0893 - val_loss: 2.2035 - 235ms/epoch - 47ms/step
# Epoch 17/100
# 5/5 - 0s - loss: 2.0092 - val_loss: 2.1233 - 259ms/epoch - 52ms/step
# Epoch 18/100
# 5/5 - 0s - loss: 1.9333 - val_loss: 2.0462 - 238ms/epoch - 48ms/step
# Epoch 19/100
# 5/5 - 0s - loss: 1.8596 - val_loss: 1.9721 - 260ms/epoch - 52ms/step
# Epoch 20/100
# 5/5 - 0s - loss: 1.7900 - val_loss: 1.9008 - 248ms/epoch - 50ms/step
# Epoch 21/100
# 5/5 - 0s - loss: 1.7224 - val_loss: 1.8322 - 234ms/epoch - 47ms/step
# Epoch 22/100
# 5/5 - 0s - loss: 1.6578 - val_loss: 1.7661 - 233ms/epoch - 47ms/step
# Epoch 23/100
# 5/5 - 0s - loss: 1.5948 - val_loss: 1.7027 - 233ms/epoch - 47ms/step
# Epoch 24/100
# 5/5 - 0s - loss: 1.5364 - val_loss: 1.6417 - 254ms/epoch - 51ms/step
# Epoch 25/100
# 5/5 - 0s - loss: 1.4780 - val_loss: 1.5829 - 242ms/epoch - 48ms/step
# Epoch 26/100
# 5/5 - 0s - loss: 1.4245 - val_loss: 1.5266 - 242ms/epoch - 48ms/step
# Epoch 27/100
# 5/5 - 0s - loss: 1.3710 - val_loss: 1.4723 - 242ms/epoch - 48ms/step
# Epoch 28/100
# 5/5 - 0s - loss: 1.3200 - val_loss: 1.4202 - 242ms/epoch - 48ms/step
# Epoch 29/100
# 5/5 - 0s - loss: 1.2708 - val_loss: 1.3701 - 242ms/epoch - 48ms/step
# Epoch 30/100
# 5/5 - 0s - loss: 1.2252 - val_loss: 1.3220 - 252ms/epoch - 50ms/step
# Epoch 31/100
# 5/5 - 0s - loss: 1.1800 - val_loss: 1.2757 - 250ms/epoch - 50ms/step
# Epoch 32/100
# 5/5 - 0s - loss: 1.1367 - val_loss: 1.2314 - 296ms/epoch - 59ms/step
# Epoch 33/100
# 5/5 - 0s - loss: 1.0964 - val_loss: 1.1888 - 260ms/epoch - 52ms/step
# Epoch 34/100
# 5/5 - 0s - loss: 1.0569 - val_loss: 1.1480 - 254ms/epoch - 51ms/step
# Epoch 35/100
# 5/5 - 0s - loss: 1.0199 - val_loss: 1.1089 - 248ms/epoch - 50ms/step
# Epoch 36/100
# 5/5 - 0s - loss: 0.9828 - val_loss: 1.0715 - 249ms/epoch - 50ms/step
# Epoch 37/100
# 5/5 - 0s - loss: 0.9476 - val_loss: 1.0356 - 252ms/epoch - 50ms/step
# Epoch 38/100
# 5/5 - 0s - loss: 0.9154 - val_loss: 1.0013 - 237ms/epoch - 47ms/step
# Epoch 39/100
# 5/5 - 0s - loss: 0.8823 - val_loss: 0.9684 - 250ms/epoch - 50ms/step
# Epoch 40/100
# 5/5 - 0s - loss: 0.8536 - val_loss: 0.9370 - 241ms/epoch - 48ms/step
# Epoch 41/100
# 5/5 - 0s - loss: 0.8245 - val_loss: 0.9069 - 251ms/epoch - 50ms/step
# Epoch 42/100
# 5/5 - 0s - loss: 0.7949 - val_loss: 0.8782 - 262ms/epoch - 52ms/step
# Epoch 43/100
# 5/5 - 0s - loss: 0.7689 - val_loss: 0.8507 - 248ms/epoch - 50ms/step
# Epoch 44/100
# 5/5 - 0s - loss: 0.7433 - val_loss: 0.8243 - 242ms/epoch - 48ms/step
# Epoch 45/100
# 5/5 - 0s - loss: 0.7183 - val_loss: 0.7990 - 236ms/epoch - 47ms/step
# Epoch 46/100
# 5/5 - 0s - loss: 0.6938 - val_loss: 0.7748 - 260ms/epoch - 52ms/step
# Epoch 47/100
# 5/5 - 0s - loss: 0.6710 - val_loss: 0.7515 - 254ms/epoch - 51ms/step
# Epoch 48/100
# 5/5 - 0s - loss: 0.6503 - val_loss: 0.7293 - 247ms/epoch - 49ms/step
# Epoch 49/100
# 5/5 - 0s - loss: 0.6285 - val_loss: 0.7081 - 276ms/epoch - 55ms/step
# Epoch 50/100
# 5/5 - 0s - loss: 0.6084 - val_loss: 0.6877 - 247ms/epoch - 49ms/step
# Epoch 51/100
# 5/5 - 0s - loss: 0.5879 - val_loss: 0.6683 - 244ms/epoch - 49ms/step
# Epoch 52/100
# ...
# Epoch 142/150
# 5/5 - 0s - loss: 0.0462 - val_loss: 0.1310 - 84ms/epoch - 17ms/step
# Epoch 143/150
# 5/5 - 0s - loss: 0.0443 - val_loss: 0.1306 - 86ms/epoch - 17ms/step
# Epoch 144/150
# 5/5 - 0s - loss: 0.0444 - val_loss: 0.1300 - 91ms/epoch - 18ms/step
# Epoch 145/150
# 5/5 - 0s - loss: 0.0444 - val_loss: 0.1295 - 103ms/epoch - 21ms/step
# Epoch 146/150
# 5/5 - 0s - loss: 0.0448 - val_loss: 0.1291 - 88ms/epoch - 18ms/step
# Epoch 147/150
# 5/5 - 0s - loss: 0.0431 - val_loss: 0.1288 - 94ms/epoch - 19ms/step
# Epoch 148/150
# 5/5 - 0s - loss: 0.0435 - val_loss: 0.1286 - 93ms/epoch - 19ms/step
# Epoch 149/150
# 5/5 - 0s - loss: 0.0430 - val_loss: 0.1283 - 86ms/epoch - 17ms/step
# Epoch 150/150
# 5/5 - 0s - loss: 0.0426 - val_loss: 0.1281 - 87ms/epoch - 17ms/step
# 20/20 [==============================] - 1s 3ms/step
# 9/9 [==============================] - 0s 2ms/step
# Train Score: 247.23 RMSE for 150 epochs
# Test Score: 583.64 RMSE for 150 epochs
# Training with LSTM layers: [2, 2]
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_172 (LSTM)             (None, 5, 2)              32
#
#  dropout_172 (Dropout)       (None, 5, 2)              0
#
#  lstm_173 (LSTM)             (None, 2)                 40
#
#  dropout_173 (Dropout)       (None, 2)                 0
#
#  dense_21 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 75
# Trainable params: 75
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 5/5 - 4s - loss: 0.1352 - val_loss: 0.3028 - 4s/epoch - 879ms/step
# Epoch 2/150
# 5/5 - 0s - loss: 0.1324 - val_loss: 0.2968 - 66ms/epoch - 13ms/step
# Epoch 3/150
# 5/5 - 0s - loss: 0.1285 - val_loss: 0.2909 - 63ms/epoch - 13ms/step
# Epoch 4/150
# 5/5 - 0s - loss: 0.1251 - val_loss: 0.2850 - 61ms/epoch - 12ms/step
# Epoch 5/150
# 5/5 - 0s - loss: 0.1216 - val_loss: 0.2792 - 57ms/epoch - 11ms/step
# Epoch 6/150
# 5/5 - 0s - loss: 0.1194 - val_loss: 0.2734 - 61ms/epoch - 12ms/step
# Epoch 7/150
# 5/5 - 0s - loss: 0.1165 - val_loss: 0.2678 - 58ms/epoch - 12ms/step
# Epoch 8/150
# 5/5 - 0s - loss: 0.1140 - val_loss: 0.2623 - 57ms/epoch - 11ms/step
# Epoch 9/150
# 5/5 - 0s - loss: 0.1096 - val_loss: 0.2567 - 60ms/epoch - 12ms/step
# Epoch 10/150
# 5/5 - 0s - loss: 0.1084 - val_loss: 0.2513 - 59ms/epoch - 12ms/step
# Epoch 11/150
# 5/5 - 0s - loss: 0.1044 - val_loss: 0.2459 - 59ms/epoch - 12ms/step
# Epoch 12/150
# 5/5 - 0s - loss: 0.1027 - val_loss: 0.2406 - 60ms/epoch - 12ms/step
# Epoch 13/150
# 5/5 - 0s - loss: 0.0982 - val_loss: 0.2353 - 60ms/epoch - 12ms/step
# Epoch 14/150
# 5/5 - 0s - loss: 0.0957 - val_loss: 0.2301 - 57ms/epoch - 11ms/step
# Epoch 15/150
# 5/5 - 0s - loss: 0.0945 - val_loss: 0.2249 - 62ms/epoch - 12ms/step
# Epoch 16/150
# 5/5 - 0s - loss: 0.0913 - val_loss: 0.2198 - 82ms/epoch - 16ms/step
# Epoch 17/150
# 5/5 - 0s - loss: 0.0899 - val_loss: 0.2149 - 64ms/epoch - 13ms/step
# Epoch 18/150
# 5/5 - 0s - loss: 0.0887 - val_loss: 0.2100 - 59ms/epoch - 12ms/step
# Epoch 19/150
# 5/5 - 0s - loss: 0.0871 - val_loss: 0.2054 - 56ms/epoch - 11ms/step
# Epoch 20/150
# 5/5 - 0s - loss: 0.0841 - val_loss: 0.2008 - 61ms/epoch - 12ms/step
# Epoch 21/150
# 5/5 - 0s - loss: 0.0811 - val_loss: 0.1963 - 58ms/epoch - 12ms/step
# Epoch 22/150
# 5/5 - 0s - loss: 0.0804 - val_loss: 0.1920 - 58ms/epoch - 12ms/step
# Epoch 23/150
# 5/5 - 0s - loss: 0.0802 - val_loss: 0.1878 - 56ms/epoch - 11ms/step
# Epoch 24/150
# 5/5 - 0s - loss: 0.0774 - val_loss: 0.1837 - 58ms/epoch - 12ms/step
# Epoch 25/150
# 5/5 - 0s - loss: 0.0742 - val_loss: 0.1797 - 59ms/epoch - 12ms/step
# Epoch 26/150
# 5/5 - 0s - loss: 0.0753 - val_loss: 0.1759 - 63ms/epoch - 13ms/step
# Epoch 27/150
# 5/5 - 0s - loss: 0.0724 - val_loss: 0.1722 - 65ms/epoch - 13ms/step
# Epoch 28/150
# 5/5 - 0s - loss: 0.0707 - val_loss: 0.1686 - 66ms/epoch - 13ms/step
# Epoch 29/150
# 5/5 - 0s - loss: 0.0704 - val_loss: 0.1651 - 64ms/epoch - 13ms/step
# Epoch 30/150
# 5/5 - 0s - loss: 0.0683 - val_loss: 0.1618 - 64ms/epoch - 13ms/step
# Epoch 31/150
# 5/5 - 0s - loss: 0.0667 - val_loss: 0.1587 - 62ms/epoch - 12ms/step
# Epoch 32/150
# 5/5 - 0s - loss: 0.0651 - val_loss: 0.1557 - 63ms/epoch - 13ms/step
# Epoch 33/150
# 5/5 - 0s - loss: 0.0657 - val_loss: 0.1528 - 59ms/epoch - 12ms/step
# Epoch 34/150
# 5/5 - 0s - loss: 0.0643 - val_loss: 0.1500 - 58ms/epoch - 12ms/step
# Epoch 35/150
# 5/5 - 0s - loss: 0.0623 - val_loss: 0.1474 - 57ms/epoch - 11ms/step
# Epoch 36/150
# 5/5 - 0s - loss: 0.0593 - val_loss: 0.1448 - 59ms/epoch - 12ms/step
# Epoch 37/150
# 5/5 - 0s - loss: 0.0624 - val_loss: 0.1424 - 58ms/epoch - 12ms/step
# Epoch 38/150
# 5/5 - 0s - loss: 0.0627 - val_loss: 0.1401 - 59ms/epoch - 12ms/step
# Epoch 39/150
# 5/5 - 0s - loss: 0.0621 - val_loss: 0.1380 - 59ms/epoch - 12ms/step
# Epoch 40/150
# 5/5 - 0s - loss: 0.0604 - val_loss: 0.1361 - 57ms/epoch - 11ms/step
# Epoch 41/150
# 5/5 - 0s - loss: 0.0607 - val_loss: 0.1342 - 58ms/epoch - 12ms/step
# Epoch 42/150
# 5/5 - 0s - loss: 0.0604 - val_loss: 0.1326 - 57ms/epoch - 11ms/step
# Epoch 43/150
# 5/5 - 0s - loss: 0.0574 - val_loss: 0.1311 - 60ms/epoch - 12ms/step
# Epoch 44/150
# 5/5 - 0s - loss: 0.0589 - val_loss: 0.1297 - 60ms/epoch - 12ms/step
# Epoch 45/150
# 5/5 - 0s - loss: 0.0571 - val_loss: 0.1283 - 58ms/epoch - 12ms/step
# Epoch 46/150
# 5/5 - 0s - loss: 0.0565 - val_loss: 0.1271 - 58ms/epoch - 12ms/step
# Epoch 47/150
# 5/5 - 0s - loss: 0.0574 - val_loss: 0.1261 - 58ms/epoch - 12ms/step
# Epoch 48/150
# 5/5 - 0s - loss: 0.0560 - val_loss: 0.1250 - 56ms/epoch - 11ms/step
# Epoch 49/150
# 5/5 - 0s - loss: 0.0574 - val_loss: 0.1240 - 67ms/epoch - 13ms/step
# Epoch 50/150
# 5/5 - 0s - loss: 0.0553 - val_loss: 0.1232 - 61ms/epoch - 12ms/step
# Epoch 51/150
# 5/5 - 0s - loss: 0.0536 - val_loss: 0.1223 - 62ms/epoch - 12ms/step
# Epoch 52/150
# 5/5 - 0s - loss: 0.0560 - val_loss: 0.1217 - 60ms/epoch - 12ms/step
# Epoch 53/150
# 5/5 - 0s - loss: 0.0544 - val_loss: 0.1210 - 68ms/epoch - 14ms/step
# Epoch 54/150
# 5/5 - 0s - loss: 0.0552 - val_loss: 0.1204 - 73ms/epoch - 15ms/step
# Epoch 55/150
# 5/5 - 0s - loss: 0.0539 - val_loss: 0.1199 - 63ms/epoch - 13ms/step
# Epoch 56/150
# 5/5 - 0s - loss: 0.0530 - val_loss: 0.1194 - 58ms/epoch - 12ms/step
# Epoch 57/150
# 5/5 - 0s - loss: 0.0536 - val_loss: 0.1189 - 56ms/epoch - 11ms/step
# Epoch 58/150
# 5/5 - 0s - loss: 0.0523 - val_loss: 0.1184 - 56ms/epoch - 11ms/step
# Epoch 59/150
# 5/5 - 0s - loss: 0.0515 - val_loss: 0.1179 - 62ms/epoch - 12ms/step
# Epoch 60/150
# 5/5 - 0s - loss: 0.0528 - val_loss: 0.1174 - 58ms/epoch - 12ms/step
# Epoch 61/150
# 5/5 - 0s - loss: 0.0508 - val_loss: 0.1168 - 57ms/epoch - 11ms/step
# Epoch 62/150
# 5/5 - 0s - loss: 0.0496 - val_loss: 0.1162 - 61ms/epoch - 12ms/step
# Epoch 63/150
# 5/5 - 0s - loss: 0.0522 - val_loss: 0.1157 - 64ms/epoch - 13ms/step
# Epoch 64/150
# 5/5 - 0s - loss: 0.0517 - val_loss: 0.1152 - 61ms/epoch - 12ms/step
# Epoch 65/150
# 5/5 - 0s - loss: 0.0498 - val_loss: 0.1148 - 55ms/epoch - 11ms/step
# Epoch 66/150
# 5/5 - 0s - loss: 0.0496 - val_loss: 0.1145 - 57ms/epoch - 11ms/step
# Epoch 67/150
# 5/5 - 0s - loss: 0.0516 - val_loss: 0.1142 - 56ms/epoch - 11ms/step
# Epoch 68/150
# 5/5 - 0s - loss: 0.0476 - val_loss: 0.1139 - 59ms/epoch - 12ms/step
# Epoch 69/150
# 5/5 - 0s - loss: 0.0491 - val_loss: 0.1136 - 58ms/epoch - 12ms/step
# Epoch 70/150
# 5/5 - 0s - loss: 0.0468 - val_loss: 0.1132 - 56ms/epoch - 11ms/step
# Epoch 71/150
# 5/5 - 0s - loss: 0.0478 - val_loss: 0.1128 - 56ms/epoch - 11ms/step
# Epoch 72/150
# 5/5 - 0s - loss: 0.0462 - val_loss: 0.1124 - 61ms/epoch - 12ms/step
# Epoch 73/150
# 5/5 - 0s - loss: 0.0490 - val_loss: 0.1120 - 59ms/epoch - 12ms/step
# Epoch 74/150
# 5/5 - 0s - loss: 0.0469 - val_loss: 0.1117 - 56ms/epoch - 11ms/step
# Epoch 75/150
# 5/5 - 0s - loss: 0.0477 - val_loss: 0.1115 - 59ms/epoch - 12ms/step
# Epoch 76/150
# 5/5 - 0s - loss: 0.0465 - val_loss: 0.1112 - 82ms/epoch - 16ms/step
# Epoch 77/150
# 5/5 - 0s - loss: 0.0452 - val_loss: 0.1109 - 61ms/epoch - 12ms/step
# Epoch 78/150
# 5/5 - 0s - loss: 0.0472 - val_loss: 0.1106 - 57ms/epoch - 11ms/step
# Epoch 79/150
# 5/5 - 0s - loss: 0.0474 - val_loss: 0.1104 - 56ms/epoch - 11ms/step
# Epoch 80/150
# 5/5 - 0s - loss: 0.0464 - val_loss: 0.1102 - 57ms/epoch - 11ms/step
# Epoch 81/150
# 5/5 - 0s - loss: 0.0455 - val_loss: 0.1100 - 55ms/epoch - 11ms/step
# Epoch 82/150
# 5/5 - 0s - loss: 0.0461 - val_loss: 0.1099 - 57ms/epoch - 11ms/step
# Epoch 83/150
# 5/5 - 0s - loss: 0.0445 - val_loss: 0.1097 - 56ms/epoch - 11ms/step
# Epoch 84/150
# 5/5 - 0s - loss: 0.0440 - val_loss: 0.1095 - 56ms/epoch - 11ms/step
# Epoch 85/150
# 5/5 - 0s - loss: 0.0423 - val_loss: 0.1091 - 56ms/epoch - 11ms/step
# Epoch 86/150
# 5/5 - 0s - loss: 0.0435 - val_loss: 0.1088 - 56ms/epoch - 11ms/step
# Epoch 87/150
# 5/5 - 0s - loss: 0.0432 - val_loss: 0.1086 - 60ms/epoch - 12ms/step
# Epoch 88/150
# 5/5 - 0s - loss: 0.0433 - val_loss: 0.1084 - 58ms/epoch - 12ms/step
# Epoch 89/150
# 5/5 - 0s - loss: 0.0433 - val_loss: 0.1083 - 58ms/epoch - 12ms/step
# Epoch 90/150
# 5/5 - 0s - loss: 0.0417 - val_loss: 0.1081 - 61ms/epoch - 12ms/step
# Epoch 91/150
# 5/5 - 0s - loss: 0.0431 - val_loss: 0.1078 - 64ms/epoch - 13ms/step
# Epoch 92/150
# 5/5 - 0s - loss: 0.0421 - val_loss: 0.1074 - 61ms/epoch - 12ms/step
# Epoch 93/150
# 5/5 - 0s - loss: 0.0400 - val_loss: 0.1072 - 59ms/epoch - 12ms/step
# Epoch 94/150
# 5/5 - 0s - loss: 0.0406 - val_loss: 0.1069 - 57ms/epoch - 11ms/step
# Epoch 95/150
# 5/5 - 0s - loss: 0.0425 - val_loss: 0.1066 - 56ms/epoch - 11ms/step
# Epoch 96/150
# 5/5 - 0s - loss: 0.0412 - val_loss: 0.1064 - 58ms/epoch - 12ms/step
# Epoch 97/150
# 5/5 - 0s - loss: 0.0391 - val_loss: 0.1063 - 57ms/epoch - 11ms/step
# Epoch 98/150
# 5/5 - 0s - loss: 0.0417 - val_loss: 0.1061 - 56ms/epoch - 11ms/step
# Epoch 99/150
# 5/5 - 0s - loss: 0.0383 - val_loss: 0.1060 - 57ms/epoch - 11ms/step
# Epoch 100/150
# 5/5 - 0s - loss: 0.0418 - val_loss: 0.1057 - 60ms/epoch - 12ms/step
# Epoch 101/150
# 5/5 - 0s - loss: 0.0406 - val_loss: 0.1057 - 59ms/epoch - 12ms/step
# Epoch 102/150
# 5/5 - 0s - loss: 0.0394 - val_loss: 0.1055 - 57ms/epoch - 11ms/step
# Epoch 103/150
# 5/5 - 0s - loss: 0.0384 - val_loss: 0.1052 - 56ms/epoch - 11ms/step
# Epoch 104/150
# 5/5 - 0s - loss: 0.0401 - val_loss: 0.1050 - 56ms/epoch - 11ms/step
# Epoch 105/150
# 5/5 - 0s - loss: 0.0392 - val_loss: 0.1048 - 56ms/epoch - 11ms/step
# Epoch 106/150
# 5/5 - 0s - loss: 0.0395 - val_loss: 0.1047 - 54ms/epoch - 11ms/step
# Epoch 107/150
# 5/5 - 0s - loss: 0.0380 - val_loss: 0.1045 - 56ms/epoch - 11ms/step
# Epoch 108/150
# 5/5 - 0s - loss: 0.0404 - val_loss: 0.1042 - 57ms/epoch - 11ms/step
# Epoch 109/150
# 5/5 - 0s - loss: 0.0393 - val_loss: 0.1042 - 57ms/epoch - 11ms/step
# Epoch 110/150
# 5/5 - 0s - loss: 0.0374 - val_loss: 0.1041 - 60ms/epoch - 12ms/step
# Epoch 111/150
# 5/5 - 0s - loss: 0.0380 - val_loss: 0.1040 - 57ms/epoch - 11ms/step
# Epoch 112/150
# 5/5 - 0s - loss: 0.0372 - val_loss: 0.1038 - 55ms/epoch - 11ms/step
# Epoch 113/150
# 5/5 - 0s - loss: 0.0376 - val_loss: 0.1037 - 55ms/epoch - 11ms/step
# Epoch 114/150
# 5/5 - 0s - loss: 0.0380 - val_loss: 0.1036 - 57ms/epoch - 11ms/step
# Epoch 115/150
# 5/5 - 0s - loss: 0.0369 - val_loss: 0.1035 - 56ms/epoch - 11ms/step
# Epoch 116/150
# 5/5 - 0s - loss: 0.0365 - val_loss: 0.1034 - 88ms/epoch - 18ms/step
# Epoch 117/150
# 5/5 - 0s - loss: 0.0360 - val_loss: 0.1032 - 70ms/epoch - 14ms/step
# Epoch 118/150
# 5/5 - 0s - loss: 0.0366 - val_loss: 0.1031 - 59ms/epoch - 12ms/step
# Epoch 119/150
# 5/5 - 0s - loss: 0.0359 - val_loss: 0.1029 - 56ms/epoch - 11ms/step
# Epoch 120/150
# 5/5 - 0s - loss: 0.0349 - val_loss: 0.1027 - 57ms/epoch - 11ms/step
# Epoch 121/150
# 5/5 - 0s - loss: 0.0349 - val_loss: 0.1026 - 56ms/epoch - 11ms/step
# Epoch 122/150
# 5/5 - 0s - loss: 0.0357 - val_loss: 0.1025 - 59ms/epoch - 12ms/step
# Epoch 123/150
# 5/5 - 0s - loss: 0.0341 - val_loss: 0.1024 - 56ms/epoch - 11ms/step
# Epoch 124/150
# 5/5 - 0s - loss: 0.0348 - val_loss: 0.1024 - 57ms/epoch - 11ms/step
# Epoch 125/150
# 5/5 - 0s - loss: 0.0341 - val_loss: 0.1022 - 56ms/epoch - 11ms/step
# Epoch 126/150
# 5/5 - 0s - loss: 0.0353 - val_loss: 0.1021 - 60ms/epoch - 12ms/step
# Epoch 127/150
# 5/5 - 0s - loss: 0.0357 - val_loss: 0.1021 - 58ms/epoch - 12ms/step
# Epoch 128/150
# 5/5 - 0s - loss: 0.0344 - val_loss: 0.1021 - 57ms/epoch - 11ms/step
# Epoch 129/150
# 5/5 - 0s - loss: 0.0341 - val_loss: 0.1018 - 56ms/epoch - 11ms/step
# Epoch 130/150
# 5/5 - 0s - loss: 0.0331 - val_loss: 0.1015 - 57ms/epoch - 11ms/step
# Epoch 131/150
# 5/5 - 0s - loss: 0.0337 - val_loss: 0.1011 - 56ms/epoch - 11ms/step
# Epoch 132/150
# 5/5 - 0s - loss: 0.0339 - val_loss: 0.1006 - 57ms/epoch - 11ms/step
# Epoch 133/150
# 5/5 - 0s - loss: 0.0337 - val_loss: 0.1005 - 56ms/epoch - 11ms/step
# Epoch 134/150
# 5/5 - 0s - loss: 0.0336 - val_loss: 0.1004 - 57ms/epoch - 11ms/step
# Epoch 135/150
# 5/5 - 0s - loss: 0.0326 - val_loss: 0.1004 - 56ms/epoch - 11ms/step
# Epoch 136/150
# 5/5 - 0s - loss: 0.0322 - val_loss: 0.1006 - 58ms/epoch - 12ms/step
# Epoch 137/150
# 5/5 - 0s - loss: 0.0317 - val_loss: 0.1003 - 61ms/epoch - 12ms/step
# Epoch 138/150
# 5/5 - 0s - loss: 0.0326 - val_loss: 0.1003 - 59ms/epoch - 12ms/step
# Epoch 139/150
# 5/5 - 0s - loss: 0.0323 - val_loss: 0.1002 - 57ms/epoch - 11ms/step
# Epoch 140/150
# 5/5 - 0s - loss: 0.0319 - val_loss: 0.1002 - 56ms/epoch - 11ms/step
# Epoch 141/150
# 5/5 - 0s - loss: 0.0323 - val_loss: 0.1000 - 58ms/epoch - 12ms/step
# Epoch 142/150
# 5/5 - 0s - loss: 0.0319 - val_loss: 0.1000 - 56ms/epoch - 11ms/step
# Epoch 143/150
# 5/5 - 0s - loss: 0.0322 - val_loss: 0.0999 - 58ms/epoch - 12ms/step
# Epoch 144/150
# 5/5 - 0s - loss: 0.0315 - val_loss: 0.1000 - 58ms/epoch - 12ms/step
# Epoch 145/150
# 5/5 - 0s - loss: 0.0314 - val_loss: 0.1002 - 76ms/epoch - 15ms/step
# Epoch 146/150
# 5/5 - 0s - loss: 0.0311 - val_loss: 0.0998 - 64ms/epoch - 13ms/step
# Epoch 147/150
# 5/5 - 0s - loss: 0.0313 - val_loss: 0.0997 - 57ms/epoch - 11ms/step
# Epoch 148/150
# 5/5 - 0s - loss: 0.0322 - val_loss: 0.0996 - 56ms/epoch - 11ms/step
# Epoch 149/150
# 5/5 - 0s - loss: 0.0303 - val_loss: 0.0997 - 56ms/epoch - 11ms/step
# Epoch 150/150
# 5/5 - 0s - loss: 0.0306 - val_loss: 0.0996 - 58ms/epoch - 12ms/step
# 20/20 [==============================] - 1s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# Train Score: 232.94 RMSE for 150 epochs
# Test Score: 529.53 RMSE for 150 epochs
# Text(0.5, 1.0, 'Model loss progress during training and validation')
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'Training and Validation Loss')
#                                                     Train RMSE   Test RMSE
# 50 epochs, [64, 64, 32, 32, 16, 16, 8, 8, 4, 4,...  259.676381  623.160784
# 50 epochs, [32, 32, 16, 16, 8, 8, 4, 4, 2, 2] l...  250.606108  598.478416
# 50 epochs, [16, 16, 8, 8, 4, 4, 2, 2] layers        252.354172  604.228990
# 50 epochs, [8, 8, 4, 4, 2, 2] layers                249.929900  596.014910
# 50 epochs, [4, 4, 2, 2] layers                      253.608967  607.754025
# 50 epochs, [2, 2] layers                            232.152180  531.766474
# 100 epochs, [64, 64, 32, 32, 16, 16, 8, 8, 4, 4...  248.348577  589.423654
# 100 epochs, [32, 32, 16, 16, 8, 8, 4, 4, 2, 2] ...  248.264046  589.026611
# 100 epochs, [16, 16, 8, 8, 4, 4, 2, 2] layers       251.773589  602.402563
# 100 epochs, [8, 8, 4, 4, 2, 2] layers               248.544594  590.322206
# 100 epochs, [4, 4, 2, 2] layers                     248.240451  589.434963
# 100 epochs, [2, 2] layers                           233.831133  538.571117
# 150 epochs, [64, 64, 32, 32, 16, 16, 8, 8, 4, 4...  247.154620  583.111153
# 150 epochs, [32, 32, 16, 16, 8, 8, 4, 4, 2, 2] ...  247.487437  585.052892
# 150 epochs, [16, 16, 8, 8, 4, 4, 2, 2] layers       247.234510  583.594197
# 150 epochs, [8, 8, 4, 4, 2, 2] layers               247.318089  584.087933
# 150 epochs, [4, 4, 2, 2] layers                     247.234962  583.641125
# 150 epochs, [2, 2] layers                           232.941357  529.532432

# %% [markdown]
# <h4>Forecast the results</h4>

# %%
# Add check for 'RATE_actual' values to avoid division by zero
def compute_accuracy(row):
    if row['RATE_actual'] == 0:
        return np.nan
    else:
        error = abs(row['RATE_actual'] - row['RATE_forecasted'])
        error_proportion = error / row['RATE_actual']
        return (1 - error_proportion) * 100

def forecast_next_weeks(model, look_back, scaler, last_values, n_weeks):
    forecast = []
    for _ in range(n_weeks):
        last_values_2d = np.array(last_values[-look_back:]).reshape(-1, 1)
        input_values_scaled = scaler.transform(last_values_2d)
        input_values_scaled = input_values_scaled.reshape((1, look_back, 1))

        prediction = model.predict(input_values_scaled)
        prediction = scaler.inverse_transform(prediction)
        forecast.append(prediction[0][0])
        last_values.append(prediction[0][0])

    return forecast

# %%
weeks = 12

# Ensure that 'YearMonthWeek' is a datetime object
agg_df['YearMonthWeek'] = pd.to_datetime(agg_df['YearMonthWeek'])
last_date = agg_df['YearMonthWeek'].iloc[-1]

last_values = list(agg_df['Rate'].values[-look_back:])
forecasted_values = forecast_next_weeks(model, look_back, scaler_rate, last_values, weeks)
forecasted_dates = pd.date_range(start=last_date, periods=weeks+1, freq='W')[1:]

df_forecasted = pd.DataFrame({
    'POD': forecasted_dates,
    'RATE': forecasted_values
})

df_forecasted["RATE"] = df_forecasted["RATE"].round(2)

df_forecasted.head(5)
df_forecasted.tail(5)
df_forecasted.info()
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - ETA: 0s
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Aloysius Wong\Documents\GitHub\Cost-Rate-Analysis\env\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#          POD        RATE
# 0 2023-02-26  780.580017
# 1 2023-03-05  761.580017
# 2 2023-03-12  740.460022
# 3 2023-03-19  726.599976
# 4 2023-03-26  716.119995
#           POD        RATE
# 7  2023-04-16  702.739990
# 8  2023-04-23  701.929993
# 9  2023-04-30  701.390015
# 10 2023-05-07  701.070007
# 11 2023-05-14  700.979980
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POD     12 non-null     datetime64[ns]
#  1   RATE    12 non-null     float32
# dtypes: datetime64[ns](1), float32(1)
# memory usage: 272.0 bytes

# %% [markdown]
# <h4>Comparing with actual updated against forecasted</h4>

# %%
comparison_df = pd.DataFrame(columns=['WeekStart', 'WeekEnd', 'POD_actual', 'RATE_forecasted', 'RATE_actual'])
df_forecasted['WeekEnd'] = df_forecasted['POD'] + pd.to_timedelta(7, unit='d')  

for _, row in df_forecasted.iterrows():
    mask = (new_dates_df['POD'] >= row['POD']) & (new_dates_df['POD'] < row['WeekEnd'])
    actual_dates_within_week = new_dates_df[mask]

    for _, actual_row in actual_dates_within_week.iterrows():
        comparison_df = comparison_df.append({
            'WeekStart': row['POD'],
            'WeekEnd': row['WeekEnd'],
            'POD_actual': actual_row['POD'],
            'RATE_forecasted': row['RATE'],
            'RATE_actual': actual_row['RATE']
        }, ignore_index=True)

# Remove duplicates
comparison_df = comparison_df.drop_duplicates(subset=['POD_actual', 'RATE_forecasted', 'RATE_actual']).reset_index(drop=True)

# Compute accuracy
comparison_df['accuracy'] = comparison_df.apply(compute_accuracy, axis=1)
comparison_df = comparison_df.dropna(subset=['accuracy'])

total_mean_accuracy = comparison_df['accuracy'].mean()
comparison_df
print(f'The mean accuracy is {total_mean_accuracy:.2f}%\n')
# Out:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_21912\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
#     WeekStart    WeekEnd POD_actual  RATE_forecasted  RATE_actual   accuracy
# 0  2023-02-26 2023-03-05 2023-03-02       780.580017       1000.0  78.058002
# 1  2023-03-05 2023-03-12 2023-03-10       761.580017       1000.0  76.158002
# 2  2023-03-12 2023-03-19 2023-03-16       740.460022       1000.0  74.046002
# 3  2023-03-19 2023-03-26 2023-03-21       726.599976        600.0  78.900004
# 4  2023-03-26 2023-04-02 2023-03-26       716.119995        600.0  80.646667
# 5  2023-03-26 2023-04-02 2023-03-31       716.119995        650.0  89.827693
# 6  2023-04-02 2023-04-09 2023-04-06       705.469971        650.0  91.466158
# 7  2023-04-09 2023-04-16 2023-04-13       703.960022        650.0  91.698458
# 8  2023-04-16 2023-04-23 2023-04-20       702.739990        650.0  91.886155
# 9  2023-04-23 2023-04-30 2023-04-28       701.929993        500.0  59.614001
# 10 2023-04-30 2023-05-07 2023-05-05       701.390015        500.0  59.721997
# 11 2023-05-07 2023-05-14 2023-05-11       701.070007        500.0  59.785999
# 12 2023-05-14 2023-05-21 2023-05-19       700.979980        400.0  24.755005
# The mean accuracy is 73.58%

# %% [markdown]
# <h4>Visualise all, Conclusion</h4>

# %%
plt.figure(figsize=(20, 10))
plt.plot(sel_df['POD'], sel_df['RATE'], color='blue', label="Actual Data")
plt.plot(new_dates_df['POD'], new_dates_df['RATE'], color='blue', label="Actual Data (Updated)")

plt.plot(df_interpolated['POD'], df_interpolated['RATE'], color='green', label="Aggregated Data")
plt.plot(df_forecasted['POD'], df_forecasted['RATE'], color='red', label="Forecasted Data")

plt.xlabel('Date(Year Month)')
plt.ylabel('Cost Rate(USD)')
plt.title('Port_BUSAN_Size_40_Type_HC_PartyID_010004286')
plt.legend()
plt.show();
