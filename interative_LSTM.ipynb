# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Dropout, LSTM, Dense, Bidirectional
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from IPython.core.interactiveshell import InteractiveShell
from sklearn.preprocessing import MinMaxScaler
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline
sns.set()
pd.options.display.max_rows = 100

# %% [markdown]
# <h4>Importing Datasets</h4>

# %%
# Import dataset and clean, ready as a dataframe for creating keys
def createDF(datasets):
    df = pd.read_csv(datasets, converters={'PARTY_ID': str, 'COM_ID': str, 'CNTR_SIZE': str})

    # Formating to type and remove NaN values
    df['POD'] = pd.to_datetime(df['POD'])
    df['ENCODED_TYPE'] = df['ENCODED_TYPE'].fillna(-1).astype(int)
    df = df.dropna(subset=['ENCODED_TYPE'])
    df['RATE'] = df['RATE'].fillna(-1).astype(float)
    df = df.dropna(subset=['RATE'])
    df['ENCODED_TYPE'] = df['ENCODED_TYPE'].astype(int)
    df_clean= df.dropna().reset_index(drop=True)

    # Selecting and rearranging columns
    sel_col = ['CSL_ID', 'CNTR_ID','POD_ID','ETD_POL_D','PARTY_ID',
            'PARTY_NAME','POD','CNTR_SIZE','CNTR_TYPE','RATE']
    df_fc = df_clean[sel_col]

    # Removing years we do not want to process in our models
    df_filtered = df_fc[df_fc['POD'].dt.year != 2002]

    # Sorting the dates
    df_filtered = df_filtered.sort_values(by='POD').reset_index(drop=True)
    
    return df_filtered

# %%
# Create Dataframes for old and new
old_data = '.\Datasets\CR_COST_FC.csv'
df1 = createDF(old_data)
df1.head()

new_data = '.\Datasets\CR_COST_FC_new.csv'
df2 = createDF(new_data)
df2.head()
# Out:
#            CSL_ID           CNTR_ID          POD_ID ETD_POL_D  PARTY_ID  \
# 0  ECS01050600224  CTNR010050700354       ROTTERDAM     NLRTM  01008827
# 1  ECS01050600610  CTNR010050700353      FELIXSTOWE     GBFXT  01002303
# 2  ECS01050600041  CTNR010050700351        AUCKLAND     NZAKL  01005136
# 3  ECS01050600163  CTNR010050700370    PASIR GUDANG     MYPGU  01002767
# 4  ECS01050600456  CTNR010050700450  KARACHI (KICT)     PKKHI  01002783
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0             YANG MING (SINGAPORE) PTE. LTD. 2005-07-15        40    HC NOR
# 1                    GLOBELINK FALLOW LIMITED 2005-07-15        40        GP
# 2  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-15        40    HC NOR
# 3          GLOBELINK CONTAINER LINES (JB) S/B 2005-07-15        40        HC
# 4                GLOBELINK PAKISTAN (PVT) LTD 2005-07-16        40        HC
#
#      RATE
# 0  1620.0
# 1  1800.0
# 2  2170.0
# 3   280.0
# 4  1625.0
#            CSL_ID           CNTR_ID          POD_ID ETD_POL_D  PARTY_ID  \
# 0  ECS01050600224  CTNR010050700354       ROTTERDAM     NLRTM  01008827
# 1  ECS01050600610  CTNR010050700353      FELIXSTOWE     GBFXT  01002303
# 2  ECS01050600041  CTNR010050700351        AUCKLAND     NZAKL  01005136
# 3  ECS01050600163  CTNR010050700370    PASIR GUDANG     MYPGU  01002767
# 4  ECS01050600456  CTNR010050700450  KARACHI (KICT)     PKKHI  01002783
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0             YANG MING (SINGAPORE) PTE. LTD. 2005-07-15        40    HC NOR
# 1                    GLOBELINK FALLOW LIMITED 2005-07-15        40        GP
# 2  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-15        40    HC NOR
# 3          GLOBELINK CONTAINER LINES (JB) S/B 2005-07-15        40        HC
# 4                GLOBELINK PAKISTAN (PVT) LTD 2005-07-16        40        HC
#
#      RATE
# 0  1620.0
# 1  1800.0
# 2  2170.0
# 3   280.0
# 4  1625.0

# %% [markdown]
# <h4>Creating Dictionary Keys</h4>

# %%
def filter_dataframe(df):
    filtered_dataframes = {}

    for (port, size, ctype, party_id), group in df.groupby(['POD_ID', 'CNTR_SIZE', 'CNTR_TYPE', 'PARTY_ID']):
        group = group.reset_index(drop=True).sort_values(by='POD')
        df_id = f"Port_{port}_Size_{size}_Type_{ctype}_PartyID_{party_id}"
        filtered_dataframes[df_id] = group

    return filtered_dataframes

# %%
# Creating keys from data
print("Old Data keys:")
filtered_dataframe1 = filter_dataframe(df1)
df_ids1 = list(filtered_dataframe1.keys())
print(list(df_ids1))
print(len(list(df_ids1)))

print("\nNew Data keys:")
filtered_dataframe2 = filter_dataframe(df2)
df_ids2 = list(filtered_dataframe2.keys())
print(list(df_ids2))
print(len(list(df_ids2)))
# Out:
# Old Data keys:
# ['Port_(CONSTANZA)_Size_40_Type_GP_PartyID_010007816', 'Port_(CONSTANZA)_Size_40_Type_HC_PartyID_010007816', 'Port_AARHUS_Size_20_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100027830', 'Port_AARHUS_Size_20_Type_GP_PartyID_010006666', 'Port_AARHUS_Size_40_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100027830', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100028193', 'Port_AARHUS_Size_40_Type_HC_PartyID_010006666', 'Port_ABIDJAN_Size_20_Type_GP_PartyID_0100027878', 'Port_ABIDJAN_Size_40_Type_HC_PartyID_010021097', 'Port_ADELAIDE_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01005078', 'Port_ADELAIDE_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ALEXANDRIA (EL DEKHELA PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC NOR_PartyID_010004995', 'Port_ALGECIRAS_Size_20_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC NOR_PartyID_01008306', 'Port_ALIAGA_Size_20_Type_GP_PartyID_01008316', 'Port_ALIAGA_Size_40_Type_HC_PartyID_01008316', 'Port_ALIAGA PORT (IZMIR)_Size_40_Type_HC_PartyID_01008316', 'Port_ANTWERP_Size_20_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC NOR_PartyID_01001449', 'Port_AQABA_Size_20_Type_GP_PartyID_010006618', 'Port_AQABA_Size_20_Type_GP_PartyID_010021081', 'Port_AQABA_Size_40_Type_HC_PartyID_010006618', 'Port_AQABA_Size_40_Type_HC_PartyID_010021081', 'Port_ASHDOD_Size_20_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_01008417', 'Port_ASHDOD_Size_40_Type_HC_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_HC_PartyID_01008417', 'Port_AUCKLAND_Size_20_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_20_Type_GP (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC NOR_PartyID_01005136', 'Port_BANGKOK_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_20_Type_GP (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (SOC)_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK (TST)_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK (TST)_Size_40_Type_HC_PartyID_010021593', 'Port_BARCELONA_Size_20_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC NOR_PartyID_01008305', 'Port_BEIRUT_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_HC_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_40_Type_HC_PartyID_0100 ...
# 789
#
# New Data keys:
# ['Port_(CONSTANZA)_Size_40_Type_GP_PartyID_010007816', 'Port_(CONSTANZA)_Size_40_Type_HC_PartyID_010007816', 'Port_AARHUS_Size_20_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100027830', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100028193', 'Port_AARHUS_Size_20_Type_GP_PartyID_010006666', 'Port_AARHUS_Size_40_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100027830', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100028193', 'Port_AARHUS_Size_40_Type_HC_PartyID_010006666', 'Port_ABIDJAN_Size_20_Type_GP_PartyID_0100027878', 'Port_ABIDJAN_Size_40_Type_HC_PartyID_010021097', 'Port_ADELAIDE_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01005078', 'Port_ADELAIDE_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ALEXANDRIA (EL DEKHELA PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC NOR_PartyID_010004995', 'Port_ALGECIRAS_Size_20_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC NOR_PartyID_01008306', 'Port_ALIAGA_Size_20_Type_GP_PartyID_01008316', 'Port_ALIAGA_Size_40_Type_HC_PartyID_01008316', 'Port_ALIAGA PORT (IZMIR)_Size_40_Type_HC_PartyID_01008316', 'Port_ANTWERP_Size_20_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC NOR_PartyID_01001449', 'Port_AQABA_Size_20_Type_GP_PartyID_010006618', 'Port_AQABA_Size_20_Type_GP_PartyID_010021081', 'Port_AQABA_Size_40_Type_HC_PartyID_010006618', 'Port_AQABA_Size_40_Type_HC_PartyID_010021081', 'Port_ASHDOD_Size_20_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_01008417', 'Port_ASHDOD_Size_40_Type_HC_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_HC_PartyID_01008417', 'Port_AUCKLAND_Size_20_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_20_Type_GP (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC NOR_PartyID_01005136', 'Port_BANGKOK_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_20_Type_GP (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (SOC)_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK (TST)_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK (TST)_Size_40_Type_HC_PartyID_010021593', 'Port_BARCELONA_Size_20_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC NOR_PartyID_01008305', 'Port_BEIRUT_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_HC_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_20_Type_GP_PartyID_010003651', ' ...
# 799

# %% [markdown]
# <h4>Getting Top 5 ports keys</h4>

# %%
def getTop5Ports(keybunch):
    keybunch_pouch = []
    
    # Get a dictionary with key and number of rows for each dataframe in filtered_dataframes
    key_row_counts = {key: len(keybunch[key]) for key in keybunch}

    # Sort the key_row_counts dictionary by value (number of rows) in descending order
    sorted_key_row_counts = sorted(key_row_counts.items(), key=lambda item: item[1], reverse=True)

    # Get the top 5 keys with the most rows
    top_5_keys_tuple = sorted_key_row_counts[:5]

    # Create a dictionary with the top 5 keys and their corresponding dataframes (with up to 5 rows per dataframe)
    keybunch_subset = {}

    for key, row_count in top_5_keys_tuple:
        keybunch_subset[key] = keybunch[key][:5]
        print(f"Number of rows in {key}: {row_count}")
        keybunch_pouch.append(key)
    
    # Return array of keys
    return keybunch_pouch

# %%
print('Old Dataset Keybunch:')
old_df = getTop5Ports(filtered_dataframe1)
print('\n')

print('New Dataset Keybunch:')
new_df = getTop5Ports(filtered_dataframe2)
# Out:
# Old Dataset Keybunch:
# Number of rows in Port_BUSAN_Size_40_Type_HC_PartyID_010004286: 1689
# Number of rows in Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136: 1688
# Number of rows in Port_MELBOURNE_Size_40_Type_HC_PartyID_01002778: 1325
# Number of rows in Port_SYDNEY_Size_40_Type_HC_PartyID_01002779: 1300
# Number of rows in Port_DUBAI (JEBEL ALI)_Size_40_Type_HC_PartyID_01002788: 1052
#
#
# New Dataset Keybunch:
# Number of rows in Port_BUSAN_Size_40_Type_HC_PartyID_010004286: 1712
# Number of rows in Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136: 1704
# Number of rows in Port_MELBOURNE_Size_40_Type_HC_PartyID_01002778: 1341
# Number of rows in Port_SYDNEY_Size_40_Type_HC_PartyID_01002779: 1308
# Number of rows in Port_DUBAI (JEBEL ALI)_Size_40_Type_HC_PartyID_01002788: 1070

# %%
# Accessing the highest count in the each keypouch, new and old.
sel_df = filtered_dataframe1[old_df[0]]
sel_df.head(5)
sel_df.tail(5)
sel_df.info()
print("\n")

latest_sel_df = filtered_dataframe2[new_df[0]]
latest_sel_df.head(5)
latest_sel_df.tail(5)
latest_sel_df.info()
# Out:
#             CSL_ID           CNTR_ID POD_ID ETD_POL_D   PARTY_ID  \
# 0  ECS010050800407  CTNR010050901151  BUSAN     KRPUS  010004286
# 1  ECS010050800407  CTNR010050901379  BUSAN     KRPUS  010004286
# 2  ECS010050900468  CTNR010051000081  BUSAN     KRPUS  010004286
# 3  ECS010050900468  CTNR010050901461  BUSAN     KRPUS  010004286
# 4  ECS010050900469  CTNR010051000434  BUSAN     KRPUS  010004286
#
#                  PARTY_NAME        POD CNTR_SIZE CNTR_TYPE   RATE
# 0  GLOBELINK KOREA CO., LTD 2005-10-03        40        HC  390.0
# 1  GLOBELINK KOREA CO., LTD 2005-10-03        40        HC  390.0
# 2  GLOBELINK KOREA CO., LTD 2005-10-07        40        HC  390.0
# 3  GLOBELINK KOREA CO., LTD 2005-10-07        40        HC  390.0
# 4  GLOBELINK KOREA CO., LTD 2005-10-14        40        HC  390.0
#                CSL_ID       CNTR_ID POD_ID ETD_POL_D   PARTY_ID  \
# 1684  ECS010230100126  010000391908  BUSAN     KRPUS  010004286
# 1685  ECS010230100126  010000380884  BUSAN     KRPUS  010004286
# 1687  ECS010230100127  010000407833  BUSAN     KRPUS  010004286
# 1686  ECS010230100127  010000390366  BUSAN     KRPUS  010004286
# 1688  ECS010230100127  010000401385  BUSAN     KRPUS  010004286
#
#                     PARTY_NAME        POD CNTR_SIZE CNTR_TYPE   RATE
# 1684  GLOBELINK KOREA CO., LTD 2023-02-22        40        HC  300.0
# 1685  GLOBELINK KOREA CO., LTD 2023-02-22        40        HC  300.0
# 1687  GLOBELINK KOREA CO., LTD 2023-02-28        40        HC  300.0
# 1686  GLOBELINK KOREA CO., LTD 2023-02-28        40        HC  300.0
# 1688  GLOBELINK KOREA CO., LTD 2023-02-28        40        HC  300.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1689 entries, 0 to 1688
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      1689 non-null   object
#  1   CNTR_ID     1689 non-null   object
#  2   POD_ID      1689 non-null   object
#  3   ETD_POL_D   1689 non-null   object
#  4   PARTY_ID    1689 non-null   object
#  5   PARTY_NAME  1689 non-null   object
#  6   POD         1689 non-null   datetime64[ns]
#  7   CNTR_SIZE   1689 non-null   object
#  8   CNTR_TYPE   1689 non-null   object
#  9   RATE        1689 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 145.1+ KB
#             CSL_ID           CNTR_ID POD_ID ETD_POL_D   PARTY_ID  \
# 0  ECS010050800407  CTNR010050901151  BUSAN     KRPUS  010004286
# 1  ECS010050800407  CTNR010050901379  BUSAN     KRPUS  010004286
# 2  ECS010050900468  CTNR010051000081  BUSAN     KRPUS  010004286
# 3  ECS010050900468  CTNR010050901461  BUSAN     KRPUS  010004286
# 4  ECS010050900469  CTNR010051000434  BUSAN     KRPUS  010004286
#
#                  PARTY_NAME        POD CNTR_SIZE CNTR_TYPE   RATE
# 0  GLOBELINK KOREA CO., LTD 2005-10-03        40        HC  390.0
# 1  GLOBELINK KOREA CO., LTD 2005-10-03        40        HC  390.0
# 2  GLOBELINK KOREA CO., LTD 2005-10-07        40        HC  390.0
# 3  GLOBELINK KOREA CO., LTD 2005-10-07        40        HC  390.0
# 4  GLOBELINK KOREA CO., LTD 2005-10-14        40        HC  390.0
#                CSL_ID       CNTR_ID POD_ID ETD_POL_D   PARTY_ID  \
# 1708  ECS010230300113  010000512466  BUSAN     KRPUS  010004286
# 1707  ECS010230300113  010000534846  BUSAN     KRPUS  010004286
# 1709  ECS010230400203  010000544930  BUSAN     KRPUS  010004286
# 1710  ECS010230400183  010000565100  BUSAN     KRPUS  010004286
# 1711  ECS010230400183  010000554335  BUSAN     KRPUS  010004286
#
#                     PARTY_NAME        POD CNTR_SIZE CNTR_TYPE   RATE
# 1708  GLOBELINK KOREA CO., LTD 2023-05-03        40        HC  260.0
# 1707  GLOBELINK KOREA CO., LTD 2023-05-03        40        HC  260.0
# 1709  GLOBELINK KOREA CO., LTD 2023-05-10        40        HC  300.0
# 1710  GLOBELINK KOREA CO., LTD 2023-05-17        40        HC  260.0
# 1711  GLOBELINK KOREA CO., LTD 2023-05-17        40        HC  260.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1712 entries, 0 to 1711
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      1712 non-null   object
#  1   CNTR_ID     1712 non-null   object
#  2   POD_ID      1712 non-null   object
#  3   ETD_POL_D   1712 non-null   object
#  4   PARTY_ID    1712 non-null   object
#  5   PARTY_NAME  1712 non-null   object
#  6   POD         1712 non-null   datetime64[ns]
#  7   CNTR_SIZE   1712 non-null   object
#  8   CNTR_TYPE   1712 non-null   object
#  9   RATE        1712 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 147.1+ KB

# %%
from sklearn.preprocessing import RobustScaler

# Select features
sel_feat = ['POD','RATE']
robust_df = sel_df[sel_feat].copy()  # make a copy to avoid SettingWithCopyWarning

# Robust Scaling
scaler = RobustScaler()
robust_df.loc[:, 'RATE'] = scaler.fit_transform(robust_df[['RATE']])
robust_df.head()
# Out:
#          POD      RATE
# 0 2005-10-03  2.777778
# 1 2005-10-03  2.777778
# 2 2005-10-07  2.777778
# 3 2005-10-07  2.777778
# 4 2005-10-14  2.777778

# %%
# Check if the DataFrame has any NaN values
if robust_df.isna().any().any():
    print("The DataFrame contains NaN values.")
else:
    print("The DataFrame does not contain NaN values.")
# Out:
# The DataFrame does not contain NaN values.

# %% [markdown]
# <h4>Interpolate missing values in between dates</h4>

# %%
# Remove duplicated dates and cost rows
robust_df = robust_df.drop_duplicates(subset=['POD', 'RATE']).reset_index(drop=True)

# Create a new dataframe with a date range from min to max date in your dataframe
new_df = pd.DataFrame()
new_df['POD'] = pd.date_range(start=robust_df['POD'].min(), end=robust_df['POD'].max())

# Merge the original dataframe with the new one. Missing dates in the original dataframe will be filled with NaN
df_interpolated = pd.merge(new_df, robust_df, on='POD', how='left')  

# Perform spline interpolation
df_interpolated['RATE'] = df_interpolated['RATE'].interpolate(method='polynomial', order=1)

df_interpolated['RATE'] = df_interpolated['RATE'].round(3)

# Now we need to inverse the scaling
df_interpolated['RATE'] = scaler.inverse_transform(df_interpolated[['RATE']])

df_interpolated.head(5)
df_interpolated.tail(5)
df_interpolated.info()
# Out:
#          POD    RATE
# 0 2005-10-03  390.02
# 1 2005-10-04  390.02
# 2 2005-10-05  390.02
# 3 2005-10-06  390.02
# 4 2005-10-07  390.02
#             POD    RATE
# 6371 2023-02-24  300.02
# 6372 2023-02-25  300.02
# 6373 2023-02-26  300.02
# 6374 2023-02-27  300.02
# 6375 2023-02-28  300.02
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6376 entries, 0 to 6375
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POD     6376 non-null   datetime64[ns]
#  1   RATE    6376 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 149.4 KB

# %% [markdown]
# <h4>Grouping it to week</h4>

# %%
from scipy import stats

# Create YearMonthWeek directly from the 'POD'
df_interpolated['YearMonthWeek'] = df_interpolated['POD'] - pd.to_timedelta(df_interpolated['POD'].dt.dayofweek, unit='D')

# Create a new dataframe with every week in the range
all_weeks = pd.date_range(start=df_interpolated['POD'].min(), end=df_interpolated['POD'].max(), freq='W')
all_weeks_df = pd.DataFrame(all_weeks, columns=['POD'])

# Create YearMonthWeek in all_weeks_df
all_weeks_df['YearMonthWeek'] = all_weeks_df['POD'] - pd.to_timedelta(all_weeks_df['POD'].dt.dayofweek, unit='D')

# Merge this with your original dataframe
merged_df = pd.merge(all_weeks_df, df_interpolated, on=['YearMonthWeek'], how='left')

# Now you can group by YearMonthWeek and compute your rate
grouped = merged_df.groupby(['YearMonthWeek'])

agg_df = pd.DataFrame(columns=['YearMonthWeek', 'Rate'])

for group_name, group_df in grouped:
    year_month_week = group_name

    # Skip if no data for this week
    if group_df['RATE'].isnull().all():
        continue

    # Calculate sum and skewness of RATE values
    rate_sum = group_df['RATE'].sum()
    rate_skew = group_df['RATE'].skew()

    # Calculate trimmed mean of RATE values
    rate_metric = stats.trim_mean(group_df['RATE'].dropna().values, 0.1) # trimming 10% from each end

    new_row = {
        'YearMonthWeek': year_month_week,
        'Rate': rate_metric
    }

    # Append row to aggregated dataframe
    agg_df = agg_df.append(new_row, ignore_index=True)

agg_df = agg_df.sort_values(by='YearMonthWeek').reset_index(drop=True)
agg_df['Rate'] = agg_df['Rate'].round(2)

agg_df.head(15)
agg_df.tail(15)
agg_df.info()
# Out:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:21: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for group_name, group_df in grouped:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# ...
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\679132877.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
#    YearMonthWeek    Rate
# 0     2005-10-03  390.02
# 1     2005-10-10  390.02
# 2     2005-10-17  390.02
# 3     2005-10-24  390.02
# 4     2005-10-31  390.02
# 5     2005-11-07  390.02
# 6     2005-11-14  390.02
# 7     2005-11-21  390.02
# 8     2005-11-28  390.02
# 9     2005-12-05  390.02
# 10    2005-12-12  390.02
# 11    2005-12-19  390.02
# 12    2005-12-26  390.02
# 13    2006-01-02  390.02
# 14    2006-01-09  390.02
#     YearMonthWeek    Rate
# 893    2022-11-14  149.99
# 894    2022-11-21  158.57
# 895    2022-11-28  191.43
# 896    2022-12-05  184.61
# 897    2022-12-12  211.52
# 898    2022-12-19  161.00
# 899    2022-12-26  159.17
# 900    2023-01-02  269.39
# 901    2023-01-09  300.02
# 902    2023-01-16  295.25
# 903    2023-01-23  233.33
# 904    2023-01-30  204.79
# 905    2023-02-06  245.25
# 906    2023-02-13  214.30
# 907    2023-02-20  292.87
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908 entries, 0 to 907
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   YearMonthWeek  908 non-null    datetime64[ns]
#  1   Rate           908 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 14.3 KB

# %% [markdown]
# <h4>Latest datapoints from Latest dataframe for comparing after forecasting (Measure accuracy)</h4>

# %%
max_date_in_old = sel_df['POD'].max()

# Create a new dataframe that only includes rows from the latest dataframe where the date is greater than the maximum date in the old dataframe
new_dates_df = latest_sel_df[latest_sel_df['POD'] > max_date_in_old].reset_index(drop=True)

# Print the new dataframe
new_dates_df.head(3)
new_dates_df.tail(3)
new_dates_df.info()
# Out:
#             CSL_ID       CNTR_ID POD_ID ETD_POL_D   PARTY_ID  \
# 0  ECS010230200077  010000419950  BUSAN     KRPUS  010004286
# 1  ECS010230200077  010000406570  BUSAN     KRPUS  010004286
# 2  ECS010230200078  010000432251  BUSAN     KRPUS  010004286
#
#                  PARTY_NAME        POD CNTR_SIZE CNTR_TYPE   RATE
# 0  GLOBELINK KOREA CO., LTD 2023-03-08        40        HC  260.0
# 1  GLOBELINK KOREA CO., LTD 2023-03-08        40        HC  260.0
# 2  GLOBELINK KOREA CO., LTD 2023-03-15        40        HC  260.0
#              CSL_ID       CNTR_ID POD_ID ETD_POL_D   PARTY_ID  \
# 20  ECS010230400203  010000544930  BUSAN     KRPUS  010004286
# 21  ECS010230400183  010000565100  BUSAN     KRPUS  010004286
# 22  ECS010230400183  010000554335  BUSAN     KRPUS  010004286
#
#                   PARTY_NAME        POD CNTR_SIZE CNTR_TYPE   RATE
# 20  GLOBELINK KOREA CO., LTD 2023-05-10        40        HC  300.0
# 21  GLOBELINK KOREA CO., LTD 2023-05-17        40        HC  260.0
# 22  GLOBELINK KOREA CO., LTD 2023-05-17        40        HC  260.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      23 non-null     object
#  1   CNTR_ID     23 non-null     object
#  2   POD_ID      23 non-null     object
#  3   ETD_POL_D   23 non-null     object
#  4   PARTY_ID    23 non-null     object
#  5   PARTY_NAME  23 non-null     object
#  6   POD         23 non-null     datetime64[ns]
#  7   CNTR_SIZE   23 non-null     object
#  8   CNTR_TYPE   23 non-null     object
#  9   RATE        23 non-null     float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 1.9+ KB

# %%
plt.figure(figsize=(20, 10))
plt.plot(sel_df['POD'], sel_df['RATE'], color='blue', label="Actual Data")
plt.plot(agg_df['YearMonthWeek'], agg_df['Rate'], color='red', label="Aggregated Data(weeks)")

plt.xlabel('Date(Year Month Week)')
plt.ylabel('Cost Rate(USD)')
plt.title('Port_BUSAN_Size_40_Type_HC_PartyID_010004286')
plt.legend()
plt.show();

# %% [markdown]
# <h4>LSTM Regression<h4>

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# Mean Square Error Function:
def calculate_RMSE(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# Update create_dataset to handle multi-feature dataset
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

def create_LSTM_model(trainX, trainY, testX, testY, epochs, lstm_layers):
    model = Sequential()

    # input layer
    model.add(Bidirectional(LSTM(lstm_layers[0], return_sequences=True), 
                            input_shape=(trainX.shape[1], trainX.shape[2])))
    model.add(Dropout(0.2))

    # hidden layers
    for i in range(1, len(lstm_layers)):
        model.add(Bidirectional(LSTM(lstm_layers[i], return_sequences=(i!=(len(lstm_layers)-1))))) 
        
    # output layer
    model.add(Dense(1))

    model.compile(loss='mean_squared_error', optimizer='adam')
    
    history = model.fit(trainX, trainY, epochs=epochs, validation_data=(testX, testY), 
                        callbacks=[EarlyStopping(monitor='val_loss', patience=10)], 
                        verbose=2, shuffle=False)

    return model, history


def plot_train_val_loss(history):
    plt.figure(figsize=(10,6))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model loss progress during training and validation')
    plt.xlabel('Epoch')
    plt.ylabel('Training and Validation Loss')
    plt.legend()
    plt.show()

# %%
# Normalize dataset for LSTM
scaler = MinMaxScaler(feature_range=(0, 1))

# Fit and transform the entire dataset
dataset = scaler.fit_transform(agg_df['Rate'].values.reshape(-1, 1))


# Split into train and test sets
train_size = int(len(dataset) * 0.7)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# Reshape into X=t and Y=t+1, timestep  look_back
look_back = 5
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# Reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], look_back, 1))
testX = np.reshape(testX, (testX.shape[0], look_back, 1))


epochs_list = [50, 100, 150]

lstm_layers_list = [
    [64, 64, 32, 32, 16, 16, 8, 8, 4, 4, 2, 2],
    [32, 32, 16, 16, 8, 8, 4, 4, 2, 2],
    [16, 16, 8, 8, 4, 4, 2, 2],
    [8, 8, 4, 4, 2, 2],
    [4, 4, 2, 2],
    [2, 2]
]

rmse_results = {}

for epochs in epochs_list:
    print(f'Training for {epochs} epochs...')
    
    for lstm_layers in lstm_layers_list:
        print(f'Training with LSTM layers: {lstm_layers}')
        model, history = create_LSTM_model(trainX, trainY, testX, testY, epochs, lstm_layers)
        
        # Add the loss for this model to the plot
        plt.plot(history.history['loss'], label=f'Train Loss - {epochs} epochs, layers: {lstm_layers}')
        plt.plot(history.history['val_loss'], label=f'Validation Loss - {epochs} epochs, layers: {lstm_layers}')

        # Evalute LSTM Model
        trainPredict = model.predict(trainX)
        testPredict = model.predict(testX)

        # inverse_transform
        trainPredict = scaler.inverse_transform(trainPredict)
        trainY_orig = scaler.inverse_transform([trainY])
        testPredict = scaler.inverse_transform(testPredict)
        testY_orig = scaler.inverse_transform([testY])

        # Calculate mean squared error
        trainScore = calculate_RMSE(trainY_orig[0], trainPredict[:,0])
        print(f'Train Score: {trainScore:.2f} RMSE for {epochs} epochs')
        testScore = calculate_RMSE(testY_orig[0], testPredict[:,0])
        print(f'Test Score: {testScore:.2f} RMSE for {epochs} epochs')

        rmse_results[f'{epochs} epochs, {lstm_layers} layers'] = {'Train RMSE': trainScore, 'Test RMSE': testScore}

# Configure and show the plot
plt.title('Model loss progress during training and validation')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend()
plt.show();

# Convert the dictionary to a DataFrame for easy display
rmse_df = pd.DataFrame(rmse_results).T
print(rmse_df)
# Out:
# Training for 50 epochs...
# Training with LSTM layers: [64, 64, 32, 32, 16, 16, 8, 8, 4, 4, 2, 2]
# Epoch 1/50
# 20/20 - 46s - loss: 0.0426 - val_loss: 0.0568 - 46s/epoch - 2s/step
# Epoch 2/50
# 20/20 - 1s - loss: 0.0211 - val_loss: 0.0405 - 717ms/epoch - 36ms/step
# Epoch 3/50
# 20/20 - 1s - loss: 0.0119 - val_loss: 0.0407 - 704ms/epoch - 35ms/step
# Epoch 4/50
# 20/20 - 1s - loss: 0.0114 - val_loss: 0.0410 - 692ms/epoch - 35ms/step
# Epoch 5/50
# 20/20 - 1s - loss: 0.0118 - val_loss: 0.0407 - 689ms/epoch - 34ms/step
# Epoch 6/50
# 20/20 - 1s - loss: 0.0116 - val_loss: 0.0395 - 690ms/epoch - 35ms/step
# Epoch 7/50
# 20/20 - 1s - loss: 0.0096 - val_loss: 0.0354 - 688ms/epoch - 34ms/step
# Epoch 8/50
# 20/20 - 1s - loss: 0.0118 - val_loss: 0.0309 - 687ms/epoch - 34ms/step
# Epoch 9/50
# 20/20 - 1s - loss: 0.0071 - val_loss: 0.0275 - 696ms/epoch - 35ms/step
# Epoch 10/50
# 20/20 - 1s - loss: 0.0043 - val_loss: 0.0242 - 709ms/epoch - 35ms/step
# Epoch 11/50
# 20/20 - 1s - loss: 0.0030 - val_loss: 0.0220 - 682ms/epoch - 34ms/step
# Epoch 12/50
# 20/20 - 1s - loss: 0.0027 - val_loss: 0.0197 - 680ms/epoch - 34ms/step
# Epoch 13/50
# 20/20 - 1s - loss: 0.0019 - val_loss: 0.0194 - 678ms/epoch - 34ms/step
# Epoch 14/50
# 20/20 - 1s - loss: 0.0018 - val_loss: 0.0173 - 681ms/epoch - 34ms/step
# Epoch 15/50
# 20/20 - 1s - loss: 0.0017 - val_loss: 0.0173 - 678ms/epoch - 34ms/step
# Epoch 16/50
# 20/20 - 1s - loss: 0.0014 - val_loss: 0.0164 - 684ms/epoch - 34ms/step
# Epoch 17/50
# 20/20 - 1s - loss: 0.0012 - val_loss: 0.0156 - 680ms/epoch - 34ms/step
# Epoch 18/50
# 20/20 - 1s - loss: 0.0011 - val_loss: 0.0144 - 679ms/epoch - 34ms/step
# Epoch 19/50
# 20/20 - 1s - loss: 9.9196e-04 - val_loss: 0.0143 - 707ms/epoch - 35ms/step
# Epoch 20/50
# 20/20 - 1s - loss: 9.9989e-04 - val_loss: 0.0139 - 692ms/epoch - 35ms/step
# Epoch 21/50
# 20/20 - 1s - loss: 9.0192e-04 - val_loss: 0.0133 - 711ms/epoch - 36ms/step
# Epoch 22/50
# 20/20 - 1s - loss: 7.1367e-04 - val_loss: 0.0128 - 683ms/epoch - 34ms/step
# Epoch 23/50
# 20/20 - 1s - loss: 5.4877e-04 - val_loss: 0.0123 - 681ms/epoch - 34ms/step
# Epoch 24/50
# 20/20 - 1s - loss: 4.6368e-04 - val_loss: 0.0126 - 681ms/epoch - 34ms/step
# Epoch 25/50
# 20/20 - 1s - loss: 4.8770e-04 - val_loss: 0.0124 - 719ms/epoch - 36ms/step
# Epoch 26/50
# 20/20 - 1s - loss: 4.0721e-04 - val_loss: 0.0115 - 688ms/epoch - 34ms/step
# Epoch 27/50
# 20/20 - 1s - loss: 8.4365e-04 - val_loss: 0.0169 - 686ms/epoch - 34ms/step
# Epoch 28/50
# 20/20 - 1s - loss: 0.0024 - val_loss: 0.0155 - 726ms/epoch - 36ms/step
# Epoch 29/50
# 20/20 - 1s - loss: 0.0010 - val_loss: 0.0127 - 699ms/epoch - 35ms/step
# Epoch 30/50
# 20/20 - 1s - loss: 0.0013 - val_loss: 0.0159 - 686ms/epoch - 34ms/step
# Epoch 31/50
# 20/20 - 1s - loss: 8.6078e-04 - val_loss: 0.0145 - 703ms/epoch - 35ms/step
# Epoch 32/50
# 20/20 - 1s - loss: 8.0551e-04 - val_loss: 0.0149 - 690ms/epoch - 34ms/step
# Epoch 33/50
# 20/20 - 1s - loss: 7.3366e-04 - val_loss: 0.0132 - 685ms/epoch - 34ms/step
# Epoch 34/50
# 20/20 - 1s - loss: 5.8116e-04 - val_loss: 0.0147 - 695ms/epoch - 35ms/step
# Epoch 35/50
# 20/20 - 1s - loss: 6.4986e-04 - val_loss: 0.0129 - 694ms/epoch - 35ms/step
# Epoch 36/50
# 20/20 - 1s - loss: 5.4460e-04 - val_loss: 0.0138 - 713ms/epoch - 36ms/step
# 20/20 [==============================] - 8s 10ms/step
# 9/9 [==============================] - 0s 9ms/step
# Train Score: 19.20 RMSE for 50 epochs
# Test Score: 109.64 RMSE for 50 epochs
# Training with LSTM layers: [32, 32, 16, 16, 8, 8, 4, 4, 2, 2]
# Epoch 1/50
# 20/20 - 37s - loss: 0.0437 - val_loss: 0.0589 - 37s/epoch - 2s/step
# Epoch 2/50
# 20/20 - 1s - loss: 0.0223 - val_loss: 0.0388 - 559ms/epoch - 28ms/step
# Epoch 3/50
# 20/20 - 1s - loss: 0.0116 - val_loss: 0.0388 - 530ms/epoch - 27ms/step
# Epoch 4/50
# 20/20 - 1s - loss: 0.0112 - val_loss: 0.0381 - 526ms/epoch - 26ms/step
# Epoch 5/50
# 20/20 - 1s - loss: 0.0111 - val_loss: 0.0361 - 522ms/epoch - 26ms/step
# Epoch 6/50
# 20/20 - 1s - loss: 0.0099 - val_loss: 0.0328 - 521ms/epoch - 26ms/step
# Epoch 7/50
# 20/20 - 1s - loss: 0.0079 - val_loss: 0.0257 - 523ms/epoch - 26ms/step
# Epoch 8/50
# 20/20 - 1s - loss: 0.0038 - val_loss: 0.0172 - 546ms/epoch - 27ms/step
# Epoch 9/50
# 20/20 - 1s - loss: 0.0013 - val_loss: 0.0150 - 595ms/epoch - 30ms/step
# Epoch 10/50
# 20/20 - 1s - loss: 0.0010 - val_loss: 0.0170 - 528ms/epoch - 26ms/step
# Epoch 11/50
# 20/20 - 1s - loss: 0.0011 - val_loss: 0.0143 - 528ms/epoch - 26ms/step
# Epoch 12/50
# 20/20 - 1s - loss: 8.7964e-04 - val_loss: 0.0141 - 523ms/epoch - 26ms/step
# Epoch 13/50
# 20/20 - 1s - loss: 8.3811e-04 - val_loss: 0.0153 - 548ms/epoch - 27ms/step
# Epoch 14/50
# 20/20 - 1s - loss: 8.6006e-04 - val_loss: 0.0141 - 561ms/epoch - 28ms/step
# Epoch 15/50
# 20/20 - 1s - loss: 7.7361e-04 - val_loss: 0.0132 - 572ms/epoch - 29ms/step
# Epoch 16/50
# 20/20 - 1s - loss: 7.7735e-04 - val_loss: 0.0142 - 570ms/epoch - 29ms/step
# Epoch 17/50
# 20/20 - 1s - loss: 7.0734e-04 - val_loss: 0.0142 - 558ms/epoch - 28ms/step
# Epoch 18/50
# 20/20 - 1s - loss: 7.4171e-04 - val_loss: 0.0133 - 565ms/epoch - 28ms/step
# Epoch 19/50
# 20/20 - 1s - loss: 6.6006e-04 - val_loss: 0.0126 - 543ms/epoch - 27ms/step
# Epoch 20/50
# 20/20 - 1s - loss: 6.9146e-04 - val_loss: 0.0132 - 577ms/epoch - 29ms/step
# Epoch 21/50
# 20/20 - 1s - loss: 6.6006e-04 - val_loss: 0.0138 - 568ms/epoch - 28ms/step
# Epoch 22/50
# 20/20 - 1s - loss: 7.1231e-04 - val_loss: 0.0137 - 528ms/epoch - 26ms/step
# Epoch 23/50
# 20/20 - 1s - loss: 7.1250e-04 - val_loss: 0.0124 - 524ms/epoch - 26ms/step
# Epoch 24/50
# 20/20 - 1s - loss: 5.9417e-04 - val_loss: 0.0116 - 524ms/epoch - 26ms/step
# Epoch 25/50
# 20/20 - 1s - loss: 7.1580e-04 - val_loss: 0.0124 - 524ms/epoch - 26ms/step
# Epoch 26/50
# 20/20 - 1s - loss: 6.8472e-04 - val_loss: 0.0137 - 526ms/epoch - 26ms/step
# Epoch 27/50
# 20/20 - 1s - loss: 7.8924e-04 - val_loss: 0.0153 - 526ms/epoch - 26ms/step
# Epoch 28/50
# 20/20 - 1s - loss: 0.0012 - val_loss: 0.0148 - 533ms/epoch - 27ms/step
# Epoch 29/50
# 20/20 - 1s - loss: 0.0014 - val_loss: 0.0133 - 525ms/epoch - 26ms/step
# Epoch 30/50
# 20/20 - 1s - loss: 9.7412e-04 - val_loss: 0.0111 - 527ms/epoch - 26ms/step
# Epoch 31/50
# 20/20 - 1s - loss: 8.4159e-04 - val_loss: 0.0107 - 533ms/epoch - 27ms/step
# Epoch 32/50
# 20/20 - 1s - loss: 0.0017 - val_loss: 0.0145 - 530ms/epoch - 27ms/step
# Epoch 33/50
# 20/20 - 1s - loss: 9.7183e-04 - val_loss: 0.0164 - 531ms/epoch - 27ms/step
# Epoch 34/50
# 20/20 - 1s - loss: 0.0012 - val_loss: 0.0154 - 531ms/epoch - 27ms/step
# Epoch 35/50
# 20/20 - 1s - loss: 0.0011 - val_loss: 0.0117 - 529ms/epoch - 26ms/step
# Epoch 36/50
# 20/20 - 1s - loss: 7.6004e-04 - val_loss: 0.0120 - 538ms/epoch - 27ms/step
# Epoch 37/50
# 20/20 - 1s - loss: 7.0978e-04 - val_loss: 0.0132 - 539ms/epoch - 27ms/step
# Epoch 38/50
# 20/20 - 1s - loss: 6.3637e-04 - val_loss: 0.0146 - 538ms/epoch - 27ms/step
# Epoch 39/50
# 20/20 - 1s - loss: 8.1593e-04 - val_loss: 0.0130 - 535ms/epoch - 27ms/step
# Epoch 40/50
# 20/20 - 1s - loss: 6.0870e-04 - val_loss: 0.0114 - 539ms/epoch - 27ms/step
# Epoch 41/50
# 20/20 - 1s - loss: 6.9008e-04 - val_loss: 0.0121 - 527ms/epoch - 26ms/step
# 20/20 [==============================] - 7s 7ms/step
# 9/9 [==============================] - 0s 7ms/step
# Train Score: 23.19 RMSE for 50 epochs
# Test Score: 102.51 RMSE for 50 epochs
# Training with LSTM layers: [16, 16, 8, 8, 4, 4, 2, 2]
# Epoch 1/50
# 20/20 - 30s - loss: 0.0402 - val_loss: 0.0501 - 30s/epoch - 2s/step
# Epoch 2/50
# 20/20 - 0s - loss: 0.0183 - val_loss: 0.0376 - 431ms/epoch - 22ms/step
# Epoch 3/50
# 20/20 - 0s - loss: 0.0106 - val_loss: 0.0378 - 421ms/epoch - 21ms/step
# Epoch 4/50
# 20/20 - 0s - loss: 0.0108 - val_loss: 0.0361 - 423ms/epoch - 21ms/step
# Epoch 5/50
# 20/20 - 0s - loss: 0.0105 - val_loss: 0.0327 - 415ms/epoch - 21ms/step
# Epoch 6/50
# 20/20 - 0s - loss: 0.0090 - val_loss: 0.0267 - 411ms/epoch - 21ms/step
# Epoch 7/50
# 20/20 - 0s - loss: 0.0063 - val_loss: 0.0167 - 415ms/epoch - 21ms/step
# Epoch 8/50
# 20/20 - 0s - loss: 0.0021 - val_loss: 0.0096 - 410ms/epoch - 20ms/step
# Epoch 9/50
# 20/20 - 0s - loss: 0.0010 - val_loss: 0.0099 - 418ms/epoch - 21ms/step
# Epoch 10/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.0138 - 415ms/epoch - 21ms/step
# Epoch 11/50
# 20/20 - 0s - loss: 9.9123e-04 - val_loss: 0.0129 - 416ms/epoch - 21ms/step
# Epoch 12/50
# 20/20 - 0s - loss: 7.8026e-04 - val_loss: 0.0103 - 412ms/epoch - 21ms/step
# Epoch 13/50
# 20/20 - 0s - loss: 6.6881e-04 - val_loss: 0.0112 - 410ms/epoch - 20ms/step
# Epoch 14/50
# 20/20 - 0s - loss: 5.7084e-04 - val_loss: 0.0119 - 411ms/epoch - 21ms/step
# Epoch 15/50
# 20/20 - 0s - loss: 6.1017e-04 - val_loss: 0.0109 - 413ms/epoch - 21ms/step
# Epoch 16/50
# 20/20 - 0s - loss: 5.6862e-04 - val_loss: 0.0107 - 409ms/epoch - 20ms/step
# Epoch 17/50
# 20/20 - 0s - loss: 5.6642e-04 - val_loss: 0.0110 - 411ms/epoch - 21ms/step
# Epoch 18/50
# 20/20 - 0s - loss: 5.4264e-04 - val_loss: 0.0109 - 410ms/epoch - 20ms/step
# 20/20 [==============================] - 5s 5ms/step
# 9/9 [==============================] - 0s 5ms/step
# Train Score: 20.52 RMSE for 50 epochs
# Test Score: 97.25 RMSE for 50 epochs
# Training with LSTM layers: [8, 8, 4, 4, 2, 2]
# Epoch 1/50
# 20/20 - 23s - loss: 0.0411 - val_loss: 0.0533 - 23s/epoch - 1s/step
# Epoch 2/50
# 20/20 - 0s - loss: 0.0187 - val_loss: 0.0363 - 338ms/epoch - 17ms/step
# Epoch 3/50
# 20/20 - 0s - loss: 0.0111 - val_loss: 0.0343 - 321ms/epoch - 16ms/step
# Epoch 4/50
# 20/20 - 0s - loss: 0.0091 - val_loss: 0.0336 - 323ms/epoch - 16ms/step
# Epoch 5/50
# 20/20 - 0s - loss: 0.0092 - val_loss: 0.0315 - 324ms/epoch - 16ms/step
# Epoch 6/50
# 20/20 - 0s - loss: 0.0085 - val_loss: 0.0287 - 317ms/epoch - 16ms/step
# Epoch 7/50
# 20/20 - 0s - loss: 0.0074 - val_loss: 0.0253 - 317ms/epoch - 16ms/step
# Epoch 8/50
# 20/20 - 0s - loss: 0.0061 - val_loss: 0.0211 - 317ms/epoch - 16ms/step
# Epoch 9/50
# 20/20 - 0s - loss: 0.0042 - val_loss: 0.0165 - 315ms/epoch - 16ms/step
# Epoch 10/50
# 20/20 - 0s - loss: 0.0023 - val_loss: 0.0126 - 318ms/epoch - 16ms/step
# Epoch 11/50
# 20/20 - 0s - loss: 9.4901e-04 - val_loss: 0.0104 - 321ms/epoch - 16ms/step
# Epoch 12/50
# 20/20 - 0s - loss: 5.8961e-04 - val_loss: 0.0099 - 315ms/epoch - 16ms/step
# Epoch 13/50
# 20/20 - 0s - loss: 5.9209e-04 - val_loss: 0.0103 - 317ms/epoch - 16ms/step
# Epoch 14/50
# 20/20 - 0s - loss: 5.6010e-04 - val_loss: 0.0103 - 317ms/epoch - 16ms/step
# Epoch 15/50
# 20/20 - 0s - loss: 5.4259e-04 - val_loss: 0.0103 - 315ms/epoch - 16ms/step
# Epoch 16/50
# 20/20 - 0s - loss: 5.1682e-04 - val_loss: 0.0102 - 317ms/epoch - 16ms/step
# Epoch 17/50
# 20/20 - 0s - loss: 5.4963e-04 - val_loss: 0.0102 - 320ms/epoch - 16ms/step
# Epoch 18/50
# 20/20 - 0s - loss: 5.5474e-04 - val_loss: 0.0102 - 312ms/epoch - 16ms/step
# Epoch 19/50
# 20/20 - 0s - loss: 5.5197e-04 - val_loss: 0.0101 - 316ms/epoch - 16ms/step
# Epoch 20/50
# 20/20 - 0s - loss: 5.6286e-04 - val_loss: 0.0102 - 313ms/epoch - 16ms/step
# Epoch 21/50
# 20/20 - 0s - loss: 5.3319e-04 - val_loss: 0.0104 - 319ms/epoch - 16ms/step
# Epoch 22/50
# 20/20 - 0s - loss: 5.7826e-04 - val_loss: 0.0102 - 323ms/epoch - 16ms/step
# 20/20 [==============================] - 4s 4ms/step
# 9/9 [==============================] - 0s 4ms/step
# Train Score: 19.60 RMSE for 50 epochs
# Test Score: 94.28 RMSE for 50 epochs
# Training with LSTM layers: [4, 4, 2, 2]
# Epoch 1/50
# 20/20 - 17s - loss: 0.0483 - val_loss: 0.0751 - 17s/epoch - 837ms/step
# Epoch 2/50
# 20/20 - 0s - loss: 0.0349 - val_loss: 0.0592 - 233ms/epoch - 12ms/step
# Epoch 3/50
# 20/20 - 0s - loss: 0.0228 - val_loss: 0.0449 - 237ms/epoch - 12ms/step
# Epoch 4/50
# 20/20 - 0s - loss: 0.0143 - val_loss: 0.0368 - 291ms/epoch - 15ms/step
# Epoch 5/50
# 20/20 - 0s - loss: 0.0105 - val_loss: 0.0344 - 287ms/epoch - 14ms/step
# Epoch 6/50
# 20/20 - 0s - loss: 0.0092 - val_loss: 0.0335 - 263ms/epoch - 13ms/step
# Epoch 7/50
# 20/20 - 0s - loss: 0.0088 - val_loss: 0.0327 - 228ms/epoch - 11ms/step
# Epoch 8/50
# 20/20 - 0s - loss: 0.0085 - val_loss: 0.0316 - 227ms/epoch - 11ms/step
# Epoch 9/50
# 20/20 - 0s - loss: 0.0082 - val_loss: 0.0304 - 234ms/epoch - 12ms/step
# Epoch 10/50
# 20/20 - 0s - loss: 0.0078 - val_loss: 0.0291 - 254ms/epoch - 13ms/step
# Epoch 11/50
# 20/20 - 0s - loss: 0.0072 - val_loss: 0.0276 - 226ms/epoch - 11ms/step
# Epoch 12/50
# 20/20 - 0s - loss: 0.0067 - val_loss: 0.0259 - 225ms/epoch - 11ms/step
# Epoch 13/50
# 20/20 - 0s - loss: 0.0060 - val_loss: 0.0239 - 225ms/epoch - 11ms/step
# Epoch 14/50
# 20/20 - 0s - loss: 0.0054 - val_loss: 0.0218 - 245ms/epoch - 12ms/step
# Epoch 15/50
# 20/20 - 0s - loss: 0.0046 - val_loss: 0.0194 - 268ms/epoch - 13ms/step
# Epoch 16/50
# 20/20 - 0s - loss: 0.0036 - val_loss: 0.0169 - 255ms/epoch - 13ms/step
# Epoch 17/50
# 20/20 - 0s - loss: 0.0028 - val_loss: 0.0145 - 249ms/epoch - 12ms/step
# Epoch 18/50
# 20/20 - 0s - loss: 0.0019 - val_loss: 0.0125 - 223ms/epoch - 11ms/step
# Epoch 19/50
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.0111 - 239ms/epoch - 12ms/step
# Epoch 20/50
# 20/20 - 0s - loss: 0.0010 - val_loss: 0.0102 - 240ms/epoch - 12ms/step
# Epoch 21/50
# 20/20 - 0s - loss: 9.0648e-04 - val_loss: 0.0099 - 241ms/epoch - 12ms/step
# Epoch 22/50
# 20/20 - 0s - loss: 7.8354e-04 - val_loss: 0.0096 - 234ms/epoch - 12ms/step
# Epoch 23/50
# 20/20 - 0s - loss: 7.3864e-04 - val_loss: 0.0098 - 254ms/epoch - 13ms/step
# Epoch 24/50
# 20/20 - 0s - loss: 7.5053e-04 - val_loss: 0.0098 - 248ms/epoch - 12ms/step
# Epoch 25/50
# 20/20 - 0s - loss: 7.4641e-04 - val_loss: 0.0098 - 255ms/epoch - 13ms/step
# Epoch 26/50
# 20/20 - 0s - loss: 7.1331e-04 - val_loss: 0.0099 - 229ms/epoch - 11ms/step
# Epoch 27/50
# 20/20 - 0s - loss: 7.4612e-04 - val_loss: 0.0100 - 249ms/epoch - 12ms/step
# Epoch 28/50
# 20/20 - 0s - loss: 6.7607e-04 - val_loss: 0.0099 - 247ms/epoch - 12ms/step
# Epoch 29/50
# 20/20 - 0s - loss: 7.7404e-04 - val_loss: 0.0099 - 239ms/epoch - 12ms/step
# Epoch 30/50
# 20/20 - 0s - loss: 7.4430e-04 - val_loss: 0.0100 - 233ms/epoch - 12ms/step
# Epoch 31/50
# 20/20 - 0s - loss: 7.0134e-04 - val_loss: 0.0099 - 237ms/epoch - 12ms/step
# Epoch 32/50
# 20/20 - 0s - loss: 6.8539e-04 - val_loss: 0.0102 - 254ms/epoch - 13ms/step
# 20/20 [==============================] - 3s 3ms/step
# 9/9 [==============================] - 0s 3ms/step
# Train Score: 19.90 RMSE for 50 epochs
# Test Score: 93.98 RMSE for 50 epochs
# Training with LSTM layers: [2, 2]
# Epoch 1/50
# 20/20 - 8s - loss: 0.0215 - val_loss: 0.0315 - 8s/epoch - 406ms/step
# Epoch 2/50
# 20/20 - 0s - loss: 0.0091 - val_loss: 0.0237 - 155ms/epoch - 8ms/step
# Epoch 3/50
# 20/20 - 0s - loss: 0.0060 - val_loss: 0.0222 - 150ms/epoch - 8ms/step
# Epoch 4/50
# 20/20 - 0s - loss: 0.0052 - val_loss: 0.0217 - 144ms/epoch - 7ms/step
# Epoch 5/50
# 20/20 - 0s - loss: 0.0050 - val_loss: 0.0211 - 138ms/epoch - 7ms/step
# Epoch 6/50
# 20/20 - 0s - loss: 0.0048 - val_loss: 0.0202 - 133ms/epoch - 7ms/step
# Epoch 7/50
# 20/20 - 0s - loss: 0.0043 - val_loss: 0.0193 - 133ms/epoch - 7ms/step
# Epoch 8/50
# 20/20 - 0s - loss: 0.0040 - val_loss: 0.0183 - 139ms/epoch - 7ms/step
# Epoch 9/50
# 20/20 - 0s - loss: 0.0039 - val_loss: 0.0174 - 140ms/epoch - 7ms/step
# Epoch 10/50
# 20/20 - 0s - loss: 0.0035 - val_loss: 0.0165 - 142ms/epoch - 7ms/step
# Epoch 11/50
# 20/20 - 0s - loss: 0.0035 - val_loss: 0.0155 - 170ms/epoch - 9ms/step
# Epoch 12/50
# 20/20 - 0s - loss: 0.0029 - val_loss: 0.0148 - 172ms/epoch - 9ms/step
# Epoch 13/50
# 20/20 - 0s - loss: 0.0030 - val_loss: 0.0138 - 153ms/epoch - 8ms/step
# Epoch 14/50
# 20/20 - 0s - loss: 0.0025 - val_loss: 0.0130 - 152ms/epoch - 8ms/step
# Epoch 15/50
# 20/20 - 0s - loss: 0.0021 - val_loss: 0.0124 - 142ms/epoch - 7ms/step
# Epoch 16/50
# 20/20 - 0s - loss: 0.0021 - val_loss: 0.0116 - 140ms/epoch - 7ms/step
# Epoch 17/50
# 20/20 - 0s - loss: 0.0018 - val_loss: 0.0112 - 150ms/epoch - 8ms/step
# Epoch 18/50
# 20/20 - 0s - loss: 0.0018 - val_loss: 0.0106 - 141ms/epoch - 7ms/step
# Epoch 19/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.0103 - 148ms/epoch - 7ms/step
# Epoch 20/50
# 20/20 - 0s - loss: 0.0016 - val_loss: 0.0098 - 140ms/epoch - 7ms/step
# Epoch 21/50
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.0096 - 141ms/epoch - 7ms/step
# Epoch 22/50
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.0094 - 139ms/epoch - 7ms/step
# Epoch 23/50
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.0092 - 133ms/epoch - 7ms/step
# Epoch 24/50
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.0092 - 134ms/epoch - 7ms/step
# Epoch 25/50
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.0089 - 133ms/epoch - 7ms/step
# Epoch 26/50
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.0090 - 139ms/epoch - 7ms/step
# Epoch 27/50
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.0089 - 134ms/epoch - 7ms/step
# Epoch 28/50
# 20/20 - 0s - loss: 0.0010 - val_loss: 0.0088 - 132ms/epoch - 7ms/step
# Epoch 29/50
# 20/20 - 0s - loss: 9.7485e-04 - val_loss: 0.0089 - 132ms/epoch - 7ms/step
# Epoch 30/50
# 20/20 - 0s - loss: 9.4446e-04 - val_loss: 0.0088 - 134ms/epoch - 7ms/step
# Epoch 31/50
# 20/20 - 0s - loss: 9.5464e-04 - val_loss: 0.0088 - 135ms/epoch - 7ms/step
# Epoch 32/50
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.0087 - 132ms/epoch - 7ms/step
# Epoch 33/50
# 20/20 - 0s - loss: 8.5157e-04 - val_loss: 0.0089 - 132ms/epoch - 7ms/step
# Epoch 34/50
# 20/20 - 0s - loss: 9.5023e-04 - val_loss: 0.0087 - 162ms/epoch - 8ms/step
# Epoch 35/50
# 20/20 - 0s - loss: 8.6669e-04 - val_loss: 0.0088 - 164ms/epoch - 8ms/step
# Epoch 36/50
# 20/20 - 0s - loss: 9.5414e-04 - val_loss: 0.0087 - 137ms/epoch - 7ms/step
# Epoch 37/50
# 20/20 - 0s - loss: 9.3592e-04 - val_loss: 0.0088 - 138ms/epoch - 7ms/step
# Epoch 38/50
# 20/20 - 0s - loss: 8.8132e-04 - val_loss: 0.0087 - 138ms/epoch - 7ms/step
# Epoch 39/50
# 20/20 - 0s - loss: 8.3429e-04 - val_loss: 0.0087 - 153ms/epoch - 8ms/step
# Epoch 40/50
# 20/20 - 0s - loss: 7.4985e-04 - val_loss: 0.0087 - 149ms/epoch - 7ms/step
# Epoch 41/50
# 20/20 - 0s - loss: 7.4049e-04 - val_loss: 0.0087 - 152ms/epoch - 8ms/step
# Epoch 42/50
# 20/20 - 0s - loss: 7.7981e-04 - val_loss: 0.0087 - 133ms/epoch - 7ms/step
# 20/20 [==============================] - 1s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# Train Score: 19.48 RMSE for 50 epochs
# Test Score: 86.92 RMSE for 50 epochs
# Training for 100 epochs...
# Training with LSTM layers: [64, 64, 32, 32, 16, 16, 8, 8, 4, 4, 2, 2]
# Epoch 1/100
# 20/20 - 48s - loss: 0.0403 - val_loss: 0.0515 - 48s/epoch - 2s/step
# Epoch 2/100
# 20/20 - 1s - loss: 0.0191 - val_loss: 0.0400 - 717ms/epoch - 36ms/step
# Epoch 3/100
# 20/20 - 1s - loss: 0.0113 - val_loss: 0.0406 - 713ms/epoch - 36ms/step
# Epoch 4/100
# 20/20 - 1s - loss: 0.0117 - val_loss: 0.0402 - 728ms/epoch - 36ms/step
# Epoch 5/100
# 20/20 - 1s - loss: 0.0116 - val_loss: 0.0387 - 710ms/epoch - 35ms/step
# Epoch 6/100
# 20/20 - 1s - loss: 0.0092 - val_loss: 0.0320 - 688ms/epoch - 34ms/step
# Epoch 7/100
# 20/20 - 1s - loss: 0.0068 - val_loss: 0.0250 - 667ms/epoch - 33ms/step
# Epoch 8/100
# 20/20 - 1s - loss: 0.0040 - val_loss: 0.0200 - 687ms/epoch - 34ms/step
# Epoch 9/100
# 20/20 - 1s - loss: 0.0028 - val_loss: 0.0233 - 678ms/epoch - 34ms/step
# Epoch 10/100
# 20/20 - 1s - loss: 0.0037 - val_loss: 0.0177 - 683ms/epoch - 34ms/step
# Epoch 11/100
# 20/20 - 1s - loss: 0.0037 - val_loss: 0.0231 - 661ms/epoch - 33ms/step
# Epoch 12/100
# 20/20 - 1s - loss: 0.0035 - val_loss: 0.0189 - 661ms/epoch - 33ms/step
# Epoch 13/100
# 20/20 - 1s - loss: 0.0020 - val_loss: 0.0189 - 679ms/epoch - 34ms/step
# Epoch 14/100
# 20/20 - 1s - loss: 0.0014 - val_loss: 0.0180 - 662ms/epoch - 33ms/step
# Epoch 15/100
# 20/20 - 1s - loss: 0.0016 - val_loss: 0.0157 - 681ms/epoch - 34ms/step
# Epoch 16/100
# 20/20 - 1s - loss: 0.0013 - val_loss: 0.0170 - 664ms/epoch - 33ms/step
# Epoch 17/100
# 20/20 - 1s - loss: 0.0013 - val_loss: 0.0148 - 685ms/epoch - 34ms/step
# Epoch 18/100
# 20/20 - 1s - loss: 9.7221e-04 - val_loss: 0.0156 - 668ms/epoch - 33ms/step
# Epoch 19/100
# 20/20 - 1s - loss: 0.0012 - val_loss: 0.0135 - 699ms/epoch - 35ms/step
# Epoch 20/100
# 20/20 - 1s - loss: 8.4410e-04 - val_loss: 0.0148 - 660ms/epoch - 33ms/step
# Epoch 21/100
# 20/20 - 1s - loss: 0.0011 - val_loss: 0.0133 - 666ms/epoch - 33ms/step
# Epoch 22/100
# 20/20 - 1s - loss: 7.5946e-04 - val_loss: 0.0136 - 667ms/epoch - 33ms/step
# Epoch 23/100
# 20/20 - 1s - loss: 8.6152e-04 - val_loss: 0.0129 - 744ms/epoch - 37ms/step
# Epoch 24/100
# 20/20 - 1s - loss: 7.0967e-04 - val_loss: 0.0124 - 694ms/epoch - 35ms/step
# Epoch 25/100
# 20/20 - 1s - loss: 6.3859e-04 - val_loss: 0.0125 - 668ms/epoch - 33ms/step
# Epoch 26/100
# 20/20 - 1s - loss: 6.6577e-04 - val_loss: 0.0122 - 663ms/epoch - 33ms/step
# Epoch 27/100
# 20/20 - 1s - loss: 5.9475e-04 - val_loss: 0.0115 - 684ms/epoch - 34ms/step
# Epoch 28/100
# 20/20 - 1s - loss: 4.4708e-04 - val_loss: 0.0116 - 713ms/epoch - 36ms/step
# Epoch 29/100
# 20/20 - 1s - loss: 4.5576e-04 - val_loss: 0.0122 - 668ms/epoch - 33ms/step
# Epoch 30/100
# 20/20 - 1s - loss: 6.0263e-04 - val_loss: 0.0112 - 680ms/epoch - 34ms/step
# Epoch 31/100
# 20/20 - 1s - loss: 4.5657e-04 - val_loss: 0.0106 - 678ms/epoch - 34ms/step
# Epoch 32/100
# 20/20 - 1s - loss: 7.6479e-04 - val_loss: 0.0197 - 659ms/epoch - 33ms/step
# Epoch 33/100
# 20/20 - 1s - loss: 0.0029 - val_loss: 0.0137 - 688ms/epoch - 34ms/step
# Epoch 34/100
# 20/20 - 1s - loss: 7.3423e-04 - val_loss: 0.0117 - 663ms/epoch - 33ms/step
# Epoch 35/100
# 20/20 - 1s - loss: 0.0010 - val_loss: 0.0156 - 662ms/epoch - 33ms/step
# Epoch 36/100
# 20/20 - 1s - loss: 0.0013 - val_loss: 0.0133 - 662ms/epoch - 33ms/step
# Epoch 37/100
# 20/20 - 1s - loss: 6.0520e-04 - val_loss: 0.0138 - 666ms/epoch - 33ms/step
# Epoch 38/100
# 20/20 - 1s - loss: 7.2085e-04 - val_loss: 0.0126 - 660ms/epoch - 33ms/step
# Epoch 39/100
# 20/20 - 1s - loss: 4.7392e-04 - val_loss: 0.0126 - 725ms/epoch - 36ms/step
# Epoch 40/100
# 20/20 - 1s - loss: 4.8690e-04 - val_loss: 0.0126 - 691ms/epoch - 35ms/step
# Epoch 41/100
# 20/20 - 1s - loss: 4.5886e-04 - val_loss: 0.0118 - 695ms/epoch - 35ms/step
# 20/20 [==============================] - 8s 9ms/step
# 9/9 [==============================] - 0s 10ms/step
# Train Score: 18.87 RMSE for 100 epochs
# Test Score: 101.43 RMSE for 100 epochs
# Training with LSTM layers: [32, 32, 16, 16, 8, 8, 4, 4, 2, 2]
# Epoch 1/100
# 20/20 - 39s - loss: 0.0392 - val_loss: 0.0458 - 39s/epoch - 2s/step
# Epoch 2/100
# 20/20 - 1s - loss: 0.0172 - val_loss: 0.0383 - 534ms/epoch - 27ms/step
# Epoch 3/100
# 20/20 - 1s - loss: 0.0107 - val_loss: 0.0388 - 540ms/epoch - 27ms/step
# Epoch 4/100
# 20/20 - 1s - loss: 0.0117 - val_loss: 0.0362 - 512ms/epoch - 26ms/step
# Epoch 5/100
# 20/20 - 1s - loss: 0.0102 - val_loss: 0.0324 - 511ms/epoch - 26ms/step
# Epoch 6/100
# 20/20 - 1s - loss: 0.0078 - val_loss: 0.0220 - 511ms/epoch - 26ms/step
# Epoch 7/100
# 20/20 - 1s - loss: 0.0028 - val_loss: 0.0126 - 514ms/epoch - 26ms/step
# Epoch 8/100
# 20/20 - 1s - loss: 9.0398e-04 - val_loss: 0.0145 - 524ms/epoch - 26ms/step
# Epoch 9/100
# 20/20 - 1s - loss: 7.6654e-04 - val_loss: 0.0156 - 564ms/epoch - 28ms/step
# Epoch 10/100
# 20/20 - 1s - loss: 9.7505e-04 - val_loss: 0.0123 - 514ms/epoch - 26ms/step
# Epoch 11/100
# 20/20 - 1s - loss: 7.2290e-04 - val_loss: 0.0119 - 537ms/epoch - 27ms/step
# Epoch 12/100
# 20/20 - 1s - loss: 8.2427e-04 - val_loss: 0.0142 - 528ms/epoch - 26ms/step
# Epoch 13/100
# 20/20 - 1s - loss: 7.6091e-04 - val_loss: 0.0147 - 549ms/epoch - 27ms/step
# Epoch 14/100
# 20/20 - 1s - loss: 8.4467e-04 - val_loss: 0.0128 - 543ms/epoch - 27ms/step
# Epoch 15/100
# 20/20 - 1s - loss: 6.1844e-04 - val_loss: 0.0111 - 509ms/epoch - 25ms/step
# Epoch 16/100
# 20/20 - 1s - loss: 8.6251e-04 - val_loss: 0.0124 - 507ms/epoch - 25ms/step
# Epoch 17/100
# 20/20 - 1s - loss: 6.5376e-04 - val_loss: 0.0137 - 545ms/epoch - 27ms/step
# Epoch 18/100
# 20/20 - 1s - loss: 7.3987e-04 - val_loss: 0.0148 - 532ms/epoch - 27ms/step
# Epoch 19/100
# 20/20 - 1s - loss: 9.7858e-04 - val_loss: 0.0125 - 534ms/epoch - 27ms/step
# Epoch 20/100
# 20/20 - 1s - loss: 6.0669e-04 - val_loss: 0.0105 - 521ms/epoch - 26ms/step
# Epoch 21/100
# 20/20 - 1s - loss: 9.4356e-04 - val_loss: 0.0114 - 538ms/epoch - 27ms/step
# Epoch 22/100
# 20/20 - 1s - loss: 7.5153e-04 - val_loss: 0.0132 - 573ms/epoch - 29ms/step
# Epoch 23/100
# 20/20 - 1s - loss: 7.4545e-04 - val_loss: 0.0159 - 532ms/epoch - 27ms/step
# Epoch 24/100
# 20/20 - 1s - loss: 0.0013 - val_loss: 0.0147 - 560ms/epoch - 28ms/step
# Epoch 25/100
# 20/20 - 1s - loss: 0.0012 - val_loss: 0.0114 - 544ms/epoch - 27ms/step
# Epoch 26/100
# 20/20 - 1s - loss: 6.3267e-04 - val_loss: 0.0100 - 529ms/epoch - 26ms/step
# Epoch 27/100
# 20/20 - 1s - loss: 0.0016 - val_loss: 0.0133 - 540ms/epoch - 27ms/step
# Epoch 28/100
# 20/20 - 1s - loss: 7.3493e-04 - val_loss: 0.0139 - 648ms/epoch - 32ms/step
# Epoch 29/100
# 20/20 - 1s - loss: 7.5355e-04 - val_loss: 0.0156 - 614ms/epoch - 31ms/step
# Epoch 30/100
# 20/20 - 1s - loss: 0.0013 - val_loss: 0.0115 - 574ms/epoch - 29ms/step
# Epoch 31/100
# 20/20 - 1s - loss: 5.7400e-04 - val_loss: 0.0105 - 526ms/epoch - 26ms/step
# Epoch 32/100
# 20/20 - 1s - loss: 9.7026e-04 - val_loss: 0.0120 - 557ms/epoch - 28ms/step
# Epoch 33/100
# 20/20 - 1s - loss: 6.4677e-04 - val_loss: 0.0140 - 549ms/epoch - 27ms/step
# Epoch 34/100
# 20/20 - 1s - loss: 7.8972e-04 - val_loss: 0.0149 - 508ms/epoch - 25ms/step
# Epoch 35/100
# 20/20 - 1s - loss: 9.9871e-04 - val_loss: 0.0118 - 506ms/epoch - 25ms/step
# Epoch 36/100
# 20/20 - 1s - loss: 5.3403e-04 - val_loss: 0.0103 - 511ms/epoch - 26ms/step
# 20/20 [==============================] - 8s 8ms/step
# 9/9 [==============================] - 0s 6ms/step
# Train Score: 25.14 RMSE for 100 epochs
# Test Score: 94.43 RMSE for 100 epochs
# Training with LSTM layers: [16, 16, 8, 8, 4, 4, 2, 2]
# Epoch 1/100
# 20/20 - 29s - loss: 0.0409 - val_loss: 0.0528 - 29s/epoch - 1s/step
# Epoch 2/100
# 20/20 - 0s - loss: 0.0189 - val_loss: 0.0378 - 409ms/epoch - 20ms/step
# Epoch 3/100
# 20/20 - 0s - loss: 0.0112 - val_loss: 0.0373 - 462ms/epoch - 23ms/step
# Epoch 4/100
# 20/20 - 0s - loss: 0.0103 - val_loss: 0.0368 - 446ms/epoch - 22ms/step
# Epoch 5/100
# 20/20 - 0s - loss: 0.0105 - val_loss: 0.0347 - 424ms/epoch - 21ms/step
# Epoch 6/100
# 20/20 - 0s - loss: 0.0096 - val_loss: 0.0318 - 402ms/epoch - 20ms/step
# Epoch 7/100
# 20/20 - 0s - loss: 0.0081 - val_loss: 0.0270 - 402ms/epoch - 20ms/step
# Epoch 8/100
# 20/20 - 0s - loss: 0.0055 - val_loss: 0.0199 - 416ms/epoch - 21ms/step
# Epoch 9/100
# 20/20 - 0s - loss: 0.0021 - val_loss: 0.0138 - 422ms/epoch - 21ms/step
# Epoch 10/100
# 20/20 - 0s - loss: 8.8379e-04 - val_loss: 0.0132 - 427ms/epoch - 21ms/step
# Epoch 11/100
# 20/20 - 0s - loss: 7.8189e-04 - val_loss: 0.0148 - 420ms/epoch - 21ms/step
# Epoch 12/100
# 20/20 - 0s - loss: 8.6802e-04 - val_loss: 0.0129 - 420ms/epoch - 21ms/step
# Epoch 13/100
# 20/20 - 0s - loss: 6.8294e-04 - val_loss: 0.0118 - 407ms/epoch - 20ms/step
# Epoch 14/100
# 20/20 - 0s - loss: 7.1492e-04 - val_loss: 0.0128 - 428ms/epoch - 21ms/step
# Epoch 15/100
# 20/20 - 0s - loss: 6.4402e-04 - val_loss: 0.0130 - 418ms/epoch - 21ms/step
# Epoch 16/100
# 20/20 - 0s - loss: 6.1453e-04 - val_loss: 0.0122 - 420ms/epoch - 21ms/step
# Epoch 17/100
# 20/20 - 0s - loss: 6.5372e-04 - val_loss: 0.0121 - 429ms/epoch - 21ms/step
# Epoch 18/100
# 20/20 - 0s - loss: 6.1233e-04 - val_loss: 0.0124 - 431ms/epoch - 22ms/step
# Epoch 19/100
# 20/20 - 0s - loss: 5.9704e-04 - val_loss: 0.0123 - 407ms/epoch - 20ms/step
# Epoch 20/100
# 20/20 - 0s - loss: 6.0639e-04 - val_loss: 0.0121 - 415ms/epoch - 21ms/step
# Epoch 21/100
# 20/20 - 0s - loss: 6.2193e-04 - val_loss: 0.0120 - 408ms/epoch - 20ms/step
# Epoch 22/100
# 20/20 - 0s - loss: 6.0142e-04 - val_loss: 0.0119 - 405ms/epoch - 20ms/step
# Epoch 23/100
# 20/20 - 0s - loss: 6.0036e-04 - val_loss: 0.0119 - 429ms/epoch - 21ms/step
# 20/20 [==============================] - 7s 5ms/step
# 9/9 [==============================] - 0s 5ms/step
# Train Score: 21.46 RMSE for 100 epochs
# Test Score: 101.53 RMSE for 100 epochs
# Training with LSTM layers: [8, 8, 4, 4, 2, 2]
# Epoch 1/100
# 20/20 - 22s - loss: 0.0456 - val_loss: 0.0674 - 22s/epoch - 1s/step
# Epoch 2/100
# 20/20 - 0s - loss: 0.0273 - val_loss: 0.0471 - 328ms/epoch - 16ms/step
# Epoch 3/100
# 20/20 - 0s - loss: 0.0157 - val_loss: 0.0377 - 323ms/epoch - 16ms/step
# Epoch 4/100
# 20/20 - 0s - loss: 0.0111 - val_loss: 0.0364 - 333ms/epoch - 17ms/step
# Epoch 5/100
# 20/20 - 0s - loss: 0.0099 - val_loss: 0.0361 - 322ms/epoch - 16ms/step
# Epoch 6/100
# 20/20 - 0s - loss: 0.0099 - val_loss: 0.0352 - 313ms/epoch - 16ms/step
# Epoch 7/100
# 20/20 - 0s - loss: 0.0096 - val_loss: 0.0339 - 322ms/epoch - 16ms/step
# Epoch 8/100
# 20/20 - 0s - loss: 0.0091 - val_loss: 0.0323 - 322ms/epoch - 16ms/step
# Epoch 9/100
# 20/20 - 0s - loss: 0.0085 - val_loss: 0.0302 - 333ms/epoch - 17ms/step
# Epoch 10/100
# 20/20 - 0s - loss: 0.0076 - val_loss: 0.0275 - 332ms/epoch - 17ms/step
# Epoch 11/100
# 20/20 - 0s - loss: 0.0064 - val_loss: 0.0239 - 334ms/epoch - 17ms/step
# Epoch 12/100
# 20/20 - 0s - loss: 0.0048 - val_loss: 0.0196 - 318ms/epoch - 16ms/step
# Epoch 13/100
# 20/20 - 0s - loss: 0.0028 - val_loss: 0.0156 - 322ms/epoch - 16ms/step
# Epoch 14/100
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.0130 - 320ms/epoch - 16ms/step
# Epoch 15/100
# 20/20 - 0s - loss: 6.6621e-04 - val_loss: 0.0124 - 314ms/epoch - 16ms/step
# Epoch 16/100
# 20/20 - 0s - loss: 6.0270e-04 - val_loss: 0.0126 - 315ms/epoch - 16ms/step
# Epoch 17/100
# 20/20 - 0s - loss: 6.2605e-04 - val_loss: 0.0124 - 323ms/epoch - 16ms/step
# Epoch 18/100
# 20/20 - 0s - loss: 6.2044e-04 - val_loss: 0.0121 - 322ms/epoch - 16ms/step
# Epoch 19/100
# 20/20 - 0s - loss: 5.9366e-04 - val_loss: 0.0119 - 322ms/epoch - 16ms/step
# Epoch 20/100
# 20/20 - 0s - loss: 5.8744e-04 - val_loss: 0.0119 - 322ms/epoch - 16ms/step
# Epoch 21/100
# 20/20 - 0s - loss: 5.6678e-04 - val_loss: 0.0118 - 319ms/epoch - 16ms/step
# Epoch 22/100
# 20/20 - 0s - loss: 5.4983e-04 - val_loss: 0.0116 - 328ms/epoch - 16ms/step
# Epoch 23/100
# 20/20 - 0s - loss: 5.4563e-04 - val_loss: 0.0116 - 325ms/epoch - 16ms/step
# Epoch 24/100
# 20/20 - 0s - loss: 5.8365e-04 - val_loss: 0.0117 - 335ms/epoch - 17ms/step
# Epoch 25/100
# 20/20 - 0s - loss: 5.4570e-04 - val_loss: 0.0115 - 344ms/epoch - 17ms/step
# Epoch 26/100
# 20/20 - 0s - loss: 5.4890e-04 - val_loss: 0.0114 - 319ms/epoch - 16ms/step
# Epoch 27/100
# 20/20 - 0s - loss: 5.3485e-04 - val_loss: 0.0114 - 315ms/epoch - 16ms/step
# Epoch 28/100
# 20/20 - 0s - loss: 5.7031e-04 - val_loss: 0.0116 - 315ms/epoch - 16ms/step
# Epoch 29/100
# 20/20 - 0s - loss: 5.3669e-04 - val_loss: 0.0115 - 315ms/epoch - 16ms/step
# Epoch 30/100
# 20/20 - 0s - loss: 5.7569e-04 - val_loss: 0.0114 - 323ms/epoch - 16ms/step
# Epoch 31/100
# 20/20 - 0s - loss: 5.8225e-04 - val_loss: 0.0115 - 324ms/epoch - 16ms/step
# Epoch 32/100
# 20/20 - 0s - loss: 5.4477e-04 - val_loss: 0.0116 - 325ms/epoch - 16ms/step
# Epoch 33/100
# 20/20 - 0s - loss: 5.6968e-04 - val_loss: 0.0114 - 337ms/epoch - 17ms/step
# Epoch 34/100
# 20/20 - 0s - loss: 5.3052e-04 - val_loss: 0.0114 - 326ms/epoch - 16ms/step
# Epoch 35/100
# 20/20 - 0s - loss: 5.2437e-04 - val_loss: 0.0114 - 351ms/epoch - 18ms/step
# Epoch 36/100
# 20/20 - 0s - loss: 5.5498e-04 - val_loss: 0.0114 - 324ms/epoch - 16ms/step
# Epoch 37/100
# 20/20 - 0s - loss: 5.3379e-04 - val_loss: 0.0115 - 319ms/epoch - 16ms/step
# Epoch 38/100
# 20/20 - 0s - loss: 5.4806e-04 - val_loss: 0.0114 - 316ms/epoch - 16ms/step
# Epoch 39/100
# 20/20 - 0s - loss: 5.1368e-04 - val_loss: 0.0113 - 374ms/epoch - 19ms/step
# Epoch 40/100
# 20/20 - 0s - loss: 5.4009e-04 - val_loss: 0.0113 - 323ms/epoch - 16ms/step
# Epoch 41/100
# 20/20 - 0s - loss: 5.3900e-04 - val_loss: 0.0114 - 314ms/epoch - 16ms/step
# Epoch 42/100
# 20/20 - 0s - loss: 4.9702e-04 - val_loss: 0.0115 - 325ms/epoch - 16ms/step
# Epoch 43/100
# 20/20 - 0s - loss: 5.4414e-04 - val_loss: 0.0113 - 317ms/epoch - 16ms/step
# Epoch 44/100
# 20/20 - 0s - loss: 5.4730e-04 - val_loss: 0.0113 - 317ms/epoch - 16ms/step
# Epoch 45/100
# 20/20 - 0s - loss: 5.6397e-04 - val_loss: 0.0115 - 319ms/epoch - 16ms/step
# Epoch 46/100
# 20/20 - 0s - loss: 5.0591e-04 - val_loss: 0.0115 - 318ms/epoch - 16ms/step
# Epoch 47/100
# 20/20 - 0s - loss: 5.0270e-04 - val_loss: 0.0113 - 320ms/epoch - 16ms/step
# Epoch 48/100
# 20/20 - 0s - loss: 4.9828e-04 - val_loss: 0.0112 - 315ms/epoch - 16ms/step
# Epoch 49/100
# 20/20 - 0s - loss: 5.1400e-04 - val_loss: 0.0112 - 316ms/epoch - 16ms/step
# Epoch 50/100
# 20/20 - 0s - loss: 5.3352e-04 - val_loss: 0.0114 - 315ms/epoch - 16ms/step
# Epoch 51/100
# 20/20 - 0s - loss: 5.2119e-04 - val_loss: 0.0113 - 339ms/epoch - 17ms/step
# Epoch 52/100
# 20/20 - 0s - loss: 5.1896e-04 - val_loss: 0.0112 - 409ms/epoch - 20ms/step
# Epoch 53/100
# 20/20 - 0s - loss: 5.1361e-04 - val_loss: 0.0113 - 481ms/epoch - 24ms/step
# Epoch 54/100
# 20/20 - 0s - loss: 5.1122e-04 - val_loss: 0.0113 - 410ms/epoch - 20ms/step
# Epoch 55/100
# 20/20 - 0s - loss: 5.2349e-04 - val_loss: 0.0114 - 382ms/epoch - 19ms/step
# Epoch 56/100
# 20/20 - 0s - loss: 4.8081e-04 - val_loss: 0.0112 - 338ms/epoch - 17ms/step
# Epoch 57/100
# 20/20 - 0s - loss: 4.8910e-04 - val_loss: 0.0112 - 347ms/epoch - 17ms/step
# Epoch 58/100
# 20/20 - 0s - loss: 5.0343e-04 - val_loss: 0.0113 - 342ms/epoch - 17ms/step
# Epoch 59/100
# 20/20 - 0s - loss: 4.9827e-04 - val_loss: 0.0112 - 362ms/epoch - 18ms/step
# Epoch 60/100
# 20/20 - 0s - loss: 5.1069e-04 - val_loss: 0.0111 - 330ms/epoch - 17ms/step
# Epoch 61/100
# 20/20 - 0s - loss: 4.9400e-04 - val_loss: 0.0113 - 314ms/epoch - 16ms/step
# Epoch 62/100
# 20/20 - 0s - loss: 4.8397e-04 - val_loss: 0.0113 - 321ms/epoch - 16ms/step
# Epoch 63/100
# 20/20 - 0s - loss: 5.0401e-04 - val_loss: 0.0112 - 328ms/epoch - 16ms/step
# Epoch 64/100
# 20/20 - 0s - loss: 5.0896e-04 - val_loss: 0.0111 - 312ms/epoch - 16ms/step
# Epoch 65/100
# 20/20 - 0s - loss: 4.8149e-04 - val_loss: 0.0111 - 312ms/epoch - 16ms/step
# Epoch 66/100
# 20/20 - 0s - loss: 4.9563e-04 - val_loss: 0.0111 - 319ms/epoch - 16ms/step
# Epoch 67/100
# 20/20 - 0s - loss: 4.9136e-04 - val_loss: 0.0111 - 331ms/epoch - 17ms/step
# Epoch 68/100
# 20/20 - 0s - loss: 4.7405e-04 - val_loss: 0.0111 - 316ms/epoch - 16ms/step
# Epoch 69/100
# 20/20 - 0s - loss: 4.8720e-04 - val_loss: 0.0111 - 309ms/epoch - 15ms/step
# Epoch 70/100
# 20/20 - 0s - loss: 4.9946e-04 - val_loss: 0.0111 - 310ms/epoch - 15ms/step
# Epoch 71/100
# 20/20 - 0s - loss: 4.9506e-04 - val_loss: 0.0110 - 315ms/epoch - 16ms/step
# Epoch 72/100
# 20/20 - 0s - loss: 4.7131e-04 - val_loss: 0.0109 - 320ms/epoch - 16ms/step
# Epoch 73/100
# 20/20 - 0s - loss: 4.9236e-04 - val_loss: 0.0110 - 311ms/epoch - 16ms/step
# Epoch 74/100
# 20/20 - 0s - loss: 4.7116e-04 - val_loss: 0.0111 - 309ms/epoch - 15ms/step
# Epoch 75/100
# 20/20 - 0s - loss: 4.9173e-04 - val_loss: 0.0113 - 313ms/epoch - 16ms/step
# Epoch 76/100
# 20/20 - 0s - loss: 5.0638e-04 - val_loss: 0.0111 - 328ms/epoch - 16ms/step
# Epoch 77/100
# 20/20 - 0s - loss: 4.8484e-04 - val_loss: 0.0112 - 319ms/epoch - 16ms/step
# Epoch 78/100
# 20/20 - 0s - loss: 4.5904e-04 - val_loss: 0.0110 - 314ms/epoch - 16ms/step
# Epoch 79/100
# 20/20 - 0s - loss: 4.8175e-04 - val_loss: 0.0109 - 320ms/epoch - 16ms/step
# Epoch 80/100
# 20/20 - 0s - loss: 4.8895e-04 - val_loss: 0.0108 - 309ms/epoch - 15ms/step
# Epoch 81/100
# 20/20 - 0s - loss: 4.7905e-04 - val_loss: 0.0110 - 308ms/epoch - 15ms/step
# Epoch 82/100
# 20/20 - 0s - loss: 4.7106e-04 - val_loss: 0.0111 - 323ms/epoch - 16ms/step
# Epoch 83/100
# 20/20 - 0s - loss: 4.6385e-04 - val_loss: 0.0109 - 355ms/epoch - 18ms/step
# Epoch 84/100
# 20/20 - 0s - loss: 4.7979e-04 - val_loss: 0.0108 - 325ms/epoch - 16ms/step
# Epoch 85/100
# 20/20 - 0s - loss: 4.8904e-04 - val_loss: 0.0110 - 322ms/epoch - 16ms/step
# Epoch 86/100
# 20/20 - 0s - loss: 4.6009e-04 - val_loss: 0.0108 - 322ms/epoch - 16ms/step
# Epoch 87/100
# 20/20 - 0s - loss: 5.0232e-04 - val_loss: 0.0110 - 315ms/epoch - 16ms/step
# Epoch 88/100
# 20/20 - 0s - loss: 4.7317e-04 - val_loss: 0.0111 - 320ms/epoch - 16ms/step
# Epoch 89/100
# 20/20 - 0s - loss: 4.7620e-04 - val_loss: 0.0110 - 336ms/epoch - 17ms/step
# Epoch 90/100
# 20/20 - 0s - loss: 4.7837e-04 - val_loss: 0.0111 - 312ms/epoch - 16ms/step
# Epoch 91/100
# 20/20 - 0s - loss: 4.6148e-04 - val_loss: 0.0110 - 353ms/epoch - 18ms/step
# Epoch 92/100
# 20/20 - 0s - loss: 4.6651e-04 - val_loss: 0.0107 - 354ms/epoch - 18ms/step
# Epoch 93/100
# 20/20 - 0s - loss: 4.3503e-04 - val_loss: 0.0104 - 329ms/epoch - 16ms/step
# Epoch 94/100
# 20/20 - 0s - loss: 5.0396e-04 - val_loss: 0.0105 - 310ms/epoch - 16ms/step
# Epoch 95/100
# 20/20 - 0s - loss: 4.9148e-04 - val_loss: 0.0106 - 340ms/epoch - 17ms/step
# Epoch 96/100
# 20/20 - 0s - loss: 4.8020e-04 - val_loss: 0.0110 - 326ms/epoch - 16ms/step
# Epoch 97/100
# 20/20 - 0s - loss: 4.9849e-04 - val_loss: 0.0113 - 321ms/epoch - 16ms/step
# Epoch 98/100
# 20/20 - 0s - loss: 4.8199e-04 - val_loss: 0.0114 - 405ms/epoch - 20ms/step
# Epoch 99/100
# 20/20 - 0s - loss: 4.8475e-04 - val_loss: 0.0110 - 340ms/epoch - 17ms/step
# Epoch 100/100
# 20/20 - 0s - loss: 4.4953e-04 - val_loss: 0.0110 - 325ms/epoch - 16ms/step
# 20/20 [==============================] - 6s 5ms/step
# 9/9 [==============================] - 0s 4ms/step
# Train Score: 18.28 RMSE for 100 epochs
# Test Score: 97.64 RMSE for 100 epochs
# Training with LSTM layers: [4, 4, 2, 2]
# Epoch 1/100
# 20/20 - 15s - loss: 0.0431 - val_loss: 0.0626 - 15s/epoch - 734ms/step
# Epoch 2/100
# 20/20 - 0s - loss: 0.0247 - val_loss: 0.0436 - 239ms/epoch - 12ms/step
# Epoch 3/100
# 20/20 - 0s - loss: 0.0139 - val_loss: 0.0349 - 228ms/epoch - 11ms/step
# Epoch 4/100
# 20/20 - 0s - loss: 0.0100 - val_loss: 0.0329 - 228ms/epoch - 11ms/step
# Epoch 5/100
# 20/20 - 0s - loss: 0.0088 - val_loss: 0.0323 - 227ms/epoch - 11ms/step
# Epoch 6/100
# 20/20 - 0s - loss: 0.0084 - val_loss: 0.0315 - 223ms/epoch - 11ms/step
# Epoch 7/100
# 20/20 - 0s - loss: 0.0081 - val_loss: 0.0304 - 222ms/epoch - 11ms/step
# Epoch 8/100
# 20/20 - 0s - loss: 0.0077 - val_loss: 0.0291 - 222ms/epoch - 11ms/step
# Epoch 9/100
# 20/20 - 0s - loss: 0.0073 - val_loss: 0.0278 - 223ms/epoch - 11ms/step
# Epoch 10/100
# 20/20 - 0s - loss: 0.0069 - val_loss: 0.0262 - 222ms/epoch - 11ms/step
# Epoch 11/100
# 20/20 - 0s - loss: 0.0064 - val_loss: 0.0245 - 223ms/epoch - 11ms/step
# Epoch 12/100
# 20/20 - 0s - loss: 0.0057 - val_loss: 0.0225 - 223ms/epoch - 11ms/step
# Epoch 13/100
# 20/20 - 0s - loss: 0.0050 - val_loss: 0.0205 - 230ms/epoch - 11ms/step
# Epoch 14/100
# 20/20 - 0s - loss: 0.0043 - val_loss: 0.0182 - 223ms/epoch - 11ms/step
# Epoch 15/100
# 20/20 - 0s - loss: 0.0037 - val_loss: 0.0159 - 227ms/epoch - 11ms/step
# Epoch 16/100
# 20/20 - 0s - loss: 0.0027 - val_loss: 0.0138 - 232ms/epoch - 12ms/step
# Epoch 17/100
# 20/20 - 0s - loss: 0.0021 - val_loss: 0.0120 - 250ms/epoch - 13ms/step
# Epoch 18/100
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.0106 - 235ms/epoch - 12ms/step
# Epoch 19/100
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.0098 - 251ms/epoch - 13ms/step
# Epoch 20/100
# 20/20 - 0s - loss: 9.6764e-04 - val_loss: 0.0094 - 235ms/epoch - 12ms/step
# Epoch 21/100
# 20/20 - 0s - loss: 8.7339e-04 - val_loss: 0.0092 - 225ms/epoch - 11ms/step
# Epoch 22/100
# 20/20 - 0s - loss: 8.5401e-04 - val_loss: 0.0091 - 224ms/epoch - 11ms/step
# Epoch 23/100
# 20/20 - 0s - loss: 9.2421e-04 - val_loss: 0.0091 - 226ms/epoch - 11ms/step
# Epoch 24/100
# 20/20 - 0s - loss: 8.0964e-04 - val_loss: 0.0091 - 230ms/epoch - 12ms/step
# Epoch 25/100
# 20/20 - 0s - loss: 8.3240e-04 - val_loss: 0.0089 - 237ms/epoch - 12ms/step
# Epoch 26/100
# 20/20 - 0s - loss: 7.9252e-04 - val_loss: 0.0090 - 227ms/epoch - 11ms/step
# Epoch 27/100
# 20/20 - 0s - loss: 8.4803e-04 - val_loss: 0.0090 - 268ms/epoch - 13ms/step
# Epoch 28/100
# 20/20 - 0s - loss: 7.9674e-04 - val_loss: 0.0090 - 244ms/epoch - 12ms/step
# Epoch 29/100
# 20/20 - 0s - loss: 7.6635e-04 - val_loss: 0.0090 - 224ms/epoch - 11ms/step
# Epoch 30/100
# 20/20 - 0s - loss: 8.0502e-04 - val_loss: 0.0090 - 250ms/epoch - 12ms/step
# Epoch 31/100
# 20/20 - 0s - loss: 7.8472e-04 - val_loss: 0.0089 - 255ms/epoch - 13ms/step
# Epoch 32/100
# 20/20 - 0s - loss: 7.7548e-04 - val_loss: 0.0091 - 238ms/epoch - 12ms/step
# Epoch 33/100
# 20/20 - 0s - loss: 8.1263e-04 - val_loss: 0.0090 - 260ms/epoch - 13ms/step
# Epoch 34/100
# 20/20 - 0s - loss: 8.3279e-04 - val_loss: 0.0089 - 225ms/epoch - 11ms/step
# Epoch 35/100
# 20/20 - 0s - loss: 7.1892e-04 - val_loss: 0.0090 - 233ms/epoch - 12ms/step
# Epoch 36/100
# 20/20 - 0s - loss: 7.3954e-04 - val_loss: 0.0091 - 263ms/epoch - 13ms/step
# Epoch 37/100
# 20/20 - 0s - loss: 8.1299e-04 - val_loss: 0.0091 - 276ms/epoch - 14ms/step
# Epoch 38/100
# 20/20 - 0s - loss: 6.9010e-04 - val_loss: 0.0090 - 248ms/epoch - 12ms/step
# Epoch 39/100
# 20/20 - 0s - loss: 7.1437e-04 - val_loss: 0.0090 - 231ms/epoch - 12ms/step
# Epoch 40/100
# 20/20 - 0s - loss: 7.8736e-04 - val_loss: 0.0089 - 230ms/epoch - 11ms/step
# Epoch 41/100
# 20/20 - 0s - loss: 7.1185e-04 - val_loss: 0.0090 - 253ms/epoch - 13ms/step
# 20/20 [==============================] - 3s 3ms/step
# 9/9 [==============================] - 0s 3ms/step
# Train Score: 20.04 RMSE for 100 epochs
# Test Score: 88.38 RMSE for 100 epochs
# Training with LSTM layers: [2, 2]
# Epoch 1/100
# 20/20 - 9s - loss: 0.0449 - val_loss: 0.0718 - 9s/epoch - 469ms/step
# Epoch 2/100
# 20/20 - 0s - loss: 0.0345 - val_loss: 0.0597 - 144ms/epoch - 7ms/step
# Epoch 3/100
# 20/20 - 0s - loss: 0.0251 - val_loss: 0.0489 - 140ms/epoch - 7ms/step
# Epoch 4/100
# 20/20 - 0s - loss: 0.0174 - val_loss: 0.0406 - 140ms/epoch - 7ms/step
# Epoch 5/100
# 20/20 - 0s - loss: 0.0124 - val_loss: 0.0357 - 141ms/epoch - 7ms/step
# Epoch 6/100
# 20/20 - 0s - loss: 0.0098 - val_loss: 0.0333 - 138ms/epoch - 7ms/step
# Epoch 7/100
# 20/20 - 0s - loss: 0.0088 - val_loss: 0.0321 - 149ms/epoch - 7ms/step
# Epoch 8/100
# 20/20 - 0s - loss: 0.0083 - val_loss: 0.0313 - 144ms/epoch - 7ms/step
# Epoch 9/100
# 20/20 - 0s - loss: 0.0079 - val_loss: 0.0307 - 139ms/epoch - 7ms/step
# Epoch 10/100
# 20/20 - 0s - loss: 0.0076 - val_loss: 0.0300 - 136ms/epoch - 7ms/step
# Epoch 11/100
# 20/20 - 0s - loss: 0.0076 - val_loss: 0.0294 - 138ms/epoch - 7ms/step
# Epoch 12/100
# 20/20 - 0s - loss: 0.0074 - val_loss: 0.0286 - 144ms/epoch - 7ms/step
# Epoch 13/100
# 20/20 - 0s - loss: 0.0070 - val_loss: 0.0279 - 138ms/epoch - 7ms/step
# Epoch 14/100
# 20/20 - 0s - loss: 0.0066 - val_loss: 0.0270 - 136ms/epoch - 7ms/step
# Epoch 15/100
# 20/20 - 0s - loss: 0.0063 - val_loss: 0.0261 - 135ms/epoch - 7ms/step
# Epoch 16/100
# 20/20 - 0s - loss: 0.0061 - val_loss: 0.0252 - 137ms/epoch - 7ms/step
# Epoch 17/100
# 20/20 - 0s - loss: 0.0055 - val_loss: 0.0242 - 141ms/epoch - 7ms/step
# Epoch 18/100
# 20/20 - 0s - loss: 0.0052 - val_loss: 0.0231 - 164ms/epoch - 8ms/step
# Epoch 19/100
# 20/20 - 0s - loss: 0.0049 - val_loss: 0.0219 - 142ms/epoch - 7ms/step
# Epoch 20/100
# 20/20 - 0s - loss: 0.0046 - val_loss: 0.0207 - 136ms/epoch - 7ms/step
# Epoch 21/100
# 20/20 - 0s - loss: 0.0042 - val_loss: 0.0193 - 137ms/epoch - 7ms/step
# Epoch 22/100
# 20/20 - 0s - loss: 0.0037 - val_loss: 0.0179 - 137ms/epoch - 7ms/step
# Epoch 23/100
# 20/20 - 0s - loss: 0.0032 - val_loss: 0.0165 - 146ms/epoch - 7ms/step
# Epoch 24/100
# 20/20 - 0s - loss: 0.0029 - val_loss: 0.0152 - 148ms/epoch - 7ms/step
# Epoch 25/100
# 20/20 - 0s - loss: 0.0022 - val_loss: 0.0139 - 139ms/epoch - 7ms/step
# Epoch 26/100
# 20/20 - 0s - loss: 0.0019 - val_loss: 0.0128 - 154ms/epoch - 8ms/step
# Epoch 27/100
# 20/20 - 0s - loss: 0.0019 - val_loss: 0.0117 - 150ms/epoch - 8ms/step
# Epoch 28/100
# 20/20 - 0s - loss: 0.0016 - val_loss: 0.0110 - 143ms/epoch - 7ms/step
# Epoch 29/100
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.0105 - 149ms/epoch - 7ms/step
# Epoch 30/100
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.0100 - 154ms/epoch - 8ms/step
# Epoch 31/100
# 20/20 - 0s - loss: 9.2533e-04 - val_loss: 0.0098 - 140ms/epoch - 7ms/step
# Epoch 32/100
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.0096 - 145ms/epoch - 7ms/step
# Epoch 33/100
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.0095 - 138ms/epoch - 7ms/step
# Epoch 34/100
# 20/20 - 0s - loss: 9.7378e-04 - val_loss: 0.0096 - 136ms/epoch - 7ms/step
# Epoch 35/100
# 20/20 - 0s - loss: 9.4441e-04 - val_loss: 0.0095 - 140ms/epoch - 7ms/step
# Epoch 36/100
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.0093 - 142ms/epoch - 7ms/step
# Epoch 37/100
# 20/20 - 0s - loss: 9.3581e-04 - val_loss: 0.0094 - 140ms/epoch - 7ms/step
# Epoch 38/100
# 20/20 - 0s - loss: 0.0010 - val_loss: 0.0093 - 143ms/epoch - 7ms/step
# Epoch 39/100
# 20/20 - 0s - loss: 9.4928e-04 - val_loss: 0.0094 - 148ms/epoch - 7ms/step
# Epoch 40/100
# 20/20 - 0s - loss: 9.5458e-04 - val_loss: 0.0094 - 155ms/epoch - 8ms/step
# Epoch 41/100
# 20/20 - 0s - loss: 9.3372e-04 - val_loss: 0.0094 - 138ms/epoch - 7ms/step
# Epoch 42/100
# 20/20 - 0s - loss: 8.9167e-04 - val_loss: 0.0094 - 137ms/epoch - 7ms/step
# Epoch 43/100
# 20/20 - 0s - loss: 9.0534e-04 - val_loss: 0.0094 - 140ms/epoch - 7ms/step
# Epoch 44/100
# 20/20 - 0s - loss: 9.0054e-04 - val_loss: 0.0095 - 145ms/epoch - 7ms/step
# Epoch 45/100
# 20/20 - 0s - loss: 9.3766e-04 - val_loss: 0.0094 - 141ms/epoch - 7ms/step
# Epoch 46/100
# 20/20 - 0s - loss: 8.1246e-04 - val_loss: 0.0094 - 136ms/epoch - 7ms/step
# 20/20 [==============================] - 1s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# Train Score: 20.93 RMSE for 100 epochs
# Test Score: 90.37 RMSE for 100 epochs
# Training for 150 epochs...
# Training with LSTM layers: [64, 64, 32, 32, 16, 16, 8, 8, 4, 4, 2, 2]
# Epoch 1/150
# 20/20 - 46s - loss: 0.0397 - val_loss: 0.0440 - 46s/epoch - 2s/step
# Epoch 2/150
# 20/20 - 1s - loss: 0.0171 - val_loss: 0.0389 - 713ms/epoch - 36ms/step
# Epoch 3/150
# 20/20 - 1s - loss: 0.0108 - val_loss: 0.0396 - 766ms/epoch - 38ms/step
# Epoch 4/150
# 20/20 - 1s - loss: 0.0119 - val_loss: 0.0369 - 759ms/epoch - 38ms/step
# Epoch 5/150
# 20/20 - 1s - loss: 0.0091 - val_loss: 0.0305 - 761ms/epoch - 38ms/step
# Epoch 6/150
# 20/20 - 1s - loss: 0.0060 - val_loss: 0.0214 - 712ms/epoch - 36ms/step
# Epoch 7/150
# 20/20 - 1s - loss: 0.0020 - val_loss: 0.0183 - 868ms/epoch - 43ms/step
# Epoch 8/150
# 20/20 - 1s - loss: 0.0014 - val_loss: 0.0149 - 762ms/epoch - 38ms/step
# Epoch 9/150
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.0164 - 769ms/epoch - 38ms/step
# Epoch 10/150
# 20/20 - 1s - loss: 9.9761e-04 - val_loss: 0.0154 - 773ms/epoch - 39ms/step
# Epoch 11/150
# 20/20 - 1s - loss: 9.1700e-04 - val_loss: 0.0149 - 795ms/epoch - 40ms/step
# Epoch 12/150
# 20/20 - 1s - loss: 8.8941e-04 - val_loss: 0.0139 - 784ms/epoch - 39ms/step
# Epoch 13/150
# 20/20 - 1s - loss: 8.0113e-04 - val_loss: 0.0135 - 740ms/epoch - 37ms/step
# Epoch 14/150
# 20/20 - 1s - loss: 8.2647e-04 - val_loss: 0.0136 - 730ms/epoch - 36ms/step
# Epoch 15/150
# 20/20 - 1s - loss: 8.0894e-04 - val_loss: 0.0134 - 738ms/epoch - 37ms/step
# Epoch 16/150
# 20/20 - 1s - loss: 7.7255e-04 - val_loss: 0.0130 - 795ms/epoch - 40ms/step
# Epoch 17/150
# 20/20 - 1s - loss: 7.0112e-04 - val_loss: 0.0129 - 777ms/epoch - 39ms/step
# Epoch 18/150
# 20/20 - 1s - loss: 7.2060e-04 - val_loss: 0.0129 - 756ms/epoch - 38ms/step
# Epoch 19/150
# 20/20 - 1s - loss: 7.0254e-04 - val_loss: 0.0127 - 747ms/epoch - 37ms/step
# Epoch 20/150
# 20/20 - 1s - loss: 6.8854e-04 - val_loss: 0.0122 - 755ms/epoch - 38ms/step
# Epoch 21/150
# 20/20 - 1s - loss: 6.2336e-04 - val_loss: 0.0120 - 757ms/epoch - 38ms/step
# Epoch 22/150
# 20/20 - 1s - loss: 6.0820e-04 - val_loss: 0.0124 - 711ms/epoch - 36ms/step
# Epoch 23/150
# 20/20 - 1s - loss: 6.6615e-04 - val_loss: 0.0129 - 726ms/epoch - 36ms/step
# Epoch 24/150
# 20/20 - 1s - loss: 8.1496e-04 - val_loss: 0.0125 - 863ms/epoch - 43ms/step
# Epoch 25/150
# 20/20 - 1s - loss: 7.6699e-04 - val_loss: 0.0115 - 668ms/epoch - 33ms/step
# Epoch 26/150
# 20/20 - 1s - loss: 5.4273e-04 - val_loss: 0.0108 - 668ms/epoch - 33ms/step
# Epoch 27/150
# 20/20 - 1s - loss: 6.7183e-04 - val_loss: 0.0127 - 679ms/epoch - 34ms/step
# Epoch 28/150
# 20/20 - 1s - loss: 7.0758e-04 - val_loss: 0.0153 - 668ms/epoch - 33ms/step
# Epoch 29/150
# 20/20 - 1s - loss: 0.0019 - val_loss: 0.0172 - 713ms/epoch - 36ms/step
# Epoch 30/150
# 20/20 - 1s - loss: 0.0029 - val_loss: 0.0171 - 677ms/epoch - 34ms/step
# Epoch 31/150
# 20/20 - 1s - loss: 0.0024 - val_loss: 0.0127 - 666ms/epoch - 33ms/step
# Epoch 32/150
# 20/20 - 1s - loss: 7.7375e-04 - val_loss: 0.0110 - 681ms/epoch - 34ms/step
# Epoch 33/150
# 20/20 - 1s - loss: 0.0019 - val_loss: 0.0169 - 669ms/epoch - 33ms/step
# Epoch 34/150
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.0144 - 668ms/epoch - 33ms/step
# Epoch 35/150
# 20/20 - 1s - loss: 8.1267e-04 - val_loss: 0.0165 - 722ms/epoch - 36ms/step
# Epoch 36/150
# 20/20 - 1s - loss: 0.0011 - val_loss: 0.0127 - 695ms/epoch - 35ms/step
# 20/20 [==============================] - 8s 9ms/step
# 9/9 [==============================] - 0s 8ms/step
# Train Score: 20.96 RMSE for 150 epochs
# Test Score: 105.17 RMSE for 150 epochs
# Training with LSTM layers: [32, 32, 16, 16, 8, 8, 4, 4, 2, 2]
# Epoch 1/150
# 20/20 - 37s - loss: 0.0449 - val_loss: 0.0644 - 37s/epoch - 2s/step
# Epoch 2/150
# 20/20 - 1s - loss: 0.0248 - val_loss: 0.0413 - 564ms/epoch - 28ms/step
# Epoch 3/150
# 20/20 - 1s - loss: 0.0139 - val_loss: 0.0392 - 586ms/epoch - 29ms/step
# Epoch 4/150
# 20/20 - 1s - loss: 0.0108 - val_loss: 0.0395 - 536ms/epoch - 27ms/step
# Epoch 5/150
# 20/20 - 1s - loss: 0.0115 - val_loss: 0.0381 - 555ms/epoch - 28ms/step
# Epoch 6/150
# 20/20 - 1s - loss: 0.0106 - val_loss: 0.0356 - 549ms/epoch - 27ms/step
# Epoch 7/150
# 20/20 - 1s - loss: 0.0090 - val_loss: 0.0296 - 528ms/epoch - 26ms/step
# Epoch 8/150
# 20/20 - 1s - loss: 0.0051 - val_loss: 0.0210 - 543ms/epoch - 27ms/step
# Epoch 9/150
# 20/20 - 1s - loss: 0.0021 - val_loss: 0.0170 - 528ms/epoch - 26ms/step
# Epoch 10/150
# 20/20 - 1s - loss: 0.0013 - val_loss: 0.0178 - 531ms/epoch - 27ms/step
# Epoch 11/150
# 20/20 - 1s - loss: 0.0013 - val_loss: 0.0149 - 545ms/epoch - 27ms/step
# Epoch 12/150
# ...
# Epoch 33/150
# 20/20 - 1s - loss: 0.0015 - val_loss: 0.0122 - 546ms/epoch - 27ms/step
# Epoch 34/150
# 20/20 - 1s - loss: 7.2146e-04 - val_loss: 0.0103 - 534ms/epoch - 27ms/step
# Epoch 35/150
# 20/20 - 1s - loss: 0.0019 - val_loss: 0.0149 - 533ms/epoch - 27ms/step
# Epoch 36/150
# 20/20 - 1s - loss: 0.0010 - val_loss: 0.0145 - 527ms/epoch - 26ms/step
# Epoch 37/150
# 20/20 - 1s - loss: 7.8652e-04 - val_loss: 0.0155 - 530ms/epoch - 26ms/step
# Epoch 38/150
# 20/20 - 1s - loss: 0.0012 - val_loss: 0.0114 - 525ms/epoch - 26ms/step
# Epoch 39/150
# 20/20 - 1s - loss: 7.7685e-04 - val_loss: 0.0126 - 525ms/epoch - 26ms/step
# Epoch 40/150
# 20/20 - 1s - loss: 6.4570e-04 - val_loss: 0.0126 - 534ms/epoch - 27ms/step
# Epoch 41/150
# 20/20 - 1s - loss: 5.7154e-04 - val_loss: 0.0145 - 541ms/epoch - 27ms/step
# Epoch 42/150
# 20/20 - 1s - loss: 8.5102e-04 - val_loss: 0.0124 - 534ms/epoch - 27ms/step
# Epoch 43/150
# 20/20 - 1s - loss: 5.1560e-04 - val_loss: 0.0114 - 578ms/epoch - 29ms/step
# Epoch 44/150
# 20/20 - 1s - loss: 6.1532e-04 - val_loss: 0.0118 - 565ms/epoch - 28ms/step
# 20/20 [==============================] - 6s 7ms/step
# 9/9 [==============================] - 0s 7ms/step
# Train Score: 22.55 RMSE for 150 epochs
# Test Score: 101.09 RMSE for 150 epochs
# Training with LSTM layers: [16, 16, 8, 8, 4, 4, 2, 2]
# Epoch 1/150
# 20/20 - 29s - loss: 0.0418 - val_loss: 0.0548 - 29s/epoch - 1s/step
# Epoch 2/150
# 20/20 - 0s - loss: 0.0198 - val_loss: 0.0373 - 467ms/epoch - 23ms/step
# Epoch 3/150
# 20/20 - 0s - loss: 0.0112 - val_loss: 0.0366 - 456ms/epoch - 23ms/step
# Epoch 4/150
# 20/20 - 0s - loss: 0.0101 - val_loss: 0.0356 - 476ms/epoch - 24ms/step
# Epoch 5/150
# 20/20 - 0s - loss: 0.0101 - val_loss: 0.0326 - 451ms/epoch - 23ms/step
# Epoch 6/150
# 20/20 - 0s - loss: 0.0086 - val_loss: 0.0283 - 444ms/epoch - 22ms/step
# Epoch 7/150
# 20/20 - 0s - loss: 0.0065 - val_loss: 0.0211 - 468ms/epoch - 23ms/step
# Epoch 8/150
# 20/20 - 0s - loss: 0.0030 - val_loss: 0.0130 - 466ms/epoch - 23ms/step
# Epoch 9/150
# 20/20 - 0s - loss: 7.1099e-04 - val_loss: 0.0102 - 449ms/epoch - 22ms/step
# Epoch 10/150
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.0130 - 481ms/epoch - 24ms/step
# Epoch 11/150
# 20/20 - 0s - loss: 6.6048e-04 - val_loss: 0.0140 - 447ms/epoch - 22ms/step
# Epoch 12/150
# 20/20 - 1s - loss: 8.0853e-04 - val_loss: 0.0113 - 504ms/epoch - 25ms/step
# Epoch 13/150
# 20/20 - 1s - loss: 6.3642e-04 - val_loss: 0.0114 - 541ms/epoch - 27ms/step
# Epoch 14/150
# 20/20 - 0s - loss: 6.1025e-04 - val_loss: 0.0127 - 479ms/epoch - 24ms/step
# Epoch 15/150
# 20/20 - 0s - loss: 6.2730e-04 - val_loss: 0.0125 - 466ms/epoch - 23ms/step
# Epoch 16/150
# 20/20 - 1s - loss: 6.1207e-04 - val_loss: 0.0113 - 505ms/epoch - 25ms/step
# Epoch 17/150
# 20/20 - 1s - loss: 5.9218e-04 - val_loss: 0.0114 - 527ms/epoch - 26ms/step
# Epoch 18/150
# 20/20 - 1s - loss: 6.0141e-04 - val_loss: 0.0121 - 550ms/epoch - 28ms/step
# Epoch 19/150
# 20/20 - 0s - loss: 5.8314e-04 - val_loss: 0.0119 - 455ms/epoch - 23ms/step
# 20/20 [==============================] - 6s 5ms/step
# 9/9 [==============================] - 0s 5ms/step
# Train Score: 20.84 RMSE for 150 epochs
# Test Score: 101.87 RMSE for 150 epochs
# Training with LSTM layers: [8, 8, 4, 4, 2, 2]
# Epoch 1/150
# 20/20 - 23s - loss: 0.0416 - val_loss: 0.0555 - 23s/epoch - 1s/step
# Epoch 2/150
# 20/20 - 0s - loss: 0.0196 - val_loss: 0.0385 - 331ms/epoch - 17ms/step
# Epoch 3/150
# 20/20 - 0s - loss: 0.0120 - val_loss: 0.0360 - 338ms/epoch - 17ms/step
# Epoch 4/150
# 20/20 - 0s - loss: 0.0097 - val_loss: 0.0355 - 336ms/epoch - 17ms/step
# Epoch 5/150
# 20/20 - 0s - loss: 0.0097 - val_loss: 0.0338 - 371ms/epoch - 19ms/step
# Epoch 6/150
# 20/20 - 0s - loss: 0.0092 - val_loss: 0.0314 - 351ms/epoch - 18ms/step
# Epoch 7/150
# 20/20 - 0s - loss: 0.0082 - val_loss: 0.0282 - 320ms/epoch - 16ms/step
# Epoch 8/150
# 20/20 - 0s - loss: 0.0070 - val_loss: 0.0240 - 326ms/epoch - 16ms/step
# Epoch 9/150
# 20/20 - 0s - loss: 0.0052 - val_loss: 0.0187 - 363ms/epoch - 18ms/step
# Epoch 10/150
# 20/20 - 0s - loss: 0.0031 - val_loss: 0.0135 - 329ms/epoch - 16ms/step
# Epoch 11/150
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.0104 - 326ms/epoch - 16ms/step
# Epoch 12/150
# 20/20 - 0s - loss: 7.5243e-04 - val_loss: 0.0098 - 321ms/epoch - 16ms/step
# Epoch 13/150
# 20/20 - 0s - loss: 7.1990e-04 - val_loss: 0.0106 - 325ms/epoch - 16ms/step
# Epoch 14/150
# 20/20 - 0s - loss: 6.2720e-04 - val_loss: 0.0105 - 333ms/epoch - 17ms/step
# Epoch 15/150
# 20/20 - 0s - loss: 6.4847e-04 - val_loss: 0.0102 - 325ms/epoch - 16ms/step
# Epoch 16/150
# 20/20 - 0s - loss: 6.3513e-04 - val_loss: 0.0104 - 323ms/epoch - 16ms/step
# Epoch 17/150
# 20/20 - 0s - loss: 6.6091e-04 - val_loss: 0.0106 - 325ms/epoch - 16ms/step
# Epoch 18/150
# 20/20 - 0s - loss: 5.8627e-04 - val_loss: 0.0107 - 363ms/epoch - 18ms/step
# Epoch 19/150
# 20/20 - 0s - loss: 6.2038e-04 - val_loss: 0.0105 - 371ms/epoch - 19ms/step
# Epoch 20/150
# 20/20 - 0s - loss: 5.8245e-04 - val_loss: 0.0106 - 358ms/epoch - 18ms/step
# Epoch 21/150
# 20/20 - 0s - loss: 5.7559e-04 - val_loss: 0.0107 - 346ms/epoch - 17ms/step
# Epoch 22/150
# 20/20 - 0s - loss: 6.0217e-04 - val_loss: 0.0105 - 361ms/epoch - 18ms/step
# 20/20 [==============================] - 4s 4ms/step
# 9/9 [==============================] - 0s 4ms/step
# Train Score: 19.87 RMSE for 150 epochs
# Test Score: 95.58 RMSE for 150 epochs
# Training with LSTM layers: [4, 4, 2, 2]
# Epoch 1/150
# 20/20 - 17s - loss: 0.0380 - val_loss: 0.0528 - 17s/epoch - 847ms/step
# Epoch 2/150
# 20/20 - 0s - loss: 0.0187 - val_loss: 0.0356 - 238ms/epoch - 12ms/step
# Epoch 3/150
# 20/20 - 0s - loss: 0.0105 - val_loss: 0.0304 - 230ms/epoch - 12ms/step
# Epoch 4/150
# 20/20 - 0s - loss: 0.0080 - val_loss: 0.0292 - 248ms/epoch - 12ms/step
# Epoch 5/150
# 20/20 - 0s - loss: 0.0075 - val_loss: 0.0283 - 240ms/epoch - 12ms/step
# Epoch 6/150
# 20/20 - 0s - loss: 0.0070 - val_loss: 0.0269 - 229ms/epoch - 11ms/step
# Epoch 7/150
# 20/20 - 0s - loss: 0.0067 - val_loss: 0.0252 - 238ms/epoch - 12ms/step
# Epoch 8/150
# 20/20 - 0s - loss: 0.0061 - val_loss: 0.0234 - 234ms/epoch - 12ms/step
# Epoch 9/150
# 20/20 - 0s - loss: 0.0055 - val_loss: 0.0215 - 244ms/epoch - 12ms/step
# Epoch 10/150
# 20/20 - 0s - loss: 0.0050 - val_loss: 0.0194 - 230ms/epoch - 12ms/step
# Epoch 11/150
# 20/20 - 0s - loss: 0.0042 - val_loss: 0.0173 - 257ms/epoch - 13ms/step
# Epoch 12/150
# 20/20 - 0s - loss: 0.0036 - val_loss: 0.0151 - 250ms/epoch - 13ms/step
# Epoch 13/150
# 20/20 - 0s - loss: 0.0027 - val_loss: 0.0131 - 233ms/epoch - 12ms/step
# Epoch 14/150
# 20/20 - 0s - loss: 0.0023 - val_loss: 0.0113 - 225ms/epoch - 11ms/step
# Epoch 15/150
# 20/20 - 0s - loss: 0.0017 - val_loss: 0.0102 - 234ms/epoch - 12ms/step
# Epoch 16/150
# 20/20 - 0s - loss: 0.0013 - val_loss: 0.0093 - 237ms/epoch - 12ms/step
# Epoch 17/150
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.0090 - 246ms/epoch - 12ms/step
# Epoch 18/150
# 20/20 - 0s - loss: 8.8122e-04 - val_loss: 0.0088 - 239ms/epoch - 12ms/step
# Epoch 19/150
# 20/20 - 0s - loss: 9.4832e-04 - val_loss: 0.0087 - 234ms/epoch - 12ms/step
# Epoch 20/150
# 20/20 - 0s - loss: 8.2426e-04 - val_loss: 0.0086 - 233ms/epoch - 12ms/step
# Epoch 21/150
# 20/20 - 0s - loss: 8.9397e-04 - val_loss: 0.0086 - 250ms/epoch - 13ms/step
# Epoch 22/150
# 20/20 - 0s - loss: 8.8631e-04 - val_loss: 0.0086 - 246ms/epoch - 12ms/step
# Epoch 23/150
# 20/20 - 0s - loss: 9.0970e-04 - val_loss: 0.0087 - 239ms/epoch - 12ms/step
# Epoch 24/150
# 20/20 - 0s - loss: 8.2250e-04 - val_loss: 0.0087 - 228ms/epoch - 11ms/step
# Epoch 25/150
# 20/20 - 0s - loss: 8.2888e-04 - val_loss: 0.0086 - 232ms/epoch - 12ms/step
# Epoch 26/150
# 20/20 - 0s - loss: 8.9587e-04 - val_loss: 0.0087 - 227ms/epoch - 11ms/step
# Epoch 27/150
# 20/20 - 0s - loss: 8.5803e-04 - val_loss: 0.0086 - 227ms/epoch - 11ms/step
# Epoch 28/150
# 20/20 - 0s - loss: 7.5580e-04 - val_loss: 0.0087 - 237ms/epoch - 12ms/step
# Epoch 29/150
# 20/20 - 0s - loss: 7.9687e-04 - val_loss: 0.0087 - 238ms/epoch - 12ms/step
# Epoch 30/150
# 20/20 - 0s - loss: 8.0960e-04 - val_loss: 0.0087 - 230ms/epoch - 11ms/step
# Epoch 31/150
# 20/20 - 0s - loss: 8.0715e-04 - val_loss: 0.0086 - 237ms/epoch - 12ms/step
# Epoch 32/150
# 20/20 - 0s - loss: 7.7463e-04 - val_loss: 0.0087 - 241ms/epoch - 12ms/step
# Epoch 33/150
# 20/20 - 0s - loss: 7.5422e-04 - val_loss: 0.0086 - 228ms/epoch - 11ms/step
# Epoch 34/150
# 20/20 - 0s - loss: 6.9597e-04 - val_loss: 0.0086 - 226ms/epoch - 11ms/step
# Epoch 35/150
# 20/20 - 0s - loss: 8.5006e-04 - val_loss: 0.0086 - 229ms/epoch - 11ms/step
# Epoch 36/150
# 20/20 - 0s - loss: 7.4087e-04 - val_loss: 0.0086 - 242ms/epoch - 12ms/step
# Epoch 37/150
# 20/20 - 0s - loss: 7.1999e-04 - val_loss: 0.0086 - 261ms/epoch - 13ms/step
# Epoch 38/150
# 20/20 - 0s - loss: 7.3869e-04 - val_loss: 0.0086 - 313ms/epoch - 16ms/step
# Epoch 39/150
# 20/20 - 0s - loss: 6.5858e-04 - val_loss: 0.0086 - 239ms/epoch - 12ms/step
# Epoch 40/150
# 20/20 - 0s - loss: 6.8264e-04 - val_loss: 0.0086 - 227ms/epoch - 11ms/step
# Epoch 41/150
# 20/20 - 0s - loss: 6.6489e-04 - val_loss: 0.0086 - 238ms/epoch - 12ms/step
# Epoch 42/150
# 20/20 - 0s - loss: 7.4346e-04 - val_loss: 0.0086 - 229ms/epoch - 11ms/step
# Epoch 43/150
# 20/20 - 0s - loss: 6.7695e-04 - val_loss: 0.0086 - 229ms/epoch - 11ms/step
# Epoch 44/150
# 20/20 - 0s - loss: 6.2860e-04 - val_loss: 0.0086 - 238ms/epoch - 12ms/step
# Epoch 45/150
# 20/20 - 0s - loss: 6.8321e-04 - val_loss: 0.0086 - 228ms/epoch - 11ms/step
# Epoch 46/150
# 20/20 - 0s - loss: 6.5068e-04 - val_loss: 0.0086 - 292ms/epoch - 15ms/step
# Epoch 47/150
# 20/20 - 0s - loss: 6.5491e-04 - val_loss: 0.0086 - 232ms/epoch - 12ms/step
# Epoch 48/150
# 20/20 - 0s - loss: 6.4946e-04 - val_loss: 0.0086 - 226ms/epoch - 11ms/step
# Epoch 49/150
# 20/20 - 0s - loss: 6.7974e-04 - val_loss: 0.0086 - 229ms/epoch - 11ms/step
# 20/20 [==============================] - 3s 3ms/step
# 9/9 [==============================] - 0s 3ms/step
# Train Score: 18.82 RMSE for 150 epochs
# Test Score: 86.48 RMSE for 150 epochs
# Training with LSTM layers: [2, 2]
# Epoch 1/150
# 20/20 - 8s - loss: 0.0423 - val_loss: 0.0630 - 8s/epoch - 378ms/step
# Epoch 2/150
# 20/20 - 0s - loss: 0.0258 - val_loss: 0.0473 - 144ms/epoch - 7ms/step
# Epoch 3/150
# 20/20 - 0s - loss: 0.0160 - val_loss: 0.0380 - 140ms/epoch - 7ms/step
# Epoch 4/150
# 20/20 - 0s - loss: 0.0109 - val_loss: 0.0337 - 139ms/epoch - 7ms/step
# Epoch 5/150
# 20/20 - 0s - loss: 0.0093 - val_loss: 0.0319 - 141ms/epoch - 7ms/step
# Epoch 6/150
# 20/20 - 0s - loss: 0.0085 - val_loss: 0.0308 - 137ms/epoch - 7ms/step
# Epoch 7/150
# 20/20 - 0s - loss: 0.0080 - val_loss: 0.0300 - 138ms/epoch - 7ms/step
# Epoch 8/150
# 20/20 - 0s - loss: 0.0073 - val_loss: 0.0291 - 140ms/epoch - 7ms/step
# Epoch 9/150
# 20/20 - 0s - loss: 0.0074 - val_loss: 0.0281 - 138ms/epoch - 7ms/step
# Epoch 10/150
# 20/20 - 0s - loss: 0.0072 - val_loss: 0.0270 - 137ms/epoch - 7ms/step
# Epoch 11/150
# 20/20 - 0s - loss: 0.0065 - val_loss: 0.0259 - 139ms/epoch - 7ms/step
# Epoch 12/150
# 20/20 - 0s - loss: 0.0062 - val_loss: 0.0248 - 137ms/epoch - 7ms/step
# Epoch 13/150
# 20/20 - 0s - loss: 0.0059 - val_loss: 0.0237 - 137ms/epoch - 7ms/step
# Epoch 14/150
# 20/20 - 0s - loss: 0.0055 - val_loss: 0.0225 - 137ms/epoch - 7ms/step
# Epoch 15/150
# 20/20 - 0s - loss: 0.0055 - val_loss: 0.0213 - 137ms/epoch - 7ms/step
# Epoch 16/150
# 20/20 - 0s - loss: 0.0047 - val_loss: 0.0201 - 138ms/epoch - 7ms/step
# Epoch 17/150
# 20/20 - 0s - loss: 0.0044 - val_loss: 0.0189 - 167ms/epoch - 8ms/step
# Epoch 18/150
# 20/20 - 0s - loss: 0.0041 - val_loss: 0.0176 - 154ms/epoch - 8ms/step
# Epoch 19/150
# 20/20 - 0s - loss: 0.0036 - val_loss: 0.0164 - 138ms/epoch - 7ms/step
# Epoch 20/150
# 20/20 - 0s - loss: 0.0031 - val_loss: 0.0153 - 136ms/epoch - 7ms/step
# Epoch 21/150
# 20/20 - 0s - loss: 0.0029 - val_loss: 0.0142 - 138ms/epoch - 7ms/step
# Epoch 22/150
# 20/20 - 0s - loss: 0.0025 - val_loss: 0.0132 - 144ms/epoch - 7ms/step
# Epoch 23/150
# 20/20 - 0s - loss: 0.0022 - val_loss: 0.0123 - 143ms/epoch - 7ms/step
# Epoch 24/150
# 20/20 - 0s - loss: 0.0017 - val_loss: 0.0115 - 139ms/epoch - 7ms/step
# Epoch 25/150
# 20/20 - 0s - loss: 0.0015 - val_loss: 0.0109 - 142ms/epoch - 7ms/step
# Epoch 26/150
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.0103 - 136ms/epoch - 7ms/step
# Epoch 27/150
# 20/20 - 0s - loss: 0.0014 - val_loss: 0.0098 - 137ms/epoch - 7ms/step
# Epoch 28/150
# 20/20 - 0s - loss: 0.0012 - val_loss: 0.0096 - 137ms/epoch - 7ms/step
# Epoch 29/150
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.0093 - 138ms/epoch - 7ms/step
# Epoch 30/150
# 20/20 - 0s - loss: 0.0011 - val_loss: 0.0090 - 135ms/epoch - 7ms/step
# Epoch 31/150
# 20/20 - 0s - loss: 9.9050e-04 - val_loss: 0.0089 - 138ms/epoch - 7ms/step
# Epoch 32/150
# 20/20 - 0s - loss: 9.6456e-04 - val_loss: 0.0087 - 138ms/epoch - 7ms/step
# Epoch 33/150
# 20/20 - 0s - loss: 8.8068e-04 - val_loss: 0.0087 - 139ms/epoch - 7ms/step
# Epoch 34/150
# 20/20 - 0s - loss: 8.6632e-04 - val_loss: 0.0087 - 146ms/epoch - 7ms/step
# Epoch 35/150
# 20/20 - 0s - loss: 8.6948e-04 - val_loss: 0.0086 - 137ms/epoch - 7ms/step
# Epoch 36/150
# 20/20 - 0s - loss: 9.3597e-04 - val_loss: 0.0086 - 138ms/epoch - 7ms/step
# Epoch 37/150
# 20/20 - 0s - loss: 8.3770e-04 - val_loss: 0.0087 - 137ms/epoch - 7ms/step
# Epoch 38/150
# 20/20 - 0s - loss: 8.9932e-04 - val_loss: 0.0087 - 137ms/epoch - 7ms/step
# Epoch 39/150
# 20/20 - 0s - loss: 9.4401e-04 - val_loss: 0.0087 - 137ms/epoch - 7ms/step
# Epoch 40/150
# 20/20 - 0s - loss: 8.7420e-04 - val_loss: 0.0086 - 135ms/epoch - 7ms/step
# Epoch 41/150
# 20/20 - 0s - loss: 8.3600e-04 - val_loss: 0.0087 - 137ms/epoch - 7ms/step
# Epoch 42/150
# 20/20 - 0s - loss: 6.7105e-04 - val_loss: 0.0087 - 137ms/epoch - 7ms/step
# Epoch 43/150
# 20/20 - 0s - loss: 9.9653e-04 - val_loss: 0.0086 - 139ms/epoch - 7ms/step
# Epoch 44/150
# 20/20 - 0s - loss: 7.4815e-04 - val_loss: 0.0086 - 137ms/epoch - 7ms/step
# Epoch 45/150
# 20/20 - 0s - loss: 8.8188e-04 - val_loss: 0.0087 - 148ms/epoch - 7ms/step
# Epoch 46/150
# 20/20 - 0s - loss: 7.9757e-04 - val_loss: 0.0087 - 139ms/epoch - 7ms/step
# Epoch 47/150
# 20/20 - 0s - loss: 7.4666e-04 - val_loss: 0.0087 - 142ms/epoch - 7ms/step
# Epoch 48/150
# 20/20 - 0s - loss: 8.1743e-04 - val_loss: 0.0087 - 173ms/epoch - 9ms/step
# Epoch 49/150
# 20/20 - 0s - loss: 6.8614e-04 - val_loss: 0.0087 - 138ms/epoch - 7ms/step
# Epoch 50/150
# 20/20 - 0s - loss: 8.1333e-04 - val_loss: 0.0086 - 137ms/epoch - 7ms/step
# Epoch 51/150
# 20/20 - 0s - loss: 7.8488e-04 - val_loss: 0.0087 - 147ms/epoch - 7ms/step
# Epoch 52/150
# 20/20 - 0s - loss: 7.5549e-04 - val_loss: 0.0086 - 139ms/epoch - 7ms/step
# Epoch 53/150
# 20/20 - 0s - loss: 7.4582e-04 - val_loss: 0.0087 - 140ms/epoch - 7ms/step
# Epoch 54/150
# 20/20 - 0s - loss: 7.4951e-04 - val_loss: 0.0087 - 138ms/epoch - 7ms/step
# 20/20 [==============================] - 1s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# Train Score: 19.29 RMSE for 150 epochs
# Test Score: 86.89 RMSE for 150 epochs
# Text(0.5, 1.0, 'Model loss progress during training and validation')
# Text(0.5, 0, 'Epoch')
# Text(0, 0.5, 'Training and Validation Loss')
#                                                     Train RMSE   Test RMSE
# 50 epochs, [64, 64, 32, 32, 16, 16, 8, 8, 4, 4,...   19.199769  109.644197
# 50 epochs, [32, 32, 16, 16, 8, 8, 4, 4, 2, 2] l...   23.187501  102.513823
# 50 epochs, [16, 16, 8, 8, 4, 4, 2, 2] layers         20.517448   97.249227
# 50 epochs, [8, 8, 4, 4, 2, 2] layers                 19.596507   94.278211
# 50 epochs, [4, 4, 2, 2] layers                       19.896551   93.981613
# 50 epochs, [2, 2] layers                             19.477290   86.919582
# 100 epochs, [64, 64, 32, 32, 16, 16, 8, 8, 4, 4...   18.868000  101.432319
# 100 epochs, [32, 32, 16, 16, 8, 8, 4, 4, 2, 2] ...   25.136946   94.425330
# 100 epochs, [16, 16, 8, 8, 4, 4, 2, 2] layers        21.461340  101.528578
# 100 epochs, [8, 8, 4, 4, 2, 2] layers                18.277820   97.636207
# 100 epochs, [4, 4, 2, 2] layers                      20.037485   88.375776
# 100 epochs, [2, 2] layers                            20.931781   90.368663
# 150 epochs, [64, 64, 32, 32, 16, 16, 8, 8, 4, 4...   20.961907  105.171713
# 150 epochs, [32, 32, 16, 16, 8, 8, 4, 4, 2, 2] ...   22.550834  101.091714
# 150 epochs, [16, 16, 8, 8, 4, 4, 2, 2] layers        20.841230  101.873617
# 150 epochs, [8, 8, 4, 4, 2, 2] layers                19.874662   95.579378
# 150 epochs, [4, 4, 2, 2] layers                      18.821667   86.476590
# 150 epochs, [2, 2] layers                            19.285914   86.890836

# %% [markdown]
# <h4>Forecast the results</h4>

# %%
# Add check for 'RATE_actual' values to avoid division by zero
def compute_accuracy(row):
    if row['RATE_actual'] == 0:
        return np.nan
    else:
        error = abs(row['RATE_actual'] - row['RATE_forecasted'])
        error_proportion = error / row['RATE_actual']
        return (1 - error_proportion) * 100

def forecast_next_weeks(model, look_back, scaler, last_values, n_weeks):
    forecast = []
    for _ in range(n_weeks):
        # Reshape last_values to 2D array with one feature
        last_values_2d = np.array(last_values[-look_back:]).reshape(-1, 1)

        # Scale the last_values_2d to be between 0 and 1
        input_values_scaled = scaler.transform(last_values_2d)

        # Reshape to [samples, time steps, features]
        input_values_scaled = input_values_scaled.reshape((1, look_back, 1))

        # Predict the next value
        prediction = model.predict(input_values_scaled)

        # Rescale the prediction back to the original scale
        prediction_rescaled = scaler.inverse_transform(prediction)

        # Append the predicted value to the forecast list
        forecast.append(prediction_rescaled[0][0])

        # Append the predicted value to the last_values list to be used as input for the next prediction
        last_values.append(prediction_rescaled[0][0])
        # Drop the first value in the last_values list
        last_values.pop(0)

    return forecast

# %%
weeks = 12

# Ensure that 'YearMonthWeek' is a datetime object
agg_df['YearMonthWeek'] = pd.to_datetime(agg_df['YearMonthWeek'])
last_date = agg_df['YearMonthWeek'].iloc[-1]

last_values = list(agg_df['Rate'].values[-look_back:])
forecasted_values = forecast_next_weeks(model, look_back, scaler, last_values, weeks)
forecasted_dates = pd.date_range(start=last_date, periods=weeks+1, freq='W')[1:]

df_forecasted = pd.DataFrame({
    'POD': forecasted_dates,
    'RATE': forecasted_values
})

df_forecasted["RATE"] = df_forecasted["RATE"].round(2)

df_forecasted.head(5)
df_forecasted.tail(5)
df_forecasted.info()
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
#          POD        RATE
# 0 2023-03-05  234.919998
# 1 2023-03-12  235.889999
# 2 2023-03-19  239.720001
# 3 2023-03-26  238.279999
# 4 2023-04-02  240.020004
#           POD        RATE
# 7  2023-04-23  230.399994
# 8  2023-04-30  228.429993
# 9  2023-05-07  226.399994
# 10 2023-05-14  223.970001
# 11 2023-05-21  222.190002
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POD     12 non-null     datetime64[ns]
#  1   RATE    12 non-null     float32
# dtypes: datetime64[ns](1), float32(1)
# memory usage: 272.0 bytes

# %% [markdown]
# <h4>Comparing with actual updated against forecasted</h4>

# %%
comparison_df = pd.DataFrame(columns=['WeekStart', 'WeekEnd', 'POD_actual', 'RATE_forecasted', 'RATE_actual'])
df_forecasted['WeekEnd'] = df_forecasted['POD'] + pd.to_timedelta(7, unit='d')  

for _, row in df_forecasted.iterrows():
    mask = (new_dates_df['POD'] >= row['POD']) & (new_dates_df['POD'] < row['WeekEnd'])
    actual_dates_within_week = new_dates_df[mask]

    for _, actual_row in actual_dates_within_week.iterrows():
        comparison_df = comparison_df.append({
            'WeekStart': row['POD'],
            'WeekEnd': row['WeekEnd'],
            'POD_actual': actual_row['POD'],
            'RATE_forecasted': row['RATE'],
            'RATE_actual': actual_row['RATE']
        }, ignore_index=True)

# Remove duplicates
comparison_df = comparison_df.drop_duplicates(subset=['POD_actual', 'RATE_forecasted', 'RATE_actual']).reset_index(drop=True)

# Compute accuracy
comparison_df['accuracy'] = comparison_df.apply(compute_accuracy, axis=1)
comparison_df = comparison_df.dropna(subset=['accuracy'])

total_mean_accuracy = comparison_df['accuracy'].mean()
comparison_df
print(f'The mean accuracy is {total_mean_accuracy:.2f}%\n')
# Out:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_28344\3783945214.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
#     WeekStart    WeekEnd POD_actual  RATE_forecasted  RATE_actual   accuracy
# 0  2023-03-05 2023-03-12 2023-03-08       234.919998        260.0  90.353845
# 1  2023-03-12 2023-03-19 2023-03-15       235.889999        260.0  90.726923
# 2  2023-03-19 2023-03-26 2023-03-19       239.720001        300.0  79.906667
# 3  2023-03-26 2023-04-02 2023-03-26       238.279999        260.0  91.646153
# 4  2023-03-26 2023-04-02 2023-04-01       238.279999        260.0  91.646153
# 5  2023-04-02 2023-04-09 2023-04-08       240.020004        260.0  92.315386
# 6  2023-04-09 2023-04-16 2023-04-12       232.470001        300.0  77.490000
# 7  2023-04-09 2023-04-16 2023-04-15       232.470001        260.0  89.411539
# 8  2023-04-16 2023-04-23 2023-04-20       231.639999        260.0  89.092307
# 9  2023-04-23 2023-04-30 2023-04-26       230.399994        300.0  76.799998
# 10 2023-04-30 2023-05-07 2023-05-03       228.429993        260.0  87.857689
# 11 2023-05-07 2023-05-14 2023-05-10       226.399994        300.0  75.466665
# 12 2023-05-14 2023-05-21 2023-05-17       223.970001        260.0  86.142308
# The mean accuracy is 86.07%

# %% [markdown]
# <h4>Visualise all, Conclusion</h4>

# %%
plt.figure(figsize=(20, 10))
plt.plot(sel_df['POD'], sel_df['RATE'], color='blue', label="Actual Data")
plt.plot(new_dates_df['POD'], new_dates_df['RATE'], color='blue', label="Actual Data (Updated)")

plt.plot(df_interpolated['POD'], df_interpolated['RATE'], color='green', label="Aggregated Data")
plt.plot(df_forecasted['POD'], df_forecasted['RATE'], color='red', label="Forecasted Data")

plt.xlabel('Date(Year Month)')
plt.ylabel('Cost Rate(USD)')
plt.title('Port_BUSAN_Size_40_Type_HC_PartyID_010004286')
plt.legend()
plt.show();
