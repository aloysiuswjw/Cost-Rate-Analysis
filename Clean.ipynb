# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from IPython.core.interactiveshell import InteractiveShell
from sklearn.model_selection import KFold
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline
sns.set()
pd.options.display.max_rows = 100

df = pd.read_csv('.\Datasets\CR_COST_FC_new.csv', converters={'PARTY_ID': str, 'COM_ID': str, 'CNTR_SIZE': str, 'RATE':float})
df['POD'] = pd.to_datetime(df['POD'])
df['ENCODED_TYPE'] = df['ENCODED_TYPE'].fillna(-1).astype(int)
df = df.dropna(subset=['ENCODED_TYPE'])
df['RATE'] = df['RATE'].fillna(-1).astype(float)
df = df.dropna(subset=['RATE'])
df['ENCODED_TYPE'] = df['ENCODED_TYPE'].astype(int)

# Remove NAN values
df_clean= df.dropna().reset_index(drop=True)

df_clean.head()
df_clean.info()
print(f'Dataset size: {df_clean.shape}')
# Out:
#   COM_ID   PARTY_ID  PARTY_ID_EN                                  PARTY_NAME  \
# 0    010  010003678     10003678                     OY TAVATUR SHIPPING LTD
# 1    010  010004286     10004286                    GLOBELINK KOREA CO., LTD
# 2    010   01005136      1005136  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND
# 3    010   01002775      1002775    GLOBELINK INTERNATIONAL PTY LTD-ADELAIDE
# 4    010   01001088      1001088                   CARGO LINES S.A.-LE HAVRE
#
#             CSL_ID  ETA_ETD_NO ETD_POL_D     POD_ID        POD  \
# 0  ECS010060100191    20060228     FIHEL   HELSINKI 2006-02-28
# 1  ECS010060100465    20060303     KRPUS      BUSAN 2006-03-03
# 2  ECS010060100321    20060227     NZAKL   AUCKLAND 2006-02-27
# 3  ECS010060200201    20060306     AUADL   ADELAIDE 2006-03-06
# 4  ECS010060200146    20060307     FRMRS  MARSEILLE 2006-03-07
#
#             CNTR_ID CNTR_SIZE CNTR_TYPE COST_TERM    RATE  ENCODED_TYPE  \
# 0  CTNR010060201232        20        GP        FC   675.0             2
# 1  CTNR010060300014        40        HC        FC   390.0             1
# 2  CTNR010060201198        40    HC NOR        FC  1615.0             4
# 3  CTNR010060300119        40        HC        FC   700.0             1
# 4  CTNR010060300185        20        GP        FC   675.0             2
#
#    ENCODED_TERM     POD_ID_EN
# 0             1  4.103561e+09
# 1             1  2.904902e+09
# 2             1  2.397848e+09
# 3             1  2.480737e+08
# 4             1  4.197227e+08
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54722 entries, 0 to 54721
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   COM_ID        54722 non-null  object
#  1   PARTY_ID      54722 non-null  object
#  2   PARTY_ID_EN   54722 non-null  int64
#  3   PARTY_NAME    54722 non-null  object
#  4   CSL_ID        54722 non-null  object
#  5   ETA_ETD_NO    54722 non-null  int64
#  6   ETD_POL_D     54722 non-null  object
#  7   POD_ID        54722 non-null  object
#  8   POD           54722 non-null  datetime64[ns]
#  9   CNTR_ID       54722 non-null  object
#  10  CNTR_SIZE     54722 non-null  object
#  11  CNTR_TYPE     54722 non-null  object
#  12  COST_TERM     54722 non-null  object
#  13  RATE          54722 non-null  float64
#  14  ENCODED_TYPE  54722 non-null  int32
#  15  ENCODED_TERM  54722 non-null  int64
#  16  POD_ID_EN     54722 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(3), object(10)
# memory usage: 6.9+ MB
# Dataset size: (54722, 17)

# %%
sel_col = ['CSL_ID', 'CNTR_ID','POD_ID','ETD_POL_D','PARTY_ID',
           'PARTY_NAME','POD','CNTR_SIZE','CNTR_TYPE','RATE']

df_fc = df_clean[sel_col]
df_fc.head()
df_fc.info()
# Out:
#             CSL_ID           CNTR_ID     POD_ID ETD_POL_D   PARTY_ID  \
# 0  ECS010060100191  CTNR010060201232   HELSINKI     FIHEL  010003678
# 1  ECS010060100465  CTNR010060300014      BUSAN     KRPUS  010004286
# 2  ECS010060100321  CTNR010060201198   AUCKLAND     NZAKL   01005136
# 3  ECS010060200201  CTNR010060300119   ADELAIDE     AUADL   01002775
# 4  ECS010060200146  CTNR010060300185  MARSEILLE     FRMRS   01001088
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0                     OY TAVATUR SHIPPING LTD 2006-02-28        20        GP
# 1                    GLOBELINK KOREA CO., LTD 2006-03-03        40        HC
# 2  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2006-02-27        40    HC NOR
# 3    GLOBELINK INTERNATIONAL PTY LTD-ADELAIDE 2006-03-06        40        HC
# 4                   CARGO LINES S.A.-LE HAVRE 2006-03-07        20        GP
#
#      RATE
# 0   675.0
# 1   390.0
# 2  1615.0
# 3   700.0
# 4   675.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54722 entries, 0 to 54721
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      54722 non-null  object
#  1   CNTR_ID     54722 non-null  object
#  2   POD_ID      54722 non-null  object
#  3   ETD_POL_D   54722 non-null  object
#  4   PARTY_ID    54722 non-null  object
#  5   PARTY_NAME  54722 non-null  object
#  6   POD         54722 non-null  datetime64[ns]
#  7   CNTR_SIZE   54722 non-null  object
#  8   CNTR_TYPE   54722 non-null  object
#  9   RATE        54722 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 4.2+ MB

# %%
# filter out rows where the year is 2002
df_filtered = df_fc[df_fc['POD'].dt.year != 2002]
df_filtered.head()
df_filtered.info()

# Checking if year 2002 is removed
df_filtered['POD'].dt.year.unique()
# Out:
#             CSL_ID           CNTR_ID     POD_ID ETD_POL_D   PARTY_ID  \
# 0  ECS010060100191  CTNR010060201232   HELSINKI     FIHEL  010003678
# 1  ECS010060100465  CTNR010060300014      BUSAN     KRPUS  010004286
# 2  ECS010060100321  CTNR010060201198   AUCKLAND     NZAKL   01005136
# 3  ECS010060200201  CTNR010060300119   ADELAIDE     AUADL   01002775
# 4  ECS010060200146  CTNR010060300185  MARSEILLE     FRMRS   01001088
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0                     OY TAVATUR SHIPPING LTD 2006-02-28        20        GP
# 1                    GLOBELINK KOREA CO., LTD 2006-03-03        40        HC
# 2  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2006-02-27        40    HC NOR
# 3    GLOBELINK INTERNATIONAL PTY LTD-ADELAIDE 2006-03-06        40        HC
# 4                   CARGO LINES S.A.-LE HAVRE 2006-03-07        20        GP
#
#      RATE
# 0   675.0
# 1   390.0
# 2  1615.0
# 3   700.0
# 4   675.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54721 entries, 0 to 54721
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      54721 non-null  object
#  1   CNTR_ID     54721 non-null  object
#  2   POD_ID      54721 non-null  object
#  3   ETD_POL_D   54721 non-null  object
#  4   PARTY_ID    54721 non-null  object
#  5   PARTY_NAME  54721 non-null  object
#  6   POD         54721 non-null  datetime64[ns]
#  7   CNTR_SIZE   54721 non-null  object
#  8   CNTR_TYPE   54721 non-null  object
#  9   RATE        54721 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 4.6+ MB
# array([2006, 2005, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2018, 2019, 2020, 2021, 2016, 2017, 2022, 2023], dtype=int64)

# %%
# Sorting the dates 
df_filtered = df_filtered.sort_values(by='POD').reset_index(drop=True)
df_filtered.head()
df_filtered.tail()
df_filtered['POD'].dt.year.unique()
# Out:
#            CSL_ID           CNTR_ID          POD_ID ETD_POL_D  PARTY_ID  \
# 0  ECS01050600224  CTNR010050700354       ROTTERDAM     NLRTM  01008827
# 1  ECS01050600610  CTNR010050700353      FELIXSTOWE     GBFXT  01002303
# 2  ECS01050600041  CTNR010050700351        AUCKLAND     NZAKL  01005136
# 3  ECS01050600163  CTNR010050700370    PASIR GUDANG     MYPGU  01002767
# 4  ECS01050600456  CTNR010050700450  KARACHI (KICT)     PKKHI  01002783
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0             YANG MING (SINGAPORE) PTE. LTD. 2005-07-15        40    HC NOR
# 1                    GLOBELINK FALLOW LIMITED 2005-07-15        40        GP
# 2  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-15        40    HC NOR
# 3          GLOBELINK CONTAINER LINES (JB) S/B 2005-07-15        40        HC
# 4                GLOBELINK PAKISTAN (PVT) LTD 2005-07-16        40        HC
#
#      RATE
# 0  1620.0
# 1  1800.0
# 2  2170.0
# 3   280.0
# 4  1625.0
#                 CSL_ID       CNTR_ID        POD_ID ETD_POL_D   PARTY_ID  \
# 54716  ECS010230400526  010000573399    VALPARAISO     CLVAP  010006350
# 54717  ECS010230400525  010000582631        CALLAO     PECLL  010026711
# 54718  ECS010230400452  010000580585  BUENOS AIRES     ARBUE  010006300
# 54719  ECS010230400451  010000554136    MONTEVIDEO     UYMVD  010021385
# 54720  ECS010230400352  010000588769        ASHDOD     ILASH  010008035
#
#                        PARTY_NAME        POD CNTR_SIZE CNTR_TYPE    RATE
# 54716  CRAFT MULTIMODAL CHILE SPA 2023-05-24        40        HC  1300.0
# 54717   CRAFT MULTIMODAL PERU S.A 2023-05-24        40    HC NOR  1300.0
# 54718          CRAFT ARGENTINA SA 2023-05-25        40        HC  2300.0
# 54719  CRAFT URUGUAY CHEBURIN S.A 2023-05-25        40        HC  1100.0
# 54720          MAYAN OVERSEAS LTD 2023-05-27        20        GP  2100.0
# array([2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023], dtype=int64)

# %% [markdown]
# <h4>Export to CSV</h4>

# %%
df_filtered.info()
df_filtered.to_csv('./Datasets/CR_FC_new_Cleaned.csv',index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54721 entries, 0 to 54720
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      54721 non-null  object
#  1   CNTR_ID     54721 non-null  object
#  2   POD_ID      54721 non-null  object
#  3   ETD_POL_D   54721 non-null  object
#  4   PARTY_ID    54721 non-null  object
#  5   PARTY_NAME  54721 non-null  object
#  6   POD         54721 non-null  datetime64[ns]
#  7   CNTR_SIZE   54721 non-null  object
#  8   CNTR_TYPE   54721 non-null  object
#  9   RATE        54721 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 4.2+ MB
