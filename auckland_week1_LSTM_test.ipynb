# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Dropout, LSTM, Dense
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from IPython.core.interactiveshell import InteractiveShell
from sklearn.model_selection import KFold
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline
sns.set()
pd.options.display.max_rows = 100

# %% [markdown]
# <h4>Importing Datasets</h4>

# %%
# Import dataset and clean, ready as a dataframe for creating keys
def createDF(datasets):
    df = pd.read_csv(datasets, converters={
                     'PARTY_ID': str, 'COM_ID': str, 'CNTR_SIZE': str})

    # Formating to type and remove NaN values
    df['POD'] = pd.to_datetime(df['POD'])
    df['ENCODED_TYPE'] = df['ENCODED_TYPE'].fillna(-1).astype(int)
    df = df.dropna(subset=['ENCODED_TYPE'])
    df['RATE'] = df['RATE'].fillna(-1).astype(float)
    df = df.dropna(subset=['RATE'])
    df['ENCODED_TYPE'] = df['ENCODED_TYPE'].astype(int)
    df_clean = df.dropna().reset_index(drop=True)

    # Selecting and rearranging columns
    sel_col = ['CSL_ID', 'CNTR_ID', 'POD_ID', 'ETD_POL_D', 'PARTY_ID',
               'PARTY_NAME', 'POD', 'CNTR_SIZE', 'CNTR_TYPE', 'RATE']
    df_fc = df_clean[sel_col]

    # Removing years we do not want to process in our models
    df_filtered = df_fc[df_fc['POD'].dt.year != 2002]

    # Sorting the dates
    df_filtered = df_filtered.sort_values(by='POD').reset_index(drop=True)

    return df_filtered

# %%
# Create Dataframes for old and new
old_data = '.\Datasets\CR_COST_FC.csv'
df1 = createDF(old_data)
df1.head()

new_data = '.\Datasets\CR_COST_FC_new.csv'
df2 = createDF(new_data)
df2.head()
# Out:
#            CSL_ID           CNTR_ID          POD_ID ETD_POL_D  PARTY_ID  \
# 0  ECS01050600224  CTNR010050700354       ROTTERDAM     NLRTM  01008827
# 1  ECS01050600610  CTNR010050700353      FELIXSTOWE     GBFXT  01002303
# 2  ECS01050600041  CTNR010050700351        AUCKLAND     NZAKL  01005136
# 3  ECS01050600163  CTNR010050700370    PASIR GUDANG     MYPGU  01002767
# 4  ECS01050600456  CTNR010050700450  KARACHI (KICT)     PKKHI  01002783
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0             YANG MING (SINGAPORE) PTE. LTD. 2005-07-15        40    HC NOR
# 1                    GLOBELINK FALLOW LIMITED 2005-07-15        40        GP
# 2  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-15        40    HC NOR
# 3          GLOBELINK CONTAINER LINES (JB) S/B 2005-07-15        40        HC
# 4                GLOBELINK PAKISTAN (PVT) LTD 2005-07-16        40        HC
#
#      RATE
# 0  1620.0
# 1  1800.0
# 2  2170.0
# 3   280.0
# 4  1625.0
#            CSL_ID           CNTR_ID          POD_ID ETD_POL_D  PARTY_ID  \
# 0  ECS01050600224  CTNR010050700354       ROTTERDAM     NLRTM  01008827
# 1  ECS01050600610  CTNR010050700353      FELIXSTOWE     GBFXT  01002303
# 2  ECS01050600041  CTNR010050700351        AUCKLAND     NZAKL  01005136
# 3  ECS01050600163  CTNR010050700370    PASIR GUDANG     MYPGU  01002767
# 4  ECS01050600456  CTNR010050700450  KARACHI (KICT)     PKKHI  01002783
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0             YANG MING (SINGAPORE) PTE. LTD. 2005-07-15        40    HC NOR
# 1                    GLOBELINK FALLOW LIMITED 2005-07-15        40        GP
# 2  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-15        40    HC NOR
# 3          GLOBELINK CONTAINER LINES (JB) S/B 2005-07-15        40        HC
# 4                GLOBELINK PAKISTAN (PVT) LTD 2005-07-16        40        HC
#
#      RATE
# 0  1620.0
# 1  1800.0
# 2  2170.0
# 3   280.0
# 4  1625.0

# %% [markdown]
# <h4>Creating Dictionary Keys</h4>

# %%
def filter_dataframe(df):
    filtered_dataframes = {}

    for (port, size, ctype, party_id), group in df.groupby(['POD_ID', 'CNTR_SIZE', 'CNTR_TYPE', 'PARTY_ID']):
        group = group.reset_index(drop=True).sort_values(by='POD')
        df_id = f"Port_{port}_Size_{size}_Type_{ctype}_PartyID_{party_id}"
        filtered_dataframes[df_id] = group

    return filtered_dataframes

# %%
# Creating keys from data
print("Old Data keys:")
filtered_dataframe1 = filter_dataframe(df1)
df_ids1 = list(filtered_dataframe1.keys())
print(list(df_ids1))
print(len(list(df_ids1)))

print("\nNew Data keys:")
filtered_dataframe2 = filter_dataframe(df2)
df_ids2 = list(filtered_dataframe2.keys())
print(list(df_ids2))
print(len(list(df_ids2)))
# Out:
# Old Data keys:
# ['Port_(CONSTANZA)_Size_40_Type_GP_PartyID_010007816', 'Port_(CONSTANZA)_Size_40_Type_HC_PartyID_010007816', 'Port_AARHUS_Size_20_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100027830', 'Port_AARHUS_Size_20_Type_GP_PartyID_010006666', 'Port_AARHUS_Size_40_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100027830', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100028193', 'Port_AARHUS_Size_40_Type_HC_PartyID_010006666', 'Port_ABIDJAN_Size_20_Type_GP_PartyID_0100027878', 'Port_ABIDJAN_Size_40_Type_HC_PartyID_010021097', 'Port_ADELAIDE_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01005078', 'Port_ADELAIDE_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ALEXANDRIA (EL DEKHELA PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC NOR_PartyID_010004995', 'Port_ALGECIRAS_Size_20_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC NOR_PartyID_01008306', 'Port_ALIAGA_Size_20_Type_GP_PartyID_01008316', 'Port_ALIAGA_Size_40_Type_HC_PartyID_01008316', 'Port_ALIAGA PORT (IZMIR)_Size_40_Type_HC_PartyID_01008316', 'Port_ANTWERP_Size_20_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC NOR_PartyID_01001449', 'Port_AQABA_Size_20_Type_GP_PartyID_010006618', 'Port_AQABA_Size_20_Type_GP_PartyID_010021081', 'Port_AQABA_Size_40_Type_HC_PartyID_010006618', 'Port_AQABA_Size_40_Type_HC_PartyID_010021081', 'Port_ASHDOD_Size_20_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_01008417', 'Port_ASHDOD_Size_40_Type_HC_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_HC_PartyID_01008417', 'Port_AUCKLAND_Size_20_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_20_Type_GP (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC NOR_PartyID_01005136', 'Port_BANGKOK_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_20_Type_GP (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (SOC)_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK (TST)_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK (TST)_Size_40_Type_HC_PartyID_010021593', 'Port_BARCELONA_Size_20_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC NOR_PartyID_01008305', 'Port_BEIRUT_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_HC_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_40_Type_HC_PartyID_0100 ...
# 789
#
# New Data keys:
# ['Port_(CONSTANZA)_Size_40_Type_GP_PartyID_010007816', 'Port_(CONSTANZA)_Size_40_Type_HC_PartyID_010007816', 'Port_AARHUS_Size_20_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100027830', 'Port_AARHUS_Size_20_Type_GP_PartyID_0100028193', 'Port_AARHUS_Size_20_Type_GP_PartyID_010006666', 'Port_AARHUS_Size_40_Type_GP_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_01000043', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100027830', 'Port_AARHUS_Size_40_Type_HC_PartyID_0100028193', 'Port_AARHUS_Size_40_Type_HC_PartyID_010006666', 'Port_ABIDJAN_Size_20_Type_GP_PartyID_0100027878', 'Port_ABIDJAN_Size_40_Type_HC_PartyID_010021097', 'Port_ADELAIDE_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_GP_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE_Size_40_Type_HC_PartyID_01005078', 'Port_ADELAIDE_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_20_Type_GP_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC_PartyID_01002775', 'Port_ADELAIDE(AU)_Size_40_Type_HC NOR_PartyID_01002775', 'Port_ALEXANDRIA (EL DEKHELA PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA (OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_20_Type_GP_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC_PartyID_010004995', 'Port_ALEXANDRIA(OLD PORT)_Size_40_Type_HC NOR_PartyID_010004995', 'Port_ALGECIRAS_Size_20_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_GP_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC_PartyID_01008306', 'Port_ALGECIRAS_Size_40_Type_HC NOR_PartyID_01008306', 'Port_ALIAGA_Size_20_Type_GP_PartyID_01008316', 'Port_ALIAGA_Size_40_Type_HC_PartyID_01008316', 'Port_ALIAGA PORT (IZMIR)_Size_40_Type_HC_PartyID_01008316', 'Port_ANTWERP_Size_20_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_GP_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC_PartyID_01001449', 'Port_ANTWERP_Size_40_Type_HC NOR_PartyID_01001449', 'Port_AQABA_Size_20_Type_GP_PartyID_010006618', 'Port_AQABA_Size_20_Type_GP_PartyID_010021081', 'Port_AQABA_Size_40_Type_HC_PartyID_010006618', 'Port_AQABA_Size_40_Type_HC_PartyID_010021081', 'Port_ASHDOD_Size_20_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_GP_PartyID_01008417', 'Port_ASHDOD_Size_40_Type_HC_PartyID_010008035', 'Port_ASHDOD_Size_40_Type_HC_PartyID_01008417', 'Port_AUCKLAND_Size_20_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_20_Type_GP (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_GP_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC (DG)_PartyID_01005136', 'Port_AUCKLAND_Size_40_Type_HC NOR_PartyID_01005136', 'Port_BANGKOK_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_20_Type_GP (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_GP_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_010021593', 'Port_BANGKOK_Size_40_Type_HC (DG)_PartyID_01002799', 'Port_BANGKOK_Size_40_Type_HC (SOC)_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_20_Type_GP_PartyID_01002799', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_010021593', 'Port_BANGKOK ( TPT )_Size_40_Type_HC_PartyID_01002799', 'Port_BANGKOK (TST)_Size_20_Type_GP_PartyID_010021593', 'Port_BANGKOK (TST)_Size_40_Type_HC_PartyID_010021593', 'Port_BARCELONA_Size_20_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_GP_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC_PartyID_01008305', 'Port_BARCELONA_Size_40_Type_HC NOR_PartyID_01008305', 'Port_BEIRUT_Size_20_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_GP_PartyID_010003651', 'Port_BEIRUT_Size_40_Type_HC_PartyID_010003651', 'Port_BEIRUT FREE ZONE_Size_20_Type_GP_PartyID_010003651', ' ...
# 799

# %% [markdown]
# <h4>Getting Top 5 ports keys</h4>

# %%
def getTop5Ports(keybunch):
    keybunch_pouch = []

    # Get a dictionary with key and number of rows for each dataframe in filtered_dataframes
    key_row_counts = {key: len(keybunch[key]) for key in keybunch}

    # Sort the key_row_counts dictionary by value (number of rows) in descending order
    sorted_key_row_counts = sorted(
        key_row_counts.items(), key=lambda item: item[1], reverse=True)

    # Get the top 5 keys with the most rows
    top_5_keys_tuple = sorted_key_row_counts[:5]

    # Create a dictionary with the top 5 keys and their corresponding dataframes (with up to 5 rows per dataframe)
    keybunch_subset = {}

    for key, row_count in top_5_keys_tuple:
        keybunch_subset[key] = keybunch[key][:5]
        print(f"Number of rows in {key}: {row_count}")
        keybunch_pouch.append(key)

    # Return array of keys
    return keybunch_pouch

# %%
print('Old Dataset Keybunch:')
old_df = getTop5Ports(filtered_dataframe1)
print('\n')

print('New Dataset Keybunch:')
new_df = getTop5Ports(filtered_dataframe2)
# Out:
# Old Dataset Keybunch:
# Number of rows in Port_BUSAN_Size_40_Type_HC_PartyID_010004286: 1689
# Number of rows in Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136: 1688
# Number of rows in Port_MELBOURNE_Size_40_Type_HC_PartyID_01002778: 1325
# Number of rows in Port_SYDNEY_Size_40_Type_HC_PartyID_01002779: 1300
# Number of rows in Port_DUBAI (JEBEL ALI)_Size_40_Type_HC_PartyID_01002788: 1052
#
#
# New Dataset Keybunch:
# Number of rows in Port_BUSAN_Size_40_Type_HC_PartyID_010004286: 1712
# Number of rows in Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136: 1704
# Number of rows in Port_MELBOURNE_Size_40_Type_HC_PartyID_01002778: 1341
# Number of rows in Port_SYDNEY_Size_40_Type_HC_PartyID_01002779: 1308
# Number of rows in Port_DUBAI (JEBEL ALI)_Size_40_Type_HC_PartyID_01002788: 1070

# %%
# Accessing the highest count in the each keypouch, new and old.
sel_df = filtered_dataframe1[old_df[1]]
sel_df.head(5)
sel_df.tail(5)
sel_df.info()
print("\n")

latest_sel_df = filtered_dataframe2[new_df[1]]
latest_sel_df.head(5)
latest_sel_df.tail(5)
latest_sel_df.info()
# Out:
#             CSL_ID           CNTR_ID    POD_ID ETD_POL_D  PARTY_ID  \
# 0   ECS01050600140  CTNR010050700496  AUCKLAND     NZAKL  01005136
# 1   ECS01050600140  CTNR010050700495  AUCKLAND     NZAKL  01005136
# 2  ECS010050700037  CTNR010050700657  AUCKLAND     NZAKL  01005136
# 3   ECS01050600141  CTNR010050700808  AUCKLAND     NZAKL  01005136
# 4   ECS01050600042  CTNR010050700971  AUCKLAND     NZAKL  01005136
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-19        40        HC
# 1  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-19        40        HC
# 2  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-21        40        HC
# 3  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-26        40        HC
# 4  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-29        40        HC
#
#      RATE
# 0  2200.0
# 1  2200.0
# 2  2300.0
# 3  2200.0
# 4  2600.0
#                CSL_ID       CNTR_ID    POD_ID ETD_POL_D  PARTY_ID  \
# 1683  ECS010230100188  010000371218  AUCKLAND     NZAKL  01005136
# 1684  ECS010230100390  010000377561  AUCKLAND     NZAKL  01005136
# 1685  ECS010230100390  010000371211  AUCKLAND     NZAKL  01005136
# 1686  ECS010230100462  010000390201  AUCKLAND     NZAKL  01005136
# 1687  ECS010230100462  010000377408  AUCKLAND     NZAKL  01005136
#
#                                       PARTY_NAME        POD CNTR_SIZE  \
# 1683  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2023-02-09        40
# 1684  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2023-02-14        40
# 1685  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2023-02-14        40
# 1686  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2023-02-21        40
# 1687  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2023-02-21        40
#
#      CNTR_TYPE    RATE
# 1683        HC  1500.0
# 1684        HC  1500.0
# 1685        HC  1500.0
# 1686        HC  1500.0
# 1687        HC  1500.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1688 entries, 0 to 1687
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      1688 non-null   object
#  1   CNTR_ID     1688 non-null   object
#  2   POD_ID      1688 non-null   object
#  3   ETD_POL_D   1688 non-null   object
#  4   PARTY_ID    1688 non-null   object
#  5   PARTY_NAME  1688 non-null   object
#  6   POD         1688 non-null   datetime64[ns]
#  7   CNTR_SIZE   1688 non-null   object
#  8   CNTR_TYPE   1688 non-null   object
#  9   RATE        1688 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 145.1+ KB
#             CSL_ID           CNTR_ID    POD_ID ETD_POL_D  PARTY_ID  \
# 0   ECS01050600140  CTNR010050700496  AUCKLAND     NZAKL  01005136
# 1   ECS01050600140  CTNR010050700495  AUCKLAND     NZAKL  01005136
# 2  ECS010050700037  CTNR010050700657  AUCKLAND     NZAKL  01005136
# 3   ECS01050600141  CTNR010050700808  AUCKLAND     NZAKL  01005136
# 4   ECS01050600042  CTNR010050700971  AUCKLAND     NZAKL  01005136
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-19        40        HC
# 1  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-19        40        HC
# 2  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-21        40        HC
# 3  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-26        40        HC
# 4  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2005-07-29        40        HC
#
#      RATE
# 0  2200.0
# 1  2200.0
# 2  2300.0
# 3  2200.0
# 4  2600.0
#                CSL_ID       CNTR_ID    POD_ID ETD_POL_D  PARTY_ID  \
# 1699  ECS010230200029  010000495920  AUCKLAND     NZAKL  01005136
# 1700  ECS010230400101  010000535699  AUCKLAND     NZAKL  01005136
# 1701  ECS010230300066  010000515298  AUCKLAND     NZAKL  01005136
# 1702  ECS010230300067  010000550266  AUCKLAND     NZAKL  01005136
# 1703  ECS010230300067  010000535541  AUCKLAND     NZAKL  01005136
#
#                                       PARTY_NAME        POD CNTR_SIZE  \
# 1699  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2023-04-23        40
# 1700  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2023-05-02        40
# 1701  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2023-05-02        40
# 1702  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2023-05-08        40
# 1703  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2023-05-08        40
#
#      CNTR_TYPE   RATE
# 1699        HC  664.0
# 1700        HC  350.0
# 1701        HC  264.0
# 1702        HC  264.0
# 1703        HC  264.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1704 entries, 0 to 1703
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      1704 non-null   object
#  1   CNTR_ID     1704 non-null   object
#  2   POD_ID      1704 non-null   object
#  3   ETD_POL_D   1704 non-null   object
#  4   PARTY_ID    1704 non-null   object
#  5   PARTY_NAME  1704 non-null   object
#  6   POD         1704 non-null   datetime64[ns]
#  7   CNTR_SIZE   1704 non-null   object
#  8   CNTR_TYPE   1704 non-null   object
#  9   RATE        1704 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 146.4+ KB

# %% [markdown]
# <h4>Interpolate missing values in between dates</h4>

# %%
# Interpolate using spline interpolation

# Remove duplicated dates and cost rows
sel_df = sel_df.drop_duplicates(subset=['POD', 'RATE']).reset_index(drop=True)

# Remove features that are not important
sel_feat = ['POD', 'RATE']
sel_df = sel_df[sel_feat]

# Create a new dataframe with a date range from min to max date in your dataframe
new_df = pd.DataFrame()
new_df['POD'] = pd.date_range(
    start=sel_df['POD'].min(), end=sel_df['POD'].max())

# Merge the original dataframe with the new one. Missing dates in the original dataframe will be filled with NaN
df_interpolated = pd.merge(new_df, sel_df, on='POD', how='left')

# Perform spline interpolation
df_interpolated['RATE'] = df_interpolated['RATE'].interpolate(
    method='spline', order=1)

df_interpolated['RATE'] = df_interpolated['RATE'].round(2)

df_interpolated.head(5)
df_interpolated.tail(5)
df_interpolated.info()
# Out:
#          POD     RATE
# 0 2005-07-19  2200.00
# 1 2005-07-20  2249.99
# 2 2005-07-21  2300.00
# 3 2005-07-22  2279.99
# 4 2005-07-23  2260.01
#             POD    RATE
# 6447 2023-02-17  1500.0
# 6448 2023-02-18  1500.0
# 6449 2023-02-19  1500.0
# 6450 2023-02-20  1500.0
# 6451 2023-02-21  1500.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6452 entries, 0 to 6451
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POD     6452 non-null   datetime64[ns]
#  1   RATE    6452 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 151.2 KB

# %% [markdown]
# <h4>Grouping it to week</h4>

# %%
# Create YearMonthWeek directly from the 'POD'
df_interpolated['YearMonthWeek'] = df_interpolated['POD'] - \
    pd.to_timedelta(df_interpolated['POD'].dt.dayofweek, unit='D')

# Create a new dataframe with every week in the range
all_weeks = pd.date_range(start=df_interpolated['POD'].min(
), end=df_interpolated['POD'].max(), freq='W')
all_weeks_df = pd.DataFrame(all_weeks, columns=['POD'])

# Create YearMonthWeek in all_weeks_df
all_weeks_df['YearMonthWeek'] = all_weeks_df['POD'] - \
    pd.to_timedelta(all_weeks_df['POD'].dt.dayofweek, unit='D')

# Merge this with your original dataframe
merged_df = pd.merge(all_weeks_df, df_interpolated,
                     on=['YearMonthWeek'], how='left')

# Now you can group by YearMonthWeek and compute your rate
grouped = merged_df.groupby(['YearMonthWeek'])

agg_df = pd.DataFrame(columns=['YearMonthWeek', 'Rate'])

for group_name, group_df in grouped:
    year_month_week = group_name

    # Skip if no data for this week
    if group_df['RATE'].isnull().all():
        continue

    # Calculate sum and skewness of RATE values
    rate_sum = group_df['RATE'].sum()
    rate_skew = group_df['RATE'].skew()

    # Calculate mean or median based on skewness
    if rate_skew < 0:
        rate_metric = group_df['RATE'].mean()
    else:
        rate_metric = group_df['RATE'].median()

    new_row = {
        'YearMonthWeek': year_month_week,
        'Rate': rate_metric
    }

    # Append row to aggregated dataframe
    agg_df = agg_df.append(new_row, ignore_index=True)

agg_df = agg_df.sort_values(by='YearMonthWeek').reset_index(drop=True)

agg_df.head(15)
agg_df.tail(15)
agg_df.info()
# Out:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:23: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for group_name, group_df in grouped:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# ...
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\564349944.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_df = agg_df.append(new_row, ignore_index=True)
#    YearMonthWeek         Rate
# 0     2005-07-18  2255.001667
# 1     2005-07-25  2388.568571
# 2     2005-08-01  2261.425714
# 3     2005-08-08  2200.000000
# 4     2005-08-15  2253.570000
# 5     2005-08-22  2252.142857
# 6     2005-08-29  2252.450000
# 7     2005-09-05  2214.290000
# 8     2005-09-12  2200.000000
# 9     2005-09-19  2200.000000
# 10    2005-09-26  2200.000000
# 11    2005-10-03  2200.000000
# 12    2005-10-10  2200.000000
# 13    2005-10-17  2200.000000
# 14    2005-10-24  2200.000000
#     YearMonthWeek         Rate
# 903    2022-11-07  5145.744286
# 904    2022-11-14  5877.270000
# 905    2022-11-21  5404.560000
# 906    2022-11-28  4232.477143
# 907    2022-12-05  3433.128571
# 908    2022-12-12  3580.520000
# 909    2022-12-19  4012.910000
# 910    2022-12-26  4166.275714
# 911    2023-01-02  2800.350000
# 912    2023-01-09  2687.470000
# 913    2023-01-16  2715.630000
# 914    2023-01-23  3350.785714
# 915    2023-01-30  1500.090000
# 916    2023-02-06  1500.000000
# 917    2023-02-13  1499.997143
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   YearMonthWeek  918 non-null    datetime64[ns]
#  1   Rate           918 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 14.5 KB

# %% [markdown]
# <h4>Latest datapoints from Latest dataframe for comparing after forecasting (Measure accuracy)</h4>

# %%
max_date_in_old = sel_df['POD'].max()

# Create a new dataframe that only includes rows from the latest dataframe where the date is greater than the maximum date in the old dataframe
new_dates_df = latest_sel_df[latest_sel_df['POD']
                             > max_date_in_old].reset_index(drop=True)

# Print the new dataframe
new_dates_df.head(3)
new_dates_df.tail(3)
new_dates_df.info()
# Out:
#             CSL_ID       CNTR_ID    POD_ID ETD_POL_D  PARTY_ID  \
# 0  ECS010230200255  010000421246  AUCKLAND     NZAKL  01005136
# 1  ECS010230200255  010000410650  AUCKLAND     NZAKL  01005136
# 2  ECS010230100273  010000423692  AUCKLAND     NZAKL  01005136
#
#                                    PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 0  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2023-03-10        40        HC
# 1  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2023-03-10        40        HC
# 2  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2023-03-14        40        HC
#
#      RATE
# 0  1100.0
# 1  1100.0
# 2   986.0
#              CSL_ID       CNTR_ID    POD_ID ETD_POL_D  PARTY_ID  \
# 13  ECS010230300066  010000515298  AUCKLAND     NZAKL  01005136
# 14  ECS010230300067  010000550266  AUCKLAND     NZAKL  01005136
# 15  ECS010230300067  010000535541  AUCKLAND     NZAKL  01005136
#
#                                     PARTY_NAME        POD CNTR_SIZE CNTR_TYPE  \
# 13  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2023-05-02        40        HC
# 14  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2023-05-08        40        HC
# 15  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND 2023-05-08        40        HC
#
#      RATE
# 13  264.0
# 14  264.0
# 15  264.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CSL_ID      16 non-null     object
#  1   CNTR_ID     16 non-null     object
#  2   POD_ID      16 non-null     object
#  3   ETD_POL_D   16 non-null     object
#  4   PARTY_ID    16 non-null     object
#  5   PARTY_NAME  16 non-null     object
#  6   POD         16 non-null     datetime64[ns]
#  7   CNTR_SIZE   16 non-null     object
#  8   CNTR_TYPE   16 non-null     object
#  9   RATE        16 non-null     float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 1.4+ KB

# %%
plt.figure(figsize=(20, 10))
plt.plot(sel_df['POD'], sel_df['RATE'], color='blue', label="Actual Data")
plt.plot(agg_df['YearMonthWeek'], agg_df['Rate'],
         color='red', label="Aggregated Data(weeks)")

plt.xlabel('Date(Year Month Week)')
plt.ylabel('Cost Rate(USD)')
plt.title(old_df[1])
plt.legend()
plt.show()
# Out:
# Text(0.5, 0, 'Date(Year Month Week)')
# Text(0, 0.5, 'Cost Rate(USD)')
# Text(0.5, 1.0, 'Port_AUCKLAND_Size_40_Type_HC_PartyID_01005136')

# %% [markdown]
# <h4>Mean Square Error Evaluation Function</h4>

# %%
# Mean Square Error Function:
def calculate_RMSE(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %% [markdown]
# <h4>LSTM Regression<h4>

# %%
from keras.layers import Dropout
from keras.callbacks import EarlyStopping
from keras.regularizers import l1_l2
from keras.wrappers.scikit_learn import KerasRegressor
from bayes_opt import BayesianOptimization
from keras.models import load_model
from keras.layers import LSTM, Dense
from keras.models import Sequential
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Define the bounds of the parameters for the Bayesian Optimization
pbounds = {
    'look_back': (1, 10),
    'neurons': (32, 128),
    'dropout': (0.1, 0.5),
    'lr': (0.0001, 0.01),
    'epochs': (10, 100),
    'batch_size': (32, 256)
}

# Restructure time series data for LSTM model
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# add l1_l2 regularization
def create_model(dropout_rate=0.0, l1_factor=0.0, l2_factor=0.0, learning_rate=0.001, neurons=64, look_back=5):
    model = Sequential()
    model.add(LSTM(neurons, return_sequences=True, input_shape=(trainX.shape[1], trainX.shape[2]), activation='tanh', recurrent_activation='hard_sigmoid', kernel_regularizer=l1_l2(l1_factor, l2_factor)))
    model.add(Dropout(dropout_rate))
    model.add(LSTM(neurons//2, activation='tanh'))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate))
    return model

def train_LSTM_model(look_back=5, neurons=64, dropout=0.3, lr=0.001, epochs=50, batch_size=64):
    look_back = int(look_back)
    neurons = int(neurons)
    epochs = int(epochs)
    batch_size = int(batch_size)

    model = create_model(dropout, 0.0, 0.0, lr, neurons, look_back)

    # Fit the model and store the history
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=batch_size, verbose=2, validation_data=(testX, testY))

    return model, history

def evaluate_model(look_back=5, neurons=64, dropout=0.3, lr=0.001, epochs=50, batch_size=64):
    _, history = train_LSTM_model(look_back, neurons, dropout, lr, epochs, batch_size)

    # Return the validation loss of the last epoch
    return -history.history['val_loss'][-1]

# Ensemble prediction
def ensemble_predictions(members, testX):
    # make predictions
    yhats = [model.predict(testX) for model in members]
    yhats = np.array(yhats)
    # sum across ensemble members
    summed = np.sum(yhats, axis=0)
    # argmax across classes
    result = summed / len(members)
    return result, testY[-result.shape[0]:]

# %%
# Normalize dataset for LSTM
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(agg_df['Rate'].values.reshape(-1,1))

# Split into train and test sets
train_size = int(len(dataset) * 0.70)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# Reshape into X=t and Y=t+1, timestep  look_back
look_back = 5
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# Reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# Initialize the optimizer
optimizer = BayesianOptimization(
    f=evaluate_model,
    pbounds=pbounds,
    random_state=1,
)

# Optimize the model
optimizer.maximize(init_points=10, n_iter=50)

# Extract the best parameters
params = optimizer.max['params']

# Train the model with the optimized hyperparameters
print('Training with optimized parameters...')
model, history = train_LSTM_model(look_back=params['look_back'], neurons=params['neurons'], dropout=params['dropout'], lr=params['lr'], epochs=params['epochs'], batch_size=params['batch_size'])
# Out:
# |   iter    |  target   | batch_... |  dropout  |  epochs   | look_back |    lr     |  neurons  |
# -------------------------------------------------------------------------------------------------
# Epoch 1/10
# 6/6 - 4s - loss: 0.0091 - val_loss: 0.1551 - 4s/epoch - 635ms/step
# Epoch 2/10
# 6/6 - 0s - loss: 0.0050 - val_loss: 0.1278 - 49ms/epoch - 8ms/step
# Epoch 3/10
# 6/6 - 0s - loss: 0.0026 - val_loss: 0.1019 - 48ms/epoch - 8ms/step
# Epoch 4/10
# 6/6 - 0s - loss: 0.0018 - val_loss: 0.0828 - 48ms/epoch - 8ms/step
# Epoch 5/10
# 6/6 - 0s - loss: 0.0019 - val_loss: 0.0762 - 47ms/epoch - 8ms/step
# Epoch 6/10
# 6/6 - 0s - loss: 0.0018 - val_loss: 0.0788 - 47ms/epoch - 8ms/step
# Epoch 7/10
# 6/6 - 0s - loss: 0.0016 - val_loss: 0.0788 - 47ms/epoch - 8ms/step
# Epoch 8/10
# 6/6 - 0s - loss: 0.0015 - val_loss: 0.0743 - 47ms/epoch - 8ms/step
# Epoch 9/10
# 6/6 - 0s - loss: 0.0015 - val_loss: 0.0655 - 47ms/epoch - 8ms/step
# Epoch 10/10
# 6/6 - 0s - loss: 0.0013 - val_loss: 0.0546 - 46ms/epoch - 8ms/step
# | 1         | -0.0546   | 125.4     | 0.3881    | 10.01     | 3.721     | 0.001553  | 40.86     |
# Epoch 1/45
# 9/9 - 4s - loss: 0.0043 - val_loss: 0.0623 - 4s/epoch - 429ms/step
# Epoch 2/45
# 9/9 - 0s - loss: 0.0017 - val_loss: 0.0672 - 65ms/epoch - 7ms/step
# Epoch 3/45
# 9/9 - 0s - loss: 9.0520e-04 - val_loss: 0.0164 - 63ms/epoch - 7ms/step
# Epoch 4/45
# 9/9 - 0s - loss: 4.3015e-04 - val_loss: 0.0034 - 64ms/epoch - 7ms/step
# Epoch 5/45
# 9/9 - 0s - loss: 3.4515e-04 - val_loss: 0.0055 - 63ms/epoch - 7ms/step
# Epoch 6/45
# 9/9 - 0s - loss: 3.2100e-04 - val_loss: 0.0031 - 66ms/epoch - 7ms/step
# Epoch 7/45
# 9/9 - 0s - loss: 3.2890e-04 - val_loss: 0.0030 - 65ms/epoch - 7ms/step
# Epoch 8/45
# 9/9 - 0s - loss: 3.1090e-04 - val_loss: 0.0030 - 64ms/epoch - 7ms/step
# Epoch 9/45
# 9/9 - 0s - loss: 2.9745e-04 - val_loss: 0.0030 - 65ms/epoch - 7ms/step
# Epoch 10/45
# 9/9 - 0s - loss: 2.5966e-04 - val_loss: 0.0028 - 65ms/epoch - 7ms/step
# Epoch 11/45
# 9/9 - 0s - loss: 2.6416e-04 - val_loss: 0.0029 - 65ms/epoch - 7ms/step
# Epoch 12/45
# 9/9 - 0s - loss: 2.6390e-04 - val_loss: 0.0028 - 65ms/epoch - 7ms/step
# Epoch 13/45
# 9/9 - 0s - loss: 2.5128e-04 - val_loss: 0.0027 - 65ms/epoch - 7ms/step
# Epoch 14/45
# 9/9 - 0s - loss: 2.4711e-04 - val_loss: 0.0028 - 65ms/epoch - 7ms/step
# Epoch 15/45
# 9/9 - 0s - loss: 2.4575e-04 - val_loss: 0.0028 - 64ms/epoch - 7ms/step
# Epoch 16/45
# 9/9 - 0s - loss: 2.4877e-04 - val_loss: 0.0026 - 65ms/epoch - 7ms/step
# Epoch 17/45
# 9/9 - 0s - loss: 2.3877e-04 - val_loss: 0.0026 - 64ms/epoch - 7ms/step
# Epoch 18/45
# 9/9 - 0s - loss: 2.3300e-04 - val_loss: 0.0027 - 64ms/epoch - 7ms/step
# Epoch 19/45
# 9/9 - 0s - loss: 2.3172e-04 - val_loss: 0.0024 - 63ms/epoch - 7ms/step
# Epoch 20/45
# 9/9 - 0s - loss: 2.3194e-04 - val_loss: 0.0025 - 64ms/epoch - 7ms/step
# Epoch 21/45
# 9/9 - 0s - loss: 2.2263e-04 - val_loss: 0.0024 - 68ms/epoch - 8ms/step
# Epoch 22/45
# 9/9 - 0s - loss: 2.1975e-04 - val_loss: 0.0026 - 68ms/epoch - 8ms/step
# Epoch 23/45
# 9/9 - 0s - loss: 2.2475e-04 - val_loss: 0.0028 - 65ms/epoch - 7ms/step
# Epoch 24/45
# 9/9 - 0s - loss: 2.2399e-04 - val_loss: 0.0026 - 64ms/epoch - 7ms/step
# Epoch 25/45
# 9/9 - 0s - loss: 2.0995e-04 - val_loss: 0.0022 - 62ms/epoch - 7ms/step
# Epoch 26/45
# 9/9 - 0s - loss: 2.1021e-04 - val_loss: 0.0024 - 63ms/epoch - 7ms/step
# Epoch 27/45
# 9/9 - 0s - loss: 2.1827e-04 - val_loss: 0.0028 - 63ms/epoch - 7ms/step
# Epoch 28/45
# 9/9 - 0s - loss: 2.0160e-04 - val_loss: 0.0024 - 63ms/epoch - 7ms/step
# Epoch 29/45
# 9/9 - 0s - loss: 2.1396e-04 - val_loss: 0.0026 - 62ms/epoch - 7ms/step
# Epoch 30/45
# 9/9 - 0s - loss: 2.1093e-04 - val_loss: 0.0025 - 63ms/epoch - 7ms/step
# Epoch 31/45
# 9/9 - 0s - loss: 2.0958e-04 - val_loss: 0.0023 - 65ms/epoch - 7ms/step
# Epoch 32/45
# 9/9 - 0s - loss: 2.0943e-04 - val_loss: 0.0023 - 63ms/epoch - 7ms/step
# Epoch 33/45
# 9/9 - 0s - loss: 2.1720e-04 - val_loss: 0.0021 - 63ms/epoch - 7ms/step
# Epoch 34/45
# 9/9 - 0s - loss: 2.3258e-04 - val_loss: 0.0023 - 62ms/epoch - 7ms/step
# Epoch 35/45
# 9/9 - 0s - loss: 2.4540e-04 - val_loss: 0.0028 - 64ms/epoch - 7ms/step
# Epoch 36/45
# 9/9 - 0s - loss: 2.4045e-04 - val_loss: 0.0036 - 63ms/epoch - 7ms/step
# Epoch 37/45
# 9/9 - 0s - loss: 2.3427e-04 - val_loss: 0.0030 - 63ms/epoch - 7ms/step
# Epoch 38/45
# 9/9 - 0s - loss: 2.2085e-04 - val_loss: 0.0025 - 63ms/epoch - 7ms/step
# Epoch 39/45
# 9/9 - 0s - loss: 2.3294e-04 - val_loss: 0.0025 - 64ms/epoch - 7ms/step
# Epoch 40/45
# 9/9 - 0s - loss: 2.2850e-04 - val_loss: 0.0025 - 65ms/epoch - 7ms/step
# Epoch 41/45
# 9/9 - 0s - loss: 2.3079e-04 - val_loss: 0.0034 - 64ms/epoch - 7ms/step
# Epoch 42/45
# 9/9 - 0s - loss: 2.2172e-04 - val_loss: 0.0038 - 65ms/epoch - 7ms/step
# Epoch 43/45
# 9/9 - 0s - loss: 2.0007e-04 - val_loss: 0.0032 - 64ms/epoch - 7ms/step
# Epoch 44/45
# 9/9 - 0s - loss: 1.9786e-04 - val_loss: 0.0034 - 63ms/epoch - 7ms/step
# Epoch 45/45
# 9/9 - 0s - loss: 1.9875e-04 - val_loss: 0.0033 - 63ms/epoch - 7ms/step
# | 2         | -0.003286 | 73.72     | 0.2382    | 45.71     | 5.849     | 0.00425   | 97.78     |
# Epoch 1/12
# 9/9 - 4s - loss: 0.0047 - val_loss: 0.0590 - 4s/epoch - 422ms/step
# Epoch 2/12
# 9/9 - 0s - loss: 0.0020 - val_loss: 0.0862 - 62ms/epoch - 7ms/step
# Epoch 3/12
# 9/9 - 0s - loss: 0.0014 - val_loss: 0.0298 - 62ms/epoch - 7ms/step
# Epoch 4/12
# 9/9 - 0s - loss: 7.4630e-04 - val_loss: 0.0114 - 62ms/epoch - 7ms/step
# Epoch 5/12
# 9/9 - 0s - loss: 3.9157e-04 - val_loss: 0.0046 - 62ms/epoch - 7ms/step
# Epoch 6/12
# 9/9 - 0s - loss: 3.6188e-04 - val_loss: 0.0062 - 61ms/epoch - 7ms/step
# Epoch 7/12
# 9/9 - 0s - loss: 3.3429e-04 - val_loss: 0.0030 - 63ms/epoch - 7ms/step
# Epoch 8/12
# 9/9 - 0s - loss: 3.1666e-04 - val_loss: 0.0038 - 62ms/epoch - 7ms/step
# Epoch 9/12
# 9/9 - 0s - loss: 2.9602e-04 - val_loss: 0.0033 - 62ms/epoch - 7ms/step
# Epoch 10/12
# 9/9 - 0s - loss: 2.9911e-04 - val_loss: 0.0029 - 87ms/epoch - 10ms/step
# Epoch 11/12
# 9/9 - 0s - loss: 2.8945e-04 - val_loss: 0.0029 - 64ms/epoch - 7ms/step
# Epoch 12/12
# 9/9 - 0s - loss: 2.9562e-04 - val_loss: 0.0030 - 62ms/epoch - 7ms/step
# | 3         | -0.00295  | 77.8      | 0.4512    | 12.46     | 7.034     | 0.004231  | 85.63     |
# Epoch 1/82
# 11/11 - 4s - loss: 0.0051 - val_loss: 0.0658 - 4s/epoch - 385ms/step
# Epoch 2/82
# 11/11 - 0s - loss: 0.0019 - val_loss: 0.0835 - 72ms/epoch - 7ms/step
# Epoch 3/82
# 11/11 - 0s - loss: 0.0012 - val_loss: 0.0250 - 71ms/epoch - 6ms/step
# Epoch 4/82
# 11/11 - 0s - loss: 6.1908e-04 - val_loss: 0.0054 - 71ms/epoch - 6ms/step
# Epoch 5/82
# 11/11 - 0s - loss: 3.1370e-04 - val_loss: 0.0059 - 72ms/epoch - 7ms/step
# Epoch 6/82
# 11/11 - 0s - loss: 2.9547e-04 - val_loss: 0.0038 - 70ms/epoch - 6ms/step
# Epoch 7/82
# 11/11 - 0s - loss: 3.2380e-04 - val_loss: 0.0034 - 71ms/epoch - 6ms/step
# Epoch 8/82
# 11/11 - 0s - loss: 2.9973e-04 - val_loss: 0.0029 - 70ms/epoch - 6ms/step
# Epoch 9/82
# 11/11 - 0s - loss: 2.8142e-04 - val_loss: 0.0029 - 72ms/epoch - 7ms/step
# Epoch 10/82
# 11/11 - 0s - loss: 2.6758e-04 - val_loss: 0.0033 - 71ms/epoch - 6ms/step
# Epoch 11/82
# 11/11 - 0s - loss: 2.6254e-04 - val_loss: 0.0030 - 72ms/epoch - 7ms/step
# Epoch 12/82
# 11/11 - 0s - loss: 2.5010e-04 - val_loss: 0.0030 - 74ms/epoch - 7ms/step
# Epoch 13/82
# 11/11 - 0s - loss: 2.6120e-04 - val_loss: 0.0028 - 74ms/epoch - 7ms/step
# Epoch 14/82
# 11/11 - 0s - loss: 2.5535e-04 - val_loss: 0.0026 - 72ms/epoch - 7ms/step
# Epoch 15/82
# 11/11 - 0s - loss: 2.4274e-04 - val_loss: 0.0026 - 73ms/epoch - 7ms/step
# Epoch 16/82
# 11/11 - 0s - loss: 2.5023e-04 - val_loss: 0.0027 - 75ms/epoch - 7ms/step
# Epoch 17/82
# 11/11 - 0s - loss: 2.4291e-04 - val_loss: 0.0026 - 72ms/epoch - 7ms/step
# Epoch 18/82
# 11/11 - 0s - loss: 2.4192e-04 - val_loss: 0.0026 - 79ms/epoch - 7ms/step
# Epoch 19/82
# 11/11 - 0s - loss: 2.3980e-04 - val_loss: 0.0025 - 74ms/epoch - 7ms/step
# Epoch 20/82
# 11/11 - 0s - loss: 2.3371e-04 - val_loss: 0.0025 - 73ms/epoch - 7ms/step
# Epoch 21/82
# 11/11 - 0s - loss: 2.3665e-04 - val_loss: 0.0027 - 71ms/epoch - 6ms/step
# Epoch 22/82
# 11/11 - 0s - loss: 2.4761e-04 - val_loss: 0.0025 - 71ms/epoch - 6ms/step
# Epoch 23/82
# 11/11 - 0s - loss: 2.2920e-04 - val_loss: 0.0023 - 72ms/epoch - 7ms/step
# Epoch 24/82
# 11/11 - 0s - loss: 2.4516e-04 - val_loss: 0.0023 - 70ms/epoch - 6ms/step
# Epoch 25/82
# 11/11 - 0s - loss: 2.2959e-04 - val_loss: 0.0023 - 70ms/epoch - 6ms/step
# Epoch 26/82
# 11/11 - 0s - loss: 2.2116e-04 - val_loss: 0.0023 - 72ms/epoch - 7ms/step
# Epoch 27/82
# 11/11 - 0s - loss: 2.1560e-04 - val_loss: 0.0023 - 70ms/epoch - 6ms/step
# Epoch 28/82
# 11/11 - 0s - loss: 2.2045e-04 - val_loss: 0.0023 - 70ms/epoch - 6ms/step
# Epoch 29/82
# 11/11 - 0s - loss: 2.1965e-04 - val_loss: 0.0031 - 70ms/epoch - 6ms/step
# Epoch 30/82
# 11/11 - 0s - loss: 2.3518e-04 - val_loss: 0.0026 - 70ms/epoch - 6ms/step
# Epoch 31/82
# 11/11 - 0s - loss: 2.1249e-04 - val_loss: 0.0022 - 70ms/epoch - 6ms/step
# Epoch 32/82
# 11/11 - 0s - loss: 2.0953e-04 - val_loss: 0.0025 - 71ms/epoch - 6ms/step
# Epoch 33/82
# 11/11 - 0s - loss: 2.1501e-04 - val_loss: 0.0028 - 71ms/epoch - 6ms/step
# Epoch 34/82
# 11/11 - 0s - loss: 2.3119e-04 - val_loss: 0.0031 - 70ms/epoch - 6ms/step
# Epoch 35/82
# 11/11 - 0s - loss: 2.1850e-04 - val_loss: 0.0025 - 71ms/epoch - 6ms/step
# Epoch 36/82
# 11/11 - 0s - loss: 2.1131e-04 - val_loss: 0.0024 - 70ms/epoch - 6ms/step
# Epoch 37/82
# 11/11 - 0s - loss: 2.0357e-04 - val_loss: 0.0027 - 72ms/epoch - 7ms/step
# Epoch 38/82
# 11/11 - 0s - loss: 2.0148e-04 - val_loss: 0.0022 - 72ms/epoch - 7ms/step
# Epoch 39/82
# 11/11 - 0s - loss: 2.1231e-04 - val_loss: 0.0022 - 92ms/epoch - 8ms/step
# Epoch 40/82
# 11/11 - 0s - loss: 2.0494e-04 - val_loss: 0.0029 - 75ms/epoch - 7ms/step
# Epoch 41/82
# 11/11 - 0s - loss: 2.6268e-04 - val_loss: 0.0033 - 71ms/epoch - 6ms/step
# Epoch 42/82
# 11/11 - 0s - loss: 2.4635e-04 - val_loss: 0.0022 - 71ms/epoch - 6ms/step
# Epoch 43/82
# 11/11 - 0s - loss: 2.0823e-04 - val_loss: 0.0023 - 71ms/epoch - 6ms/step
# Epoch 44/82
# 11/11 - 0s - loss: 1.9554e-04 - val_loss: 0.0033 - 71ms/epoch - 6ms/step
# Epoch 45/82
# 11/11 - 0s - loss: 2.1124e-04 - val_loss: 0.0032 - 71ms/epoch - 6ms/step
# Epoch 46/82
# 11/11 - 0s - loss: 2.1190e-04 - val_loss: 0.0031 - 70ms/epoch - 6ms/step
# Epoch 47/82
# 11/11 - 0s - loss: 2.1568e-04 - val_loss: 0.0036 - 72ms/epoch - 7ms/step
# Epoch 48/82
# 11/11 - 0s - loss: 1.9963e-04 - val_loss: 0.0024 - 70ms/epoch - 6ms/step
# Epoch 49/82
# 11/11 - 0s - loss: 2.0150e-04 - val_loss: 0.0037 - 71ms/epoch - 6ms/step
# Epoch 50/82
# 11/11 - 0s - loss: 2.4177e-04 - val_loss: 0.0045 - 70ms/epoch - 6ms/step
# Epoch 51/82
# 11/11 - 0s - loss: 2.1835e-04 - val_loss: 0.0036 - 70ms/epoch - 6ms/step
# Epoch 52/82
# 11/11 - 0s - loss: 1.9486e-04 - val_loss: 0.0024 - 70ms/epoch - 6ms/step
# Epoch 53/82
# 11/11 - 0s - loss: 2.1532e-04 - val_loss: 0.0026 - 73ms/epoch - 7ms/step
# Epoch 54/82
# 11/11 - 0s - loss: 2.1147e-04 - val_loss: 0.0025 - 70ms/epoch - 6ms/step
# Epoch 55/82
# 11/11 - 0s - loss: 2.0037e-04 - val_loss: 0.0022 - 71ms/epoch - 6ms/step
# Epoch 56/82
# 11/11 - 0s - loss: 2.0312e-04 - val_loss: 0.0025 - 71ms/epoch - 6ms/step
# Epoch 57/82
# 11/11 - 0s - loss: 2.0661e-04 - val_loss: 0.0028 - 71ms/epoch - 6ms/step
# Epoch 58/82
# 11/11 - 0s - loss: 2.1939e-04 - val_loss: 0.0056 - 70ms/epoch - 6ms/step
# Epoch 59/82
# 11/11 - 0s - loss: 3.3630e-04 - val_loss: 0.0060 - 71ms/epoch - 6ms/step
# Epoch 60/82
# 11/11 - 0s - loss: 2.5940e-04 - val_loss: 0.0049 - 71ms/epoch - 6ms/step
# Epoch 61/82
# 11/11 - 0s - loss: 2.0634e-04 - val_loss: 0.0047 - 70ms/epoch - 6ms/step
# Epoch 62/82
# 11/11 - 0s - loss: 1.9701e-04 - val_loss: 0.0034 - 69ms/epoch - 6ms/step
# Epoch 63/82
# 11/11 - 0s - loss: 2.0001e-04 - val_loss: 0.0041 - 70ms/epoch - 6ms/step
# Epoch 64/82
# 11/11 - 0s - loss: 1.9610e-04 - val_loss: 0.0041 - 70ms/epoch - 6ms/step
# Epoch 65/82
# 11/11 - 0s - loss: 1.9367e-04 - val_loss: 0.0041 - 70ms/epoch - 6ms/step
# Epoch 66/82
# 11/11 - 0s - loss: 2.0259e-04 - val_loss: 0.0048 - 71ms/epoch - 6ms/step
# Epoch 67/82
# 11/11 - 0s - loss: 1.9846e-04 - val_loss: 0.0046 - 70ms/epoch - 6ms/step
# Epoch 68/82
# 11/11 - 0s - loss: 1.9559e-04 - val_loss: 0.0066 - 71ms/epoch - 6ms/step
# Epoch 69/82
# 11/11 - 0s - loss: 2.7062e-04 - val_loss: 0.0073 - 70ms/epoch - 6ms/step
# Epoch 70/82
# 11/11 - 0s - loss: 2.1466e-04 - val_loss: 0.0038 - 70ms/epoch - 6ms/step
# Epoch 71/82
# 11/11 - 0s - loss: 1.9644e-04 - val_loss: 0.0048 - 71ms/epoch - 6ms/step
# Epoch 72/82
# 11/11 - 0s - loss: 1.9008e-04 - val_loss: 0.0044 - 70ms/epoch - 6ms/step
# Epoch 73/82
# 11/11 - 0s - loss: 1.9442e-04 - val_loss: 0.0057 - 70ms/epoch - 6ms/step
# Epoch 74/82
# 11/11 - 0s - loss: 2.1886e-04 - val_loss: 0.0072 - 72ms/epoch - 7ms/step
# Epoch 75/82
# 11/11 - 0s - loss: 2.0745e-04 - val_loss: 0.0055 - 70ms/epoch - 6ms/step
# Epoch 76/82
# 11/11 - 0s - loss: 1.9891e-04 - val_loss: 0.0046 - 70ms/epoch - 6ms/step
# Epoch 77/82
# 11/11 - 0s - loss: 2.2038e-04 - val_loss: 0.0046 - 70ms/epoch - 6ms/step
# Epoch 78/82
# 11/11 - 0s - loss: 2.0116e-04 - val_loss: 0.0036 - 72ms/epoch - 7ms/step
# Epoch 79/82
# 11/11 - 0s - loss: 2.0137e-04 - val_loss: 0.0049 - 70ms/epoch - 6ms/step
# Epoch 80/82
# 11/11 - 0s - loss: 2.1774e-04 - val_loss: 0.0060 - 70ms/epoch - 6ms/step
# Epoch 81/82
# 11/11 - 0s - loss: 1.9501e-04 - val_loss: 0.0047 - 71ms/epoch - 6ms/step
# Epoch 82/82
# 11/11 - 0s - loss: 1.9503e-04 - val_loss: 0.0051 - 71ms/epoch - 6ms/step
# | 4         | -0.005112 | 63.45     | 0.1792    | 82.07     | 9.714     | 0.003203  | 98.46     |
# Epoch 1/17
# 3/3 - 4s - loss: 0.0097 - val_loss: 0.1607 - 4s/epoch - 1s/step
# Epoch 2/17
# 3/3 - 0s - loss: 0.0056 - val_loss: 0.1296 - 71ms/epoch - 24ms/step
# Epoch 3/17
# 3/3 - 0s - loss: 0.0028 - val_loss: 0.0984 - 53ms/epoch - 18ms/step
# Epoch 4/17
# 3/3 - 0s - loss: 0.0016 - val_loss: 0.0722 - 45ms/epoch - 15ms/step
# Epoch 5/17
# 3/3 - 0s - loss: 0.0022 - val_loss: 0.0600 - 46ms/epoch - 15ms/step
# Epoch 6/17
# 3/3 - 0s - loss: 0.0024 - val_loss: 0.0617 - 45ms/epoch - 15ms/step
# Epoch 7/17
# 3/3 - 0s - loss: 0.0019 - val_loss: 0.0693 - 46ms/epoch - 15ms/step
# Epoch 8/17
# 3/3 - 0s - loss: 0.0014 - val_loss: 0.0760 - 45ms/epoch - 15ms/step
# Epoch 9/17
# 3/3 - 0s - loss: 0.0014 - val_loss: 0.0772 - 47ms/epoch - 16ms/step
# Epoch 10/17
# 3/3 - 0s - loss: 0.0015 - val_loss: 0.0714 - 45ms/epoch - 15ms/step
# Epoch 11/17
# 3/3 - 0s - loss: 0.0013 - val_loss: 0.0598 - 46ms/epoch - 15ms/step
# Epoch 12/17
# 3/3 - 0s - loss: 0.0011 - val_loss: 0.0460 - 46ms/epoch - 15ms/step
# Epoch 13/17
# 3/3 - 0s - loss: 9.5393e-04 - val_loss: 0.0336 - 46ms/epoch - 15ms/step
# Epoch 14/17
# 3/3 - 0s - loss: 8.9022e-04 - val_loss: 0.0252 - 45ms/epoch - 15ms/step
# Epoch 15/17
# 3/3 - 0s - loss: 7.7065e-04 - val_loss: 0.0204 - 45ms/epoch - 15ms/step
# Epoch 16/17
# 3/3 - 0s - loss: 6.3906e-04 - val_loss: 0.0166 - 47ms/epoch - 16ms/step
# Epoch 17/17
# 3/3 - 0s - loss: 5.4351e-04 - val_loss: 0.0126 - 48ms/epoch - 16ms/step
# | 5         | -0.01261  | 228.3     | 0.4578    | 17.65     | 1.351     | 0.001781  | 116.3     |
# Epoch 1/96
# 12/12 - 4s - loss: 0.0037 - val_loss: 0.0999 - 4s/epoch - 315ms/step
# Epoch 2/96
# 12/12 - 0s - loss: 0.0016 - val_loss: 0.0414 - 65ms/epoch - 5ms/step
# Epoch 3/96
# 12/12 - 0s - loss: 7.7246e-04 - val_loss: 0.0033 - 65ms/epoch - 5ms/step
# Epoch 4/96
# 12/12 - 0s - loss: 4.0026e-04 - val_loss: 0.0084 - 65ms/epoch - 5ms/step
# Epoch 5/96
# 12/12 - 0s - loss: 3.8229e-04 - val_loss: 0.0048 - 65ms/epoch - 5ms/step
# Epoch 6/96
# 12/12 - 0s - loss: 3.2056e-04 - val_loss: 0.0043 - 66ms/epoch - 5ms/step
# Epoch 7/96
# 12/12 - 0s - loss: 3.0822e-04 - val_loss: 0.0039 - 66ms/epoch - 5ms/step
# Epoch 8/96
# 12/12 - 0s - loss: 2.8519e-04 - val_loss: 0.0047 - 65ms/epoch - 5ms/step
# Epoch 9/96
# 12/12 - 0s - loss: 2.6969e-04 - val_loss: 0.0050 - 64ms/epoch - 5ms/step
# Epoch 10/96
# 12/12 - 0s - loss: 2.5858e-04 - val_loss: 0.0055 - 65ms/epoch - 5ms/step
# Epoch 11/96
# 12/12 - 0s - loss: 2.7161e-04 - val_loss: 0.0066 - 65ms/epoch - 5ms/step
# Epoch 12/96
# 12/12 - 0s - loss: 2.5882e-04 - val_loss: 0.0063 - 64ms/epoch - 5ms/step
# Epoch 13/96
# 12/12 - 0s - loss: 2.6602e-04 - val_loss: 0.0088 - 66ms/epoch - 5ms/step
# Epoch 14/96
# 12/12 - 0s - loss: 2.5179e-04 - val_loss: 0.0081 - 65ms/epoch - 5ms/step
# Epoch 15/96
# 12/12 - 0s - loss: 2.8419e-04 - val_loss: 0.0072 - 64ms/epoch - 5ms/step
# Epoch 16/96
# 12/12 - 0s - loss: 2.6028e-04 - val_loss: 0.0095 - 65ms/epoch - 5ms/step
# Epoch 17/96
# 12/12 - 0s - loss: 2.3756e-04 - val_loss: 0.0086 - 64ms/epoch - 5ms/step
# Epoch 18/96
# 12/12 - 0s - loss: 2.2702e-04 - val_loss: 0.0104 - 66ms/epoch - 5ms/step
# Epoch 19/96
# 12/12 - 0s - loss: 2.3847e-04 - val_loss: 0.0082 - 65ms/epoch - 5ms/step
# Epoch 20/96
# 12/12 - 0s - loss: 2.2402e-04 - val_loss: 0.0078 - 63ms/epoch - 5ms/step
# Epoch 21/96
# 12/12 - 0s - loss: 2.1740e-04 - val_loss: 0.0091 - 63ms/epoch - 5ms/step
# Epoch 22/96
# 12/12 - 0s - loss: 2.2666e-04 - val_loss: 0.0097 - 62ms/epoch - 5ms/step
# Epoch 23/96
# 12/12 - 0s - loss: 2.3821e-04 - val_loss: 0.0098 - 64ms/epoch - 5ms/step
# Epoch 24/96
# 12/12 - 0s - loss: 2.1261e-04 - val_loss: 0.0097 - 65ms/epoch - 5ms/step
# Epoch 25/96
# 12/12 - 0s - loss: 2.2310e-04 - val_loss: 0.0104 - 63ms/epoch - 5ms/step
# Epoch 26/96
# 12/12 - 0s - loss: 2.3488e-04 - val_loss: 0.0093 - 66ms/epoch - 6ms/step
# Epoch 27/96
# 12/12 - 0s - loss: 2.1592e-04 - val_loss: 0.0091 - 65ms/epoch - 5ms/step
# Epoch 28/96
# 12/12 - 0s - loss: 2.1315e-04 - val_loss: 0.0098 - 65ms/epoch - 5ms/step
# Epoch 29/96
# 12/12 - 0s - loss: 2.1249e-04 - val_loss: 0.0103 - 87ms/epoch - 7ms/step
# Epoch 30/96
# 12/12 - 0s - loss: 2.3122e-04 - val_loss: 0.0091 - 68ms/epoch - 6ms/step
# Epoch 31/96
# 12/12 - 0s - loss: 2.2029e-04 - val_loss: 0.0113 - 63ms/epoch - 5ms/step
# Epoch 32/96
# 12/12 - 0s - loss: 2.1613e-04 - val_loss: 0.0104 - 63ms/epoch - 5ms/step
# Epoch 33/96
# 12/12 - 0s - loss: 2.1032e-04 - val_loss: 0.0102 - 63ms/epoch - 5ms/step
# Epoch 34/96
# 12/12 - 0s - loss: 2.1118e-04 - val_loss: 0.0106 - 64ms/epoch - 5ms/step
# Epoch 35/96
# 12/12 - 0s - loss: 2.0723e-04 - val_loss: 0.0102 - 63ms/epoch - 5ms/step
# Epoch 36/96
# 12/12 - 0s - loss: 2.0346e-04 - val_loss: 0.0106 - 67ms/epoch - 6ms/step
# Epoch 37/96
# 12/12 - 0s - loss: 2.2339e-04 - val_loss: 0.0107 - 64ms/epoch - 5ms/step
# Epoch 38/96
# 12/12 - 0s - loss: 2.1337e-04 - val_loss: 0.0110 - 64ms/epoch - 5ms/step
# Epoch 39/96
# 12/12 - 0s - loss: 2.0994e-04 - val_loss: 0.0112 - 64ms/epoch - 5ms/step
# Epoch 40/96
# 12/12 - 0s - loss: 2.0490e-04 - val_loss: 0.0121 - 64ms/epoch - 5ms/step
# Epoch 41/96
# 12/12 - 0s - loss: 2.2502e-04 - val_loss: 0.0106 - 64ms/epoch - 5ms/step
# Epoch 42/96
# 12/12 - 0s - loss: 2.2078e-04 - val_loss: 0.0109 - 63ms/epoch - 5ms/step
# Epoch 43/96
# 12/12 - 0s - loss: 2.0802e-04 - val_loss: 0.0120 - 63ms/epoch - 5ms/step
# Epoch 44/96
# 12/12 - 0s - loss: 2.0400e-04 - val_loss: 0.0122 - 63ms/epoch - 5ms/step
# Epoch 45/96
# 12/12 - 0s - loss: 2.1662e-04 - val_loss: 0.0116 - 65ms/epoch - 5ms/step
# Epoch 46/96
# 12/12 - 0s - loss: 2.2164e-04 - val_loss: 0.0116 - 64ms/epoch - 5ms/step
# Epoch 47/96
# 12/12 - 0s - loss: 2.0723e-04 - val_loss: 0.0123 - 63ms/epoch - 5ms/step
# Epoch 48/96
# 12/12 - 0s - loss: 2.0278e-04 - val_loss: 0.0129 - 64ms/epoch - 5ms/step
# Epoch 49/96
# 12/12 - 0s - loss: 1.9923e-04 - val_loss: 0.0146 - 63ms/epoch - 5ms/step
# Epoch 50/96
# 12/12 - 0s - loss: 2.0383e-04 - val_loss: 0.0145 - 63ms/epoch - 5ms/step
# Epoch 51/96
# 12/12 - 0s - loss: 2.1179e-04 - val_loss: 0.0148 - 63ms/epoch - 5ms/step
# Epoch 52/96
# 12/12 - 0s - loss: 2.2561e-04 - val_loss: 0.0120 - 64ms/epoch - 5ms/step
# Epoch 53/96
# 12/12 - 0s - loss: 2.1839e-04 - val_loss: 0.0158 - 64ms/epoch - 5ms/step
# Epoch 54/96
# 12/12 - 0s - loss: 1.9810e-04 - val_loss: 0.0125 - 64ms/epoch - 5ms/step
# Epoch 55/96
# 12/12 - 0s - loss: 2.0459e-04 - val_loss: 0.0151 - 63ms/epoch - 5ms/step
# Epoch 56/96
# 12/12 - 0s - loss: 2.1500e-04 - val_loss: 0.0152 - 64ms/epoch - 5ms/step
# Epoch 57/96
# 12/12 - 0s - loss: 2.1572e-04 - val_loss: 0.0129 - 64ms/epoch - 5ms/step
# Epoch 58/96
# 12/12 - 0s - loss: 2.0699e-04 - val_loss: 0.0163 - 64ms/epoch - 5ms/step
# Epoch 59/96
# 12/12 - 0s - loss: 2.0710e-04 - val_loss: 0.0176 - 63ms/epoch - 5ms/step
# Epoch 60/96
# 12/12 - 0s - loss: 1.9843e-04 - val_loss: 0.0150 - 63ms/epoch - 5ms/step
# Epoch 61/96
# 12/12 - 0s - loss: 2.1906e-04 - val_loss: 0.0207 - 63ms/epoch - 5ms/step
# Epoch 62/96
# 12/12 - 0s - loss: 2.1642e-04 - val_loss: 0.0133 - 63ms/epoch - 5ms/step
# Epoch 63/96
# 12/12 - 0s - loss: 2.1205e-04 - val_loss: 0.0183 - 63ms/epoch - 5ms/step
# Epoch 64/96
# 12/12 - 0s - loss: 1.9962e-04 - val_loss: 0.0167 - 63ms/epoch - 5ms/step
# Epoch 65/96
# 12/12 - 0s - loss: 1.9482e-04 - val_loss: 0.0155 - 64ms/epoch - 5ms/step
# Epoch 66/96
# 12/12 - 0s - loss: 1.9532e-04 - val_loss: 0.0173 - 64ms/epoch - 5ms/step
# Epoch 67/96
# 12/12 - 0s - loss: 2.1790e-04 - val_loss: 0.0194 - 63ms/epoch - 5ms/step
# Epoch 68/96
# 12/12 - 0s - loss: 2.6533e-04 - val_loss: 0.0137 - 64ms/epoch - 5ms/step
# Epoch 69/96
# 12/12 - 0s - loss: 2.7234e-04 - val_loss: 0.0225 - 64ms/epoch - 5ms/step
# Epoch 70/96
# 12/12 - 0s - loss: 2.2904e-04 - val_loss: 0.0152 - 63ms/epoch - 5ms/step
# Epoch 71/96
# 12/12 - 0s - loss: 2.1007e-04 - val_loss: 0.0168 - 64ms/epoch - 5ms/step
# Epoch 72/96
# 12/12 - 0s - loss: 2.1180e-04 - val_loss: 0.0186 - 62ms/epoch - 5ms/step
# Epoch 73/96
# 12/12 - 0s - loss: 2.0698e-04 - val_loss: 0.0160 - 64ms/epoch - 5ms/step
# Epoch 74/96
# 12/12 - 0s - loss: 2.1055e-04 - val_loss: 0.0209 - 63ms/epoch - 5ms/step
# Epoch 75/96
# 12/12 - 0s - loss: 2.3116e-04 - val_loss: 0.0187 - 64ms/epoch - 5ms/step
# Epoch 76/96
# 12/12 - 0s - loss: 2.2298e-04 - val_loss: 0.0191 - 63ms/epoch - 5ms/step
# Epoch 77/96
# 12/12 - 0s - loss: 2.1412e-04 - val_loss: 0.0205 - 64ms/epoch - 5ms/step
# Epoch 78/96
# 12/12 - 0s - loss: 1.9942e-04 - val_loss: 0.0195 - 63ms/epoch - 5ms/step
# Epoch 79/96
# 12/12 - 0s - loss: 1.9885e-04 - val_loss: 0.0184 - 64ms/epoch - 5ms/step
# Epoch 80/96
# 12/12 - 0s - loss: 2.0741e-04 - val_loss: 0.0221 - 63ms/epoch - 5ms/step
# Epoch 81/96
# 12/12 - 0s - loss: 2.1464e-04 - val_loss: 0.0212 - 63ms/epoch - 5ms/step
# Epoch 82/96
# 12/12 - 0s - loss: 2.0100e-04 - val_loss: 0.0222 - 89ms/epoch - 7ms/step
# Epoch 83/96
# 12/12 - 0s - loss: 2.0802e-04 - val_loss: 0.0227 - 66ms/epoch - 5ms/step
# Epoch 84/96
# 12/12 - 0s - loss: 1.9709e-04 - val_loss: 0.0227 - 64ms/epoch - 5ms/step
# Epoch 85/96
# 12/12 - 0s - loss: 2.0550e-04 - val_loss: 0.0239 - 63ms/epoch - 5ms/step
# Epoch 86/96
# 12/12 - 0s - loss: 2.0720e-04 - val_loss: 0.0247 - 65ms/epoch - 5ms/step
# Epoch 87/96
# 12/12 - 0s - loss: 2.0225e-04 - val_loss: 0.0224 - 63ms/epoch - 5ms/step
# Epoch 88/96
# 12/12 - 0s - loss: 2.0157e-04 - val_loss: 0.0253 - 65ms/epoch - 5ms/step
# Epoch 89/96
# 12/12 - 0s - loss: 2.2064e-04 - val_loss: 0.0217 - 64ms/epoch - 5ms/step
# Epoch 90/96
# 12/12 - 0s - loss: 2.1296e-04 - val_loss: 0.0219 - 65ms/epoch - 5ms/step
# Epoch 91/96
# 12/12 - 0s - loss: 2.0333e-04 - val_loss: 0.0217 - 64ms/epoch - 5ms/step
# Epoch 92/96
# 12/12 - 0s - loss: 2.2362e-04 - val_loss: 0.0259 - 68ms/epoch - 6ms/step
# Epoch 93/96
# 12/12 - 0s - loss: 2.4547e-04 - val_loss: 0.0288 - 69ms/epoch - 6ms/step
# Epoch 94/96
# 12/12 - 0s - loss: 2.3275e-04 - val_loss: 0.0265 - 64ms/epoch - 5ms/step
# Epoch 95/96
# 12/12 - 0s - loss: 2.0848e-04 - val_loss: 0.0306 - 65ms/epoch - 5ms/step
# Epoch 96/96
# 12/12 - 0s - loss: 2.2382e-04 - val_loss: 0.0284 - 64ms/epoch - 5ms/step
# | 6         | -0.02839  | 54.03     | 0.2684    | 96.21     | 5.798     | 0.00695   | 62.29     |
# Epoch 1/11
# 4/4 - 4s - loss: 0.0057 - val_loss: 0.0594 - 4s/epoch - 939ms/step
# Epoch 2/11
# 4/4 - 0s - loss: 0.0025 - val_loss: 0.1107 - 48ms/epoch - 12ms/step
# Epoch 3/11
# 4/4 - 0s - loss: 0.0022 - val_loss: 0.0533 - 48ms/epoch - 12ms/step
# Epoch 4/11
# 4/4 - 0s - loss: 0.0015 - val_loss: 0.0327 - 49ms/epoch - 12ms/step
# Epoch 5/11
# 4/4 - 0s - loss: 7.7392e-04 - val_loss: 0.0219 - 48ms/epoch - 12ms/step
# Epoch 6/11
# 4/4 - 0s - loss: 5.1826e-04 - val_loss: 0.0031 - 48ms/epoch - 12ms/step
# Epoch 7/11
# 4/4 - 0s - loss: 4.8159e-04 - val_loss: 0.0032 - 48ms/epoch - 12ms/step
# Epoch 8/11
# 4/4 - 0s - loss: 4.3668e-04 - val_loss: 0.0031 - 50ms/epoch - 12ms/step
# Epoch 9/11
# 4/4 - 0s - loss: 3.7722e-04 - val_loss: 0.0040 - 47ms/epoch - 12ms/step
# Epoch 10/11
# 4/4 - 0s - loss: 3.0718e-04 - val_loss: 0.0101 - 49ms/epoch - 12ms/step
# Epoch 11/11
# 4/4 - 0s - loss: 3.0212e-04 - val_loss: 0.0095 - 48ms/epoch - 12ms/step
# | 7         | -0.009475 | 185.8     | 0.4339    | 11.65     | 7.751     | 0.00989   | 103.8     |
# Epoch 1/19
# 7/7 - 4s - loss: 0.0051 - val_loss: 0.0788 - 4s/epoch - 539ms/step
# Epoch 2/19
# 7/7 - 0s - loss: 0.0023 - val_loss: 0.0965 - 52ms/epoch - 7ms/step
# Epoch 3/19
# 7/7 - 0s - loss: 0.0016 - val_loss: 0.0426 - 51ms/epoch - 7ms/step
# Epoch 4/19
# 7/7 - 0s - loss: 9.2802e-04 - val_loss: 0.0210 - 52ms/epoch - 7ms/step
# Epoch 5/19
# 7/7 - 0s - loss: 4.9336e-04 - val_loss: 0.0034 - 52ms/epoch - 7ms/step
# Epoch 6/19
# 7/7 - 0s - loss: 3.9742e-04 - val_loss: 0.0044 - 52ms/epoch - 7ms/step
# Epoch 7/19
# 7/7 - 0s - loss: 3.5973e-04 - val_loss: 0.0038 - 52ms/epoch - 7ms/step
# Epoch 8/19
# 7/7 - 0s - loss: 3.3938e-04 - val_loss: 0.0066 - 52ms/epoch - 7ms/step
# Epoch 9/19
# 7/7 - 0s - loss: 3.3519e-04 - val_loss: 0.0077 - 52ms/epoch - 7ms/step
# Epoch 10/19
# 7/7 - 0s - loss: 3.1811e-04 - val_loss: 0.0065 - 50ms/epoch - 7ms/step
# Epoch 11/19
# 7/7 - 0s - loss: 3.0058e-04 - val_loss: 0.0052 - 52ms/epoch - 7ms/step
# Epoch 12/19
# 7/7 - 0s - loss: 2.9779e-04 - val_loss: 0.0073 - 68ms/epoch - 10ms/step
# Epoch 13/19
# 7/7 - 0s - loss: 2.9121e-04 - val_loss: 0.0078 - 63ms/epoch - 9ms/step
# Epoch 14/19
# 7/7 - 0s - loss: 2.8603e-04 - val_loss: 0.0078 - 54ms/epoch - 8ms/step
# Epoch 15/19
# 7/7 - 0s - loss: 2.7712e-04 - val_loss: 0.0082 - 52ms/epoch - 7ms/step
# Epoch 16/19
# 7/7 - 0s - loss: 2.7971e-04 - val_loss: 0.0100 - 52ms/epoch - 7ms/step
# Epoch 17/19
# 7/7 - 0s - loss: 2.9155e-04 - val_loss: 0.0121 - 52ms/epoch - 7ms/step
# Epoch 18/19
# 7/7 - 0s - loss: 3.0754e-04 - val_loss: 0.0107 - 51ms/epoch - 7ms/step
# Epoch 19/19
# 7/7 - 0s - loss: 2.8448e-04 - val_loss: 0.0091 - 51ms/epoch - 7ms/step
# | 8         | -0.009108 | 94.82     | 0.4157    | 19.29     | 5.031     | 0.009095  | 60.19     |
# Epoch 1/11
# 7/7 - 5s - loss: 0.0077 - val_loss: 0.1359 - 5s/epoch - 647ms/step
# Epoch 2/11
# 7/7 - 0s - loss: 0.0023 - val_loss: 0.0831 - 53ms/epoch - 8ms/step
# Epoch 3/11
# 7/7 - 0s - loss: 0.0023 - val_loss: 0.0727 - 52ms/epoch - 7ms/step
# Epoch 4/11
# 7/7 - 0s - loss: 0.0017 - val_loss: 0.0841 - 51ms/epoch - 7ms/step
# Epoch 5/11
# 7/7 - 0s - loss: 0.0015 - val_loss: 0.0770 - 52ms/epoch - 7ms/step
# Epoch 6/11
# 7/7 - 0s - loss: 0.0013 - val_loss: 0.0519 - 53ms/epoch - 8ms/step
# Epoch 7/11
# 7/7 - 0s - loss: 9.9728e-04 - val_loss: 0.0306 - 52ms/epoch - 7ms/step
# Epoch 8/11
# 7/7 - 0s - loss: 7.8737e-04 - val_loss: 0.0170 - 52ms/epoch - 7ms/step
# Epoch 9/11
# 7/7 - 0s - loss: 5.3614e-04 - val_loss: 0.0064 - 52ms/epoch - 7ms/step
# Epoch 10/11
# 7/7 - 0s - loss: 3.8777e-04 - val_loss: 0.0041 - 52ms/epoch - 7ms/step
# Epoch 11/11
# 7/7 - 0s - loss: 3.1185e-04 - val_loss: 0.0091 - 52ms/epoch - 7ms/step
# | 9         | -0.009106 | 96.46     | 0.152     | 11.74     | 7.11      | 0.002195  | 57.49     |
# Epoch 1/61
# 5/5 - 4s - loss: 0.0054 - val_loss: 0.0572 - 4s/epoch - 760ms/step
# Epoch 2/61
# 5/5 - 0s - loss: 0.0028 - val_loss: 0.0904 - 53ms/epoch - 11ms/step
# Epoch 3/61
# 5/5 - 0s - loss: 0.0019 - val_loss: 0.0791 - 53ms/epoch - 11ms/step
# Epoch 4/61
# 5/5 - 0s - loss: 0.0012 - val_loss: 0.0319 - 52ms/epoch - 10ms/step
# Epoch 5/61
# 5/5 - 0s - loss: 9.0098e-04 - val_loss: 0.0203 - 52ms/epoch - 10ms/step
# Epoch 6/61
# 5/5 - 0s - loss: 4.8618e-04 - val_loss: 0.0050 - 53ms/epoch - 11ms/step
# Epoch 7/61
# 5/5 - 0s - loss: 3.4249e-04 - val_loss: 0.0058 - 76ms/epoch - 15ms/step
# Epoch 8/61
# 5/5 - 0s - loss: 3.3543e-04 - val_loss: 0.0049 - 57ms/epoch - 11ms/step
# Epoch 9/61
# 5/5 - 0s - loss: 3.2104e-04 - val_loss: 0.0047 - 53ms/epoch - 11ms/step
# Epoch 10/61
# 5/5 - 0s - loss: 2.8284e-04 - val_loss: 0.0036 - 55ms/epoch - 11ms/step
# Epoch 11/61
# 5/5 - 0s - loss: 2.7803e-04 - val_loss: 0.0044 - 58ms/epoch - 12ms/step
# Epoch 12/61
# 5/5 - 0s - loss: 2.7929e-04 - val_loss: 0.0046 - 55ms/epoch - 11ms/step
# Epoch 13/61
# 5/5 - 0s - loss: 2.6461e-04 - val_loss: 0.0042 - 54ms/epoch - 11ms/step
# Epoch 14/61
# 5/5 - 0s - loss: 2.6229e-04 - val_loss: 0.0030 - 53ms/epoch - 11ms/step
# Epoch 15/61
# 5/5 - 0s - loss: 2.4897e-04 - val_loss: 0.0030 - 52ms/epoch - 10ms/step
# Epoch 16/61
# 5/5 - 0s - loss: 2.5256e-04 - val_loss: 0.0028 - 52ms/epoch - 10ms/step
# Epoch 17/61
# 5/5 - 0s - loss: 2.4827e-04 - val_loss: 0.0032 - 53ms/epoch - 11ms/step
# Epoch 18/61
# 5/5 - 0s - loss: 2.5098e-04 - val_loss: 0.0032 - 51ms/epoch - 10ms/step
# Epoch 19/61
# 5/5 - 0s - loss: 2.4304e-04 - val_loss: 0.0032 - 55ms/epoch - 11ms/step
# Epoch 20/61
# 5/5 - 0s - loss: 2.4140e-04 - val_loss: 0.0031 - 54ms/epoch - 11ms/step
# Epoch 21/61
# 5/5 - 0s - loss: 2.4285e-04 - val_loss: 0.0031 - 53ms/epoch - 11ms/step
# Epoch 22/61
# 5/5 - 0s - loss: 2.3251e-04 - val_loss: 0.0027 - 52ms/epoch - 10ms/step
# Epoch 23/61
# 5/5 - 0s - loss: 2.3016e-04 - val_loss: 0.0028 - 54ms/epoch - 11ms/step
# Epoch 24/61
# 5/5 - 0s - loss: 2.3565e-04 - val_loss: 0.0027 - 53ms/epoch - 11ms/step
# Epoch 25/61
# 5/5 - 0s - loss: 2.3036e-04 - val_loss: 0.0032 - 53ms/epoch - 11ms/step
# Epoch 26/61
# 5/5 - 0s - loss: 2.3514e-04 - val_loss: 0.0027 - 52ms/epoch - 10ms/step
# Epoch 27/61
# 5/5 - 0s - loss: 2.3099e-04 - val_loss: 0.0030 - 53ms/epoch - 11ms/step
# Epoch 28/61
# 5/5 - 0s - loss: 2.3157e-04 - val_loss: 0.0028 - 53ms/epoch - 11ms/step
# Epoch 29/61
# 5/5 - 0s - loss: 2.1845e-04 - val_loss: 0.0028 - 52ms/epoch - 10ms/step
# Epoch 30/61
# 5/5 - 0s - loss: 2.2139e-04 - val_loss: 0.0030 - 53ms/epoch - 11ms/step
# Epoch 31/61
# 5/5 - 0s - loss: 2.1539e-04 - val_loss: 0.0026 - 53ms/epoch - 11ms/step
# Epoch 32/61
# 5/5 - 0s - loss: 2.1587e-04 - val_loss: 0.0031 - 53ms/epoch - 11ms/step
# Epoch 33/61
# 5/5 - 0s - loss: 2.2056e-04 - val_loss: 0.0025 - 52ms/epoch - 10ms/step
# Epoch 34/61
# 5/5 - 0s - loss: 2.2340e-04 - val_loss: 0.0031 - 53ms/epoch - 11ms/step
# Epoch 35/61
# 5/5 - 0s - loss: 2.1539e-04 - val_loss: 0.0025 - 53ms/epoch - 11ms/step
# Epoch 36/61
# 5/5 - 0s - loss: 2.1346e-04 - val_loss: 0.0025 - 53ms/epoch - 11ms/step
# Epoch 37/61
# 5/5 - 0s - loss: 2.1074e-04 - val_loss: 0.0030 - 55ms/epoch - 11ms/step
# Epoch 38/61
# 5/5 - 0s - loss: 2.0755e-04 - val_loss: 0.0024 - 55ms/epoch - 11ms/step
# Epoch 39/61
# 5/5 - 0s - loss: 2.1802e-04 - val_loss: 0.0025 - 53ms/epoch - 11ms/step
# Epoch 40/61
# 5/5 - 0s - loss: 2.0955e-04 - val_loss: 0.0027 - 53ms/epoch - 11ms/step
# Epoch 41/61
# 5/5 - 0s - loss: 2.0823e-04 - val_loss: 0.0024 - 57ms/epoch - 11ms/step
# Epoch 42/61
# 5/5 - 0s - loss: 1.9821e-04 - val_loss: 0.0029 - 55ms/epoch - 11ms/step
# Epoch 43/61
# 5/5 - 0s - loss: 2.0518e-04 - val_loss: 0.0027 - 53ms/epoch - 11ms/step
# Epoch 44/61
# 5/5 - 0s - loss: 1.9808e-04 - val_loss: 0.0026 - 53ms/epoch - 11ms/step
# Epoch 45/61
# 5/5 - 0s - loss: 2.0228e-04 - val_loss: 0.0029 - 53ms/epoch - 11ms/step
# Epoch 46/61
# 5/5 - 0s - loss: 2.0408e-04 - val_loss: 0.0024 - 52ms/epoch - 10ms/step
# Epoch 47/61
# 5/5 - 0s - loss: 2.0414e-04 - val_loss: 0.0025 - 53ms/epoch - 11ms/step
# Epoch 48/61
# 5/5 - 0s - loss: 2.0173e-04 - val_loss: 0.0031 - 53ms/epoch - 11ms/step
# Epoch 49/61
# 5/5 - 0s - loss: 2.2138e-04 - val_loss: 0.0025 - 53ms/epoch - 11ms/step
# Epoch 50/61
# 5/5 - 0s - loss: 2.0733e-04 - val_loss: 0.0026 - 53ms/epoch - 11ms/step
# Epoch 51/61
# 5/5 - 0s - loss: 1.9641e-04 - val_loss: 0.0026 - 53ms/epoch - 11ms/step
# Epoch 52/61
# 5/5 - 0s - loss: 2.0659e-04 - val_loss: 0.0028 - 53ms/epoch - 11ms/step
# Epoch 53/61
# 5/5 - 0s - loss: 2.0622e-04 - val_loss: 0.0026 - 54ms/epoch - 11ms/step
# Epoch 54/61
# 5/5 - 0s - loss: 1.9485e-04 - val_loss: 0.0024 - 53ms/epoch - 11ms/step
# Epoch 55/61
# 5/5 - 0s - loss: 1.9763e-04 - val_loss: 0.0027 - 53ms/epoch - 11ms/step
# Epoch 56/61
# 5/5 - 0s - loss: 1.9402e-04 - val_loss: 0.0025 - 71ms/epoch - 14ms/step
# Epoch 57/61
# 5/5 - 0s - loss: 1.9471e-04 - val_loss: 0.0027 - 62ms/epoch - 12ms/step
# Epoch 58/61
# 5/5 - 0s - loss: 1.9649e-04 - val_loss: 0.0026 - 54ms/epoch - 11ms/step
# Epoch 59/61
# 5/5 - 0s - loss: 1.9734e-04 - val_loss: 0.0030 - 52ms/epoch - 10ms/step
# Epoch 60/61
# 5/5 - 0s - loss: 2.0392e-04 - val_loss: 0.0033 - 53ms/epoch - 11ms/step
# Epoch 61/61
# 5/5 - 0s - loss: 2.1372e-04 - val_loss: 0.0032 - 52ms/epoch - 10ms/step
# | 10        | -0.003152 | 142.1     | 0.1213    | 61.67     | 2.321     | 0.005934  | 99.18     |
# Epoch 1/61
# 5/5 - 4s - loss: 0.0062 - val_loss: 0.0808 - 4s/epoch - 765ms/step
# Epoch 2/61
# 5/5 - 0s - loss: 0.0030 - val_loss: 0.0727 - 53ms/epoch - 11ms/step
# Epoch 3/61
# 5/5 - 0s - loss: 0.0017 - val_loss: 0.1001 - 52ms/epoch - 10ms/step
# Epoch 4/61
# 5/5 - 0s - loss: 0.0019 - val_loss: 0.0687 - 53ms/epoch - 11ms/step
# Epoch 5/61
# 5/5 - 0s - loss: 0.0011 - val_loss: 0.0317 - 52ms/epoch - 10ms/step
# Epoch 6/61
# 5/5 - 0s - loss: 9.6962e-04 - val_loss: 0.0209 - 53ms/epoch - 11ms/step
# Epoch 7/61
# 5/5 - 0s - loss: 5.4967e-04 - val_loss: 0.0077 - 51ms/epoch - 10ms/step
# Epoch 8/61
# 5/5 - 0s - loss: 3.2345e-04 - val_loss: 0.0050 - 53ms/epoch - 11ms/step
# Epoch 9/61
# 5/5 - 0s - loss: 3.2682e-04 - val_loss: 0.0063 - 52ms/epoch - 10ms/step
# Epoch 10/61
# 5/5 - 0s - loss: 3.4878e-04 - val_loss: 0.0069 - 53ms/epoch - 11ms/step
# Epoch 11/61
# 5/5 - 0s - loss: 3.0995e-04 - val_loss: 0.0042 - 52ms/epoch - 10ms/step
# Epoch 12/61
# 5/5 - 0s - loss: 2.9370e-04 - val_loss: 0.0031 - 52ms/epoch - 10ms/step
# Epoch 13/61
# 5/5 - 0s - loss: 2.8143e-04 - val_loss: 0.0031 - 52ms/epoch - 10ms/step
# Epoch 14/61
# 5/5 - 0s - loss: 2.8222e-04 - val_loss: 0.0036 - 52ms/epoch - 10ms/step
# Epoch 15/61
# 5/5 - 0s - loss: 2.8702e-04 - val_loss: 0.0031 - 53ms/epoch - 11ms/step
# Epoch 16/61
# 5/5 - 0s - loss: 2.7933e-04 - val_loss: 0.0028 - 53ms/epoch - 11ms/step
# Epoch 17/61
# 5/5 - 0s - loss: 2.8371e-04 - val_loss: 0.0028 - 54ms/epoch - 11ms/step
# Epoch 18/61
# 5/5 - 0s - loss: 2.6555e-04 - val_loss: 0.0029 - 52ms/epoch - 10ms/step
# Epoch 19/61
# 5/5 - 0s - loss: 2.7019e-04 - val_loss: 0.0028 - 54ms/epoch - 11ms/step
# Epoch 20/61
# 5/5 - 0s - loss: 2.5613e-04 - val_loss: 0.0027 - 55ms/epoch - 11ms/step
# Epoch 21/61
# 5/5 - 0s - loss: 2.6211e-04 - val_loss: 0.0031 - 53ms/epoch - 11ms/step
# Epoch 22/61
# 5/5 - 0s - loss: 2.5995e-04 - val_loss: 0.0029 - 51ms/epoch - 10ms/step
# Epoch 23/61
# 5/5 - 0s - loss: 2.4996e-04 - val_loss: 0.0029 - 53ms/epoch - 11ms/step
# Epoch 24/61
# 5/5 - 0s - loss: 2.6814e-04 - val_loss: 0.0027 - 53ms/epoch - 11ms/step
# Epoch 25/61
# 5/5 - 0s - loss: 2.5007e-04 - val_loss: 0.0027 - 52ms/epoch - 10ms/step
# Epoch 26/61
# 5/5 - 0s - loss: 2.3371e-04 - val_loss: 0.0026 - 52ms/epoch - 10ms/step
# Epoch 27/61
# 5/5 - 0s - loss: 2.3978e-04 - val_loss: 0.0026 - 52ms/epoch - 10ms/step
# Epoch 28/61
# 5/5 - 0s - loss: 2.4178e-04 - val_loss: 0.0027 - 52ms/epoch - 10ms/step
# Epoch 29/61
# 5/5 - 0s - loss: 2.3560e-04 - val_loss: 0.0027 - 53ms/epoch - 11ms/step
# Epoch 30/61
# 5/5 - 0s - loss: 2.3370e-04 - val_loss: 0.0028 - 53ms/epoch - 11ms/step
# Epoch 31/61
# 5/5 - 0s - loss: 2.2531e-04 - val_loss: 0.0027 - 53ms/epoch - 11ms/step
# Epoch 32/61
# 5/5 - 0s - loss: 2.3594e-04 - val_loss: 0.0026 - 53ms/epoch - 11ms/step
# Epoch 33/61
# 5/5 - 0s - loss: 2.2512e-04 - val_loss: 0.0025 - 53ms/epoch - 11ms/step
# Epoch 34/61
# 5/5 - 0s - loss: 2.2060e-04 - val_loss: 0.0027 - 51ms/epoch - 10ms/step
# Epoch 35/61
# 5/5 - 0s - loss: 2.4782e-04 - val_loss: 0.0025 - 53ms/epoch - 11ms/step
# Epoch 36/61
# 5/5 - 0s - loss: 2.4702e-04 - val_loss: 0.0031 - 53ms/epoch - 11ms/step
# Epoch 37/61
# 5/5 - 0s - loss: 2.3330e-04 - val_loss: 0.0029 - 53ms/epoch - 11ms/step
# Epoch 38/61
# 5/5 - 0s - loss: 2.2759e-04 - val_loss: 0.0026 - 53ms/epoch - 11ms/step
# Epoch 39/61
# 5/5 - 0s - loss: 2.1323e-04 - val_loss: 0.0027 - 53ms/epoch - 11ms/step
# Epoch 40/61
# 5/5 - 0s - loss: 2.1369e-04 - val_loss: 0.0023 - 80ms/epoch - 16ms/step
# Epoch 41/61
# 5/5 - 0s - loss: 2.3201e-04 - val_loss: 0.0028 - 59ms/epoch - 12ms/step
# Epoch 42/61
# 5/5 - 0s - loss: 2.1248e-04 - val_loss: 0.0025 - 53ms/epoch - 11ms/step
# Epoch 43/61
# 5/5 - 0s - loss: 2.2423e-04 - val_loss: 0.0032 - 52ms/epoch - 10ms/step
# Epoch 44/61
# 5/5 - 0s - loss: 2.3012e-04 - val_loss: 0.0030 - 52ms/epoch - 10ms/step
# Epoch 45/61
# 5/5 - 0s - loss: 2.2783e-04 - val_loss: 0.0025 - 55ms/epoch - 11ms/step
# Epoch 46/61
# 5/5 - 0s - loss: 2.1702e-04 - val_loss: 0.0028 - 53ms/epoch - 11ms/step
# Epoch 47/61
# 5/5 - 0s - loss: 2.1883e-04 - val_loss: 0.0024 - 52ms/epoch - 10ms/step
# Epoch 48/61
# 5/5 - 0s - loss: 2.1491e-04 - val_loss: 0.0029 - 52ms/epoch - 10ms/step
# Epoch 49/61
# 5/5 - 0s - loss: 2.1710e-04 - val_loss: 0.0026 - 53ms/epoch - 11ms/step
# Epoch 50/61
# 5/5 - 0s - loss: 2.2313e-04 - val_loss: 0.0029 - 53ms/epoch - 11ms/step
# Epoch 51/61
# 5/5 - 0s - loss: 2.0632e-04 - val_loss: 0.0025 - 52ms/epoch - 10ms/step
# Epoch 52/61
# 5/5 - 0s - loss: 2.1284e-04 - val_loss: 0.0026 - 53ms/epoch - 11ms/step
# Epoch 53/61
# 5/5 - 0s - loss: 2.0321e-04 - val_loss: 0.0025 - 52ms/epoch - 10ms/step
# Epoch 54/61
# 5/5 - 0s - loss: 2.1031e-04 - val_loss: 0.0023 - 53ms/epoch - 11ms/step
# Epoch 55/61
# 5/5 - 0s - loss: 2.0534e-04 - val_loss: 0.0029 - 53ms/epoch - 11ms/step
# Epoch 56/61
# 5/5 - 0s - loss: 2.0769e-04 - val_loss: 0.0029 - 53ms/epoch - 11ms/step
# Epoch 57/61
# 5/5 - 0s - loss: 1.9933e-04 - val_loss: 0.0027 - 56ms/epoch - 11ms/step
# Epoch 58/61
# 5/5 - 0s - loss: 2.0185e-04 - val_loss: 0.0025 - 54ms/epoch - 11ms/step
# Epoch 59/61
# 5/5 - 0s - loss: 2.1460e-04 - val_loss: 0.0023 - 54ms/epoch - 11ms/step
# Epoch 60/61
# 5/5 - 0s - loss: 2.0701e-04 - val_loss: 0.0035 - 53ms/epoch - 11ms/step
# Epoch 61/61
# 5/5 - 0s - loss: 2.0623e-04 - val_loss: 0.0031 - 54ms/epoch - 11ms/step
# | 11        | -0.003054 | 144.7     | 0.2992    | 61.08     | 1.637     | 0.004696  | 98.93     |
# Epoch 1/72
# 7/7 - 4s - loss: 0.0072 - val_loss: 0.1199 - 4s/epoch - 541ms/step
# Epoch 2/72
# 7/7 - 0s - loss: 0.0019 - val_loss: 0.0613 - 62ms/epoch - 9ms/step
# Epoch 3/72
# 7/7 - 0s - loss: 0.0021 - val_loss: 0.0697 - 62ms/epoch - 9ms/step
# Epoch 4/72
# 7/7 - 0s - loss: 0.0014 - val_loss: 0.0732 - 67ms/epoch - 10ms/step
# Epoch 5/72
# 7/7 - 0s - loss: 0.0012 - val_loss: 0.0438 - 85ms/epoch - 12ms/step
# Epoch 6/72
# 7/7 - 0s - loss: 8.2860e-04 - val_loss: 0.0216 - 64ms/epoch - 9ms/step
# Epoch 7/72
# 7/7 - 0s - loss: 5.6866e-04 - val_loss: 0.0118 - 62ms/epoch - 9ms/step
# Epoch 8/72
# 7/7 - 0s - loss: 3.8774e-04 - val_loss: 0.0034 - 64ms/epoch - 9ms/step
# Epoch 9/72
# 7/7 - 0s - loss: 3.0481e-04 - val_loss: 0.0044 - 63ms/epoch - 9ms/step
# Epoch 10/72
# 7/7 - 0s - loss: 2.9815e-04 - val_loss: 0.0053 - 64ms/epoch - 9ms/step
# Epoch 11/72
# 7/7 - 0s - loss: 2.9219e-04 - val_loss: 0.0046 - 62ms/epoch - 9ms/step
# Epoch 12/72
# 7/7 - 0s - loss: 2.8744e-04 - val_loss: 0.0032 - 62ms/epoch - 9ms/step
# Epoch 13/72
# 7/7 - 0s - loss: 2.8254e-04 - val_loss: 0.0030 - 63ms/epoch - 9ms/step
# Epoch 14/72
# 7/7 - 0s - loss: 2.7510e-04 - val_loss: 0.0030 - 63ms/epoch - 9ms/step
# Epoch 15/72
# 7/7 - 0s - loss: 2.6133e-04 - val_loss: 0.0030 - 63ms/epoch - 9ms/step
# Epoch 16/72
# 7/7 - 0s - loss: 2.7518e-04 - val_loss: 0.0031 - 64ms/epoch - 9ms/step
# Epoch 17/72
# 7/7 - 0s - loss: 2.6192e-04 - val_loss: 0.0030 - 63ms/epoch - 9ms/step
# Epoch 18/72
# 7/7 - 0s - loss: 2.6594e-04 - val_loss: 0.0031 - 64ms/epoch - 9ms/step
# Epoch 19/72
# 7/7 - 0s - loss: 2.7273e-04 - val_loss: 0.0028 - 63ms/epoch - 9ms/step
# Epoch 20/72
# 7/7 - 0s - loss: 2.5407e-04 - val_loss: 0.0029 - 63ms/epoch - 9ms/step
# Epoch 21/72
# 7/7 - 0s - loss: 2.6550e-04 - val_loss: 0.0028 - 63ms/epoch - 9ms/step
# Epoch 22/72
# 7/7 - 0s - loss: 2.6604e-04 - val_loss: 0.0030 - 63ms/epoch - 9ms/step
# Epoch 23/72
# 7/7 - 0s - loss: 2.5826e-04 - val_loss: 0.0027 - 64ms/epoch - 9ms/step
# Epoch 24/72
# 7/7 - 0s - loss: 2.5737e-04 - val_loss: 0.0028 - 64ms/epoch - 9ms/step
# Epoch 25/72
# 7/7 - 0s - loss: 2.3266e-04 - val_loss: 0.0027 - 64ms/epoch - 9ms/step
# Epoch 26/72
# 7/7 - 0s - loss: 2.4950e-04 - val_loss: 0.0029 - 63ms/epoch - 9ms/step
# Epoch 27/72
# 7/7 - 0s - loss: 2.4330e-04 - val_loss: 0.0027 - 63ms/epoch - 9ms/step
# Epoch 28/72
# 7/7 - 0s - loss: 2.4797e-04 - val_loss: 0.0027 - 63ms/epoch - 9ms/step
# Epoch 29/72
# 7/7 - 0s - loss: 2.3605e-04 - val_loss: 0.0026 - 63ms/epoch - 9ms/step
# Epoch 30/72
# 7/7 - 0s - loss: 2.4136e-04 - val_loss: 0.0026 - 62ms/epoch - 9ms/step
# Epoch 31/72
# 7/7 - 0s - loss: 2.3839e-04 - val_loss: 0.0025 - 63ms/epoch - 9ms/step
# Epoch 32/72
# 7/7 - 0s - loss: 2.3557e-04 - val_loss: 0.0027 - 62ms/epoch - 9ms/step
# Epoch 33/72
# 7/7 - 0s - loss: 2.3926e-04 - val_loss: 0.0025 - 63ms/epoch - 9ms/step
# Epoch 34/72
# 7/7 - 0s - loss: 2.2108e-04 - val_loss: 0.0026 - 62ms/epoch - 9ms/step
# Epoch 35/72
# 7/7 - 0s - loss: 2.3107e-04 - val_loss: 0.0024 - 63ms/epoch - 9ms/step
# Epoch 36/72
# 7/7 - 0s - loss: 2.3326e-04 - val_loss: 0.0024 - 63ms/epoch - 9ms/step
# Epoch 37/72
# 7/7 - 0s - loss: 2.2723e-04 - val_loss: 0.0024 - 63ms/epoch - 9ms/step
# Epoch 38/72
# 7/7 - 0s - loss: 2.1816e-04 - val_loss: 0.0024 - 63ms/epoch - 9ms/step
# Epoch 39/72
# 7/7 - 0s - loss: 2.1814e-04 - val_loss: 0.0025 - 63ms/epoch - 9ms/step
# Epoch 40/72
# 7/7 - 0s - loss: 2.1844e-04 - val_loss: 0.0024 - 62ms/epoch - 9ms/step
# Epoch 41/72
# 7/7 - 0s - loss: 2.1692e-04 - val_loss: 0.0023 - 63ms/epoch - 9ms/step
# Epoch 42/72
# 7/7 - 0s - loss: 2.1926e-04 - val_loss: 0.0023 - 63ms/epoch - 9ms/step
# Epoch 43/72
# 7/7 - 0s - loss: 2.1585e-04 - val_loss: 0.0022 - 65ms/epoch - 9ms/step
# Epoch 44/72
# 7/7 - 0s - loss: 2.1082e-04 - val_loss: 0.0023 - 64ms/epoch - 9ms/step
# Epoch 45/72
# 7/7 - 0s - loss: 2.1501e-04 - val_loss: 0.0023 - 63ms/epoch - 9ms/step
# Epoch 46/72
# 7/7 - 0s - loss: 2.2292e-04 - val_loss: 0.0022 - 63ms/epoch - 9ms/step
# Epoch 47/72
# 7/7 - 0s - loss: 2.2274e-04 - val_loss: 0.0023 - 62ms/epoch - 9ms/step
# Epoch 48/72
# 7/7 - 0s - loss: 2.2160e-04 - val_loss: 0.0022 - 63ms/epoch - 9ms/step
# Epoch 49/72
# 7/7 - 0s - loss: 2.1864e-04 - val_loss: 0.0023 - 63ms/epoch - 9ms/step
# Epoch 50/72
# 7/7 - 0s - loss: 2.2309e-04 - val_loss: 0.0022 - 64ms/epoch - 9ms/step
# Epoch 51/72
# 7/7 - 0s - loss: 2.0833e-04 - val_loss: 0.0022 - 63ms/epoch - 9ms/step
# Epoch 52/72
# 7/7 - 0s - loss: 2.0812e-04 - val_loss: 0.0021 - 62ms/epoch - 9ms/step
# Epoch 53/72
# 7/7 - 0s - loss: 2.1388e-04 - val_loss: 0.0021 - 61ms/epoch - 9ms/step
# Epoch 54/72
# 7/7 - 0s - loss: 1.9722e-04 - val_loss: 0.0021 - 63ms/epoch - 9ms/step
# Epoch 55/72
# 7/7 - 0s - loss: 2.0365e-04 - val_loss: 0.0021 - 62ms/epoch - 9ms/step
# Epoch 56/72
# 7/7 - 0s - loss: 2.0120e-04 - val_loss: 0.0021 - 62ms/epoch - 9ms/step
# Epoch 57/72
# 7/7 - 0s - loss: 2.0104e-04 - val_loss: 0.0021 - 85ms/epoch - 12ms/step
# Epoch 58/72
# 7/7 - 0s - loss: 2.0076e-04 - val_loss: 0.0021 - 65ms/epoch - 9ms/step
# Epoch 59/72
# 7/7 - 0s - loss: 2.0467e-04 - val_loss: 0.0021 - 63ms/epoch - 9ms/step
# Epoch 60/72
# 7/7 - 0s - loss: 2.0337e-04 - val_loss: 0.0021 - 63ms/epoch - 9ms/step
# Epoch 61/72
# 7/7 - 0s - loss: 2.0313e-04 - val_loss: 0.0021 - 63ms/epoch - 9ms/step
# Epoch 62/72
# 7/7 - 0s - loss: 1.9749e-04 - val_loss: 0.0022 - 62ms/epoch - 9ms/step
# Epoch 63/72
# 7/7 - 0s - loss: 2.0312e-04 - val_loss: 0.0020 - 62ms/epoch - 9ms/step
# Epoch 64/72
# 7/7 - 0s - loss: 2.0129e-04 - val_loss: 0.0020 - 63ms/epoch - 9ms/step
# Epoch 65/72
# 7/7 - 0s - loss: 1.9238e-04 - val_loss: 0.0021 - 63ms/epoch - 9ms/step
# Epoch 66/72
# 7/7 - 0s - loss: 2.0324e-04 - val_loss: 0.0020 - 62ms/epoch - 9ms/step
# Epoch 67/72
# 7/7 - 0s - loss: 2.0290e-04 - val_loss: 0.0021 - 63ms/epoch - 9ms/step
# Epoch 68/72
# 7/7 - 0s - loss: 2.0460e-04 - val_loss: 0.0020 - 62ms/epoch - 9ms/step
# Epoch 69/72
# 7/7 - 0s - loss: 2.0012e-04 - val_loss: 0.0020 - 62ms/epoch - 9ms/step
# Epoch 70/72
# 7/7 - 0s - loss: 2.0104e-04 - val_loss: 0.0020 - 62ms/epoch - 9ms/step
# Epoch 71/72
# 7/7 - 0s - loss: 1.9898e-04 - val_loss: 0.0020 - 62ms/epoch - 9ms/step
# Epoch 72/72
# 7/7 - 0s - loss: 1.9667e-04 - val_loss: 0.0021 - 62ms/epoch - 9ms/step
# | 12        | -0.002102 | 91.08     | 0.2312    | 72.89     | 8.034     | 0.001929  | 124.9     |
# Epoch 1/28
# 6/6 - 4s - loss: 0.0060 - val_loss: 0.0827 - 4s/epoch - 643ms/step
# Epoch 2/28
# 6/6 - 0s - loss: 0.0023 - val_loss: 0.0510 - 61ms/epoch - 10ms/step
# Epoch 3/28
# 6/6 - 0s - loss: 0.0015 - val_loss: 0.0763 - 61ms/epoch - 10ms/step
# Epoch 4/28
# 6/6 - 0s - loss: 0.0015 - val_loss: 0.0559 - 61ms/epoch - 10ms/step
# Epoch 5/28
# 6/6 - 0s - loss: 9.2550e-04 - val_loss: 0.0229 - 61ms/epoch - 10ms/step
# Epoch 6/28
# 6/6 - 0s - loss: 7.4445e-04 - val_loss: 0.0149 - 62ms/epoch - 10ms/step
# Epoch 7/28
# 6/6 - 0s - loss: 4.8163e-04 - val_loss: 0.0072 - 61ms/epoch - 10ms/step
# Epoch 8/28
# 6/6 - 0s - loss: 3.2117e-04 - val_loss: 0.0040 - 59ms/epoch - 10ms/step
# Epoch 9/28
# 6/6 - 0s - loss: 3.0616e-04 - val_loss: 0.0045 - 60ms/epoch - 10ms/step
# Epoch 10/28
# 6/6 - 0s - loss: 3.1179e-04 - val_loss: 0.0059 - 62ms/epoch - 10ms/step
# Epoch 11/28
# 6/6 - 0s - loss: 3.1326e-04 - val_loss: 0.0045 - 62ms/epoch - 10ms/step
# Epoch 12/28
# 6/6 - 0s - loss: 2.8955e-04 - val_loss: 0.0031 - 61ms/epoch - 10ms/step
# Epoch 13/28
# 6/6 - 0s - loss: 2.8456e-04 - val_loss: 0.0031 - 61ms/epoch - 10ms/step
# Epoch 14/28
# 6/6 - 0s - loss: 2.7344e-04 - val_loss: 0.0030 - 61ms/epoch - 10ms/step
# Epoch 15/28
# 6/6 - 0s - loss: 2.8019e-04 - val_loss: 0.0030 - 60ms/epoch - 10ms/step
# Epoch 16/28
# 6/6 - 0s - loss: 2.6502e-04 - val_loss: 0.0030 - 61ms/epoch - 10ms/step
# Epoch 17/28
# 6/6 - 0s - loss: 2.5405e-04 - val_loss: 0.0031 - 61ms/epoch - 10ms/step
# Epoch 18/28
# 6/6 - 0s - loss: 2.5177e-04 - val_loss: 0.0030 - 61ms/epoch - 10ms/step
# Epoch 19/28
# 6/6 - 0s - loss: 2.6124e-04 - val_loss: 0.0029 - 61ms/epoch - 10ms/step
# Epoch 20/28
# 6/6 - 0s - loss: 2.5563e-04 - val_loss: 0.0029 - 60ms/epoch - 10ms/step
# Epoch 21/28
# 6/6 - 0s - loss: 2.5472e-04 - val_loss: 0.0029 - 60ms/epoch - 10ms/step
# Epoch 22/28
# 6/6 - 0s - loss: 2.5970e-04 - val_loss: 0.0028 - 60ms/epoch - 10ms/step
# Epoch 23/28
# 6/6 - 0s - loss: 2.7528e-04 - val_loss: 0.0028 - 61ms/epoch - 10ms/step
# Epoch 24/28
# 6/6 - 0s - loss: 2.5553e-04 - val_loss: 0.0027 - 86ms/epoch - 14ms/step
# Epoch 25/28
# 6/6 - 0s - loss: 2.4975e-04 - val_loss: 0.0027 - 66ms/epoch - 11ms/step
# Epoch 26/28
# 6/6 - 0s - loss: 2.3731e-04 - val_loss: 0.0027 - 62ms/epoch - 10ms/step
# Epoch 27/28
# 6/6 - 0s - loss: 2.4900e-04 - val_loss: 0.0027 - 61ms/epoch - 10ms/step
# Epoch 28/28
# 6/6 - 0s - loss: 2.4546e-04 - val_loss: 0.0026 - 60ms/epoch - 10ms/step
# | 13        | -0.002625 | 109.3     | 0.227     | 28.38     | 3.166     | 0.002628  | 127.5     |
# Epoch 1/55
# 14/14 - 5s - loss: 0.0108 - val_loss: 0.1870 - 5s/epoch - 333ms/step
# Epoch 2/55
# 14/14 - 0s - loss: 0.0096 - val_loss: 0.1790 - 86ms/epoch - 6ms/step
# Epoch 3/55
# 14/14 - 0s - loss: 0.0085 - val_loss: 0.1708 - 85ms/epoch - 6ms/step
# Epoch 4/55
# 14/14 - 0s - loss: 0.0074 - val_loss: 0.1623 - 86ms/epoch - 6ms/step
# Epoch 5/55
# 14/14 - 0s - loss: 0.0064 - val_loss: 0.1535 - 85ms/epoch - 6ms/step
# Epoch 6/55
# 14/14 - 0s - loss: 0.0054 - val_loss: 0.1444 - 86ms/epoch - 6ms/step
# Epoch 7/55
# 14/14 - 0s - loss: 0.0045 - val_loss: 0.1347 - 88ms/epoch - 6ms/step
# Epoch 8/55
# 14/14 - 0s - loss: 0.0037 - val_loss: 0.1248 - 85ms/epoch - 6ms/step
# Epoch 9/55
# 14/14 - 0s - loss: 0.0030 - val_loss: 0.1149 - 86ms/epoch - 6ms/step
# Epoch 10/55
# 14/14 - 0s - loss: 0.0024 - val_loss: 0.1056 - 87ms/epoch - 6ms/step
# Epoch 11/55
# 14/14 - 0s - loss: 0.0020 - val_loss: 0.0969 - 87ms/epoch - 6ms/step
# Epoch 12/55
# 14/14 - 0s - loss: 0.0017 - val_loss: 0.0895 - 86ms/epoch - 6ms/step
# Epoch 13/55
# 14/14 - 0s - loss: 0.0016 - val_loss: 0.0832 - 87ms/epoch - 6ms/step
# Epoch 14/55
# 14/14 - 0s - loss: 0.0015 - val_loss: 0.0780 - 85ms/epoch - 6ms/step
# Epoch 15/55
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0740 - 86ms/epoch - 6ms/step
# Epoch 16/55
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0708 - 87ms/epoch - 6ms/step
# Epoch 17/55
# 14/14 - 0s - loss: 0.0013 - val_loss: 0.0679 - 85ms/epoch - 6ms/step
# Epoch 18/55
# 14/14 - 0s - loss: 0.0013 - val_loss: 0.0656 - 84ms/epoch - 6ms/step
# Epoch 19/55
# 14/14 - 0s - loss: 0.0013 - val_loss: 0.0636 - 84ms/epoch - 6ms/step
# Epoch 20/55
# 14/14 - 0s - loss: 0.0013 - val_loss: 0.0605 - 84ms/epoch - 6ms/step
# Epoch 21/55
# 14/14 - 0s - loss: 0.0012 - val_loss: 0.0581 - 85ms/epoch - 6ms/step
# Epoch 22/55
# 14/14 - 0s - loss: 0.0012 - val_loss: 0.0557 - 85ms/epoch - 6ms/step
# Epoch 23/55
# 14/14 - 0s - loss: 0.0011 - val_loss: 0.0533 - 88ms/epoch - 6ms/step
# Epoch 24/55
# 14/14 - 0s - loss: 0.0011 - val_loss: 0.0506 - 89ms/epoch - 6ms/step
# Epoch 25/55
# 14/14 - 0s - loss: 0.0011 - val_loss: 0.0480 - 84ms/epoch - 6ms/step
# Epoch 26/55
# 14/14 - 0s - loss: 0.0010 - val_loss: 0.0456 - 85ms/epoch - 6ms/step
# Epoch 27/55
# 14/14 - 0s - loss: 9.9772e-04 - val_loss: 0.0427 - 85ms/epoch - 6ms/step
# Epoch 28/55
# 14/14 - 0s - loss: 9.5957e-04 - val_loss: 0.0402 - 85ms/epoch - 6ms/step
# Epoch 29/55
# 14/14 - 0s - loss: 9.2976e-04 - val_loss: 0.0373 - 86ms/epoch - 6ms/step
# Epoch 30/55
# 14/14 - 0s - loss: 8.6875e-04 - val_loss: 0.0347 - 85ms/epoch - 6ms/step
# Epoch 31/55
# 14/14 - 0s - loss: 8.6009e-04 - val_loss: 0.0322 - 85ms/epoch - 6ms/step
# Epoch 32/55
# 14/14 - 0s - loss: 8.1263e-04 - val_loss: 0.0299 - 85ms/epoch - 6ms/step
# Epoch 33/55
# 14/14 - 0s - loss: 7.7683e-04 - val_loss: 0.0275 - 86ms/epoch - 6ms/step
# Epoch 34/55
# 14/14 - 0s - loss: 7.3725e-04 - val_loss: 0.0247 - 86ms/epoch - 6ms/step
# Epoch 35/55
# ...
# 3/3 - 0s - loss: 0.0088 - val_loss: 0.1751 - 48ms/epoch - 16ms/step
# Epoch 13/55
# 3/3 - 0s - loss: 0.0086 - val_loss: 0.1737 - 64ms/epoch - 21ms/step
# Epoch 14/55
# 3/3 - 0s - loss: 0.0084 - val_loss: 0.1722 - 50ms/epoch - 17ms/step
# Epoch 15/55
# 3/3 - 0s - loss: 0.0082 - val_loss: 0.1708 - 58ms/epoch - 19ms/step
# Epoch 16/55
# 3/3 - 0s - loss: 0.0080 - val_loss: 0.1694 - 47ms/epoch - 16ms/step
# Epoch 17/55
# 3/3 - 0s - loss: 0.0078 - val_loss: 0.1680 - 45ms/epoch - 15ms/step
# Epoch 18/55
# 3/3 - 0s - loss: 0.0076 - val_loss: 0.1666 - 46ms/epoch - 15ms/step
# Epoch 19/55
# 3/3 - 0s - loss: 0.0074 - val_loss: 0.1651 - 44ms/epoch - 15ms/step
# Epoch 20/55
# 3/3 - 0s - loss: 0.0072 - val_loss: 0.1637 - 54ms/epoch - 18ms/step
# Epoch 21/55
# 3/3 - 0s - loss: 0.0070 - val_loss: 0.1623 - 47ms/epoch - 16ms/step
# Epoch 22/55
# 3/3 - 0s - loss: 0.0069 - val_loss: 0.1608 - 45ms/epoch - 15ms/step
# Epoch 23/55
# 3/3 - 0s - loss: 0.0067 - val_loss: 0.1594 - 56ms/epoch - 19ms/step
# Epoch 24/55
# 3/3 - 0s - loss: 0.0065 - val_loss: 0.1579 - 48ms/epoch - 16ms/step
# Epoch 25/55
# 3/3 - 0s - loss: 0.0063 - val_loss: 0.1565 - 44ms/epoch - 15ms/step
# Epoch 26/55
# 3/3 - 0s - loss: 0.0062 - val_loss: 0.1550 - 42ms/epoch - 14ms/step
# Epoch 27/55
# 3/3 - 0s - loss: 0.0060 - val_loss: 0.1535 - 57ms/epoch - 19ms/step
# Epoch 28/55
# 3/3 - 0s - loss: 0.0059 - val_loss: 0.1521 - 49ms/epoch - 16ms/step
# Epoch 29/55
# 3/3 - 0s - loss: 0.0057 - val_loss: 0.1506 - 44ms/epoch - 15ms/step
# Epoch 30/55
# 3/3 - 0s - loss: 0.0055 - val_loss: 0.1491 - 46ms/epoch - 15ms/step
# Epoch 31/55
# 3/3 - 0s - loss: 0.0054 - val_loss: 0.1476 - 42ms/epoch - 14ms/step
# Epoch 32/55
# 3/3 - 0s - loss: 0.0052 - val_loss: 0.1462 - 55ms/epoch - 18ms/step
# Epoch 33/55
# 3/3 - 0s - loss: 0.0051 - val_loss: 0.1447 - 49ms/epoch - 16ms/step
# Epoch 34/55
# 3/3 - 0s - loss: 0.0049 - val_loss: 0.1432 - 43ms/epoch - 14ms/step
# Epoch 35/55
# 3/3 - 0s - loss: 0.0048 - val_loss: 0.1417 - 51ms/epoch - 17ms/step
# Epoch 36/55
# 3/3 - 0s - loss: 0.0046 - val_loss: 0.1402 - 60ms/epoch - 20ms/step
# Epoch 37/55
# 3/3 - 0s - loss: 0.0045 - val_loss: 0.1387 - 49ms/epoch - 16ms/step
# Epoch 38/55
# 3/3 - 0s - loss: 0.0043 - val_loss: 0.1371 - 56ms/epoch - 19ms/step
# Epoch 39/55
# 3/3 - 0s - loss: 0.0042 - val_loss: 0.1356 - 47ms/epoch - 16ms/step
# Epoch 40/55
# 3/3 - 0s - loss: 0.0041 - val_loss: 0.1341 - 43ms/epoch - 14ms/step
# Epoch 41/55
# 3/3 - 0s - loss: 0.0039 - val_loss: 0.1325 - 45ms/epoch - 15ms/step
# Epoch 42/55
# 3/3 - 0s - loss: 0.0038 - val_loss: 0.1310 - 43ms/epoch - 14ms/step
# Epoch 43/55
# 3/3 - 0s - loss: 0.0037 - val_loss: 0.1294 - 52ms/epoch - 17ms/step
# Epoch 44/55
# 3/3 - 0s - loss: 0.0036 - val_loss: 0.1279 - 50ms/epoch - 17ms/step
# Epoch 45/55
# 3/3 - 0s - loss: 0.0035 - val_loss: 0.1263 - 45ms/epoch - 15ms/step
# Epoch 46/55
# 3/3 - 0s - loss: 0.0033 - val_loss: 0.1248 - 42ms/epoch - 14ms/step
# Epoch 47/55
# 3/3 - 0s - loss: 0.0032 - val_loss: 0.1233 - 43ms/epoch - 14ms/step
# Epoch 48/55
# 3/3 - 0s - loss: 0.0031 - val_loss: 0.1218 - 58ms/epoch - 19ms/step
# Epoch 49/55
# 3/3 - 0s - loss: 0.0030 - val_loss: 0.1203 - 44ms/epoch - 15ms/step
# Epoch 50/55
# 3/3 - 0s - loss: 0.0029 - val_loss: 0.1188 - 44ms/epoch - 15ms/step
# Epoch 51/55
# 3/3 - 0s - loss: 0.0029 - val_loss: 0.1174 - 45ms/epoch - 15ms/step
# Epoch 52/55
# 3/3 - 0s - loss: 0.0028 - val_loss: 0.1159 - 50ms/epoch - 17ms/step
# Epoch 53/55
# 3/3 - 0s - loss: 0.0027 - val_loss: 0.1144 - 50ms/epoch - 17ms/step
# Epoch 54/55
# 3/3 - 0s - loss: 0.0026 - val_loss: 0.1130 - 47ms/epoch - 16ms/step
# Epoch 55/55
# 3/3 - 0s - loss: 0.0025 - val_loss: 0.1115 - 44ms/epoch - 15ms/step
# | 59        | -0.1115   | 256.0     | 0.1       | 55.81     | 1.0       | 0.0001    | 74.86     |
# Epoch 1/74
# 3/3 - 4s - loss: 0.0075 - val_loss: 0.0893 - 4s/epoch - 1s/step
# Epoch 2/74
# 3/3 - 0s - loss: 0.0028 - val_loss: 0.0621 - 59ms/epoch - 20ms/step
# Epoch 3/74
# 3/3 - 0s - loss: 0.0022 - val_loss: 0.1005 - 54ms/epoch - 18ms/step
# Epoch 4/74
# 3/3 - 0s - loss: 0.0022 - val_loss: 0.0916 - 48ms/epoch - 16ms/step
# Epoch 5/74
# 3/3 - 0s - loss: 0.0017 - val_loss: 0.0522 - 47ms/epoch - 16ms/step
# Epoch 6/74
# 3/3 - 0s - loss: 0.0014 - val_loss: 0.0313 - 47ms/epoch - 16ms/step
# Epoch 7/74
# 3/3 - 0s - loss: 0.0012 - val_loss: 0.0296 - 57ms/epoch - 19ms/step
# Epoch 8/74
# 3/3 - 0s - loss: 6.9544e-04 - val_loss: 0.0228 - 49ms/epoch - 16ms/step
# Epoch 9/74
# 3/3 - 0s - loss: 6.7618e-04 - val_loss: 0.0070 - 47ms/epoch - 16ms/step
# Epoch 10/74
# 3/3 - 0s - loss: 3.8075e-04 - val_loss: 0.0034 - 48ms/epoch - 16ms/step
# Epoch 11/74
# 3/3 - 0s - loss: 4.6479e-04 - val_loss: 0.0034 - 46ms/epoch - 15ms/step
# Epoch 12/74
# 3/3 - 0s - loss: 4.0013e-04 - val_loss: 0.0032 - 59ms/epoch - 20ms/step
# Epoch 13/74
# 3/3 - 0s - loss: 4.4659e-04 - val_loss: 0.0034 - 50ms/epoch - 17ms/step
# Epoch 14/74
# 3/3 - 0s - loss: 3.8335e-04 - val_loss: 0.0030 - 49ms/epoch - 16ms/step
# Epoch 15/74
# 3/3 - 0s - loss: 3.2233e-04 - val_loss: 0.0043 - 47ms/epoch - 16ms/step
# Epoch 16/74
# 3/3 - 0s - loss: 3.1246e-04 - val_loss: 0.0064 - 47ms/epoch - 16ms/step
# Epoch 17/74
# 3/3 - 0s - loss: 3.3920e-04 - val_loss: 0.0058 - 79ms/epoch - 26ms/step
# Epoch 18/74
# 3/3 - 0s - loss: 3.1809e-04 - val_loss: 0.0056 - 62ms/epoch - 21ms/step
# Epoch 19/74
# 3/3 - 0s - loss: 3.2030e-04 - val_loss: 0.0066 - 50ms/epoch - 17ms/step
# Epoch 20/74
# 3/3 - 0s - loss: 3.1552e-04 - val_loss: 0.0056 - 48ms/epoch - 16ms/step
# Epoch 21/74
# 3/3 - 0s - loss: 2.8797e-04 - val_loss: 0.0040 - 63ms/epoch - 21ms/step
# Epoch 22/74
# 3/3 - 0s - loss: 2.9637e-04 - val_loss: 0.0037 - 49ms/epoch - 16ms/step
# Epoch 23/74
# 3/3 - 0s - loss: 2.8395e-04 - val_loss: 0.0039 - 47ms/epoch - 16ms/step
# Epoch 24/74
# 3/3 - 0s - loss: 2.7578e-04 - val_loss: 0.0039 - 48ms/epoch - 16ms/step
# Epoch 25/74
# 3/3 - 0s - loss: 2.7051e-04 - val_loss: 0.0040 - 47ms/epoch - 16ms/step
# Epoch 26/74
# 3/3 - 0s - loss: 2.6851e-04 - val_loss: 0.0043 - 59ms/epoch - 20ms/step
# Epoch 27/74
# 3/3 - 0s - loss: 2.7134e-04 - val_loss: 0.0047 - 48ms/epoch - 16ms/step
# Epoch 28/74
# 3/3 - 0s - loss: 2.7419e-04 - val_loss: 0.0047 - 48ms/epoch - 16ms/step
# Epoch 29/74
# 3/3 - 0s - loss: 2.6977e-04 - val_loss: 0.0048 - 47ms/epoch - 16ms/step
# Epoch 30/74
# 3/3 - 0s - loss: 2.5863e-04 - val_loss: 0.0050 - 48ms/epoch - 16ms/step
# Epoch 31/74
# 3/3 - 0s - loss: 2.6984e-04 - val_loss: 0.0052 - 62ms/epoch - 21ms/step
# Epoch 32/74
# 3/3 - 0s - loss: 2.6201e-04 - val_loss: 0.0046 - 50ms/epoch - 17ms/step
# Epoch 33/74
# 3/3 - 0s - loss: 2.6158e-04 - val_loss: 0.0040 - 47ms/epoch - 16ms/step
# Epoch 34/74
# 3/3 - 0s - loss: 2.6005e-04 - val_loss: 0.0046 - 47ms/epoch - 16ms/step
# Epoch 35/74
# 3/3 - 0s - loss: 2.6690e-04 - val_loss: 0.0046 - 51ms/epoch - 17ms/step
# Epoch 36/74
# 3/3 - 0s - loss: 2.5213e-04 - val_loss: 0.0040 - 74ms/epoch - 25ms/step
# Epoch 37/74
# 3/3 - 0s - loss: 2.6062e-04 - val_loss: 0.0049 - 50ms/epoch - 17ms/step
# Epoch 38/74
# 3/3 - 0s - loss: 2.6823e-04 - val_loss: 0.0053 - 60ms/epoch - 20ms/step
# Epoch 39/74
# 3/3 - 0s - loss: 2.5597e-04 - val_loss: 0.0048 - 58ms/epoch - 19ms/step
# Epoch 40/74
# 3/3 - 0s - loss: 2.5624e-04 - val_loss: 0.0048 - 52ms/epoch - 17ms/step
# Epoch 41/74
# 3/3 - 0s - loss: 2.4837e-04 - val_loss: 0.0048 - 67ms/epoch - 22ms/step
# Epoch 42/74
# 3/3 - 0s - loss: 2.5403e-04 - val_loss: 0.0044 - 48ms/epoch - 16ms/step
# Epoch 43/74
# 3/3 - 0s - loss: 2.4074e-04 - val_loss: 0.0041 - 47ms/epoch - 16ms/step
# Epoch 44/74
# 3/3 - 0s - loss: 2.4262e-04 - val_loss: 0.0043 - 47ms/epoch - 16ms/step
# Epoch 45/74
# 3/3 - 0s - loss: 2.4295e-04 - val_loss: 0.0044 - 57ms/epoch - 19ms/step
# Epoch 46/74
# 3/3 - 0s - loss: 2.5095e-04 - val_loss: 0.0049 - 51ms/epoch - 17ms/step
# Epoch 47/74
# 3/3 - 0s - loss: 2.4747e-04 - val_loss: 0.0049 - 48ms/epoch - 16ms/step
# Epoch 48/74
# 3/3 - 0s - loss: 2.4152e-04 - val_loss: 0.0050 - 47ms/epoch - 16ms/step
# Epoch 49/74
# 3/3 - 0s - loss: 2.4086e-04 - val_loss: 0.0047 - 47ms/epoch - 16ms/step
# Epoch 50/74
# 3/3 - 0s - loss: 2.3019e-04 - val_loss: 0.0049 - 62ms/epoch - 21ms/step
# Epoch 51/74
# 3/3 - 0s - loss: 2.4563e-04 - val_loss: 0.0045 - 47ms/epoch - 16ms/step
# Epoch 52/74
# 3/3 - 0s - loss: 2.3400e-04 - val_loss: 0.0042 - 47ms/epoch - 16ms/step
# Epoch 53/74
# 3/3 - 0s - loss: 2.4059e-04 - val_loss: 0.0047 - 46ms/epoch - 15ms/step
# Epoch 54/74
# 3/3 - 0s - loss: 2.3686e-04 - val_loss: 0.0043 - 47ms/epoch - 16ms/step
# Epoch 55/74
# 3/3 - 0s - loss: 2.3721e-04 - val_loss: 0.0045 - 72ms/epoch - 24ms/step
# Epoch 56/74
# 3/3 - 0s - loss: 2.1645e-04 - val_loss: 0.0045 - 66ms/epoch - 22ms/step
# Epoch 57/74
# 3/3 - 0s - loss: 2.4840e-04 - val_loss: 0.0038 - 52ms/epoch - 17ms/step
# Epoch 58/74
# 3/3 - 0s - loss: 2.3772e-04 - val_loss: 0.0043 - 48ms/epoch - 16ms/step
# Epoch 59/74
# 3/3 - 0s - loss: 2.2511e-04 - val_loss: 0.0038 - 48ms/epoch - 16ms/step
# Epoch 60/74
# 3/3 - 0s - loss: 2.2273e-04 - val_loss: 0.0035 - 47ms/epoch - 16ms/step
# Epoch 61/74
# 3/3 - 0s - loss: 2.2322e-04 - val_loss: 0.0038 - 59ms/epoch - 20ms/step
# Epoch 62/74
# 3/3 - 0s - loss: 2.3527e-04 - val_loss: 0.0034 - 51ms/epoch - 17ms/step
# Epoch 63/74
# 3/3 - 0s - loss: 2.2756e-04 - val_loss: 0.0044 - 48ms/epoch - 16ms/step
# Epoch 64/74
# 3/3 - 0s - loss: 2.2285e-04 - val_loss: 0.0042 - 47ms/epoch - 16ms/step
# Epoch 65/74
# 3/3 - 0s - loss: 2.2201e-04 - val_loss: 0.0046 - 48ms/epoch - 16ms/step
# Epoch 66/74
# 3/3 - 0s - loss: 2.2564e-04 - val_loss: 0.0040 - 60ms/epoch - 20ms/step
# Epoch 67/74
# 3/3 - 0s - loss: 2.2172e-04 - val_loss: 0.0034 - 49ms/epoch - 16ms/step
# Epoch 68/74
# 3/3 - 0s - loss: 2.2498e-04 - val_loss: 0.0033 - 47ms/epoch - 16ms/step
# Epoch 69/74
# 3/3 - 0s - loss: 2.1900e-04 - val_loss: 0.0034 - 48ms/epoch - 16ms/step
# Epoch 70/74
# 3/3 - 0s - loss: 2.1676e-04 - val_loss: 0.0033 - 47ms/epoch - 16ms/step
# Epoch 71/74
# 3/3 - 0s - loss: 2.2486e-04 - val_loss: 0.0038 - 74ms/epoch - 25ms/step
# Epoch 72/74
# 3/3 - 0s - loss: 2.2135e-04 - val_loss: 0.0043 - 63ms/epoch - 21ms/step
# Epoch 73/74
# 3/3 - 0s - loss: 2.1091e-04 - val_loss: 0.0041 - 53ms/epoch - 18ms/step
# Epoch 74/74
# 3/3 - 0s - loss: 2.2502e-04 - val_loss: 0.0038 - 48ms/epoch - 16ms/step
# | 60        | -0.003758 | 245.2     | 0.5       | 74.37     | 7.189     | 0.006765  | 115.9     |
# =================================================================================================
# Training with optimized parameters...
# Epoch 1/72
# 7/7 - 5s - loss: 0.0065 - val_loss: 0.1061 - 5s/epoch - 674ms/step
# Epoch 2/72
# 7/7 - 0s - loss: 0.0020 - val_loss: 0.0543 - 64ms/epoch - 9ms/step
# Epoch 3/72
# 7/7 - 0s - loss: 0.0019 - val_loss: 0.0715 - 89ms/epoch - 13ms/step
# Epoch 4/72
# 7/7 - 0s - loss: 0.0014 - val_loss: 0.0697 - 71ms/epoch - 10ms/step
# Epoch 5/72
# 7/7 - 0s - loss: 0.0011 - val_loss: 0.0367 - 79ms/epoch - 11ms/step
# Epoch 6/72
# 7/7 - 0s - loss: 8.5912e-04 - val_loss: 0.0189 - 68ms/epoch - 10ms/step
# Epoch 7/72
# 7/7 - 0s - loss: 5.3319e-04 - val_loss: 0.0127 - 66ms/epoch - 9ms/step
# Epoch 8/72
# 7/7 - 0s - loss: 3.6993e-04 - val_loss: 0.0033 - 66ms/epoch - 9ms/step
# Epoch 9/72
# 7/7 - 0s - loss: 3.1563e-04 - val_loss: 0.0038 - 77ms/epoch - 11ms/step
# Epoch 10/72
# 7/7 - 0s - loss: 2.9447e-04 - val_loss: 0.0051 - 66ms/epoch - 9ms/step
# Epoch 11/72
# 7/7 - 0s - loss: 3.0244e-04 - val_loss: 0.0049 - 67ms/epoch - 10ms/step
# Epoch 12/72
# 7/7 - 0s - loss: 2.9050e-04 - val_loss: 0.0037 - 64ms/epoch - 9ms/step
# Epoch 13/72
# 7/7 - 0s - loss: 2.8127e-04 - val_loss: 0.0034 - 65ms/epoch - 9ms/step
# Epoch 14/72
# 7/7 - 0s - loss: 2.7708e-04 - val_loss: 0.0030 - 83ms/epoch - 12ms/step
# Epoch 15/72
# 7/7 - 0s - loss: 2.7872e-04 - val_loss: 0.0031 - 63ms/epoch - 9ms/step
# Epoch 16/72
# 7/7 - 0s - loss: 2.6741e-04 - val_loss: 0.0030 - 67ms/epoch - 10ms/step
# Epoch 17/72
# 7/7 - 0s - loss: 2.7268e-04 - val_loss: 0.0031 - 65ms/epoch - 9ms/step
# Epoch 18/72
# 7/7 - 0s - loss: 2.6975e-04 - val_loss: 0.0031 - 78ms/epoch - 11ms/step
# Epoch 19/72
# 7/7 - 0s - loss: 2.5611e-04 - val_loss: 0.0031 - 65ms/epoch - 9ms/step
# Epoch 20/72
# 7/7 - 0s - loss: 2.6267e-04 - val_loss: 0.0029 - 65ms/epoch - 9ms/step
# Epoch 21/72
# 7/7 - 0s - loss: 2.5593e-04 - val_loss: 0.0029 - 64ms/epoch - 9ms/step
# Epoch 22/72
# 7/7 - 0s - loss: 2.4547e-04 - val_loss: 0.0029 - 65ms/epoch - 9ms/step
# Epoch 23/72
# 7/7 - 0s - loss: 2.5070e-04 - val_loss: 0.0029 - 80ms/epoch - 11ms/step
# Epoch 24/72
# 7/7 - 0s - loss: 2.5087e-04 - val_loss: 0.0030 - 65ms/epoch - 9ms/step
# Epoch 25/72
# 7/7 - 0s - loss: 2.6072e-04 - val_loss: 0.0027 - 90ms/epoch - 13ms/step
# Epoch 26/72
# 7/7 - 0s - loss: 2.4699e-04 - val_loss: 0.0027 - 72ms/epoch - 10ms/step
# Epoch 27/72
# 7/7 - 0s - loss: 2.4602e-04 - val_loss: 0.0028 - 65ms/epoch - 9ms/step
# Epoch 28/72
# 7/7 - 0s - loss: 2.4752e-04 - val_loss: 0.0027 - 78ms/epoch - 11ms/step
# Epoch 29/72
# 7/7 - 0s - loss: 2.4570e-04 - val_loss: 0.0027 - 65ms/epoch - 9ms/step
# Epoch 30/72
# 7/7 - 0s - loss: 2.4690e-04 - val_loss: 0.0026 - 64ms/epoch - 9ms/step
# Epoch 31/72
# 7/7 - 0s - loss: 2.2528e-04 - val_loss: 0.0026 - 66ms/epoch - 9ms/step
# Epoch 32/72
# 7/7 - 0s - loss: 2.3196e-04 - val_loss: 0.0025 - 66ms/epoch - 9ms/step
# Epoch 33/72
# 7/7 - 0s - loss: 2.2676e-04 - val_loss: 0.0026 - 81ms/epoch - 12ms/step
# Epoch 34/72
# 7/7 - 0s - loss: 2.2727e-04 - val_loss: 0.0025 - 66ms/epoch - 9ms/step
# Epoch 35/72
# 7/7 - 0s - loss: 2.3569e-04 - val_loss: 0.0024 - 66ms/epoch - 9ms/step
# Epoch 36/72
# 7/7 - 0s - loss: 2.2808e-04 - val_loss: 0.0025 - 65ms/epoch - 9ms/step
# Epoch 37/72
# 7/7 - 0s - loss: 2.2581e-04 - val_loss: 0.0024 - 63ms/epoch - 9ms/step
# Epoch 38/72
# 7/7 - 0s - loss: 2.1918e-04 - val_loss: 0.0024 - 79ms/epoch - 11ms/step
# Epoch 39/72
# 7/7 - 0s - loss: 2.0799e-04 - val_loss: 0.0024 - 65ms/epoch - 9ms/step
# Epoch 40/72
# 7/7 - 0s - loss: 2.1212e-04 - val_loss: 0.0024 - 64ms/epoch - 9ms/step
# Epoch 41/72
# 7/7 - 0s - loss: 2.2197e-04 - val_loss: 0.0023 - 65ms/epoch - 9ms/step
# Epoch 42/72
# 7/7 - 0s - loss: 2.2839e-04 - val_loss: 0.0023 - 80ms/epoch - 11ms/step
# Epoch 43/72
# 7/7 - 0s - loss: 2.2438e-04 - val_loss: 0.0023 - 64ms/epoch - 9ms/step
# Epoch 44/72
# 7/7 - 0s - loss: 2.1364e-04 - val_loss: 0.0023 - 64ms/epoch - 9ms/step
# Epoch 45/72
# 7/7 - 0s - loss: 2.1004e-04 - val_loss: 0.0023 - 81ms/epoch - 12ms/step
# Epoch 46/72
# 7/7 - 0s - loss: 2.1769e-04 - val_loss: 0.0023 - 89ms/epoch - 13ms/step
# Epoch 47/72
# 7/7 - 0s - loss: 2.1758e-04 - val_loss: 0.0022 - 70ms/epoch - 10ms/step
# Epoch 48/72
# 7/7 - 0s - loss: 2.1574e-04 - val_loss: 0.0023 - 63ms/epoch - 9ms/step
# Epoch 49/72
# 7/7 - 0s - loss: 2.0560e-04 - val_loss: 0.0022 - 67ms/epoch - 10ms/step
# Epoch 50/72
# 7/7 - 0s - loss: 2.1150e-04 - val_loss: 0.0022 - 64ms/epoch - 9ms/step
# Epoch 51/72
# 7/7 - 0s - loss: 2.1553e-04 - val_loss: 0.0022 - 76ms/epoch - 11ms/step
# Epoch 52/72
# 7/7 - 0s - loss: 2.1014e-04 - val_loss: 0.0022 - 65ms/epoch - 9ms/step
# Epoch 53/72
# 7/7 - 0s - loss: 2.1224e-04 - val_loss: 0.0021 - 65ms/epoch - 9ms/step
# Epoch 54/72
# 7/7 - 0s - loss: 2.1683e-04 - val_loss: 0.0022 - 64ms/epoch - 9ms/step
# Epoch 55/72
# 7/7 - 0s - loss: 2.1883e-04 - val_loss: 0.0022 - 79ms/epoch - 11ms/step
# Epoch 56/72
# 7/7 - 0s - loss: 2.1306e-04 - val_loss: 0.0021 - 65ms/epoch - 9ms/step
# Epoch 57/72
# 7/7 - 0s - loss: 2.1359e-04 - val_loss: 0.0021 - 64ms/epoch - 9ms/step
# Epoch 58/72
# 7/7 - 0s - loss: 2.0705e-04 - val_loss: 0.0021 - 64ms/epoch - 9ms/step
# Epoch 59/72
# 7/7 - 0s - loss: 1.9948e-04 - val_loss: 0.0021 - 64ms/epoch - 9ms/step
# Epoch 60/72
# 7/7 - 0s - loss: 2.0113e-04 - val_loss: 0.0021 - 77ms/epoch - 11ms/step
# Epoch 61/72
# 7/7 - 0s - loss: 2.0881e-04 - val_loss: 0.0021 - 65ms/epoch - 9ms/step
# Epoch 62/72
# 7/7 - 0s - loss: 1.9891e-04 - val_loss: 0.0021 - 63ms/epoch - 9ms/step
# Epoch 63/72
# 7/7 - 0s - loss: 1.9365e-04 - val_loss: 0.0020 - 64ms/epoch - 9ms/step
# Epoch 64/72
# 7/7 - 0s - loss: 2.0295e-04 - val_loss: 0.0021 - 64ms/epoch - 9ms/step
# Epoch 65/72
# 7/7 - 0s - loss: 2.1827e-04 - val_loss: 0.0020 - 79ms/epoch - 11ms/step
# Epoch 66/72
# 7/7 - 0s - loss: 2.0840e-04 - val_loss: 0.0021 - 68ms/epoch - 10ms/step
# Epoch 67/72
# 7/7 - 0s - loss: 2.0068e-04 - val_loss: 0.0021 - 67ms/epoch - 10ms/step
# Epoch 68/72
# 7/7 - 0s - loss: 2.0308e-04 - val_loss: 0.0020 - 91ms/epoch - 13ms/step
# Epoch 69/72
# 7/7 - 0s - loss: 1.9969e-04 - val_loss: 0.0020 - 85ms/epoch - 12ms/step
# Epoch 70/72
# 7/7 - 0s - loss: 2.0453e-04 - val_loss: 0.0021 - 67ms/epoch - 10ms/step
# Epoch 71/72
# 7/7 - 0s - loss: 1.9650e-04 - val_loss: 0.0021 - 64ms/epoch - 9ms/step
# Epoch 72/72
# 7/7 - 0s - loss: 1.9522e-04 - val_loss: 0.0021 - 64ms/epoch - 9ms/step

# %%
# add early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

# save ensemble models
saved_models = []
for i in range(n_members):
    model.fit(trainX, trainY, validation_data=(testX, testY), epochs=100, verbose=0, callbacks=[early_stopping])
    filename = 'model_' + str(i + 1) + '.h5'
    model.save(filename)
    saved_models.append(filename)

# load models
members = [load_model(model) for model in saved_models]

# Get ensemble predictions
ensemble_predictions = np.zeros((testX.shape[0], 1))
for model in members:
    predictions = model.predict(testX)
    ensemble_predictions += predictions
ensemble_predictions /= len(members)

# Reshape ensemble predictions and apply inverse transformation
ensemble_predictions = scaler.inverse_transform(ensemble_predictions)
ensemble_testY = scaler.inverse_transform(testY.reshape(-1, 1))

# Get ensemble RMSE
ensemble_rmse = calculate_RMSE(ensemble_testY, ensemble_predictions)
print(f'Ensemble RMSE: {ensemble_rmse:.2f}')
# Out:
# 9/9 [==============================] - 1s 2ms/step
# 9/9 [==============================] - 1s 1ms/step
# 9/9 [==============================] - 1s 2ms/step
# 9/9 [==============================] - 1s 2ms/step
# 9/9 [==============================] - 1s 2ms/step
# Ensemble RMSE: 846.44

# %% [markdown]
# <h4>Forecast the results</h4>

# %%
def forecast_next_week(model, look_back, scaler, last_values, n_weeks):
    forecast = []
    input_values = np.array(last_values)
    for _ in range(n_weeks):
        input_values_scaled = scaler.transform(input_values[-look_back:].reshape(-1, 1))
        input_values_scaled = input_values_scaled.reshape((1, 1, look_back))
        prediction = model.predict(input_values_scaled)
        prediction = scaler.inverse_transform(prediction)
        forecast.append(prediction[0, 0])
        input_values = np.append(input_values, prediction)
    return forecast

# %%
# How many weeks you want to forecast
weeks = 12

# Get the last "look_back" values
last_values = list(agg_df['Rate'].values[-look_back:])

# Forecast the next weeks using the individual models
forecasted_values = []
for model in members:
    forecast = forecast_next_week(
        model, look_back, scaler, last_values, weeks)
    forecasted_values.append(forecast)

# Calculate the ensemble forecast by taking the average of individual forecasts
ensemble_forecast = np.mean(forecasted_values, axis=0)

# Get the last date from 'YearMonthWeek'
last_date = agg_df['YearMonthWeek'].iloc[-1]

# Create new dates
new_dates = pd.date_range(
    last_date + pd.DateOffset(weeks=1), periods=weeks, freq='W')

# Create a new DataFrame for the forecasted values
df_forecasted = pd.DataFrame(
    data={'POD': new_dates, 'RATE': ensemble_forecast})

# Rounding of the rate nearest 2 decimal points
df_forecasted["RATE"] = df_forecasted["RATE"].round(2)

df_forecasted.head(5)
df_forecasted.tail(5)
df_forecasted.info()
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
#          POD         RATE
# 0 2023-02-26  1694.550049
# 1 2023-03-05  1846.839966
# 2 2023-03-12  1739.530029
# 3 2023-03-19  1680.310059
# 4 2023-03-26  1629.670044
#           POD         RATE
# 7  2023-04-16  1610.339966
# 8  2023-04-23  1592.589966
# 9  2023-04-30  1571.680054
# 10 2023-05-07  1554.040039
# 11 2023-05-14  1539.609985
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POD     12 non-null     datetime64[ns]
#  1   RATE    12 non-null     float32
# dtypes: datetime64[ns](1), float32(1)
# memory usage: 272.0 bytes

# %% [markdown]
# <h4>Comparing with actual updated against forecasted</h4>

# %%
# Create an empty DataFrame to store comparison data
comparison_df = pd.DataFrame(columns=[
                             'WeekStart', 'WeekEnd', 'POD_actual', 'RATE_forecasted', 'RATE_actual', 'error', 'accuracy'])
df_forecasted['WeekEnd'] = df_forecasted['POD'] + pd.to_timedelta(7, unit='d')

# Loop over df_forecasted
for _, row in df_forecasted.iterrows():
    # Find the actual dates within the week of the forecasted date
    # Add a 'WeekEnd' column to df_forecasted
    mask = (new_dates_df['POD'] >= row['POD']) & (
        new_dates_df['POD'] < row['WeekEnd'])
    actual_dates_within_week = new_dates_df[mask]

    # Calculate the absolute error and accuracy for each actual date within the week
    for _, actual_row in actual_dates_within_week.iterrows():
        error = abs(actual_row['RATE'] - row['RATE'])
        error_proportion = error / actual_row['RATE']
        accuracy = (1 - error_proportion) * 100

        # Append the data to comparison_df
        comparison_df = comparison_df.append({
            'WeekStart': row['POD'],
            'WeekEnd': row['WeekEnd'],
            'POD_actual': actual_row['POD'],
            'RATE_forecasted': row['RATE'],
            'RATE_actual': actual_row['RATE'],
            'error': error,
            'accuracy': accuracy
        }, ignore_index=True)

# Remove duplicates based on 'POD_actual', 'RATE_forecasted', and 'RATE_actual'
comparison_df = comparison_df.drop_duplicates(
    subset=['POD_actual', 'RATE_forecasted', 'RATE_actual']).reset_index(drop=True)

# Display the comparison dataframe
comparison_df
comparison_df.info()

total_mean_accuracy = comparison_df['accuracy'].mean()
print(f'The mean accuracy is {total_mean_accuracy:.2f}%')
# Out:
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\295198027.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\295198027.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\295198027.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\295198027.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\295198027.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\295198027.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\295198027.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\295198027.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\295198027.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\295198027.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\295198027.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\295198027.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\295198027.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\295198027.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\295198027.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
# C:\Users\Aloysius Wong\AppData\Local\Temp\ipykernel_16700\295198027.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   comparison_df = comparison_df.append({
#     WeekStart    WeekEnd POD_actual  RATE_forecasted  RATE_actual  \
# 0  2023-03-05 2023-03-12 2023-03-10      1846.839966       1100.0
# 1  2023-03-12 2023-03-19 2023-03-14      1739.530029        986.0
# 2  2023-03-19 2023-03-26 2023-03-25      1680.310059       1972.0
# 3  2023-04-02 2023-04-09 2023-04-03      1619.560059        664.0
# 4  2023-04-02 2023-04-09 2023-04-08      1619.560059        664.0
# 5  2023-04-09 2023-04-16 2023-04-13      1623.520020        600.0
# 6  2023-04-16 2023-04-23 2023-04-16      1610.339966        664.0
# 7  2023-04-23 2023-04-30 2023-04-23      1592.589966        664.0
# 8  2023-04-30 2023-05-07 2023-05-02      1571.680054        350.0
# 9  2023-04-30 2023-05-07 2023-05-02      1571.680054        264.0
# 10 2023-05-07 2023-05-14 2023-05-08      1554.040039        264.0
#
#           error    accuracy
# 0    746.839966   32.105458
# 1    753.530029   23.577076
# 2    291.689941   85.208421
# 3    955.560059  -43.909647
# 4    955.560059  -43.909647
# 5   1023.520020  -70.586670
# 6    946.339966  -42.521079
# 7    928.589966  -39.847886
# 8   1221.680054 -249.051444
# 9   1307.680054 -395.333354
# 10  1290.040039 -388.651530
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   WeekStart        11 non-null     datetime64[ns]
#  1   WeekEnd          11 non-null     datetime64[ns]
#  2   POD_actual       11 non-null     datetime64[ns]
#  3   RATE_forecasted  11 non-null     float64
#  4   RATE_actual      11 non-null     float64
#  5   error            11 non-null     float64
#  6   accuracy         11 non-null     float64
# dtypes: datetime64[ns](3), float64(4)
# memory usage: 744.0 bytes
# The mean accuracy is -102.99%

# %%
# # Identify rows where accuracy is negative
# negative_accuracy_df = comparison_df[comparison_df['accuracy'] < 0]

# # Display these rows
# negative_accuracy_df

# # Check if error_proportion is greater than 1
# large_error_df = comparison_df[comparison_df['error'] /
#                                comparison_df['RATE_actual'] > 1]

# # Display these rows
# large_error_df

# %% [markdown]
# <h4>Visualise all, Conclusion</h4>

# %%
# plt.figure(figsize=(20, 10))
# plt.plot(sel_df['POD'], sel_df['RATE'], color='blue', label="Actual Data")
# plt.plot(new_dates_df['POD'], new_dates_df['RATE'],
#          color='blue', label="Actual Data (Updated)")

# plt.plot(df_interpolated['POD'], df_interpolated['RATE'],
#          color='green', label="Aggregated Data")
# plt.plot(df_forecasted['POD'], df_forecasted['RATE'],
#          color='red', label="Forecasted Data")

# plt.xlabel('Date(Year Month)')
# plt.ylabel('Cost Rate(USD)')
# plt.title(old_df[1])
# plt.legend()
# plt.show()
