# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline
sns.set()
pd.options.display.max_rows = 100


df = pd.read_csv('CR_FC_PREP_0522.csv', converters={'PARTY_ID': str, 'COM_ID': str})
df.head()
df.info()
print(f'Dataset size: {df.shape}')
# Out:
#    Unnamed: 0         POD  RATE COM_ID  PARTY_ID  PARTY_ID_EN  \
# 0           0  2005-07-15  1710    010  01008827      1008827
# 1           1  2005-07-16   862    010  01001867      1001867
# 2           2  2005-07-17   315    010  01004649      1004649
# 3           3  2005-07-18  3300    010  01008144      1008144
# 4           4  2005-07-19   850    010  01005136      1005136
#
#                                    PARTY_NAME           CSL_ID  ETA_ETD_NO  \
# 0             YANG MING (SINGAPORE) PTE. LTD.   ECS01050600224    20050715
# 1           DONGSUE CONSOLIDATION COMPANY LTD   ECS01050600325    20050716
# 2      M & P INTERNATIONAL CO LTD-HO CHI MINH  ECS010050700025    20050717
# 3                     TRANSLOGISTICS SA DE CV   ECS01050600497    20050718
# 4  MONDIALE FREIGHT SERVICES LIMITED-AUCKLAND   ECS01050600140    20050719
#
#   ETD_POL_D                       POD_ID           CNTR_ID  CNTR_SIZE  \
# ...

# %%
# View which is the most popular port using numpy
port_id, port_count = np.unique(df["POD_ID"], return_counts=True)
count_sort_ind = np.argsort(-port_count)
print(list(zip(port_id[count_sort_ind], port_count[count_sort_ind])))
print(len(port_id))
# Out:
# [('AUCKLAND', 304), ('MANILA (NORTH HARBOUR)', 214), ('MELBOURNE', 192), ('BUSAN', 190), ('SYDNEY', 174), ('PORT LOUIS', 145), ('FREMANTLE', 142), ('BANGKOK', 130), ('LAEM CHABANG', 127), ('DUBAI (JEBEL ALI)', 126), ('CAT LAI (HO CHI MINH)', 119), ('BRISBANE', 119), ('LYTTELTON', 110), ('HOCHIMINH CAT LAI,VIETNAM', 104), ('FELIXSTOWE', 95), ('PIRAEUS', 93), ('BARCELONA', 88), ('CEBU', 88), ('PENANG', 84), ('ADELAIDE', 84), ('LIMASSOL', 84), ('PASIR GUDANG', 81), ('MANZANILLO , MEXICO', 81), ('LE HAVRE', 80), ('VALPARAISO', 77), ('BEIRUT', 77), ('NHAVA SHEVA', 76), ('HAIPHONG', 75), ('COLOMBO', 72), ('NEW YORK', 61), ('MOMBASA', 61), ('MADRAS/CHENNAI', 61), ('SEMARANG', 59), ('KARACHI', 57), ('HONG KONG', 55), ('KOPER', 53), ('MARSEILLE', 53), ('TOKYO', 52), ('GDYNIA', 52), ('ISTANBUL(HAYDARPASA)', 52), ('DURBAN', 51), ('CALLAO', 51), ('HELSINKI', 50), ('DUBLIN', 47), ('YANGON (AWT)', 46), ('PRAGUE', 46), ('PORT KLANG (NORTH PORT)', 45), ('HAMBURG', 45), ('VALENCIA', 42), ('FOS SUR ME
# ...

# %% [markdown]
# <p>Auckland port is one of the biggest exports from Singapore</p>
